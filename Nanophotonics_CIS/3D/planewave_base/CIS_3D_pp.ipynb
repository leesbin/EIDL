# %%
# CIS 3D color router verification
# Find OE


# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
from matplotlib import pyplot as plt
import os

mp.verbosity(1)

design_dir = "./CIS_result/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=16)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 100 
gapop = 0 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, direction = mp.Z)]
Sourcespace = 1

# 전체 공간
Sx = design_region_width_x
Sy = design_region_width_y
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx, Sy, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')
# structure_weight = np.where(structure_weight < 0.5, 0.0, 1.0)
# np.savetxt('check.txt',structure_weight)


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(25)

# source 설정
width = 0.4

fcen_red = 1/(0.65*um_scale)
fwidth_red = fcen_red * width

fcen_green = 1/(0.55*um_scale)
fwidth_green = fcen_green * width

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = fcen_blue * width

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth=fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2 ] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]

# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * design_region_width_x)) + 1
Ny = int(round(design_region_resolution * design_region_width_y)) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, TiO2, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),

    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),

    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/4, Sy/4, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/4, -Sy/4, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/4, -Sy/4, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/4, Sy/4, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    )
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
print(Nz)
# Out:
# 51

# %%
###############################################################################################################################
# ## 2. Optimization Environment

# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    redfactor = 1.5
    greenfactor = 1.1
    bluefactor = 2
    return bluefactor * blue + greenfactor * green + redfactor * red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-5,
)

# %%
###############################################################################################################################

# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")
# Out:
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      block, center = (0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      block, center = (0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1.5)))
plt.savefig(design_dir+"LastdesignPD.png")
# Out:
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      block, center = (0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)

# %%
##############################################################################################################################
# ## 5. Optical Efficiency
opt.sim.reset_meep()

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center),mp.Source(src, component=mp.Ex, size=source_size, center=source_center)]
opt.sim.change_sources(source)

# %%
# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
#      block, center = (0,0,0)
#           size (2.8,2.8,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.60148e-05 s
# Working in 3D dimensions.
# Computational cell is 2.8 x 2.8 x 6 with resolution 100
#      block, center = (0,0,0)
#           size (2.8,2.8,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# subpixel-averaging is 29.5028% done, 9.55881 s remaining
# subpixel-averaging is 59.0501% done, 2.77402 s remaining
# subpixel-averaging is 88.5339% done, 0.518046 s remaining
# subpixel-averaging is 28.9601% done, 9.81228 s remaining
# subpixel-averaging is 58.1201% done, 2.88256 s remaining
# subpixel-averaging is 87.6579% done, 0.563254 s remaining
# subpixel-averaging is 29.2108% done, 9.6944 s remaining
# subpixel-averaging is 57.8948% done, 2.90919 s remaining
# subpixel-averaging is 87.1469% done, 0.590001 s remaining
# time for set_epsilon = 62.0927 s
# -----------
# on time step 1 (time=0.005), 10.1061 s/step
# on time step 7 (time=0.035), 0.755592 s/step
# on time step 13 (time=0.065), 0.735288 s/step
# on time step 19 (time=0.095), 0.721021 s/step
# on time step 25 (time=0.125), 0.728034 s/step
# on time step 31 (time=0.155), 0.729665 s/step
# on time step 37 (time=0.185), 0.751836 s/step
# on time step 43 (time=0.215), 0.739992 s/step
# on time step 49 (time=0.245), 0.762582 s/step
# on time step 55 (time=0.275), 0.760624 s/step
# on time step 61 (time=0.305), 0.781538 s/step
# on time step 65 (time=0.325), 1.0131 s/step
# on time step 70 (time=0.35), 0.974257 s/step
# on time step 74 (time=0.37), 1.12922 s/step
# on time step 79 (time=0.395), 0.978846 s/step
# on time step 84 (time=0.42), 0.980333 s/step
# on time step 89 (time=0.445), 0.979248 s/step
# on time step 94 (time=0.47), 0.960851 s/step
# on time step 99 (time=0.495), 0.957025 s/step
# on time step 104 (time=0.52), 0.978774 s/step
# on time step 109 (time=0.545), 0.941556 s/step
# on time step 114 (time=0.57), 0.955473 s/step
# on time step 119 (time=0.595), 0.95406 s/step
# on time step 123 (time=0.615), 1.0006 s/step
# on time step 128 (time=0.64), 0.985419 s/step
# on time step 133 (time=0.665), 0.803472 s/step
# on time step 138 (time=0.69), 0.986524 s/step
# on time step 143 (time=0.715), 0.994365 s/step
# on time step 147 (time=0.735), 1.14221 s/step
# on time step 152 (time=0.76), 0.981404 s/step
# on time step 157 (time=0.785), 0.962912 s/step
# on time step 162 (time=0.81), 1.00294 s/step
# on time step 166 (time=0.83), 1.00867 s/step
# on time step 171 (time=0.855), 0.977167 s/step
# on time step 176 (time=0.88), 0.968178 s/step
# on time step 181 (time=0.905), 0.955811 s/step
# on time step 186 (time=0.93), 0.950178 s/step
# on time step 191 (time=0.955), 0.990096 s/step
# on time step 196 (time=0.98), 0.964019 s/step
# on time step 201 (time=1.005), 0.952438 s/step
# on time step 206 (time=1.03), 0.958514 s/step
# on time step 211 (time=1.055), 0.952228 s/step
# on time step 216 (time=1.08), 0.969798 s/step
# on time step 220 (time=1.1), 1.12375 s/step
# on time step 225 (time=1.125), 0.988795 s/step
# on time step 230 (time=1.15), 0.984603 s/step
# on time step 235 (time=1.175), 0.976445 s/step
# on time step 240 (time=1.2), 0.942807 s/step
# on time step 245 (time=1.225), 0.981736 s/step
# on time step 250 (time=1.25), 0.985879 s/step
# on time step 255 (time=1.275), 0.976176 s/step
# on time step 260 (time=1.3), 0.966964 s/step
# on time step 265 (time=1.325), 0.981215 s/step
# on time step 270 (time=1.35), 0.97975 s/step
# on time step 275 (time=1.375), 0.975171 s/step
# on time step 280 (time=1.4), 0.959206 s/step
# on time step 285 (time=1.425), 0.817238 s/step
# on time step 290 (time=1.45), 0.939919 s/step
# on time step 294 (time=1.47), 1.13461 s/step
# on time step 299 (time=1.495), 1.00094 s/step
# on time step 304 (time=1.52), 0.97398 s/step
# on time step 309 (time=1.545), 0.991829 s/step
# on time step 314 (time=1.57), 0.977998 s/step
# on time step 319 (time=1.595), 0.994392 s/step
# on time step 324 (time=1.62), 0.977714 s/step
# on time step 329 (time=1.645), 0.978556 s/step
# on time step 334 (time=1.67), 0.979814 s/step
# on time step 339 (time=1.695), 0.97392 s/step
# on time step 344 (time=1.72), 0.967979 s/step
# on time step 349 (time=1.745), 0.9859 s/step
# on time step 354 (time=1.77), 0.994056 s/step
# on time step 359 (time=1.795), 0.984614 s/step
# on time step 364 (time=1.82), 0.969258 s/step
# on time step 368 (time=1.84), 1.11552 s/step
# on time step 373 (time=1.865), 0.980545 s/step
# on time step 378 (time=1.89), 0.98832 s/step
# on time step 383 (time=1.915), 0.978152 s/step
# on time step 388 (time=1.94), 0.988128 s/step
# on time step 392 (time=1.96), 1.00411 s/step
# on time step 396 (time=1.98), 1.0137 s/step
# on time step 400 (time=2), 1.00569 s/step
# on time step 405 (time=2.025), 0.985203 s/step
# on time step 410 (time=2.05), 0.988246 s/step
# on time step 415 (time=2.075), 0.934422 s/step
# on time step 419 (time=2.095), 1.01543 s/step
# on time step 423 (time=2.115), 1.03287 s/step
# on time step 427 (time=2.135), 1.03113 s/step
# on time step 431 (time=2.155), 1.0063 s/step
# on time step 436 (time=2.18), 0.988693 s/step
# on time step 440 (time=2.2), 1.13775 s/step
# on time step 446 (time=2.23), 0.760962 s/step
# on time step 451 (time=2.255), 0.84277 s/step
# on time step 456 (time=2.28), 0.92482 s/step
# on time step 461 (time=2.305), 0.931945 s/step
# on time step 466 (time=2.33), 0.920467 s/step
# on time step 471 (time=2.355), 0.918326 s/step
# on time step 476 (time=2.38), 0.892125 s/step
# on time step 481 (time=2.405), 0.985083 s/step
# on time step 485 (time=2.425), 1.01826 s/step
# on time step 490 (time=2.45), 0.891149 s/step
# on time step 495 (time=2.475), 0.88957 s/step
# on time step 500 (time=2.5), 0.883755 s/step
# on time step 505 (time=2.525), 0.873178 s/step
# on time step 510 (time=2.55), 0.885084 s/step
# on time step 514 (time=2.57), 1.01352 s/step
# on time step 519 (time=2.595), 0.913233 s/step
# on time step 524 (time=2.62), 0.906075 s/step
# on time step 529 (time=2.645), 0.930616 s/step
# on time step 534 (time=2.67), 0.91336 s/step
# on time step 539 (time=2.695), 0.910054 s/step
# on time step 544 (time=2.72), 0.910662 s/step
# on time step 549 (time=2.745), 0.915235 s/step
# on time step 554 (time=2.77), 0.902938 s/step
# on time step 559 (time=2.795), 0.904749 s/step
# on time step 564 (time=2.82), 0.89022 s/step
# on time step 569 (time=2.845), 0.886369 s/step
# on time step 574 (time=2.87), 0.879702 s/step
# on time step 579 (time=2.895), 0.887104 s/step
# on time step 584 (time=2.92), 0.985079 s/step
# on time step 589 (time=2.945), 0.889225 s/step
# on time step 594 (time=2.97), 0.876377 s/step
# on time step 599 (time=2.995), 0.893085 s/step
# on time step 604 (time=3.02), 0.889298 s/step
# on time step 609 (time=3.045), 0.877389 s/step
# on time step 614 (time=3.07), 0.884932 s/step
# on time step 619 (time=3.095), 0.897866 s/step
# on time step 624 (time=3.12), 0.87971 s/step
# on time step 629 (time=3.145), 0.875194 s/step
# on time step 634 (time=3.17), 0.885011 s/step
# on time step 639 (time=3.195), 0.884783 s/step
# on time step 644 (time=3.22), 0.885245 s/step
# on time step 649 (time=3.245), 0.88771 s/step
# on time step 654 (time=3.27), 0.886952 s/step
# on time step 658 (time=3.29), 1.00108 s/step
# on time step 663 (time=3.315), 0.879129 s/step
# on time step 668 (time=3.34), 0.894669 s/step
# on time step 673 (time=3.365), 0.895032 s/step
# on time step 678 (time=3.39), 0.810946 s/step
# on time step 684 (time=3.42), 0.776777 s/step
# on time step 690 (time=3.45), 0.702147 s/step
# on time step 696 (time=3.48), 0.70365 s/step
# on time step 702 (time=3.51), 0.703198 s/step
# on time step 708 (time=3.54), 0.690656 s/step
# on time step 714 (time=3.57), 0.717729 s/step
# on time step 720 (time=3.6), 0.707591 s/step
# on time step 726 (time=3.63), 0.671454 s/step
# on time step 732 (time=3.66), 0.736596 s/step
# on time step 738 (time=3.69), 0.67354 s/step
# on time step 745 (time=3.725), 0.660283 s/step
# on time step 752 (time=3.76), 0.660432 s/step
# on time step 759 (time=3.795), 0.658938 s/step
# on time step 766 (time=3.83), 0.666578 s/step
# on time step 773 (time=3.865), 0.668073 s/step
# on time step 779 (time=3.895), 0.672195 s/step
# on time step 786 (time=3.93), 0.6636 s/step
# on time step 792 (time=3.96), 0.671024 s/step
# on time step 799 (time=3.995), 0.663629 s/step
# on time step 805 (time=4.025), 0.729218 s/step
# on time step 811 (time=4.055), 0.674571 s/step
# on time step 817 (time=4.085), 0.669878 s/step
# on time step 824 (time=4.12), 0.666329 s/step
# on time step 831 (time=4.155), 0.661211 s/step
# on time step 837 (time=4.185), 0.672928 s/step
# on time step 843 (time=4.215), 0.680262 s/step
# on time step 850 (time=4.25), 0.669188 s/step
# on time step 856 (time=4.28), 0.67236 s/step
# on time step 863 (time=4.315), 0.661108 s/step
# on time step 869 (time=4.345), 0.66796 s/step
# on time step 875 (time=4.375), 0.670083 s/step
# on time step 881 (time=4.405), 0.736558 s/step
# on time step 887 (time=4.435), 0.673834 s/step
# on time step 893 (time=4.465), 0.669127 s/step
# on time step 900 (time=4.5), 0.664788 s/step
# on time step 906 (time=4.53), 0.671751 s/step
# on time step 913 (time=4.565), 0.662624 s/step
# on time step 919 (time=4.595), 0.674257 s/step
# on time step 925 (time=4.625), 0.667174 s/step
# on time step 931 (time=4.655), 0.669703 s/step
# on time step 938 (time=4.69), 0.659534 s/step
# on time step 945 (time=4.725), 0.656727 s/step
# on time step 951 (time=4.755), 0.727852 s/step
# on time step 958 (time=4.79), 0.668889 s/step
# on time step 964 (time=4.82), 0.67245 s/step
# on time step 971 (time=4.855), 0.665147 s/step
# on time step 978 (time=4.89), 0.660394 s/step
# on time step 985 (time=4.925), 0.657785 s/step
# on time step 991 (time=4.955), 0.668574 s/step
# on time step 997 (time=4.985), 0.673182 s/step
# on time step 1003 (time=5.015), 0.671952 s/step
# on time step 1009 (time=5.045), 0.672777 s/step
# on time step 1015 (time=5.075), 0.671245 s/step
# on time step 1021 (time=5.105), 0.676244 s/step
# on time step 1027 (time=5.135), 0.739721 s/step
# on time step 1033 (time=5.165), 0.675159 s/step
# on time step 1039 (time=5.195), 0.668515 s/step
# on time step 1046 (time=5.23), 0.662569 s/step
# on time step 1052 (time=5.26), 0.676429 s/step
# on time step 1058 (time=5.29), 0.667691 s/step
# on time step 1064 (time=5.32), 0.668582 s/step
# on time step 1070 (time=5.35), 0.674794 s/step
# on time step 1076 (time=5.38), 0.668683 s/step
# on time step 1082 (time=5.41), 0.668302 s/step
# on time step 1088 (time=5.44), 0.669523 s/step
# on time step 1095 (time=5.475), 0.723059 s/step
# on time step 1102 (time=5.51), 0.662234 s/step
# on time step 1108 (time=5.54), 0.67716 s/step
# on time step 1114 (time=5.57), 0.676792 s/step
# on time step 1121 (time=5.605), 0.657449 s/step
# on time step 1128 (time=5.64), 0.663791 s/step
# on time step 1134 (time=5.67), 0.671072 s/step
# on time step 1140 (time=5.7), 0.678572 s/step
# on time step 1147 (time=5.735), 0.666649 s/step
# on time step 1153 (time=5.765), 0.669792 s/step
# on time step 1159 (time=5.795), 0.676136 s/step
# on time step 1166 (time=5.83), 0.665701 s/step
# on time step 1172 (time=5.86), 0.747879 s/step
# on time step 1178 (time=5.89), 0.672602 s/step
# on time step 1185 (time=5.925), 0.663246 s/step
# on time step 1191 (time=5.955), 0.673835 s/step
# on time step 1197 (time=5.985), 0.667811 s/step
# on time step 1203 (time=6.015), 0.676875 s/step
# on time step 1209 (time=6.045), 0.670675 s/step
# on time step 1215 (time=6.075), 0.673846 s/step
# on time step 1222 (time=6.11), 0.665218 s/step
# on time step 1228 (time=6.14), 0.67327 s/step
# on time step 1234 (time=6.17), 0.671533 s/step
# on time step 1240 (time=6.2), 0.669978 s/step
# on time step 1246 (time=6.23), 0.735703 s/step
# on time step 1252 (time=6.26), 0.668689 s/step
# on time step 1259 (time=6.295), 0.664504 s/step
# on time step 1266 (time=6.33), 0.658107 s/step
# on time step 1272 (time=6.36), 0.667194 s/step
# on time step 1278 (time=6.39), 0.672664 s/step
# on time step 1284 (time=6.42), 0.667612 s/step
# on time step 1290 (time=6.45), 0.671215 s/step
# on time step 1296 (time=6.48), 0.674714 s/step
# on time step 1303 (time=6.515), 0.664821 s/step
# on time step 1309 (time=6.545), 0.67265 s/step
# on time step 1315 (time=6.575), 0.726007 s/step
# on time step 1321 (time=6.605), 0.670154 s/step
# on time step 1327 (time=6.635), 0.67486 s/step
# on time step 1333 (time=6.665), 0.670722 s/step
# on time step 1339 (time=6.695), 0.681586 s/step
# on time step 1345 (time=6.725), 0.752344 s/step
# on time step 1351 (time=6.755), 0.772988 s/step
# on time step 1357 (time=6.785), 0.757911 s/step
# on time step 1363 (time=6.815), 0.744105 s/step
# on time step 1369 (time=6.845), 0.685799 s/step
# on time step 1375 (time=6.875), 0.687531 s/step
# on time step 1381 (time=6.905), 0.725045 s/step
# on time step 1386 (time=6.93), 0.805613 s/step
# on time step 1391 (time=6.955), 0.814207 s/step
# on time step 1397 (time=6.985), 0.801397 s/step
# on time step 1402 (time=7.01), 0.832669 s/step
# on time step 1407 (time=7.035), 0.814202 s/step
# on time step 1413 (time=7.065), 0.683473 s/step
# on time step 1419 (time=7.095), 0.696188 s/step
# on time step 1425 (time=7.125), 0.76165 s/step
# on time step 1431 (time=7.155), 0.72714 s/step
# on time step 1437 (time=7.185), 0.69182 s/step
# on time step 1443 (time=7.215), 0.755095 s/step
# on time step 1449 (time=7.245), 0.727934 s/step
# on time step 1455 (time=7.275), 0.693798 s/step
# on time step 1460 (time=7.3), 0.840654 s/step
# on time step 1466 (time=7.33), 0.735754 s/step
# on time step 1472 (time=7.36), 0.692278 s/step
# on time step 1478 (time=7.39), 0.686214 s/step
# on time step 1484 (time=7.42), 0.689114 s/step
# on time step 1490 (time=7.45), 0.715776 s/step
# on time step 1496 (time=7.48), 0.745471 s/step
# on time step 1502 (time=7.51), 0.71441 s/step
# on time step 1508 (time=7.54), 0.66673 s/step
# on time step 1514 (time=7.57), 0.685103 s/step
# on time step 1519 (time=7.595), 0.807069 s/step
# on time step 1525 (time=7.625), 0.686382 s/step
# on time step 1530 (time=7.65), 0.840074 s/step
# on time step 1535 (time=7.675), 0.856268 s/step
# on time step 1541 (time=7.705), 0.706342 s/step
# on time step 1547 (time=7.735), 0.713912 s/step
# on time step 1553 (time=7.765), 0.698513 s/step
# on time step 1559 (time=7.795), 0.691338 s/step
# on time step 1565 (time=7.825), 0.670369 s/step
# on time step 1571 (time=7.855), 0.672795 s/step
# on time step 1577 (time=7.885), 0.802422 s/step
# on time step 1583 (time=7.915), 0.733149 s/step
# on time step 1589 (time=7.945), 0.799925 s/step
# on time step 1595 (time=7.975), 0.709191 s/step
# on time step 1601 (time=8.005), 0.70349 s/step
# on time step 1606 (time=8.03), 0.81203 s/step
# on time step 1611 (time=8.055), 0.839017 s/step
# on time step 1617 (time=8.085), 0.728189 s/step
# on time step 1624 (time=8.12), 0.668127 s/step
# on time step 1630 (time=8.15), 0.76469 s/step
# on time step 1636 (time=8.18), 0.682161 s/step
# on time step 1642 (time=8.21), 0.764179 s/step
# on time step 1648 (time=8.24), 0.667747 s/step
# on time step 1654 (time=8.27), 0.670779 s/step
# on time step 1661 (time=8.305), 0.661943 s/step
# on time step 1667 (time=8.335), 0.668278 s/step
# on time step 1673 (time=8.365), 0.677994 s/step
# on time step 1679 (time=8.395), 0.737648 s/step
# on time step 1685 (time=8.425), 0.666766 s/step
# on time step 1692 (time=8.46), 0.666602 s/step
# on time step 1698 (time=8.49), 0.668984 s/step
# on time step 1704 (time=8.52), 0.667114 s/step
# on time step 1710 (time=8.55), 0.671479 s/step
# on time step 1716 (time=8.58), 0.674121 s/step
# on time step 1722 (time=8.61), 0.669518 s/step
# on time step 1728 (time=8.64), 0.669934 s/step
# on time step 1735 (time=8.675), 0.66271 s/step
# on time step 1742 (time=8.71), 0.667619 s/step
# on time step 1748 (time=8.74), 0.669488 s/step
# on time step 1754 (time=8.77), 0.74727 s/step
# on time step 1761 (time=8.805), 0.66554 s/step
# on time step 1768 (time=8.84), 0.658077 s/step
# on time step 1774 (time=8.87), 0.674155 s/step
# on time step 1780 (time=8.9), 0.68015 s/step
# on time step 1787 (time=8.935), 0.658337 s/step
# on time step 1793 (time=8.965), 0.67792 s/step
# on time step 1799 (time=8.995), 0.666869 s/step
# on time step 1805 (time=9.025), 0.67513 s/step
# on time step 1811 (time=9.055), 0.674022 s/step
# on time step 1817 (time=9.085), 0.673098 s/step
# on time step 1823 (time=9.115), 0.677078 s/step
# on time step 1829 (time=9.145), 0.732009 s/step
# on time step 1835 (time=9.175), 0.666671 s/step
# on time step 1842 (time=9.21), 0.664029 s/step
# on time step 1848 (time=9.24), 0.667626 s/step
# on time step 1855 (time=9.275), 0.667558 s/step
# on time step 1862 (time=9.31), 0.660199 s/step
# on time step 1868 (time=9.34), 0.679965 s/step
# on time step 1874 (time=9.37), 0.690728 s/step
# on time step 1880 (time=9.4), 0.678733 s/step
# on time step 1886 (time=9.43), 0.723367 s/step
# on time step 1892 (time=9.46), 0.710003 s/step
# on time step 1898 (time=9.49), 0.756231 s/step
# on time step 1904 (time=9.52), 0.760379 s/step
# on time step 1909 (time=9.545), 0.805742 s/step
# on time step 1915 (time=9.575), 0.758901 s/step
# on time step 1920 (time=9.6), 0.80366 s/step
# on time step 1926 (time=9.63), 0.692354 s/step
# on time step 1932 (time=9.66), 0.697413 s/step
# on time step 1938 (time=9.69), 0.676704 s/step
# on time step 1945 (time=9.725), 0.662237 s/step
# on time step 1952 (time=9.76), 0.671918 s/step
# on time step 1958 (time=9.79), 0.672775 s/step
# on time step 1964 (time=9.82), 0.707716 s/step
# on time step 1970 (time=9.85), 0.676908 s/step
# on time step 1976 (time=9.88), 0.738361 s/step
# on time step 1983 (time=9.915), 0.664068 s/step
# on time step 1990 (time=9.95), 0.660534 s/step
# on time step 1996 (time=9.98), 0.670439 s/step
# field decay(t = 10.005): 0.07867996643775842 / 0.07867996643775842 = 1.0
# on time step 2002 (time=10.01), 0.672948 s/step
# on time step 2008 (time=10.04), 0.669023 s/step
# on time step 2014 (time=10.07), 0.672588 s/step
# on time step 2020 (time=10.1), 0.670956 s/step
# on time step 2026 (time=10.13), 0.676213 s/step
# on time step 2033 (time=10.165), 0.662548 s/step
# on time step 2039 (time=10.195), 0.674593 s/step
# on time step 2045 (time=10.225), 0.731885 s/step
# on time step 2052 (time=10.26), 0.658872 s/step
# on time step 2058 (time=10.29), 0.667705 s/step
# on time step 2064 (time=10.32), 0.694691 s/step
# on time step 2070 (time=10.35), 0.682267 s/step
# on time step 2076 (time=10.38), 0.69009 s/step
# on time step 2082 (time=10.41), 0.685669 s/step
# on time step 2088 (time=10.44), 0.690886 s/step
# on time step 2094 (time=10.47), 0.685858 s/step
# on time step 2100 (time=10.5), 0.679286 s/step
# on time step 2106 (time=10.53), 0.676591 s/step
# on time step 2113 (time=10.565), 0.66184 s/step
# on time step 2119 (time=10.595), 0.734589 s/step
# on time step 2125 (time=10.625), 0.669353 s/step
# on time step 2131 (time=10.655), 0.670964 s/step
# on time step 2137 (time=10.685), 0.738771 s/step
# on time step 2143 (time=10.715), 0.701971 s/step
# on time step 2149 (time=10.745), 0.718019 s/step
# on time step 2155 (time=10.775), 0.681852 s/step
# on time step 2162 (time=10.81), 0.662465 s/step
# on time step 2168 (time=10.84), 0.674749 s/step
# on time step 2174 (time=10.87), 0.688517 s/step
# on time step 2180 (time=10.9), 0.683887 s/step
# on time step 2186 (time=10.93), 0.679261 s/step
# on time step 2192 (time=10.96), 0.765664 s/step
# on time step 2199 (time=10.995), 0.584865 s/step
# on time step 2208 (time=11.04), 0.483898 s/step
# on time step 2217 (time=11.085), 0.491342 s/step
# on time step 2225 (time=11.125), 0.503425 s/step
# on time step 2234 (time=11.17), 0.484053 s/step
# on time step 2242 (time=11.21), 0.507629 s/step
# on time step 2250 (time=11.25), 0.507518 s/step
# on time step 2259 (time=11.295), 0.488587 s/step
# on time step 2267 (time=11.335), 0.544548 s/step
# on time step 2275 (time=11.375), 0.533374 s/step
# on time step 2283 (time=11.415), 0.574157 s/step
# on time step 2289 (time=11.445), 0.725614 s/step
# on time step 2295 (time=11.475), 0.743054 s/step
# on time step 2301 (time=11.505), 0.712962 s/step
# on time step 2307 (time=11.535), 0.678924 s/step
# on time step 2313 (time=11.565), 0.674715 s/step
# on time step 2319 (time=11.595), 0.689185 s/step
# on time step 2325 (time=11.625), 0.727793 s/step
# on time step 2331 (time=11.655), 0.730621 s/step
# on time step 2336 (time=11.68), 0.816362 s/step
# on time step 2342 (time=11.71), 0.742984 s/step
# on time step 2348 (time=11.74), 0.686255 s/step
# on time step 2354 (time=11.77), 0.721659 s/step
# on time step 2360 (time=11.8), 0.705862 s/step
# on time step 2366 (time=11.83), 0.694541 s/step
# on time step 2372 (time=11.86), 0.684517 s/step
# on time step 2378 (time=11.89), 0.670661 s/step
# on time step 2384 (time=11.92), 0.682162 s/step
# on time step 2391 (time=11.955), 0.666027 s/step
# on time step 2397 (time=11.985), 0.707021 s/step
# on time step 2403 (time=12.015), 0.757848 s/step
# on time step 2409 (time=12.045), 0.785916 s/step
# on time step 2415 (time=12.075), 0.669917 s/step
# on time step 2421 (time=12.105), 0.668144 s/step
# on time step 2427 (time=12.135), 0.69608 s/step
# on time step 2433 (time=12.165), 0.719153 s/step
# on time step 2439 (time=12.195), 0.691709 s/step
# on time step 2445 (time=12.225), 0.700655 s/step
# on time step 2451 (time=12.255), 0.708938 s/step
# on time step 2457 (time=12.285), 0.682329 s/step
# on time step 2463 (time=12.315), 0.674375 s/step
# on time step 2469 (time=12.345), 0.69382 s/step
# on time step 2475 (time=12.375), 0.71931 s/step
# on time step 2481 (time=12.405), 0.677399 s/step
# on time step 2487 (time=12.435), 0.750067 s/step
# on time step 2493 (time=12.465), 0.685357 s/step
# on time step 2499 (time=12.495), 0.685129 s/step
# on time step 2505 (time=12.525), 0.692313 s/step
# on time step 2511 (time=12.555), 0.721019 s/step
# on time step 2517 (time=12.585), 0.701289 s/step
# on time step 2523 (time=12.615), 0.69537 s/step
# on time step 2529 (time=12.645), 0.728919 s/step
# on time step 2535 (time=12.675), 0.683022 s/step
# on time step 2541 (time=12.705), 0.682286 s/step
# on time step 2547 (time=12.735), 0.711133 s/step
# on time step 2553 (time=12.765), 0.726018 s/step
# on time step 2559 (time=12.795), 0.762319 s/step
# on time step 2565 (time=12.825), 0.707092 s/step
# on time step 2571 (time=12.855), 0.689143 s/step
# on time step 2577 (time=12.885), 0.669011 s/step
# on time step 2583 (time=12.915), 0.677889 s/step
# on time step 2589 (time=12.945), 0.687885 s/step
# on time step 2595 (time=12.975), 0.725666 s/step
# on time step 2601 (time=13.005), 0.708702 s/step
# on time step 2607 (time=13.035), 0.780559 s/step
# on time step 2613 (time=13.065), 0.757182 s/step
# on time step 2619 (time=13.095), 0.781638 s/step
# on time step 2625 (time=13.125), 0.725061 s/step
# on time step 2630 (time=13.15), 0.824584 s/step
# on time step 2636 (time=13.18), 0.708953 s/step
# on time step 2642 (time=13.21), 0.744283 s/step
# on time step 2648 (time=13.24), 0.726247 s/step
# on time step 2654 (time=13.27), 0.697999 s/step
# on time step 2660 (time=13.3), 0.694445 s/step
# on time step 2666 (time=13.33), 0.68349 s/step
# on time step 2672 (time=13.36), 0.717191 s/step
# on time step 2678 (time=13.39), 0.741352 s/step
# on time step 2684 (time=13.42), 0.772692 s/step
# on time step 2690 (time=13.45), 0.692781 s/step
# on time step 2696 (time=13.48), 0.681894 s/step
# on time step 2701 (time=13.505), 0.867219 s/step
# on time step 2707 (time=13.535), 0.761224 s/step
# on time step 2713 (time=13.565), 0.76771 s/step
# on time step 2719 (time=13.595), 0.754979 s/step
# on time step 2725 (time=13.625), 0.694322 s/step
# on time step 2731 (time=13.655), 0.694231 s/step
# on time step 2737 (time=13.685), 0.674406 s/step
# on time step 2743 (time=13.715), 0.698477 s/step
# on time step 2749 (time=13.745), 0.671946 s/step
# on time step 2755 (time=13.775), 0.692217 s/step
# on time step 2761 (time=13.805), 0.744139 s/step
# on time step 2767 (time=13.835), 0.686736 s/step
# on time step 2773 (time=13.865), 0.740083 s/step
# on time step 2778 (time=13.89), 0.807463 s/step
# on time step 2784 (time=13.92), 0.744319 s/step
# on time step 2790 (time=13.95), 0.700476 s/step
# on time step 2796 (time=13.98), 0.695641 s/step
# on time step 2802 (time=14.01), 0.718035 s/step
# on time step 2808 (time=14.04), 0.703706 s/step
# on time step 2814 (time=14.07), 0.710476 s/step
# on time step 2820 (time=14.1), 0.70041 s/step
# on time step 2826 (time=14.13), 0.701963 s/step
# on time step 2832 (time=14.16), 0.733817 s/step
# on time step 2838 (time=14.19), 0.747175 s/step
# on time step 2844 (time=14.22), 0.719967 s/step
# on time step 2850 (time=14.25), 0.769169 s/step
# on time step 2856 (time=14.28), 0.679274 s/step
# on time step 2862 (time=14.31), 0.673966 s/step
# on time step 2868 (time=14.34), 0.669403 s/step
# on time step 2874 (time=14.37), 0.71254 s/step
# on time step 2880 (time=14.4), 0.717342 s/step
# on time step 2885 (time=14.425), 0.800927 s/step
# on time step 2891 (time=14.455), 0.683945 s/step
# on time step 2897 (time=14.485), 0.694257 s/step
# on time step 2903 (time=14.515), 0.726894 s/step
# on time step 2909 (time=14.545), 0.715352 s/step
# on time step 2915 (time=14.575), 0.71255 s/step
# on time step 2920 (time=14.6), 0.817474 s/step
# on time step 2926 (time=14.63), 0.730675 s/step
# on time step 2932 (time=14.66), 0.724578 s/step
# on time step 2938 (time=14.69), 0.692279 s/step
# on time step 2944 (time=14.72), 0.716498 s/step
# on time step 2950 (time=14.75), 0.698792 s/step
# on time step 2956 (time=14.78), 0.67408 s/step
# on time step 2962 (time=14.81), 0.697788 s/step
# on time step 2968 (time=14.84), 0.680596 s/step
# on time step 2974 (time=14.87), 0.693952 s/step
# on time step 2980 (time=14.9), 0.696477 s/step
# on time step 2986 (time=14.93), 0.696649 s/step
# on time step 2992 (time=14.96), 0.755018 s/step
# on time step 2997 (time=14.985), 0.855976 s/step
# on time step 3003 (time=15.015), 0.706106 s/step
# on time step 3009 (time=15.045), 0.681926 s/step
# on time step 3015 (time=15.075), 0.691646 s/step
# on time step 3021 (time=15.105), 0.680368 s/step
# on time step 3027 (time=15.135), 0.704474 s/step
# on time step 3033 (time=15.165), 0.681393 s/step
# on time step 3039 (time=15.195), 0.670488 s/step
# on time step 3045 (time=15.225), 0.674305 s/step
# on time step 3051 (time=15.255), 0.67363 s/step
# on time step 3058 (time=15.29), 0.663721 s/step
# on time step 3064 (time=15.32), 0.674242 s/step
# on time step 3070 (time=15.35), 0.738424 s/step
# on time step 3076 (time=15.38), 0.695204 s/step
# on time step 3082 (time=15.41), 0.714715 s/step
# on time step 3088 (time=15.44), 0.760512 s/step
# on time step 3094 (time=15.47), 0.713242 s/step
# on time step 3100 (time=15.5), 0.723265 s/step
# on time step 3106 (time=15.53), 0.725858 s/step
# on time step 3112 (time=15.56), 0.716793 s/step
# on time step 3118 (time=15.59), 0.683801 s/step
# on time step 3124 (time=15.62), 0.676597 s/step
# on time step 3130 (time=15.65), 0.69079 s/step
# on time step 3136 (time=15.68), 0.677402 s/step
# on time step 3142 (time=15.71), 0.764917 s/step
# on time step 3148 (time=15.74), 0.731872 s/step
# on time step 3154 (time=15.77), 0.723664 s/step
# on time step 3160 (time=15.8), 0.679492 s/step
# on time step 3166 (time=15.83), 0.675968 s/step
# on time step 3172 (time=15.86), 0.695997 s/step
# on time step 3178 (time=15.89), 0.718423 s/step
# on time step 3184 (time=15.92), 0.742881 s/step
# on time step 3190 (time=15.95), 0.709821 s/step
# on time step 3196 (time=15.98), 0.675649 s/step
# on time step 3202 (time=16.01), 0.674624 s/step
# on time step 3208 (time=16.04), 0.675114 s/step
# on time step 3213 (time=16.065), 0.814302 s/step
# on time step 3219 (time=16.095), 0.747897 s/step
# on time step 3225 (time=16.125), 0.720767 s/step
# on time step 3231 (time=16.155), 0.704478 s/step
# on time step 3237 (time=16.185), 0.736318 s/step
# on time step 3243 (time=16.215), 0.710916 s/step
# on time step 3249 (time=16.245), 0.68957 s/step
# on time step 3255 (time=16.275), 0.707914 s/step
# on time step 3261 (time=16.305), 0.71326 s/step
# on time step 3267 (time=16.335), 0.680302 s/step
# on time step 3273 (time=16.365), 0.683673 s/step
# on time step 3279 (time=16.395), 0.708427 s/step
# on time step 3285 (time=16.425), 0.788312 s/step
# on time step 3291 (time=16.455), 0.737086 s/step
# on time step 3297 (time=16.485), 0.683073 s/step
# on time step 3303 (time=16.515), 0.694315 s/step
# on time step 3309 (time=16.545), 0.693014 s/step
# on time step 3315 (time=16.575), 0.687797 s/step
# on time step 3321 (time=16.605), 0.768467 s/step
# on time step 3327 (time=16.635), 0.703566 s/step
# on time step 3333 (time=16.665), 0.6944 s/step
# on time step 3339 (time=16.695), 0.686165 s/step
# on time step 3345 (time=16.725), 0.717498 s/step
# on time step 3351 (time=16.755), 0.679855 s/step
# on time step 3357 (time=16.785), 0.669088 s/step
# on time step 3363 (time=16.815), 0.738945 s/step
# on time step 3369 (time=16.845), 0.680763 s/step
# on time step 3375 (time=16.875), 0.674293 s/step
# on time step 3381 (time=16.905), 0.668482 s/step
# on time step 3387 (time=16.935), 0.671716 s/step
# on time step 3393 (time=16.965), 0.680809 s/step
# on time step 3399 (time=16.995), 0.68096 s/step
# on time step 3405 (time=17.025), 0.689872 s/step
# on time step 3411 (time=17.055), 0.722461 s/step
# on time step 3417 (time=17.085), 0.71681 s/step
# on time step 3423 (time=17.115), 0.709924 s/step
# on time step 3429 (time=17.145), 0.746498 s/step
# on time step 3435 (time=17.175), 0.780629 s/step
# on time step 3441 (time=17.205), 0.7214 s/step
# on time step 3447 (time=17.235), 0.686027 s/step
# on time step 3453 (time=17.265), 0.768081 s/step
# on time step 3459 (time=17.295), 0.712431 s/step
# on time step 3465 (time=17.325), 0.683507 s/step
# on time step 3471 (time=17.355), 0.72462 s/step
# on time step 3477 (time=17.385), 0.70566 s/step
# on time step 3483 (time=17.415), 0.744823 s/step
# on time step 3489 (time=17.445), 0.703005 s/step
# on time step 3495 (time=17.475), 0.714399 s/step
# on time step 3501 (time=17.505), 0.688221 s/step
# on time step 3507 (time=17.535), 0.759881 s/step
# on time step 3513 (time=17.565), 0.702838 s/step
# on time step 3519 (time=17.595), 0.726819 s/step
# on time step 3525 (time=17.625), 0.71792 s/step
# on time step 3531 (time=17.655), 0.707826 s/step
# on time step 3537 (time=17.685), 0.680305 s/step
# on time step 3543 (time=17.715), 0.73436 s/step
# on time step 3549 (time=17.745), 0.676601 s/step
# on time step 3555 (time=17.775), 0.674524 s/step
# on time step 3562 (time=17.81), 0.667323 s/step
# on time step 3568 (time=17.84), 0.679714 s/step
# on time step 3574 (time=17.87), 0.668651 s/step
# on time step 3580 (time=17.9), 0.73673 s/step
# on time step 3587 (time=17.935), 0.664582 s/step
# on time step 3593 (time=17.965), 0.671608 s/step
# on time step 3599 (time=17.995), 0.688822 s/step
# on time step 3605 (time=18.025), 0.677275 s/step
# on time step 3611 (time=18.055), 0.688485 s/step
# on time step 3617 (time=18.085), 0.676075 s/step
# on time step 3623 (time=18.115), 0.70358 s/step
# on time step 3629 (time=18.145), 0.719767 s/step
# on time step 3635 (time=18.175), 0.689188 s/step
# on time step 3641 (time=18.205), 0.681752 s/step
# on time step 3647 (time=18.235), 0.790571 s/step
# on time step 3653 (time=18.265), 0.789893 s/step
# on time step 3659 (time=18.295), 0.710368 s/step
# on time step 3665 (time=18.325), 0.721212 s/step
# on time step 3671 (time=18.355), 0.686128 s/step
# on time step 3677 (time=18.385), 0.67476 s/step
# on time step 3683 (time=18.415), 0.680263 s/step
# on time step 3689 (time=18.445), 0.707648 s/step
# on time step 3695 (time=18.475), 0.749732 s/step
# on time step 3701 (time=18.505), 0.69884 s/step
# on time step 3707 (time=18.535), 0.742182 s/step
# on time step 3713 (time=18.565), 0.700788 s/step
# on time step 3719 (time=18.595), 0.708961 s/step
# on time step 3725 (time=18.625), 0.74457 s/step
# on time step 3731 (time=18.655), 0.695161 s/step
# on time step 3737 (time=18.685), 0.724201 s/step
# on time step 3743 (time=18.715), 0.674158 s/step
# on time step 3749 (time=18.745), 0.668739 s/step
# on time step 3755 (time=18.775), 0.68184 s/step
# on time step 3761 (time=18.805), 0.688428 s/step
# on time step 3767 (time=18.835), 0.758576 s/step
# on time step 3773 (time=18.865), 0.75781 s/step
# on time step 3779 (time=18.895), 0.744744 s/step
# on time step 3785 (time=18.925), 0.685955 s/step
# on time step 3791 (time=18.955), 0.70997 s/step
# on time step 3796 (time=18.98), 0.839547 s/step
# on time step 3802 (time=19.01), 0.747771 s/step
# on time step 3808 (time=19.04), 0.709407 s/step
# on time step 3814 (time=19.07), 0.736555 s/step
# on time step 3820 (time=19.1), 0.732231 s/step
# on time step 3826 (time=19.13), 0.754317 s/step
# on time step 3832 (time=19.16), 0.760721 s/step
# on time step 3838 (time=19.19), 0.775051 s/step
# on time step 3844 (time=19.22), 0.774907 s/step
# on time step 3850 (time=19.25), 0.708622 s/step
# on time step 3856 (time=19.28), 0.712843 s/step
# on time step 3862 (time=19.31), 0.700417 s/step
# on time step 3868 (time=19.34), 0.686206 s/step
# on time step 3874 (time=19.37), 0.735022 s/step
# on time step 3880 (time=19.4), 0.712586 s/step
# on time step 3886 (time=19.43), 0.709643 s/step
# on time step 3892 (time=19.46), 0.739065 s/step
# on time step 3898 (time=19.49), 0.702866 s/step
# on time step 3904 (time=19.52), 0.683196 s/step
# on time step 3910 (time=19.55), 0.676545 s/step
# on time step 3916 (time=19.58), 0.679894 s/step
# on time step 3922 (time=19.61), 0.695263 s/step
# on time step 3928 (time=19.64), 0.673991 s/step
# on time step 3934 (time=19.67), 0.682786 s/step
# on time step 3940 (time=19.7), 0.679711 s/step
# on time step 3946 (time=19.73), 0.739608 s/step
# on time step 3953 (time=19.765), 0.671108 s/step
# on time step 3959 (time=19.795), 0.678517 s/step
# on time step 3965 (time=19.825), 0.70428 s/step
# on time step 3971 (time=19.855), 0.706873 s/step
# on time step 3977 (time=19.885), 0.681746 s/step
# on time step 3983 (time=19.915), 0.673815 s/step
# on time step 3989 (time=19.945), 0.669992 s/step
# on time step 3995 (time=19.975), 0.688698 s/step
# on time step 4001 (time=20.005), 0.706264 s/step
# field decay(t = 20.01): 0.2499620503689741 / 0.2499620503689741 = 1.0
# on time step 4007 (time=20.035), 0.672091 s/step
# on time step 4013 (time=20.065), 0.678574 s/step
# on time step 4018 (time=20.09), 0.811493 s/step
# on time step 4024 (time=20.12), 0.695543 s/step
# on time step 4030 (time=20.15), 0.714646 s/step
# on time step 4036 (time=20.18), 0.697555 s/step
# on time step 4042 (time=20.21), 0.685722 s/step
# on time step 4048 (time=20.24), 0.688606 s/step
# on time step 4054 (time=20.27), 0.697692 s/step
# on time step 4060 (time=20.3), 0.677781 s/step
# on time step 4066 (time=20.33), 0.675831 s/step
# on time step 4072 (time=20.36), 0.694826 s/step
# on time step 4078 (time=20.39), 0.714304 s/step
# on time step 4084 (time=20.42), 0.684164 s/step
# on time step 4090 (time=20.45), 0.763278 s/step
# on time step 4096 (time=20.48), 0.667592 s/step
# on time step 4102 (time=20.51), 0.681046 s/step
# on time step 4108 (time=20.54), 0.743424 s/step
# on time step 4114 (time=20.57), 0.709012 s/step
# on time step 4120 (time=20.6), 0.766602 s/step
# on time step 4126 (time=20.63), 0.7321 s/step
# on time step 4132 (time=20.66), 0.734895 s/step
# on time step 4138 (time=20.69), 0.758377 s/step
# on time step 4144 (time=20.72), 0.768697 s/step
# on time step 4150 (time=20.75), 0.727974 s/step
# on time step 4156 (time=20.78), 0.686859 s/step
# on time step 4162 (time=20.81), 0.779509 s/step
# on time step 4169 (time=20.845), 0.666338 s/step
# on time step 4175 (time=20.875), 0.670618 s/step
# on time step 4182 (time=20.91), 0.662661 s/step
# on time step 4188 (time=20.94), 0.668818 s/step
# on time step 4195 (time=20.975), 0.667617 s/step
# on time step 4201 (time=21.005), 0.683318 s/step
# on time step 4207 (time=21.035), 0.674568 s/step
# on time step 4213 (time=21.065), 0.672854 s/step
# on time step 4219 (time=21.095), 0.696697 s/step
# on time step 4225 (time=21.125), 0.687992 s/step
# on time step 4231 (time=21.155), 0.677251 s/step
# on time step 4237 (time=21.185), 0.743228 s/step
# on time step 4243 (time=21.215), 0.674707 s/step
# on time step 4249 (time=21.245), 0.671365 s/step
# on time step 4255 (time=21.275), 0.67444 s/step
# on time step 4261 (time=21.305), 0.683844 s/step
# on time step 4267 (time=21.335), 0.696294 s/step
# on time step 4273 (time=21.365), 0.67976 s/step
# on time step 4279 (time=21.395), 0.677139 s/step
# on time step 4285 (time=21.425), 0.667176 s/step
# on time step 4291 (time=21.455), 0.681045 s/step
# on time step 4297 (time=21.485), 0.682295 s/step
# on time step 4303 (time=21.515), 0.705939 s/step
# on time step 4309 (time=21.545), 0.757109 s/step
# on time step 4315 (time=21.575), 0.710326 s/step
# on time step 4321 (time=21.605), 0.684469 s/step
# on time step 4327 (time=21.635), 0.67618 s/step
# on time step 4333 (time=21.665), 0.700239 s/step
# on time step 4339 (time=21.695), 0.690581 s/step
# on time step 4345 (time=21.725), 0.684714 s/step
# on time step 4351 (time=21.755), 0.672764 s/step
# on time step 4357 (time=21.785), 0.693911 s/step
# on time step 4363 (time=21.815), 0.671699 s/step
# on time step 4369 (time=21.845), 0.683031 s/step
# on time step 4375 (time=21.875), 0.668019 s/step
# on time step 4381 (time=21.905), 0.775576 s/step
# on time step 4387 (time=21.935), 0.695083 s/step
# on time step 4393 (time=21.965), 0.743762 s/step
# on time step 4399 (time=21.995), 0.704573 s/step
# on time step 4405 (time=22.025), 0.677766 s/step
# on time step 4411 (time=22.055), 0.688662 s/step
# on time step 4419 (time=22.095), 0.556684 s/step
# on time step 4428 (time=22.14), 0.492087 s/step
# on time step 4437 (time=22.185), 0.493483 s/step
# on time step 4446 (time=22.23), 0.495001 s/step
# on time step 4454 (time=22.27), 0.523479 s/step
# on time step 4463 (time=22.315), 0.492054 s/step
# on time step 4472 (time=22.36), 0.48666 s/step
# on time step 4480 (time=22.4), 0.509083 s/step
# on time step 4488 (time=22.44), 0.506635 s/step
# on time step 4496 (time=22.48), 0.51229 s/step
# on time step 4503 (time=22.515), 0.592574 s/step
# on time step 4509 (time=22.545), 0.678938 s/step
# on time step 4515 (time=22.575), 0.69986 s/step
# on time step 4521 (time=22.605), 0.696008 s/step
# on time step 4526 (time=22.63), 0.80233 s/step
# on time step 4532 (time=22.66), 0.680064 s/step
# on time step 4538 (time=22.69), 0.699379 s/step
# on time step 4544 (time=22.72), 0.682271 s/step
# on time step 4550 (time=22.75), 0.688268 s/step
# on time step 4556 (time=22.78), 0.731122 s/step
# on time step 4562 (time=22.81), 0.701254 s/step
# on time step 4568 (time=22.84), 0.780795 s/step
# on time step 4573 (time=22.865), 0.804325 s/step
# on time step 4579 (time=22.895), 0.713753 s/step
# on time step 4585 (time=22.925), 0.675626 s/step
# on time step 4591 (time=22.955), 0.693963 s/step
# on time step 4598 (time=22.99), 0.663508 s/step
# on time step 4604 (time=23.02), 0.748407 s/step
# on time step 4610 (time=23.05), 0.677508 s/step
# on time step 4616 (time=23.08), 0.675577 s/step
# on time step 4622 (time=23.11), 0.670421 s/step
# on time step 4629 (time=23.145), 0.665789 s/step
# on time step 4636 (time=23.18), 0.665682 s/step
# on time step 4642 (time=23.21), 0.67501 s/step
# on time step 4648 (time=23.24), 0.675659 s/step
# on time step 4654 (time=23.27), 0.700123 s/step
# on time step 4660 (time=23.3), 0.679056 s/step
# on time step 4667 (time=23.335), 0.666161 s/step
# on time step 4673 (time=23.365), 0.746884 s/step
# on time step 4679 (time=23.395), 0.690985 s/step
# on time step 4685 (time=23.425), 0.681591 s/step
# on time step 4691 (time=23.455), 0.721739 s/step
# on time step 4697 (time=23.485), 0.692577 s/step
# on time step 4703 (time=23.515), 0.707912 s/step
# on time step 4709 (time=23.545), 0.722029 s/step
# on time step 4715 (time=23.575), 0.739785 s/step
# on time step 4721 (time=23.605), 0.696118 s/step
# on time step 4727 (time=23.635), 0.698033 s/step
# on time step 4733 (time=23.665), 0.688161 s/step
# on time step 4739 (time=23.695), 0.695572 s/step
# on time step 4745 (time=23.725), 0.762739 s/step
# on time step 4751 (time=23.755), 0.707934 s/step
# on time step 4757 (time=23.785), 0.741616 s/step
# on time step 4763 (time=23.815), 0.686404 s/step
# on time step 4769 (time=23.845), 0.670436 s/step
# on time step 4775 (time=23.875), 0.749452 s/step
# on time step 4781 (time=23.905), 0.692269 s/step
# on time step 4787 (time=23.935), 0.704552 s/step
# on time step 4793 (time=23.965), 0.736429 s/step
# on time step 4799 (time=23.995), 0.712937 s/step
# on time step 4805 (time=24.025), 0.674174 s/step
# on time step 4811 (time=24.055), 0.678096 s/step
# on time step 4817 (time=24.085), 0.670077 s/step
# on time step 4823 (time=24.115), 0.734648 s/step
# on time step 4829 (time=24.145), 0.679132 s/step
# on time step 4835 (time=24.175), 0.678431 s/step
# on time step 4841 (time=24.205), 0.676718 s/step
# on time step 4847 (time=24.235), 0.667874 s/step
# on time step 4853 (time=24.265), 0.69565 s/step
# on time step 4859 (time=24.295), 0.697966 s/step
# on time step 4865 (time=24.325), 0.669147 s/step
# on time step 4871 (time=24.355), 0.685431 s/step
# on time step 4877 (time=24.385), 0.683708 s/step
# on time step 4883 (time=24.415), 0.677733 s/step
# on time step 4889 (time=24.445), 0.674745 s/step
# on time step 4895 (time=24.475), 0.745101 s/step
# on time step 4901 (time=24.505), 0.71816 s/step
# on time step 4907 (time=24.535), 0.688526 s/step
# on time step 4913 (time=24.565), 0.742002 s/step
# on time step 4919 (time=24.595), 0.708525 s/step
# on time step 4925 (time=24.625), 0.715559 s/step
# on time step 4931 (time=24.655), 0.734044 s/step
# on time step 4937 (time=24.685), 0.686236 s/step
# on time step 4943 (time=24.715), 0.703821 s/step
# on time step 4949 (time=24.745), 0.675088 s/step
# on time step 4955 (time=24.775), 0.678861 s/step
# on time step 4961 (time=24.805), 0.676724 s/step
# on time step 4967 (time=24.835), 0.734903 s/step
# on time step 4974 (time=24.87), 0.664067 s/step
# on time step 4980 (time=24.9), 0.67922 s/step
# on time step 4986 (time=24.93), 0.748375 s/step
# on time step 4992 (time=24.96), 0.689408 s/step
# on time step 4998 (time=24.99), 0.678598 s/step
# on time step 5004 (time=25.02), 0.719834 s/step
# on time step 5010 (time=25.05), 0.699506 s/step
# on time step 5016 (time=25.08), 0.700794 s/step
# on time step 5022 (time=25.11), 0.682767 s/step
# on time step 5028 (time=25.14), 0.700652 s/step
# on time step 5034 (time=25.17), 0.684941 s/step
# on time step 5040 (time=25.2), 0.760603 s/step
# on time step 5046 (time=25.23), 0.687923 s/step
# on time step 5052 (time=25.26), 0.677067 s/step
# on time step 5058 (time=25.29), 0.677259 s/step
# on time step 5064 (time=25.32), 0.691011 s/step
# on time step 5070 (time=25.35), 0.696765 s/step
# on time step 5076 (time=25.38), 0.694167 s/step
# on time step 5082 (time=25.41), 0.725606 s/step
# on time step 5088 (time=25.44), 0.68845 s/step
# on time step 5094 (time=25.47), 0.683861 s/step
# on time step 5100 (time=25.5), 0.676996 s/step
# on time step 5106 (time=25.53), 0.678209 s/step
# on time step 5112 (time=25.56), 0.751064 s/step
# on time step 5118 (time=25.59), 0.673919 s/step
# on time step 5124 (time=25.62), 0.725211 s/step
# on time step 5130 (time=25.65), 0.672056 s/step
# on time step 5136 (time=25.68), 0.720661 s/step
# on time step 5142 (time=25.71), 0.685018 s/step
# on time step 5148 (time=25.74), 0.691915 s/step
# on time step 5154 (time=25.77), 0.680703 s/step
# on time step 5160 (time=25.8), 0.691166 s/step
# on time step 5166 (time=25.83), 0.732706 s/step
# on time step 5172 (time=25.86), 0.688205 s/step
# on time step 5178 (time=25.89), 0.680915 s/step
# on time step 5184 (time=25.92), 0.749405 s/step
# on time step 5190 (time=25.95), 0.677004 s/step
# on time step 5196 (time=25.98), 0.670933 s/step
# on time step 5202 (time=26.01), 0.676419 s/step
# on time step 5208 (time=26.04), 0.724828 s/step
# on time step 5214 (time=26.07), 0.684728 s/step
# on time step 5220 (time=26.1), 0.700677 s/step
# on time step 5226 (time=26.13), 0.710144 s/step
# on time step 5232 (time=26.16), 0.67589 s/step
# on time step 5238 (time=26.19), 0.716905 s/step
# on time step 5244 (time=26.22), 0.694699 s/step
# on time step 5250 (time=26.25), 0.672554 s/step
# on time step 5256 (time=26.28), 0.748942 s/step
# on time step 5262 (time=26.31), 0.689118 s/step
# on time step 5268 (time=26.34), 0.682892 s/step
# on time step 5274 (time=26.37), 0.726774 s/step
# on time step 5280 (time=26.4), 0.675724 s/step
# on time step 5286 (time=26.43), 0.718145 s/step
# on time step 5292 (time=26.46), 0.713289 s/step
# on time step 5298 (time=26.49), 0.679867 s/step
# on time step 5304 (time=26.52), 0.687247 s/step
# on time step 5310 (time=26.55), 0.724434 s/step
# on time step 5316 (time=26.58), 0.676416 s/step
# on time step 5322 (time=26.61), 0.671345 s/step
# on time step 5328 (time=26.64), 0.678245 s/step
# on time step 5334 (time=26.67), 0.760032 s/step
# on time step 5340 (time=26.7), 0.692986 s/step
# on time step 5346 (time=26.73), 0.746112 s/step
# on time step 5352 (time=26.76), 0.701233 s/step
# on time step 5358 (time=26.79), 0.684977 s/step
# on time step 5364 (time=26.82), 0.677837 s/step
# on time step 5370 (time=26.85), 0.719202 s/step
# on time step 5376 (time=26.88), 0.69065 s/step
# on time step 5382 (time=26.91), 0.684136 s/step
# on time step 5388 (time=26.94), 0.714212 s/step
# on time step 5394 (time=26.97), 0.703154 s/step
# on time step 5400 (time=27), 0.713597 s/step
# on time step 5406 (time=27.03), 0.737489 s/step
# on time step 5412 (time=27.06), 0.678637 s/step
# on time step 5418 (time=27.09), 0.674223 s/step
# on time step 5424 (time=27.12), 0.667465 s/step
# on time step 5430 (time=27.15), 0.717215 s/step
# on time step 5436 (time=27.18), 0.695766 s/step
# on time step 5442 (time=27.21), 0.761856 s/step
# on time step 5448 (time=27.24), 0.723769 s/step
# on time step 5454 (time=27.27), 0.696759 s/step
# on time step 5460 (time=27.3), 0.694022 s/step
# on time step 5466 (time=27.33), 0.683114 s/step
# on time step 5472 (time=27.36), 0.717405 s/step
# on time step 5478 (time=27.39), 0.759081 s/step
# on time step 5484 (time=27.42), 0.70855 s/step
# on time step 5490 (time=27.45), 0.69093 s/step
# on time step 5496 (time=27.48), 0.685736 s/step
# on time step 5502 (time=27.51), 0.668853 s/step
# on time step 5508 (time=27.54), 0.667489 s/step
# on time step 5514 (time=27.57), 0.66787 s/step
# on time step 5521 (time=27.605), 0.664934 s/step
# on time step 5527 (time=27.635), 0.727071 s/step
# on time step 5533 (time=27.665), 0.723116 s/step
# on time step 5539 (time=27.695), 0.773256 s/step
# on time step 5545 (time=27.725), 0.755095 s/step
# on time step 5550 (time=27.75), 0.82685 s/step
# on time step 5556 (time=27.78), 0.718928 s/step
# on time step 5562 (time=27.81), 0.734707 s/step
# on time step 5568 (time=27.84), 0.751957 s/step
# on time step 5574 (time=27.87), 0.733647 s/step
# on time step 5580 (time=27.9), 0.726602 s/step
# on time step 5586 (time=27.93), 0.736768 s/step
# on time step 5592 (time=27.96), 0.764546 s/step
# on time step 5598 (time=27.99), 0.722235 s/step
# on time step 5604 (time=28.02), 0.722983 s/step
# on time step 5610 (time=28.05), 0.739211 s/step
# on time step 5616 (time=28.08), 0.744382 s/step
# on time step 5621 (time=28.105), 0.844963 s/step
# on time step 5627 (time=28.135), 0.750827 s/step
# on time step 5633 (time=28.165), 0.762562 s/step
# on time step 5639 (time=28.195), 0.799358 s/step
# on time step 5644 (time=28.22), 0.806622 s/step
# on time step 5650 (time=28.25), 0.768999 s/step
# on time step 5656 (time=28.28), 0.693307 s/step
# on time step 5662 (time=28.31), 0.701273 s/step
# on time step 5668 (time=28.34), 0.780331 s/step
# on time step 5674 (time=28.37), 0.767549 s/step
# on time step 5680 (time=28.4), 0.757584 s/step
# on time step 5686 (time=28.43), 0.745258 s/step
# on time step 5692 (time=28.46), 0.739544 s/step
# on time step 5697 (time=28.485), 0.812557 s/step
# on time step 5703 (time=28.515), 0.734512 s/step
# on time step 5709 (time=28.545), 0.73591 s/step
# on time step 5715 (time=28.575), 0.738737 s/step
# on time step 5721 (time=28.605), 0.724885 s/step
# on time step 5727 (time=28.635), 0.72638 s/step
# on time step 5733 (time=28.665), 0.719127 s/step
# on time step 5739 (time=28.695), 0.748098 s/step
# on time step 5745 (time=28.725), 0.777268 s/step
# on time step 5750 (time=28.75), 0.801818 s/step
# on time step 5755 (time=28.775), 0.807012 s/step
# on time step 5761 (time=28.805), 0.745776 s/step
# on time step 5767 (time=28.835), 0.849535 s/step
# on time step 5773 (time=28.865), 0.730618 s/step
# on time step 5779 (time=28.895), 0.731672 s/step
# on time step 5785 (time=28.925), 0.742956 s/step
# on time step 5791 (time=28.955), 0.729277 s/step
# on time step 5797 (time=28.985), 0.754913 s/step
# on time step 5803 (time=29.015), 0.738902 s/step
# on time step 5809 (time=29.045), 0.729204 s/step
# on time step 5815 (time=29.075), 0.753225 s/step
# on time step 5820 (time=29.1), 0.818622 s/step
# on time step 5826 (time=29.13), 0.730957 s/step
# on time step 5832 (time=29.16), 0.73119 s/step
# on time step 5838 (time=29.19), 0.762508 s/step
# on time step 5843 (time=29.215), 0.88275 s/step
# on time step 5849 (time=29.245), 0.717431 s/step
# on time step 5855 (time=29.275), 0.755822 s/step
# on time step 5861 (time=29.305), 0.790687 s/step
# on time step 5867 (time=29.335), 0.770862 s/step
# on time step 5873 (time=29.365), 0.758446 s/step
# on time step 5879 (time=29.395), 0.733496 s/step
# on time step 5884 (time=29.42), 0.817762 s/step
# on time step 5890 (time=29.45), 0.722365 s/step
# on time step 5896 (time=29.48), 0.69777 s/step
# on time step 5902 (time=29.51), 0.754912 s/step
# on time step 5908 (time=29.54), 0.708837 s/step
# on time step 5914 (time=29.57), 0.74885 s/step
# on time step 5920 (time=29.6), 0.699386 s/step
# on time step 5926 (time=29.63), 0.68601 s/step
# on time step 5932 (time=29.66), 0.697657 s/step
# on time step 5938 (time=29.69), 0.684617 s/step
# on time step 5944 (time=29.72), 0.694179 s/step
# on time step 5950 (time=29.75), 0.722779 s/step
# on time step 5956 (time=29.78), 0.684869 s/step
# on time step 5962 (time=29.81), 0.670934 s/step
# on time step 5968 (time=29.84), 0.698011 s/step
# on time step 5974 (time=29.87), 0.716659 s/step
# on time step 5980 (time=29.9), 0.753427 s/step
# on time step 5986 (time=29.93), 0.825786 s/step
# on time step 5992 (time=29.96), 0.683072 s/step
# on time step 5998 (time=29.99), 0.684486 s/step
# field decay(t = 30.015): 9.597336308090515e-10 / 0.2499620503689741 = 3.8395173563041635e-09
# run 0 finished at t = 30.015 (6003 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)


# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

# 픽셀에 들어온 flux 구하기

tran_p = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(design_region_width_x, design_region_width_y, 0)
)

tran_pixel = opt.sim.add_flux(fcen, df, nfreq, tran_p)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 5.91278e-05 s
# Working in 3D dimensions.
# Computational cell is 2.8 x 2.8 x 6 with resolution 100
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      block, center = (0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
# subpixel-averaging is 86.2799% done, 0.636118 s remaining
# subpixel-averaging is 56.2203% done, 3.11529 s remaining
# subpixel-averaging is 8.74134% done, 41.7634 s remaining
# subpixel-averaging is 17.4763% done, 18.8914 s remaining
# subpixel-averaging is 26.0463% done, 11.3612 s remaining
# subpixel-averaging is 34.5432% done, 7.58098 s remaining
# subpixel-averaging is 43.0307% done, 5.29746 s remaining
# subpixel-averaging is 51.7117% done, 3.73603 s remaining
# subpixel-averaging is 60.2309% done, 2.64112 s remaining
# subpixel-averaging is 68.658% done, 1.82619 s remaining
# subpixel-averaging is 77.1264% done, 1.18673 s remaining
# subpixel-averaging is 85.7058% done, 0.667134 s remaining
# subpixel-averaging is 94.3615% done, 0.239023 s remaining
# subpixel-averaging is 86.6027% done, 0.618835 s remaining
# subpixel-averaging is 55.376% done, 3.22342 s remaining
# subpixel-averaging is 8.74134% done, 41.7711 s remaining
# subpixel-averaging is 17.47% done, 18.9022 s remaining
# subpixel-averaging is 26.1891% done, 11.2742 s remaining
# subpixel-averaging is 34.8194% done, 7.49044 s remaining
# subpixel-averaging is 43.2941% done, 5.2404 s remaining
# subpixel-averaging is 52.0291% done, 3.68833 s remaining
# subpixel-averaging is 60.561% done, 2.60534 s remaining
# subpixel-averaging is 69.2007% done, 1.78054 s remaining
# subpixel-averaging is 78.0087% done, 1.12786 s remaining
# subpixel-averaging is 86.7945% done, 0.608649 s remaining
# subpixel-averaging is 95.5676% done, 0.185531 s remaining
# subpixel-averaging is 90.1537% done, 0.436899 s remaining
# subpixel-averaging is 56.9653% done, 3.02246 s remaining
# subpixel-averaging is 8.74452% done, 41.7536 s remaining
# subpixel-averaging is 17.3208% done, 19.0987 s remaining
# subpixel-averaging is 25.9003% done, 11.4468 s remaining
# subpixel-averaging is 34.3369% done, 7.65155 s remaining
# subpixel-averaging is 42.8783% done, 5.3291 s remaining
# subpixel-averaging is 51.426% done, 3.7787 s remaining
# subpixel-averaging is 60.0277% done, 2.66402 s remaining
# subpixel-averaging is 68.7754% done, 1.8161 s remaining
# subpixel-averaging is 77.266% done, 1.17733 s remaining
# subpixel-averaging is 85.6233% done, 0.671716 s remaining
# subpixel-averaging is 94.025% done, 0.254215 s remaining
# time for set_epsilon = 174.32 s
# -----------
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      block, center = (0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (0.7,-0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)
#      block, center = (-0.7,0.7,-2)
#           size (1,1,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (16,16,16)

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)
tran_flux_p = mp.get_fluxes(tran_pixel)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
# Out:
# on time step 1 (time=0.005), 10.7849 s/step
# on time step 6 (time=0.03), 0.992924 s/step
# on time step 11 (time=0.055), 0.968158 s/step
# on time step 16 (time=0.08), 0.92097 s/step
# on time step 21 (time=0.105), 0.920204 s/step
# on time step 26 (time=0.13), 0.899793 s/step
# on time step 31 (time=0.155), 0.92143 s/step
# on time step 36 (time=0.18), 1.03008 s/step
# on time step 41 (time=0.205), 0.963081 s/step
# on time step 46 (time=0.23), 0.918207 s/step
# on time step 51 (time=0.255), 0.93411 s/step
# on time step 56 (time=0.28), 0.981979 s/step
# on time step 62 (time=0.31), 0.740514 s/step
# on time step 69 (time=0.345), 0.633226 s/step
# on time step 73 (time=0.365), 1.01047 s/step
# on time step 80 (time=0.4), 0.628235 s/step
# on time step 85 (time=0.425), 0.809275 s/step
# on time step 90 (time=0.45), 0.918598 s/step
# on time step 95 (time=0.475), 0.915098 s/step
# on time step 100 (time=0.5), 0.931822 s/step
# on time step 105 (time=0.525), 0.916982 s/step
# on time step 110 (time=0.55), 0.933622 s/step
# on time step 115 (time=0.575), 0.895195 s/step
# on time step 120 (time=0.6), 0.922814 s/step
# on time step 125 (time=0.625), 0.952082 s/step
# on time step 130 (time=0.65), 0.905884 s/step
# on time step 135 (time=0.675), 0.932125 s/step
# on time step 140 (time=0.7), 0.892399 s/step
# on time step 145 (time=0.725), 0.902926 s/step
# on time step 149 (time=0.745), 1.14561 s/step
# on time step 154 (time=0.77), 0.931808 s/step
# on time step 159 (time=0.795), 0.957545 s/step
# on time step 164 (time=0.82), 0.961392 s/step
# on time step 169 (time=0.845), 0.964543 s/step
# on time step 174 (time=0.87), 0.926479 s/step
# on time step 179 (time=0.895), 0.929771 s/step
# on time step 184 (time=0.92), 0.958566 s/step
# on time step 189 (time=0.945), 0.930506 s/step
# on time step 194 (time=0.97), 0.930459 s/step
# on time step 199 (time=0.995), 0.900561 s/step
# on time step 204 (time=1.02), 0.917355 s/step
# on time step 209 (time=1.045), 0.911504 s/step
# on time step 214 (time=1.07), 0.929171 s/step
# on time step 219 (time=1.095), 1.08688 s/step
# on time step 224 (time=1.12), 0.904558 s/step
# on time step 229 (time=1.145), 0.917314 s/step
# on time step 234 (time=1.17), 0.95173 s/step
# on time step 239 (time=1.195), 0.966541 s/step
# on time step 244 (time=1.22), 0.91148 s/step
# on time step 249 (time=1.245), 0.999114 s/step
# on time step 254 (time=1.27), 0.958754 s/step
# on time step 259 (time=1.295), 0.962454 s/step
# on time step 264 (time=1.32), 0.90758 s/step
# on time step 269 (time=1.345), 0.895006 s/step
# on time step 274 (time=1.37), 0.899096 s/step
# on time step 279 (time=1.395), 0.875316 s/step
# on time step 284 (time=1.42), 0.875488 s/step
# on time step 289 (time=1.445), 0.869349 s/step
# on time step 293 (time=1.465), 1.10398 s/step
# on time step 298 (time=1.49), 0.917191 s/step
# on time step 303 (time=1.515), 0.922517 s/step
# on time step 308 (time=1.54), 0.904742 s/step
# on time step 313 (time=1.565), 0.929473 s/step
# on time step 318 (time=1.59), 0.975627 s/step
# on time step 323 (time=1.615), 0.966179 s/step
# on time step 328 (time=1.64), 0.921416 s/step
# on time step 333 (time=1.665), 0.900352 s/step
# on time step 338 (time=1.69), 0.891417 s/step
# on time step 343 (time=1.715), 0.909945 s/step
# on time step 348 (time=1.74), 0.968051 s/step
# on time step 353 (time=1.765), 0.906882 s/step
# on time step 358 (time=1.79), 0.892817 s/step
# on time step 363 (time=1.815), 0.883613 s/step
# on time step 367 (time=1.835), 1.1263 s/step
# on time step 372 (time=1.86), 0.888966 s/step
# on time step 377 (time=1.885), 0.887695 s/step
# on time step 382 (time=1.91), 0.925775 s/step
# on time step 387 (time=1.935), 0.917491 s/step
# on time step 392 (time=1.96), 0.923896 s/step
# on time step 397 (time=1.985), 0.911824 s/step
# on time step 402 (time=2.01), 0.9067 s/step
# on time step 407 (time=2.035), 0.896096 s/step
# on time step 412 (time=2.06), 0.899519 s/step
# on time step 417 (time=2.085), 0.883005 s/step
# on time step 422 (time=2.11), 0.891201 s/step
# on time step 427 (time=2.135), 0.897322 s/step
# on time step 432 (time=2.16), 0.956724 s/step
# on time step 436 (time=2.18), 1.04123 s/step
# on time step 440 (time=2.2), 1.15797 s/step
# on time step 445 (time=2.225), 0.895046 s/step
# on time step 450 (time=2.25), 0.958423 s/step
# on time step 455 (time=2.275), 0.914911 s/step
# on time step 461 (time=2.305), 0.675421 s/step
# on time step 467 (time=2.335), 0.700242 s/step
# on time step 474 (time=2.37), 0.648533 s/step
# on time step 481 (time=2.405), 0.638904 s/step
# on time step 488 (time=2.44), 0.648621 s/step
# on time step 495 (time=2.475), 0.644318 s/step
# on time step 502 (time=2.51), 0.622921 s/step
# on time step 508 (time=2.54), 0.66885 s/step
# on time step 513 (time=2.565), 0.848382 s/step
# on time step 520 (time=2.6), 0.658649 s/step
# on time step 525 (time=2.625), 0.869086 s/step
# on time step 530 (time=2.65), 0.886608 s/step
# on time step 535 (time=2.675), 0.894266 s/step
# on time step 540 (time=2.7), 0.938216 s/step
# on time step 545 (time=2.725), 0.891171 s/step
# on time step 550 (time=2.75), 0.898789 s/step
# on time step 555 (time=2.775), 0.918319 s/step
# on time step 560 (time=2.8), 0.920407 s/step
# on time step 565 (time=2.825), 0.965555 s/step
# on time step 569 (time=2.845), 1.00204 s/step
# on time step 574 (time=2.87), 0.899409 s/step
# on time step 579 (time=2.895), 0.920381 s/step
# on time step 584 (time=2.92), 1.05377 s/step
# on time step 589 (time=2.945), 0.894744 s/step
# on time step 594 (time=2.97), 0.884654 s/step
# on time step 599 (time=2.995), 0.879251 s/step
# on time step 604 (time=3.02), 0.907982 s/step
# on time step 609 (time=3.045), 0.910415 s/step
# on time step 614 (time=3.07), 0.912084 s/step
# on time step 619 (time=3.095), 0.901413 s/step
# on time step 624 (time=3.12), 0.908349 s/step
# on time step 629 (time=3.145), 0.911478 s/step
# on time step 634 (time=3.17), 0.909881 s/step
# on time step 639 (time=3.195), 0.920875 s/step
# on time step 644 (time=3.22), 0.90571 s/step
# on time step 648 (time=3.24), 1.01154 s/step
# on time step 653 (time=3.265), 0.906279 s/step
# on time step 657 (time=3.285), 1.08105 s/step
# on time step 662 (time=3.31), 0.913428 s/step
# on time step 667 (time=3.335), 0.953993 s/step
# on time step 672 (time=3.36), 0.940581 s/step
# on time step 677 (time=3.385), 0.899753 s/step
# on time step 682 (time=3.41), 0.905018 s/step
# on time step 687 (time=3.435), 0.889467 s/step
# on time step 692 (time=3.46), 0.939931 s/step
# on time step 697 (time=3.485), 0.922103 s/step
# on time step 702 (time=3.51), 0.895614 s/step
# on time step 707 (time=3.535), 0.909747 s/step
# on time step 711 (time=3.555), 1.02118 s/step
# on time step 716 (time=3.58), 0.877402 s/step
# on time step 721 (time=3.605), 0.888799 s/step
# on time step 726 (time=3.63), 0.888391 s/step
# on time step 730 (time=3.65), 1.1109 s/step
# on time step 735 (time=3.675), 0.88156 s/step
# on time step 740 (time=3.7), 0.889729 s/step
# on time step 745 (time=3.725), 0.90025 s/step
# on time step 750 (time=3.75), 0.92415 s/step
# on time step 755 (time=3.775), 0.920705 s/step
# on time step 760 (time=3.8), 0.922392 s/step
# on time step 765 (time=3.825), 0.903378 s/step
# on time step 770 (time=3.85), 0.890354 s/step
# on time step 775 (time=3.875), 0.980808 s/step
# on time step 779 (time=3.895), 1.00691 s/step
# on time step 784 (time=3.92), 0.994891 s/step
# on time step 788 (time=3.94), 1.01819 s/step
# on time step 793 (time=3.965), 0.960204 s/step
# on time step 798 (time=3.99), 0.900097 s/step
# on time step 803 (time=4.015), 1.03185 s/step
# on time step 808 (time=4.04), 0.933605 s/step
# on time step 813 (time=4.065), 0.891518 s/step
# on time step 818 (time=4.09), 0.890872 s/step
# on time step 823 (time=4.115), 0.957721 s/step
# on time step 828 (time=4.14), 0.909256 s/step
# on time step 833 (time=4.165), 0.90406 s/step
# on time step 838 (time=4.19), 0.887345 s/step
# on time step 843 (time=4.215), 0.899278 s/step
# on time step 848 (time=4.24), 0.941653 s/step
# on time step 853 (time=4.265), 0.942632 s/step
# on time step 858 (time=4.29), 0.927433 s/step
# on time step 863 (time=4.315), 0.932926 s/step
# on time step 868 (time=4.34), 0.969214 s/step
# on time step 873 (time=4.365), 0.953256 s/step
# on time step 877 (time=4.385), 1.088 s/step
# on time step 882 (time=4.41), 0.916954 s/step
# on time step 887 (time=4.435), 0.885215 s/step
# on time step 892 (time=4.46), 0.926263 s/step
# on time step 897 (time=4.485), 0.987023 s/step
# on time step 902 (time=4.51), 0.899328 s/step
# on time step 907 (time=4.535), 0.934271 s/step
# on time step 912 (time=4.56), 0.95151 s/step
# on time step 917 (time=4.585), 0.944765 s/step
# on time step 922 (time=4.61), 0.929902 s/step
# on time step 927 (time=4.635), 0.935056 s/step
# on time step 932 (time=4.66), 0.905144 s/step
# on time step 937 (time=4.685), 0.964751 s/step
# on time step 942 (time=4.71), 0.897238 s/step
# on time step 947 (time=4.735), 0.900777 s/step
# on time step 951 (time=4.755), 1.18351 s/step
# on time step 956 (time=4.78), 0.949942 s/step
# on time step 961 (time=4.805), 0.974756 s/step
# on time step 966 (time=4.83), 0.981843 s/step
# on time step 971 (time=4.855), 0.964258 s/step
# on time step 976 (time=4.88), 0.910967 s/step
# on time step 981 (time=4.905), 0.951222 s/step
# on time step 986 (time=4.93), 0.916301 s/step
# on time step 991 (time=4.955), 0.972169 s/step
# on time step 996 (time=4.98), 0.902166 s/step
# on time step 1001 (time=5.005), 0.892674 s/step
# on time step 1006 (time=5.03), 0.911883 s/step
# on time step 1011 (time=5.055), 0.92096 s/step
# on time step 1016 (time=5.08), 0.977242 s/step
# on time step 1021 (time=5.105), 0.982824 s/step
# on time step 1025 (time=5.125), 1.15944 s/step
# on time step 1030 (time=5.15), 0.974935 s/step
# on time step 1035 (time=5.175), 0.931908 s/step
# on time step 1040 (time=5.2), 0.937886 s/step
# on time step 1045 (time=5.225), 0.979368 s/step
# on time step 1050 (time=5.25), 0.914834 s/step
# on time step 1055 (time=5.275), 0.890343 s/step
# on time step 1060 (time=5.3), 0.912521 s/step
# on time step 1065 (time=5.325), 0.948508 s/step
# on time step 1070 (time=5.35), 0.917795 s/step
# on time step 1075 (time=5.375), 0.91985 s/step
# on time step 1080 (time=5.4), 0.902161 s/step
# on time step 1085 (time=5.425), 0.904743 s/step
# on time step 1090 (time=5.45), 0.949915 s/step
# on time step 1095 (time=5.475), 1.0582 s/step
# on time step 1100 (time=5.5), 0.90819 s/step
# on time step 1105 (time=5.525), 0.912486 s/step
# on time step 1110 (time=5.55), 0.905518 s/step
# on time step 1115 (time=5.575), 0.875267 s/step
# on time step 1120 (time=5.6), 0.908055 s/step
# on time step 1125 (time=5.625), 0.913099 s/step
# on time step 1130 (time=5.65), 0.906075 s/step
# on time step 1135 (time=5.675), 0.911234 s/step
# on time step 1140 (time=5.7), 0.912837 s/step
# on time step 1145 (time=5.725), 0.940876 s/step
# on time step 1150 (time=5.75), 0.904804 s/step
# on time step 1155 (time=5.775), 0.916842 s/step
# on time step 1160 (time=5.8), 0.900491 s/step
# on time step 1165 (time=5.825), 0.898495 s/step
# on time step 1169 (time=5.845), 1.099 s/step
# on time step 1174 (time=5.87), 0.902779 s/step
# on time step 1179 (time=5.895), 0.916332 s/step
# on time step 1184 (time=5.92), 0.898993 s/step
# on time step 1189 (time=5.945), 0.90437 s/step
# on time step 1194 (time=5.97), 0.910687 s/step
# on time step 1199 (time=5.995), 0.893806 s/step
# on time step 1204 (time=6.02), 0.915335 s/step
# on time step 1209 (time=6.045), 0.957098 s/step
# on time step 1214 (time=6.07), 0.886606 s/step
# on time step 1219 (time=6.095), 0.911006 s/step
# on time step 1224 (time=6.12), 0.902416 s/step
# on time step 1229 (time=6.145), 0.894872 s/step
# on time step 1234 (time=6.17), 0.938271 s/step
# on time step 1239 (time=6.195), 0.932553 s/step
# on time step 1243 (time=6.215), 1.16309 s/step
# on time step 1248 (time=6.24), 0.922108 s/step
# on time step 1253 (time=6.265), 0.948154 s/step
# on time step 1258 (time=6.29), 0.907413 s/step
# on time step 1263 (time=6.315), 0.917726 s/step
# on time step 1268 (time=6.34), 0.907774 s/step
# on time step 1273 (time=6.365), 0.902739 s/step
# on time step 1278 (time=6.39), 0.921603 s/step
# on time step 1283 (time=6.415), 0.921898 s/step
# on time step 1288 (time=6.44), 0.897845 s/step
# on time step 1293 (time=6.465), 0.933175 s/step
# on time step 1298 (time=6.49), 0.945936 s/step
# on time step 1303 (time=6.515), 0.89726 s/step
# on time step 1308 (time=6.54), 0.900946 s/step
# on time step 1313 (time=6.565), 0.892091 s/step
# on time step 1317 (time=6.585), 1.18333 s/step
# on time step 1322 (time=6.61), 0.947532 s/step
# on time step 1327 (time=6.635), 0.947889 s/step
# on time step 1332 (time=6.66), 0.905393 s/step
# on time step 1337 (time=6.685), 0.892997 s/step
# on time step 1342 (time=6.71), 0.892635 s/step
# on time step 1347 (time=6.735), 0.894206 s/step
# on time step 1352 (time=6.76), 0.90225 s/step
# on time step 1357 (time=6.785), 0.90469 s/step
# on time step 1362 (time=6.81), 0.897608 s/step
# on time step 1367 (time=6.835), 0.892717 s/step
# on time step 1372 (time=6.86), 0.898952 s/step
# on time step 1377 (time=6.885), 0.902783 s/step
# on time step 1382 (time=6.91), 0.9046 s/step
# on time step 1387 (time=6.935), 1.05527 s/step
# on time step 1392 (time=6.96), 0.978795 s/step
# on time step 1397 (time=6.985), 0.89778 s/step
# on time step 1402 (time=7.01), 0.885387 s/step
# on time step 1407 (time=7.035), 0.941122 s/step
# on time step 1412 (time=7.06), 0.955632 s/step
# on time step 1417 (time=7.085), 0.934311 s/step
# on time step 1422 (time=7.11), 0.907077 s/step
# on time step 1427 (time=7.135), 0.943925 s/step
# on time step 1432 (time=7.16), 0.919248 s/step
# on time step 1437 (time=7.185), 0.974981 s/step
# on time step 1442 (time=7.21), 0.891158 s/step
# on time step 1447 (time=7.235), 0.91084 s/step
# on time step 1452 (time=7.26), 0.945103 s/step
# on time step 1457 (time=7.285), 0.96118 s/step
# on time step 1461 (time=7.305), 1.16798 s/step
# on time step 1466 (time=7.33), 0.93554 s/step
# on time step 1471 (time=7.355), 0.924693 s/step
# on time step 1476 (time=7.38), 0.90735 s/step
# on time step 1481 (time=7.405), 0.911117 s/step
# on time step 1486 (time=7.43), 0.907331 s/step
# on time step 1491 (time=7.455), 0.900399 s/step
# on time step 1496 (time=7.48), 0.908785 s/step
# on time step 1501 (time=7.505), 0.904489 s/step
# on time step 1506 (time=7.53), 0.901114 s/step
# on time step 1511 (time=7.555), 0.900331 s/step
# on time step 1516 (time=7.58), 0.956314 s/step
# on time step 1521 (time=7.605), 0.925269 s/step
# on time step 1526 (time=7.63), 0.912257 s/step
# on time step 1531 (time=7.655), 0.896999 s/step
# on time step 1535 (time=7.675), 1.108 s/step
# on time step 1540 (time=7.7), 0.907031 s/step
# on time step 1545 (time=7.725), 0.902802 s/step
# on time step 1550 (time=7.75), 0.972427 s/step
# on time step 1555 (time=7.775), 0.883751 s/step
# on time step 1560 (time=7.8), 0.895867 s/step
# on time step 1565 (time=7.825), 0.902728 s/step
# on time step 1570 (time=7.85), 0.981181 s/step
# on time step 1575 (time=7.875), 0.910095 s/step
# on time step 1580 (time=7.9), 0.971585 s/step
# on time step 1585 (time=7.925), 0.917309 s/step
# on time step 1590 (time=7.95), 0.893445 s/step
# on time step 1595 (time=7.975), 0.898732 s/step
# on time step 1600 (time=8), 0.897849 s/step
# on time step 1605 (time=8.025), 0.895078 s/step
# on time step 1609 (time=8.045), 1.11843 s/step
# on time step 1614 (time=8.07), 0.908609 s/step
# on time step 1619 (time=8.095), 0.909136 s/step
# on time step 1624 (time=8.12), 0.964973 s/step
# on time step 1629 (time=8.145), 0.89071 s/step
# on time step 1634 (time=8.17), 0.897263 s/step
# on time step 1639 (time=8.195), 0.906704 s/step
# on time step 1644 (time=8.22), 0.894403 s/step
# on time step 1649 (time=8.245), 0.901902 s/step
# on time step 1654 (time=8.27), 0.941111 s/step
# on time step 1659 (time=8.295), 0.895315 s/step
# on time step 1664 (time=8.32), 0.904434 s/step
# on time step 1669 (time=8.345), 0.8785 s/step
# on time step 1674 (time=8.37), 0.911003 s/step
# on time step 1679 (time=8.395), 1.06139 s/step
# on time step 1684 (time=8.42), 0.894252 s/step
# on time step 1689 (time=8.445), 0.886166 s/step
# on time step 1694 (time=8.47), 0.900888 s/step
# on time step 1699 (time=8.495), 0.897808 s/step
# on time step 1704 (time=8.52), 0.928179 s/step
# on time step 1709 (time=8.545), 0.907078 s/step
# on time step 1714 (time=8.57), 0.939751 s/step
# on time step 1719 (time=8.595), 0.920409 s/step
# on time step 1724 (time=8.62), 0.911117 s/step
# on time step 1729 (time=8.645), 0.924039 s/step
# on time step 1734 (time=8.67), 0.904368 s/step
# on time step 1739 (time=8.695), 0.938145 s/step
# on time step 1744 (time=8.72), 0.966103 s/step
# on time step 1749 (time=8.745), 0.910458 s/step
# on time step 1753 (time=8.765), 1.08624 s/step
# on time step 1758 (time=8.79), 0.893889 s/step
# on time step 1763 (time=8.815), 0.931335 s/step
# on time step 1768 (time=8.84), 0.887245 s/step
# on time step 1773 (time=8.865), 0.949484 s/step
# on time step 1778 (time=8.89), 0.891865 s/step
# on time step 1783 (time=8.915), 0.953889 s/step
# on time step 1788 (time=8.94), 0.942521 s/step
# on time step 1793 (time=8.965), 0.886953 s/step
# on time step 1798 (time=8.99), 0.8842 s/step
# on time step 1803 (time=9.015), 0.900773 s/step
# on time step 1808 (time=9.04), 0.977291 s/step
# on time step 1813 (time=9.065), 0.907451 s/step
# on time step 1818 (time=9.09), 0.981942 s/step
# on time step 1823 (time=9.115), 0.909093 s/step
# on time step 1827 (time=9.135), 1.10842 s/step
# on time step 1832 (time=9.16), 0.879754 s/step
# on time step 1837 (time=9.185), 0.894473 s/step
# on time step 1842 (time=9.21), 0.898115 s/step
# on time step 1847 (time=9.235), 0.903484 s/step
# on time step 1852 (time=9.26), 0.897991 s/step
# on time step 1857 (time=9.285), 0.924471 s/step
# on time step 1862 (time=9.31), 0.947701 s/step
# on time step 1867 (time=9.335), 0.90807 s/step
# on time step 1872 (time=9.36), 0.894427 s/step
# on time step 1877 (time=9.385), 0.908245 s/step
# on time step 1882 (time=9.41), 0.899427 s/step
# on time step 1887 (time=9.435), 0.886546 s/step
# on time step 1892 (time=9.46), 0.891828 s/step
# on time step 1897 (time=9.485), 0.975025 s/step
# on time step 1901 (time=9.505), 1.14352 s/step
# on time step 1906 (time=9.53), 0.904318 s/step
# on time step 1911 (time=9.555), 0.946331 s/step
# on time step 1916 (time=9.58), 0.929541 s/step
# on time step 1921 (time=9.605), 0.912502 s/step
# on time step 1925 (time=9.625), 1.03683 s/step
# on time step 1929 (time=9.645), 1.03499 s/step
# on time step 1934 (time=9.67), 0.911747 s/step
# on time step 1939 (time=9.695), 0.943568 s/step
# on time step 1944 (time=9.72), 0.979176 s/step
# on time step 1949 (time=9.745), 0.922576 s/step
# on time step 1954 (time=9.77), 0.903709 s/step
# on time step 1959 (time=9.795), 0.887172 s/step
# on time step 1964 (time=9.82), 0.887508 s/step
# on time step 1969 (time=9.845), 0.933072 s/step
# on time step 1973 (time=9.865), 1.16659 s/step
# on time step 1978 (time=9.89), 0.953343 s/step
# on time step 1983 (time=9.915), 0.95416 s/step
# on time step 1988 (time=9.94), 0.949577 s/step
# on time step 1993 (time=9.965), 0.905749 s/step
# on time step 1998 (time=9.99), 0.901999 s/step
# field decay(t = 10.005): 8.26566328113221e-07 / 8.26566328113221e-07 = 1.0
# on time step 2003 (time=10.015), 0.959975 s/step
# on time step 2008 (time=10.04), 0.88968 s/step
# on time step 2013 (time=10.065), 0.876486 s/step
# on time step 2018 (time=10.09), 0.829874 s/step
# on time step 2024 (time=10.12), 0.70679 s/step
# on time step 2031 (time=10.155), 0.657006 s/step
# on time step 2037 (time=10.185), 0.677336 s/step
# on time step 2043 (time=10.215), 0.670228 s/step
# on time step 2047 (time=10.235), 1.0364 s/step
# on time step 2052 (time=10.26), 0.897125 s/step
# on time step 2057 (time=10.285), 0.872167 s/step
# on time step 2062 (time=10.31), 0.916791 s/step
# on time step 2067 (time=10.335), 0.903311 s/step
# on time step 2072 (time=10.36), 0.881759 s/step
# on time step 2077 (time=10.385), 0.869771 s/step
# on time step 2082 (time=10.41), 0.882093 s/step
# on time step 2087 (time=10.435), 0.872401 s/step
# on time step 2092 (time=10.46), 0.888562 s/step
# on time step 2097 (time=10.485), 0.881403 s/step
# on time step 2102 (time=10.51), 0.874317 s/step
# on time step 2107 (time=10.535), 0.880753 s/step
# on time step 2112 (time=10.56), 0.888094 s/step
# on time step 2116 (time=10.58), 1.00207 s/step
# on time step 2120 (time=10.6), 1.16302 s/step
# on time step 2125 (time=10.625), 0.939167 s/step
# on time step 2130 (time=10.65), 0.94244 s/step
# on time step 2135 (time=10.675), 0.964284 s/step
# on time step 2140 (time=10.7), 0.899787 s/step
# on time step 2145 (time=10.725), 0.909391 s/step
# on time step 2150 (time=10.75), 0.896522 s/step
# on time step 2155 (time=10.775), 0.898118 s/step
# on time step 2160 (time=10.8), 0.877494 s/step
# on time step 2165 (time=10.825), 0.881235 s/step
# on time step 2170 (time=10.85), 0.888561 s/step
# on time step 2175 (time=10.875), 0.898881 s/step
# on time step 2180 (time=10.9), 0.9158 s/step
# on time step 2185 (time=10.925), 0.935667 s/step
# on time step 2190 (time=10.95), 1.10004 s/step
# on time step 2195 (time=10.975), 0.890219 s/step
# on time step 2200 (time=11), 0.897545 s/step
# on time step 2205 (time=11.025), 0.893476 s/step
# on time step 2210 (time=11.05), 0.894095 s/step
# on time step 2215 (time=11.075), 0.882753 s/step
# on time step 2220 (time=11.1), 0.910039 s/step
# on time step 2225 (time=11.125), 0.915519 s/step
# on time step 2230 (time=11.15), 0.946772 s/step
# on time step 2235 (time=11.175), 0.933272 s/step
# on time step 2240 (time=11.2), 0.959133 s/step
# on time step 2245 (time=11.225), 0.912463 s/step
# on time step 2250 (time=11.25), 0.88213 s/step
# on time step 2255 (time=11.275), 0.93948 s/step
# on time step 2260 (time=11.3), 0.911777 s/step
# on time step 2264 (time=11.32), 1.11155 s/step
# on time step 2269 (time=11.345), 0.885011 s/step
# on time step 2274 (time=11.37), 0.877817 s/step
# on time step 2279 (time=11.395), 0.899738 s/step
# on time step 2284 (time=11.42), 0.957669 s/step
# on time step 2289 (time=11.445), 0.912858 s/step
# on time step 2294 (time=11.47), 0.876328 s/step
# on time step 2299 (time=11.495), 0.873821 s/step
# on time step 2304 (time=11.52), 0.889006 s/step
# on time step 2309 (time=11.545), 0.946894 s/step
# on time step 2314 (time=11.57), 0.971358 s/step
# on time step 2319 (time=11.595), 0.945908 s/step
# on time step 2323 (time=11.615), 1.00052 s/step
# on time step 2327 (time=11.635), 1.00498 s/step
# on time step 2332 (time=11.66), 0.956877 s/step
# on time step 2336 (time=11.68), 1.17078 s/step
# on time step 2341 (time=11.705), 0.904073 s/step
# on time step 2346 (time=11.73), 0.887553 s/step
# on time step 2351 (time=11.755), 0.891024 s/step
# on time step 2356 (time=11.78), 0.879561 s/step
# on time step 2361 (time=11.805), 0.887204 s/step
# on time step 2366 (time=11.83), 0.884013 s/step
# on time step 2371 (time=11.855), 0.897031 s/step
# on time step 2376 (time=11.88), 0.939716 s/step
# on time step 2381 (time=11.905), 0.924489 s/step
# on time step 2386 (time=11.93), 0.968183 s/step
# on time step 2390 (time=11.95), 1.00799 s/step
# on time step 2395 (time=11.975), 0.986052 s/step
# on time step 2400 (time=12), 0.966373 s/step
# on time step 2405 (time=12.025), 0.980214 s/step
# on time step 2409 (time=12.045), 1.20459 s/step
# on time step 2413 (time=12.065), 1.01457 s/step
# on time step 2418 (time=12.09), 0.85586 s/step
# on time step 2424 (time=12.12), 0.68549 s/step
# on time step 2431 (time=12.155), 0.668706 s/step
# on time step 2438 (time=12.19), 0.652592 s/step
# on time step 2445 (time=12.225), 0.641715 s/step
# on time step 2452 (time=12.26), 0.652086 s/step
# on time step 2458 (time=12.29), 0.677119 s/step
# on time step 2465 (time=12.325), 0.654728 s/step
# on time step 2472 (time=12.36), 0.651738 s/step
# on time step 2479 (time=12.395), 0.633161 s/step
# on time step 2485 (time=12.425), 0.756157 s/step
# on time step 2490 (time=12.45), 0.88214 s/step
# on time step 2495 (time=12.475), 0.886405 s/step
# on time step 2500 (time=12.5), 0.89135 s/step
# on time step 2505 (time=12.525), 0.887732 s/step
# on time step 2510 (time=12.55), 0.898287 s/step
# on time step 2515 (time=12.575), 0.890161 s/step
# on time step 2520 (time=12.6), 0.891281 s/step
# on time step 2525 (time=12.625), 0.884697 s/step
# on time step 2530 (time=12.65), 0.895235 s/step
# on time step 2535 (time=12.675), 0.888607 s/step
# on time step 2540 (time=12.7), 0.882818 s/step
# on time step 2545 (time=12.725), 0.907954 s/step
# on time step 2550 (time=12.75), 0.890619 s/step
# on time step 2555 (time=12.775), 1.06271 s/step
# on time step 2560 (time=12.8), 0.890005 s/step
# on time step 2565 (time=12.825), 0.907171 s/step
# on time step 2570 (time=12.85), 0.894205 s/step
# on time step 2575 (time=12.875), 0.894969 s/step
# on time step 2580 (time=12.9), 0.892189 s/step
# on time step 2585 (time=12.925), 0.910242 s/step
# on time step 2590 (time=12.95), 0.89421 s/step
# on time step 2595 (time=12.975), 0.889791 s/step
# on time step 2600 (time=13), 0.88876 s/step
# on time step 2605 (time=13.025), 0.88717 s/step
# on time step 2610 (time=13.05), 0.892248 s/step
# on time step 2615 (time=13.075), 0.878217 s/step
# on time step 2620 (time=13.1), 0.901787 s/step
# on time step 2625 (time=13.125), 0.897891 s/step
# on time step 2629 (time=13.145), 1.10265 s/step
# on time step 2634 (time=13.17), 0.890112 s/step
# on time step 2639 (time=13.195), 0.874708 s/step
# on time step 2644 (time=13.22), 0.899886 s/step
# on time step 2649 (time=13.245), 0.878497 s/step
# on time step 2654 (time=13.27), 0.897294 s/step
# on time step 2659 (time=13.295), 0.896213 s/step
# on time step 2663 (time=13.315), 1.02512 s/step
# on time step 2668 (time=13.34), 0.905448 s/step
# on time step 2673 (time=13.365), 0.875302 s/step
# on time step 2678 (time=13.39), 0.889142 s/step
# on time step 2683 (time=13.415), 0.875893 s/step
# on time step 2688 (time=13.44), 0.870152 s/step
# on time step 2693 (time=13.465), 0.874382 s/step
# on time step 2698 (time=13.49), 0.89151 s/step
# on time step 2702 (time=13.51), 1.0638 s/step
# on time step 2707 (time=13.535), 0.881352 s/step
# on time step 2712 (time=13.56), 0.87389 s/step
# on time step 2717 (time=13.585), 0.866965 s/step
# on time step 2722 (time=13.61), 0.885978 s/step
# on time step 2727 (time=13.635), 0.883278 s/step
# on time step 2732 (time=13.66), 0.883067 s/step
# on time step 2737 (time=13.685), 0.884206 s/step
# on time step 2742 (time=13.71), 0.925753 s/step
# on time step 2747 (time=13.735), 0.891111 s/step
# on time step 2752 (time=13.76), 0.909475 s/step
# on time step 2757 (time=13.785), 0.906493 s/step
# on time step 2762 (time=13.81), 0.923157 s/step
# on time step 2767 (time=13.835), 0.894232 s/step
# on time step 2772 (time=13.86), 0.898211 s/step
# on time step 2776 (time=13.88), 1.12166 s/step
# on time step 2781 (time=13.905), 0.933351 s/step
# on time step 2786 (time=13.93), 0.90705 s/step
# on time step 2791 (time=13.955), 0.895546 s/step
# on time step 2796 (time=13.98), 0.947969 s/step
# on time step 2800 (time=14), 1.00469 s/step
# on time step 2805 (time=14.025), 0.89789 s/step
# on time step 2810 (time=14.05), 0.971768 s/step
# on time step 2815 (time=14.075), 0.923599 s/step
# on time step 2820 (time=14.1), 0.890251 s/step
# on time step 2825 (time=14.125), 0.905114 s/step
# on time step 2830 (time=14.15), 0.92534 s/step
# on time step 2835 (time=14.175), 0.940486 s/step
# on time step 2840 (time=14.2), 0.925025 s/step
# on time step 2845 (time=14.225), 0.930084 s/step
# on time step 2849 (time=14.245), 1.14153 s/step
# on time step 2854 (time=14.27), 0.899082 s/step
# on time step 2859 (time=14.295), 0.900159 s/step
# on time step 2864 (time=14.32), 0.91881 s/step
# on time step 2869 (time=14.345), 0.93021 s/step
# on time step 2874 (time=14.37), 0.877116 s/step
# on time step 2879 (time=14.395), 0.903934 s/step
# on time step 2884 (time=14.42), 0.875874 s/step
# on time step 2889 (time=14.445), 0.897428 s/step
# on time step 2894 (time=14.47), 0.900386 s/step
# on time step 2899 (time=14.495), 0.905888 s/step
# on time step 2904 (time=14.52), 0.939844 s/step
# on time step 2909 (time=14.545), 0.89805 s/step
# on time step 2914 (time=14.57), 0.892629 s/step
# on time step 2919 (time=14.595), 0.902342 s/step
# on time step 2923 (time=14.615), 1.09822 s/step
# on time step 2928 (time=14.64), 0.893809 s/step
# on time step 2933 (time=14.665), 0.894473 s/step
# on time step 2938 (time=14.69), 0.964723 s/step
# on time step 2943 (time=14.715), 0.896576 s/step
# on time step 2948 (time=14.74), 0.877921 s/step
# on time step 2953 (time=14.765), 0.890232 s/step
# on time step 2958 (time=14.79), 0.897643 s/step
# on time step 2963 (time=14.815), 0.889435 s/step
# on time step 2968 (time=14.84), 0.927351 s/step
# on time step 2973 (time=14.865), 0.888648 s/step
# on time step 2978 (time=14.89), 0.896321 s/step
# on time step 2983 (time=14.915), 0.903993 s/step
# on time step 2988 (time=14.94), 0.968292 s/step
# on time step 2993 (time=14.965), 1.04682 s/step
# on time step 2998 (time=14.99), 0.904004 s/step
# on time step 3003 (time=15.015), 0.866241 s/step
# on time step 3008 (time=15.04), 0.899051 s/step
# on time step 3013 (time=15.065), 0.879342 s/step
# on time step 3018 (time=15.09), 0.907417 s/step
# on time step 3023 (time=15.115), 0.897966 s/step
# on time step 3028 (time=15.14), 0.902272 s/step
# on time step 3033 (time=15.165), 0.898878 s/step
# on time step 3038 (time=15.19), 0.930547 s/step
# on time step 3043 (time=15.215), 0.904593 s/step
# on time step 3048 (time=15.24), 0.881999 s/step
# on time step 3053 (time=15.265), 0.926497 s/step
# on time step 3058 (time=15.29), 0.929119 s/step
# on time step 3063 (time=15.315), 0.923504 s/step
# on time step 3067 (time=15.335), 1.08841 s/step
# on time step 3072 (time=15.36), 0.941702 s/step
# on time step 3077 (time=15.385), 0.884935 s/step
# on time step 3082 (time=15.41), 0.926169 s/step
# on time step 3087 (time=15.435), 0.943675 s/step
# on time step 3092 (time=15.46), 0.932226 s/step
# on time step 3097 (time=15.485), 0.916715 s/step
# on time step 3102 (time=15.51), 0.882343 s/step
# on time step 3107 (time=15.535), 0.88567 s/step
# on time step 3112 (time=15.56), 0.908656 s/step
# on time step 3117 (time=15.585), 0.990164 s/step
# on time step 3122 (time=15.61), 0.981572 s/step
# on time step 3126 (time=15.63), 1.02884 s/step
# on time step 3130 (time=15.65), 1.01933 s/step
# on time step 3135 (time=15.675), 0.973994 s/step
# on time step 3139 (time=15.695), 1.17261 s/step
# on time step 3144 (time=15.72), 0.883881 s/step
# on time step 3149 (time=15.745), 0.882731 s/step
# on time step 3154 (time=15.77), 0.871788 s/step
# on time step 3159 (time=15.795), 0.904127 s/step
# on time step 3164 (time=15.82), 0.939358 s/step
# on time step 3169 (time=15.845), 0.886144 s/step
# on time step 3174 (time=15.87), 0.887085 s/step
# on time step 3179 (time=15.895), 0.893977 s/step
# on time step 3184 (time=15.92), 0.891425 s/step
# on time step 3189 (time=15.945), 0.895169 s/step
# on time step 3194 (time=15.97), 0.889058 s/step
# on time step 3199 (time=15.995), 0.912056 s/step
# on time step 3204 (time=16.02), 0.917232 s/step
# on time step 3209 (time=16.045), 0.915253 s/step
# on time step 3213 (time=16.065), 1.06407 s/step
# on time step 3218 (time=16.09), 0.870469 s/step
# on time step 3223 (time=16.115), 0.952875 s/step
# on time step 3228 (time=16.14), 0.873724 s/step
# on time step 3233 (time=16.165), 0.87361 s/step
# on time step 3238 (time=16.19), 0.89519 s/step
# on time step 3243 (time=16.215), 0.961888 s/step
# on time step 3248 (time=16.24), 0.904318 s/step
# on time step 3253 (time=16.265), 0.938971 s/step
# on time step 3257 (time=16.285), 1.02654 s/step
# on time step 3262 (time=16.31), 0.919517 s/step
# on time step 3267 (time=16.335), 0.972413 s/step
# on time step 3272 (time=16.36), 0.865228 s/step
# on time step 3277 (time=16.385), 0.884692 s/step
# on time step 3282 (time=16.41), 0.866652 s/step
# on time step 3286 (time=16.43), 1.10071 s/step
# on time step 3291 (time=16.455), 0.909165 s/step
# on time step 3296 (time=16.48), 0.894806 s/step
# on time step 3301 (time=16.505), 0.942684 s/step
# on time step 3306 (time=16.53), 0.888493 s/step
# on time step 3311 (time=16.555), 0.935588 s/step
# on time step 3316 (time=16.58), 0.936881 s/step
# on time step 3321 (time=16.605), 0.873543 s/step
# on time step 3326 (time=16.63), 0.8648 s/step
# on time step 3331 (time=16.655), 0.867649 s/step
# on time step 3336 (time=16.68), 0.875417 s/step
# on time step 3341 (time=16.705), 0.870086 s/step
# on time step 3346 (time=16.73), 0.876279 s/step
# on time step 3351 (time=16.755), 0.883577 s/step
# on time step 3356 (time=16.78), 0.869333 s/step
# on time step 3360 (time=16.8), 1.06114 s/step
# on time step 3365 (time=16.825), 0.882161 s/step
# on time step 3370 (time=16.85), 0.876949 s/step
# on time step 3375 (time=16.875), 0.867901 s/step
# on time step 3380 (time=16.9), 0.901252 s/step
# on time step 3385 (time=16.925), 0.920482 s/step
# on time step 3390 (time=16.95), 0.870063 s/step
# on time step 3395 (time=16.975), 0.874171 s/step
# on time step 3400 (time=17), 0.946454 s/step
# on time step 3405 (time=17.025), 0.904421 s/step
# on time step 3410 (time=17.05), 0.865725 s/step
# on time step 3415 (time=17.075), 0.876659 s/step
# on time step 3420 (time=17.1), 0.873402 s/step
# on time step 3425 (time=17.125), 0.865081 s/step
# on time step 3430 (time=17.15), 0.860167 s/step
# on time step 3434 (time=17.17), 1.13167 s/step
# on time step 3439 (time=17.195), 0.915607 s/step
# on time step 3444 (time=17.22), 0.873449 s/step
# on time step 3449 (time=17.245), 0.884852 s/step
# on time step 3454 (time=17.27), 0.861621 s/step
# on time step 3459 (time=17.295), 0.899167 s/step
# on time step 3464 (time=17.32), 0.907453 s/step
# on time step 3469 (time=17.345), 0.908316 s/step
# on time step 3474 (time=17.37), 0.87955 s/step
# on time step 3479 (time=17.395), 0.89467 s/step
# on time step 3484 (time=17.42), 0.898884 s/step
# on time step 3489 (time=17.445), 0.874828 s/step
# on time step 3494 (time=17.47), 0.902052 s/step
# on time step 3499 (time=17.495), 0.91421 s/step
# on time step 3504 (time=17.52), 1.04938 s/step
# on time step 3509 (time=17.545), 0.865861 s/step
# on time step 3514 (time=17.57), 0.924409 s/step
# on time step 3519 (time=17.595), 0.932939 s/step
# on time step 3524 (time=17.62), 0.876448 s/step
# on time step 3529 (time=17.645), 0.88317 s/step
# on time step 3534 (time=17.67), 0.888099 s/step
# on time step 3539 (time=17.695), 0.870961 s/step
# on time step 3544 (time=17.72), 0.905852 s/step
# on time step 3549 (time=17.745), 0.873065 s/step
# on time step 3554 (time=17.77), 0.910039 s/step
# on time step 3559 (time=17.795), 0.911996 s/step
# on time step 3564 (time=17.82), 0.888833 s/step
# on time step 3569 (time=17.845), 0.912103 s/step
# on time step 3574 (time=17.87), 0.871963 s/step
# on time step 3578 (time=17.89), 1.12024 s/step
# on time step 3583 (time=17.915), 0.891848 s/step
# on time step 3588 (time=17.94), 0.865063 s/step
# on time step 3593 (time=17.965), 0.85986 s/step
# on time step 3598 (time=17.99), 0.855071 s/step
# on time step 3603 (time=18.015), 0.864657 s/step
# on time step 3608 (time=18.04), 0.855379 s/step
# on time step 3613 (time=18.065), 0.855761 s/step
# on time step 3618 (time=18.09), 0.859288 s/step
# on time step 3623 (time=18.115), 0.846743 s/step
# on time step 3628 (time=18.14), 0.858823 s/step
# on time step 3633 (time=18.165), 0.86047 s/step
# on time step 3638 (time=18.19), 0.85983 s/step
# on time step 3643 (time=18.215), 0.852434 s/step
# on time step 3648 (time=18.24), 0.865146 s/step
# on time step 3652 (time=18.26), 1.06238 s/step
# on time step 3657 (time=18.285), 0.873564 s/step
# on time step 3662 (time=18.31), 0.893766 s/step
# on time step 3667 (time=18.335), 0.888705 s/step
# on time step 3672 (time=18.36), 0.898967 s/step
# on time step 3677 (time=18.385), 0.895357 s/step
# on time step 3682 (time=18.41), 0.962537 s/step
# on time step 3687 (time=18.435), 0.893221 s/step
# on time step 3692 (time=18.46), 0.893319 s/step
# on time step 3697 (time=18.485), 0.915352 s/step
# on time step 3702 (time=18.51), 0.883955 s/step
# on time step 3707 (time=18.535), 0.869686 s/step
# on time step 3712 (time=18.56), 0.870309 s/step
# on time step 3717 (time=18.585), 0.910704 s/step
# on time step 3722 (time=18.61), 0.894108 s/step
# on time step 3726 (time=18.63), 1.1083 s/step
# on time step 3731 (time=18.655), 0.902493 s/step
# on time step 3736 (time=18.68), 0.893908 s/step
# on time step 3741 (time=18.705), 0.902511 s/step
# on time step 3746 (time=18.73), 0.941785 s/step
# on time step 3751 (time=18.755), 0.899898 s/step
# on time step 3756 (time=18.78), 0.895289 s/step
# on time step 3761 (time=18.805), 0.887825 s/step
# on time step 3766 (time=18.83), 0.876171 s/step
# on time step 3771 (time=18.855), 0.877846 s/step
# on time step 3776 (time=18.88), 0.950753 s/step
# on time step 3781 (time=18.905), 0.919714 s/step
# on time step 3786 (time=18.93), 0.913027 s/step
# on time step 3791 (time=18.955), 0.874802 s/step
# on time step 3796 (time=18.98), 1.06545 s/step
# on time step 3801 (time=19.005), 0.944772 s/step
# on time step 3806 (time=19.03), 0.922126 s/step
# on time step 3811 (time=19.055), 0.902699 s/step
# on time step 3816 (time=19.08), 0.951482 s/step
# on time step 3821 (time=19.105), 0.877984 s/step
# on time step 3826 (time=19.13), 0.902852 s/step
# on time step 3831 (time=19.155), 0.895305 s/step
# on time step 3836 (time=19.18), 0.9433 s/step
# on time step 3841 (time=19.205), 0.886874 s/step
# on time step 3846 (time=19.23), 0.907092 s/step
# on time step 3851 (time=19.255), 0.903457 s/step
# on time step 3856 (time=19.28), 0.948423 s/step
# on time step 3861 (time=19.305), 0.882437 s/step
# on time step 3866 (time=19.33), 0.866577 s/step
# on time step 3870 (time=19.35), 1.07712 s/step
# on time step 3875 (time=19.375), 0.871806 s/step
# on time step 3880 (time=19.4), 0.887398 s/step
# on time step 3885 (time=19.425), 0.877176 s/step
# on time step 3890 (time=19.45), 0.861953 s/step
# on time step 3895 (time=19.475), 0.870187 s/step
# on time step 3900 (time=19.5), 0.879653 s/step
# on time step 3905 (time=19.525), 0.883018 s/step
# on time step 3910 (time=19.55), 0.882484 s/step
# on time step 3915 (time=19.575), 0.881895 s/step
# on time step 3920 (time=19.6), 0.876351 s/step
# on time step 3925 (time=19.625), 0.874544 s/step
# on time step 3930 (time=19.65), 0.882075 s/step
# on time step 3935 (time=19.675), 0.88523 s/step
# on time step 3940 (time=19.7), 0.877623 s/step
# on time step 3944 (time=19.72), 1.05689 s/step
# on time step 3949 (time=19.745), 0.874518 s/step
# on time step 3954 (time=19.77), 0.864851 s/step
# on time step 3959 (time=19.795), 0.872888 s/step
# on time step 3964 (time=19.82), 0.919831 s/step
# on time step 3969 (time=19.845), 0.897166 s/step
# on time step 3974 (time=19.87), 0.886932 s/step
# on time step 3979 (time=19.895), 0.883191 s/step
# on time step 3984 (time=19.92), 0.893079 s/step
# on time step 3989 (time=19.945), 0.889852 s/step
# on time step 3994 (time=19.97), 0.954211 s/step
# on time step 3999 (time=19.995), 0.899864 s/step
# field decay(t = 20.01): 0.1460058335313089 / 0.1460058335313089 = 1.0
# on time step 4004 (time=20.02), 0.884251 s/step
# on time step 4009 (time=20.045), 0.91809 s/step
# on time step 4014 (time=20.07), 0.872401 s/step
# on time step 4018 (time=20.09), 1.16947 s/step
# on time step 4023 (time=20.115), 0.87314 s/step
# on time step 4028 (time=20.14), 0.903836 s/step
# on time step 4034 (time=20.17), 0.740483 s/step
# on time step 4041 (time=20.205), 0.646046 s/step
# on time step 4048 (time=20.24), 0.604329 s/step
# on time step 4055 (time=20.275), 0.609633 s/step
# on time step 4062 (time=20.31), 0.622936 s/step
# on time step 4069 (time=20.345), 0.601743 s/step
# on time step 4076 (time=20.38), 0.63105 s/step
# on time step 4083 (time=20.415), 0.601436 s/step
# on time step 4089 (time=20.445), 0.702902 s/step
# on time step 4096 (time=20.48), 0.616844 s/step
# on time step 4103 (time=20.515), 0.606458 s/step
# on time step 4110 (time=20.55), 0.609143 s/step
# on time step 4117 (time=20.585), 0.60549 s/step
# on time step 4124 (time=20.62), 0.613931 s/step
# on time step 4131 (time=20.655), 0.642034 s/step
# on time step 4138 (time=20.69), 0.616135 s/step
# on time step 4145 (time=20.725), 0.605922 s/step
# on time step 4152 (time=20.76), 0.602719 s/step
# on time step 4159 (time=20.795), 0.604203 s/step
# on time step 4165 (time=20.825), 0.743697 s/step
# on time step 4172 (time=20.86), 0.597133 s/step
# on time step 4179 (time=20.895), 0.608967 s/step
# on time step 4186 (time=20.93), 0.649202 s/step
# on time step 4193 (time=20.965), 0.644587 s/step
# on time step 4200 (time=21), 0.617467 s/step
# on time step 4207 (time=21.035), 0.617279 s/step
# on time step 4214 (time=21.07), 0.612564 s/step
# on time step 4221 (time=21.105), 0.641622 s/step
# on time step 4228 (time=21.14), 0.590071 s/step
# on time step 4234 (time=21.17), 0.69319 s/step
# on time step 4241 (time=21.205), 0.593792 s/step
# on time step 4248 (time=21.24), 0.590784 s/step
# on time step 4255 (time=21.275), 0.592032 s/step
# on time step 4262 (time=21.31), 0.595211 s/step
# on time step 4269 (time=21.345), 0.598928 s/step
# on time step 4276 (time=21.38), 0.604312 s/step
# on time step 4283 (time=21.415), 0.59745 s/step
# on time step 4290 (time=21.45), 0.591239 s/step
# on time step 4297 (time=21.485), 0.595643 s/step
# on time step 4304 (time=21.52), 0.601775 s/step
# on time step 4310 (time=21.55), 0.692996 s/step
# on time step 4317 (time=21.585), 0.59136 s/step
# on time step 4324 (time=21.62), 0.604714 s/step
# on time step 4331 (time=21.655), 0.603235 s/step
# on time step 4338 (time=21.69), 0.621197 s/step
# on time step 4345 (time=21.725), 0.609423 s/step
# on time step 4352 (time=21.76), 0.64032 s/step
# on time step 4359 (time=21.795), 0.612116 s/step
# on time step 4366 (time=21.83), 0.598858 s/step
# on time step 4373 (time=21.865), 0.596606 s/step
# on time step 4380 (time=21.9), 0.699233 s/step
# on time step 4387 (time=21.935), 0.655511 s/step
# on time step 4394 (time=21.97), 0.620886 s/step
# on time step 4401 (time=22.005), 0.639687 s/step
# on time step 4408 (time=22.04), 0.61925 s/step
# on time step 4415 (time=22.075), 0.600642 s/step
# on time step 4422 (time=22.11), 0.59372 s/step
# on time step 4429 (time=22.145), 0.592165 s/step
# on time step 4436 (time=22.18), 0.592642 s/step
# on time step 4443 (time=22.215), 0.590066 s/step
# on time step 4450 (time=22.25), 0.59179 s/step
# on time step 4456 (time=22.28), 0.705012 s/step
# on time step 4463 (time=22.315), 0.610964 s/step
# on time step 4470 (time=22.35), 0.598651 s/step
# on time step 4477 (time=22.385), 0.641206 s/step
# on time step 4484 (time=22.42), 0.601242 s/step
# on time step 4491 (time=22.455), 0.598919 s/step
# on time step 4498 (time=22.49), 0.607402 s/step
# on time step 4505 (time=22.525), 0.598069 s/step
# on time step 4512 (time=22.56), 0.603127 s/step
# on time step 4519 (time=22.595), 0.638328 s/step
# on time step 4526 (time=22.63), 0.689764 s/step
# on time step 4533 (time=22.665), 0.596952 s/step
# on time step 4540 (time=22.7), 0.597167 s/step
# on time step 4547 (time=22.735), 0.602602 s/step
# on time step 4554 (time=22.77), 0.600743 s/step
# on time step 4561 (time=22.805), 0.600318 s/step
# on time step 4568 (time=22.84), 0.597221 s/step
# on time step 4575 (time=22.875), 0.601172 s/step
# on time step 4582 (time=22.91), 0.601189 s/step
# on time step 4589 (time=22.945), 0.602905 s/step
# on time step 4596 (time=22.98), 0.603329 s/step
# on time step 4602 (time=23.01), 0.691964 s/step
# on time step 4609 (time=23.045), 0.602117 s/step
# on time step 4616 (time=23.08), 0.604198 s/step
# on time step 4623 (time=23.115), 0.603354 s/step
# on time step 4630 (time=23.15), 0.594218 s/step
# on time step 4637 (time=23.185), 0.604637 s/step
# on time step 4644 (time=23.22), 0.595662 s/step
# on time step 4651 (time=23.255), 0.598124 s/step
# on time step 4658 (time=23.29), 0.595836 s/step
# on time step 4665 (time=23.325), 0.602839 s/step
# on time step 4672 (time=23.36), 0.686222 s/step
# on time step 4679 (time=23.395), 0.602483 s/step
# on time step 4686 (time=23.43), 0.60652 s/step
# on time step 4693 (time=23.465), 0.601865 s/step
# on time step 4700 (time=23.5), 0.597533 s/step
# on time step 4707 (time=23.535), 0.597012 s/step
# on time step 4714 (time=23.57), 0.597224 s/step
# on time step 4721 (time=23.605), 0.605342 s/step
# on time step 4728 (time=23.64), 0.602961 s/step
# on time step 4735 (time=23.675), 0.595419 s/step
# on time step 4742 (time=23.71), 0.594919 s/step
# on time step 4748 (time=23.74), 0.694183 s/step
# on time step 4755 (time=23.775), 0.596551 s/step
# on time step 4762 (time=23.81), 0.596776 s/step
# on time step 4769 (time=23.845), 0.595922 s/step
# on time step 4776 (time=23.88), 0.600695 s/step
# on time step 4783 (time=23.915), 0.601654 s/step
# on time step 4790 (time=23.95), 0.602858 s/step
# on time step 4797 (time=23.985), 0.597138 s/step
# on time step 4804 (time=24.02), 0.606465 s/step
# on time step 4811 (time=24.055), 0.602217 s/step
# on time step 4818 (time=24.09), 0.71107 s/step
# on time step 4825 (time=24.125), 0.590968 s/step
# on time step 4832 (time=24.16), 0.590625 s/step
# on time step 4839 (time=24.195), 0.598572 s/step
# on time step 4846 (time=24.23), 0.595534 s/step
# on time step 4853 (time=24.265), 0.598479 s/step
# on time step 4860 (time=24.3), 0.600198 s/step
# on time step 4867 (time=24.335), 0.589257 s/step
# on time step 4874 (time=24.37), 0.590571 s/step
# on time step 4881 (time=24.405), 0.610982 s/step
# on time step 4888 (time=24.44), 0.601392 s/step
# on time step 4894 (time=24.47), 0.700793 s/step
# on time step 4901 (time=24.505), 0.596139 s/step
# on time step 4908 (time=24.54), 0.594296 s/step
# on time step 4915 (time=24.575), 0.632864 s/step
# on time step 4922 (time=24.61), 0.606924 s/step
# on time step 4929 (time=24.645), 0.61075 s/step
# on time step 4936 (time=24.68), 0.601963 s/step
# on time step 4943 (time=24.715), 0.597295 s/step
# on time step 4950 (time=24.75), 0.596453 s/step
# on time step 4957 (time=24.785), 0.603551 s/step
# on time step 4964 (time=24.82), 0.68578 s/step
# on time step 4971 (time=24.855), 0.617041 s/step
# on time step 4978 (time=24.89), 0.607779 s/step
# on time step 4985 (time=24.925), 0.611675 s/step
# on time step 4992 (time=24.96), 0.603574 s/step
# on time step 4999 (time=24.995), 0.600263 s/step
# on time step 5006 (time=25.03), 0.602476 s/step
# on time step 5013 (time=25.065), 0.59678 s/step
# on time step 5020 (time=25.1), 0.602372 s/step
# on time step 5027 (time=25.135), 0.596247 s/step
# on time step 5034 (time=25.17), 0.598786 s/step
# on time step 5040 (time=25.2), 0.701814 s/step
# on time step 5047 (time=25.235), 0.600882 s/step
# on time step 5054 (time=25.27), 0.591917 s/step
# on time step 5061 (time=25.305), 0.5984 s/step
# on time step 5068 (time=25.34), 0.598724 s/step
# on time step 5075 (time=25.375), 0.597262 s/step
# on time step 5082 (time=25.41), 0.600585 s/step
# on time step 5089 (time=25.445), 0.599664 s/step
# on time step 5096 (time=25.48), 0.604803 s/step
# on time step 5103 (time=25.515), 0.598438 s/step
# on time step 5110 (time=25.55), 0.686835 s/step
# on time step 5117 (time=25.585), 0.599854 s/step
# on time step 5124 (time=25.62), 0.601765 s/step
# on time step 5131 (time=25.655), 0.597367 s/step
# on time step 5138 (time=25.69), 0.598586 s/step
# on time step 5145 (time=25.725), 0.602076 s/step
# on time step 5152 (time=25.76), 0.600966 s/step
# on time step 5159 (time=25.795), 0.597285 s/step
# on time step 5166 (time=25.83), 0.600065 s/step
# on time step 5173 (time=25.865), 0.6027 s/step
# on time step 5180 (time=25.9), 0.603645 s/step
# on time step 5186 (time=25.93), 0.706779 s/step
# on time step 5193 (time=25.965), 0.602805 s/step
# on time step 5200 (time=26), 0.599485 s/step
# on time step 5207 (time=26.035), 0.603069 s/step
# on time step 5214 (time=26.07), 0.607708 s/step
# on time step 5221 (time=26.105), 0.602969 s/step
# on time step 5228 (time=26.14), 0.593633 s/step
# on time step 5235 (time=26.175), 0.594643 s/step
# on time step 5242 (time=26.21), 0.602381 s/step
# on time step 5249 (time=26.245), 0.605101 s/step
# on time step 5256 (time=26.28), 0.691446 s/step
# on time step 5263 (time=26.315), 0.604375 s/step
# on time step 5270 (time=26.35), 0.604217 s/step
# on time step 5277 (time=26.385), 0.591365 s/step
# on time step 5284 (time=26.42), 0.595358 s/step
# on time step 5291 (time=26.455), 0.59874 s/step
# on time step 5298 (time=26.49), 0.59178 s/step
# on time step 5305 (time=26.525), 0.597814 s/step
# on time step 5312 (time=26.56), 0.597407 s/step
# on time step 5319 (time=26.595), 0.593612 s/step
# on time step 5326 (time=26.63), 0.606494 s/step
# on time step 5332 (time=26.66), 0.704423 s/step
# on time step 5339 (time=26.695), 0.609595 s/step
# on time step 5346 (time=26.73), 0.599752 s/step
# on time step 5353 (time=26.765), 0.599462 s/step
# on time step 5360 (time=26.8), 0.595762 s/step
# on time step 5367 (time=26.835), 0.601028 s/step
# on time step 5374 (time=26.87), 0.60004 s/step
# ...
# on time step 21841 (time=109.205), 0.582608 s/step
# on time step 21848 (time=109.24), 0.589019 s/step
# on time step 21855 (time=109.275), 0.57836 s/step
# on time step 21862 (time=109.31), 0.581426 s/step
# on time step 21869 (time=109.345), 0.580177 s/step
# on time step 21876 (time=109.38), 0.581265 s/step
# on time step 21883 (time=109.415), 0.578226 s/step
# on time step 21890 (time=109.45), 0.577603 s/step
# on time step 21897 (time=109.485), 0.580305 s/step
# on time step 21903 (time=109.515), 0.679057 s/step
# on time step 21910 (time=109.55), 0.579569 s/step
# on time step 21917 (time=109.585), 0.58144 s/step
# on time step 21924 (time=109.62), 0.581288 s/step
# on time step 21931 (time=109.655), 0.581176 s/step
# on time step 21938 (time=109.69), 0.579025 s/step
# on time step 21945 (time=109.725), 0.579287 s/step
# on time step 21952 (time=109.76), 0.581393 s/step
# on time step 21959 (time=109.795), 0.583291 s/step
# on time step 21966 (time=109.83), 0.579628 s/step
# on time step 21973 (time=109.865), 0.666619 s/step
# on time step 21980 (time=109.9), 0.580255 s/step
# on time step 21987 (time=109.935), 0.578775 s/step
# on time step 21994 (time=109.97), 0.582966 s/step
# on time step 22001 (time=110.005), 0.582367 s/step
# on time step 22008 (time=110.04), 0.577531 s/step
# field decay(t = 110.055): 0.0004244537359437804 / 0.1460058335313089 = 0.002907101214231706
# on time step 22015 (time=110.075), 0.580581 s/step
# on time step 22022 (time=110.11), 0.581165 s/step
# on time step 22029 (time=110.145), 0.578882 s/step
# on time step 22036 (time=110.18), 0.581858 s/step
# on time step 22043 (time=110.215), 0.579118 s/step
# on time step 22049 (time=110.245), 0.680827 s/step
# on time step 22056 (time=110.28), 0.583134 s/step
# on time step 22063 (time=110.315), 0.57901 s/step
# on time step 22070 (time=110.35), 0.580765 s/step
# on time step 22077 (time=110.385), 0.57807 s/step
# on time step 22084 (time=110.42), 0.581446 s/step
# on time step 22091 (time=110.455), 0.579968 s/step
# on time step 22098 (time=110.49), 0.581727 s/step
# on time step 22105 (time=110.525), 0.580842 s/step
# on time step 22112 (time=110.56), 0.578898 s/step
# on time step 22119 (time=110.595), 0.667158 s/step
# on time step 22126 (time=110.63), 0.57939 s/step
# on time step 22133 (time=110.665), 0.580531 s/step
# on time step 22140 (time=110.7), 0.585171 s/step
# on time step 22147 (time=110.735), 0.577838 s/step
# on time step 22154 (time=110.77), 0.585279 s/step
# on time step 22161 (time=110.805), 0.580801 s/step
# on time step 22168 (time=110.84), 0.582281 s/step
# on time step 22175 (time=110.875), 0.58107 s/step
# on time step 22182 (time=110.91), 0.576981 s/step
# on time step 22189 (time=110.945), 0.577981 s/step
# on time step 22195 (time=110.975), 0.683307 s/step
# on time step 22202 (time=111.01), 0.578537 s/step
# on time step 22209 (time=111.045), 0.581536 s/step
# on time step 22216 (time=111.08), 0.58082 s/step
# on time step 22223 (time=111.115), 0.578992 s/step
# on time step 22230 (time=111.15), 0.579048 s/step
# on time step 22237 (time=111.185), 0.579347 s/step
# on time step 22244 (time=111.22), 0.579896 s/step
# on time step 22251 (time=111.255), 0.577735 s/step
# on time step 22258 (time=111.29), 0.580021 s/step
# on time step 22265 (time=111.325), 0.662739 s/step
# on time step 22272 (time=111.36), 0.577883 s/step
# on time step 22279 (time=111.395), 0.577103 s/step
# on time step 22286 (time=111.43), 0.576795 s/step
# on time step 22293 (time=111.465), 0.581071 s/step
# on time step 22300 (time=111.5), 0.582152 s/step
# on time step 22307 (time=111.535), 0.580614 s/step
# on time step 22314 (time=111.57), 0.577977 s/step
# on time step 22321 (time=111.605), 0.57771 s/step
# on time step 22328 (time=111.64), 0.58081 s/step
# on time step 22335 (time=111.675), 0.579669 s/step
# on time step 22341 (time=111.705), 0.682523 s/step
# on time step 22348 (time=111.74), 0.581782 s/step
# on time step 22355 (time=111.775), 0.59184 s/step
# on time step 22362 (time=111.81), 0.582053 s/step
# on time step 22369 (time=111.845), 0.58369 s/step
# on time step 22376 (time=111.88), 0.581206 s/step
# on time step 22383 (time=111.915), 0.590922 s/step
# on time step 22390 (time=111.95), 0.58108 s/step
# on time step 22397 (time=111.985), 0.590588 s/step
# on time step 22404 (time=112.02), 0.585539 s/step
# on time step 22411 (time=112.055), 0.668121 s/step
# on time step 22418 (time=112.09), 0.584507 s/step
# on time step 22425 (time=112.125), 0.5809 s/step
# on time step 22432 (time=112.16), 0.580024 s/step
# on time step 22439 (time=112.195), 0.576894 s/step
# on time step 22446 (time=112.23), 0.578664 s/step
# on time step 22453 (time=112.265), 0.584059 s/step
# on time step 22460 (time=112.3), 0.582271 s/step
# on time step 22467 (time=112.335), 0.581297 s/step
# on time step 22474 (time=112.37), 0.579128 s/step
# on time step 22481 (time=112.405), 0.582043 s/step
# on time step 22487 (time=112.435), 0.677744 s/step
# on time step 22494 (time=112.47), 0.583411 s/step
# on time step 22501 (time=112.505), 0.579649 s/step
# on time step 22508 (time=112.54), 0.583853 s/step
# on time step 22515 (time=112.575), 0.586558 s/step
# on time step 22522 (time=112.61), 0.580064 s/step
# on time step 22529 (time=112.645), 0.578634 s/step
# on time step 22536 (time=112.68), 0.592085 s/step
# on time step 22543 (time=112.715), 0.58803 s/step
# on time step 22550 (time=112.75), 0.577504 s/step
# on time step 22557 (time=112.785), 0.667907 s/step
# on time step 22564 (time=112.82), 0.58425 s/step
# on time step 22571 (time=112.855), 0.586125 s/step
# on time step 22578 (time=112.89), 0.581567 s/step
# on time step 22585 (time=112.925), 0.583453 s/step
# on time step 22592 (time=112.96), 0.580675 s/step
# on time step 22599 (time=112.995), 0.581731 s/step
# on time step 22606 (time=113.03), 0.581871 s/step
# on time step 22613 (time=113.065), 0.577884 s/step
# on time step 22620 (time=113.1), 0.581591 s/step
# on time step 22627 (time=113.135), 0.582324 s/step
# on time step 22633 (time=113.165), 0.679657 s/step
# on time step 22640 (time=113.2), 0.577068 s/step
# on time step 22647 (time=113.235), 0.589681 s/step
# on time step 22654 (time=113.27), 0.57835 s/step
# on time step 22661 (time=113.305), 0.580186 s/step
# on time step 22668 (time=113.34), 0.584286 s/step
# on time step 22675 (time=113.375), 0.580831 s/step
# on time step 22682 (time=113.41), 0.578994 s/step
# on time step 22689 (time=113.445), 0.579821 s/step
# on time step 22696 (time=113.48), 0.588537 s/step
# on time step 22703 (time=113.515), 0.664881 s/step
# on time step 22710 (time=113.55), 0.579846 s/step
# on time step 22717 (time=113.585), 0.578706 s/step
# on time step 22724 (time=113.62), 0.58017 s/step
# on time step 22731 (time=113.655), 0.577712 s/step
# on time step 22738 (time=113.69), 0.578569 s/step
# on time step 22745 (time=113.725), 0.580583 s/step
# on time step 22752 (time=113.76), 0.578708 s/step
# on time step 22759 (time=113.795), 0.58296 s/step
# on time step 22766 (time=113.83), 0.578935 s/step
# on time step 22773 (time=113.865), 0.582668 s/step
# on time step 22779 (time=113.895), 0.690983 s/step
# on time step 22786 (time=113.93), 0.583431 s/step
# on time step 22793 (time=113.965), 0.587371 s/step
# on time step 22800 (time=114), 0.588082 s/step
# on time step 22807 (time=114.035), 0.581888 s/step
# on time step 22814 (time=114.07), 0.584634 s/step
# on time step 22821 (time=114.105), 0.584862 s/step
# on time step 22828 (time=114.14), 0.589708 s/step
# on time step 22835 (time=114.175), 0.591342 s/step
# on time step 22842 (time=114.21), 0.580096 s/step
# on time step 22849 (time=114.245), 0.666454 s/step
# on time step 22856 (time=114.28), 0.577014 s/step
# on time step 22863 (time=114.315), 0.576626 s/step
# on time step 22870 (time=114.35), 0.580738 s/step
# on time step 22877 (time=114.385), 0.578331 s/step
# on time step 22884 (time=114.42), 0.579104 s/step
# on time step 22891 (time=114.455), 0.583465 s/step
# on time step 22898 (time=114.49), 0.585401 s/step
# on time step 22905 (time=114.525), 0.583472 s/step
# on time step 22912 (time=114.56), 0.584001 s/step
# on time step 22919 (time=114.595), 0.589835 s/step
# on time step 22925 (time=114.625), 0.680514 s/step
# on time step 22932 (time=114.66), 0.583815 s/step
# on time step 22939 (time=114.695), 0.579164 s/step
# on time step 22946 (time=114.73), 0.583343 s/step
# on time step 22953 (time=114.765), 0.579588 s/step
# on time step 22960 (time=114.8), 0.577645 s/step
# on time step 22967 (time=114.835), 0.581061 s/step
# on time step 22974 (time=114.87), 0.579677 s/step
# on time step 22981 (time=114.905), 0.580132 s/step
# on time step 22988 (time=114.94), 0.578704 s/step
# on time step 22995 (time=114.975), 0.665639 s/step
# on time step 23002 (time=115.01), 0.580485 s/step
# on time step 23009 (time=115.045), 0.581054 s/step
# on time step 23016 (time=115.08), 0.579153 s/step
# on time step 23023 (time=115.115), 0.582772 s/step
# on time step 23030 (time=115.15), 0.580855 s/step
# on time step 23037 (time=115.185), 0.580593 s/step
# on time step 23044 (time=115.22), 0.57792 s/step
# on time step 23051 (time=115.255), 0.577393 s/step
# on time step 23058 (time=115.29), 0.580418 s/step
# on time step 23065 (time=115.325), 0.580663 s/step
# on time step 23071 (time=115.355), 0.686963 s/step
# on time step 23078 (time=115.39), 0.586297 s/step
# on time step 23085 (time=115.425), 0.580853 s/step
# on time step 23092 (time=115.46), 0.579727 s/step
# on time step 23099 (time=115.495), 0.58062 s/step
# on time step 23106 (time=115.53), 0.580559 s/step
# on time step 23113 (time=115.565), 0.579227 s/step
# on time step 23120 (time=115.6), 0.580155 s/step
# on time step 23127 (time=115.635), 0.584476 s/step
# on time step 23134 (time=115.67), 0.582437 s/step
# on time step 23141 (time=115.705), 0.671321 s/step
# on time step 23148 (time=115.74), 0.581143 s/step
# on time step 23155 (time=115.775), 0.586919 s/step
# on time step 23162 (time=115.81), 0.580844 s/step
# on time step 23169 (time=115.845), 0.582417 s/step
# on time step 23176 (time=115.88), 0.584748 s/step
# on time step 23183 (time=115.915), 0.587609 s/step
# on time step 23190 (time=115.95), 0.58327 s/step
# on time step 23197 (time=115.985), 0.582429 s/step
# on time step 23204 (time=116.02), 0.584096 s/step
# on time step 23211 (time=116.055), 0.583776 s/step
# on time step 23217 (time=116.085), 0.684892 s/step
# on time step 23224 (time=116.12), 0.581437 s/step
# on time step 23231 (time=116.155), 0.585022 s/step
# on time step 23238 (time=116.19), 0.580208 s/step
# on time step 23245 (time=116.225), 0.585872 s/step
# on time step 23252 (time=116.26), 0.580836 s/step
# on time step 23259 (time=116.295), 0.58011 s/step
# on time step 23266 (time=116.33), 0.585775 s/step
# on time step 23273 (time=116.365), 0.576888 s/step
# on time step 23280 (time=116.4), 0.580084 s/step
# on time step 23287 (time=116.435), 0.669628 s/step
# on time step 23294 (time=116.47), 0.577677 s/step
# on time step 23301 (time=116.505), 0.586756 s/step
# on time step 23308 (time=116.54), 0.58824 s/step
# on time step 23315 (time=116.575), 0.588732 s/step
# on time step 23322 (time=116.61), 0.5825 s/step
# on time step 23329 (time=116.645), 0.58118 s/step
# on time step 23336 (time=116.68), 0.581204 s/step
# on time step 23343 (time=116.715), 0.583681 s/step
# on time step 23350 (time=116.75), 0.583158 s/step
# on time step 23357 (time=116.785), 0.583485 s/step
# on time step 23363 (time=116.815), 0.683242 s/step
# on time step 23370 (time=116.85), 0.592567 s/step
# on time step 23377 (time=116.885), 0.584807 s/step
# on time step 23384 (time=116.92), 0.581998 s/step
# on time step 23391 (time=116.955), 0.581223 s/step
# on time step 23398 (time=116.99), 0.585754 s/step
# on time step 23405 (time=117.025), 0.578376 s/step
# on time step 23412 (time=117.06), 0.579127 s/step
# on time step 23419 (time=117.095), 0.581448 s/step
# on time step 23426 (time=117.13), 0.577603 s/step
# on time step 23433 (time=117.165), 0.67602 s/step
# on time step 23440 (time=117.2), 0.581168 s/step
# on time step 23447 (time=117.235), 0.584122 s/step
# on time step 23454 (time=117.27), 0.581225 s/step
# on time step 23461 (time=117.305), 0.579693 s/step
# on time step 23468 (time=117.34), 0.579615 s/step
# on time step 23475 (time=117.375), 0.581528 s/step
# on time step 23482 (time=117.41), 0.581971 s/step
# on time step 23489 (time=117.445), 0.584667 s/step
# on time step 23496 (time=117.48), 0.580743 s/step
# on time step 23503 (time=117.515), 0.579347 s/step
# on time step 23509 (time=117.545), 0.679793 s/step
# on time step 23516 (time=117.58), 0.589205 s/step
# on time step 23523 (time=117.615), 0.58013 s/step
# on time step 23530 (time=117.65), 0.581281 s/step
# on time step 23537 (time=117.685), 0.582766 s/step
# on time step 23544 (time=117.72), 0.579647 s/step
# on time step 23551 (time=117.755), 0.578824 s/step
# on time step 23558 (time=117.79), 0.584366 s/step
# on time step 23565 (time=117.825), 0.580427 s/step
# on time step 23572 (time=117.86), 0.583831 s/step
# on time step 23579 (time=117.895), 0.666386 s/step
# on time step 23586 (time=117.93), 0.579235 s/step
# on time step 23593 (time=117.965), 0.57797 s/step
# on time step 23600 (time=118), 0.580277 s/step
# on time step 23607 (time=118.035), 0.577831 s/step
# on time step 23614 (time=118.07), 0.579124 s/step
# on time step 23621 (time=118.105), 0.581565 s/step
# on time step 23628 (time=118.14), 0.579264 s/step
# on time step 23635 (time=118.175), 0.578325 s/step
# on time step 23642 (time=118.21), 0.581586 s/step
# on time step 23649 (time=118.245), 0.58235 s/step
# on time step 23655 (time=118.275), 0.680759 s/step
# on time step 23662 (time=118.31), 0.579954 s/step
# on time step 23669 (time=118.345), 0.581681 s/step
# on time step 23676 (time=118.38), 0.582265 s/step
# on time step 23683 (time=118.415), 0.579335 s/step
# on time step 23690 (time=118.45), 0.582634 s/step
# on time step 23697 (time=118.485), 0.585255 s/step
# on time step 23704 (time=118.52), 0.582584 s/step
# on time step 23711 (time=118.555), 0.580098 s/step
# on time step 23718 (time=118.59), 0.587022 s/step
# on time step 23725 (time=118.625), 0.677053 s/step
# on time step 23732 (time=118.66), 0.592101 s/step
# on time step 23739 (time=118.695), 0.586757 s/step
# on time step 23746 (time=118.73), 0.579525 s/step
# on time step 23753 (time=118.765), 0.582698 s/step
# on time step 23760 (time=118.8), 0.580915 s/step
# on time step 23767 (time=118.835), 0.579202 s/step
# on time step 23774 (time=118.87), 0.582122 s/step
# on time step 23781 (time=118.905), 0.586374 s/step
# on time step 23788 (time=118.94), 0.583364 s/step
# on time step 23795 (time=118.975), 0.581236 s/step
# on time step 23801 (time=119.005), 0.683547 s/step
# on time step 23808 (time=119.04), 0.581057 s/step
# on time step 23815 (time=119.075), 0.584364 s/step
# on time step 23822 (time=119.11), 0.580906 s/step
# on time step 23829 (time=119.145), 0.58176 s/step
# on time step 23836 (time=119.18), 0.585143 s/step
# on time step 23843 (time=119.215), 0.580238 s/step
# on time step 23850 (time=119.25), 0.581036 s/step
# on time step 23857 (time=119.285), 0.584254 s/step
# on time step 23864 (time=119.32), 0.581649 s/step
# on time step 23871 (time=119.355), 0.670279 s/step
# on time step 23878 (time=119.39), 0.583476 s/step
# on time step 23885 (time=119.425), 0.582094 s/step
# on time step 23892 (time=119.46), 0.582724 s/step
# on time step 23899 (time=119.495), 0.581445 s/step
# on time step 23906 (time=119.53), 0.584184 s/step
# on time step 23913 (time=119.565), 0.58502 s/step
# on time step 23920 (time=119.6), 0.579508 s/step
# on time step 23927 (time=119.635), 0.581236 s/step
# on time step 23934 (time=119.67), 0.579187 s/step
# on time step 23941 (time=119.705), 0.579436 s/step
# on time step 23947 (time=119.735), 0.683791 s/step
# on time step 23954 (time=119.77), 0.577869 s/step
# on time step 23961 (time=119.805), 0.578562 s/step
# on time step 23968 (time=119.84), 0.588723 s/step
# on time step 23975 (time=119.875), 0.587594 s/step
# on time step 23982 (time=119.91), 0.582746 s/step
# on time step 23989 (time=119.945), 0.586305 s/step
# on time step 23996 (time=119.98), 0.592766 s/step
# on time step 24003 (time=120.015), 0.581992 s/step
# on time step 24010 (time=120.05), 0.580692 s/step
# field decay(t = 120.06): 5.8761886909996036e-05 / 0.1460058335313089 = 0.000402462596793404
# run 0 finished at t = 120.06 (24012 timesteps)

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / total_flux[i])
    Tg = np.append(Tg, green_flux[i] / total_flux[i])
    Tb = np.append(Tb, blue_flux[i] / total_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 투과율과 반사율

Rs = []
Ts = []
for i in range(nfreq):
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
convenional = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux_p[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux_p[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux_p[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux_p[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])

    convenional = np.append(convenional,0.25)

if mp.am_master():
    plt.figure(dpi=600)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    # plt.plot(wl, Trt, "r--",)
    # plt.plot(wl, Tgt+Tg0t, "g--",)
    # plt.plot(wl, Tbt, "b--",)
    # plt.plot(wl, convenional, 'k--')
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("Wavelength (μm)")
    plt.ylabel("Optical efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical_efficiency.png",bbox_inches='tight')

# %%
print(np.mean(Tr[0:66]))
print(np.mean(Tg[66:160]))
print(np.mean(Tb[160:300]))
print(max(Tr[0:66]))
print(max(Tg[66:160]))
print(max(Tb[160:300]))
print(max((Tr - Tg)[0:66]))
print(max((Tg - Tr)[66:160]))
print(max((Tb - Tr)[160:300]))
print(np.mean(Tr[66:300]))
print((sum(Tg[0:66]) + sum(Tg[160:300]))/206)
print(np.mean(Tb[0:160]))
# Out:
# 0.6156701723157638
# 0.29665501112301523
# 0.5003092591048153
# 0.8256978685297439
# 0.400332307162291
# 0.7128384758809595
# 0.8004531219759948
# 0.35317557040440384
# 0.6596097140907958
# 0.11670217400357141
# 0.07140533538332933
# 0.08806470661740629

# %%
fred = np.loadtxt('fred.txt')
fgreen = np.loadtxt('fgreen.txt')
fblue = np.loadtxt('fblue.txt')

plt.figure()

# plt.plot(evaluation_history/max(evaluation_history), "k-",label='total pixel')
plt.plot(fred/max(fred), "r-", linewidth='1')
plt.plot(fgreen/max(fgreen), "g-", linewidth='1')
plt.plot(fblue/max(fblue), "b-", linewidth='1')
plt.grid(False)
plt.axis([0, 211, 0, 1.03])
plt.tick_params(axis='x', direction='in', pad = 5)
plt.tick_params(axis='y', direction='in', pad = 10)
plt.xlabel("Iteration")
plt.ylabel("Normalized FoM")
# plt.legend(loc='right',frameon=False)
plt.savefig(design_dir+"FoMresultr.png",dpi=900,bbox_inches='tight')

# %%
from matplotlib.colors import LinearSegmentedColormap
gray_color = '#b9b9b9'
black_color = '#404040'

# Create a custom colormap from 'gray' to 'black'
cmap = LinearSegmentedColormap.from_list('gray_to_black', [gray_color, black_color])

# %%
plt.imshow(npa.rot90((structure_weight.reshape(Nx*Ny, Nz).transpose()[50]).reshape(Nx,Ny)), cmap=cmap)
plt.gca().axes.xaxis.set_visible(False)
plt.gca().axes.yaxis.set_visible(False)
plt.savefig(design_dir+"design_up.png",dpi=600,bbox_inches='tight',pad_inches=0)

# %%
plt.imshow(npa.rot90((structure_weight.reshape(Nx*Ny, Nz).transpose()[0]).reshape(Nx,Ny)), cmap=cmap)
plt.gca().axes.xaxis.set_visible(False)
plt.gca().axes.yaxis.set_visible(False)
plt.savefig(design_dir+"design_down.png",dpi=600,bbox_inches='tight',pad_inches=0)

# %%
plt.imshow(npa.rot90((structure_weight.reshape(Nx*Ny, Nz).transpose()[25]).reshape(Nx,Ny)), cmap=cmap)
plt.gca().axes.xaxis.set_visible(False)
plt.gca().axes.yaxis.set_visible(False)
plt.savefig(design_dir+"design_mid.png",dpi=600,bbox_inches='tight',pad_inches=0)

# %%
plt.imshow(npa.rot90((structure_weight.reshape(Nx,Ny,Nz)[0])), cmap=cmap)
plt.gca().axes.xaxis.set_visible(False)
plt.gca().axes.yaxis.set_visible(False)
plt.savefig(design_dir+"design_side1.png",dpi=1500)

# %%
plt.imshow(npa.rot90((structure_weight.reshape(Nx,Ny,Nz)[70])), cmap=cmap)
plt.gca().axes.xaxis.set_visible(False)
plt.gca().axes.yaxis.set_visible(False)
plt.savefig(design_dir+"design_side2.png",dpi=1500)
