# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=5)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 1 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * (design_region_width_x-air_gap*2))) + 1
Ny = int(round(design_region_resolution * (design_region_width_y-air_gap*2))) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1


# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, SiN, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000695944 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 73.3971% done, 1.45032 s remaining
# subpixel-averaging is 72.5184% done, 1.51615 s remaining
# subpixel-averaging is 73.2584% done, 1.46044 s remaining
# time for set_epsilon = 29.7567 s
# -----------
# on time step 1 (time=0.02), 8.05793 s/step
# on time step 19 (time=0.38), 0.228195 s/step
# on time step 37 (time=0.74), 0.226192 s/step
# on time step 55 (time=1.1), 0.226391 s/step
# on time step 73 (time=1.46), 0.226443 s/step
# on time step 91 (time=1.82), 0.226545 s/step
# on time step 109 (time=2.18), 0.225853 s/step
# on time step 127 (time=2.54), 0.226325 s/step
# on time step 145 (time=2.9), 0.22602 s/step
# on time step 163 (time=3.26), 0.225628 s/step
# on time step 181 (time=3.62), 0.226496 s/step
# on time step 199 (time=3.98), 0.226218 s/step
# on time step 217 (time=4.34), 0.22611 s/step
# on time step 235 (time=4.7), 0.226425 s/step
# on time step 253 (time=5.06), 0.226073 s/step
# on time step 271 (time=5.42), 0.226345 s/step
# on time step 289 (time=5.78), 0.225643 s/step
# on time step 309 (time=6.18), 0.201473 s/step
# on time step 327 (time=6.54), 0.225083 s/step
# on time step 345 (time=6.9), 0.225726 s/step
# on time step 363 (time=7.26), 0.224567 s/step
# on time step 381 (time=7.62), 0.225141 s/step
# on time step 404 (time=8.08), 0.182149 s/step
# on time step 422 (time=8.44), 0.225949 s/step
# on time step 440 (time=8.8), 0.227025 s/step
# on time step 458 (time=9.16), 0.225462 s/step
# on time step 476 (time=9.52), 0.226128 s/step
# on time step 494 (time=9.88), 0.226118 s/step
# field decay(t = 10.02): 1.7809636873553238e-07 / 1.7809636873553238e-07 = 1.0
# on time step 512 (time=10.24), 0.226257 s/step
# on time step 530 (time=10.6), 0.228281 s/step
# on time step 548 (time=10.96), 0.226539 s/step
# on time step 566 (time=11.32), 0.225967 s/step
# on time step 584 (time=11.68), 0.226542 s/step
# on time step 602 (time=12.04), 0.226037 s/step
# on time step 620 (time=12.4), 0.225461 s/step
# on time step 638 (time=12.76), 0.226361 s/step
# on time step 656 (time=13.12), 0.22616 s/step
# on time step 674 (time=13.48), 0.225811 s/step
# on time step 692 (time=13.84), 0.22638 s/step
# on time step 710 (time=14.2), 0.225665 s/step
# on time step 728 (time=14.56), 0.226057 s/step
# on time step 746 (time=14.92), 0.226202 s/step
# on time step 764 (time=15.28), 0.226171 s/step
# on time step 782 (time=15.64), 0.225921 s/step
# on time step 800 (time=16), 0.225845 s/step
# on time step 818 (time=16.36), 0.225346 s/step
# on time step 836 (time=16.72), 0.225717 s/step
# on time step 854 (time=17.08), 0.225551 s/step
# on time step 872 (time=17.44), 0.226288 s/step
# on time step 896 (time=17.92), 0.170713 s/step
# on time step 920 (time=18.4), 0.169761 s/step
# on time step 944 (time=18.88), 0.171526 s/step
# on time step 968 (time=19.36), 0.16969 s/step
# on time step 992 (time=19.84), 0.169093 s/step
# field decay(t = 20.04): 0.004867405545476801 / 0.004867405545476801 = 1.0
# on time step 1016 (time=20.32), 0.170046 s/step
# on time step 1040 (time=20.8), 0.170652 s/step
# on time step 1064 (time=21.28), 0.169233 s/step
# on time step 1088 (time=21.76), 0.169119 s/step
# on time step 1112 (time=22.24), 0.169351 s/step
# on time step 1136 (time=22.72), 0.169089 s/step
# on time step 1160 (time=23.2), 0.169511 s/step
# on time step 1184 (time=23.68), 0.168988 s/step
# on time step 1208 (time=24.16), 0.169067 s/step
# on time step 1232 (time=24.64), 0.170355 s/step
# on time step 1256 (time=25.12), 0.172707 s/step
# on time step 1280 (time=25.6), 0.170981 s/step
# on time step 1304 (time=26.08), 0.170667 s/step
# on time step 1328 (time=26.56), 0.170365 s/step
# on time step 1352 (time=27.04), 0.170438 s/step
# on time step 1376 (time=27.52), 0.170674 s/step
# on time step 1399 (time=27.98), 0.174052 s/step
# on time step 1423 (time=28.46), 0.170983 s/step
# on time step 1447 (time=28.94), 0.1706 s/step
# on time step 1471 (time=29.42), 0.170669 s/step
# on time step 1495 (time=29.9), 0.170417 s/step
# field decay(t = 30.060000000000002): 0.00862350968731374 / 0.00862350968731374 = 1.0
# on time step 1519 (time=30.38), 0.170923 s/step
# on time step 1543 (time=30.86), 0.172166 s/step
# on time step 1567 (time=31.34), 0.170316 s/step
# on time step 1591 (time=31.82), 0.170554 s/step
# on time step 1615 (time=32.3), 0.170775 s/step
# on time step 1639 (time=32.78), 0.170648 s/step
# on time step 1663 (time=33.26), 0.170156 s/step
# on time step 1687 (time=33.74), 0.170404 s/step
# on time step 1711 (time=34.22), 0.171167 s/step
# on time step 1735 (time=34.7), 0.170779 s/step
# on time step 1759 (time=35.18), 0.172444 s/step
# on time step 1783 (time=35.66), 0.170589 s/step
# on time step 1807 (time=36.14), 0.170446 s/step
# on time step 1831 (time=36.62), 0.173575 s/step
# on time step 1855 (time=37.1), 0.170139 s/step
# on time step 1879 (time=37.58), 0.170667 s/step
# on time step 1903 (time=38.06), 0.170243 s/step
# on time step 1927 (time=38.54), 0.17041 s/step
# on time step 1951 (time=39.02), 0.170456 s/step
# on time step 1974 (time=39.48), 0.17477 s/step
# on time step 1995 (time=39.9), 0.192306 s/step
# field decay(t = 40.06): 0.008725268749624926 / 0.008725268749624926 = 1.0
# on time step 2017 (time=40.34), 0.186218 s/step
# on time step 2040 (time=40.8), 0.182512 s/step
# on time step 2063 (time=41.26), 0.175314 s/step
# on time step 2087 (time=41.74), 0.170209 s/step
# on time step 2111 (time=42.22), 0.172964 s/step
# on time step 2134 (time=42.68), 0.175151 s/step
# on time step 2157 (time=43.14), 0.175317 s/step
# on time step 2181 (time=43.62), 0.17331 s/step
# on time step 2205 (time=44.1), 0.170725 s/step
# on time step 2229 (time=44.58), 0.170247 s/step
# on time step 2253 (time=45.06), 0.171412 s/step
# on time step 2277 (time=45.54), 0.173017 s/step
# on time step 2300 (time=46), 0.177047 s/step
# on time step 2324 (time=46.48), 0.171049 s/step
# on time step 2347 (time=46.94), 0.174959 s/step
# on time step 2370 (time=47.4), 0.17422 s/step
# on time step 2394 (time=47.88), 0.172092 s/step
# on time step 2418 (time=48.36), 0.170604 s/step
# on time step 2442 (time=48.84), 0.172128 s/step
# on time step 2465 (time=49.3), 0.175032 s/step
# on time step 2489 (time=49.78), 0.170843 s/step
# field decay(t = 50.08): 0.000543257869065429 / 0.008725268749624926 = 0.06226259438584996
# on time step 2513 (time=50.26), 0.169702 s/step
# on time step 2537 (time=50.74), 0.168892 s/step
# on time step 2561 (time=51.22), 0.168949 s/step
# on time step 2585 (time=51.7), 0.168822 s/step
# on time step 2609 (time=52.18), 0.168892 s/step
# on time step 2633 (time=52.66), 0.168765 s/step
# on time step 2657 (time=53.14), 0.168846 s/step
# on time step 2681 (time=53.62), 0.170316 s/step
# on time step 2704 (time=54.08), 0.179152 s/step
# on time step 2726 (time=54.52), 0.186862 s/step
# on time step 2749 (time=54.98), 0.178694 s/step
# on time step 2772 (time=55.44), 0.17809 s/step
# on time step 2796 (time=55.92), 0.169768 s/step
# on time step 2820 (time=56.4), 0.169797 s/step
# on time step 2844 (time=56.88), 0.173983 s/step
# on time step 2868 (time=57.36), 0.173659 s/step
# on time step 2890 (time=57.8), 0.182427 s/step
# on time step 2913 (time=58.26), 0.17922 s/step
# on time step 2936 (time=58.72), 0.180888 s/step
# on time step 2957 (time=59.14), 0.190681 s/step
# on time step 2978 (time=59.56), 0.193315 s/step
# on time step 2999 (time=59.98), 0.192424 s/step
# field decay(t = 60.1): 0.0002527391364290854 / 0.008725268749624926 = 0.028966344038394223
# on time step 3021 (time=60.42), 0.183698 s/step
# on time step 3043 (time=60.86), 0.183411 s/step
# on time step 3065 (time=61.3), 0.182478 s/step
# on time step 3087 (time=61.74), 0.184734 s/step
# on time step 3109 (time=62.18), 0.185077 s/step
# on time step 3131 (time=62.62), 0.185442 s/step
# on time step 3153 (time=63.06), 0.184405 s/step
# on time step 3175 (time=63.5), 0.182374 s/step
# on time step 3197 (time=63.94), 0.184682 s/step
# on time step 3219 (time=64.38), 0.185075 s/step
# on time step 3241 (time=64.82), 0.184343 s/step
# on time step 3263 (time=65.26), 0.182019 s/step
# on time step 3285 (time=65.7), 0.184594 s/step
# on time step 3307 (time=66.14), 0.187388 s/step
# on time step 3330 (time=66.6), 0.178871 s/step
# on time step 3351 (time=67.02), 0.195777 s/step
# on time step 3373 (time=67.46), 0.187796 s/step
# on time step 3395 (time=67.9), 0.182527 s/step
# on time step 3418 (time=68.36), 0.175282 s/step
# on time step 3440 (time=68.8), 0.184565 s/step
# on time step 3462 (time=69.24), 0.182616 s/step
# on time step 3485 (time=69.7), 0.181639 s/step
# field decay(t = 70.12): 3.9988045162970197e-05 / 0.008725268749624926 = 0.004583015871538532
# on time step 3507 (time=70.14), 0.186718 s/step
# on time step 3529 (time=70.58), 0.186837 s/step
# on time step 3552 (time=71.04), 0.177147 s/step
# on time step 3576 (time=71.52), 0.173109 s/step
# on time step 3600 (time=72), 0.173209 s/step
# on time step 3624 (time=72.48), 0.173284 s/step
# on time step 3648 (time=72.96), 0.173329 s/step
# on time step 3670 (time=73.4), 0.184684 s/step
# on time step 3693 (time=73.86), 0.176491 s/step
# on time step 3717 (time=74.34), 0.171061 s/step
# on time step 3741 (time=74.82), 0.171891 s/step
# on time step 3765 (time=75.3), 0.171838 s/step
# on time step 3789 (time=75.78), 0.173529 s/step
# on time step 3812 (time=76.24), 0.176635 s/step
# on time step 3836 (time=76.72), 0.172598 s/step
# on time step 3860 (time=77.2), 0.170228 s/step
# on time step 3883 (time=77.66), 0.176648 s/step
# on time step 3906 (time=78.12), 0.176152 s/step
# on time step 3930 (time=78.6), 0.173735 s/step
# on time step 3953 (time=79.06), 0.177294 s/step
# on time step 3977 (time=79.54), 0.173096 s/step
# on time step 4000 (time=80), 0.178136 s/step
# field decay(t = 80.14): 1.942881111620279e-06 / 0.008725268749624926 = 0.0002226729247398595
# run 0 finished at t = 80.14 (4007 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00063014 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 73.0734% done, 1.47408 s remaining
# subpixel-averaging is 72.9346% done, 1.4847 s remaining
# subpixel-averaging is 70.0441% done, 1.71118 s remaining
# time for set_epsilon = 30.1801 s
# -----------
# on time step 1 (time=0.02), 8.02806 s/step
# on time step 23 (time=0.46), 0.184508 s/step
# on time step 45 (time=0.9), 0.186869 s/step
# on time step 67 (time=1.34), 0.185989 s/step
# on time step 90 (time=1.8), 0.180476 s/step
# on time step 108 (time=2.16), 0.225114 s/step
# on time step 126 (time=2.52), 0.23588 s/step
# on time step 144 (time=2.88), 0.234573 s/step
# on time step 161 (time=3.22), 0.245499 s/step
# on time step 177 (time=3.54), 0.265718 s/step
# on time step 193 (time=3.86), 0.263071 s/step
# on time step 210 (time=4.2), 0.247654 s/step
# on time step 230 (time=4.6), 0.202095 s/step
# on time step 246 (time=4.92), 0.264647 s/step
# on time step 264 (time=5.28), 0.233187 s/step
# on time step 282 (time=5.64), 0.230787 s/step
# on time step 298 (time=5.96), 0.256445 s/step
# on time step 313 (time=6.26), 0.269967 s/step
# on time step 330 (time=6.6), 0.247512 s/step
# on time step 346 (time=6.92), 0.253888 s/step
# on time step 362 (time=7.24), 0.256111 s/step
# on time step 379 (time=7.58), 0.238844 s/step
# on time step 395 (time=7.9), 0.257107 s/step
# on time step 411 (time=8.22), 0.264592 s/step
# on time step 428 (time=8.56), 0.236274 s/step
# on time step 446 (time=8.92), 0.22552 s/step
# on time step 464 (time=9.28), 0.229827 s/step
# on time step 482 (time=9.64), 0.227283 s/step
# on time step 500 (time=10), 0.224563 s/step
# field decay(t = 10.02): 3.7538205295563295e-09 / 3.7538205295563295e-09 = 1.0
# on time step 518 (time=10.36), 0.224521 s/step
# on time step 536 (time=10.72), 0.22479 s/step
# on time step 554 (time=11.08), 0.225619 s/step
# on time step 572 (time=11.44), 0.2247 s/step
# on time step 590 (time=11.8), 0.224553 s/step
# on time step 608 (time=12.16), 0.22626 s/step
# on time step 626 (time=12.52), 0.225322 s/step
# on time step 644 (time=12.88), 0.223671 s/step
# on time step 662 (time=13.24), 0.224439 s/step
# on time step 680 (time=13.6), 0.225239 s/step
# on time step 698 (time=13.96), 0.225967 s/step
# on time step 716 (time=14.32), 0.225784 s/step
# on time step 734 (time=14.68), 0.224627 s/step
# on time step 752 (time=15.04), 0.22594 s/step
# on time step 770 (time=15.4), 0.22416 s/step
# on time step 788 (time=15.76), 0.224107 s/step
# on time step 806 (time=16.12), 0.224603 s/step
# on time step 824 (time=16.48), 0.22432 s/step
# on time step 842 (time=16.84), 0.225185 s/step
# on time step 860 (time=17.2), 0.225993 s/step
# on time step 878 (time=17.56), 0.2244 s/step
# on time step 896 (time=17.92), 0.225282 s/step
# on time step 914 (time=18.28), 0.226163 s/step
# on time step 932 (time=18.64), 0.225627 s/step
# on time step 950 (time=19), 0.225074 s/step
# on time step 968 (time=19.36), 0.225686 s/step
# on time step 986 (time=19.72), 0.225462 s/step
# field decay(t = 20.04): 0.0001264270236702211 / 0.0001264270236702211 = 1.0
# on time step 1004 (time=20.08), 0.224766 s/step
# on time step 1022 (time=20.44), 0.224471 s/step
# on time step 1044 (time=20.88), 0.183727 s/step
# on time step 1068 (time=21.36), 0.170334 s/step
# on time step 1092 (time=21.84), 0.169559 s/step
# on time step 1116 (time=22.32), 0.169472 s/step
# on time step 1140 (time=22.8), 0.17054 s/step
# on time step 1164 (time=23.28), 0.169215 s/step
# on time step 1188 (time=23.76), 0.17025 s/step
# on time step 1212 (time=24.24), 0.16889 s/step
# on time step 1236 (time=24.72), 0.168618 s/step
# on time step 1260 (time=25.2), 0.168213 s/step
# on time step 1284 (time=25.68), 0.168792 s/step
# on time step 1308 (time=26.16), 0.168302 s/step
# on time step 1332 (time=26.64), 0.168309 s/step
# on time step 1356 (time=27.12), 0.168832 s/step
# on time step 1380 (time=27.6), 0.168101 s/step
# on time step 1404 (time=28.08), 0.168404 s/step
# on time step 1428 (time=28.56), 0.168654 s/step
# on time step 1452 (time=29.04), 0.168515 s/step
# on time step 1476 (time=29.52), 0.168834 s/step
# on time step 1500 (time=30), 0.168497 s/step
# field decay(t = 30.060000000000002): 0.01704460987012745 / 0.01704460987012745 = 1.0
# on time step 1524 (time=30.48), 0.168429 s/step
# on time step 1548 (time=30.96), 0.168672 s/step
# on time step 1572 (time=31.44), 0.168741 s/step
# on time step 1596 (time=31.92), 0.168281 s/step
# on time step 1620 (time=32.4), 0.16913 s/step
# on time step 1644 (time=32.88), 0.168879 s/step
# on time step 1668 (time=33.36), 0.168838 s/step
# on time step 1692 (time=33.84), 0.168872 s/step
# on time step 1714 (time=34.28), 0.182635 s/step
# on time step 1737 (time=34.74), 0.17645 s/step
# on time step 1760 (time=35.2), 0.175472 s/step
# on time step 1784 (time=35.68), 0.170712 s/step
# on time step 1807 (time=36.14), 0.177818 s/step
# on time step 1831 (time=36.62), 0.172239 s/step
# on time step 1853 (time=37.06), 0.18197 s/step
# on time step 1876 (time=37.52), 0.177838 s/step
# on time step 1899 (time=37.98), 0.175871 s/step
# on time step 1923 (time=38.46), 0.172056 s/step
# on time step 1946 (time=38.92), 0.175469 s/step
# on time step 1968 (time=39.36), 0.182153 s/step
# on time step 1991 (time=39.82), 0.17471 s/step
# field decay(t = 40.06): 0.022574369104685042 / 0.022574369104685042 = 1.0
# on time step 2014 (time=40.28), 0.177189 s/step
# on time step 2038 (time=40.76), 0.172482 s/step
# on time step 2061 (time=41.22), 0.178593 s/step
# on time step 2084 (time=41.68), 0.179189 s/step
# on time step 2107 (time=42.14), 0.180269 s/step
# on time step 2131 (time=42.62), 0.172337 s/step
# on time step 2155 (time=43.1), 0.170897 s/step
# on time step 2177 (time=43.54), 0.188094 s/step
# on time step 2197 (time=43.94), 0.20336 s/step
# on time step 2220 (time=44.4), 0.178728 s/step
# on time step 2243 (time=44.86), 0.177302 s/step
# on time step 2261 (time=45.22), 0.234504 s/step
# on time step 2279 (time=45.58), 0.226482 s/step
# on time step 2297 (time=45.94), 0.229095 s/step
# on time step 2315 (time=46.3), 0.227221 s/step
# on time step 2333 (time=46.66), 0.227815 s/step
# on time step 2351 (time=47.02), 0.225766 s/step
# on time step 2369 (time=47.38), 0.226197 s/step
# on time step 2387 (time=47.74), 0.227198 s/step
# on time step 2405 (time=48.1), 0.226385 s/step
# on time step 2423 (time=48.46), 0.226387 s/step
# on time step 2441 (time=48.82), 0.227319 s/step
# on time step 2459 (time=49.18), 0.231488 s/step
# on time step 2477 (time=49.54), 0.225614 s/step
# on time step 2495 (time=49.9), 0.228382 s/step
# field decay(t = 50.08): 0.006328304085536638 / 0.022574369104685042 = 0.2803313818512551
# on time step 2513 (time=50.26), 0.227184 s/step
# on time step 2531 (time=50.62), 0.226543 s/step
# on time step 2549 (time=50.98), 0.22495 s/step
# on time step 2567 (time=51.34), 0.225613 s/step
# on time step 2585 (time=51.7), 0.225506 s/step
# on time step 2603 (time=52.06), 0.224541 s/step
# on time step 2621 (time=52.42), 0.227213 s/step
# on time step 2639 (time=52.78), 0.22605 s/step
# on time step 2657 (time=53.14), 0.229329 s/step
# on time step 2675 (time=53.5), 0.225866 s/step
# on time step 2693 (time=53.86), 0.225857 s/step
# on time step 2711 (time=54.22), 0.225887 s/step
# on time step 2729 (time=54.58), 0.225419 s/step
# on time step 2747 (time=54.94), 0.22527 s/step
# on time step 2765 (time=55.3), 0.226516 s/step
# on time step 2783 (time=55.66), 0.226824 s/step
# on time step 2801 (time=56.02), 0.226659 s/step
# on time step 2818 (time=56.36), 0.244797 s/step
# on time step 2833 (time=56.66), 0.268253 s/step
# on time step 2850 (time=57), 0.243107 s/step
# on time step 2866 (time=57.32), 0.251857 s/step
# on time step 2882 (time=57.64), 0.253222 s/step
# on time step 2899 (time=57.98), 0.238965 s/step
# on time step 2917 (time=58.34), 0.223453 s/step
# on time step 2935 (time=58.7), 0.225277 s/step
# on time step 2953 (time=59.06), 0.230478 s/step
# on time step 2971 (time=59.42), 0.233764 s/step
# on time step 2989 (time=59.78), 0.227924 s/step
# field decay(t = 60.1): 0.0005285452046688238 / 0.022574369104685042 = 0.023413509463665612
# on time step 3006 (time=60.12), 0.249186 s/step
# on time step 3023 (time=60.46), 0.248055 s/step
# on time step 3040 (time=60.8), 0.239656 s/step
# on time step 3058 (time=61.16), 0.224571 s/step
# on time step 3075 (time=61.5), 0.249691 s/step
# on time step 3092 (time=61.84), 0.241839 s/step
# on time step 3108 (time=62.16), 0.250511 s/step
# on time step 3125 (time=62.5), 0.238906 s/step
# on time step 3143 (time=62.86), 0.22835 s/step
# on time step 3161 (time=63.22), 0.233721 s/step
# on time step 3179 (time=63.58), 0.23042 s/step
# on time step 3197 (time=63.94), 0.229253 s/step
# on time step 3215 (time=64.3), 0.233815 s/step
# on time step 3232 (time=64.64), 0.236591 s/step
# on time step 3250 (time=65), 0.231214 s/step
# on time step 3267 (time=65.34), 0.236871 s/step
# on time step 3284 (time=65.68), 0.24258 s/step
# on time step 3301 (time=66.02), 0.238355 s/step
# on time step 3319 (time=66.38), 0.231822 s/step
# on time step 3336 (time=66.72), 0.235478 s/step
# on time step 3353 (time=67.06), 0.235521 s/step
# on time step 3370 (time=67.4), 0.23918 s/step
# on time step 3387 (time=67.74), 0.237594 s/step
# on time step 3405 (time=68.1), 0.230566 s/step
# on time step 3422 (time=68.44), 0.2383 s/step
# on time step 3440 (time=68.8), 0.229728 s/step
# on time step 3458 (time=69.16), 0.233759 s/step
# on time step 3476 (time=69.52), 0.224915 s/step
# on time step 3494 (time=69.88), 0.223505 s/step
# field decay(t = 70.12): 4.193995151589758e-05 / 0.022574369104685042 = 0.0018578570821362818
# on time step 3512 (time=70.24), 0.225715 s/step
# on time step 3530 (time=70.6), 0.225646 s/step
# on time step 3548 (time=70.96), 0.223835 s/step
# on time step 3566 (time=71.32), 0.224829 s/step
# on time step 3584 (time=71.68), 0.223476 s/step
# on time step 3602 (time=72.04), 0.22375 s/step
# on time step 3620 (time=72.4), 0.223349 s/step
# on time step 3638 (time=72.76), 0.223623 s/step
# on time step 3656 (time=73.12), 0.224184 s/step
# on time step 3674 (time=73.48), 0.224684 s/step
# on time step 3692 (time=73.84), 0.224896 s/step
# on time step 3710 (time=74.2), 0.22362 s/step
# on time step 3728 (time=74.56), 0.223565 s/step
# on time step 3746 (time=74.92), 0.22286 s/step
# on time step 3764 (time=75.28), 0.224528 s/step
# on time step 3782 (time=75.64), 0.224221 s/step
# on time step 3800 (time=76), 0.225214 s/step
# on time step 3818 (time=76.36), 0.22466 s/step
# on time step 3836 (time=76.72), 0.224756 s/step
# on time step 3854 (time=77.08), 0.223783 s/step
# on time step 3872 (time=77.44), 0.22404 s/step
# on time step 3888 (time=77.76), 0.251691 s/step
# on time step 3905 (time=78.1), 0.241033 s/step
# on time step 3923 (time=78.46), 0.230578 s/step
# on time step 3941 (time=78.82), 0.226747 s/step
# on time step 3959 (time=79.18), 0.228872 s/step
# on time step 3977 (time=79.54), 0.227123 s/step
# on time step 3995 (time=79.9), 0.226723 s/step
# field decay(t = 80.14): 2.1760004422330383e-05 / 0.022574369104685042 = 0.0009639252517499748
# run 0 finished at t = 80.14 (4007 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000709057 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.0615% done, 1.62899 s remaining
# subpixel-averaging is 71.8247% done, 1.56923 s remaining
# subpixel-averaging is 72.6571% done, 1.50586 s remaining
# time for set_epsilon = 30.113 s
# -----------
# on time step 1 (time=0.02), 8.1389 s/step
# on time step 19 (time=0.38), 0.228216 s/step
# on time step 37 (time=0.74), 0.231301 s/step
# on time step 55 (time=1.1), 0.227621 s/step
# on time step 72 (time=1.44), 0.241622 s/step
# on time step 89 (time=1.78), 0.244428 s/step
# on time step 106 (time=2.12), 0.240067 s/step
# on time step 124 (time=2.48), 0.234459 s/step
# on time step 142 (time=2.84), 0.224097 s/step
# on time step 160 (time=3.2), 0.222692 s/step
# on time step 178 (time=3.56), 0.224027 s/step
# on time step 196 (time=3.92), 0.223908 s/step
# on time step 214 (time=4.28), 0.222479 s/step
# on time step 232 (time=4.64), 0.223292 s/step
# on time step 250 (time=5), 0.224303 s/step
# on time step 268 (time=5.36), 0.231623 s/step
# on time step 284 (time=5.68), 0.250841 s/step
# on time step 302 (time=6.04), 0.233355 s/step
# on time step 320 (time=6.4), 0.233708 s/step
# on time step 338 (time=6.76), 0.228652 s/step
# on time step 358 (time=7.16), 0.202206 s/step
# on time step 380 (time=7.6), 0.182418 s/step
# on time step 403 (time=8.06), 0.180498 s/step
# on time step 424 (time=8.48), 0.19225 s/step
# on time step 441 (time=8.82), 0.240974 s/step
# on time step 458 (time=9.16), 0.245417 s/step
# on time step 475 (time=9.5), 0.241453 s/step
# on time step 491 (time=9.82), 0.254922 s/step
# field decay(t = 10.02): 7.3685555931583224e-09 / 7.3685555931583224e-09 = 1.0
# on time step 508 (time=10.16), 0.247018 s/step
# on time step 526 (time=10.52), 0.234413 s/step
# on time step 546 (time=10.92), 0.204661 s/step
# on time step 566 (time=11.32), 0.204355 s/step
# on time step 584 (time=11.68), 0.234869 s/step
# on time step 602 (time=12.04), 0.23344 s/step
# on time step 620 (time=12.4), 0.22716 s/step
# on time step 638 (time=12.76), 0.233024 s/step
# on time step 656 (time=13.12), 0.228106 s/step
# on time step 674 (time=13.48), 0.230077 s/step
# on time step 692 (time=13.84), 0.227651 s/step
# on time step 709 (time=14.18), 0.23804 s/step
# on time step 726 (time=14.52), 0.236707 s/step
# on time step 744 (time=14.88), 0.228618 s/step
# on time step 762 (time=15.24), 0.230158 s/step
# on time step 780 (time=15.6), 0.230487 s/step
# on time step 798 (time=15.96), 0.231939 s/step
# on time step 816 (time=16.32), 0.227149 s/step
# on time step 834 (time=16.68), 0.227293 s/step
# on time step 852 (time=17.04), 0.229885 s/step
# on time step 870 (time=17.4), 0.226647 s/step
# on time step 888 (time=17.76), 0.226458 s/step
# on time step 906 (time=18.12), 0.226549 s/step
# on time step 924 (time=18.48), 0.226449 s/step
# on time step 942 (time=18.84), 0.22799 s/step
# on time step 960 (time=19.2), 0.226464 s/step
# on time step 978 (time=19.56), 0.228467 s/step
# on time step 996 (time=19.92), 0.229034 s/step
# field decay(t = 20.04): 0.00022657518567611664 / 0.00022657518567611664 = 1.0
# on time step 1014 (time=20.28), 0.225412 s/step
# on time step 1032 (time=20.64), 0.225251 s/step
# on time step 1050 (time=21), 0.224942 s/step
# on time step 1068 (time=21.36), 0.225308 s/step
# on time step 1086 (time=21.72), 0.226861 s/step
# on time step 1104 (time=22.08), 0.223895 s/step
# on time step 1122 (time=22.44), 0.223947 s/step
# on time step 1140 (time=22.8), 0.226204 s/step
# on time step 1158 (time=23.16), 0.224655 s/step
# on time step 1176 (time=23.52), 0.224907 s/step
# on time step 1194 (time=23.88), 0.225154 s/step
# on time step 1212 (time=24.24), 0.22446 s/step
# on time step 1234 (time=24.68), 0.185295 s/step
# on time step 1258 (time=25.16), 0.168642 s/step
# on time step 1282 (time=25.64), 0.168632 s/step
# on time step 1306 (time=26.12), 0.16984 s/step
# on time step 1330 (time=26.6), 0.168361 s/step
# on time step 1354 (time=27.08), 0.168401 s/step
# on time step 1378 (time=27.56), 0.168968 s/step
# on time step 1402 (time=28.04), 0.168738 s/step
# on time step 1426 (time=28.52), 0.168587 s/step
# on time step 1450 (time=29), 0.168852 s/step
# on time step 1474 (time=29.48), 0.169417 s/step
# on time step 1498 (time=29.96), 0.169017 s/step
# field decay(t = 30.060000000000002): 0.042539804092535265 / 0.042539804092535265 = 1.0
# on time step 1522 (time=30.44), 0.169724 s/step
# on time step 1546 (time=30.92), 0.168486 s/step
# on time step 1570 (time=31.4), 0.169693 s/step
# on time step 1593 (time=31.86), 0.178711 s/step
# on time step 1615 (time=32.3), 0.183464 s/step
# on time step 1638 (time=32.76), 0.175192 s/step
# on time step 1662 (time=33.24), 0.170862 s/step
# on time step 1686 (time=33.72), 0.17181 s/step
# on time step 1709 (time=34.18), 0.17654 s/step
# on time step 1732 (time=34.64), 0.179168 s/step
# on time step 1756 (time=35.12), 0.174062 s/step
# on time step 1778 (time=35.56), 0.18614 s/step
# on time step 1800 (time=36), 0.188614 s/step
# on time step 1823 (time=36.46), 0.176703 s/step
# on time step 1847 (time=36.94), 0.173442 s/step
# on time step 1871 (time=37.42), 0.171644 s/step
# on time step 1895 (time=37.9), 0.170747 s/step
# on time step 1919 (time=38.38), 0.170209 s/step
# on time step 1943 (time=38.86), 0.170086 s/step
# on time step 1967 (time=39.34), 0.170639 s/step
# on time step 1991 (time=39.82), 0.1705 s/step
# field decay(t = 40.06): 0.07149941318905284 / 0.07149941318905284 = 1.0
# on time step 2015 (time=40.3), 0.171007 s/step
# on time step 2039 (time=40.78), 0.169993 s/step
# on time step 2063 (time=41.26), 0.169808 s/step
# on time step 2087 (time=41.74), 0.170481 s/step
# on time step 2111 (time=42.22), 0.170014 s/step
# on time step 2135 (time=42.7), 0.169939 s/step
# on time step 2159 (time=43.18), 0.170335 s/step
# on time step 2183 (time=43.66), 0.169909 s/step
# on time step 2207 (time=44.14), 0.170006 s/step
# on time step 2231 (time=44.62), 0.171089 s/step
# on time step 2255 (time=45.1), 0.170201 s/step
# on time step 2279 (time=45.58), 0.170357 s/step
# on time step 2303 (time=46.06), 0.170835 s/step
# on time step 2327 (time=46.54), 0.170011 s/step
# on time step 2350 (time=47), 0.179356 s/step
# on time step 2373 (time=47.46), 0.175992 s/step
# on time step 2395 (time=47.9), 0.190174 s/step
# on time step 2418 (time=48.36), 0.180819 s/step
# on time step 2441 (time=48.82), 0.179075 s/step
# on time step 2460 (time=49.2), 0.215506 s/step
# on time step 2478 (time=49.56), 0.234368 s/step
# on time step 2495 (time=49.9), 0.237162 s/step
# field decay(t = 50.08): 0.042082910655325906 / 0.07149941318905284 = 0.5885770075350654
# on time step 2513 (time=50.26), 0.232191 s/step
# on time step 2531 (time=50.62), 0.227817 s/step
# on time step 2549 (time=50.98), 0.225782 s/step
# on time step 2568 (time=51.36), 0.215855 s/step
# on time step 2589 (time=51.78), 0.194621 s/step
# on time step 2607 (time=52.14), 0.226452 s/step
# on time step 2625 (time=52.5), 0.226623 s/step
# on time step 2643 (time=52.86), 0.228187 s/step
# on time step 2661 (time=53.22), 0.226649 s/step
# on time step 2679 (time=53.58), 0.227147 s/step
# on time step 2697 (time=53.94), 0.230235 s/step
# on time step 2715 (time=54.3), 0.226638 s/step
# on time step 2733 (time=54.66), 0.227026 s/step
# on time step 2751 (time=55.02), 0.226206 s/step
# on time step 2769 (time=55.38), 0.226415 s/step
# on time step 2787 (time=55.74), 0.227912 s/step
# on time step 2805 (time=56.1), 0.226393 s/step
# on time step 2823 (time=56.46), 0.228032 s/step
# on time step 2841 (time=56.82), 0.227299 s/step
# on time step 2859 (time=57.18), 0.226774 s/step
# on time step 2877 (time=57.54), 0.227124 s/step
# on time step 2895 (time=57.9), 0.225939 s/step
# on time step 2913 (time=58.26), 0.227378 s/step
# on time step 2931 (time=58.62), 0.229562 s/step
# on time step 2949 (time=58.98), 0.226377 s/step
# on time step 2967 (time=59.34), 0.228416 s/step
# on time step 2985 (time=59.7), 0.225833 s/step
# on time step 3003 (time=60.06), 0.226551 s/step
# field decay(t = 60.1): 0.0034649050017707575 / 0.07149941318905284 = 0.04846060753826247
# on time step 3021 (time=60.42), 0.227286 s/step
# on time step 3039 (time=60.78), 0.225808 s/step
# on time step 3057 (time=61.14), 0.229562 s/step
# on time step 3075 (time=61.5), 0.226508 s/step
# on time step 3093 (time=61.86), 0.226091 s/step
# on time step 3111 (time=62.22), 0.227031 s/step
# on time step 3129 (time=62.58), 0.226008 s/step
# on time step 3147 (time=62.94), 0.226587 s/step
# on time step 3165 (time=63.3), 0.226713 s/step
# on time step 3183 (time=63.66), 0.225973 s/step
# on time step 3201 (time=64.02), 0.229678 s/step
# on time step 3219 (time=64.38), 0.227104 s/step
# on time step 3237 (time=64.74), 0.226091 s/step
# on time step 3255 (time=65.1), 0.226271 s/step
# on time step 3273 (time=65.46), 0.22689 s/step
# on time step 3293 (time=65.86), 0.202402 s/step
# on time step 3317 (time=66.34), 0.170893 s/step
# on time step 3341 (time=66.82), 0.170031 s/step
# on time step 3365 (time=67.3), 0.17044 s/step
# on time step 3389 (time=67.78), 0.170365 s/step
# on time step 3413 (time=68.26), 0.169875 s/step
# on time step 3437 (time=68.74), 0.169595 s/step
# on time step 3461 (time=69.22), 0.17025 s/step
# on time step 3485 (time=69.7), 0.169903 s/step
# field decay(t = 70.12): 0.0001531592509915193 / 0.07149941318905284 = 0.0021421050070236
# on time step 3509 (time=70.18), 0.170955 s/step
# on time step 3533 (time=70.66), 0.17041 s/step
# on time step 3557 (time=71.14), 0.170162 s/step
# on time step 3581 (time=71.62), 0.172023 s/step
# on time step 3605 (time=72.1), 0.173749 s/step
# on time step 3629 (time=72.58), 0.170236 s/step
# on time step 3653 (time=73.06), 0.170554 s/step
# on time step 3677 (time=73.54), 0.169613 s/step
# on time step 3701 (time=74.02), 0.169916 s/step
# on time step 3725 (time=74.5), 0.170121 s/step
# on time step 3749 (time=74.98), 0.169696 s/step
# on time step 3773 (time=75.46), 0.169644 s/step
# on time step 3797 (time=75.94), 0.169345 s/step
# on time step 3821 (time=76.42), 0.169412 s/step
# on time step 3845 (time=76.9), 0.169981 s/step
# on time step 3869 (time=77.38), 0.169954 s/step
# on time step 3893 (time=77.86), 0.169726 s/step
# on time step 3917 (time=78.34), 0.170002 s/step
# on time step 3941 (time=78.82), 0.170053 s/step
# on time step 3963 (time=79.26), 0.183397 s/step
# on time step 3986 (time=79.72), 0.181185 s/step
# field decay(t = 80.14): 8.650537449140607e-05 / 0.07149941318905284 = 0.0012098753071256082
# on time step 4009 (time=80.18), 0.174228 s/step
# on time step 4032 (time=80.64), 0.181044 s/step
# on time step 4055 (time=81.1), 0.181195 s/step
# on time step 4077 (time=81.54), 0.190362 s/step
# on time step 4099 (time=81.98), 0.186121 s/step
# on time step 4123 (time=82.46), 0.170875 s/step
# on time step 4147 (time=82.94), 0.169971 s/step
# on time step 4171 (time=83.42), 0.169813 s/step
# on time step 4195 (time=83.9), 0.169308 s/step
# on time step 4219 (time=84.38), 0.169455 s/step
# on time step 4243 (time=84.86), 0.172193 s/step
# on time step 4267 (time=85.34), 0.170448 s/step
# on time step 4291 (time=85.82), 0.169682 s/step
# on time step 4315 (time=86.3), 0.169761 s/step
# on time step 4339 (time=86.78), 0.16969 s/step
# on time step 4363 (time=87.26), 0.169769 s/step
# on time step 4387 (time=87.74), 0.16924 s/step
# on time step 4411 (time=88.22), 0.1695 s/step
# on time step 4435 (time=88.7), 0.169549 s/step
# on time step 4459 (time=89.18), 0.16942 s/step
# on time step 4483 (time=89.66), 0.169632 s/step
# on time step 4507 (time=90.14), 0.16971 s/step
# field decay(t = 90.16): 2.875147669522702e-05 / 0.07149941318905284 = 0.00040212185545082364
# run 0 finished at t = 90.16 (4508 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000375986 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 7.45673 s
# -----------
# on time step 1 (time=0.02), 7.78814 s/step
# on time step 28 (time=0.56), 0.153526 s/step
# on time step 54 (time=1.08), 0.158011 s/step
# on time step 80 (time=1.6), 0.153905 s/step
# on time step 106 (time=2.12), 0.153867 s/step
# on time step 132 (time=2.64), 0.15875 s/step
# on time step 159 (time=3.18), 0.153511 s/step
# on time step 185 (time=3.7), 0.158569 s/step
# on time step 212 (time=4.24), 0.153243 s/step
# on time step 238 (time=4.76), 0.157419 s/step
# on time step 265 (time=5.3), 0.15353 s/step
# on time step 291 (time=5.82), 0.157701 s/step
# on time step 318 (time=6.36), 0.153306 s/step
# on time step 344 (time=6.88), 0.157573 s/step
# on time step 370 (time=7.4), 0.156317 s/step
# on time step 396 (time=7.92), 0.158444 s/step
# on time step 422 (time=8.44), 0.153988 s/step
# on time step 449 (time=8.98), 0.153522 s/step
# on time step 475 (time=9.5), 0.157584 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 502 (time=10.04), 0.1534 s/step
# on time step 528 (time=10.56), 0.157469 s/step
# on time step 555 (time=11.1), 0.153271 s/step
# on time step 581 (time=11.62), 0.157588 s/step
# on time step 608 (time=12.16), 0.153097 s/step
# on time step 634 (time=12.68), 0.157884 s/step
# on time step 661 (time=13.22), 0.153577 s/step
# on time step 687 (time=13.74), 0.157698 s/step
# on time step 714 (time=14.28), 0.153069 s/step
# on time step 740 (time=14.8), 0.157541 s/step
# on time step 767 (time=15.34), 0.153355 s/step
# on time step 792 (time=15.84), 0.163003 s/step
# on time step 818 (time=16.36), 0.157387 s/step
# on time step 844 (time=16.88), 0.1549 s/step
# on time step 869 (time=17.38), 0.162867 s/step
# on time step 894 (time=17.88), 0.166642 s/step
# on time step 918 (time=18.36), 0.171777 s/step
# on time step 943 (time=18.86), 0.162698 s/step
# on time step 970 (time=19.4), 0.153184 s/step
# on time step 996 (time=19.92), 0.158649 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1023 (time=20.46), 0.152939 s/step
# on time step 1049 (time=20.98), 0.157686 s/step
# on time step 1076 (time=21.52), 0.153117 s/step
# on time step 1101 (time=22.02), 0.160287 s/step
# on time step 1128 (time=22.56), 0.152741 s/step
# on time step 1154 (time=23.08), 0.157066 s/step
# on time step 1181 (time=23.62), 0.152973 s/step
# on time step 1207 (time=24.14), 0.157728 s/step
# on time step 1234 (time=24.68), 0.153499 s/step
# on time step 1260 (time=25.2), 0.157114 s/step
# on time step 1287 (time=25.74), 0.152636 s/step
# on time step 1314 (time=26.28), 0.156667 s/step
# on time step 1341 (time=26.82), 0.15296 s/step
# on time step 1368 (time=27.36), 0.157277 s/step
# on time step 1395 (time=27.9), 0.152873 s/step
# on time step 1422 (time=28.44), 0.156498 s/step
# on time step 1449 (time=28.98), 0.153638 s/step
# on time step 1476 (time=29.52), 0.157311 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000624895 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.9172% done, 1.56223 s remaining
# subpixel-averaging is 74.2527% done, 1.38728 s remaining
# subpixel-averaging is 74.854% done, 1.34416 s remaining
# time for set_epsilon = 29.3173 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 7.75813 s/step
# on time step 24 (time=0.48), 0.175183 s/step
# on time step 47 (time=0.94), 0.174479 s/step
# on time step 71 (time=1.42), 0.17315 s/step
# on time step 94 (time=1.88), 0.179505 s/step
# on time step 118 (time=2.36), 0.173092 s/step
# on time step 142 (time=2.84), 0.173474 s/step
# on time step 165 (time=3.3), 0.179496 s/step
# on time step 189 (time=3.78), 0.173023 s/step
# on time step 213 (time=4.26), 0.173343 s/step
# on time step 236 (time=4.72), 0.179613 s/step
# on time step 259 (time=5.18), 0.174046 s/step
# on time step 282 (time=5.64), 0.174796 s/step
# on time step 305 (time=6.1), 0.174851 s/step
# on time step 328 (time=6.56), 0.180059 s/step
# on time step 351 (time=7.02), 0.174554 s/step
# on time step 374 (time=7.48), 0.17414 s/step
# on time step 397 (time=7.94), 0.180412 s/step
# on time step 420 (time=8.4), 0.174854 s/step
# on time step 443 (time=8.86), 0.17458 s/step
# on time step 466 (time=9.32), 0.174645 s/step
# on time step 488 (time=9.76), 0.181823 s/step
# field decay(t = 10.02): 0.0011280885028027037 / 0.0011280885028027037 = 1.0
# on time step 511 (time=10.22), 0.175143 s/step
# on time step 535 (time=10.7), 0.173368 s/step
# on time step 558 (time=11.16), 0.179558 s/step
# on time step 582 (time=11.64), 0.173315 s/step
# on time step 605 (time=12.1), 0.175716 s/step
# on time step 629 (time=12.58), 0.173128 s/step
# on time step 651 (time=13.02), 0.185783 s/step
# on time step 672 (time=13.44), 0.195438 s/step
# on time step 694 (time=13.88), 0.185734 s/step
# on time step 717 (time=14.34), 0.175824 s/step
# on time step 740 (time=14.8), 0.180743 s/step
# on time step 763 (time=15.26), 0.174654 s/step
# on time step 786 (time=15.72), 0.176501 s/step
# on time step 809 (time=16.18), 0.179175 s/step
# on time step 831 (time=16.62), 0.183529 s/step
# on time step 854 (time=17.08), 0.174654 s/step
# on time step 877 (time=17.54), 0.174748 s/step
# on time step 900 (time=18), 0.180538 s/step
# on time step 923 (time=18.46), 0.17478 s/step
# on time step 946 (time=18.92), 0.174257 s/step
# on time step 969 (time=19.38), 0.174942 s/step
# on time step 992 (time=19.84), 0.180809 s/step
# field decay(t = 20.04): 0.040876979508742375 / 0.040876979508742375 = 1.0
# on time step 1015 (time=20.3), 0.174698 s/step
# on time step 1038 (time=20.76), 0.174384 s/step
# on time step 1061 (time=21.22), 0.174862 s/step
# on time step 1084 (time=21.68), 0.180443 s/step
# on time step 1107 (time=22.14), 0.174329 s/step
# on time step 1130 (time=22.6), 0.174869 s/step
# on time step 1152 (time=23.04), 0.183291 s/step
# on time step 1175 (time=23.5), 0.175091 s/step
# on time step 1198 (time=23.96), 0.174632 s/step
# on time step 1221 (time=24.42), 0.174293 s/step
# on time step 1244 (time=24.88), 0.18069 s/step
# on time step 1267 (time=25.34), 0.174804 s/step
# on time step 1290 (time=25.8), 0.174818 s/step
# on time step 1313 (time=26.26), 0.17688 s/step
# on time step 1336 (time=26.72), 0.18073 s/step
# on time step 1359 (time=27.18), 0.174442 s/step
# on time step 1382 (time=27.64), 0.174528 s/step
# on time step 1404 (time=28.08), 0.18364 s/step
# on time step 1427 (time=28.54), 0.174644 s/step
# on time step 1450 (time=29), 0.175274 s/step
# on time step 1473 (time=29.46), 0.174496 s/step
# on time step 1496 (time=29.92), 0.180513 s/step
# field decay(t = 30.060000000000002): 0.0005862806524625048 / 0.040876979508742375 = 0.014342562965962707
# on time step 1519 (time=30.38), 0.175002 s/step
# on time step 1542 (time=30.84), 0.174407 s/step
# on time step 1565 (time=31.3), 0.174715 s/step
# on time step 1588 (time=31.76), 0.180698 s/step
# on time step 1611 (time=32.22), 0.174307 s/step
# on time step 1634 (time=32.68), 0.17448 s/step
# on time step 1656 (time=33.12), 0.181842 s/step
# on time step 1679 (time=33.58), 0.174602 s/step
# on time step 1702 (time=34.04), 0.176474 s/step
# on time step 1725 (time=34.5), 0.178015 s/step
# on time step 1747 (time=34.94), 0.187236 s/step
# on time step 1770 (time=35.4), 0.174301 s/step
# on time step 1793 (time=35.86), 0.174452 s/step
# on time step 1816 (time=36.32), 0.174366 s/step
# on time step 1837 (time=36.74), 0.193037 s/step
# on time step 1859 (time=37.18), 0.187801 s/step
# on time step 1880 (time=37.6), 0.197585 s/step
# on time step 1901 (time=38.02), 0.196403 s/step
# on time step 1923 (time=38.46), 0.187566 s/step
# on time step 1944 (time=38.88), 0.194938 s/step
# on time step 1966 (time=39.32), 0.185603 s/step
# on time step 1988 (time=39.76), 0.187223 s/step
# field decay(t = 40.06): 0.00027525035311363566 / 0.040876979508742375 = 0.006733627494535592
# on time step 2010 (time=40.2), 0.185838 s/step
# on time step 2032 (time=40.64), 0.18571 s/step
# on time step 2053 (time=41.06), 0.196316 s/step
# on time step 2075 (time=41.5), 0.186085 s/step
# on time step 2097 (time=41.94), 0.18737 s/step
# on time step 2118 (time=42.36), 0.191538 s/step
# on time step 2139 (time=42.78), 0.195984 s/step
# on time step 2160 (time=43.2), 0.20624 s/step
# on time step 2182 (time=43.64), 0.187939 s/step
# on time step 2205 (time=44.1), 0.176943 s/step
# on time step 2228 (time=44.56), 0.176748 s/step
# on time step 2250 (time=45), 0.183439 s/step
# on time step 2273 (time=45.46), 0.17619 s/step
# on time step 2296 (time=45.92), 0.180717 s/step
# on time step 2319 (time=46.38), 0.178453 s/step
# on time step 2341 (time=46.82), 0.181854 s/step
# on time step 2364 (time=47.28), 0.174968 s/step
# on time step 2387 (time=47.74), 0.175926 s/step
# on time step 2410 (time=48.2), 0.175793 s/step
# on time step 2432 (time=48.64), 0.183952 s/step
# on time step 2455 (time=49.1), 0.177357 s/step
# on time step 2478 (time=49.56), 0.175867 s/step
# on time step 2501 (time=50.02), 0.176039 s/step
# field decay(t = 50.08): 4.246270363586663e-05 / 0.040876979508742375 = 0.001038792595396759
# on time step 2523 (time=50.46), 0.186017 s/step
# on time step 2546 (time=50.92), 0.175552 s/step
# on time step 2569 (time=51.38), 0.174928 s/step
# on time step 2592 (time=51.84), 0.181371 s/step
# on time step 2615 (time=52.3), 0.175484 s/step
# on time step 2638 (time=52.76), 0.175052 s/step
# on time step 2661 (time=53.22), 0.17535 s/step
# on time step 2684 (time=53.68), 0.1804 s/step
# on time step 2707 (time=54.14), 0.174558 s/step
# on time step 2730 (time=54.6), 0.174594 s/step
# on time step 2753 (time=55.06), 0.174516 s/step
# on time step 2775 (time=55.5), 0.182123 s/step
# on time step 2798 (time=55.96), 0.17472 s/step
# on time step 2821 (time=56.42), 0.174901 s/step
# on time step 2844 (time=56.88), 0.180878 s/step
# on time step 2867 (time=57.34), 0.174584 s/step
# on time step 2890 (time=57.8), 0.174638 s/step
# on time step 2913 (time=58.26), 0.174997 s/step
# on time step 2936 (time=58.72), 0.180705 s/step
# on time step 2959 (time=59.18), 0.175229 s/step
# on time step 2982 (time=59.64), 0.174677 s/step
# field decay(t = 60.1): 7.3477853168796775e-06 / 0.040876979508742375 = 0.00017975362674016077
# run 0 finished at t = 60.1 (3005 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])
if mp.am_master():
    plt.figure(dpi=300)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical efficiency (in-pixel)")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")
