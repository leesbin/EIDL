# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=5)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 1 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * (design_region_width_x-air_gap*2))) + 1
Ny = int(round(design_region_resolution * (design_region_width_y-air_gap*2))) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1


# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, SiN, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000699997 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.339% done, 1.60721 s remaining
# IOStream.flush timed out
# subpixel-averaging is 71.6628% done, 1.58223 s remaining
# subpixel-averaging is 72.1021% done, 1.54786 s remaining
# time for set_epsilon = 30.361 s
# -----------
# on time step 1 (time=0.02), 8.21608 s/step
# on time step 20 (time=0.4), 0.212952 s/step
# on time step 37 (time=0.74), 0.24624 s/step
# on time step 53 (time=1.06), 0.252326 s/step
# on time step 70 (time=1.4), 0.249193 s/step
# on time step 86 (time=1.72), 0.251758 s/step
# on time step 102 (time=2.04), 0.258538 s/step
# on time step 118 (time=2.36), 0.253834 s/step
# on time step 134 (time=2.68), 0.254606 s/step
# on time step 151 (time=3.02), 0.245567 s/step
# on time step 167 (time=3.34), 0.265612 s/step
# on time step 184 (time=3.68), 0.237935 s/step
# on time step 203 (time=4.06), 0.217246 s/step
# on time step 219 (time=4.38), 0.251915 s/step
# on time step 235 (time=4.7), 0.258926 s/step
# on time step 251 (time=5.02), 0.257419 s/step
# on time step 267 (time=5.34), 0.257999 s/step
# on time step 283 (time=5.66), 0.259432 s/step
# on time step 299 (time=5.98), 0.255325 s/step
# on time step 315 (time=6.3), 0.261324 s/step
# on time step 331 (time=6.62), 0.255692 s/step
# on time step 347 (time=6.94), 0.260487 s/step
# on time step 362 (time=7.24), 0.269026 s/step
# on time step 378 (time=7.56), 0.251524 s/step
# on time step 396 (time=7.92), 0.225693 s/step
# on time step 412 (time=8.24), 0.251836 s/step
# on time step 428 (time=8.56), 0.251319 s/step
# on time step 445 (time=8.9), 0.248632 s/step
# on time step 462 (time=9.24), 0.238653 s/step
# on time step 481 (time=9.62), 0.212193 s/step
# on time step 498 (time=9.96), 0.246397 s/step
# field decay(t = 10.02): 3.6395078827399247e-07 / 3.6395078827399247e-07 = 1.0
# on time step 515 (time=10.3), 0.247234 s/step
# on time step 532 (time=10.64), 0.247531 s/step
# on time step 549 (time=10.98), 0.247368 s/step
# on time step 566 (time=11.32), 0.246878 s/step
# on time step 583 (time=11.66), 0.248339 s/step
# on time step 599 (time=11.98), 0.255775 s/step
# on time step 615 (time=12.3), 0.252215 s/step
# on time step 631 (time=12.62), 0.250846 s/step
# on time step 648 (time=12.96), 0.249642 s/step
# on time step 665 (time=13.3), 0.2496 s/step
# on time step 682 (time=13.64), 0.248656 s/step
# on time step 699 (time=13.98), 0.248752 s/step
# on time step 716 (time=14.32), 0.247127 s/step
# on time step 733 (time=14.66), 0.248853 s/step
# on time step 750 (time=15), 0.24801 s/step
# on time step 767 (time=15.34), 0.248647 s/step
# on time step 787 (time=15.74), 0.205419 s/step
# on time step 808 (time=16.16), 0.190851 s/step
# on time step 829 (time=16.58), 0.191008 s/step
# on time step 850 (time=17), 0.191752 s/step
# on time step 871 (time=17.42), 0.19173 s/step
# on time step 892 (time=17.84), 0.192099 s/step
# on time step 913 (time=18.26), 0.191475 s/step
# on time step 934 (time=18.68), 0.196285 s/step
# on time step 955 (time=19.1), 0.191928 s/step
# on time step 976 (time=19.52), 0.192641 s/step
# on time step 997 (time=19.94), 0.198111 s/step
# field decay(t = 20.04): 0.07539928254727561 / 0.07539928254727561 = 1.0
# on time step 1018 (time=20.36), 0.197096 s/step
# on time step 1039 (time=20.78), 0.198771 s/step
# on time step 1060 (time=21.2), 0.199585 s/step
# on time step 1081 (time=21.62), 0.197995 s/step
# on time step 1102 (time=22.04), 0.197378 s/step
# on time step 1122 (time=22.44), 0.201401 s/step
# on time step 1143 (time=22.86), 0.199876 s/step
# on time step 1163 (time=23.26), 0.200791 s/step
# on time step 1184 (time=23.68), 0.197982 s/step
# on time step 1205 (time=24.1), 0.19481 s/step
# on time step 1226 (time=24.52), 0.193824 s/step
# on time step 1247 (time=24.94), 0.193221 s/step
# on time step 1268 (time=25.36), 0.193018 s/step
# on time step 1289 (time=25.78), 0.192767 s/step
# on time step 1310 (time=26.2), 0.192466 s/step
# on time step 1331 (time=26.62), 0.192788 s/step
# on time step 1352 (time=27.04), 0.192417 s/step
# on time step 1373 (time=27.46), 0.192319 s/step
# on time step 1394 (time=27.88), 0.192661 s/step
# on time step 1415 (time=28.3), 0.192791 s/step
# on time step 1436 (time=28.72), 0.19447 s/step
# on time step 1457 (time=29.14), 0.19307 s/step
# on time step 1478 (time=29.56), 0.193796 s/step
# on time step 1499 (time=29.98), 0.19557 s/step
# field decay(t = 30.060000000000002): 0.31875266035406197 / 0.31875266035406197 = 1.0
# on time step 1520 (time=30.4), 0.195424 s/step
# on time step 1540 (time=30.8), 0.202544 s/step
# on time step 1561 (time=31.22), 0.196778 s/step
# on time step 1582 (time=31.64), 0.197096 s/step
# on time step 1603 (time=32.06), 0.199148 s/step
# on time step 1624 (time=32.48), 0.195253 s/step
# on time step 1645 (time=32.9), 0.193744 s/step
# on time step 1666 (time=33.32), 0.196655 s/step
# on time step 1686 (time=33.72), 0.207061 s/step
# on time step 1706 (time=34.12), 0.208318 s/step
# on time step 1725 (time=34.5), 0.214553 s/step
# on time step 1744 (time=34.88), 0.216493 s/step
# on time step 1764 (time=35.28), 0.207575 s/step
# on time step 1784 (time=35.68), 0.20647 s/step
# on time step 1803 (time=36.06), 0.211601 s/step
# on time step 1822 (time=36.44), 0.2114 s/step
# on time step 1842 (time=36.84), 0.205978 s/step
# on time step 1862 (time=37.24), 0.207236 s/step
# on time step 1882 (time=37.64), 0.203463 s/step
# on time step 1902 (time=38.04), 0.208737 s/step
# on time step 1923 (time=38.46), 0.198485 s/step
# on time step 1944 (time=38.88), 0.19924 s/step
# on time step 1965 (time=39.3), 0.194724 s/step
# on time step 1986 (time=39.72), 0.196875 s/step
# field decay(t = 40.06): 0.029915687009535587 / 0.31875266035406197 = 0.09385235240485848
# on time step 2007 (time=40.14), 0.197523 s/step
# on time step 2027 (time=40.54), 0.200649 s/step
# on time step 2047 (time=40.94), 0.201848 s/step
# on time step 2068 (time=41.36), 0.198988 s/step
# on time step 2089 (time=41.78), 0.194889 s/step
# on time step 2110 (time=42.2), 0.196296 s/step
# on time step 2130 (time=42.6), 0.201124 s/step
# on time step 2151 (time=43.02), 0.199424 s/step
# on time step 2172 (time=43.44), 0.195787 s/step
# on time step 2193 (time=43.86), 0.197534 s/step
# on time step 2214 (time=44.28), 0.196309 s/step
# on time step 2235 (time=44.7), 0.196382 s/step
# on time step 2256 (time=45.12), 0.198025 s/step
# on time step 2277 (time=45.54), 0.19689 s/step
# on time step 2298 (time=45.96), 0.194736 s/step
# on time step 2319 (time=46.38), 0.193323 s/step
# on time step 2340 (time=46.8), 0.197594 s/step
# on time step 2361 (time=47.22), 0.196146 s/step
# on time step 2382 (time=47.64), 0.192322 s/step
# on time step 2403 (time=48.06), 0.192129 s/step
# on time step 2424 (time=48.48), 0.192248 s/step
# on time step 2445 (time=48.9), 0.196333 s/step
# on time step 2466 (time=49.32), 0.195907 s/step
# on time step 2487 (time=49.74), 0.197574 s/step
# field decay(t = 50.08): 0.0009269738086108366 / 0.31875266035406197 = 0.0029081288532029153
# on time step 2508 (time=50.16), 0.198907 s/step
# on time step 2529 (time=50.58), 0.191296 s/step
# on time step 2550 (time=51), 0.196885 s/step
# on time step 2570 (time=51.4), 0.201266 s/step
# on time step 2590 (time=51.8), 0.207392 s/step
# on time step 2610 (time=52.2), 0.201114 s/step
# on time step 2631 (time=52.62), 0.196743 s/step
# on time step 2652 (time=53.04), 0.193369 s/step
# on time step 2673 (time=53.46), 0.195081 s/step
# on time step 2694 (time=53.88), 0.195288 s/step
# on time step 2715 (time=54.3), 0.197108 s/step
# on time step 2737 (time=54.74), 0.190124 s/step
# on time step 2758 (time=55.16), 0.190593 s/step
# on time step 2779 (time=55.58), 0.198367 s/step
# on time step 2801 (time=56.02), 0.1899 s/step
# on time step 2822 (time=56.44), 0.192024 s/step
# on time step 2843 (time=56.86), 0.194865 s/step
# on time step 2864 (time=57.28), 0.195198 s/step
# on time step 2885 (time=57.7), 0.194625 s/step
# on time step 2906 (time=58.12), 0.194176 s/step
# on time step 2927 (time=58.54), 0.196933 s/step
# on time step 2948 (time=58.96), 0.192379 s/step
# on time step 2969 (time=59.38), 0.194272 s/step
# on time step 2990 (time=59.8), 0.192631 s/step
# field decay(t = 60.1): 0.0005119674624677466 / 0.31875266035406197 = 0.0016061590259327304
# on time step 3011 (time=60.22), 0.195283 s/step
# on time step 3032 (time=60.64), 0.197457 s/step
# on time step 3054 (time=61.08), 0.189717 s/step
# on time step 3075 (time=61.5), 0.191491 s/step
# on time step 3096 (time=61.92), 0.193684 s/step
# on time step 3117 (time=62.34), 0.191717 s/step
# on time step 3138 (time=62.76), 0.190909 s/step
# on time step 3159 (time=63.18), 0.193526 s/step
# on time step 3179 (time=63.58), 0.20698 s/step
# on time step 3199 (time=63.98), 0.204565 s/step
# on time step 3219 (time=64.38), 0.200099 s/step
# on time step 3239 (time=64.78), 0.200578 s/step
# on time step 3260 (time=65.2), 0.198323 s/step
# on time step 3281 (time=65.62), 0.193671 s/step
# on time step 3302 (time=66.04), 0.191816 s/step
# on time step 3323 (time=66.46), 0.192017 s/step
# on time step 3344 (time=66.88), 0.191881 s/step
# on time step 3365 (time=67.3), 0.191596 s/step
# on time step 3386 (time=67.72), 0.192314 s/step
# on time step 3407 (time=68.14), 0.192803 s/step
# on time step 3428 (time=68.56), 0.19247 s/step
# on time step 3449 (time=68.98), 0.192571 s/step
# on time step 3470 (time=69.4), 0.192459 s/step
# on time step 3491 (time=69.82), 0.193548 s/step
# field decay(t = 70.12): 2.5122196911136113e-05 / 0.31875266035406197 = 7.881407760873601e-05
# run 0 finished at t = 70.12 (3506 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000746012 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 74.0446% done, 1.40225 s remaining
# subpixel-averaging is 72.9346% done, 1.48448 s remaining
# subpixel-averaging is 72.7959% done, 1.49505 s remaining
# time for set_epsilon = 29.7865 s
# -----------
# on time step 1 (time=0.02), 7.92251 s/step
# on time step 24 (time=0.48), 0.178368 s/step
# on time step 47 (time=0.94), 0.175036 s/step
# on time step 71 (time=1.42), 0.172538 s/step
# on time step 94 (time=1.88), 0.176283 s/step
# on time step 117 (time=2.34), 0.17474 s/step
# on time step 140 (time=2.8), 0.176506 s/step
# on time step 163 (time=3.26), 0.180399 s/step
# on time step 186 (time=3.72), 0.175549 s/step
# on time step 209 (time=4.18), 0.173951 s/step
# on time step 233 (time=4.66), 0.172388 s/step
# on time step 257 (time=5.14), 0.171699 s/step
# on time step 280 (time=5.6), 0.175702 s/step
# on time step 304 (time=6.08), 0.173437 s/step
# on time step 327 (time=6.54), 0.174412 s/step
# on time step 351 (time=7.02), 0.173819 s/step
# on time step 375 (time=7.5), 0.173034 s/step
# on time step 399 (time=7.98), 0.172448 s/step
# on time step 423 (time=8.46), 0.172267 s/step
# on time step 447 (time=8.94), 0.171772 s/step
# on time step 471 (time=9.42), 0.17151 s/step
# on time step 495 (time=9.9), 0.172009 s/step
# field decay(t = 10.02): 1.7893225788962308e-09 / 1.7893225788962308e-09 = 1.0
# on time step 519 (time=10.38), 0.173571 s/step
# on time step 543 (time=10.86), 0.17279 s/step
# on time step 567 (time=11.34), 0.172411 s/step
# on time step 590 (time=11.8), 0.174993 s/step
# on time step 614 (time=12.28), 0.173418 s/step
# on time step 637 (time=12.74), 0.174723 s/step
# on time step 661 (time=13.22), 0.17305 s/step
# on time step 685 (time=13.7), 0.173686 s/step
# on time step 709 (time=14.18), 0.172801 s/step
# on time step 733 (time=14.66), 0.173418 s/step
# on time step 756 (time=15.12), 0.175073 s/step
# on time step 780 (time=15.6), 0.173875 s/step
# on time step 804 (time=16.08), 0.173119 s/step
# on time step 828 (time=16.56), 0.173396 s/step
# on time step 852 (time=17.04), 0.173266 s/step
# on time step 876 (time=17.52), 0.173507 s/step
# on time step 900 (time=18), 0.17324 s/step
# on time step 923 (time=18.46), 0.174033 s/step
# on time step 947 (time=18.94), 0.172501 s/step
# on time step 971 (time=19.42), 0.172081 s/step
# on time step 995 (time=19.9), 0.172654 s/step
# field decay(t = 20.04): 0.0001218892434467351 / 0.0001218892434467351 = 1.0
# on time step 1018 (time=20.36), 0.17551 s/step
# on time step 1042 (time=20.84), 0.171511 s/step
# on time step 1066 (time=21.32), 0.17163 s/step
# on time step 1090 (time=21.8), 0.172036 s/step
# on time step 1114 (time=22.28), 0.172832 s/step
# on time step 1138 (time=22.76), 0.172473 s/step
# on time step 1162 (time=23.24), 0.172331 s/step
# on time step 1186 (time=23.72), 0.172286 s/step
# on time step 1210 (time=24.2), 0.173246 s/step
# on time step 1233 (time=24.66), 0.174473 s/step
# on time step 1257 (time=25.14), 0.172387 s/step
# on time step 1281 (time=25.62), 0.172325 s/step
# on time step 1305 (time=26.1), 0.172441 s/step
# on time step 1329 (time=26.58), 0.173095 s/step
# on time step 1353 (time=27.06), 0.173201 s/step
# on time step 1377 (time=27.54), 0.172906 s/step
# on time step 1401 (time=28.02), 0.171826 s/step
# on time step 1425 (time=28.5), 0.172431 s/step
# on time step 1449 (time=28.98), 0.172119 s/step
# on time step 1473 (time=29.46), 0.171405 s/step
# on time step 1497 (time=29.94), 0.171367 s/step
# field decay(t = 30.060000000000002): 0.04975087034063097 / 0.04975087034063097 = 1.0
# on time step 1521 (time=30.42), 0.172677 s/step
# on time step 1545 (time=30.9), 0.173227 s/step
# on time step 1569 (time=31.38), 0.172602 s/step
# on time step 1593 (time=31.86), 0.171386 s/step
# on time step 1617 (time=32.34), 0.17322 s/step
# on time step 1641 (time=32.82), 0.17326 s/step
# on time step 1664 (time=33.28), 0.175313 s/step
# on time step 1688 (time=33.76), 0.171516 s/step
# on time step 1712 (time=34.24), 0.171515 s/step
# on time step 1736 (time=34.72), 0.171596 s/step
# on time step 1760 (time=35.2), 0.171648 s/step
# on time step 1784 (time=35.68), 0.171909 s/step
# on time step 1808 (time=36.16), 0.171714 s/step
# on time step 1832 (time=36.64), 0.173486 s/step
# on time step 1855 (time=37.1), 0.175654 s/step
# on time step 1879 (time=37.58), 0.172139 s/step
# on time step 1903 (time=38.06), 0.171866 s/step
# on time step 1927 (time=38.54), 0.171956 s/step
# on time step 1951 (time=39.02), 0.171573 s/step
# on time step 1975 (time=39.5), 0.171822 s/step
# on time step 1999 (time=39.98), 0.17212 s/step
# field decay(t = 40.06): 0.2153232317058376 / 0.2153232317058376 = 1.0
# on time step 2022 (time=40.44), 0.174914 s/step
# on time step 2046 (time=40.92), 0.171916 s/step
# on time step 2070 (time=41.4), 0.172175 s/step
# on time step 2094 (time=41.88), 0.171552 s/step
# on time step 2117 (time=42.34), 0.173938 s/step
# on time step 2140 (time=42.8), 0.174212 s/step
# on time step 2163 (time=43.26), 0.174303 s/step
# on time step 2186 (time=43.72), 0.175304 s/step
# on time step 2209 (time=44.18), 0.175065 s/step
# on time step 2232 (time=44.64), 0.174977 s/step
# on time step 2256 (time=45.12), 0.171788 s/step
# on time step 2280 (time=45.6), 0.171619 s/step
# on time step 2304 (time=46.08), 0.17198 s/step
# on time step 2328 (time=46.56), 0.172821 s/step
# on time step 2352 (time=47.04), 0.172652 s/step
# on time step 2376 (time=47.52), 0.171991 s/step
# on time step 2400 (time=48), 0.172892 s/step
# on time step 2423 (time=48.46), 0.175827 s/step
# on time step 2447 (time=48.94), 0.173258 s/step
# on time step 2471 (time=49.42), 0.171926 s/step
# on time step 2495 (time=49.9), 0.172064 s/step
# field decay(t = 50.08): 0.17434348873181996 / 0.2153232317058376 = 0.8096826680086159
# on time step 2519 (time=50.38), 0.173039 s/step
# on time step 2542 (time=50.84), 0.175387 s/step
# on time step 2566 (time=51.32), 0.172034 s/step
# on time step 2590 (time=51.8), 0.171882 s/step
# on time step 2614 (time=52.28), 0.172754 s/step
# on time step 2638 (time=52.76), 0.171333 s/step
# on time step 2662 (time=53.24), 0.171341 s/step
# on time step 2686 (time=53.72), 0.17222 s/step
# on time step 2710 (time=54.2), 0.171772 s/step
# on time step 2733 (time=54.66), 0.174632 s/step
# on time step 2757 (time=55.14), 0.172841 s/step
# on time step 2781 (time=55.62), 0.171781 s/step
# on time step 2805 (time=56.1), 0.171557 s/step
# on time step 2829 (time=56.58), 0.171741 s/step
# on time step 2853 (time=57.06), 0.172927 s/step
# on time step 2877 (time=57.54), 0.173085 s/step
# on time step 2900 (time=58), 0.174301 s/step
# on time step 2924 (time=58.48), 0.172806 s/step
# on time step 2948 (time=58.96), 0.17265 s/step
# on time step 2972 (time=59.44), 0.172865 s/step
# on time step 2996 (time=59.92), 0.173676 s/step
# field decay(t = 60.1): 0.007940871101006847 / 0.2153232317058376 = 0.03687884042096868
# on time step 3019 (time=60.38), 0.176289 s/step
# on time step 3043 (time=60.86), 0.173116 s/step
# on time step 3067 (time=61.34), 0.171775 s/step
# on time step 3091 (time=61.82), 0.17151 s/step
# on time step 3114 (time=62.28), 0.17457 s/step
# on time step 3138 (time=62.76), 0.171815 s/step
# on time step 3162 (time=63.24), 0.171677 s/step
# on time step 3186 (time=63.72), 0.171823 s/step
# on time step 3210 (time=64.2), 0.171881 s/step
# on time step 3234 (time=64.68), 0.171941 s/step
# on time step 3258 (time=65.16), 0.171913 s/step
# on time step 3282 (time=65.64), 0.171796 s/step
# on time step 3306 (time=66.12), 0.171973 s/step
# on time step 3330 (time=66.6), 0.173857 s/step
# on time step 3354 (time=67.08), 0.171187 s/step
# on time step 3378 (time=67.56), 0.170538 s/step
# on time step 3402 (time=68.04), 0.170943 s/step
# on time step 3426 (time=68.52), 0.170364 s/step
# on time step 3450 (time=69), 0.172906 s/step
# on time step 3474 (time=69.48), 0.173688 s/step
# on time step 3497 (time=69.94), 0.17405 s/step
# field decay(t = 70.12): 0.00023568812069457875 / 0.2153232317058376 = 0.0010945782246876293
# on time step 3520 (time=70.4), 0.173951 s/step
# on time step 3544 (time=70.88), 0.170711 s/step
# on time step 3568 (time=71.36), 0.170775 s/step
# on time step 3592 (time=71.84), 0.170899 s/step
# on time step 3616 (time=72.32), 0.170812 s/step
# on time step 3640 (time=72.8), 0.170616 s/step
# on time step 3664 (time=73.28), 0.170223 s/step
# on time step 3688 (time=73.76), 0.170036 s/step
# on time step 3712 (time=74.24), 0.172289 s/step
# on time step 3736 (time=74.72), 0.171859 s/step
# on time step 3760 (time=75.2), 0.171084 s/step
# on time step 3784 (time=75.68), 0.170168 s/step
# on time step 3808 (time=76.16), 0.170465 s/step
# on time step 3832 (time=76.64), 0.170156 s/step
# on time step 3856 (time=77.12), 0.170572 s/step
# on time step 3880 (time=77.6), 0.170261 s/step
# on time step 3904 (time=78.08), 0.17042 s/step
# on time step 3928 (time=78.56), 0.170726 s/step
# on time step 3952 (time=79.04), 0.172848 s/step
# on time step 3976 (time=79.52), 0.171136 s/step
# on time step 4000 (time=80), 0.170994 s/step
# field decay(t = 80.14): 3.5111959668332475e-05 / 0.2153232317058376 = 0.00016306628592822
# run 0 finished at t = 80.14 (4007 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000638008 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 74.0215% done, 1.40399 s remaining
# subpixel-averaging is 73.744% done, 1.42441 s remaining
# subpixel-averaging is 71.0847% done, 1.6273 s remaining
# time for set_epsilon = 29.8687 s
# -----------
# on time step 1 (time=0.02), 7.82887 s/step
# on time step 25 (time=0.5), 0.172445 s/step
# on time step 49 (time=0.98), 0.17279 s/step
# on time step 73 (time=1.46), 0.172407 s/step
# on time step 97 (time=1.94), 0.172445 s/step
# on time step 120 (time=2.4), 0.175016 s/step
# on time step 143 (time=2.86), 0.175092 s/step
# on time step 167 (time=3.34), 0.173236 s/step
# on time step 191 (time=3.82), 0.172389 s/step
# on time step 215 (time=4.3), 0.172257 s/step
# on time step 238 (time=4.76), 0.174703 s/step
# on time step 262 (time=5.24), 0.172706 s/step
# on time step 286 (time=5.72), 0.171949 s/step
# on time step 310 (time=6.2), 0.172879 s/step
# on time step 334 (time=6.68), 0.172722 s/step
# on time step 358 (time=7.16), 0.172291 s/step
# on time step 382 (time=7.64), 0.172669 s/step
# on time step 406 (time=8.12), 0.172286 s/step
# on time step 430 (time=8.6), 0.172022 s/step
# on time step 453 (time=9.06), 0.174065 s/step
# on time step 476 (time=9.52), 0.175618 s/step
# on time step 499 (time=9.98), 0.177323 s/step
# field decay(t = 10.02): 2.34529109612483e-09 / 2.34529109612483e-09 = 1.0
# on time step 523 (time=10.46), 0.172932 s/step
# on time step 547 (time=10.94), 0.173369 s/step
# on time step 570 (time=11.4), 0.174363 s/step
# on time step 594 (time=11.88), 0.173052 s/step
# on time step 618 (time=12.36), 0.173393 s/step
# on time step 641 (time=12.82), 0.178944 s/step
# on time step 664 (time=13.28), 0.177177 s/step
# on time step 687 (time=13.74), 0.176568 s/step
# on time step 710 (time=14.2), 0.176756 s/step
# on time step 733 (time=14.66), 0.17945 s/step
# on time step 756 (time=15.12), 0.179409 s/step
# on time step 779 (time=15.58), 0.177008 s/step
# on time step 802 (time=16.04), 0.175935 s/step
# on time step 825 (time=16.5), 0.177549 s/step
# on time step 848 (time=16.96), 0.176799 s/step
# on time step 871 (time=17.42), 0.176782 s/step
# on time step 894 (time=17.88), 0.177347 s/step
# on time step 916 (time=18.32), 0.183919 s/step
# on time step 939 (time=18.78), 0.179672 s/step
# on time step 962 (time=19.24), 0.176805 s/step
# on time step 985 (time=19.7), 0.17748 s/step
# field decay(t = 20.04): 6.931503427831917e-05 / 6.931503427831917e-05 = 1.0
# on time step 1008 (time=20.16), 0.178922 s/step
# on time step 1031 (time=20.62), 0.179077 s/step
# on time step 1054 (time=21.08), 0.177724 s/step
# on time step 1077 (time=21.54), 0.176304 s/step
# on time step 1100 (time=22), 0.17552 s/step
# on time step 1123 (time=22.46), 0.179772 s/step
# on time step 1147 (time=22.94), 0.174064 s/step
# on time step 1170 (time=23.4), 0.174892 s/step
# on time step 1194 (time=23.88), 0.172615 s/step
# on time step 1217 (time=24.34), 0.17403 s/step
# on time step 1240 (time=24.8), 0.178257 s/step
# on time step 1263 (time=25.26), 0.176225 s/step
# on time step 1286 (time=25.72), 0.17954 s/step
# on time step 1309 (time=26.18), 0.17579 s/step
# on time step 1332 (time=26.64), 0.175387 s/step
# on time step 1356 (time=27.12), 0.173868 s/step
# on time step 1380 (time=27.6), 0.172998 s/step
# on time step 1404 (time=28.08), 0.173046 s/step
# on time step 1428 (time=28.56), 0.173047 s/step
# on time step 1452 (time=29.04), 0.173578 s/step
# on time step 1476 (time=29.52), 0.173291 s/step
# on time step 1499 (time=29.98), 0.174248 s/step
# field decay(t = 30.060000000000002): 0.014578567951636099 / 0.014578567951636099 = 1.0
# on time step 1522 (time=30.44), 0.175371 s/step
# on time step 1546 (time=30.92), 0.173655 s/step
# on time step 1569 (time=31.38), 0.174324 s/step
# on time step 1592 (time=31.84), 0.174437 s/step
# on time step 1616 (time=32.32), 0.173689 s/step
# on time step 1640 (time=32.8), 0.173788 s/step
# on time step 1663 (time=33.26), 0.175275 s/step
# on time step 1686 (time=33.72), 0.17504 s/step
# on time step 1710 (time=34.2), 0.172736 s/step
# on time step 1734 (time=34.68), 0.173486 s/step
# on time step 1758 (time=35.16), 0.17316 s/step
# on time step 1781 (time=35.62), 0.173964 s/step
# on time step 1804 (time=36.08), 0.175641 s/step
# on time step 1827 (time=36.54), 0.177469 s/step
# on time step 1849 (time=36.98), 0.18191 s/step
# on time step 1872 (time=37.44), 0.177987 s/step
# on time step 1894 (time=37.88), 0.190416 s/step
# on time step 1917 (time=38.34), 0.180909 s/step
# on time step 1940 (time=38.8), 0.175621 s/step
# on time step 1963 (time=39.26), 0.174682 s/step
# on time step 1986 (time=39.72), 0.174204 s/step
# field decay(t = 40.06): 0.029724227731814268 / 0.029724227731814268 = 1.0
# on time step 2009 (time=40.18), 0.178095 s/step
# on time step 2033 (time=40.66), 0.173768 s/step
# on time step 2056 (time=41.12), 0.174277 s/step
# on time step 2079 (time=41.58), 0.176808 s/step
# on time step 2103 (time=42.06), 0.171775 s/step
# on time step 2126 (time=42.52), 0.178407 s/step
# on time step 2149 (time=42.98), 0.175072 s/step
# on time step 2172 (time=43.44), 0.180255 s/step
# on time step 2195 (time=43.9), 0.178989 s/step
# on time step 2218 (time=44.36), 0.177614 s/step
# on time step 2241 (time=44.82), 0.176445 s/step
# on time step 2264 (time=45.28), 0.18115 s/step
# on time step 2287 (time=45.74), 0.181196 s/step
# on time step 2310 (time=46.2), 0.178288 s/step
# on time step 2334 (time=46.68), 0.173773 s/step
# on time step 2358 (time=47.16), 0.17216 s/step
# on time step 2381 (time=47.62), 0.17408 s/step
# on time step 2405 (time=48.1), 0.172499 s/step
# on time step 2429 (time=48.58), 0.172672 s/step
# on time step 2453 (time=49.06), 0.172983 s/step
# on time step 2477 (time=49.54), 0.172134 s/step
# on time step 2501 (time=50.02), 0.172732 s/step
# field decay(t = 50.08): 0.014920520695318571 / 0.029724227731814268 = 0.5019649570020258
# on time step 2524 (time=50.48), 0.174062 s/step
# on time step 2548 (time=50.96), 0.172781 s/step
# on time step 2572 (time=51.44), 0.172523 s/step
# on time step 2596 (time=51.92), 0.172509 s/step
# on time step 2620 (time=52.4), 0.172689 s/step
# on time step 2644 (time=52.88), 0.172791 s/step
# on time step 2668 (time=53.36), 0.172219 s/step
# on time step 2692 (time=53.84), 0.172245 s/step
# on time step 2716 (time=54.32), 0.172296 s/step
# on time step 2740 (time=54.8), 0.172438 s/step
# on time step 2764 (time=55.28), 0.173313 s/step
# on time step 2788 (time=55.76), 0.17222 s/step
# on time step 2812 (time=56.24), 0.172402 s/step
# on time step 2836 (time=56.72), 0.17253 s/step
# on time step 2860 (time=57.2), 0.172405 s/step
# on time step 2883 (time=57.66), 0.175059 s/step
# on time step 2906 (time=58.12), 0.173957 s/step
# on time step 2930 (time=58.6), 0.172064 s/step
# on time step 2954 (time=59.08), 0.172227 s/step
# on time step 2978 (time=59.56), 0.172674 s/step
# on time step 3001 (time=60.02), 0.174338 s/step
# field decay(t = 60.1): 0.0015967742458588682 / 0.029724227731814268 = 0.05371962091885798
# on time step 3024 (time=60.48), 0.174052 s/step
# on time step 3048 (time=60.96), 0.173252 s/step
# on time step 3071 (time=61.42), 0.175165 s/step
# on time step 3095 (time=61.9), 0.173708 s/step
# on time step 3119 (time=62.38), 0.17295 s/step
# on time step 3142 (time=62.84), 0.175555 s/step
# on time step 3166 (time=63.32), 0.172076 s/step
# on time step 3189 (time=63.78), 0.174317 s/step
# on time step 3213 (time=64.26), 0.172579 s/step
# on time step 3237 (time=64.74), 0.172219 s/step
# on time step 3261 (time=65.22), 0.172063 s/step
# on time step 3285 (time=65.7), 0.173774 s/step
# on time step 3309 (time=66.18), 0.173061 s/step
# on time step 3333 (time=66.66), 0.172083 s/step
# on time step 3357 (time=67.14), 0.172615 s/step
# on time step 3381 (time=67.62), 0.172759 s/step
# on time step 3405 (time=68.1), 0.171831 s/step
# on time step 3429 (time=68.58), 0.172595 s/step
# on time step 3453 (time=69.06), 0.172646 s/step
# on time step 3477 (time=69.54), 0.172537 s/step
# on time step 3501 (time=70.02), 0.17355 s/step
# field decay(t = 70.12): 1.5933657237243068e-05 / 0.029724227731814268 = 0.0005360494940694135
# run 0 finished at t = 70.12 (3506 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000345945 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 7.47866 s
# -----------
# on time step 1 (time=0.02), 7.85535 s/step
# on time step 27 (time=0.54), 0.156426 s/step
# on time step 53 (time=1.06), 0.156154 s/step
# on time step 78 (time=1.56), 0.160001 s/step
# on time step 104 (time=2.08), 0.156171 s/step
# on time step 129 (time=2.58), 0.160694 s/step
# on time step 155 (time=3.1), 0.156279 s/step
# on time step 180 (time=3.6), 0.160788 s/step
# on time step 206 (time=4.12), 0.157325 s/step
# on time step 232 (time=4.64), 0.156887 s/step
# on time step 257 (time=5.14), 0.160457 s/step
# on time step 283 (time=5.66), 0.15697 s/step
# on time step 308 (time=6.16), 0.160989 s/step
# on time step 334 (time=6.68), 0.15809 s/step
# on time step 360 (time=7.2), 0.162646 s/step
# on time step 386 (time=7.72), 0.155469 s/step
# on time step 412 (time=8.24), 0.155265 s/step
# on time step 438 (time=8.76), 0.159328 s/step
# on time step 464 (time=9.28), 0.154789 s/step
# on time step 490 (time=9.8), 0.158943 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 516 (time=10.32), 0.154973 s/step
# on time step 542 (time=10.84), 0.159137 s/step
# on time step 568 (time=11.36), 0.154933 s/step
# on time step 594 (time=11.88), 0.158889 s/step
# on time step 620 (time=12.4), 0.154687 s/step
# on time step 646 (time=12.92), 0.156569 s/step
# on time step 671 (time=13.42), 0.160125 s/step
# on time step 697 (time=13.94), 0.155128 s/step
# on time step 723 (time=14.46), 0.159398 s/step
# on time step 749 (time=14.98), 0.15499 s/step
# on time step 775 (time=15.5), 0.159349 s/step
# on time step 800 (time=16), 0.162764 s/step
# on time step 825 (time=16.5), 0.161606 s/step
# on time step 849 (time=16.98), 0.16784 s/step
# on time step 875 (time=17.5), 0.155557 s/step
# on time step 900 (time=18), 0.160468 s/step
# on time step 926 (time=18.52), 0.155953 s/step
# on time step 952 (time=19.04), 0.156157 s/step
# on time step 977 (time=19.54), 0.16036 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1003 (time=20.06), 0.157115 s/step
# on time step 1028 (time=20.56), 0.16181 s/step
# on time step 1054 (time=21.08), 0.156093 s/step
# on time step 1080 (time=21.6), 0.163106 s/step
# on time step 1105 (time=22.1), 0.163986 s/step
# on time step 1130 (time=22.6), 0.160945 s/step
# on time step 1156 (time=23.12), 0.156933 s/step
# on time step 1183 (time=23.66), 0.152724 s/step
# on time step 1209 (time=24.18), 0.159491 s/step
# on time step 1235 (time=24.7), 0.15469 s/step
# on time step 1261 (time=25.22), 0.158354 s/step
# on time step 1288 (time=25.76), 0.153409 s/step
# on time step 1314 (time=26.28), 0.158677 s/step
# on time step 1340 (time=26.8), 0.153903 s/step
# on time step 1367 (time=27.34), 0.153217 s/step
# on time step 1393 (time=27.86), 0.157725 s/step
# on time step 1420 (time=28.4), 0.153163 s/step
# on time step 1446 (time=28.92), 0.158683 s/step
# on time step 1473 (time=29.46), 0.153458 s/step
# on time step 1499 (time=29.98), 0.157123 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000659943 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.7553% done, 1.57472 s remaining
# subpixel-averaging is 74.2527% done, 1.38736 s remaining
# subpixel-averaging is 74.8771% done, 1.34244 s remaining
# time for set_epsilon = 29.5202 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 7.78303 s/step
# on time step 24 (time=0.48), 0.175291 s/step
# on time step 47 (time=0.94), 0.17466 s/step
# on time step 70 (time=1.4), 0.175166 s/step
# on time step 93 (time=1.86), 0.181104 s/step
# on time step 116 (time=2.32), 0.174616 s/step
# on time step 139 (time=2.78), 0.175166 s/step
# on time step 162 (time=3.24), 0.181225 s/step
# on time step 185 (time=3.7), 0.175397 s/step
# on time step 208 (time=4.16), 0.175326 s/step
# on time step 231 (time=4.62), 0.174925 s/step
# on time step 253 (time=5.06), 0.181874 s/step
# on time step 276 (time=5.52), 0.175047 s/step
# on time step 299 (time=5.98), 0.175537 s/step
# on time step 322 (time=6.44), 0.176606 s/step
# on time step 344 (time=6.88), 0.18198 s/step
# on time step 367 (time=7.34), 0.175169 s/step
# on time step 390 (time=7.8), 0.174679 s/step
# on time step 413 (time=8.26), 0.175032 s/step
# on time step 435 (time=8.7), 0.181957 s/step
# on time step 458 (time=9.16), 0.175345 s/step
# on time step 481 (time=9.62), 0.174761 s/step
# field decay(t = 10.02): 0.0011489542744040722 / 0.0011489542744040722 = 1.0
# on time step 504 (time=10.08), 0.183575 s/step
# on time step 527 (time=10.54), 0.175866 s/step
# on time step 550 (time=11), 0.174594 s/step
# on time step 573 (time=11.46), 0.17401 s/step
# on time step 596 (time=11.92), 0.180071 s/step
# on time step 620 (time=12.4), 0.173617 s/step
# on time step 643 (time=12.86), 0.174605 s/step
# on time step 666 (time=13.32), 0.1809 s/step
# on time step 689 (time=13.78), 0.174695 s/step
# on time step 712 (time=14.24), 0.174036 s/step
# on time step 735 (time=14.7), 0.174174 s/step
# on time step 758 (time=15.16), 0.180528 s/step
# on time step 781 (time=15.62), 0.174104 s/step
# on time step 804 (time=16.08), 0.174004 s/step
# on time step 827 (time=16.54), 0.17435 s/step
# on time step 850 (time=17), 0.180192 s/step
# on time step 873 (time=17.46), 0.17465 s/step
# on time step 896 (time=17.92), 0.174279 s/step
# on time step 919 (time=18.38), 0.18029 s/step
# on time step 942 (time=18.84), 0.176171 s/step
# on time step 965 (time=19.3), 0.175888 s/step
# on time step 989 (time=19.78), 0.173276 s/step
# field decay(t = 20.04): 0.1181454072915966 / 0.1181454072915966 = 1.0
# on time step 1012 (time=20.24), 0.180049 s/step
# on time step 1036 (time=20.72), 0.173432 s/step
# on time step 1060 (time=21.2), 0.173313 s/step
# on time step 1083 (time=21.66), 0.179563 s/step
# on time step 1106 (time=22.12), 0.173997 s/step
# on time step 1130 (time=22.6), 0.173446 s/step
# on time step 1153 (time=23.06), 0.17972 s/step
# on time step 1176 (time=23.52), 0.174007 s/step
# on time step 1200 (time=24), 0.173606 s/step
# on time step 1223 (time=24.46), 0.173935 s/step
# on time step 1246 (time=24.92), 0.180321 s/step
# on time step 1270 (time=25.4), 0.173294 s/step
# on time step 1294 (time=25.88), 0.173603 s/step
# on time step 1317 (time=26.34), 0.17982 s/step
# on time step 1340 (time=26.8), 0.175369 s/step
# on time step 1363 (time=27.26), 0.174363 s/step
# on time step 1386 (time=27.72), 0.179852 s/step
# on time step 1409 (time=28.18), 0.173923 s/step
# on time step 1433 (time=28.66), 0.173417 s/step
# on time step 1457 (time=29.14), 0.17361 s/step
# on time step 1480 (time=29.6), 0.179704 s/step
# field decay(t = 30.060000000000002): 0.005139610264909889 / 0.1181454072915966 = 0.043502412685621654
# on time step 1503 (time=30.06), 0.174055 s/step
# on time step 1527 (time=30.54), 0.173492 s/step
# on time step 1550 (time=31), 0.180163 s/step
# on time step 1573 (time=31.46), 0.175195 s/step
# on time step 1596 (time=31.92), 0.174343 s/step
# on time step 1620 (time=32.4), 0.179545 s/step
# on time step 1644 (time=32.88), 0.173215 s/step
# on time step 1668 (time=33.36), 0.173367 s/step
# on time step 1692 (time=33.84), 0.17919 s/step
# on time step 1716 (time=34.32), 0.173052 s/step
# on time step 1740 (time=34.8), 0.173189 s/step
# on time step 1763 (time=35.26), 0.173977 s/step
# on time step 1786 (time=35.72), 0.179587 s/step
# on time step 1810 (time=36.2), 0.173528 s/step
# on time step 1833 (time=36.66), 0.174688 s/step
# on time step 1856 (time=37.12), 0.179956 s/step
# on time step 1879 (time=37.58), 0.174086 s/step
# on time step 1902 (time=38.04), 0.175124 s/step
# on time step 1925 (time=38.5), 0.175443 s/step
# on time step 1948 (time=38.96), 0.180846 s/step
# on time step 1971 (time=39.42), 0.174684 s/step
# on time step 1994 (time=39.88), 0.174874 s/step
# field decay(t = 40.06): 0.0005188007362740803 / 0.1181454072915966 = 0.0043912052797246675
# on time step 2016 (time=40.32), 0.181981 s/step
# on time step 2039 (time=40.78), 0.174941 s/step
# on time step 2062 (time=41.24), 0.174596 s/step
# on time step 2085 (time=41.7), 0.174602 s/step
# on time step 2108 (time=42.16), 0.180578 s/step
# on time step 2131 (time=42.62), 0.174404 s/step
# on time step 2154 (time=43.08), 0.176229 s/step
# on time step 2177 (time=43.54), 0.174282 s/step
# on time step 2200 (time=44), 0.180654 s/step
# on time step 2223 (time=44.46), 0.175572 s/step
# on time step 2247 (time=44.94), 0.17314 s/step
# on time step 2270 (time=45.4), 0.179225 s/step
# on time step 2294 (time=45.88), 0.173448 s/step
# on time step 2318 (time=46.36), 0.173456 s/step
# on time step 2341 (time=46.82), 0.179881 s/step
# on time step 2365 (time=47.3), 0.173307 s/step
# on time step 2389 (time=47.78), 0.173246 s/step
# on time step 2412 (time=48.24), 0.179876 s/step
# on time step 2436 (time=48.72), 0.173496 s/step
# on time step 2460 (time=49.2), 0.173284 s/step
# on time step 2484 (time=49.68), 0.179326 s/step
# field decay(t = 50.08): 4.915415103308199e-05 / 0.1181454072915966 = 0.00041604792060823684
# run 0 finished at t = 50.08 (2504 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])
if mp.am_master():
    plt.figure(dpi=300)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical efficiency (in-pixel)")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")
