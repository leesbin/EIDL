# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=11.8)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 1 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('structure_0187.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * (design_region_width_x-air_gap*2))) + 1
Ny = int(round(design_region_resolution * (design_region_width_y-air_gap*2))) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, TiO2, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00134706 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 66.321% done, 2.0313 s remaining
# subpixel-averaging is 64.9798% done, 2.15595 s remaining
# subpixel-averaging is 65.6735% done, 2.09084 s remaining
# IOStream.flush timed out
# time for set_epsilon = 31.9392 s
# -----------
# on time step 1 (time=0.02), 8.27635 s/step
# on time step 24 (time=0.48), 0.17999 s/step
# on time step 46 (time=0.92), 0.184605 s/step
# on time step 68 (time=1.36), 0.187198 s/step
# on time step 90 (time=1.8), 0.181916 s/step
# on time step 113 (time=2.26), 0.177621 s/step
# on time step 136 (time=2.72), 0.178132 s/step
# on time step 154 (time=3.08), 0.231331 s/step
# on time step 162 (time=3.24), 0.526123 s/step
# on time step 170 (time=3.4), 0.570698 s/step
# on time step 178 (time=3.56), 0.533347 s/step
# on time step 187 (time=3.74), 0.502291 s/step
# on time step 195 (time=3.9), 0.519361 s/step
# on time step 203 (time=4.06), 0.5061 s/step
# on time step 211 (time=4.22), 0.526469 s/step
# on time step 219 (time=4.38), 0.542298 s/step
# on time step 227 (time=4.54), 0.542469 s/step
# on time step 235 (time=4.7), 0.543335 s/step
# on time step 243 (time=4.86), 0.54345 s/step
# on time step 251 (time=5.02), 0.523255 s/step
# on time step 259 (time=5.18), 0.527363 s/step
# on time step 267 (time=5.34), 0.516181 s/step
# on time step 276 (time=5.52), 0.496872 s/step
# on time step 284 (time=5.68), 0.513326 s/step
# on time step 292 (time=5.84), 0.512662 s/step
# on time step 300 (time=6), 0.518876 s/step
# on time step 307 (time=6.14), 0.602275 s/step
# on time step 314 (time=6.28), 0.591312 s/step
# on time step 321 (time=6.42), 0.598912 s/step
# on time step 328 (time=6.56), 0.618306 s/step
# on time step 335 (time=6.7), 0.61121 s/step
# on time step 342 (time=6.84), 0.607951 s/step
# on time step 349 (time=6.98), 0.600749 s/step
# on time step 356 (time=7.12), 0.603852 s/step
# on time step 363 (time=7.26), 0.598862 s/step
# on time step 383 (time=7.66), 0.205098 s/step
# on time step 406 (time=8.12), 0.178108 s/step
# on time step 429 (time=8.58), 0.177386 s/step
# on time step 452 (time=9.04), 0.179659 s/step
# on time step 475 (time=9.5), 0.180496 s/step
# on time step 497 (time=9.94), 0.185308 s/step
# field decay(t = 10.02): 7.201863587882398e-10 / 7.201863587882398e-10 = 1.0
# on time step 519 (time=10.38), 0.182103 s/step
# on time step 541 (time=10.82), 0.182185 s/step
# on time step 563 (time=11.26), 0.184432 s/step
# on time step 586 (time=11.72), 0.178018 s/step
# on time step 608 (time=12.16), 0.182711 s/step
# on time step 619 (time=12.38), 0.388779 s/step
# on time step 627 (time=12.54), 0.533622 s/step
# on time step 635 (time=12.7), 0.537262 s/step
# on time step 643 (time=12.86), 0.523845 s/step
# on time step 652 (time=13.04), 0.502764 s/step
# on time step 660 (time=13.2), 0.5192 s/step
# on time step 668 (time=13.36), 0.515811 s/step
# on time step 676 (time=13.52), 0.502771 s/step
# on time step 684 (time=13.68), 0.511628 s/step
# on time step 692 (time=13.84), 0.52023 s/step
# on time step 700 (time=14), 0.526932 s/step
# on time step 708 (time=14.16), 0.540709 s/step
# on time step 716 (time=14.32), 0.544987 s/step
# on time step 724 (time=14.48), 0.504454 s/step
# on time step 733 (time=14.66), 0.498884 s/step
# on time step 741 (time=14.82), 0.504883 s/step
# on time step 749 (time=14.98), 0.504192 s/step
# on time step 758 (time=15.16), 0.494156 s/step
# on time step 766 (time=15.32), 0.504265 s/step
# on time step 773 (time=15.46), 0.594933 s/step
# on time step 780 (time=15.6), 0.611096 s/step
# on time step 787 (time=15.74), 0.596204 s/step
# on time step 794 (time=15.88), 0.604002 s/step
# on time step 801 (time=16.02), 0.609873 s/step
# on time step 808 (time=16.16), 0.60927 s/step
# on time step 821 (time=16.42), 0.314365 s/step
# on time step 844 (time=16.88), 0.181012 s/step
# on time step 867 (time=17.34), 0.178458 s/step
# on time step 890 (time=17.8), 0.180942 s/step
# on time step 913 (time=18.26), 0.181299 s/step
# on time step 936 (time=18.72), 0.179044 s/step
# on time step 959 (time=19.18), 0.181901 s/step
# on time step 982 (time=19.64), 0.180456 s/step
# field decay(t = 20.04): 0.0006011164553593983 / 0.0006011164553593983 = 1.0
# on time step 1005 (time=20.1), 0.177724 s/step
# on time step 1028 (time=20.56), 0.176944 s/step
# on time step 1051 (time=21.02), 0.180434 s/step
# on time step 1066 (time=21.32), 0.28993 s/step
# on time step 1074 (time=21.48), 0.540813 s/step
# on time step 1082 (time=21.64), 0.553298 s/step
# on time step 1090 (time=21.8), 0.525987 s/step
# on time step 1098 (time=21.96), 0.551491 s/step
# on time step 1107 (time=22.14), 0.471757 s/step
# on time step 1115 (time=22.3), 0.502845 s/step
# on time step 1123 (time=22.46), 0.511719 s/step
# on time step 1131 (time=22.62), 0.514791 s/step
# on time step 1139 (time=22.78), 0.543568 s/step
# on time step 1147 (time=22.94), 0.528215 s/step
# on time step 1155 (time=23.1), 0.538596 s/step
# on time step 1163 (time=23.26), 0.529924 s/step
# on time step 1171 (time=23.42), 0.517004 s/step
# on time step 1179 (time=23.58), 0.511483 s/step
# on time step 1187 (time=23.74), 0.519551 s/step
# on time step 1195 (time=23.9), 0.511286 s/step
# on time step 1203 (time=24.06), 0.542164 s/step
# on time step 1211 (time=24.22), 0.522236 s/step
# on time step 1219 (time=24.38), 0.565684 s/step
# on time step 1226 (time=24.52), 0.618872 s/step
# on time step 1233 (time=24.66), 0.619648 s/step
# on time step 1240 (time=24.8), 0.613546 s/step
# on time step 1247 (time=24.94), 0.6181 s/step
# on time step 1254 (time=25.08), 0.637563 s/step
# on time step 1261 (time=25.22), 0.624391 s/step
# on time step 1268 (time=25.36), 0.630254 s/step
# on time step 1275 (time=25.5), 0.617467 s/step
# on time step 1282 (time=25.64), 0.613974 s/step
# on time step 1289 (time=25.78), 0.629103 s/step
# on time step 1296 (time=25.92), 0.641275 s/step
# on time step 1303 (time=26.06), 0.612749 s/step
# on time step 1310 (time=26.2), 0.62039 s/step
# on time step 1317 (time=26.34), 0.597755 s/step
# on time step 1324 (time=26.48), 0.62841 s/step
# on time step 1331 (time=26.62), 0.623629 s/step
# on time step 1338 (time=26.76), 0.616215 s/step
# on time step 1345 (time=26.9), 0.626146 s/step
# on time step 1352 (time=27.04), 0.624825 s/step
# on time step 1359 (time=27.18), 0.631022 s/step
# on time step 1381 (time=27.62), 0.188508 s/step
# on time step 1404 (time=28.08), 0.181386 s/step
# on time step 1426 (time=28.52), 0.182943 s/step
# on time step 1449 (time=28.98), 0.181056 s/step
# on time step 1472 (time=29.44), 0.179822 s/step
# on time step 1494 (time=29.88), 0.181899 s/step
# field decay(t = 30.060000000000002): 0.05293567324415544 / 0.05293567324415544 = 1.0
# on time step 1516 (time=30.32), 0.184573 s/step
# on time step 1539 (time=30.78), 0.177571 s/step
# on time step 1562 (time=31.24), 0.177813 s/step
# on time step 1585 (time=31.7), 0.180321 s/step
# on time step 1606 (time=32.12), 0.191156 s/step
# on time step 1615 (time=32.3), 0.449519 s/step
# on time step 1623 (time=32.46), 0.517694 s/step
# on time step 1631 (time=32.62), 0.516521 s/step
# on time step 1639 (time=32.78), 0.520767 s/step
# on time step 1647 (time=32.94), 0.523181 s/step
# on time step 1656 (time=33.12), 0.463632 s/step
# on time step 1664 (time=33.28), 0.501115 s/step
# on time step 1672 (time=33.44), 0.50557 s/step
# on time step 1680 (time=33.6), 0.520389 s/step
# on time step 1688 (time=33.76), 0.520859 s/step
# on time step 1696 (time=33.92), 0.516414 s/step
# on time step 1704 (time=34.08), 0.517888 s/step
# on time step 1712 (time=34.24), 0.520365 s/step
# on time step 1720 (time=34.4), 0.512873 s/step
# on time step 1728 (time=34.56), 0.512628 s/step
# on time step 1736 (time=34.72), 0.509546 s/step
# on time step 1744 (time=34.88), 0.523675 s/step
# on time step 1752 (time=35.04), 0.532163 s/step
# on time step 1760 (time=35.2), 0.526635 s/step
# on time step 1767 (time=35.34), 0.609874 s/step
# on time step 1774 (time=35.48), 0.609523 s/step
# on time step 1781 (time=35.62), 0.609892 s/step
# on time step 1788 (time=35.76), 0.620458 s/step
# on time step 1795 (time=35.9), 0.613001 s/step
# on time step 1802 (time=36.04), 0.617285 s/step
# on time step 1809 (time=36.18), 0.622122 s/step
# on time step 1816 (time=36.32), 0.615604 s/step
# on time step 1823 (time=36.46), 0.614236 s/step
# on time step 1830 (time=36.6), 0.625953 s/step
# on time step 1847 (time=36.94), 0.237894 s/step
# on time step 1870 (time=37.4), 0.181351 s/step
# on time step 1892 (time=37.84), 0.18466 s/step
# on time step 1914 (time=38.28), 0.184372 s/step
# on time step 1937 (time=38.74), 0.179968 s/step
# on time step 1960 (time=39.2), 0.179248 s/step
# on time step 1983 (time=39.66), 0.177903 s/step
# field decay(t = 40.06): 0.08329269248777621 / 0.08329269248777621 = 1.0
# on time step 2005 (time=40.1), 0.185395 s/step
# on time step 2028 (time=40.56), 0.181044 s/step
# on time step 2050 (time=41), 0.183911 s/step
# on time step 2073 (time=41.46), 0.178802 s/step
# on time step 2084 (time=41.68), 0.39601 s/step
# on time step 2092 (time=41.84), 0.521929 s/step
# on time step 2100 (time=42), 0.525441 s/step
# on time step 2108 (time=42.16), 0.527112 s/step
# on time step 2117 (time=42.34), 0.494009 s/step
# on time step 2125 (time=42.5), 0.526652 s/step
# on time step 2133 (time=42.66), 0.551254 s/step
# on time step 2141 (time=42.82), 0.544597 s/step
# on time step 2149 (time=42.98), 0.516249 s/step
# on time step 2157 (time=43.14), 0.522776 s/step
# on time step 2165 (time=43.3), 0.526725 s/step
# on time step 2173 (time=43.46), 0.51781 s/step
# on time step 2181 (time=43.62), 0.514739 s/step
# on time step 2189 (time=43.78), 0.503937 s/step
# on time step 2197 (time=43.94), 0.516288 s/step
# on time step 2205 (time=44.1), 0.511399 s/step
# on time step 2213 (time=44.26), 0.500439 s/step
# on time step 2221 (time=44.42), 0.506022 s/step
# on time step 2229 (time=44.58), 0.537867 s/step
# on time step 2236 (time=44.72), 0.61102 s/step
# on time step 2243 (time=44.86), 0.611659 s/step
# on time step 2250 (time=45), 0.613937 s/step
# on time step 2257 (time=45.14), 0.607898 s/step
# on time step 2264 (time=45.28), 0.609596 s/step
# on time step 2271 (time=45.42), 0.611508 s/step
# on time step 2278 (time=45.56), 0.605376 s/step
# on time step 2285 (time=45.7), 0.594682 s/step
# on time step 2292 (time=45.84), 0.600337 s/step
# on time step 2299 (time=45.98), 0.60052 s/step
# on time step 2306 (time=46.12), 0.603925 s/step
# on time step 2313 (time=46.26), 0.5997 s/step
# on time step 2320 (time=46.4), 0.611844 s/step
# on time step 2327 (time=46.54), 0.608558 s/step
# on time step 2334 (time=46.68), 0.610412 s/step
# on time step 2341 (time=46.82), 0.611894 s/step
# on time step 2348 (time=46.96), 0.608044 s/step
# on time step 2355 (time=47.1), 0.609784 s/step
# on time step 2362 (time=47.24), 0.608836 s/step
# on time step 2369 (time=47.38), 0.604018 s/step
# on time step 2376 (time=47.52), 0.604622 s/step
# on time step 2383 (time=47.66), 0.603248 s/step
# on time step 2390 (time=47.8), 0.605093 s/step
# on time step 2397 (time=47.94), 0.605122 s/step
# on time step 2404 (time=48.08), 0.587556 s/step
# on time step 2427 (time=48.54), 0.176598 s/step
# on time step 2450 (time=49), 0.176502 s/step
# on time step 2473 (time=49.46), 0.179556 s/step
# on time step 2496 (time=49.92), 0.176509 s/step
# field decay(t = 50.08): 0.018838350138242952 / 0.08329269248777621 = 0.22617050278459438
# on time step 2518 (time=50.36), 0.182795 s/step
# on time step 2541 (time=50.82), 0.17755 s/step
# on time step 2564 (time=51.28), 0.175636 s/step
# on time step 2587 (time=51.74), 0.178567 s/step
# on time step 2610 (time=52.2), 0.179298 s/step
# on time step 2633 (time=52.66), 0.177565 s/step
# on time step 2655 (time=53.1), 0.190396 s/step
# on time step 2663 (time=53.26), 0.524084 s/step
# on time step 2671 (time=53.42), 0.521249 s/step
# on time step 2679 (time=53.58), 0.51928 s/step
# on time step 2687 (time=53.74), 0.517689 s/step
# on time step 2696 (time=53.92), 0.481268 s/step
# on time step 2704 (time=54.08), 0.508493 s/step
# on time step 2712 (time=54.24), 0.504766 s/step
# on time step 2720 (time=54.4), 0.505759 s/step
# on time step 2728 (time=54.56), 0.514127 s/step
# on time step 2736 (time=54.72), 0.540719 s/step
# on time step 2743 (time=54.86), 0.576151 s/step
# on time step 2751 (time=55.02), 0.555221 s/step
# on time step 2759 (time=55.18), 0.516549 s/step
# on time step 2767 (time=55.34), 0.520798 s/step
# on time step 2775 (time=55.5), 0.517305 s/step
# on time step 2783 (time=55.66), 0.543361 s/step
# on time step 2791 (time=55.82), 0.529763 s/step
# on time step 2799 (time=55.98), 0.545179 s/step
# on time step 2807 (time=56.14), 0.543316 s/step
# on time step 2814 (time=56.28), 0.608534 s/step
# on time step 2821 (time=56.42), 0.611806 s/step
# on time step 2828 (time=56.56), 0.641187 s/step
# on time step 2835 (time=56.7), 0.650469 s/step
# on time step 2841 (time=56.82), 0.672409 s/step
# on time step 2848 (time=56.96), 0.641666 s/step
# on time step 2855 (time=57.1), 0.654818 s/step
# on time step 2862 (time=57.24), 0.617172 s/step
# on time step 2869 (time=57.38), 0.61454 s/step
# on time step 2876 (time=57.52), 0.650014 s/step
# on time step 2882 (time=57.64), 0.668127 s/step
# on time step 2888 (time=57.76), 0.679772 s/step
# on time step 2894 (time=57.88), 0.67945 s/step
# on time step 2906 (time=58.12), 0.336823 s/step
# on time step 2928 (time=58.56), 0.189858 s/step
# on time step 2949 (time=58.98), 0.198671 s/step
# on time step 2971 (time=59.42), 0.19021 s/step
# on time step 2992 (time=59.84), 0.191773 s/step
# field decay(t = 60.1): 0.006039450117649799 / 0.08329269248777621 = 0.0725087632211689
# on time step 3013 (time=60.26), 0.191866 s/step
# on time step 3034 (time=60.68), 0.192387 s/step
# on time step 3056 (time=61.12), 0.187772 s/step
# on time step 3078 (time=61.56), 0.189519 s/step
# on time step 3100 (time=62), 0.188465 s/step
# on time step 3122 (time=62.44), 0.188382 s/step
# on time step 3139 (time=62.78), 0.255757 s/step
# on time step 3147 (time=62.94), 0.533601 s/step
# on time step 3155 (time=63.1), 0.548503 s/step
# on time step 3163 (time=63.26), 0.552218 s/step
# on time step 3171 (time=63.42), 0.552726 s/step
# on time step 3179 (time=63.58), 0.51641 s/step
# on time step 3187 (time=63.74), 0.545942 s/step
# on time step 3195 (time=63.9), 0.528559 s/step
# on time step 3203 (time=64.06), 0.529327 s/step
# on time step 3211 (time=64.22), 0.529447 s/step
# on time step 3218 (time=64.36), 0.580215 s/step
# on time step 3225 (time=64.5), 0.580485 s/step
# on time step 3233 (time=64.66), 0.531617 s/step
# on time step 3241 (time=64.82), 0.54393 s/step
# on time step 3249 (time=64.98), 0.548639 s/step
# on time step 3257 (time=65.14), 0.557588 s/step
# on time step 3265 (time=65.3), 0.533788 s/step
# on time step 3273 (time=65.46), 0.559866 s/step
# on time step 3281 (time=65.62), 0.52612 s/step
# on time step 3289 (time=65.78), 0.54979 s/step
# on time step 3295 (time=65.9), 0.693748 s/step
# on time step 3301 (time=66.02), 0.684142 s/step
# on time step 3308 (time=66.16), 0.616632 s/step
# on time step 3315 (time=66.3), 0.607014 s/step
# on time step 3322 (time=66.44), 0.607003 s/step
# on time step 3329 (time=66.58), 0.603457 s/step
# on time step 3336 (time=66.72), 0.602259 s/step
# on time step 3343 (time=66.86), 0.623017 s/step
# on time step 3350 (time=67), 0.648568 s/step
# on time step 3356 (time=67.12), 0.681544 s/step
# on time step 3362 (time=67.24), 0.702931 s/step
# on time step 3368 (time=67.36), 0.703513 s/step
# on time step 3389 (time=67.78), 0.198321 s/step
# on time step 3410 (time=68.2), 0.196454 s/step
# on time step 3431 (time=68.62), 0.190769 s/step
# on time step 3452 (time=69.04), 0.192449 s/step
# on time step 3473 (time=69.46), 0.194707 s/step
# on time step 3494 (time=69.88), 0.192698 s/step
# field decay(t = 70.12): 0.006340500178080834 / 0.08329269248777621 = 0.07612312663576516
# on time step 3515 (time=70.3), 0.195501 s/step
# on time step 3536 (time=70.72), 0.195417 s/step
# on time step 3557 (time=71.14), 0.194663 s/step
# on time step 3578 (time=71.56), 0.194895 s/step
# on time step 3599 (time=71.98), 0.196723 s/step
# on time step 3609 (time=72.18), 0.450115 s/step
# on time step 3616 (time=72.32), 0.610627 s/step
# on time step 3624 (time=72.48), 0.544627 s/step
# on time step 3632 (time=72.64), 0.540543 s/step
# on time step 3640 (time=72.8), 0.558429 s/step
# on time step 3649 (time=72.98), 0.478434 s/step
# on time step 3657 (time=73.14), 0.52251 s/step
# on time step 3665 (time=73.3), 0.544343 s/step
# on time step 3673 (time=73.46), 0.529839 s/step
# on time step 3681 (time=73.62), 0.534007 s/step
# on time step 3689 (time=73.78), 0.513526 s/step
# on time step 3697 (time=73.94), 0.505567 s/step
# on time step 3705 (time=74.1), 0.514855 s/step
# on time step 3714 (time=74.28), 0.500022 s/step
# on time step 3722 (time=74.44), 0.506642 s/step
# on time step 3730 (time=74.6), 0.506617 s/step
# on time step 3738 (time=74.76), 0.511894 s/step
# on time step 3746 (time=74.92), 0.509728 s/step
# on time step 3754 (time=75.08), 0.511239 s/step
# on time step 3761 (time=75.22), 0.594142 s/step
# on time step 3768 (time=75.36), 0.613869 s/step
# on time step 3775 (time=75.5), 0.6035 s/step
# on time step 3782 (time=75.64), 0.60208 s/step
# on time step 3789 (time=75.78), 0.59893 s/step
# on time step 3796 (time=75.92), 0.601831 s/step
# on time step 3803 (time=76.06), 0.601574 s/step
# on time step 3810 (time=76.2), 0.60049 s/step
# on time step 3817 (time=76.34), 0.606554 s/step
# on time step 3824 (time=76.48), 0.60543 s/step
# on time step 3831 (time=76.62), 0.606146 s/step
# on time step 3841 (time=76.82), 0.411429 s/step
# on time step 3864 (time=77.28), 0.177573 s/step
# on time step 3887 (time=77.74), 0.180976 s/step
# on time step 3910 (time=78.2), 0.180916 s/step
# on time step 3931 (time=78.62), 0.19061 s/step
# on time step 3953 (time=79.06), 0.18781 s/step
# on time step 3975 (time=79.5), 0.185385 s/step
# on time step 3997 (time=79.94), 0.183775 s/step
# field decay(t = 80.14): 0.0005126570466646643 / 0.08329269248777621 = 0.006154886237347897
# on time step 4019 (time=80.38), 0.184445 s/step
# on time step 4041 (time=80.82), 0.183808 s/step
# on time step 4062 (time=81.24), 0.190894 s/step
# on time step 4083 (time=81.66), 0.20622 s/step
# on time step 4091 (time=81.82), 0.530041 s/step
# on time step 4099 (time=81.98), 0.541342 s/step
# on time step 4107 (time=82.14), 0.545037 s/step
# on time step 4115 (time=82.3), 0.546157 s/step
# on time step 4124 (time=82.48), 0.498335 s/step
# on time step 4132 (time=82.64), 0.534071 s/step
# on time step 4140 (time=82.8), 0.514653 s/step
# on time step 4148 (time=82.96), 0.513607 s/step
# on time step 4156 (time=83.12), 0.512253 s/step
# on time step 4164 (time=83.28), 0.51376 s/step
# on time step 4172 (time=83.44), 0.512486 s/step
# on time step 4180 (time=83.6), 0.512109 s/step
# on time step 4189 (time=83.78), 0.496693 s/step
# on time step 4197 (time=83.94), 0.501136 s/step
# on time step 4205 (time=84.1), 0.50484 s/step
# on time step 4213 (time=84.26), 0.501106 s/step
# on time step 4221 (time=84.42), 0.506348 s/step
# on time step 4230 (time=84.6), 0.502247 s/step
# on time step 4238 (time=84.76), 0.530522 s/step
# on time step 4245 (time=84.9), 0.602525 s/step
# on time step 4252 (time=85.04), 0.595763 s/step
# on time step 4259 (time=85.18), 0.591509 s/step
# on time step 4266 (time=85.32), 0.599384 s/step
# on time step 4273 (time=85.46), 0.593408 s/step
# on time step 4280 (time=85.6), 0.597634 s/step
# on time step 4287 (time=85.74), 0.603031 s/step
# on time step 4294 (time=85.88), 0.604909 s/step
# on time step 4301 (time=86.02), 0.608961 s/step
# on time step 4308 (time=86.16), 0.60475 s/step
# on time step 4315 (time=86.3), 0.594459 s/step
# on time step 4338 (time=86.76), 0.177685 s/step
# on time step 4361 (time=87.22), 0.177055 s/step
# on time step 4384 (time=87.68), 0.175649 s/step
# on time step 4407 (time=88.14), 0.175244 s/step
# on time step 4430 (time=88.6), 0.176746 s/step
# on time step 4453 (time=89.06), 0.175875 s/step
# on time step 4476 (time=89.52), 0.179603 s/step
# on time step 4499 (time=89.98), 0.178431 s/step
# field decay(t = 90.16): 0.000664251381664179 / 0.08329269248777621 = 0.007974905862980268
# on time step 4522 (time=90.44), 0.181382 s/step
# on time step 4545 (time=90.9), 0.179188 s/step
# on time step 4567 (time=91.34), 0.206533 s/step
# on time step 4575 (time=91.5), 0.539921 s/step
# on time step 4583 (time=91.66), 0.550652 s/step
# on time step 4591 (time=91.82), 0.539038 s/step
# on time step 4599 (time=91.98), 0.532822 s/step
# on time step 4608 (time=92.16), 0.480097 s/step
# on time step 4616 (time=92.32), 0.521513 s/step
# on time step 4624 (time=92.48), 0.513799 s/step
# on time step 4632 (time=92.64), 0.513046 s/step
# on time step 4640 (time=92.8), 0.509874 s/step
# on time step 4648 (time=92.96), 0.509928 s/step
# on time step 4656 (time=93.12), 0.51813 s/step
# on time step 4664 (time=93.28), 0.518335 s/step
# on time step 4672 (time=93.44), 0.513797 s/step
# on time step 4680 (time=93.6), 0.507602 s/step
# on time step 4688 (time=93.76), 0.505906 s/step
# on time step 4696 (time=93.92), 0.505197 s/step
# on time step 4704 (time=94.08), 0.529002 s/step
# on time step 4712 (time=94.24), 0.504281 s/step
# on time step 4720 (time=94.4), 0.515258 s/step
# on time step 4727 (time=94.54), 0.601333 s/step
# on time step 4734 (time=94.68), 0.602298 s/step
# on time step 4741 (time=94.82), 0.597158 s/step
# on time step 4748 (time=94.96), 0.596588 s/step
# on time step 4755 (time=95.1), 0.598289 s/step
# on time step 4762 (time=95.24), 0.598983 s/step
# on time step 4769 (time=95.38), 0.607084 s/step
# on time step 4776 (time=95.52), 0.59933 s/step
# on time step 4783 (time=95.66), 0.642991 s/step
# on time step 4790 (time=95.8), 0.620604 s/step
# on time step 4797 (time=95.94), 0.630928 s/step
# on time step 4813 (time=96.26), 0.258963 s/step
# on time step 4835 (time=96.7), 0.182866 s/step
# on time step 4858 (time=97.16), 0.17909 s/step
# on time step 4880 (time=97.6), 0.183695 s/step
# on time step 4902 (time=98.04), 0.185274 s/step
# on time step 4924 (time=98.48), 0.182848 s/step
# on time step 4946 (time=98.92), 0.182739 s/step
# on time step 4969 (time=99.38), 0.180712 s/step
# on time step 4992 (time=99.84), 0.180402 s/step
# field decay(t = 100.18): 8.234388238525433e-06 / 0.08329269248777621 = 9.886087233563602e-05
# run 0 finished at t = 100.18 (5009 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00067091 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 64.5404% done, 2.19787 s remaining
# subpixel-averaging is 64.5867% done, 2.19375 s remaining
# subpixel-averaging is 65.8123% done, 2.07797 s remaining
# time for set_epsilon = 32.1434 s
# -----------
# on time step 1 (time=0.02), 8.69796 s/step
# on time step 9 (time=0.18), 0.515606 s/step
# on time step 17 (time=0.34), 0.514084 s/step
# on time step 25 (time=0.5), 0.516902 s/step
# on time step 33 (time=0.66), 0.520785 s/step
# on time step 41 (time=0.82), 0.513483 s/step
# on time step 49 (time=0.98), 0.518559 s/step
# on time step 57 (time=1.14), 0.517213 s/step
# on time step 65 (time=1.3), 0.515043 s/step
# on time step 73 (time=1.46), 0.526517 s/step
# on time step 80 (time=1.6), 0.581765 s/step
# on time step 87 (time=1.74), 0.610264 s/step
# on time step 94 (time=1.88), 0.628563 s/step
# on time step 101 (time=2.02), 0.627653 s/step
# on time step 108 (time=2.16), 0.63048 s/step
# on time step 115 (time=2.3), 0.634382 s/step
# on time step 122 (time=2.44), 0.631219 s/step
# on time step 129 (time=2.58), 0.627271 s/step
# on time step 136 (time=2.72), 0.623443 s/step
# on time step 143 (time=2.86), 0.624293 s/step
# on time step 150 (time=3), 0.618369 s/step
# on time step 157 (time=3.14), 0.618872 s/step
# on time step 180 (time=3.6), 0.181593 s/step
# on time step 202 (time=4.04), 0.184743 s/step
# on time step 225 (time=4.5), 0.180013 s/step
# on time step 248 (time=4.96), 0.17674 s/step
# on time step 271 (time=5.42), 0.178371 s/step
# on time step 294 (time=5.88), 0.175301 s/step
# on time step 317 (time=6.34), 0.175815 s/step
# on time step 340 (time=6.8), 0.180838 s/step
# on time step 363 (time=7.26), 0.176175 s/step
# on time step 386 (time=7.72), 0.175099 s/step
# on time step 409 (time=8.18), 0.178123 s/step
# on time step 418 (time=8.36), 0.496357 s/step
# on time step 426 (time=8.52), 0.524512 s/step
# on time step 434 (time=8.68), 0.51817 s/step
# on time step 442 (time=8.84), 0.516845 s/step
# on time step 451 (time=9.02), 0.489791 s/step
# on time step 459 (time=9.18), 0.513756 s/step
# on time step 468 (time=9.36), 0.498443 s/step
# on time step 476 (time=9.52), 0.506985 s/step
# on time step 484 (time=9.68), 0.50842 s/step
# on time step 492 (time=9.84), 0.518541 s/step
# on time step 500 (time=10), 0.510529 s/step
# field decay(t = 10.02): 3.947888938092113e-10 / 3.947888938092113e-10 = 1.0
# on time step 508 (time=10.16), 0.511898 s/step
# on time step 516 (time=10.32), 0.503587 s/step
# on time step 525 (time=10.5), 0.498036 s/step
# on time step 533 (time=10.66), 0.50082 s/step
# on time step 541 (time=10.82), 0.500692 s/step
# on time step 549 (time=10.98), 0.507024 s/step
# on time step 557 (time=11.14), 0.505012 s/step
# on time step 565 (time=11.3), 0.530393 s/step
# on time step 572 (time=11.44), 0.610782 s/step
# on time step 579 (time=11.58), 0.607256 s/step
# on time step 586 (time=11.72), 0.598458 s/step
# on time step 593 (time=11.86), 0.600611 s/step
# on time step 600 (time=12), 0.608479 s/step
# on time step 607 (time=12.14), 0.607468 s/step
# on time step 614 (time=12.28), 0.607029 s/step
# on time step 621 (time=12.42), 0.603153 s/step
# on time step 628 (time=12.56), 0.608307 s/step
# on time step 635 (time=12.7), 0.605928 s/step
# on time step 642 (time=12.84), 0.596598 s/step
# on time step 662 (time=13.24), 0.202361 s/step
# on time step 685 (time=13.7), 0.175856 s/step
# on time step 708 (time=14.16), 0.175503 s/step
# on time step 731 (time=14.62), 0.179183 s/step
# on time step 754 (time=15.08), 0.177819 s/step
# on time step 777 (time=15.54), 0.179913 s/step
# on time step 800 (time=16), 0.178046 s/step
# on time step 823 (time=16.46), 0.177707 s/step
# on time step 846 (time=16.92), 0.179326 s/step
# on time step 869 (time=17.38), 0.17844 s/step
# on time step 891 (time=17.82), 0.181829 s/step
# on time step 902 (time=18.04), 0.364713 s/step
# on time step 910 (time=18.2), 0.520631 s/step
# on time step 918 (time=18.36), 0.521267 s/step
# on time step 926 (time=18.52), 0.524375 s/step
# on time step 934 (time=18.68), 0.518327 s/step
# on time step 943 (time=18.86), 0.488983 s/step
# on time step 951 (time=19.02), 0.504192 s/step
# on time step 959 (time=19.18), 0.516728 s/step
# on time step 967 (time=19.34), 0.510144 s/step
# on time step 975 (time=19.5), 0.522156 s/step
# on time step 983 (time=19.66), 0.520488 s/step
# on time step 991 (time=19.82), 0.522169 s/step
# on time step 999 (time=19.98), 0.515208 s/step
# field decay(t = 20.04): 4.087082128821947e-05 / 4.087082128821947e-05 = 1.0
# on time step 1007 (time=20.14), 0.510544 s/step
# on time step 1015 (time=20.3), 0.508288 s/step
# on time step 1023 (time=20.46), 0.50974 s/step
# on time step 1031 (time=20.62), 0.507701 s/step
# on time step 1039 (time=20.78), 0.501812 s/step
# on time step 1047 (time=20.94), 0.500977 s/step
# on time step 1054 (time=21.08), 0.574513 s/step
# on time step 1061 (time=21.22), 0.603193 s/step
# on time step 1068 (time=21.36), 0.598037 s/step
# on time step 1075 (time=21.5), 0.606743 s/step
# on time step 1082 (time=21.64), 0.607527 s/step
# on time step 1089 (time=21.78), 0.603318 s/step
# on time step 1096 (time=21.92), 0.60521 s/step
# on time step 1103 (time=22.06), 0.604025 s/step
# on time step 1110 (time=22.2), 0.600408 s/step
# on time step 1117 (time=22.34), 0.604512 s/step
# on time step 1124 (time=22.48), 0.611341 s/step
# on time step 1136 (time=22.72), 0.334724 s/step
# on time step 1159 (time=23.18), 0.179761 s/step
# on time step 1182 (time=23.64), 0.176607 s/step
# on time step 1205 (time=24.1), 0.17938 s/step
# on time step 1228 (time=24.56), 0.177429 s/step
# on time step 1251 (time=25.02), 0.178658 s/step
# on time step 1274 (time=25.48), 0.178618 s/step
# on time step 1297 (time=25.94), 0.178542 s/step
# on time step 1320 (time=26.4), 0.180047 s/step
# on time step 1343 (time=26.86), 0.176816 s/step
# on time step 1366 (time=27.32), 0.17704 s/step
# on time step 1382 (time=27.64), 0.251236 s/step
# on time step 1390 (time=27.8), 0.517246 s/step
# on time step 1398 (time=27.96), 0.518853 s/step
# on time step 1406 (time=28.12), 0.517344 s/step
# on time step 1414 (time=28.28), 0.516108 s/step
# on time step 1423 (time=28.46), 0.485937 s/step
# on time step 1431 (time=28.62), 0.510455 s/step
# on time step 1439 (time=28.78), 0.508929 s/step
# on time step 1447 (time=28.94), 0.509096 s/step
# on time step 1455 (time=29.1), 0.508812 s/step
# on time step 1463 (time=29.26), 0.517553 s/step
# on time step 1471 (time=29.42), 0.505454 s/step
# on time step 1479 (time=29.58), 0.526957 s/step
# on time step 1487 (time=29.74), 0.50727 s/step
# on time step 1496 (time=29.92), 0.498002 s/step
# field decay(t = 30.060000000000002): 0.01849782326838811 / 0.01849782326838811 = 1.0
# on time step 1505 (time=30.1), 0.497536 s/step
# on time step 1514 (time=30.28), 0.501599 s/step
# on time step 1522 (time=30.44), 0.503484 s/step
# on time step 1530 (time=30.6), 0.507685 s/step
# on time step 1538 (time=30.76), 0.571831 s/step
# on time step 1545 (time=30.9), 0.599159 s/step
# on time step 1552 (time=31.04), 0.5984 s/step
# on time step 1559 (time=31.18), 0.604699 s/step
# on time step 1566 (time=31.32), 0.596702 s/step
# on time step 1573 (time=31.46), 0.605456 s/step
# on time step 1580 (time=31.6), 0.608697 s/step
# on time step 1587 (time=31.74), 0.601675 s/step
# on time step 1594 (time=31.88), 0.604353 s/step
# on time step 1601 (time=32.02), 0.601076 s/step
# on time step 1608 (time=32.16), 0.592302 s/step
# on time step 1619 (time=32.38), 0.372162 s/step
# on time step 1642 (time=32.84), 0.179131 s/step
# on time step 1665 (time=33.3), 0.180442 s/step
# on time step 1688 (time=33.76), 0.179146 s/step
# on time step 1711 (time=34.22), 0.178075 s/step
# on time step 1734 (time=34.68), 0.17976 s/step
# on time step 1757 (time=35.14), 0.177151 s/step
# on time step 1780 (time=35.6), 0.17717 s/step
# on time step 1803 (time=36.06), 0.177324 s/step
# on time step 1826 (time=36.52), 0.177056 s/step
# on time step 1849 (time=36.98), 0.176905 s/step
# on time step 1867 (time=37.34), 0.222384 s/step
# on time step 1875 (time=37.5), 0.523181 s/step
# on time step 1883 (time=37.66), 0.520814 s/step
# on time step 1891 (time=37.82), 0.519671 s/step
# on time step 1899 (time=37.98), 0.523352 s/step
# on time step 1908 (time=38.16), 0.474871 s/step
# on time step 1916 (time=38.32), 0.514986 s/step
# on time step 1924 (time=38.48), 0.508926 s/step
# on time step 1932 (time=38.64), 0.514927 s/step
# on time step 1940 (time=38.8), 0.520048 s/step
# on time step 1948 (time=38.96), 0.519518 s/step
# on time step 1956 (time=39.12), 0.523959 s/step
# on time step 1964 (time=39.28), 0.517639 s/step
# on time step 1972 (time=39.44), 0.50772 s/step
# on time step 1980 (time=39.6), 0.505803 s/step
# on time step 1988 (time=39.76), 0.50333 s/step
# on time step 1997 (time=39.94), 0.498891 s/step
# field decay(t = 40.06): 0.0834522862239523 / 0.0834522862239523 = 1.0
# on time step 2005 (time=40.1), 0.50089 s/step
# on time step 2013 (time=40.26), 0.504702 s/step
# on time step 2021 (time=40.42), 0.537964 s/step
# on time step 2028 (time=40.56), 0.602682 s/step
# on time step 2035 (time=40.7), 0.596512 s/step
# on time step 2042 (time=40.84), 0.600755 s/step
# on time step 2049 (time=40.98), 0.622558 s/step
# on time step 2056 (time=41.12), 0.649447 s/step
# on time step 2063 (time=41.26), 0.631436 s/step
# on time step 2070 (time=41.4), 0.646146 s/step
# on time step 2077 (time=41.54), 0.621511 s/step
# on time step 2084 (time=41.68), 0.610423 s/step
# on time step 2091 (time=41.82), 0.591064 s/step
# on time step 2098 (time=41.96), 0.64782 s/step
# on time step 2116 (time=42.32), 0.230049 s/step
# on time step 2139 (time=42.78), 0.177374 s/step
# on time step 2162 (time=43.24), 0.176289 s/step
# on time step 2185 (time=43.7), 0.177995 s/step
# on time step 2207 (time=44.14), 0.18359 s/step
# on time step 2229 (time=44.58), 0.18774 s/step
# on time step 2251 (time=45.02), 0.188844 s/step
# on time step 2272 (time=45.44), 0.191517 s/step
# on time step 2293 (time=45.86), 0.199786 s/step
# on time step 2314 (time=46.28), 0.193644 s/step
# on time step 2336 (time=46.72), 0.191029 s/step
# on time step 2347 (time=46.94), 0.364364 s/step
# on time step 2355 (time=47.1), 0.539452 s/step
# on time step 2363 (time=47.26), 0.521062 s/step
# on time step 2371 (time=47.42), 0.527394 s/step
# on time step 2379 (time=47.58), 0.52083 s/step
# on time step 2388 (time=47.76), 0.498903 s/step
# on time step 2396 (time=47.92), 0.546576 s/step
# on time step 2404 (time=48.08), 0.526759 s/step
# on time step 2412 (time=48.24), 0.529802 s/step
# on time step 2420 (time=48.4), 0.511925 s/step
# on time step 2428 (time=48.56), 0.529028 s/step
# on time step 2436 (time=48.72), 0.514718 s/step
# on time step 2444 (time=48.88), 0.515162 s/step
# on time step 2452 (time=49.04), 0.521208 s/step
# on time step 2460 (time=49.2), 0.513549 s/step
# on time step 2468 (time=49.36), 0.50603 s/step
# on time step 2476 (time=49.52), 0.512382 s/step
# on time step 2484 (time=49.68), 0.50782 s/step
# on time step 2492 (time=49.84), 0.515689 s/step
# on time step 2500 (time=50), 0.532567 s/step
# field decay(t = 50.08): 0.0819871061270404 / 0.0834522862239523 = 0.9824429004499655
# on time step 2507 (time=50.14), 0.617762 s/step
# on time step 2514 (time=50.28), 0.641726 s/step
# on time step 2521 (time=50.42), 0.621147 s/step
# on time step 2528 (time=50.56), 0.628581 s/step
# on time step 2535 (time=50.7), 0.620504 s/step
# on time step 2542 (time=50.84), 0.602175 s/step
# on time step 2549 (time=50.98), 0.61616 s/step
# on time step 2556 (time=51.12), 0.606745 s/step
# on time step 2563 (time=51.26), 0.603362 s/step
# on time step 2570 (time=51.4), 0.631096 s/step
# on time step 2577 (time=51.54), 0.631616 s/step
# on time step 2588 (time=51.76), 0.364927 s/step
# on time step 2610 (time=52.2), 0.187215 s/step
# on time step 2631 (time=52.62), 0.196707 s/step
# on time step 2653 (time=53.06), 0.183919 s/step
# on time step 2676 (time=53.52), 0.175757 s/step
# on time step 2699 (time=53.98), 0.175553 s/step
# on time step 2722 (time=54.44), 0.176277 s/step
# on time step 2745 (time=54.9), 0.179163 s/step
# on time step 2768 (time=55.36), 0.178346 s/step
# on time step 2791 (time=55.82), 0.1757 s/step
# on time step 2814 (time=56.28), 0.175145 s/step
# on time step 2833 (time=56.66), 0.225475 s/step
# on time step 2841 (time=56.82), 0.530158 s/step
# on time step 2849 (time=56.98), 0.533398 s/step
# on time step 2857 (time=57.14), 0.530457 s/step
# on time step 2865 (time=57.3), 0.521372 s/step
# on time step 2874 (time=57.48), 0.484794 s/step
# on time step 2882 (time=57.64), 0.527996 s/step
# on time step 2890 (time=57.8), 0.507274 s/step
# on time step 2898 (time=57.96), 0.508313 s/step
# on time step 2906 (time=58.12), 0.521688 s/step
# on time step 2914 (time=58.28), 0.537087 s/step
# on time step 2922 (time=58.44), 0.547965 s/step
# on time step 2930 (time=58.6), 0.503733 s/step
# on time step 2938 (time=58.76), 0.512457 s/step
# on time step 2946 (time=58.92), 0.538594 s/step
# on time step 2954 (time=59.08), 0.518976 s/step
# on time step 2962 (time=59.24), 0.518592 s/step
# on time step 2970 (time=59.4), 0.52144 s/step
# on time step 2978 (time=59.56), 0.520528 s/step
# on time step 2986 (time=59.72), 0.511138 s/step
# on time step 2993 (time=59.86), 0.6119 s/step
# on time step 3000 (time=60), 0.597052 s/step
# field decay(t = 60.1): 0.030840372380737946 / 0.0834522862239523 = 0.36955695015921813
# on time step 3007 (time=60.14), 0.609159 s/step
# on time step 3014 (time=60.28), 0.616582 s/step
# on time step 3021 (time=60.42), 0.595631 s/step
# on time step 3028 (time=60.56), 0.609723 s/step
# on time step 3035 (time=60.7), 0.590746 s/step
# on time step 3042 (time=60.84), 0.593339 s/step
# on time step 3049 (time=60.98), 0.603074 s/step
# on time step 3056 (time=61.12), 0.599382 s/step
# on time step 3063 (time=61.26), 0.604525 s/step
# on time step 3077 (time=61.54), 0.28749 s/step
# on time step 3099 (time=61.98), 0.182667 s/step
# on time step 3121 (time=62.42), 0.184203 s/step
# on time step 3143 (time=62.86), 0.189567 s/step
# on time step 3165 (time=63.3), 0.185067 s/step
# on time step 3187 (time=63.74), 0.183632 s/step
# on time step 3209 (time=64.18), 0.183471 s/step
# on time step 3231 (time=64.62), 0.182069 s/step
# on time step 3253 (time=65.06), 0.190055 s/step
# on time step 3275 (time=65.5), 0.188783 s/step
# on time step 3298 (time=65.96), 0.177655 s/step
# on time step 3317 (time=66.34), 0.2294 s/step
# on time step 3325 (time=66.5), 0.50929 s/step
# on time step 3333 (time=66.66), 0.505815 s/step
# on time step 3341 (time=66.82), 0.518468 s/step
# on time step 3349 (time=66.98), 0.5246 s/step
# on time step 3358 (time=67.16), 0.487539 s/step
# on time step 3366 (time=67.32), 0.51395 s/step
# on time step 3374 (time=67.48), 0.514749 s/step
# on time step 3382 (time=67.64), 0.51126 s/step
# on time step 3390 (time=67.8), 0.511782 s/step
# on time step 3398 (time=67.96), 0.543501 s/step
# on time step 3406 (time=68.12), 0.539732 s/step
# on time step 3414 (time=68.28), 0.535374 s/step
# on time step 3422 (time=68.44), 0.512302 s/step
# on time step 3430 (time=68.6), 0.503246 s/step
# on time step 3439 (time=68.78), 0.49807 s/step
# on time step 3448 (time=68.96), 0.495958 s/step
# on time step 3457 (time=69.14), 0.499723 s/step
# on time step 3465 (time=69.3), 0.50234 s/step
# on time step 3473 (time=69.46), 0.56438 s/step
# on time step 3480 (time=69.6), 0.596738 s/step
# on time step 3487 (time=69.74), 0.596258 s/step
# on time step 3494 (time=69.88), 0.598414 s/step
# on time step 3501 (time=70.02), 0.594683 s/step
# field decay(t = 70.12): 0.0074631682108766695 / 0.0834522862239523 = 0.089430362528937
# on time step 3508 (time=70.16), 0.593655 s/step
# on time step 3515 (time=70.3), 0.592274 s/step
# on time step 3522 (time=70.44), 0.593227 s/step
# on time step 3529 (time=70.58), 0.595979 s/step
# on time step 3536 (time=70.72), 0.591898 s/step
# on time step 3543 (time=70.86), 0.599188 s/step
# on time step 3556 (time=71.12), 0.309145 s/step
# on time step 3579 (time=71.58), 0.177554 s/step
# on time step 3602 (time=72.04), 0.175048 s/step
# on time step 3626 (time=72.52), 0.173597 s/step
# on time step 3649 (time=72.98), 0.174934 s/step
# on time step 3672 (time=73.44), 0.177538 s/step
# on time step 3695 (time=73.9), 0.174637 s/step
# on time step 3718 (time=74.36), 0.175641 s/step
# on time step 3741 (time=74.82), 0.176012 s/step
# on time step 3764 (time=75.28), 0.176224 s/step
# on time step 3787 (time=75.74), 0.17946 s/step
# on time step 3803 (time=76.06), 0.27889 s/step
# on time step 3811 (time=76.22), 0.522137 s/step
# on time step 3819 (time=76.38), 0.520728 s/step
# on time step 3827 (time=76.54), 0.522409 s/step
# on time step 3835 (time=76.7), 0.530976 s/step
# on time step 3844 (time=76.88), 0.47817 s/step
# on time step 3852 (time=77.04), 0.503068 s/step
# on time step 3861 (time=77.22), 0.499565 s/step
# on time step 3869 (time=77.38), 0.511687 s/step
# on time step 3877 (time=77.54), 0.514516 s/step
# on time step 3885 (time=77.7), 0.539628 s/step
# on time step 3893 (time=77.86), 0.531078 s/step
# on time step 3901 (time=78.02), 0.526921 s/step
# on time step 3909 (time=78.18), 0.506941 s/step
# on time step 3917 (time=78.34), 0.510077 s/step
# on time step 3925 (time=78.5), 0.516774 s/step
# on time step 3934 (time=78.68), 0.490214 s/step
# on time step 3943 (time=78.86), 0.498663 s/step
# on time step 3952 (time=79.04), 0.488606 s/step
# on time step 3959 (time=79.18), 0.581556 s/step
# on time step 3966 (time=79.32), 0.598571 s/step
# on time step 3973 (time=79.46), 0.593764 s/step
# on time step 3980 (time=79.6), 0.595789 s/step
# on time step 3987 (time=79.74), 0.60061 s/step
# on time step 3994 (time=79.88), 0.588784 s/step
# on time step 4001 (time=80.02), 0.596963 s/step
# field decay(t = 80.14): 0.002037601614661099 / 0.0834522862239523 = 0.024416366607296982
# on time step 4008 (time=80.16), 0.597589 s/step
# on time step 4015 (time=80.3), 0.593996 s/step
# on time step 4022 (time=80.44), 0.595394 s/step
# on time step 4029 (time=80.58), 0.59936 s/step
# on time step 4044 (time=80.88), 0.277615 s/step
# on time step 4067 (time=81.34), 0.177478 s/step
# on time step 4090 (time=81.8), 0.175545 s/step
# on time step 4113 (time=82.26), 0.17437 s/step
# on time step 4136 (time=82.72), 0.176626 s/step
# on time step 4159 (time=83.18), 0.177595 s/step
# on time step 4182 (time=83.64), 0.178493 s/step
# on time step 4205 (time=84.1), 0.17829 s/step
# on time step 4228 (time=84.56), 0.176876 s/step
# on time step 4251 (time=85.02), 0.177665 s/step
# on time step 4274 (time=85.48), 0.174832 s/step
# on time step 4290 (time=85.8), 0.276528 s/step
# on time step 4298 (time=85.96), 0.516444 s/step
# on time step 4306 (time=86.12), 0.513229 s/step
# on time step 4314 (time=86.28), 0.513598 s/step
# on time step 4322 (time=86.44), 0.510659 s/step
# on time step 4331 (time=86.62), 0.473775 s/step
# on time step 4340 (time=86.8), 0.500519 s/step
# on time step 4348 (time=86.96), 0.501085 s/step
# on time step 4356 (time=87.12), 0.500445 s/step
# on time step 4364 (time=87.28), 0.506631 s/step
# on time step 4372 (time=87.44), 0.501371 s/step
# on time step 4380 (time=87.6), 0.507352 s/step
# on time step 4388 (time=87.76), 0.502412 s/step
# on time step 4396 (time=87.92), 0.500349 s/step
# on time step 4405 (time=88.1), 0.494833 s/step
# on time step 4414 (time=88.28), 0.499039 s/step
# on time step 4423 (time=88.46), 0.489044 s/step
# on time step 4432 (time=88.64), 0.489511 s/step
# on time step 4440 (time=88.8), 0.503269 s/step
# on time step 4447 (time=88.94), 0.594178 s/step
# on time step 4454 (time=89.08), 0.595662 s/step
# on time step 4461 (time=89.22), 0.59056 s/step
# on time step 4468 (time=89.36), 0.586518 s/step
# on time step 4475 (time=89.5), 0.598872 s/step
# on time step 4482 (time=89.64), 0.595256 s/step
# on time step 4489 (time=89.78), 0.598009 s/step
# on time step 4496 (time=89.92), 0.596929 s/step
# on time step 4503 (time=90.06), 0.601866 s/step
# field decay(t = 90.16): 0.0026056068733526267 / 0.0834522862239523 = 0.031222714095096544
# on time step 4510 (time=90.2), 0.595595 s/step
# on time step 4517 (time=90.34), 0.601509 s/step
# on time step 4535 (time=90.7), 0.222764 s/step
# on time step 4558 (time=91.16), 0.176379 s/step
# on time step 4581 (time=91.62), 0.177075 s/step
# on time step 4604 (time=92.08), 0.176545 s/step
# on time step 4627 (time=92.54), 0.175572 s/step
# on time step 4650 (time=93), 0.175918 s/step
# on time step 4673 (time=93.46), 0.177757 s/step
# on time step 4696 (time=93.92), 0.17678 s/step
# on time step 4719 (time=94.38), 0.17557 s/step
# on time step 4742 (time=94.84), 0.175477 s/step
# on time step 4765 (time=95.3), 0.174936 s/step
# on time step 4780 (time=95.6), 0.279401 s/step
# on time step 4788 (time=95.76), 0.513333 s/step
# on time step 4796 (time=95.92), 0.507845 s/step
# on time step 4804 (time=96.08), 0.509519 s/step
# on time step 4812 (time=96.24), 0.509034 s/step
# on time step 4821 (time=96.42), 0.476184 s/step
# on time step 4829 (time=96.58), 0.518536 s/step
# on time step 4837 (time=96.74), 0.506671 s/step
# on time step 4845 (time=96.9), 0.502318 s/step
# on time step 4853 (time=97.06), 0.525815 s/step
# on time step 4861 (time=97.22), 0.529604 s/step
# on time step 4869 (time=97.38), 0.536438 s/step
# on time step 4877 (time=97.54), 0.530286 s/step
# on time step 4885 (time=97.7), 0.542412 s/step
# on time step 4893 (time=97.86), 0.522946 s/step
# on time step 4901 (time=98.02), 0.513196 s/step
# on time step 4909 (time=98.18), 0.516318 s/step
# on time step 4917 (time=98.34), 0.523064 s/step
# on time step 4925 (time=98.5), 0.509303 s/step
# on time step 4933 (time=98.66), 0.551559 s/step
# on time step 4940 (time=98.8), 0.618184 s/step
# on time step 4947 (time=98.94), 0.635439 s/step
# on time step 4954 (time=99.08), 0.634973 s/step
# on time step 4961 (time=99.22), 0.624184 s/step
# on time step 4968 (time=99.36), 0.607759 s/step
# on time step 4975 (time=99.5), 0.617253 s/step
# on time step 4982 (time=99.64), 0.599825 s/step
# on time step 4989 (time=99.78), 0.598557 s/step
# on time step 4996 (time=99.92), 0.600956 s/step
# on time step 5003 (time=100.06), 0.596902 s/step
# field decay(t = 100.18): 0.002104608214429061 / 0.0834522862239523 = 0.02521929967000713
# on time step 5010 (time=100.2), 0.597157 s/step
# on time step 5032 (time=100.64), 0.18711 s/step
# on time step 5055 (time=101.1), 0.177975 s/step
# on time step 5078 (time=101.56), 0.178324 s/step
# on time step 5101 (time=102.02), 0.176425 s/step
# on time step 5124 (time=102.48), 0.174876 s/step
# on time step 5147 (time=102.94), 0.177564 s/step
# on time step 5170 (time=103.4), 0.177996 s/step
# on time step 5193 (time=103.86), 0.176482 s/step
# on time step 5216 (time=104.32), 0.177959 s/step
# on time step 5239 (time=104.78), 0.176143 s/step
# on time step 5263 (time=105.26), 0.173875 s/step
# on time step 5275 (time=105.5), 0.344486 s/step
# on time step 5283 (time=105.66), 0.508844 s/step
# on time step 5291 (time=105.82), 0.508179 s/step
# on time step 5299 (time=105.98), 0.511128 s/step
# on time step 5307 (time=106.14), 0.513579 s/step
# on time step 5316 (time=106.32), 0.472691 s/step
# on time step 5325 (time=106.5), 0.496886 s/step
# on time step 5333 (time=106.66), 0.501589 s/step
# on time step 5341 (time=106.82), 0.500346 s/step
# on time step 5349 (time=106.98), 0.504828 s/step
# on time step 5357 (time=107.14), 0.511351 s/step
# on time step 5365 (time=107.3), 0.509764 s/step
# on time step 5373 (time=107.46), 0.506376 s/step
# on time step 5382 (time=107.64), 0.494577 s/step
# on time step 5391 (time=107.82), 0.49563 s/step
# on time step 5400 (time=108), 0.497861 s/step
# on time step 5408 (time=108.16), 0.500695 s/step
# on time step 5417 (time=108.34), 0.496012 s/step
# on time step 5425 (time=108.5), 0.530992 s/step
# on time step 5432 (time=108.64), 0.599303 s/step
# on time step 5439 (time=108.78), 0.597269 s/step
# on time step 5446 (time=108.92), 0.597339 s/step
# on time step 5453 (time=109.06), 0.597247 s/step
# on time step 5460 (time=109.2), 0.59271 s/step
# on time step 5467 (time=109.34), 0.59812 s/step
# on time step 5474 (time=109.48), 0.591727 s/step
# on time step 5481 (time=109.62), 0.590712 s/step
# on time step 5488 (time=109.76), 0.594142 s/step
# on time step 5495 (time=109.9), 0.597459 s/step
# on time step 5502 (time=110.04), 0.600892 s/step
# field decay(t = 110.2): 0.0006704975968779999 / 0.0834522862239523 = 0.008034502435063966
# on time step 5525 (time=110.5), 0.177705 s/step
# on time step 5548 (time=110.96), 0.176855 s/step
# on time step 5571 (time=111.42), 0.177194 s/step
# on time step 5594 (time=111.88), 0.174726 s/step
# on time step 5617 (time=112.34), 0.176094 s/step
# on time step 5640 (time=112.8), 0.175563 s/step
# on time step 5663 (time=113.26), 0.174158 s/step
# on time step 5686 (time=113.72), 0.174468 s/step
# on time step 5709 (time=114.18), 0.176812 s/step
# on time step 5732 (time=114.64), 0.175262 s/step
# on time step 5755 (time=115.1), 0.176126 s/step
# on time step 5768 (time=115.36), 0.329567 s/step
# on time step 5776 (time=115.52), 0.515965 s/step
# on time step 5784 (time=115.68), 0.513211 s/step
# on time step 5792 (time=115.84), 0.512618 s/step
# on time step 5800 (time=116), 0.514248 s/step
# on time step 5809 (time=116.18), 0.473699 s/step
# on time step 5818 (time=116.36), 0.498116 s/step
# on time step 5826 (time=116.52), 0.504173 s/step
# on time step 5835 (time=116.7), 0.498588 s/step
# on time step 5843 (time=116.86), 0.508311 s/step
# on time step 5851 (time=117.02), 0.511068 s/step
# on time step 5859 (time=117.18), 0.510891 s/step
# on time step 5867 (time=117.34), 0.504776 s/step
# on time step 5875 (time=117.5), 0.502766 s/step
# on time step 5883 (time=117.66), 0.500483 s/step
# on time step 5891 (time=117.82), 0.500645 s/step
# on time step 5900 (time=118), 0.493087 s/step
# on time step 5909 (time=118.18), 0.495794 s/step
# on time step 5917 (time=118.34), 0.522905 s/step
# on time step 5924 (time=118.48), 0.593321 s/step
# on time step 5931 (time=118.62), 0.595317 s/step
# on time step 5938 (time=118.76), 0.603244 s/step
# on time step 5945 (time=118.9), 0.600972 s/step
# on time step 5952 (time=119.04), 0.600344 s/step
# on time step 5959 (time=119.18), 0.594456 s/step
# on time step 5966 (time=119.32), 0.597323 s/step
# on time step 5973 (time=119.46), 0.59269 s/step
# on time step 5980 (time=119.6), 0.596671 s/step
# on time step 5987 (time=119.74), 0.595429 s/step
# on time step 5994 (time=119.88), 0.5948 s/step
# field decay(t = 120.22): 0.0003089230687506673 / 0.0834522862239523 = 0.0037017927576201122
# on time step 6017 (time=120.34), 0.18123 s/step
# on time step 6040 (time=120.8), 0.176984 s/step
# on time step 6063 (time=121.26), 0.178374 s/step
# on time step 6086 (time=121.72), 0.17425 s/step
# on time step 6110 (time=122.2), 0.173736 s/step
# on time step 6133 (time=122.66), 0.175122 s/step
# on time step 6156 (time=123.12), 0.174852 s/step
# on time step 6179 (time=123.58), 0.174569 s/step
# on time step 6202 (time=124.04), 0.176454 s/step
# on time step 6226 (time=124.52), 0.173985 s/step
# on time step 6249 (time=124.98), 0.192286 s/step
# on time step 6257 (time=125.14), 0.508789 s/step
# on time step 6265 (time=125.3), 0.507909 s/step
# on time step 6273 (time=125.46), 0.507453 s/step
# on time step 6281 (time=125.62), 0.50789 s/step
# on time step 6290 (time=125.8), 0.466309 s/step
# on time step 6298 (time=125.96), 0.504868 s/step
# on time step 6307 (time=126.14), 0.4906 s/step
# on time step 6315 (time=126.3), 0.502517 s/step
# on time step 6323 (time=126.46), 0.50544 s/step
# on time step 6331 (time=126.62), 0.508456 s/step
# on time step 6339 (time=126.78), 0.509462 s/step
# on time step 6347 (time=126.94), 0.50878 s/step
# on time step 6355 (time=127.1), 0.51071 s/step
# on time step 6364 (time=127.28), 0.493866 s/step
# on time step 6373 (time=127.46), 0.49372 s/step
# on time step 6381 (time=127.62), 0.502628 s/step
# on time step 6389 (time=127.78), 0.500001 s/step
# on time step 6397 (time=127.94), 0.501683 s/step
# on time step 6405 (time=128.1), 0.544331 s/step
# on time step 6412 (time=128.24), 0.594906 s/step
# on time step 6419 (time=128.38), 0.591674 s/step
# on time step 6426 (time=128.52), 0.592679 s/step
# on time step 6433 (time=128.66), 0.594196 s/step
# on time step 6440 (time=128.8), 0.589699 s/step
# on time step 6447 (time=128.94), 0.579971 s/step
# on time step 6454 (time=129.08), 0.595164 s/step
# on time step 6461 (time=129.22), 0.590082 s/step
# on time step 6468 (time=129.36), 0.591838 s/step
# on time step 6475 (time=129.5), 0.594334 s/step
# on time step 6483 (time=129.66), 0.520846 s/step
# on time step 6506 (time=130.12), 0.17551 s/step
# field decay(t = 130.24): 3.6429300167373704e-05 / 0.0834522862239523 = 0.0004365284861053674
# run 0 finished at t = 130.24 (6512 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000672817 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 67.8241% done, 1.89776 s remaining
# subpixel-averaging is 66.0898% done, 2.0527 s remaining
# subpixel-averaging is 67.0841% done, 1.96268 s remaining
# time for set_epsilon = 31.6061 s
# -----------
# on time step 1 (time=0.02), 8.49284 s/step
# on time step 9 (time=0.18), 0.514622 s/step
# on time step 17 (time=0.34), 0.515265 s/step
# on time step 25 (time=0.5), 0.51498 s/step
# on time step 33 (time=0.66), 0.516338 s/step
# on time step 42 (time=0.84), 0.477652 s/step
# on time step 51 (time=1.02), 0.499398 s/step
# on time step 59 (time=1.18), 0.504052 s/step
# on time step 67 (time=1.34), 0.507755 s/step
# on time step 75 (time=1.5), 0.505874 s/step
# on time step 83 (time=1.66), 0.514091 s/step
# on time step 91 (time=1.82), 0.512943 s/step
# on time step 99 (time=1.98), 0.513576 s/step
# on time step 107 (time=2.14), 0.505797 s/step
# on time step 116 (time=2.32), 0.498841 s/step
# on time step 124 (time=2.48), 0.501421 s/step
# on time step 132 (time=2.64), 0.502333 s/step
# on time step 141 (time=2.82), 0.499671 s/step
# on time step 150 (time=3), 0.510757 s/step
# on time step 157 (time=3.14), 0.597522 s/step
# on time step 164 (time=3.28), 0.600753 s/step
# on time step 171 (time=3.42), 0.593721 s/step
# on time step 178 (time=3.56), 0.594481 s/step
# on time step 185 (time=3.7), 0.59935 s/step
# on time step 192 (time=3.84), 0.596426 s/step
# on time step 199 (time=3.98), 0.594569 s/step
# on time step 206 (time=4.12), 0.596042 s/step
# on time step 213 (time=4.26), 0.598398 s/step
# on time step 220 (time=4.4), 0.596967 s/step
# on time step 227 (time=4.54), 0.599958 s/step
# on time step 247 (time=4.94), 0.207692 s/step
# on time step 270 (time=5.4), 0.177969 s/step
# on time step 293 (time=5.86), 0.174532 s/step
# on time step 316 (time=6.32), 0.176005 s/step
# on time step 339 (time=6.78), 0.177576 s/step
# on time step 362 (time=7.24), 0.177655 s/step
# on time step 385 (time=7.7), 0.174111 s/step
# on time step 408 (time=8.16), 0.17658 s/step
# on time step 431 (time=8.62), 0.174099 s/step
# on time step 454 (time=9.08), 0.175234 s/step
# on time step 477 (time=9.54), 0.177339 s/step
# on time step 493 (time=9.86), 0.281149 s/step
# field decay(t = 10.02): 1.9578662795981986e-09 / 1.9578662795981986e-09 = 1.0
# on time step 501 (time=10.02), 0.511789 s/step
# on time step 509 (time=10.18), 0.511605 s/step
# on time step 517 (time=10.34), 0.507358 s/step
# on time step 525 (time=10.5), 0.512374 s/step
# on time step 534 (time=10.68), 0.474136 s/step
# on time step 542 (time=10.84), 0.504165 s/step
# on time step 551 (time=11.02), 0.498379 s/step
# on time step 559 (time=11.18), 0.501229 s/step
# on time step 567 (time=11.34), 0.503677 s/step
# on time step 575 (time=11.5), 0.510792 s/step
# on time step 583 (time=11.66), 0.511595 s/step
# on time step 591 (time=11.82), 0.50731 s/step
# on time step 599 (time=11.98), 0.506004 s/step
# on time step 607 (time=12.14), 0.502476 s/step
# on time step 615 (time=12.3), 0.502739 s/step
# on time step 624 (time=12.48), 0.497451 s/step
# on time step 633 (time=12.66), 0.497922 s/step
# on time step 642 (time=12.84), 0.506771 s/step
# on time step 649 (time=12.98), 0.606693 s/step
# on time step 656 (time=13.12), 0.602599 s/step
# on time step 663 (time=13.26), 0.600484 s/step
# on time step 670 (time=13.4), 0.598537 s/step
# on time step 677 (time=13.54), 0.602278 s/step
# on time step 684 (time=13.68), 0.589738 s/step
# on time step 691 (time=13.82), 0.597891 s/step
# on time step 698 (time=13.96), 0.600022 s/step
# on time step 705 (time=14.1), 0.595792 s/step
# on time step 712 (time=14.24), 0.598288 s/step
# on time step 719 (time=14.38), 0.600356 s/step
# on time step 740 (time=14.8), 0.198102 s/step
# on time step 763 (time=15.26), 0.176291 s/step
# on time step 786 (time=15.72), 0.175153 s/step
# on time step 809 (time=16.18), 0.174767 s/step
# on time step 832 (time=16.64), 0.176509 s/step
# on time step 855 (time=17.1), 0.176718 s/step
# on time step 878 (time=17.56), 0.177055 s/step
# on time step 901 (time=18.02), 0.177568 s/step
# on time step 924 (time=18.48), 0.174495 s/step
# on time step 947 (time=18.94), 0.174734 s/step
# on time step 970 (time=19.4), 0.177041 s/step
# on time step 985 (time=19.7), 0.28977 s/step
# on time step 993 (time=19.86), 0.50926 s/step
# on time step 1001 (time=20.02), 0.510276 s/step
# field decay(t = 20.04): 0.00012070019970849999 / 0.00012070019970849999 = 1.0
# on time step 1009 (time=20.18), 0.511395 s/step
# on time step 1017 (time=20.34), 0.512717 s/step
# on time step 1026 (time=20.52), 0.471586 s/step
# on time step 1035 (time=20.7), 0.494565 s/step
# on time step 1044 (time=20.88), 0.494604 s/step
# on time step 1052 (time=21.04), 0.506319 s/step
# on time step 1060 (time=21.2), 0.506266 s/step
# on time step 1068 (time=21.36), 0.506513 s/step
# on time step 1076 (time=21.52), 0.511061 s/step
# on time step 1084 (time=21.68), 0.509686 s/step
# on time step 1092 (time=21.84), 0.504932 s/step
# on time step 1100 (time=22), 0.502634 s/step
# on time step 1109 (time=22.18), 0.49739 s/step
# on time step 1118 (time=22.36), 0.497959 s/step
# on time step 1127 (time=22.54), 0.496362 s/step
# on time step 1135 (time=22.7), 0.511893 s/step
# on time step 1142 (time=22.84), 0.593727 s/step
# on time step 1149 (time=22.98), 0.599582 s/step
# on time step 1156 (time=23.12), 0.598694 s/step
# on time step 1163 (time=23.26), 0.599518 s/step
# on time step 1170 (time=23.4), 0.600711 s/step
# on time step 1177 (time=23.54), 0.589886 s/step
# on time step 1184 (time=23.68), 0.597649 s/step
# on time step 1191 (time=23.82), 0.602083 s/step
# on time step 1198 (time=23.96), 0.597724 s/step
# on time step 1205 (time=24.1), 0.597389 s/step
# on time step 1212 (time=24.24), 0.596347 s/step
# on time step 1233 (time=24.66), 0.196152 s/step
# on time step 1256 (time=25.12), 0.176087 s/step
# on time step 1279 (time=25.58), 0.177356 s/step
# on time step 1302 (time=26.04), 0.176175 s/step
# on time step 1325 (time=26.5), 0.177735 s/step
# on time step 1348 (time=26.96), 0.175628 s/step
# on time step 1371 (time=27.42), 0.17631 s/step
# on time step 1394 (time=27.88), 0.176095 s/step
# on time step 1417 (time=28.34), 0.176753 s/step
# on time step 1440 (time=28.8), 0.175705 s/step
# on time step 1463 (time=29.26), 0.177225 s/step
# on time step 1473 (time=29.46), 0.434117 s/step
# on time step 1481 (time=29.62), 0.510438 s/step
# on time step 1489 (time=29.78), 0.509027 s/step
# on time step 1497 (time=29.94), 0.50966 s/step
# field decay(t = 30.060000000000002): 0.05548565722206492 / 0.05548565722206492 = 1.0
# on time step 1505 (time=30.1), 0.514533 s/step
# on time step 1514 (time=30.28), 0.467913 s/step
# on time step 1523 (time=30.46), 0.489861 s/step
# on time step 1531 (time=30.62), 0.507089 s/step
# on time step 1539 (time=30.78), 0.50208 s/step
# on time step 1547 (time=30.94), 0.50408 s/step
# on time step 1555 (time=31.1), 0.505926 s/step
# on time step 1563 (time=31.26), 0.508688 s/step
# on time step 1571 (time=31.42), 0.513961 s/step
# on time step 1580 (time=31.6), 0.495848 s/step
# on time step 1588 (time=31.76), 0.50109 s/step
# on time step 1597 (time=31.94), 0.499327 s/step
# on time step 1606 (time=32.12), 0.497254 s/step
# on time step 1615 (time=32.3), 0.492662 s/step
# on time step 1623 (time=32.46), 0.538452 s/step
# on time step 1630 (time=32.6), 0.593111 s/step
# on time step 1637 (time=32.74), 0.59038 s/step
# on time step 1644 (time=32.88), 0.595993 s/step
# on time step 1651 (time=33.02), 0.592372 s/step
# on time step 1658 (time=33.16), 0.596322 s/step
# on time step 1665 (time=33.3), 0.592026 s/step
# on time step 1672 (time=33.44), 0.592782 s/step
# on time step 1679 (time=33.58), 0.589729 s/step
# on time step 1686 (time=33.72), 0.595764 s/step
# on time step 1693 (time=33.86), 0.592826 s/step
# on time step 1701 (time=34.02), 0.502121 s/step
# on time step 1724 (time=34.48), 0.174253 s/step
# on time step 1747 (time=34.94), 0.176561 s/step
# on time step 1770 (time=35.4), 0.173921 s/step
# on time step 1794 (time=35.88), 0.173856 s/step
# on time step 1817 (time=36.34), 0.177879 s/step
# on time step 1840 (time=36.8), 0.176768 s/step
# on time step 1863 (time=37.26), 0.177216 s/step
# on time step 1886 (time=37.72), 0.178405 s/step
# on time step 1909 (time=38.18), 0.178362 s/step
# on time step 1932 (time=38.64), 0.177775 s/step
# on time step 1953 (time=39.06), 0.206295 s/step
# on time step 1961 (time=39.22), 0.510012 s/step
# on time step 1969 (time=39.38), 0.511845 s/step
# on time step 1977 (time=39.54), 0.513563 s/step
# on time step 1985 (time=39.7), 0.510767 s/step
# on time step 1994 (time=39.88), 0.472443 s/step
# on time step 2002 (time=40.04), 0.506148 s/step
# field decay(t = 40.06): 0.15015950768369926 / 0.15015950768369926 = 1.0
# on time step 2010 (time=40.2), 0.503308 s/step
# on time step 2019 (time=40.38), 0.498759 s/step
# on time step 2027 (time=40.54), 0.50239 s/step
# on time step 2035 (time=40.7), 0.505532 s/step
# on time step 2043 (time=40.86), 0.501028 s/step
# on time step 2051 (time=41.02), 0.501026 s/step
# on time step 2060 (time=41.2), 0.496989 s/step
# on time step 2069 (time=41.38), 0.494622 s/step
# on time step 2078 (time=41.56), 0.497668 s/step
# on time step 2087 (time=41.74), 0.491129 s/step
# on time step 2095 (time=41.9), 0.502321 s/step
# on time step 2103 (time=42.06), 0.504924 s/step
# on time step 2110 (time=42.2), 0.572617 s/step
# on time step 2117 (time=42.34), 0.598165 s/step
# on time step 2124 (time=42.48), 0.59337 s/step
# on time step 2131 (time=42.62), 0.592164 s/step
# on time step 2138 (time=42.76), 0.598726 s/step
# on time step 2145 (time=42.9), 0.598114 s/step
# on time step 2152 (time=43.04), 0.598876 s/step
# on time step 2159 (time=43.18), 0.598576 s/step
# on time step 2166 (time=43.32), 0.598114 s/step
# on time step 2173 (time=43.46), 0.598892 s/step
# on time step 2180 (time=43.6), 0.605212 s/step
# on time step 2193 (time=43.86), 0.311048 s/step
# on time step 2216 (time=44.32), 0.175521 s/step
# on time step 2239 (time=44.78), 0.175401 s/step
# on time step 2262 (time=45.24), 0.175493 s/step
# on time step 2285 (time=45.7), 0.177225 s/step
# on time step 2308 (time=46.16), 0.17479 s/step
# on time step 2331 (time=46.62), 0.177336 s/step
# on time step 2354 (time=47.08), 0.177722 s/step
# on time step 2377 (time=47.54), 0.177757 s/step
# on time step 2400 (time=48), 0.17763 s/step
# on time step 2423 (time=48.46), 0.174702 s/step
# on time step 2442 (time=48.84), 0.225216 s/step
# on time step 2450 (time=49), 0.511362 s/step
# on time step 2458 (time=49.16), 0.514824 s/step
# on time step 2466 (time=49.32), 0.51959 s/step
# on time step 2474 (time=49.48), 0.515495 s/step
# on time step 2483 (time=49.66), 0.479291 s/step
# on time step 2491 (time=49.82), 0.50803 s/step
# on time step 2499 (time=49.98), 0.502215 s/step
# field decay(t = 50.08): 0.0797930324384759 / 0.15015950768369926 = 0.5313884792866693
# on time step 2507 (time=50.14), 0.501898 s/step
# on time step 2515 (time=50.3), 0.505953 s/step
# on time step 2523 (time=50.46), 0.509387 s/step
# on time step 2531 (time=50.62), 0.507831 s/step
# on time step 2539 (time=50.78), 0.506084 s/step
# on time step 2547 (time=50.94), 0.502281 s/step
# on time step 2555 (time=51.1), 0.500431 s/step
# on time step 2564 (time=51.28), 0.496937 s/step
# on time step 2572 (time=51.44), 0.500954 s/step
# on time step 2581 (time=51.62), 0.498138 s/step
# on time step 2590 (time=51.8), 0.49811 s/step
# on time step 2597 (time=51.94), 0.572751 s/step
# on time step 2604 (time=52.08), 0.59964 s/step
# on time step 2611 (time=52.22), 0.605715 s/step
# on time step 2618 (time=52.36), 0.600601 s/step
# on time step 2625 (time=52.5), 0.604597 s/step
# on time step 2632 (time=52.64), 0.601963 s/step
# on time step 2639 (time=52.78), 0.606317 s/step
# on time step 2646 (time=52.92), 0.597132 s/step
# on time step 2653 (time=53.06), 0.597775 s/step
# on time step 2660 (time=53.2), 0.601737 s/step
# on time step 2667 (time=53.34), 0.604608 s/step
# on time step 2682 (time=53.64), 0.271107 s/step
# on time step 2705 (time=54.1), 0.175026 s/step
# on time step 2728 (time=54.56), 0.176002 s/step
# on time step 2751 (time=55.02), 0.175477 s/step
# on time step 2774 (time=55.48), 0.176918 s/step
# on time step 2797 (time=55.94), 0.175794 s/step
# on time step 2820 (time=56.4), 0.178446 s/step
# on time step 2843 (time=56.86), 0.175919 s/step
# on time step 2866 (time=57.32), 0.177176 s/step
# on time step 2889 (time=57.78), 0.176145 s/step
# on time step 2912 (time=58.24), 0.176393 s/step
# on time step 2929 (time=58.58), 0.261008 s/step
# on time step 2937 (time=58.74), 0.515285 s/step
# on time step 2945 (time=58.9), 0.513789 s/step
# on time step 2953 (time=59.06), 0.515903 s/step
# on time step 2961 (time=59.22), 0.516465 s/step
# on time step 2970 (time=59.4), 0.467909 s/step
# on time step 2978 (time=59.56), 0.500143 s/step
# on time step 2986 (time=59.72), 0.500063 s/step
# on time step 2994 (time=59.88), 0.511406 s/step
# on time step 3002 (time=60.04), 0.506951 s/step
# field decay(t = 60.1): 0.017705399867717686 / 0.15015950768369926 = 0.11791061479112531
# on time step 3010 (time=60.2), 0.510299 s/step
# on time step 3018 (time=60.36), 0.509311 s/step
# on time step 3026 (time=60.52), 0.507356 s/step
# on time step 3034 (time=60.68), 0.505171 s/step
# on time step 3042 (time=60.84), 0.504056 s/step
# on time step 3051 (time=61.02), 0.498146 s/step
# on time step 3060 (time=61.2), 0.494835 s/step
# on time step 3069 (time=61.38), 0.496401 s/step
# on time step 3077 (time=61.54), 0.501583 s/step
# on time step 3084 (time=61.68), 0.598418 s/step
# on time step 3091 (time=61.82), 0.601139 s/step
# on time step 3098 (time=61.96), 0.598765 s/step
# on time step 3105 (time=62.1), 0.59805 s/step
# on time step 3112 (time=62.24), 0.598862 s/step
# on time step 3119 (time=62.38), 0.598494 s/step
# on time step 3126 (time=62.52), 0.597469 s/step
# on time step 3133 (time=62.66), 0.599997 s/step
# on time step 3140 (time=62.8), 0.596252 s/step
# on time step 3147 (time=62.94), 0.596537 s/step
# on time step 3154 (time=63.08), 0.598377 s/step
# on time step 3171 (time=63.42), 0.237444 s/step
# on time step 3194 (time=63.88), 0.175867 s/step
# on time step 3217 (time=64.34), 0.178353 s/step
# on time step 3240 (time=64.8), 0.177054 s/step
# on time step 3263 (time=65.26), 0.175378 s/step
# on time step 3286 (time=65.72), 0.176199 s/step
# on time step 3309 (time=66.18), 0.176794 s/step
# on time step 3332 (time=66.64), 0.17594 s/step
# on time step 3355 (time=67.1), 0.177336 s/step
# on time step 3378 (time=67.56), 0.175324 s/step
# on time step 3401 (time=68.02), 0.175984 s/step
# on time step 3415 (time=68.3), 0.299079 s/step
# on time step 3423 (time=68.46), 0.513312 s/step
# on time step 3431 (time=68.62), 0.513209 s/step
# on time step 3439 (time=68.78), 0.519455 s/step
# on time step 3447 (time=68.94), 0.513322 s/step
# on time step 3456 (time=69.12), 0.472224 s/step
# on time step 3465 (time=69.3), 0.496809 s/step
# on time step 3474 (time=69.48), 0.496951 s/step
# on time step 3482 (time=69.64), 0.502552 s/step
# on time step 3490 (time=69.8), 0.50685 s/step
# on time step 3498 (time=69.96), 0.513541 s/step
# field decay(t = 70.12): 0.005250742464219857 / 0.15015950768369926 = 0.03496776557952086
# on time step 3506 (time=70.12), 0.511783 s/step
# on time step 3514 (time=70.28), 0.516036 s/step
# on time step 3522 (time=70.44), 0.504531 s/step
# on time step 3531 (time=70.62), 0.498358 s/step
# on time step 3539 (time=70.78), 0.50184 s/step
# on time step 3548 (time=70.96), 0.499783 s/step
# on time step 3556 (time=71.12), 0.500904 s/step
# on time step 3564 (time=71.28), 0.522667 s/step
# on time step 3571 (time=71.42), 0.599566 s/step
# on time step 3578 (time=71.56), 0.596399 s/step
# on time step 3585 (time=71.7), 0.596457 s/step
# on time step 3592 (time=71.84), 0.594815 s/step
# on time step 3599 (time=71.98), 0.601388 s/step
# on time step 3606 (time=72.12), 0.596914 s/step
# on time step 3613 (time=72.26), 0.599311 s/step
# on time step 3620 (time=72.4), 0.590295 s/step
# on time step 3627 (time=72.54), 0.599068 s/step
# on time step 3634 (time=72.68), 0.597565 s/step
# on time step 3641 (time=72.82), 0.593224 s/step
# on time step 3662 (time=73.24), 0.193144 s/step
# on time step 3685 (time=73.7), 0.175294 s/step
# on time step 3708 (time=74.16), 0.174994 s/step
# on time step 3731 (time=74.62), 0.17587 s/step
# on time step 3754 (time=75.08), 0.175625 s/step
# on time step 3777 (time=75.54), 0.175531 s/step
# on time step 3800 (time=76), 0.174269 s/step
# on time step 3823 (time=76.46), 0.176808 s/step
# on time step 3846 (time=76.92), 0.174295 s/step
# on time step 3869 (time=77.38), 0.174052 s/step
# on time step 3893 (time=77.86), 0.175323 s/step
# on time step 3905 (time=78.1), 0.372361 s/step
# on time step 3913 (time=78.26), 0.513717 s/step
# on time step 3921 (time=78.42), 0.511514 s/step
# on time step 3929 (time=78.58), 0.514603 s/step
# on time step 3937 (time=78.74), 0.515756 s/step
# on time step 3946 (time=78.92), 0.475455 s/step
# on time step 3955 (time=79.1), 0.500271 s/step
# on time step 3963 (time=79.26), 0.504881 s/step
# on time step 3971 (time=79.42), 0.506438 s/step
# on time step 3979 (time=79.58), 0.51197 s/step
# on time step 3987 (time=79.74), 0.511243 s/step
# on time step 3995 (time=79.9), 0.510057 s/step
# on time step 4003 (time=80.06), 0.510506 s/step
# field decay(t = 80.14): 0.0009437916737132601 / 0.15015950768369926 = 0.006285260842099275
# on time step 4012 (time=80.24), 0.497928 s/step
# on time step 4021 (time=80.42), 0.498769 s/step
# on time step 4030 (time=80.6), 0.496744 s/step
# on time step 4038 (time=80.76), 0.500396 s/step
# on time step 4047 (time=80.94), 0.4972 s/step
# on time step 4055 (time=81.1), 0.559068 s/step
# on time step 4062 (time=81.24), 0.602131 s/step
# on time step 4069 (time=81.38), 0.600871 s/step
# on time step 4076 (time=81.52), 0.600092 s/step
# on time step 4083 (time=81.66), 0.599638 s/step
# on time step 4090 (time=81.8), 0.600306 s/step
# on time step 4097 (time=81.94), 0.597982 s/step
# on time step 4104 (time=82.08), 0.597035 s/step
# on time step 4111 (time=82.22), 0.599801 s/step
# on time step 4118 (time=82.36), 0.603958 s/step
# on time step 4125 (time=82.5), 0.599931 s/step
# on time step 4138 (time=82.76), 0.313679 s/step
# on time step 4161 (time=83.22), 0.176962 s/step
# on time step 4184 (time=83.68), 0.175649 s/step
# on time step 4207 (time=84.14), 0.175548 s/step
# on time step 4230 (time=84.6), 0.17589 s/step
# on time step 4253 (time=85.06), 0.175028 s/step
# on time step 4276 (time=85.52), 0.175439 s/step
# on time step 4299 (time=85.98), 0.176319 s/step
# on time step 4322 (time=86.44), 0.177998 s/step
# on time step 4345 (time=86.9), 0.174423 s/step
# on time step 4368 (time=87.36), 0.175863 s/step
# on time step 4387 (time=87.74), 0.234727 s/step
# on time step 4395 (time=87.9), 0.510088 s/step
# on time step 4403 (time=88.06), 0.510039 s/step
# on time step 4411 (time=88.22), 0.514119 s/step
# on time step 4419 (time=88.38), 0.51178 s/step
# on time step 4428 (time=88.56), 0.477216 s/step
# on time step 4436 (time=88.72), 0.502649 s/step
# on time step 4444 (time=88.88), 0.503223 s/step
# on time step 4452 (time=89.04), 0.507799 s/step
# on time step 4460 (time=89.2), 0.509318 s/step
# on time step 4468 (time=89.36), 0.508934 s/step
# on time step 4476 (time=89.52), 0.509158 s/step
# on time step 4484 (time=89.68), 0.507835 s/step
# on time step 4493 (time=89.86), 0.496141 s/step
# on time step 4502 (time=90.04), 0.492377 s/step
# field decay(t = 90.16): 0.0008498123502247455 / 0.15015950768369926 = 0.005659397552200405
# on time step 4511 (time=90.22), 0.496307 s/step
# on time step 4520 (time=90.4), 0.495524 s/step
# on time step 4529 (time=90.58), 0.486042 s/step
# on time step 4538 (time=90.76), 0.507999 s/step
# on time step 4545 (time=90.9), 0.598754 s/step
# on time step 4552 (time=91.04), 0.597777 s/step
# on time step 4559 (time=91.18), 0.600776 s/step
# on time step 4566 (time=91.32), 0.597688 s/step
# on time step 4573 (time=91.46), 0.596248 s/step
# on time step 4580 (time=91.6), 0.600759 s/step
# on time step 4587 (time=91.74), 0.601504 s/step
# on time step 4594 (time=91.88), 0.594867 s/step
# on time step 4601 (time=92.02), 0.597093 s/step
# on time step 4608 (time=92.16), 0.593793 s/step
# on time step 4615 (time=92.3), 0.598223 s/step
# on time step 4635 (time=92.7), 0.204385 s/step
# on time step 4658 (time=93.16), 0.178528 s/step
# on time step 4681 (time=93.62), 0.175927 s/step
# on time step 4704 (time=94.08), 0.176445 s/step
# on time step 4727 (time=94.54), 0.175724 s/step
# on time step 4750 (time=95), 0.176201 s/step
# on time step 4773 (time=95.46), 0.179041 s/step
# on time step 4796 (time=95.92), 0.179543 s/step
# on time step 4819 (time=96.38), 0.179321 s/step
# on time step 4842 (time=96.84), 0.17594 s/step
# on time step 4865 (time=97.3), 0.177806 s/step
# on time step 4877 (time=97.54), 0.358731 s/step
# on time step 4885 (time=97.7), 0.509296 s/step
# on time step 4893 (time=97.86), 0.510406 s/step
# on time step 4901 (time=98.02), 0.513114 s/step
# on time step 4909 (time=98.18), 0.511299 s/step
# on time step 4918 (time=98.36), 0.48521 s/step
# on time step 4927 (time=98.54), 0.499046 s/step
# on time step 4935 (time=98.7), 0.510614 s/step
# on time step 4943 (time=98.86), 0.510099 s/step
# on time step 4951 (time=99.02), 0.509421 s/step
# on time step 4959 (time=99.18), 0.511638 s/step
# on time step 4967 (time=99.34), 0.508509 s/step
# on time step 4975 (time=99.5), 0.500707 s/step
# on time step 4984 (time=99.68), 0.496604 s/step
# on time step 4993 (time=99.86), 0.490786 s/step
# on time step 5002 (time=100.04), 0.491753 s/step
# field decay(t = 100.18): 0.00010643820660552717 / 0.15015950768369926 = 0.000708834280608671
# run 0 finished at t = 100.18 (5009 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000386 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 7.89074 s
# -----------
# on time step 1 (time=0.02), 8.68145 s/step
# on time step 9 (time=0.18), 0.502391 s/step
# on time step 17 (time=0.34), 0.501499 s/step
# on time step 25 (time=0.5), 0.544214 s/step
# on time step 34 (time=0.68), 0.499601 s/step
# on time step 42 (time=0.84), 0.537621 s/step
# on time step 50 (time=1), 0.502966 s/step
# on time step 58 (time=1.16), 0.536368 s/step
# on time step 67 (time=1.34), 0.496248 s/step
# on time step 90 (time=1.8), 0.183308 s/step
# on time step 115 (time=2.3), 0.161455 s/step
# on time step 140 (time=2.8), 0.160135 s/step
# on time step 165 (time=3.3), 0.162232 s/step
# on time step 190 (time=3.8), 0.160887 s/step
# on time step 215 (time=4.3), 0.161552 s/step
# on time step 240 (time=4.8), 0.165604 s/step
# on time step 265 (time=5.3), 0.161377 s/step
# on time step 290 (time=5.8), 0.165594 s/step
# on time step 316 (time=6.32), 0.15845 s/step
# on time step 341 (time=6.82), 0.160074 s/step
# on time step 353 (time=7.06), 0.345647 s/step
# on time step 362 (time=7.24), 0.462275 s/step
# on time step 372 (time=7.44), 0.429989 s/step
# on time step 381 (time=7.62), 0.461095 s/step
# on time step 391 (time=7.82), 0.433289 s/step
# on time step 401 (time=8.02), 0.428545 s/step
# on time step 411 (time=8.22), 0.427184 s/step
# on time step 420 (time=8.4), 0.462088 s/step
# on time step 430 (time=8.6), 0.429386 s/step
# on time step 439 (time=8.78), 0.465269 s/step
# on time step 449 (time=8.98), 0.440258 s/step
# on time step 458 (time=9.16), 0.471677 s/step
# on time step 468 (time=9.36), 0.459842 s/step
# on time step 478 (time=9.56), 0.43246 s/step
# on time step 487 (time=9.74), 0.459569 s/step
# on time step 497 (time=9.94), 0.427938 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 506 (time=10.12), 0.458513 s/step
# on time step 516 (time=10.32), 0.426758 s/step
# on time step 524 (time=10.48), 0.520218 s/step
# on time step 532 (time=10.64), 0.507383 s/step
# on time step 540 (time=10.8), 0.555277 s/step
# on time step 548 (time=10.96), 0.505438 s/step
# on time step 556 (time=11.12), 0.504461 s/step
# on time step 564 (time=11.28), 0.54539 s/step
# on time step 573 (time=11.46), 0.498882 s/step
# on time step 581 (time=11.62), 0.541961 s/step
# on time step 589 (time=11.78), 0.502497 s/step
# on time step 597 (time=11.94), 0.540451 s/step
# on time step 606 (time=12.12), 0.499864 s/step
# on time step 623 (time=12.46), 0.239174 s/step
# on time step 648 (time=12.96), 0.162189 s/step
# on time step 674 (time=13.48), 0.157797 s/step
# on time step 700 (time=14), 0.158152 s/step
# on time step 725 (time=14.5), 0.162592 s/step
# on time step 751 (time=15.02), 0.159629 s/step
# on time step 776 (time=15.52), 0.163841 s/step
# on time step 802 (time=16.04), 0.15981 s/step
# on time step 828 (time=16.56), 0.16207 s/step
# on time step 854 (time=17.08), 0.159755 s/step
# on time step 880 (time=17.6), 0.158224 s/step
# on time step 894 (time=17.88), 0.291137 s/step
# on time step 903 (time=18.06), 0.466404 s/step
# on time step 913 (time=18.26), 0.436076 s/step
# on time step 922 (time=18.44), 0.469167 s/step
# on time step 932 (time=18.64), 0.438435 s/step
# on time step 942 (time=18.84), 0.439601 s/step
# on time step 952 (time=19.04), 0.419151 s/step
# on time step 961 (time=19.22), 0.460258 s/step
# on time step 971 (time=19.42), 0.427844 s/step
# on time step 980 (time=19.6), 0.466206 s/step
# on time step 990 (time=19.8), 0.459946 s/step
# on time step 1000 (time=20), 0.432884 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1009 (time=20.18), 0.459838 s/step
# on time step 1019 (time=20.38), 0.422546 s/step
# on time step 1028 (time=20.56), 0.448761 s/step
# on time step 1038 (time=20.76), 0.425696 s/step
# on time step 1047 (time=20.94), 0.452665 s/step
# on time step 1057 (time=21.14), 0.413247 s/step
# on time step 1066 (time=21.32), 0.491153 s/step
# on time step 1074 (time=21.48), 0.504441 s/step
# on time step 1082 (time=21.64), 0.545323 s/step
# on time step 1090 (time=21.8), 0.502175 s/step
# on time step 1098 (time=21.96), 0.546157 s/step
# on time step 1106 (time=22.12), 0.502804 s/step
# on time step 1114 (time=22.28), 0.502187 s/step
# on time step 1122 (time=22.44), 0.543235 s/step
# on time step 1130 (time=22.6), 0.504028 s/step
# on time step 1138 (time=22.76), 0.550965 s/step
# on time step 1146 (time=22.92), 0.50941 s/step
# on time step 1155 (time=23.1), 0.4486 s/step
# on time step 1180 (time=23.6), 0.160611 s/step
# on time step 1205 (time=24.1), 0.160904 s/step
# on time step 1230 (time=24.6), 0.163794 s/step
# on time step 1255 (time=25.1), 0.161526 s/step
# on time step 1280 (time=25.6), 0.166173 s/step
# on time step 1306 (time=26.12), 0.15835 s/step
# on time step 1331 (time=26.62), 0.162003 s/step
# on time step 1355 (time=27.1), 0.167511 s/step
# on time step 1380 (time=27.6), 0.162709 s/step
# on time step 1405 (time=28.1), 0.164048 s/step
# on time step 1428 (time=28.56), 0.185528 s/step
# on time step 1438 (time=28.76), 0.4375 s/step
# on time step 1447 (time=28.94), 0.471002 s/step
# on time step 1457 (time=29.14), 0.438299 s/step
# on time step 1466 (time=29.32), 0.466692 s/step
# on time step 1476 (time=29.52), 0.437896 s/step
# on time step 1486 (time=29.72), 0.435418 s/step
# on time step 1495 (time=29.9), 0.452296 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000663996 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 63.4305% done, 2.30668 s remaining
# subpixel-averaging is 62.5749% done, 2.39286 s remaining
# subpixel-averaging is 64.4942% done, 2.2023 s remaining
# time for set_epsilon = 32.8503 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 8.76403 s/step
# on time step 8 (time=0.16), 0.591333 s/step
# on time step 15 (time=0.3), 0.595041 s/step
# on time step 22 (time=0.44), 0.648669 s/step
# on time step 29 (time=0.58), 0.596419 s/step
# on time step 36 (time=0.72), 0.653029 s/step
# on time step 43 (time=0.86), 0.592832 s/step
# on time step 50 (time=1), 0.592348 s/step
# on time step 57 (time=1.14), 0.652722 s/step
# on time step 64 (time=1.28), 0.599161 s/step
# on time step 82 (time=1.64), 0.227193 s/step
# on time step 104 (time=2.08), 0.182378 s/step
# on time step 126 (time=2.52), 0.189562 s/step
# on time step 149 (time=2.98), 0.18035 s/step
# on time step 172 (time=3.44), 0.181151 s/step
# on time step 194 (time=3.88), 0.181985 s/step
# on time step 216 (time=4.32), 0.186849 s/step
# on time step 239 (time=4.78), 0.181022 s/step
# on time step 262 (time=5.24), 0.180496 s/step
# on time step 284 (time=5.68), 0.183676 s/step
# on time step 306 (time=6.12), 0.18991 s/step
# on time step 317 (time=6.34), 0.387378 s/step
# on time step 325 (time=6.5), 0.551953 s/step
# on time step 333 (time=6.66), 0.506793 s/step
# on time step 341 (time=6.82), 0.508321 s/step
# on time step 349 (time=6.98), 0.538651 s/step
# on time step 358 (time=7.16), 0.494354 s/step
# on time step 366 (time=7.32), 0.548329 s/step
# on time step 374 (time=7.48), 0.509818 s/step
# on time step 382 (time=7.64), 0.554654 s/step
# on time step 390 (time=7.8), 0.51387 s/step
# on time step 398 (time=7.96), 0.559379 s/step
# on time step 406 (time=8.12), 0.511451 s/step
# on time step 414 (time=8.28), 0.553215 s/step
# on time step 422 (time=8.44), 0.501498 s/step
# on time step 431 (time=8.62), 0.495437 s/step
# on time step 439 (time=8.78), 0.542793 s/step
# on time step 448 (time=8.96), 0.494841 s/step
# on time step 456 (time=9.12), 0.547601 s/step
# on time step 463 (time=9.26), 0.593821 s/step
# on time step 469 (time=9.38), 0.672714 s/step
# on time step 476 (time=9.52), 0.59955 s/step
# on time step 483 (time=9.66), 0.603097 s/step
# on time step 489 (time=9.78), 0.675507 s/step
# on time step 496 (time=9.92), 0.601386 s/step
# field decay(t = 10.02): 1.8595361844392578e-05 / 1.8595361844392578e-05 = 1.0
# on time step 503 (time=10.06), 0.60396 s/step
# on time step 509 (time=10.18), 0.672402 s/step
# on time step 516 (time=10.32), 0.599337 s/step
# on time step 522 (time=10.44), 0.669454 s/step
# on time step 529 (time=10.58), 0.598728 s/step
# on time step 544 (time=10.88), 0.278056 s/step
# on time step 567 (time=11.34), 0.181056 s/step
# on time step 590 (time=11.8), 0.180109 s/step
# on time step 612 (time=12.24), 0.186946 s/step
# on time step 635 (time=12.7), 0.181256 s/step
# on time step 657 (time=13.14), 0.183451 s/step
# on time step 680 (time=13.6), 0.180016 s/step
# on time step 702 (time=14.04), 0.186502 s/step
# on time step 725 (time=14.5), 0.180041 s/step
# on time step 747 (time=14.94), 0.18208 s/step
# on time step 769 (time=15.38), 0.184647 s/step
# on time step 781 (time=15.62), 0.34867 s/step
# on time step 789 (time=15.78), 0.512811 s/step
# on time step 797 (time=15.94), 0.553612 s/step
# on time step 805 (time=16.1), 0.508095 s/step
# on time step 813 (time=16.26), 0.554029 s/step
# on time step 822 (time=16.44), 0.476979 s/step
# on time step 830 (time=16.6), 0.545357 s/step
# on time step 838 (time=16.76), 0.506261 s/step
# on time step 846 (time=16.92), 0.557404 s/step
# on time step 854 (time=17.08), 0.513784 s/step
# on time step 862 (time=17.24), 0.507653 s/step
# on time step 870 (time=17.4), 0.552191 s/step
# on time step 878 (time=17.56), 0.508041 s/step
# on time step 886 (time=17.72), 0.543198 s/step
# on time step 894 (time=17.88), 0.501404 s/step
# on time step 902 (time=18.04), 0.543787 s/step
# on time step 910 (time=18.2), 0.501701 s/step
# on time step 918 (time=18.36), 0.545629 s/step
# on time step 926 (time=18.52), 0.551277 s/step
# on time step 933 (time=18.66), 0.59737 s/step
# on time step 940 (time=18.8), 0.652318 s/step
# on time step 947 (time=18.94), 0.596671 s/step
# on time step 954 (time=19.08), 0.64892 s/step
# on time step 961 (time=19.22), 0.594052 s/step
# on time step 968 (time=19.36), 0.594962 s/step
# on time step 975 (time=19.5), 0.651155 s/step
# on time step 982 (time=19.64), 0.595206 s/step
# on time step 989 (time=19.78), 0.602028 s/step
# on time step 995 (time=19.9), 0.667923 s/step
# field decay(t = 20.04): 0.012886819693586444 / 0.012886819693586444 = 1.0
# on time step 1008 (time=20.16), 0.314621 s/step
# on time step 1030 (time=20.6), 0.18268 s/step
# on time step 1052 (time=21.04), 0.183252 s/step
# on time step 1075 (time=21.5), 0.18146 s/step
# on time step 1097 (time=21.94), 0.18367 s/step
# on time step 1119 (time=22.38), 0.186678 s/step
# on time step 1142 (time=22.84), 0.180086 s/step
# on time step 1165 (time=23.3), 0.180277 s/step
# on time step 1188 (time=23.76), 0.186157 s/step
# on time step 1210 (time=24.2), 0.183752 s/step
# on time step 1233 (time=24.66), 0.180777 s/step
# on time step 1247 (time=24.94), 0.321339 s/step
# on time step 1255 (time=25.1), 0.509484 s/step
# on time step 1263 (time=25.26), 0.554765 s/step
# on time step 1271 (time=25.42), 0.508764 s/step
# on time step 1279 (time=25.58), 0.558893 s/step
# on time step 1288 (time=25.76), 0.457454 s/step
# on time step 1296 (time=25.92), 0.543518 s/step
# on time step 1304 (time=26.08), 0.500479 s/step
# on time step 1312 (time=26.24), 0.500347 s/step
# on time step 1320 (time=26.4), 0.548647 s/step
# on time step 1328 (time=26.56), 0.5078 s/step
# on time step 1336 (time=26.72), 0.555682 s/step
# on time step 1344 (time=26.88), 0.510064 s/step
# on time step 1352 (time=27.04), 0.548135 s/step
# on time step 1360 (time=27.2), 0.500353 s/step
# on time step 1368 (time=27.36), 0.545625 s/step
# on time step 1377 (time=27.54), 0.497498 s/step
# on time step 1386 (time=27.72), 0.540336 s/step
# on time step 1394 (time=27.88), 0.560575 s/step
# on time step 1401 (time=28.02), 0.597298 s/step
# on time step 1407 (time=28.14), 0.669447 s/step
# on time step 1414 (time=28.28), 0.59816 s/step
# on time step 1421 (time=28.42), 0.600608 s/step
# on time step 1428 (time=28.56), 0.653365 s/step
# on time step 1435 (time=28.7), 0.592294 s/step
# on time step 1441 (time=28.82), 0.668362 s/step
# on time step 1448 (time=28.96), 0.60205 s/step
# on time step 1455 (time=29.1), 0.598762 s/step
# on time step 1462 (time=29.24), 0.654116 s/step
# on time step 1477 (time=29.54), 0.273839 s/step
# on time step 1499 (time=29.98), 0.183018 s/step
# field decay(t = 30.060000000000002): 0.01555310049408076 / 0.01555310049408076 = 1.0
# on time step 1521 (time=30.42), 0.182239 s/step
# on time step 1543 (time=30.86), 0.183675 s/step
# on time step 1565 (time=31.3), 0.181851 s/step
# on time step 1586 (time=31.72), 0.190752 s/step
# on time step 1609 (time=32.18), 0.18136 s/step
# on time step 1631 (time=32.62), 0.182578 s/step
# on time step 1653 (time=33.06), 0.186033 s/step
# on time step 1675 (time=33.5), 0.187472 s/step
# on time step 1697 (time=33.94), 0.182737 s/step
# on time step 1712 (time=34.24), 0.267453 s/step
# on time step 1720 (time=34.4), 0.508487 s/step
# on time step 1728 (time=34.56), 0.557625 s/step
# on time step 1736 (time=34.72), 0.507626 s/step
# on time step 1744 (time=34.88), 0.508456 s/step
# on time step 1752 (time=35.04), 0.513354 s/step
# on time step 1761 (time=35.22), 0.498842 s/step
# on time step 1769 (time=35.38), 0.546678 s/step
# on time step 1778 (time=35.56), 0.499343 s/step
# on time step 1786 (time=35.72), 0.549253 s/step
# on time step 1795 (time=35.9), 0.496415 s/step
# on time step 1803 (time=36.06), 0.553418 s/step
# on time step 1811 (time=36.22), 0.50949 s/step
# on time step 1819 (time=36.38), 0.546147 s/step
# on time step 1827 (time=36.54), 0.500267 s/step
# on time step 1836 (time=36.72), 0.538899 s/step
# on time step 1844 (time=36.88), 0.502857 s/step
# on time step 1853 (time=37.06), 0.499945 s/step
# on time step 1860 (time=37.2), 0.613996 s/step
# on time step 1867 (time=37.34), 0.601043 s/step
# on time step 1873 (time=37.46), 0.671572 s/step
# on time step 1880 (time=37.6), 0.601667 s/step
# on time step 1887 (time=37.74), 0.600101 s/step
# on time step 1893 (time=37.86), 0.673053 s/step
# on time step 1900 (time=38), 0.603394 s/step
# on time step 1907 (time=38.14), 0.600518 s/step
# on time step 1913 (time=38.26), 0.669379 s/step
# on time step 1920 (time=38.4), 0.598025 s/step
# on time step 1926 (time=38.52), 0.668283 s/step
# on time step 1935 (time=38.7), 0.457698 s/step
# on time step 1957 (time=39.14), 0.185113 s/step
# on time step 1979 (time=39.58), 0.184796 s/step
# on time step 2001 (time=40.02), 0.1872 s/step
# field decay(t = 40.06): 0.0031163203486054163 / 0.01555310049408076 = 0.20036650247270207
# on time step 2024 (time=40.48), 0.181078 s/step
# on time step 2047 (time=40.94), 0.181251 s/step
# on time step 2070 (time=41.4), 0.187081 s/step
# on time step 2093 (time=41.86), 0.180938 s/step
# on time step 2115 (time=42.3), 0.183588 s/step
# on time step 2137 (time=42.74), 0.182425 s/step
# on time step 2159 (time=43.18), 0.181929 s/step
# on time step 2180 (time=43.6), 0.203316 s/step
# on time step 2188 (time=43.76), 0.508479 s/step
# on time step 2196 (time=43.92), 0.559046 s/step
# on time step 2204 (time=44.08), 0.512995 s/step
# on time step 2212 (time=44.24), 0.511926 s/step
# on time step 2220 (time=44.4), 0.512735 s/step
# on time step 2228 (time=44.56), 0.5134 s/step
# on time step 2236 (time=44.72), 0.545669 s/step
# on time step 2244 (time=44.88), 0.505701 s/step
# on time step 2252 (time=45.04), 0.55261 s/step
# on time step 2260 (time=45.2), 0.508925 s/step
# on time step 2268 (time=45.36), 0.554306 s/step
# on time step 2276 (time=45.52), 0.506738 s/step
# on time step 2285 (time=45.7), 0.494792 s/step
# on time step 2293 (time=45.86), 0.545976 s/step
# on time step 2301 (time=46.02), 0.500873 s/step
# on time step 2309 (time=46.18), 0.543176 s/step
# on time step 2318 (time=46.36), 0.494208 s/step
# on time step 2326 (time=46.52), 0.545489 s/step
# on time step 2333 (time=46.66), 0.596845 s/step
# on time step 2340 (time=46.8), 0.660341 s/step
# on time step 2347 (time=46.94), 0.598296 s/step
# on time step 2354 (time=47.08), 0.59872 s/step
# on time step 2360 (time=47.2), 0.670773 s/step
# on time step 2367 (time=47.34), 0.603417 s/step
# on time step 2374 (time=47.48), 0.595464 s/step
# on time step 2380 (time=47.6), 0.672755 s/step
# on time step 2387 (time=47.74), 0.600895 s/step
# on time step 2394 (time=47.88), 0.659938 s/step
# on time step 2401 (time=48.02), 0.602858 s/step
# on time step 2420 (time=48.4), 0.211144 s/step
# on time step 2442 (time=48.84), 0.185758 s/step
# on time step 2464 (time=49.28), 0.182342 s/step
# on time step 2486 (time=49.72), 0.188503 s/step
# field decay(t = 50.08): 0.0016100830993123162 / 0.01555310049408076 = 0.10352168044725783
# on time step 2508 (time=50.16), 0.182564 s/step
# on time step 2530 (time=50.6), 0.182431 s/step
# on time step 2552 (time=51.04), 0.182529 s/step
# on time step 2574 (time=51.48), 0.188429 s/step
# on time step 2596 (time=51.92), 0.1823 s/step
# on time step 2618 (time=52.36), 0.182564 s/step
# on time step 2640 (time=52.8), 0.185465 s/step
# on time step 2653 (time=53.06), 0.320863 s/step
# on time step 2661 (time=53.22), 0.514015 s/step
# on time step 2669 (time=53.38), 0.558985 s/step
# on time step 2677 (time=53.54), 0.514776 s/step
# on time step 2685 (time=53.7), 0.560828 s/step
# on time step 2694 (time=53.88), 0.478379 s/step
# on time step 2702 (time=54.04), 0.541282 s/step
# on time step 2711 (time=54.22), 0.499238 s/step
# on time step 2719 (time=54.38), 0.547735 s/step
# on time step 2727 (time=54.54), 0.504516 s/step
# on time step 2735 (time=54.7), 0.513014 s/step
# on time step 2743 (time=54.86), 0.556956 s/step
# on time step 2752 (time=55.04), 0.499122 s/step
# on time step 2760 (time=55.2), 0.536412 s/step
# on time step 2769 (time=55.38), 0.497452 s/step
# on time step 2777 (time=55.54), 0.526261 s/step
# on time step 2786 (time=55.72), 0.495843 s/step
# on time step 2794 (time=55.88), 0.542825 s/step
# on time step 2801 (time=56.02), 0.577991 s/step
# on time step 2808 (time=56.16), 0.655039 s/step
# on time step 2815 (time=56.3), 0.595371 s/step
# on time step 2822 (time=56.44), 0.597017 s/step
# on time step 2828 (time=56.56), 0.670609 s/step
# on time step 2835 (time=56.7), 0.601401 s/step
# on time step 2842 (time=56.84), 0.603042 s/step
# on time step 2848 (time=56.96), 0.66784 s/step
# on time step 2855 (time=57.1), 0.600371 s/step
# on time step 2862 (time=57.24), 0.653794 s/step
# on time step 2869 (time=57.38), 0.593361 s/step
# on time step 2884 (time=57.68), 0.27144 s/step
# on time step 2906 (time=58.12), 0.183838 s/step
# on time step 2928 (time=58.56), 0.18254 s/step
# on time step 2950 (time=59), 0.183079 s/step
# on time step 2972 (time=59.44), 0.187503 s/step
# on time step 2994 (time=59.88), 0.182163 s/step
# field decay(t = 60.1): 0.0006033794588629723 / 0.01555310049408076 = 0.03879480230276967
# on time step 3016 (time=60.32), 0.184078 s/step
# on time step 3038 (time=60.76), 0.181999 s/step
# on time step 3060 (time=61.2), 0.188095 s/step
# on time step 3082 (time=61.64), 0.183117 s/step
# on time step 3104 (time=62.08), 0.182029 s/step
# on time step 3123 (time=62.46), 0.22597 s/step
# on time step 3131 (time=62.62), 0.509401 s/step
# on time step 3139 (time=62.78), 0.554107 s/step
# on time step 3147 (time=62.94), 0.506659 s/step
# on time step 3155 (time=63.1), 0.553224 s/step
# on time step 3164 (time=63.28), 0.468133 s/step
# on time step 3172 (time=63.44), 0.546784 s/step
# on time step 3181 (time=63.62), 0.499661 s/step
# on time step 3189 (time=63.78), 0.548318 s/step
# on time step 3197 (time=63.94), 0.50584 s/step
# on time step 3205 (time=64.1), 0.559141 s/step
# on time step 3213 (time=64.26), 0.514551 s/step
# on time step 3221 (time=64.42), 0.514463 s/step
# on time step 3229 (time=64.58), 0.545276 s/step
# on time step 3237 (time=64.74), 0.501341 s/step
# on time step 3245 (time=64.9), 0.547976 s/step
# on time step 3254 (time=65.08), 0.497393 s/step
# on time step 3262 (time=65.24), 0.539745 s/step
# on time step 3270 (time=65.4), 0.528115 s/step
# on time step 3276 (time=65.52), 0.670891 s/step
# on time step 3283 (time=65.66), 0.594485 s/step
# on time step 3290 (time=65.8), 0.596689 s/step
# on time step 3296 (time=65.92), 0.675403 s/step
# on time step 3303 (time=66.06), 0.604284 s/step
# on time step 3310 (time=66.2), 0.60015 s/step
# on time step 3316 (time=66.32), 0.674334 s/step
# on time step 3323 (time=66.46), 0.601438 s/step
# on time step 3330 (time=66.6), 0.656229 s/step
# on time step 3337 (time=66.74), 0.596195 s/step
# on time step 3344 (time=66.88), 0.583256 s/step
# on time step 3366 (time=67.32), 0.189977 s/step
# on time step 3388 (time=67.76), 0.182041 s/step
# on time step 3410 (time=68.2), 0.183529 s/step
# on time step 3432 (time=68.64), 0.183714 s/step
# on time step 3454 (time=69.08), 0.184101 s/step
# on time step 3476 (time=69.52), 0.187689 s/step
# on time step 3499 (time=69.98), 0.180164 s/step
# field decay(t = 70.12): 0.0005062793720879204 / 0.01555310049408076 = 0.03255166854226921
# on time step 3521 (time=70.42), 0.182032 s/step
# on time step 3544 (time=70.88), 0.180628 s/step
# on time step 3566 (time=71.32), 0.188824 s/step
# on time step 3588 (time=71.76), 0.18281 s/step
# on time step 3599 (time=71.98), 0.379543 s/step
# on time step 3607 (time=72.14), 0.557762 s/step
# on time step 3615 (time=72.3), 0.517454 s/step
# on time step 3623 (time=72.46), 0.559065 s/step
# on time step 3632 (time=72.64), 0.474311 s/step
# on time step 3640 (time=72.8), 0.552311 s/step
# on time step 3648 (time=72.96), 0.501283 s/step
# on time step 3656 (time=73.12), 0.549491 s/step
# on time step 3664 (time=73.28), 0.500896 s/step
# on time step 3672 (time=73.44), 0.547802 s/step
# on time step 3680 (time=73.6), 0.502667 s/step
# on time step 3688 (time=73.76), 0.510111 s/step
# on time step 3696 (time=73.92), 0.548981 s/step
# on time step 3705 (time=74.1), 0.496235 s/step
# on time step 3713 (time=74.26), 0.525887 s/step
# on time step 3721 (time=74.42), 0.502871 s/step
# on time step 3729 (time=74.58), 0.542584 s/step
# on time step 3738 (time=74.76), 0.494188 s/step
# on time step 3745 (time=74.9), 0.635299 s/step
# on time step 3752 (time=75.04), 0.599165 s/step
# on time step 3759 (time=75.18), 0.603778 s/step
# on time step 3765 (time=75.3), 0.672331 s/step
# on time step 3772 (time=75.44), 0.597296 s/step
# on time step 3779 (time=75.58), 0.597124 s/step
# on time step 3785 (time=75.7), 0.669427 s/step
# on time step 3792 (time=75.84), 0.599265 s/step
# on time step 3798 (time=75.96), 0.676274 s/step
# on time step 3805 (time=76.1), 0.598858 s/step
# on time step 3812 (time=76.24), 0.596863 s/step
# on time step 3825 (time=76.5), 0.315557 s/step
# on time step 3847 (time=76.94), 0.182339 s/step
# on time step 3869 (time=77.38), 0.182303 s/step
# on time step 3891 (time=77.82), 0.1881 s/step
# on time step 3913 (time=78.26), 0.182887 s/step
# on time step 3936 (time=78.72), 0.180952 s/step
# on time step 3958 (time=79.16), 0.185109 s/step
# on time step 3980 (time=79.6), 0.188439 s/step
# on time step 4003 (time=80.06), 0.180533 s/step
# field decay(t = 80.14): 0.00017300396844874435 / 0.01555310049408076 = 0.011123439247022589
# on time step 4026 (time=80.52), 0.181282 s/step
# on time step 4049 (time=80.98), 0.180151 s/step
# on time step 4067 (time=81.34), 0.233771 s/step
# on time step 4075 (time=81.5), 0.553192 s/step
# on time step 4083 (time=81.66), 0.510809 s/step
# on time step 4091 (time=81.82), 0.557049 s/step
# on time step 4099 (time=81.98), 0.510084 s/step
# on time step 4107 (time=82.14), 0.506934 s/step
# on time step 4116 (time=82.32), 0.496801 s/step
# on time step 4124 (time=82.48), 0.546856 s/step
# on time step 4132 (time=82.64), 0.500823 s/step
# on time step 4140 (time=82.8), 0.549015 s/step
# on time step 4148 (time=82.96), 0.510938 s/step
# on time step 4156 (time=83.12), 0.507765 s/step
# on time step 4164 (time=83.28), 0.553999 s/step
# on time step 4173 (time=83.46), 0.492088 s/step
# on time step 4181 (time=83.62), 0.542422 s/step
# on time step 4190 (time=83.8), 0.492942 s/step
# on time step 4198 (time=83.96), 0.541739 s/step
# on time step 4207 (time=84.14), 0.496726 s/step
# on time step 4214 (time=84.28), 0.592477 s/step
# on time step 4221 (time=84.42), 0.599915 s/step
# on time step 4228 (time=84.56), 0.598105 s/step
# on time step 4234 (time=84.68), 0.666902 s/step
# on time step 4241 (time=84.82), 0.593401 s/step
# on time step 4248 (time=84.96), 0.655479 s/step
# on time step 4255 (time=85.1), 0.595957 s/step
# on time step 4262 (time=85.24), 0.596104 s/step
# on time step 4268 (time=85.36), 0.674386 s/step
# on time step 4275 (time=85.5), 0.592922 s/step
# on time step 4282 (time=85.64), 0.596809 s/step
# on time step 4288 (time=85.76), 0.667009 s/step
# on time step 4310 (time=86.2), 0.182493 s/step
# on time step 4332 (time=86.64), 0.182453 s/step
# on time step 4354 (time=87.08), 0.182902 s/step
# on time step 4376 (time=87.52), 0.188625 s/step
# on time step 4398 (time=87.96), 0.182341 s/step
# on time step 4420 (time=88.4), 0.182668 s/step
# on time step 4442 (time=88.84), 0.18249 s/step
# on time step 4464 (time=89.28), 0.188719 s/step
# on time step 4486 (time=89.72), 0.183052 s/step
# field decay(t = 90.16): 0.00017629499177618238 / 0.01555310049408076 = 0.011335038428079161
# on time step 4508 (time=90.16), 0.182287 s/step
# on time step 4530 (time=90.6), 0.184392 s/step
# on time step 4540 (time=90.8), 0.404599 s/step
# on time step 4548 (time=90.96), 0.512577 s/step
# on time step 4556 (time=91.12), 0.55777 s/step
# on time step 4564 (time=91.28), 0.513882 s/step
# on time step 4572 (time=91.44), 0.548168 s/step
# on time step 4581 (time=91.62), 0.484962 s/step
# on time step 4590 (time=91.8), 0.541704 s/step
# on time step 4598 (time=91.96), 0.504721 s/step
# on time step 4606 (time=92.12), 0.501213 s/step
# on time step 4614 (time=92.28), 0.552076 s/step
# on time step 4622 (time=92.44), 0.511586 s/step
# on time step 4630 (time=92.6), 0.559058 s/step
# on time step 4638 (time=92.76), 0.508282 s/step
# on time step 4646 (time=92.92), 0.547938 s/step
# on time step 4655 (time=93.1), 0.49908 s/step
# on time step 4663 (time=93.26), 0.547845 s/step
# on time step 4671 (time=93.42), 0.501509 s/step
# on time step 4679 (time=93.58), 0.502364 s/step
# on time step 4686 (time=93.72), 0.641647 s/step
# on time step 4693 (time=93.86), 0.599231 s/step
# on time step 4699 (time=93.98), 0.669148 s/step
# on time step 4706 (time=94.12), 0.598847 s/step
# on time step 4713 (time=94.26), 0.598623 s/step
# on time step 4719 (time=94.38), 0.667654 s/step
# on time step 4726 (time=94.52), 0.602915 s/step
# on time step 4733 (time=94.66), 0.600835 s/step
# on time step 4739 (time=94.78), 0.673509 s/step
# on time step 4746 (time=94.92), 0.603558 s/step
# on time step 4752 (time=95.04), 0.673703 s/step
# on time step 4766 (time=95.32), 0.288255 s/step
# on time step 4788 (time=95.76), 0.190088 s/step
# on time step 4810 (time=96.2), 0.185744 s/step
# on time step 4832 (time=96.64), 0.185874 s/step
# on time step 4854 (time=97.08), 0.1847 s/step
# on time step 4876 (time=97.52), 0.184377 s/step
# on time step 4898 (time=97.96), 0.187643 s/step
# on time step 4921 (time=98.42), 0.18096 s/step
# on time step 4944 (time=98.88), 0.181134 s/step
# on time step 4966 (time=99.32), 0.184919 s/step
# on time step 4987 (time=99.74), 0.190681 s/step
# on time step 5002 (time=100.04), 0.269494 s/step
# field decay(t = 100.18): 3.726504486058042e-05 / 0.01555310049408076 = 0.0023959881744969663
# on time step 5010 (time=100.2), 0.555782 s/step
# on time step 5018 (time=100.36), 0.514676 s/step
# on time step 5026 (time=100.52), 0.550991 s/step
# on time step 5034 (time=100.68), 0.506254 s/step
# on time step 5042 (time=100.84), 0.510929 s/step
# on time step 5051 (time=101.02), 0.496974 s/step
# on time step 5059 (time=101.18), 0.543283 s/step
# on time step 5067 (time=101.34), 0.503184 s/step
# on time step 5075 (time=101.5), 0.50375 s/step
# on time step 5083 (time=101.66), 0.552192 s/step
# on time step 5092 (time=101.84), 0.498428 s/step
# on time step 5100 (time=102), 0.546805 s/step
# on time step 5109 (time=102.18), 0.490304 s/step
# on time step 5117 (time=102.34), 0.528912 s/step
# on time step 5126 (time=102.52), 0.496053 s/step
# on time step 5134 (time=102.68), 0.540305 s/step
# on time step 5143 (time=102.86), 0.495266 s/step
# on time step 5150 (time=103), 0.603551 s/step
# on time step 5157 (time=103.14), 0.597015 s/step
# on time step 5164 (time=103.28), 0.59532 s/step
# on time step 5170 (time=103.4), 0.669773 s/step
# on time step 5177 (time=103.54), 0.598693 s/step
# on time step 5184 (time=103.68), 0.658404 s/step
# on time step 5191 (time=103.82), 0.595541 s/step
# on time step 5198 (time=103.96), 0.594737 s/step
# on time step 5205 (time=104.1), 0.653633 s/step
# on time step 5212 (time=104.24), 0.594752 s/step
# on time step 5219 (time=104.38), 0.596194 s/step
# on time step 5231 (time=104.62), 0.335212 s/step
# on time step 5254 (time=105.08), 0.181005 s/step
# on time step 5276 (time=105.52), 0.18815 s/step
# on time step 5299 (time=105.98), 0.180874 s/step
# on time step 5321 (time=106.42), 0.184554 s/step
# on time step 5344 (time=106.88), 0.181017 s/step
# on time step 5366 (time=107.32), 0.188569 s/step
# on time step 5388 (time=107.76), 0.182292 s/step
# on time step 5411 (time=108.22), 0.180053 s/step
# on time step 5433 (time=108.66), 0.182954 s/step
# on time step 5455 (time=109.1), 0.189462 s/step
# on time step 5472 (time=109.44), 0.273358 s/step
# on time step 5480 (time=109.6), 0.515894 s/step
# on time step 5488 (time=109.76), 0.513927 s/step
# on time step 5496 (time=109.92), 0.560906 s/step
# on time step 5505 (time=110.1), 0.477189 s/step
# field decay(t = 110.2): 8.434267671189324e-06 / 0.01555310049408076 = 0.000542288508609538
# run 0 finished at t = 110.2 (5510 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])
if mp.am_master():
    plt.figure(dpi=300)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical efficiency (in-pixel)")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
print(np.mean(Tr[0:66]))
print(np.mean(Tg[66:160]))
print(np.mean(Tb[160:300]))
print(max(Tr[0:66]))
print(max(Tg[66:160]))
print(max(Tb[160:300]))
print(max((Tr - Tg)[0:66]))
print(max((Tg - Tr)[66:160]))
print(max((Tb - Tr)[160:300]))
print(np.mean(Tr[66:300]))
print((sum(Tg[0:66]) + sum(Tg[160:300]))/206)
print(np.mean(Tb[0:160]))
# Out:
# 0.5454783756047338
# 0.2933041529522359
# 0.3708739192138925
# 0.7329657025880767
# 0.3951855052518417
# 0.5934104776462858
# 0.6997572602403821
# 0.3574767583930352
# 0.5275704721595292
# 0.09135059531812943
# 0.08588920848197643
# 0.05999209760392101
