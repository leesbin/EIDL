# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=11.8)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 1 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * (design_region_width_x-air_gap*2))) + 1
Ny = int(round(design_region_resolution * (design_region_width_y-air_gap*2))) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, TiO2, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000993013 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 53.4176% done, 3.4892 s remaining
# subpixel-averaging is 95.851% done, 0.173218 s remaining
# subpixel-averaging is 47.2664% done, 4.46509 s remaining
# subpixel-averaging is 91.6423% done, 0.364993 s remaining
# subpixel-averaging is 44.1215% done, 5.06892 s remaining
# subpixel-averaging is 87.3181% done, 0.581017 s remaining
# time for set_epsilon = 46.5058 s
# -----------
# on time step 1 (time=0.02), 13.1705 s/step
# on time step 7 (time=0.14), 0.706287 s/step
# on time step 13 (time=0.26), 0.695815 s/step
# on time step 19 (time=0.38), 0.704099 s/step
# on time step 26 (time=0.52), 0.645086 s/step
# on time step 32 (time=0.64), 0.673665 s/step
# on time step 39 (time=0.78), 0.678189 s/step
# on time step 45 (time=0.9), 0.722817 s/step
# on time step 52 (time=1.04), 0.646636 s/step
# on time step 59 (time=1.18), 0.617472 s/step
# on time step 66 (time=1.32), 0.660848 s/step
# on time step 72 (time=1.44), 0.769827 s/step
# on time step 78 (time=1.56), 0.803324 s/step
# on time step 84 (time=1.68), 0.780218 s/step
# on time step 90 (time=1.8), 0.73029 s/step
# on time step 96 (time=1.92), 0.770339 s/step
# on time step 102 (time=2.04), 0.789867 s/step
# on time step 107 (time=2.14), 0.92073 s/step
# on time step 113 (time=2.26), 0.762203 s/step
# on time step 120 (time=2.4), 0.644023 s/step
# on time step 126 (time=2.52), 0.784526 s/step
# on time step 132 (time=2.64), 0.731266 s/step
# on time step 138 (time=2.76), 0.774779 s/step
# on time step 144 (time=2.88), 0.773234 s/step
# on time step 150 (time=3), 0.783747 s/step
# on time step 155 (time=3.1), 0.846655 s/step
# on time step 161 (time=3.22), 0.764141 s/step
# on time step 167 (time=3.34), 0.684373 s/step
# on time step 173 (time=3.46), 0.674928 s/step
# on time step 179 (time=3.58), 0.7333 s/step
# on time step 185 (time=3.7), 0.755554 s/step
# on time step 191 (time=3.82), 0.7664 s/step
# on time step 197 (time=3.94), 0.768788 s/step
# on time step 204 (time=4.08), 0.621832 s/step
# on time step 211 (time=4.22), 0.606284 s/step
# on time step 218 (time=4.36), 0.648191 s/step
# on time step 224 (time=4.48), 0.740397 s/step
# on time step 230 (time=4.6), 0.704294 s/step
# on time step 236 (time=4.72), 0.789349 s/step
# on time step 242 (time=4.84), 0.714632 s/step
# on time step 248 (time=4.96), 0.733137 s/step
# on time step 254 (time=5.08), 0.743981 s/step
# on time step 260 (time=5.2), 0.770309 s/step
# on time step 266 (time=5.32), 0.784886 s/step
# on time step 272 (time=5.44), 0.755969 s/step
# on time step 278 (time=5.56), 0.796976 s/step
# on time step 284 (time=5.68), 0.783327 s/step
# on time step 291 (time=5.82), 0.654309 s/step
# on time step 298 (time=5.96), 0.649975 s/step
# on time step 303 (time=6.06), 0.852835 s/step
# on time step 309 (time=6.18), 0.723146 s/step
# on time step 316 (time=6.32), 0.66561 s/step
# on time step 323 (time=6.46), 0.630716 s/step
# on time step 329 (time=6.58), 0.744398 s/step
# on time step 334 (time=6.68), 0.802732 s/step
# on time step 341 (time=6.82), 0.640226 s/step
# on time step 347 (time=6.94), 0.715602 s/step
# on time step 352 (time=7.04), 0.90398 s/step
# on time step 357 (time=7.14), 0.92811 s/step
# on time step 362 (time=7.24), 0.821507 s/step
# on time step 367 (time=7.34), 0.879393 s/step
# on time step 372 (time=7.44), 0.896038 s/step
# on time step 377 (time=7.54), 0.939217 s/step
# on time step 382 (time=7.64), 0.905745 s/step
# on time step 387 (time=7.74), 0.909288 s/step
# on time step 392 (time=7.84), 0.910472 s/step
# on time step 397 (time=7.94), 0.903065 s/step
# on time step 402 (time=8.04), 0.913626 s/step
# on time step 407 (time=8.14), 0.957693 s/step
# on time step 412 (time=8.24), 0.859109 s/step
# on time step 418 (time=8.36), 0.799665 s/step
# on time step 423 (time=8.46), 0.810095 s/step
# on time step 429 (time=8.58), 0.75753 s/step
# on time step 436 (time=8.72), 0.664659 s/step
# on time step 443 (time=8.86), 0.612113 s/step
# on time step 450 (time=9), 0.606052 s/step
# on time step 455 (time=9.1), 0.920817 s/step
# on time step 460 (time=9.2), 0.892417 s/step
# on time step 464 (time=9.28), 1.31066 s/step
# on time step 467 (time=9.34), 1.50775 s/step
# on time step 471 (time=9.42), 1.21216 s/step
# on time step 474 (time=9.48), 1.52737 s/step
# on time step 478 (time=9.56), 1.30083 s/step
# on time step 482 (time=9.64), 1.11126 s/step
# on time step 486 (time=9.72), 1.22618 s/step
# on time step 490 (time=9.8), 1.02786 s/step
# on time step 494 (time=9.88), 1.03892 s/step
# on time step 499 (time=9.98), 0.992284 s/step
# field decay(t = 10.02): 2.1430828287917356e-09 / 2.1430828287917356e-09 = 1.0
# on time step 503 (time=10.06), 1.10993 s/step
# on time step 507 (time=10.14), 1.08154 s/step
# on time step 510 (time=10.2), 1.4213 s/step
# on time step 514 (time=10.28), 1.27302 s/step
# on time step 517 (time=10.34), 1.44363 s/step
# on time step 520 (time=10.4), 1.45569 s/step
# on time step 523 (time=10.46), 1.39044 s/step
# on time step 526 (time=10.52), 1.42039 s/step
# on time step 529 (time=10.58), 1.49916 s/step
# on time step 532 (time=10.64), 1.3753 s/step
# on time step 537 (time=10.74), 0.944681 s/step
# on time step 540 (time=10.8), 1.51614 s/step
# on time step 543 (time=10.86), 1.53807 s/step
# on time step 547 (time=10.94), 1.07619 s/step
# on time step 551 (time=11.02), 1.00686 s/step
# on time step 555 (time=11.1), 1.20709 s/step
# on time step 559 (time=11.18), 1.3095 s/step
# on time step 563 (time=11.26), 1.17785 s/step
# on time step 567 (time=11.34), 1.40907 s/step
# on time step 571 (time=11.42), 1.11487 s/step
# on time step 574 (time=11.48), 1.49945 s/step
# on time step 579 (time=11.58), 0.925629 s/step
# on time step 583 (time=11.66), 1.01221 s/step
# on time step 587 (time=11.74), 1.20097 s/step
# on time step 591 (time=11.82), 1.37569 s/step
# on time step 595 (time=11.9), 1.27637 s/step
# on time step 598 (time=11.96), 1.51281 s/step
# on time step 602 (time=12.04), 1.10311 s/step
# on time step 607 (time=12.14), 0.960788 s/step
# on time step 611 (time=12.22), 1.26065 s/step
# on time step 614 (time=12.28), 1.45071 s/step
# on time step 618 (time=12.36), 1.06231 s/step
# on time step 622 (time=12.44), 1.17975 s/step
# on time step 626 (time=12.52), 1.16359 s/step
# on time step 630 (time=12.6), 1.24547 s/step
# on time step 634 (time=12.68), 1.30036 s/step
# on time step 637 (time=12.74), 1.36917 s/step
# on time step 640 (time=12.8), 1.37374 s/step
# on time step 644 (time=12.88), 1.30691 s/step
# on time step 647 (time=12.94), 1.37102 s/step
# on time step 650 (time=13), 1.37751 s/step
# on time step 653 (time=13.06), 1.38579 s/step
# on time step 656 (time=13.12), 1.42354 s/step
# on time step 659 (time=13.18), 1.42495 s/step
# on time step 663 (time=13.26), 1.24717 s/step
# on time step 667 (time=13.34), 1.34711 s/step
# on time step 670 (time=13.4), 1.37379 s/step
# on time step 674 (time=13.48), 1.20354 s/step
# on time step 678 (time=13.56), 1.01066 s/step
# on time step 681 (time=13.62), 1.35821 s/step
# on time step 684 (time=13.68), 1.3643 s/step
# on time step 688 (time=13.76), 1.13228 s/step
# on time step 693 (time=13.86), 0.960904 s/step
# on time step 698 (time=13.96), 0.953987 s/step
# on time step 702 (time=14.04), 1.25013 s/step
# on time step 706 (time=14.12), 1.10235 s/step
# on time step 710 (time=14.2), 1.21019 s/step
# on time step 713 (time=14.26), 1.36624 s/step
# on time step 716 (time=14.32), 1.39727 s/step
# on time step 719 (time=14.38), 1.45627 s/step
# on time step 722 (time=14.44), 1.44411 s/step
# on time step 726 (time=14.52), 1.24181 s/step
# on time step 730 (time=14.6), 1.31042 s/step
# on time step 734 (time=14.68), 1.20092 s/step
# on time step 739 (time=14.78), 0.934811 s/step
# on time step 743 (time=14.86), 1.05562 s/step
# on time step 748 (time=14.96), 0.960636 s/step
# on time step 752 (time=15.04), 1.12204 s/step
# on time step 756 (time=15.12), 1.10659 s/step
# on time step 761 (time=15.22), 1.02745 s/step
# on time step 765 (time=15.3), 1.22223 s/step
# on time step 768 (time=15.36), 1.47524 s/step
# on time step 772 (time=15.44), 1.26179 s/step
# on time step 775 (time=15.5), 1.42381 s/step
# on time step 779 (time=15.58), 1.00333 s/step
# on time step 782 (time=15.64), 1.48083 s/step
# on time step 785 (time=15.7), 1.44794 s/step
# on time step 788 (time=15.76), 1.41432 s/step
# on time step 792 (time=15.84), 1.13362 s/step
# on time step 796 (time=15.92), 1.19835 s/step
# on time step 800 (time=16), 1.1416 s/step
# on time step 804 (time=16.08), 1.17503 s/step
# on time step 808 (time=16.16), 1.18929 s/step
# on time step 811 (time=16.22), 1.34425 s/step
# on time step 814 (time=16.28), 1.38902 s/step
# on time step 817 (time=16.34), 1.49057 s/step
# on time step 821 (time=16.42), 1.22141 s/step
# on time step 824 (time=16.48), 1.46744 s/step
# on time step 827 (time=16.54), 1.43615 s/step
# on time step 830 (time=16.6), 1.43328 s/step
# on time step 833 (time=16.66), 1.38256 s/step
# on time step 836 (time=16.72), 1.37651 s/step
# on time step 840 (time=16.8), 1.34019 s/step
# on time step 843 (time=16.86), 1.47744 s/step
# on time step 846 (time=16.92), 1.47059 s/step
# on time step 850 (time=17), 1.27998 s/step
# on time step 854 (time=17.08), 1.0859 s/step
# on time step 858 (time=17.16), 1.13571 s/step
# on time step 862 (time=17.24), 1.33015 s/step
# on time step 865 (time=17.3), 1.34552 s/step
# on time step 869 (time=17.38), 1.24356 s/step
# on time step 873 (time=17.46), 1.27219 s/step
# on time step 877 (time=17.54), 1.0195 s/step
# on time step 881 (time=17.62), 1.06416 s/step
# on time step 885 (time=17.7), 1.06766 s/step
# on time step 890 (time=17.8), 0.952417 s/step
# on time step 894 (time=17.88), 1.24597 s/step
# on time step 898 (time=17.96), 1.29472 s/step
# on time step 901 (time=18.02), 1.40571 s/step
# on time step 904 (time=18.08), 1.40505 s/step
# on time step 907 (time=18.14), 1.41616 s/step
# on time step 910 (time=18.2), 1.4126 s/step
# on time step 913 (time=18.26), 1.41645 s/step
# on time step 916 (time=18.32), 1.39027 s/step
# on time step 919 (time=18.38), 1.36923 s/step
# on time step 922 (time=18.44), 1.38096 s/step
# on time step 925 (time=18.5), 1.4004 s/step
# on time step 928 (time=18.56), 1.42522 s/step
# on time step 931 (time=18.62), 1.37382 s/step
# on time step 934 (time=18.68), 1.34049 s/step
# on time step 937 (time=18.74), 1.35886 s/step
# on time step 940 (time=18.8), 1.34517 s/step
# on time step 943 (time=18.86), 1.36855 s/step
# on time step 946 (time=18.92), 1.36954 s/step
# on time step 950 (time=19), 1.15208 s/step
# on time step 954 (time=19.08), 1.14556 s/step
# on time step 957 (time=19.14), 1.40883 s/step
# on time step 960 (time=19.2), 1.34269 s/step
# on time step 964 (time=19.28), 1.03598 s/step
# on time step 967 (time=19.34), 1.48797 s/step
# on time step 971 (time=19.42), 1.30561 s/step
# on time step 974 (time=19.48), 1.37762 s/step
# on time step 978 (time=19.56), 1.29952 s/step
# on time step 982 (time=19.64), 1.3486 s/step
# on time step 986 (time=19.72), 1.28971 s/step
# on time step 990 (time=19.8), 1.16144 s/step
# on time step 993 (time=19.86), 1.34547 s/step
# on time step 996 (time=19.92), 1.39908 s/step
# on time step 1000 (time=20), 1.1971 s/step
# field decay(t = 20.04): 2.9676858559592004e-05 / 2.9676858559592004e-05 = 1.0
# on time step 1003 (time=20.06), 1.37702 s/step
# on time step 1007 (time=20.14), 1.18882 s/step
# on time step 1011 (time=20.22), 1.25909 s/step
# on time step 1015 (time=20.3), 1.14203 s/step
# on time step 1019 (time=20.38), 1.08139 s/step
# on time step 1023 (time=20.46), 1.2684 s/step
# on time step 1027 (time=20.54), 1.05353 s/step
# on time step 1032 (time=20.64), 0.984791 s/step
# on time step 1036 (time=20.72), 1.06928 s/step
# on time step 1040 (time=20.8), 1.32369 s/step
# on time step 1043 (time=20.86), 1.41237 s/step
# on time step 1046 (time=20.92), 1.43362 s/step
# on time step 1049 (time=20.98), 1.52349 s/step
# on time step 1053 (time=21.06), 1.24942 s/step
# on time step 1057 (time=21.14), 1.12995 s/step
# on time step 1061 (time=21.22), 1.18875 s/step
# on time step 1065 (time=21.3), 1.11136 s/step
# on time step 1069 (time=21.38), 1.23808 s/step
# on time step 1072 (time=21.44), 1.33767 s/step
# on time step 1076 (time=21.52), 1.33105 s/step
# on time step 1079 (time=21.58), 1.4633 s/step
# on time step 1083 (time=21.66), 1.3151 s/step
# on time step 1087 (time=21.74), 1.19861 s/step
# on time step 1091 (time=21.82), 1.11537 s/step
# on time step 1095 (time=21.9), 1.04458 s/step
# on time step 1099 (time=21.98), 1.30818 s/step
# on time step 1103 (time=22.06), 1.15712 s/step
# on time step 1106 (time=22.12), 1.43475 s/step
# on time step 1109 (time=22.18), 1.47395 s/step
# on time step 1113 (time=22.26), 1.36176 s/step
# on time step 1116 (time=22.32), 1.38534 s/step
# on time step 1120 (time=22.4), 1.25279 s/step
# on time step 1123 (time=22.46), 1.40133 s/step
# on time step 1126 (time=22.52), 1.52499 s/step
# on time step 1129 (time=22.58), 1.49106 s/step
# on time step 1132 (time=22.64), 1.55467 s/step
# on time step 1135 (time=22.7), 1.47057 s/step
# on time step 1139 (time=22.78), 1.24553 s/step
# on time step 1142 (time=22.84), 1.34837 s/step
# on time step 1145 (time=22.9), 1.46091 s/step
# on time step 1148 (time=22.96), 1.42723 s/step
# on time step 1151 (time=23.02), 1.50743 s/step
# on time step 1154 (time=23.08), 1.35126 s/step
# on time step 1158 (time=23.16), 1.18475 s/step
# on time step 1161 (time=23.22), 1.39992 s/step
# on time step 1164 (time=23.28), 1.35102 s/step
# on time step 1167 (time=23.34), 1.4306 s/step
# on time step 1171 (time=23.42), 1.12026 s/step
# on time step 1175 (time=23.5), 1.02329 s/step
# on time step 1180 (time=23.6), 0.98938 s/step
# on time step 1184 (time=23.68), 1.05277 s/step
# on time step 1187 (time=23.74), 1.42352 s/step
# on time step 1191 (time=23.82), 1.23486 s/step
# on time step 1194 (time=23.88), 1.5433 s/step
# on time step 1198 (time=23.96), 1.25526 s/step
# on time step 1201 (time=24.02), 1.44115 s/step
# on time step 1205 (time=24.1), 1.24569 s/step
# on time step 1209 (time=24.18), 1.19575 s/step
# on time step 1213 (time=24.26), 1.29133 s/step
# on time step 1216 (time=24.32), 1.53435 s/step
# on time step 1219 (time=24.38), 1.46675 s/step
# on time step 1223 (time=24.46), 1.24385 s/step
# on time step 1227 (time=24.54), 1.29112 s/step
# on time step 1230 (time=24.6), 1.39979 s/step
# on time step 1233 (time=24.66), 1.38136 s/step
# on time step 1236 (time=24.72), 1.40545 s/step
# on time step 1239 (time=24.78), 1.50339 s/step
# on time step 1243 (time=24.86), 1.2875 s/step
# on time step 1246 (time=24.92), 1.42404 s/step
# on time step 1249 (time=24.98), 1.50625 s/step
# on time step 1252 (time=25.04), 1.4895 s/step
# on time step 1255 (time=25.1), 1.43188 s/step
# on time step 1259 (time=25.18), 1.27023 s/step
# on time step 1262 (time=25.24), 1.45669 s/step
# on time step 1265 (time=25.3), 1.39903 s/step
# on time step 1269 (time=25.38), 1.31031 s/step
# on time step 1272 (time=25.44), 1.37884 s/step
# on time step 1275 (time=25.5), 1.42166 s/step
# on time step 1278 (time=25.56), 1.39982 s/step
# on time step 1281 (time=25.62), 1.43361 s/step
# on time step 1284 (time=25.68), 1.33786 s/step
# on time step 1288 (time=25.76), 1.35475 s/step
# on time step 1291 (time=25.82), 1.4366 s/step
# on time step 1294 (time=25.88), 1.51852 s/step
# on time step 1297 (time=25.94), 1.46657 s/step
# on time step 1300 (time=26), 1.44768 s/step
# on time step 1303 (time=26.06), 1.33535 s/step
# on time step 1307 (time=26.14), 1.04115 s/step
# on time step 1311 (time=26.22), 1.26105 s/step
# on time step 1314 (time=26.28), 1.47031 s/step
# on time step 1317 (time=26.34), 1.43562 s/step
# on time step 1321 (time=26.42), 1.20967 s/step
# on time step 1324 (time=26.48), 1.42677 s/step
# on time step 1328 (time=26.56), 1.31517 s/step
# on time step 1332 (time=26.64), 1.22496 s/step
# on time step 1336 (time=26.72), 1.15209 s/step
# on time step 1340 (time=26.8), 1.23873 s/step
# on time step 1343 (time=26.86), 1.43676 s/step
# on time step 1346 (time=26.92), 1.43895 s/step
# on time step 1349 (time=26.98), 1.42575 s/step
# on time step 1352 (time=27.04), 1.48525 s/step
# on time step 1355 (time=27.1), 1.45652 s/step
# on time step 1359 (time=27.18), 1.1983 s/step
# on time step 1362 (time=27.24), 1.46414 s/step
# on time step 1365 (time=27.3), 1.46286 s/step
# on time step 1368 (time=27.36), 1.44019 s/step
# on time step 1372 (time=27.44), 1.28884 s/step
# on time step 1375 (time=27.5), 1.4279 s/step
# on time step 1378 (time=27.56), 1.40039 s/step
# on time step 1381 (time=27.62), 1.41996 s/step
# on time step 1384 (time=27.68), 1.45296 s/step
# on time step 1387 (time=27.74), 1.5397 s/step
# on time step 1390 (time=27.8), 1.55469 s/step
# on time step 1393 (time=27.86), 1.46934 s/step
# on time step 1397 (time=27.94), 1.06444 s/step
# on time step 1400 (time=28), 1.47527 s/step
# on time step 1403 (time=28.06), 1.42707 s/step
# on time step 1407 (time=28.14), 1.12979 s/step
# on time step 1411 (time=28.22), 1.15742 s/step
# on time step 1415 (time=28.3), 1.13438 s/step
# on time step 1419 (time=28.38), 1.17459 s/step
# on time step 1422 (time=28.44), 1.43492 s/step
# on time step 1425 (time=28.5), 1.39731 s/step
# on time step 1428 (time=28.56), 1.55345 s/step
# on time step 1432 (time=28.64), 1.01319 s/step
# on time step 1435 (time=28.7), 1.4516 s/step
# on time step 1439 (time=28.78), 1.17854 s/step
# on time step 1442 (time=28.84), 1.84192 s/step
# on time step 1445 (time=28.9), 1.51106 s/step
# on time step 1449 (time=28.98), 1.08795 s/step
# on time step 1454 (time=29.08), 1.0122 s/step
# on time step 1458 (time=29.16), 1.08676 s/step
# on time step 1462 (time=29.24), 1.09666 s/step
# on time step 1466 (time=29.32), 1.25132 s/step
# on time step 1469 (time=29.38), 1.44033 s/step
# on time step 1472 (time=29.44), 1.44266 s/step
# on time step 1475 (time=29.5), 1.44709 s/step
# on time step 1479 (time=29.58), 1.0065 s/step
# on time step 1482 (time=29.64), 1.41941 s/step
# on time step 1487 (time=29.74), 0.859152 s/step
# on time step 1492 (time=29.84), 0.961342 s/step
# on time step 1496 (time=29.92), 1.26431 s/step
# on time step 1500 (time=30), 1.12694 s/step
# field decay(t = 30.060000000000002): 0.023780022141168228 / 0.023780022141168228 = 1.0
# on time step 1504 (time=30.08), 1.12077 s/step
# on time step 1507 (time=30.14), 1.40847 s/step
# on time step 1510 (time=30.2), 1.53261 s/step
# on time step 1514 (time=30.28), 1.07479 s/step
# on time step 1518 (time=30.36), 1.32309 s/step
# on time step 1523 (time=30.46), 0.936949 s/step
# on time step 1527 (time=30.54), 1.19762 s/step
# on time step 1530 (time=30.6), 1.34194 s/step
# on time step 1534 (time=30.68), 1.15876 s/step
# on time step 1538 (time=30.76), 1.22264 s/step
# on time step 1541 (time=30.82), 1.42968 s/step
# on time step 1545 (time=30.9), 1.34633 s/step
# on time step 1549 (time=30.98), 1.0857 s/step
# on time step 1553 (time=31.06), 1.14026 s/step
# on time step 1558 (time=31.16), 0.955385 s/step
# on time step 1563 (time=31.26), 1.10075 s/step
# on time step 1566 (time=31.32), 1.54244 s/step
# on time step 1569 (time=31.38), 1.54872 s/step
# on time step 1572 (time=31.44), 1.50701 s/step
# on time step 1575 (time=31.5), 1.4251 s/step
# on time step 1578 (time=31.56), 1.42402 s/step
# on time step 1581 (time=31.62), 1.45599 s/step
# on time step 1584 (time=31.68), 1.4416 s/step
# on time step 1587 (time=31.74), 1.40943 s/step
# on time step 1591 (time=31.82), 1.13867 s/step
# on time step 1595 (time=31.9), 1.21308 s/step
# on time step 1598 (time=31.96), 1.44474 s/step
# on time step 1601 (time=32.02), 1.4714 s/step
# on time step 1604 (time=32.08), 1.36464 s/step
# on time step 1607 (time=32.14), 1.44798 s/step
# on time step 1610 (time=32.2), 1.45475 s/step
# on time step 1614 (time=32.28), 1.05204 s/step
# on time step 1617 (time=32.34), 1.46146 s/step
# on time step 1620 (time=32.4), 1.45915 s/step
# on time step 1623 (time=32.46), 1.45634 s/step
# on time step 1626 (time=32.52), 1.42602 s/step
# on time step 1629 (time=32.58), 1.41876 s/step
# on time step 1632 (time=32.64), 1.46497 s/step
# on time step 1635 (time=32.7), 1.424 s/step
# on time step 1638 (time=32.76), 1.4278 s/step
# on time step 1641 (time=32.82), 1.46013 s/step
# on time step 1644 (time=32.88), 1.49515 s/step
# on time step 1647 (time=32.94), 1.63846 s/step
# on time step 1650 (time=33), 1.4822 s/step
# on time step 1653 (time=33.06), 1.52932 s/step
# on time step 1656 (time=33.12), 1.40545 s/step
# on time step 1659 (time=33.18), 1.42059 s/step
# on time step 1663 (time=33.26), 1.26079 s/step
# on time step 1667 (time=33.34), 1.33166 s/step
# on time step 1670 (time=33.4), 1.48298 s/step
# on time step 1673 (time=33.46), 1.48177 s/step
# on time step 1676 (time=33.52), 1.47251 s/step
# on time step 1679 (time=33.58), 1.47325 s/step
# on time step 1683 (time=33.66), 1.06613 s/step
# on time step 1688 (time=33.76), 0.951632 s/step
# on time step 1693 (time=33.86), 0.96636 s/step
# on time step 1697 (time=33.94), 1.0165 s/step
# on time step 1700 (time=34), 1.41545 s/step
# on time step 1703 (time=34.06), 1.4974 s/step
# on time step 1706 (time=34.12), 1.51872 s/step
# on time step 1709 (time=34.18), 1.41652 s/step
# on time step 1712 (time=34.24), 1.43433 s/step
# on time step 1715 (time=34.3), 1.41332 s/step
# on time step 1718 (time=34.36), 1.45768 s/step
# on time step 1722 (time=34.44), 1.13852 s/step
# on time step 1726 (time=34.52), 1.11902 s/step
# on time step 1731 (time=34.62), 0.852576 s/step
# on time step 1734 (time=34.68), 1.33836 s/step
# on time step 1737 (time=34.74), 1.47753 s/step
# on time step 1741 (time=34.82), 1.20014 s/step
# on time step 1746 (time=34.92), 0.937756 s/step
# on time step 1750 (time=35), 1.01677 s/step
# on time step 1754 (time=35.08), 1.2176 s/step
# on time step 1757 (time=35.14), 1.50587 s/step
# on time step 1760 (time=35.2), 1.45927 s/step
# on time step 1764 (time=35.28), 1.16978 s/step
# on time step 1767 (time=35.34), 1.41125 s/step
# on time step 1770 (time=35.4), 1.51959 s/step
# on time step 1773 (time=35.46), 1.45514 s/step
# on time step 1776 (time=35.52), 1.41475 s/step
# on time step 1779 (time=35.58), 1.41745 s/step
# on time step 1782 (time=35.64), 1.40124 s/step
# on time step 1785 (time=35.7), 1.42155 s/step
# on time step 1788 (time=35.76), 1.4143 s/step
# on time step 1791 (time=35.82), 1.41748 s/step
# on time step 1794 (time=35.88), 1.4511 s/step
# on time step 1797 (time=35.94), 1.43069 s/step
# on time step 1800 (time=36), 1.44671 s/step
# on time step 1803 (time=36.06), 1.46017 s/step
# on time step 1806 (time=36.12), 1.44139 s/step
# on time step 1809 (time=36.18), 1.50157 s/step
# on time step 1812 (time=36.24), 1.45939 s/step
# on time step 1815 (time=36.3), 1.36795 s/step
# on time step 1818 (time=36.36), 1.34273 s/step
# on time step 1822 (time=36.44), 1.46019 s/step
# on time step 1827 (time=36.54), 0.910458 s/step
# on time step 1831 (time=36.62), 1.32028 s/step
# on time step 1835 (time=36.7), 1.25901 s/step
# on time step 1838 (time=36.76), 1.4609 s/step
# on time step 1843 (time=36.86), 0.954595 s/step
# on time step 1847 (time=36.94), 1.14913 s/step
# on time step 1850 (time=37), 1.46002 s/step
# on time step 1853 (time=37.06), 1.43581 s/step
# on time step 1856 (time=37.12), 1.49839 s/step
# on time step 1860 (time=37.2), 1.33759 s/step
# on time step 1863 (time=37.26), 1.4093 s/step
# on time step 1866 (time=37.32), 1.40979 s/step
# on time step 1869 (time=37.38), 1.41833 s/step
# on time step 1873 (time=37.46), 1.11899 s/step
# on time step 1877 (time=37.54), 1.33906 s/step
# on time step 1880 (time=37.6), 1.42684 s/step
# on time step 1884 (time=37.68), 1.30994 s/step
# on time step 1888 (time=37.76), 1.08617 s/step
# on time step 1892 (time=37.84), 1.28247 s/step
# on time step 1895 (time=37.9), 1.4103 s/step
# on time step 1900 (time=38), 0.903525 s/step
# on time step 1904 (time=38.08), 1.168 s/step
# on time step 1909 (time=38.18), 0.910407 s/step
# on time step 1912 (time=38.24), 1.39645 s/step
# on time step 1915 (time=38.3), 1.43867 s/step
# on time step 1918 (time=38.36), 1.48005 s/step
# on time step 1922 (time=38.44), 1.15634 s/step
# on time step 1925 (time=38.5), 1.40937 s/step
# on time step 1928 (time=38.56), 1.45192 s/step
# on time step 1932 (time=38.64), 1.26228 s/step
# on time step 1936 (time=38.72), 1.33031 s/step
# on time step 1940 (time=38.8), 1.0969 s/step
# on time step 1943 (time=38.86), 1.38162 s/step
# on time step 1946 (time=38.92), 1.42047 s/step
# on time step 1949 (time=38.98), 1.47813 s/step
# on time step 1952 (time=39.04), 1.44027 s/step
# on time step 1955 (time=39.1), 1.41401 s/step
# on time step 1959 (time=39.18), 1.27056 s/step
# on time step 1962 (time=39.24), 1.33489 s/step
# on time step 1966 (time=39.32), 1.01566 s/step
# on time step 1970 (time=39.4), 1.25938 s/step
# on time step 1973 (time=39.46), 1.41602 s/step
# on time step 1978 (time=39.56), 1.00642 s/step
# on time step 1982 (time=39.64), 1.32165 s/step
# on time step 1985 (time=39.7), 1.45006 s/step
# on time step 1989 (time=39.78), 1.22982 s/step
# on time step 1993 (time=39.86), 1.00746 s/step
# on time step 1997 (time=39.94), 1.30701 s/step
# on time step 2000 (time=40), 1.43074 s/step
# field decay(t = 40.06): 0.01852829670721948 / 0.023780022141168228 = 0.7791538879664496
# on time step 2005 (time=40.1), 0.884968 s/step
# on time step 2008 (time=40.16), 1.45326 s/step
# on time step 2012 (time=40.24), 1.26496 s/step
# on time step 2016 (time=40.32), 1.08195 s/step
# on time step 2020 (time=40.4), 1.08964 s/step
# on time step 2024 (time=40.48), 1.3224 s/step
# on time step 2028 (time=40.56), 1.23652 s/step
# on time step 2032 (time=40.64), 1.0826 s/step
# on time step 2037 (time=40.74), 0.898491 s/step
# on time step 2040 (time=40.8), 1.36745 s/step
# on time step 2043 (time=40.86), 1.4413 s/step
# on time step 2047 (time=40.94), 1.1256 s/step
# on time step 2052 (time=41.04), 1.02182 s/step
# on time step 2056 (time=41.12), 1.29534 s/step
# on time step 2060 (time=41.2), 1.17832 s/step
# on time step 2064 (time=41.28), 1.19399 s/step
# on time step 2067 (time=41.34), 1.34841 s/step
# on time step 2071 (time=41.42), 1.05664 s/step
# on time step 2075 (time=41.5), 1.15319 s/step
# on time step 2078 (time=41.56), 1.46172 s/step
# on time step 2081 (time=41.62), 1.46763 s/step
# on time step 2085 (time=41.7), 1.32528 s/step
# on time step 2088 (time=41.76), 1.41204 s/step
# on time step 2091 (time=41.82), 1.41624 s/step
# on time step 2094 (time=41.88), 1.3918 s/step
# on time step 2097 (time=41.94), 1.37938 s/step
# on time step 2100 (time=42), 1.39968 s/step
# on time step 2103 (time=42.06), 1.37987 s/step
# on time step 2106 (time=42.12), 1.43923 s/step
# on time step 2109 (time=42.18), 1.35358 s/step
# on time step 2112 (time=42.24), 1.40182 s/step
# on time step 2115 (time=42.3), 1.40983 s/step
# on time step 2119 (time=42.38), 1.01529 s/step
# on time step 2123 (time=42.46), 1.27398 s/step
# on time step 2127 (time=42.54), 1.1678 s/step
# on time step 2131 (time=42.62), 1.3577 s/step
# on time step 2134 (time=42.68), 1.38746 s/step
# on time step 2137 (time=42.74), 1.38916 s/step
# on time step 2140 (time=42.8), 1.39128 s/step
# on time step 2143 (time=42.86), 1.37978 s/step
# on time step 2146 (time=42.92), 1.36612 s/step
# on time step 2149 (time=42.98), 1.39142 s/step
# on time step 2152 (time=43.04), 1.35863 s/step
# on time step 2156 (time=43.12), 1.03326 s/step
# on time step 2161 (time=43.22), 0.902592 s/step
# on time step 2164 (time=43.28), 1.45932 s/step
# on time step 2167 (time=43.34), 1.42209 s/step
# on time step 2170 (time=43.4), 1.42318 s/step
# on time step 2173 (time=43.46), 1.41253 s/step
# on time step 2177 (time=43.54), 1.2888 s/step
# on time step 2180 (time=43.6), 1.41173 s/step
# on time step 2184 (time=43.68), 1.1121 s/step
# on time step 2188 (time=43.76), 1.08605 s/step
# on time step 2192 (time=43.84), 1.15513 s/step
# on time step 2196 (time=43.92), 1.28124 s/step
# on time step 2199 (time=43.98), 1.42053 s/step
# on time step 2203 (time=44.06), 1.00503 s/step
# on time step 2206 (time=44.12), 1.44015 s/step
# on time step 2209 (time=44.18), 1.40822 s/step
# on time step 2212 (time=44.24), 1.40651 s/step
# on time step 2216 (time=44.32), 1.27707 s/step
# on time step 2219 (time=44.38), 1.41745 s/step
# on time step 2222 (time=44.44), 1.44056 s/step
# on time step 2225 (time=44.5), 1.42449 s/step
# on time step 2228 (time=44.56), 1.33576 s/step
# on time step 2231 (time=44.62), 1.43841 s/step
# on time step 2234 (time=44.68), 1.43472 s/step
# on time step 2237 (time=44.74), 1.45163 s/step
# on time step 2240 (time=44.8), 1.48327 s/step
# on time step 2243 (time=44.86), 1.4078 s/step
# on time step 2246 (time=44.92), 1.41657 s/step
# on time step 2249 (time=44.98), 1.40702 s/step
# on time step 2252 (time=45.04), 1.42838 s/step
# on time step 2255 (time=45.1), 1.42252 s/step
# on time step 2259 (time=45.18), 1.21042 s/step
# on time step 2263 (time=45.26), 1.06286 s/step
# on time step 2267 (time=45.34), 1.12738 s/step
# on time step 2271 (time=45.42), 1.00498 s/step
# on time step 2274 (time=45.48), 1.36154 s/step
# on time step 2277 (time=45.54), 1.40833 s/step
# on time step 2280 (time=45.6), 1.43055 s/step
# on time step 2283 (time=45.66), 1.42578 s/step
# on time step 2286 (time=45.72), 1.41031 s/step
# on time step 2289 (time=45.78), 1.4038 s/step
# on time step 2292 (time=45.84), 1.46818 s/step
# on time step 2295 (time=45.9), 1.43707 s/step
# on time step 2298 (time=45.96), 1.4317 s/step
# on time step 2302 (time=46.04), 1.16865 s/step
# on time step 2306 (time=46.12), 1.14719 s/step
# on time step 2309 (time=46.18), 1.4327 s/step
# on time step 2312 (time=46.24), 1.35503 s/step
# on time step 2316 (time=46.32), 1.14721 s/step
# on time step 2320 (time=46.4), 1.20208 s/step
# on time step 2323 (time=46.46), 1.45809 s/step
# on time step 2326 (time=46.52), 1.42709 s/step
# on time step 2330 (time=46.6), 1.27892 s/step
# on time step 2333 (time=46.66), 1.43203 s/step
# on time step 2336 (time=46.72), 1.42459 s/step
# on time step 2339 (time=46.78), 1.42416 s/step
# on time step 2342 (time=46.84), 1.43589 s/step
# on time step 2345 (time=46.9), 1.43079 s/step
# on time step 2348 (time=46.96), 1.42679 s/step
# on time step 2351 (time=47.02), 1.41055 s/step
# on time step 2354 (time=47.08), 1.40857 s/step
# on time step 2357 (time=47.14), 1.41872 s/step
# on time step 2360 (time=47.2), 1.3696 s/step
# on time step 2364 (time=47.28), 1.27428 s/step
# on time step 2367 (time=47.34), 1.42781 s/step
# on time step 2370 (time=47.4), 1.43645 s/step
# on time step 2373 (time=47.46), 1.43669 s/step
# on time step 2376 (time=47.52), 1.41712 s/step
# on time step 2379 (time=47.58), 1.41878 s/step
# on time step 2383 (time=47.66), 1.29886 s/step
# on time step 2386 (time=47.72), 1.42736 s/step
# on time step 2389 (time=47.78), 1.42229 s/step
# on time step 2393 (time=47.86), 1.28214 s/step
# on time step 2397 (time=47.94), 1.3381 s/step
# on time step 2400 (time=48), 1.43139 s/step
# on time step 2403 (time=48.06), 1.40211 s/step
# on time step 2406 (time=48.12), 1.36801 s/step
# on time step 2409 (time=48.18), 1.38746 s/step
# on time step 2413 (time=48.26), 1.19766 s/step
# on time step 2416 (time=48.32), 1.42257 s/step
# on time step 2419 (time=48.38), 1.37281 s/step
# on time step 2422 (time=48.44), 1.36648 s/step
# on time step 2425 (time=48.5), 1.4096 s/step
# on time step 2428 (time=48.56), 1.42253 s/step
# on time step 2431 (time=48.62), 1.45438 s/step
# on time step 2434 (time=48.68), 1.43077 s/step
# on time step 2437 (time=48.74), 1.44173 s/step
# on time step 2440 (time=48.8), 1.47923 s/step
# on time step 2444 (time=48.88), 1.1597 s/step
# on time step 2447 (time=48.94), 1.34099 s/step
# on time step 2451 (time=49.02), 1.21282 s/step
# on time step 2455 (time=49.1), 1.08416 s/step
# on time step 2460 (time=49.2), 0.882792 s/step
# on time step 2464 (time=49.28), 1.02707 s/step
# on time step 2468 (time=49.36), 1.11814 s/step
# on time step 2472 (time=49.44), 1.06405 s/step
# on time step 2475 (time=49.5), 1.4673 s/step
# on time step 2478 (time=49.56), 1.37147 s/step
# on time step 2481 (time=49.62), 1.42743 s/step
# on time step 2485 (time=49.7), 1.01248 s/step
# on time step 2488 (time=49.76), 1.33991 s/step
# on time step 2491 (time=49.82), 1.33861 s/step
# on time step 2495 (time=49.9), 1.15523 s/step
# on time step 2498 (time=49.96), 1.33419 s/step
# on time step 2502 (time=50.04), 1.213 s/step
# field decay(t = 50.08): 0.01428136942373606 / 0.023780022141168228 = 0.6005616537678492
# on time step 2506 (time=50.12), 1.22634 s/step
# on time step 2509 (time=50.18), 1.41528 s/step
# on time step 2513 (time=50.26), 1.05567 s/step
# on time step 2517 (time=50.34), 1.18558 s/step
# on time step 2522 (time=50.44), 0.976006 s/step
# on time step 2527 (time=50.54), 0.913713 s/step
# on time step 2532 (time=50.64), 0.892243 s/step
# on time step 2537 (time=50.74), 0.978189 s/step
# on time step 2541 (time=50.82), 1.04248 s/step
# on time step 2544 (time=50.88), 1.47461 s/step
# on time step 2548 (time=50.96), 1.04017 s/step
# on time step 2552 (time=51.04), 1.15699 s/step
# on time step 2556 (time=51.12), 1.17426 s/step
# on time step 2560 (time=51.2), 1.3325 s/step
# on time step 2563 (time=51.26), 1.43845 s/step
# on time step 2567 (time=51.34), 1.27305 s/step
# on time step 2570 (time=51.4), 1.43473 s/step
# on time step 2573 (time=51.46), 1.43233 s/step
# on time step 2576 (time=51.52), 1.41703 s/step
# on time step 2579 (time=51.58), 1.39845 s/step
# on time step 2582 (time=51.64), 1.41821 s/step
# on time step 2585 (time=51.7), 1.46634 s/step
# on time step 2588 (time=51.76), 1.4356 s/step
# on time step 2592 (time=51.84), 1.33233 s/step
# on time step 2595 (time=51.9), 1.43377 s/step
# on time step 2599 (time=51.98), 1.29963 s/step
# on time step 2603 (time=52.06), 1.34994 s/step
# on time step 2606 (time=52.12), 1.42832 s/step
# on time step 2609 (time=52.18), 1.41707 s/step
# on time step 2612 (time=52.24), 1.45426 s/step
# on time step 2615 (time=52.3), 1.45701 s/step
# on time step 2618 (time=52.36), 1.43992 s/step
# on time step 2622 (time=52.44), 1.01466 s/step
# on time step 2626 (time=52.52), 1.11492 s/step
# on time step 2629 (time=52.58), 1.42015 s/step
# on time step 2633 (time=52.66), 1.27085 s/step
# on time step 2636 (time=52.72), 1.42265 s/step
# on time step 2640 (time=52.8), 1.31232 s/step
# on time step 2643 (time=52.86), 1.3999 s/step
# on time step 2647 (time=52.94), 1.17161 s/step
# on time step 2651 (time=53.02), 1.32211 s/step
# on time step 2655 (time=53.1), 1.34101 s/step
# on time step 2658 (time=53.16), 1.42287 s/step
# on time step 2661 (time=53.22), 1.3829 s/step
# on time step 2664 (time=53.28), 1.40429 s/step
# on time step 2667 (time=53.34), 1.41571 s/step
# on time step 2670 (time=53.4), 1.41084 s/step
# on time step 2675 (time=53.5), 0.965682 s/step
# on time step 2679 (time=53.58), 1.25243 s/step
# on time step 2682 (time=53.64), 1.35555 s/step
# on time step 2685 (time=53.7), 1.34551 s/step
# on time step 2688 (time=53.76), 1.41149 s/step
# on time step 2692 (time=53.84), 1.22328 s/step
# on time step 2695 (time=53.9), 1.4166 s/step
# on time step 2698 (time=53.96), 1.42522 s/step
# on time step 2701 (time=54.02), 1.41071 s/step
# on time step 2704 (time=54.08), 1.39938 s/step
# on time step 2707 (time=54.14), 1.42302 s/step
# on time step 2710 (time=54.2), 1.45991 s/step
# on time step 2713 (time=54.26), 1.41905 s/step
# on time step 2716 (time=54.32), 1.40564 s/step
# on time step 2719 (time=54.38), 1.4262 s/step
# on time step 2724 (time=54.48), 0.903225 s/step
# on time step 2729 (time=54.58), 0.934228 s/step
# on time step 2732 (time=54.64), 1.37229 s/step
# on time step 2736 (time=54.72), 1.04907 s/step
# on time step 2740 (time=54.8), 1.24205 s/step
# on time step 2743 (time=54.86), 1.41883 s/step
# on time step 2746 (time=54.92), 1.42355 s/step
# on time step 2749 (time=54.98), 1.3835 s/step
# on time step 2752 (time=55.04), 1.36453 s/step
# on time step 2755 (time=55.1), 1.36793 s/step
# on time step 2758 (time=55.16), 1.37504 s/step
# on time step 2761 (time=55.22), 1.36926 s/step
# on time step 2764 (time=55.28), 1.3514 s/step
# on time step 2768 (time=55.36), 1.24247 s/step
# on time step 2772 (time=55.44), 1.06688 s/step
# on time step 2776 (time=55.52), 1.29737 s/step
# on time step 2779 (time=55.58), 1.49613 s/step
# on time step 2782 (time=55.64), 1.36302 s/step
# on time step 2786 (time=55.72), 1.19554 s/step
# on time step 2789 (time=55.78), 1.40277 s/step
# on time step 2792 (time=55.84), 1.41042 s/step
# on time step 2795 (time=55.9), 1.41075 s/step
# on time step 2798 (time=55.96), 1.4047 s/step
# on time step 2801 (time=56.02), 1.42127 s/step
# on time step 2804 (time=56.08), 1.40313 s/step
# on time step 2807 (time=56.14), 1.41585 s/step
# on time step 2810 (time=56.2), 1.41548 s/step
# on time step 2813 (time=56.26), 1.40932 s/step
# on time step 2817 (time=56.34), 1.12088 s/step
# on time step 2820 (time=56.4), 1.3785 s/step
# on time step 2823 (time=56.46), 1.41269 s/step
# on time step 2827 (time=56.54), 1.03793 s/step
# on time step 2830 (time=56.6), 1.3514 s/step
# on time step 2834 (time=56.68), 1.07334 s/step
# on time step 2838 (time=56.76), 1.07253 s/step
# on time step 2841 (time=56.82), 1.38069 s/step
# on time step 2844 (time=56.88), 1.3976 s/step
# on time step 2848 (time=56.96), 1.33362 s/step
# on time step 2851 (time=57.02), 1.41376 s/step
# on time step 2854 (time=57.08), 1.43042 s/step
# on time step 2857 (time=57.14), 1.42343 s/step
# on time step 2860 (time=57.2), 1.45405 s/step
# on time step 2864 (time=57.28), 1.25091 s/step
# on time step 2868 (time=57.36), 1.08728 s/step
# on time step 2871 (time=57.42), 1.40205 s/step
# on time step 2874 (time=57.48), 1.47128 s/step
# on time step 2878 (time=57.56), 1.06098 s/step
# on time step 2883 (time=57.66), 1.0143 s/step
# on time step 2886 (time=57.72), 1.47869 s/step
# on time step 2890 (time=57.8), 1.16696 s/step
# on time step 2893 (time=57.86), 1.44508 s/step
# on time step 2897 (time=57.94), 1.0764 s/step
# on time step 2902 (time=58.04), 1.0166 s/step
# on time step 2905 (time=58.1), 1.44813 s/step
# on time step 2908 (time=58.16), 1.45141 s/step
# on time step 2912 (time=58.24), 1.2894 s/step
# on time step 2915 (time=58.3), 1.34326 s/step
# on time step 2918 (time=58.36), 1.37502 s/step
# on time step 2921 (time=58.42), 1.40146 s/step
# on time step 2924 (time=58.48), 1.40828 s/step
# on time step 2927 (time=58.54), 1.44749 s/step
# on time step 2930 (time=58.6), 1.42957 s/step
# on time step 2933 (time=58.66), 1.41509 s/step
# on time step 2936 (time=58.72), 1.43531 s/step
# on time step 2939 (time=58.78), 1.40959 s/step
# on time step 2942 (time=58.84), 1.3546 s/step
# on time step 2945 (time=58.9), 1.40599 s/step
# on time step 2948 (time=58.96), 1.35571 s/step
# on time step 2951 (time=59.02), 1.44115 s/step
# on time step 2954 (time=59.08), 1.47639 s/step
# on time step 2957 (time=59.14), 1.42356 s/step
# on time step 2960 (time=59.2), 1.42292 s/step
# on time step 2963 (time=59.26), 1.43747 s/step
# on time step 2966 (time=59.32), 1.44973 s/step
# on time step 2969 (time=59.38), 1.45941 s/step
# on time step 2972 (time=59.44), 1.36972 s/step
# on time step 2975 (time=59.5), 1.38754 s/step
# on time step 2978 (time=59.56), 1.38231 s/step
# on time step 2981 (time=59.62), 1.45112 s/step
# on time step 2984 (time=59.68), 1.42296 s/step
# on time step 2987 (time=59.74), 1.38665 s/step
# on time step 2990 (time=59.8), 1.41174 s/step
# on time step 2994 (time=59.88), 1.29167 s/step
# on time step 2998 (time=59.96), 1.26045 s/step
# on time step 3002 (time=60.04), 1.299 s/step
# field decay(t = 60.1): 0.0095132542893312 / 0.023780022141168228 = 0.40005237307419295
# on time step 3005 (time=60.1), 1.33809 s/step
# on time step 3008 (time=60.16), 1.35542 s/step
# on time step 3011 (time=60.22), 1.47744 s/step
# on time step 3015 (time=60.3), 1.1674 s/step
# on time step 3020 (time=60.4), 0.999228 s/step
# on time step 3024 (time=60.48), 1.00567 s/step
# on time step 3028 (time=60.56), 1.10663 s/step
# on time step 3033 (time=60.66), 0.827365 s/step
# on time step 3038 (time=60.76), 0.889487 s/step
# on time step 3043 (time=60.86), 1.06699 s/step
# on time step 3046 (time=60.92), 1.42955 s/step
# on time step 3049 (time=60.98), 1.4157 s/step
# on time step 3054 (time=61.08), 0.949796 s/step
# on time step 3058 (time=61.16), 1.08594 s/step
# on time step 3061 (time=61.22), 1.39613 s/step
# on time step 3065 (time=61.3), 1.24946 s/step
# on time step 3068 (time=61.36), 1.40991 s/step
# on time step 3071 (time=61.42), 1.41418 s/step
# on time step 3074 (time=61.48), 1.4197 s/step
# on time step 3078 (time=61.56), 1.00073 s/step
# on time step 3083 (time=61.66), 0.878348 s/step
# on time step 3087 (time=61.74), 1.11344 s/step
# on time step 3090 (time=61.8), 1.4141 s/step
# on time step 3093 (time=61.86), 1.45307 s/step
# on time step 3096 (time=61.92), 1.43957 s/step
# on time step 3099 (time=61.98), 1.40509 s/step
# on time step 3102 (time=62.04), 1.43801 s/step
# on time step 3105 (time=62.1), 1.55465 s/step
# on time step 3109 (time=62.18), 1.24747 s/step
# on time step 3114 (time=62.28), 0.940976 s/step
# on time step 3117 (time=62.34), 1.40838 s/step
# on time step 3121 (time=62.42), 1.18521 s/step
# on time step 3125 (time=62.5), 1.12817 s/step
# on time step 3130 (time=62.6), 0.850505 s/step
# on time step 3136 (time=62.72), 0.775148 s/step
# on time step 3142 (time=62.84), 0.778565 s/step
# on time step 3147 (time=62.94), 0.838339 s/step
# on time step 3154 (time=63.08), 0.626147 s/step
# on time step 3161 (time=63.22), 0.642827 s/step
# on time step 3167 (time=63.34), 0.784607 s/step
# on time step 3173 (time=63.46), 0.77498 s/step
# on time step 3179 (time=63.58), 0.756341 s/step
# on time step 3185 (time=63.7), 0.752373 s/step
# on time step 3191 (time=63.82), 0.747129 s/step
# on time step 3196 (time=63.92), 0.919619 s/step
# on time step 3201 (time=64.02), 0.932948 s/step
# on time step 3206 (time=64.12), 0.963888 s/step
# on time step 3211 (time=64.22), 0.967791 s/step
# on time step 3216 (time=64.32), 0.967655 s/step
# on time step 3221 (time=64.42), 0.974538 s/step
# on time step 3226 (time=64.52), 0.967565 s/step
# on time step 3231 (time=64.62), 0.965483 s/step
# on time step 3237 (time=64.74), 0.754264 s/step
# on time step 3243 (time=64.86), 0.672942 s/step
# on time step 3249 (time=64.98), 0.774534 s/step
# on time step 3255 (time=65.1), 0.758094 s/step
# on time step 3261 (time=65.22), 0.728955 s/step
# on time step 3267 (time=65.34), 0.742249 s/step
# on time step 3273 (time=65.46), 0.739027 s/step
# on time step 3279 (time=65.58), 0.697 s/step
# on time step 3285 (time=65.7), 0.69682 s/step
# on time step 3292 (time=65.84), 0.649447 s/step
# on time step 3297 (time=65.94), 0.806387 s/step
# on time step 3302 (time=66.04), 0.925532 s/step
# on time step 3307 (time=66.14), 0.948555 s/step
# on time step 3312 (time=66.24), 0.939768 s/step
# on time step 3317 (time=66.34), 0.915412 s/step
# on time step 3322 (time=66.44), 0.927471 s/step
# on time step 3327 (time=66.54), 0.904926 s/step
# on time step 3335 (time=66.7), 0.565983 s/step
# on time step 3340 (time=66.8), 0.839349 s/step
# on time step 3345 (time=66.9), 0.902775 s/step
# on time step 3350 (time=67), 0.839896 s/step
# on time step 3356 (time=67.12), 0.797618 s/step
# on time step 3362 (time=67.24), 0.768347 s/step
# on time step 3368 (time=67.36), 0.757895 s/step
# on time step 3374 (time=67.48), 0.748344 s/step
# on time step 3380 (time=67.6), 0.791745 s/step
# on time step 3385 (time=67.7), 0.801982 s/step
# on time step 3390 (time=67.8), 0.95402 s/step
# on time step 3395 (time=67.9), 0.988133 s/step
# on time step 3400 (time=68), 0.985254 s/step
# on time step 3405 (time=68.1), 0.921059 s/step
# on time step 3411 (time=68.22), 0.698713 s/step
# on time step 3416 (time=68.32), 0.832904 s/step
# on time step 3422 (time=68.44), 0.764456 s/step
# on time step 3428 (time=68.56), 0.718591 s/step
# on time step 3434 (time=68.68), 0.738274 s/step
# on time step 3439 (time=68.78), 0.828498 s/step
# on time step 3445 (time=68.9), 0.746329 s/step
# on time step 3451 (time=69.02), 0.760924 s/step
# on time step 3457 (time=69.14), 0.769943 s/step
# on time step 3463 (time=69.26), 0.76133 s/step
# on time step 3469 (time=69.38), 0.766363 s/step
# on time step 3475 (time=69.5), 0.765323 s/step
# on time step 3480 (time=69.6), 0.801882 s/step
# on time step 3485 (time=69.7), 0.860122 s/step
# on time step 3491 (time=69.82), 0.764865 s/step
# on time step 3505 (time=70.1), 0.285938 s/step
# field decay(t = 70.12): 0.004219944190454193 / 0.023780022141168228 = 0.17745753832367467
# on time step 3522 (time=70.44), 0.237276 s/step
# on time step 3539 (time=70.78), 0.236435 s/step
# on time step 3556 (time=71.12), 0.237131 s/step
# on time step 3573 (time=71.46), 0.236712 s/step
# on time step 3590 (time=71.8), 0.236769 s/step
# on time step 3607 (time=72.14), 0.237187 s/step
# on time step 3624 (time=72.48), 0.237135 s/step
# on time step 3641 (time=72.82), 0.237145 s/step
# on time step 3658 (time=73.16), 0.236738 s/step
# on time step 3675 (time=73.5), 0.23665 s/step
# on time step 3692 (time=73.84), 0.236946 s/step
# on time step 3709 (time=74.18), 0.237673 s/step
# on time step 3726 (time=74.52), 0.236613 s/step
# on time step 3743 (time=74.86), 0.237149 s/step
# on time step 3760 (time=75.2), 0.237694 s/step
# on time step 3777 (time=75.54), 0.236836 s/step
# on time step 3794 (time=75.88), 0.23753 s/step
# on time step 3811 (time=76.22), 0.237412 s/step
# on time step 3828 (time=76.56), 0.236814 s/step
# on time step 3845 (time=76.9), 0.23773 s/step
# on time step 3862 (time=77.24), 0.236838 s/step
# on time step 3879 (time=77.58), 0.237075 s/step
# on time step 3896 (time=77.92), 0.238178 s/step
# on time step 3913 (time=78.26), 0.237136 s/step
# on time step 3930 (time=78.6), 0.236959 s/step
# on time step 3947 (time=78.94), 0.237278 s/step
# on time step 3964 (time=79.28), 0.237076 s/step
# on time step 3981 (time=79.62), 0.237119 s/step
# on time step 3998 (time=79.96), 0.237259 s/step
# field decay(t = 80.14): 0.0019037595454082716 / 0.023780022141168228 = 0.08005709726032857
# on time step 4015 (time=80.3), 0.23675 s/step
# on time step 4032 (time=80.64), 0.237013 s/step
# on time step 4049 (time=80.98), 0.241499 s/step
# on time step 4066 (time=81.32), 0.238428 s/step
# on time step 4083 (time=81.66), 0.238072 s/step
# on time step 4100 (time=82), 0.239479 s/step
# on time step 4116 (time=82.32), 0.262949 s/step
# on time step 4133 (time=82.66), 0.241816 s/step
# on time step 4150 (time=83), 0.240259 s/step
# on time step 4167 (time=83.34), 0.239905 s/step
# on time step 4184 (time=83.68), 0.241082 s/step
# on time step 4201 (time=84.02), 0.239509 s/step
# on time step 4218 (time=84.36), 0.236545 s/step
# on time step 4235 (time=84.7), 0.238039 s/step
# on time step 4252 (time=85.04), 0.240132 s/step
# on time step 4269 (time=85.38), 0.239951 s/step
# on time step 4286 (time=85.72), 0.240695 s/step
# on time step 4303 (time=86.06), 0.239915 s/step
# on time step 4320 (time=86.4), 0.239755 s/step
# on time step 4337 (time=86.74), 0.240166 s/step
# on time step 4354 (time=87.08), 0.243985 s/step
# on time step 4371 (time=87.42), 0.236729 s/step
# on time step 4388 (time=87.76), 0.2354 s/step
# on time step 4405 (time=88.1), 0.236591 s/step
# on time step 4422 (time=88.44), 0.237552 s/step
# on time step 4439 (time=88.78), 0.236966 s/step
# on time step 4456 (time=89.12), 0.237087 s/step
# on time step 4473 (time=89.46), 0.237886 s/step
# on time step 4490 (time=89.8), 0.23765 s/step
# on time step 4507 (time=90.14), 0.237677 s/step
# field decay(t = 90.16): 0.0006933283485899808 / 0.023780022141168228 = 0.029155916864756964
# on time step 4524 (time=90.48), 0.237969 s/step
# on time step 4541 (time=90.82), 0.237066 s/step
# on time step 4558 (time=91.16), 0.237024 s/step
# on time step 4575 (time=91.5), 0.237888 s/step
# on time step 4592 (time=91.84), 0.23718 s/step
# on time step 4609 (time=92.18), 0.23695 s/step
# on time step 4626 (time=92.52), 0.237582 s/step
# on time step 4643 (time=92.86), 0.237216 s/step
# on time step 4660 (time=93.2), 0.237095 s/step
# on time step 4677 (time=93.54), 0.237333 s/step
# on time step 4694 (time=93.88), 0.237756 s/step
# on time step 4711 (time=94.22), 0.237277 s/step
# on time step 4728 (time=94.56), 0.237731 s/step
# on time step 4745 (time=94.9), 0.236946 s/step
# on time step 4762 (time=95.24), 0.237212 s/step
# on time step 4779 (time=95.58), 0.237155 s/step
# on time step 4796 (time=95.92), 0.237023 s/step
# on time step 4813 (time=96.26), 0.237614 s/step
# on time step 4830 (time=96.6), 0.236825 s/step
# on time step 4847 (time=96.94), 0.237305 s/step
# on time step 4864 (time=97.28), 0.237681 s/step
# on time step 4881 (time=97.62), 0.237372 s/step
# on time step 4898 (time=97.96), 0.236949 s/step
# on time step 4915 (time=98.3), 0.237324 s/step
# on time step 4932 (time=98.64), 0.237179 s/step
# on time step 4949 (time=98.98), 0.247014 s/step
# on time step 4968 (time=99.36), 0.21239 s/step
# on time step 4983 (time=99.66), 0.27483 s/step
# on time step 5000 (time=100), 0.239733 s/step
# field decay(t = 100.18): 0.00036214893824245277 / 0.023780022141168228 = 0.015229125359622633
# on time step 5018 (time=100.36), 0.224627 s/step
# on time step 5035 (time=100.7), 0.240099 s/step
# on time step 5052 (time=101.04), 0.237173 s/step
# on time step 5071 (time=101.42), 0.218968 s/step
# on time step 5088 (time=101.76), 0.239251 s/step
# on time step 5105 (time=102.1), 0.239633 s/step
# on time step 5122 (time=102.44), 0.239236 s/step
# on time step 5139 (time=102.78), 0.238318 s/step
# on time step 5156 (time=103.12), 0.238265 s/step
# on time step 5173 (time=103.46), 0.235583 s/step
# on time step 5190 (time=103.8), 0.236312 s/step
# on time step 5207 (time=104.14), 0.237645 s/step
# on time step 5224 (time=104.48), 0.236264 s/step
# on time step 5241 (time=104.82), 0.235532 s/step
# on time step 5258 (time=105.16), 0.235513 s/step
# on time step 5275 (time=105.5), 0.235604 s/step
# on time step 5292 (time=105.84), 0.236083 s/step
# on time step 5309 (time=106.18), 0.236083 s/step
# on time step 5326 (time=106.52), 0.235631 s/step
# on time step 5344 (time=106.88), 0.235294 s/step
# on time step 5361 (time=107.22), 0.235999 s/step
# on time step 5378 (time=107.56), 0.235468 s/step
# on time step 5395 (time=107.9), 0.236327 s/step
# on time step 5412 (time=108.24), 0.236412 s/step
# on time step 5429 (time=108.58), 0.236673 s/step
# on time step 5446 (time=108.92), 0.236741 s/step
# on time step 5463 (time=109.26), 0.236142 s/step
# on time step 5480 (time=109.6), 0.235439 s/step
# on time step 5497 (time=109.94), 0.235641 s/step
# field decay(t = 110.2): 0.00012934722247874225 / 0.023780022141168228 = 0.005439323046500237
# on time step 5514 (time=110.28), 0.235887 s/step
# on time step 5531 (time=110.62), 0.235607 s/step
# on time step 5548 (time=110.96), 0.235733 s/step
# on time step 5565 (time=111.3), 0.235741 s/step
# on time step 5582 (time=111.64), 0.23584 s/step
# on time step 5600 (time=112), 0.234407 s/step
# on time step 5617 (time=112.34), 0.235464 s/step
# on time step 5634 (time=112.68), 0.235937 s/step
# on time step 5651 (time=113.02), 0.23586 s/step
# on time step 5668 (time=113.36), 0.235995 s/step
# on time step 5685 (time=113.7), 0.236235 s/step
# on time step 5702 (time=114.04), 0.236388 s/step
# on time step 5720 (time=114.4), 0.235382 s/step
# on time step 5737 (time=114.74), 0.23555 s/step
# on time step 5754 (time=115.08), 0.236358 s/step
# on time step 5771 (time=115.42), 0.235707 s/step
# on time step 5788 (time=115.76), 0.236213 s/step
# on time step 5805 (time=116.1), 0.237095 s/step
# on time step 5822 (time=116.44), 0.236017 s/step
# on time step 5839 (time=116.78), 0.235717 s/step
# on time step 5856 (time=117.12), 0.236495 s/step
# on time step 5873 (time=117.46), 0.236454 s/step
# on time step 5890 (time=117.8), 0.236037 s/step
# on time step 5907 (time=118.14), 0.236436 s/step
# on time step 5924 (time=118.48), 0.235883 s/step
# on time step 5941 (time=118.82), 0.235979 s/step
# on time step 5958 (time=119.16), 0.236421 s/step
# on time step 5975 (time=119.5), 0.236121 s/step
# on time step 5992 (time=119.84), 0.235877 s/step
# on time step 6009 (time=120.18), 0.236269 s/step
# field decay(t = 120.22): 8.491129665348284e-05 / 0.023780022141168228 = 0.0035706988054684564
# on time step 6026 (time=120.52), 0.235944 s/step
# on time step 6043 (time=120.86), 0.236361 s/step
# on time step 6060 (time=121.2), 0.236695 s/step
# on time step 6077 (time=121.54), 0.236989 s/step
# on time step 6094 (time=121.88), 0.235912 s/step
# on time step 6111 (time=122.22), 0.236542 s/step
# on time step 6128 (time=122.56), 0.236091 s/step
# on time step 6145 (time=122.9), 0.23595 s/step
# on time step 6162 (time=123.24), 0.236849 s/step
# on time step 6179 (time=123.58), 0.235855 s/step
# on time step 6196 (time=123.92), 0.235974 s/step
# on time step 6213 (time=124.26), 0.237024 s/step
# on time step 6230 (time=124.6), 0.235929 s/step
# on time step 6247 (time=124.94), 0.236587 s/step
# on time step 6264 (time=125.28), 0.236537 s/step
# on time step 6281 (time=125.62), 0.235882 s/step
# on time step 6298 (time=125.96), 0.23599 s/step
# on time step 6315 (time=126.3), 0.237334 s/step
# on time step 6332 (time=126.64), 0.23594 s/step
# on time step 6349 (time=126.98), 0.23661 s/step
# on time step 6366 (time=127.32), 0.236085 s/step
# on time step 6383 (time=127.66), 0.235971 s/step
# on time step 6400 (time=128), 0.241789 s/step
# on time step 6417 (time=128.34), 0.239636 s/step
# on time step 6434 (time=128.68), 0.240038 s/step
# on time step 6451 (time=129.02), 0.240744 s/step
# on time step 6468 (time=129.36), 0.239923 s/step
# on time step 6485 (time=129.7), 0.236595 s/step
# on time step 6502 (time=130.04), 0.236294 s/step
# field decay(t = 130.24): 6.890864977163279e-05 / 0.023780022141168228 = 0.002897753810428015
# on time step 6519 (time=130.38), 0.235677 s/step
# on time step 6536 (time=130.72), 0.236052 s/step
# on time step 6553 (time=131.06), 0.236551 s/step
# on time step 6570 (time=131.4), 0.236071 s/step
# on time step 6587 (time=131.74), 0.236046 s/step
# on time step 6604 (time=132.08), 0.23654 s/step
# on time step 6621 (time=132.42), 0.236575 s/step
# on time step 6638 (time=132.76), 0.235598 s/step
# on time step 6655 (time=133.1), 0.237277 s/step
# on time step 6672 (time=133.44), 0.235913 s/step
# on time step 6689 (time=133.78), 0.236146 s/step
# on time step 6706 (time=134.12), 0.236567 s/step
# on time step 6723 (time=134.46), 0.236203 s/step
# on time step 6740 (time=134.8), 0.236256 s/step
# on time step 6757 (time=135.14), 0.236327 s/step
# on time step 6774 (time=135.48), 0.235966 s/step
# on time step 6791 (time=135.82), 0.236397 s/step
# on time step 6808 (time=136.16), 0.236311 s/step
# on time step 6825 (time=136.5), 0.235966 s/step
# on time step 6842 (time=136.84), 0.236529 s/step
# on time step 6859 (time=137.18), 0.236075 s/step
# on time step 6876 (time=137.52), 0.236493 s/step
# on time step 6893 (time=137.86), 0.23603 s/step
# on time step 6910 (time=138.2), 0.237024 s/step
# on time step 6927 (time=138.54), 0.235746 s/step
# on time step 6944 (time=138.88), 0.23614 s/step
# on time step 6961 (time=139.22), 0.237091 s/step
# on time step 6978 (time=139.56), 0.235371 s/step
# on time step 6995 (time=139.9), 0.236171 s/step
# on time step 7012 (time=140.24), 0.236274 s/step
# field decay(t = 140.26): 1.8306701527813438e-05 / 0.023780022141168228 = 0.0007698353441025894
# run 0 finished at t = 140.26 (7013 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00090003 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 42.1328% done, 5.49433 s remaining
# subpixel-averaging is 82.9707% done, 0.821143 s remaining
# subpixel-averaging is 41.8553% done, 5.55741 s remaining
# subpixel-averaging is 82.3001% done, 0.860418 s remaining
# subpixel-averaging is 42.0866% done, 5.50765 s remaining
# subpixel-averaging is 82.7625% done, 0.833423 s remaining
# time for set_epsilon = 52.4246 s
# -----------
# on time step 1 (time=0.02), 13.3337 s/step
# on time step 19 (time=0.38), 0.234568 s/step
# on time step 36 (time=0.72), 0.235415 s/step
# on time step 54 (time=1.08), 0.234362 s/step
# on time step 71 (time=1.42), 0.235767 s/step
# on time step 88 (time=1.76), 0.235956 s/step
# on time step 106 (time=2.12), 0.234765 s/step
# on time step 124 (time=2.48), 0.234521 s/step
# on time step 142 (time=2.84), 0.234709 s/step
# on time step 160 (time=3.2), 0.235001 s/step
# on time step 177 (time=3.54), 0.235834 s/step
# on time step 195 (time=3.9), 0.234005 s/step
# on time step 213 (time=4.26), 0.235177 s/step
# on time step 231 (time=4.62), 0.234678 s/step
# on time step 249 (time=4.98), 0.234965 s/step
# on time step 267 (time=5.34), 0.235206 s/step
# on time step 285 (time=5.7), 0.234695 s/step
# on time step 303 (time=6.06), 0.234931 s/step
# on time step 321 (time=6.42), 0.234329 s/step
# on time step 339 (time=6.78), 0.234687 s/step
# on time step 357 (time=7.14), 0.234739 s/step
# on time step 375 (time=7.5), 0.23453 s/step
# on time step 393 (time=7.86), 0.235017 s/step
# on time step 411 (time=8.22), 0.234348 s/step
# on time step 429 (time=8.58), 0.234329 s/step
# on time step 447 (time=8.94), 0.234963 s/step
# on time step 465 (time=9.3), 0.234367 s/step
# on time step 483 (time=9.66), 0.234946 s/step
# field decay(t = 10.02): 7.807378317576053e-10 / 7.807378317576053e-10 = 1.0
# on time step 501 (time=10.02), 0.234711 s/step
# on time step 519 (time=10.38), 0.234281 s/step
# on time step 537 (time=10.74), 0.234738 s/step
# on time step 555 (time=11.1), 0.234528 s/step
# on time step 572 (time=11.44), 0.235415 s/step
# on time step 590 (time=11.8), 0.234657 s/step
# on time step 608 (time=12.16), 0.234848 s/step
# on time step 626 (time=12.52), 0.234762 s/step
# on time step 644 (time=12.88), 0.234952 s/step
# on time step 661 (time=13.22), 0.235427 s/step
# on time step 679 (time=13.58), 0.234556 s/step
# on time step 697 (time=13.94), 0.234566 s/step
# on time step 716 (time=14.32), 0.210847 s/step
# on time step 737 (time=14.74), 0.196482 s/step
# on time step 757 (time=15.14), 0.200537 s/step
# on time step 778 (time=15.56), 0.196618 s/step
# on time step 798 (time=15.96), 0.202011 s/step
# on time step 819 (time=16.38), 0.19678 s/step
# on time step 837 (time=16.74), 0.230427 s/step
# on time step 855 (time=17.1), 0.234453 s/step
# on time step 873 (time=17.46), 0.235323 s/step
# on time step 891 (time=17.82), 0.234903 s/step
# on time step 908 (time=18.16), 0.23705 s/step
# on time step 925 (time=18.5), 0.23635 s/step
# on time step 942 (time=18.84), 0.235895 s/step
# on time step 959 (time=19.18), 0.235571 s/step
# on time step 977 (time=19.54), 0.234779 s/step
# on time step 995 (time=19.9), 0.234438 s/step
# field decay(t = 20.04): 4.838343451161703e-05 / 4.838343451161703e-05 = 1.0
# on time step 1012 (time=20.24), 0.235465 s/step
# on time step 1030 (time=20.6), 0.23436 s/step
# on time step 1048 (time=20.96), 0.235451 s/step
# on time step 1066 (time=21.32), 0.234831 s/step
# on time step 1084 (time=21.68), 0.234414 s/step
# on time step 1102 (time=22.04), 0.234886 s/step
# on time step 1120 (time=22.4), 0.234013 s/step
# on time step 1138 (time=22.76), 0.235302 s/step
# on time step 1156 (time=23.12), 0.234261 s/step
# on time step 1174 (time=23.48), 0.23402 s/step
# on time step 1191 (time=23.82), 0.235444 s/step
# on time step 1209 (time=24.18), 0.234216 s/step
# on time step 1227 (time=24.54), 0.235373 s/step
# on time step 1245 (time=24.9), 0.234078 s/step
# on time step 1263 (time=25.26), 0.234728 s/step
# on time step 1280 (time=25.6), 0.235354 s/step
# on time step 1298 (time=25.96), 0.228931 s/step
# on time step 1316 (time=26.32), 0.235012 s/step
# on time step 1334 (time=26.68), 0.234878 s/step
# on time step 1352 (time=27.04), 0.234238 s/step
# on time step 1370 (time=27.4), 0.234714 s/step
# on time step 1387 (time=27.74), 0.235671 s/step
# on time step 1404 (time=28.08), 0.238633 s/step
# on time step 1421 (time=28.42), 0.23867 s/step
# on time step 1438 (time=28.76), 0.238608 s/step
# on time step 1457 (time=29.14), 0.21304 s/step
# on time step 1478 (time=29.56), 0.198118 s/step
# on time step 1499 (time=29.98), 0.197684 s/step
# field decay(t = 30.060000000000002): 0.019118490245525466 / 0.019118490245525466 = 1.0
# on time step 1520 (time=30.4), 0.198724 s/step
# on time step 1541 (time=30.82), 0.197514 s/step
# on time step 1562 (time=31.24), 0.197677 s/step
# on time step 1583 (time=31.66), 0.198951 s/step
# on time step 1604 (time=32.08), 0.198528 s/step
# on time step 1625 (time=32.5), 0.199937 s/step
# on time step 1645 (time=32.9), 0.200387 s/step
# on time step 1666 (time=33.32), 0.196891 s/step
# on time step 1687 (time=33.74), 0.198356 s/step
# on time step 1708 (time=34.16), 0.197634 s/step
# on time step 1729 (time=34.58), 0.198795 s/step
# on time step 1750 (time=35), 0.199022 s/step
# on time step 1771 (time=35.42), 0.197257 s/step
# on time step 1792 (time=35.84), 0.198982 s/step
# on time step 1813 (time=36.26), 0.197654 s/step
# on time step 1834 (time=36.68), 0.197972 s/step
# on time step 1853 (time=37.06), 0.218007 s/step
# on time step 1871 (time=37.42), 0.23415 s/step
# on time step 1889 (time=37.78), 0.235352 s/step
# on time step 1907 (time=38.14), 0.235031 s/step
# on time step 1925 (time=38.5), 0.234919 s/step
# on time step 1943 (time=38.86), 0.234932 s/step
# on time step 1961 (time=39.22), 0.234774 s/step
# on time step 1978 (time=39.56), 0.235597 s/step
# on time step 1996 (time=39.92), 0.235172 s/step
# field decay(t = 40.06): 0.09767254040175773 / 0.09767254040175773 = 1.0
# on time step 2014 (time=40.28), 0.232548 s/step
# on time step 2034 (time=40.68), 0.205848 s/step
# on time step 2053 (time=41.06), 0.220638 s/step
# on time step 2071 (time=41.42), 0.230991 s/step
# on time step 2089 (time=41.78), 0.234772 s/step
# on time step 2106 (time=42.12), 0.23544 s/step
# on time step 2124 (time=42.48), 0.234871 s/step
# on time step 2142 (time=42.84), 0.234588 s/step
# on time step 2160 (time=43.2), 0.234918 s/step
# on time step 2178 (time=43.56), 0.234691 s/step
# on time step 2196 (time=43.92), 0.235297 s/step
# on time step 2213 (time=44.26), 0.235447 s/step
# on time step 2231 (time=44.62), 0.235017 s/step
# on time step 2249 (time=44.98), 0.234202 s/step
# on time step 2267 (time=45.34), 0.234872 s/step
# on time step 2285 (time=45.7), 0.234576 s/step
# on time step 2302 (time=46.04), 0.235661 s/step
# on time step 2320 (time=46.4), 0.23458 s/step
# on time step 2338 (time=46.76), 0.234603 s/step
# on time step 2356 (time=47.12), 0.234754 s/step
# on time step 2374 (time=47.48), 0.234391 s/step
# on time step 2392 (time=47.84), 0.234982 s/step
# on time step 2409 (time=48.18), 0.235747 s/step
# on time step 2427 (time=48.54), 0.234402 s/step
# on time step 2445 (time=48.9), 0.233951 s/step
# on time step 2463 (time=49.26), 0.233549 s/step
# on time step 2481 (time=49.62), 0.234483 s/step
# on time step 2499 (time=49.98), 0.233087 s/step
# field decay(t = 50.08): 0.09332578111985951 / 0.09767254040175773 = 0.9554966087293456
# on time step 2517 (time=50.34), 0.234082 s/step
# on time step 2535 (time=50.7), 0.233927 s/step
# on time step 2553 (time=51.06), 0.233249 s/step
# on time step 2571 (time=51.42), 0.23424 s/step
# on time step 2589 (time=51.78), 0.233543 s/step
# on time step 2607 (time=52.14), 0.233922 s/step
# on time step 2625 (time=52.5), 0.234114 s/step
# on time step 2643 (time=52.86), 0.232901 s/step
# on time step 2660 (time=53.2), 0.23754 s/step
# on time step 2678 (time=53.56), 0.2336 s/step
# on time step 2696 (time=53.92), 0.233693 s/step
# on time step 2714 (time=54.28), 0.23422 s/step
# on time step 2732 (time=54.64), 0.233326 s/step
# on time step 2750 (time=55), 0.234797 s/step
# on time step 2768 (time=55.36), 0.233321 s/step
# on time step 2786 (time=55.72), 0.234246 s/step
# on time step 2804 (time=56.08), 0.234246 s/step
# on time step 2822 (time=56.44), 0.234294 s/step
# on time step 2840 (time=56.8), 0.233996 s/step
# on time step 2858 (time=57.16), 0.233238 s/step
# on time step 2876 (time=57.52), 0.233685 s/step
# on time step 2894 (time=57.88), 0.233758 s/step
# on time step 2911 (time=58.22), 0.240436 s/step
# on time step 2928 (time=58.56), 0.236061 s/step
# on time step 2946 (time=58.92), 0.233859 s/step
# on time step 2964 (time=59.28), 0.234093 s/step
# on time step 2982 (time=59.64), 0.234524 s/step
# on time step 3000 (time=60), 0.23452 s/step
# field decay(t = 60.1): 0.01592932387522496 / 0.09767254040175773 = 0.16308907098865932
# on time step 3018 (time=60.36), 0.233797 s/step
# on time step 3036 (time=60.72), 0.233793 s/step
# on time step 3054 (time=61.08), 0.231766 s/step
# on time step 3072 (time=61.44), 0.233326 s/step
# on time step 3090 (time=61.8), 0.233909 s/step
# on time step 3108 (time=62.16), 0.234077 s/step
# on time step 3126 (time=62.52), 0.233946 s/step
# on time step 3144 (time=62.88), 0.233086 s/step
# on time step 3162 (time=63.24), 0.234056 s/step
# on time step 3180 (time=63.6), 0.234028 s/step
# on time step 3198 (time=63.96), 0.233283 s/step
# on time step 3216 (time=64.32), 0.233857 s/step
# on time step 3234 (time=64.68), 0.233128 s/step
# on time step 3252 (time=65.04), 0.234151 s/step
# on time step 3270 (time=65.4), 0.233095 s/step
# on time step 3288 (time=65.76), 0.23449 s/step
# on time step 3306 (time=66.12), 0.233098 s/step
# on time step 3324 (time=66.48), 0.234221 s/step
# on time step 3341 (time=66.82), 0.239215 s/step
# on time step 3358 (time=67.16), 0.238767 s/step
# on time step 3375 (time=67.5), 0.238754 s/step
# on time step 3392 (time=67.84), 0.23818 s/step
# on time step 3409 (time=68.18), 0.238929 s/step
# on time step 3426 (time=68.52), 0.239193 s/step
# on time step 3443 (time=68.86), 0.238679 s/step
# on time step 3460 (time=69.2), 0.238739 s/step
# on time step 3477 (time=69.54), 0.238582 s/step
# on time step 3494 (time=69.88), 0.238235 s/step
# field decay(t = 70.12): 0.0027764458031116386 / 0.09767254040175773 = 0.02842606316669197
# on time step 3511 (time=70.22), 0.23906 s/step
# on time step 3528 (time=70.56), 0.23921 s/step
# on time step 3545 (time=70.9), 0.238621 s/step
# on time step 3562 (time=71.24), 0.238443 s/step
# on time step 3579 (time=71.58), 0.239615 s/step
# on time step 3596 (time=71.92), 0.238988 s/step
# on time step 3613 (time=72.26), 0.238661 s/step
# on time step 3630 (time=72.6), 0.239188 s/step
# on time step 3647 (time=72.94), 0.237774 s/step
# on time step 3664 (time=73.28), 0.238609 s/step
# on time step 3681 (time=73.62), 0.239691 s/step
# on time step 3698 (time=73.96), 0.238025 s/step
# on time step 3715 (time=74.3), 0.23937 s/step
# on time step 3732 (time=74.64), 0.239058 s/step
# on time step 3749 (time=74.98), 0.238265 s/step
# on time step 3766 (time=75.32), 0.239576 s/step
# on time step 3783 (time=75.66), 0.238563 s/step
# on time step 3800 (time=76), 0.238446 s/step
# on time step 3817 (time=76.34), 0.239387 s/step
# on time step 3834 (time=76.68), 0.238104 s/step
# on time step 3851 (time=77.02), 0.238743 s/step
# on time step 3868 (time=77.36), 0.2386 s/step
# on time step 3885 (time=77.7), 0.238627 s/step
# on time step 3902 (time=78.04), 0.238268 s/step
# on time step 3919 (time=78.38), 0.238476 s/step
# on time step 3936 (time=78.72), 0.238525 s/step
# on time step 3953 (time=79.06), 0.239271 s/step
# on time step 3970 (time=79.4), 0.23946 s/step
# on time step 3987 (time=79.74), 0.237746 s/step
# on time step 4004 (time=80.08), 0.238307 s/step
# field decay(t = 80.14): 0.0012910889801030574 / 0.09767254040175773 = 0.013218546121483115
# on time step 4021 (time=80.42), 0.238673 s/step
# on time step 4038 (time=80.76), 0.238836 s/step
# on time step 4055 (time=81.1), 0.239642 s/step
# on time step 4072 (time=81.44), 0.237061 s/step
# on time step 4089 (time=81.78), 0.236278 s/step
# on time step 4106 (time=82.12), 0.238529 s/step
# on time step 4123 (time=82.46), 0.237645 s/step
# on time step 4140 (time=82.8), 0.238407 s/step
# on time step 4157 (time=83.14), 0.238785 s/step
# on time step 4174 (time=83.48), 0.237564 s/step
# on time step 4191 (time=83.82), 0.239651 s/step
# on time step 4208 (time=84.16), 0.238698 s/step
# on time step 4225 (time=84.5), 0.237123 s/step
# on time step 4242 (time=84.84), 0.238279 s/step
# on time step 4259 (time=85.18), 0.239058 s/step
# on time step 4276 (time=85.52), 0.238619 s/step
# on time step 4293 (time=85.86), 0.238977 s/step
# on time step 4310 (time=86.2), 0.239437 s/step
# on time step 4327 (time=86.54), 0.235553 s/step
# on time step 4345 (time=86.9), 0.234733 s/step
# on time step 4363 (time=87.26), 0.23443 s/step
# on time step 4381 (time=87.62), 0.234641 s/step
# on time step 4399 (time=87.98), 0.234494 s/step
# on time step 4417 (time=88.34), 0.234021 s/step
# on time step 4435 (time=88.7), 0.234993 s/step
# on time step 4453 (time=89.06), 0.226074 s/step
# on time step 4471 (time=89.42), 0.232393 s/step
# on time step 4489 (time=89.78), 0.232463 s/step
# on time step 4506 (time=90.12), 0.24055 s/step
# field decay(t = 90.16): 0.00013542509455362933 / 0.09767254040175773 = 0.0013865216773986172
# on time step 4520 (time=90.4), 0.301213 s/step
# on time step 4538 (time=90.76), 0.234761 s/step
# on time step 4555 (time=91.1), 0.246235 s/step
# on time step 4573 (time=91.46), 0.234174 s/step
# on time step 4591 (time=91.82), 0.230155 s/step
# on time step 4609 (time=92.18), 0.232079 s/step
# on time step 4627 (time=92.54), 0.233379 s/step
# on time step 4645 (time=92.9), 0.23089 s/step
# on time step 4663 (time=93.26), 0.231534 s/step
# on time step 4681 (time=93.62), 0.23106 s/step
# on time step 4699 (time=93.98), 0.230929 s/step
# on time step 4717 (time=94.34), 0.231873 s/step
# on time step 4735 (time=94.7), 0.232278 s/step
# on time step 4753 (time=95.06), 0.233235 s/step
# on time step 4771 (time=95.42), 0.232061 s/step
# on time step 4789 (time=95.78), 0.232946 s/step
# on time step 4807 (time=96.14), 0.233482 s/step
# on time step 4825 (time=96.5), 0.232358 s/step
# on time step 4843 (time=96.86), 0.232378 s/step
# on time step 4861 (time=97.22), 0.232441 s/step
# on time step 4879 (time=97.58), 0.232707 s/step
# on time step 4896 (time=97.92), 0.242266 s/step
# on time step 4912 (time=98.24), 0.254644 s/step
# on time step 4931 (time=98.62), 0.221128 s/step
# on time step 4951 (time=99.02), 0.208603 s/step
# on time step 4970 (time=99.4), 0.221828 s/step
# on time step 4987 (time=99.74), 0.23636 s/step
# on time step 5003 (time=100.06), 0.25554 s/step
# field decay(t = 100.18): 0.00012939531296163258 / 0.09767254040175773 = 0.001324787012085374
# on time step 5019 (time=100.38), 0.265785 s/step
# on time step 5034 (time=100.68), 0.266743 s/step
# on time step 5050 (time=101), 0.266075 s/step
# on time step 5066 (time=101.32), 0.265939 s/step
# on time step 5082 (time=101.64), 0.265501 s/step
# on time step 5098 (time=101.96), 0.265676 s/step
# on time step 5114 (time=102.28), 0.266093 s/step
# on time step 5130 (time=102.6), 0.265656 s/step
# on time step 5146 (time=102.92), 0.265801 s/step
# on time step 5162 (time=103.24), 0.266043 s/step
# on time step 5178 (time=103.56), 0.266625 s/step
# on time step 5194 (time=103.88), 0.265801 s/step
# on time step 5210 (time=104.2), 0.26635 s/step
# on time step 5226 (time=104.52), 0.265824 s/step
# on time step 5241 (time=104.82), 0.268806 s/step
# on time step 5257 (time=105.14), 0.266346 s/step
# on time step 5273 (time=105.46), 0.265948 s/step
# on time step 5289 (time=105.78), 0.266236 s/step
# on time step 5305 (time=106.1), 0.265744 s/step
# on time step 5318 (time=106.36), 0.330947 s/step
# on time step 5336 (time=106.72), 0.248664 s/step
# on time step 5344 (time=106.88), 0.53486 s/step
# on time step 5351 (time=107.02), 0.616509 s/step
# on time step 5357 (time=107.14), 0.773942 s/step
# on time step 5363 (time=107.26), 0.734451 s/step
# on time step 5368 (time=107.36), 0.807764 s/step
# on time step 5374 (time=107.48), 0.764231 s/step
# on time step 5380 (time=107.6), 0.746347 s/step
# on time step 5386 (time=107.72), 0.75806 s/step
# on time step 5392 (time=107.84), 0.746347 s/step
# on time step 5398 (time=107.96), 0.734644 s/step
# on time step 5405 (time=108.1), 0.573339 s/step
# on time step 5412 (time=108.24), 0.58888 s/step
# on time step 5417 (time=108.34), 0.838732 s/step
# on time step 5422 (time=108.44), 0.941519 s/step
# on time step 5427 (time=108.54), 0.816951 s/step
# on time step 5432 (time=108.64), 0.975979 s/step
# on time step 5437 (time=108.74), 0.975514 s/step
# on time step 5443 (time=108.86), 0.748323 s/step
# on time step 5449 (time=108.98), 0.733509 s/step
# on time step 5455 (time=109.1), 0.742765 s/step
# on time step 5460 (time=109.2), 0.831203 s/step
# on time step 5465 (time=109.3), 0.926192 s/step
# on time step 5473 (time=109.46), 0.612601 s/step
# on time step 5478 (time=109.56), 0.976674 s/step
# on time step 5483 (time=109.66), 0.892405 s/step
# on time step 5488 (time=109.76), 0.824098 s/step
# on time step 5493 (time=109.86), 0.850964 s/step
# on time step 5499 (time=109.98), 0.741861 s/step
# on time step 5504 (time=110.08), 0.807176 s/step
# field decay(t = 110.2): 9.611693911795296e-05 / 0.09767254040175773 = 0.000984073299645877
# run 0 finished at t = 110.2 (5510 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000968933 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 44.2371% done, 5.04456 s remaining
# subpixel-averaging is 87.3874% done, 0.577646 s remaining
# subpixel-averaging is 43.8209% done, 5.12986 s remaining
# subpixel-averaging is 86.4856% done, 0.625193 s remaining
# subpixel-averaging is 44.1215% done, 5.06737 s remaining
# subpixel-averaging is 87.0868% done, 0.593298 s remaining
# time for set_epsilon = 49.11 s
# -----------
# on time step 1 (time=0.02), 13.0879 s/step
# on time step 6 (time=0.12), 0.83774 s/step
# on time step 11 (time=0.22), 0.848017 s/step
# on time step 16 (time=0.32), 0.828575 s/step
# on time step 21 (time=0.42), 0.848403 s/step
# on time step 26 (time=0.52), 0.836254 s/step
# on time step 31 (time=0.62), 0.86303 s/step
# on time step 36 (time=0.72), 0.874362 s/step
# on time step 41 (time=0.82), 0.863027 s/step
# on time step 46 (time=0.92), 0.848094 s/step
# on time step 51 (time=1.02), 0.858041 s/step
# on time step 56 (time=1.12), 0.899033 s/step
# on time step 62 (time=1.24), 0.847751 s/step
# on time step 66 (time=1.32), 1.16146 s/step
# on time step 71 (time=1.42), 0.977911 s/step
# on time step 76 (time=1.52), 0.901381 s/step
# on time step 81 (time=1.62), 0.839689 s/step
# on time step 86 (time=1.72), 0.831822 s/step
# on time step 92 (time=1.84), 0.729347 s/step
# on time step 97 (time=1.94), 0.866048 s/step
# on time step 102 (time=2.04), 0.965578 s/step
# on time step 107 (time=2.14), 0.949785 s/step
# on time step 112 (time=2.24), 0.919807 s/step
# on time step 117 (time=2.34), 0.917914 s/step
# on time step 122 (time=2.44), 0.917245 s/step
# on time step 127 (time=2.54), 0.953663 s/step
# on time step 132 (time=2.64), 0.986044 s/step
# on time step 137 (time=2.74), 0.961719 s/step
# on time step 142 (time=2.84), 0.894424 s/step
# on time step 147 (time=2.94), 0.809299 s/step
# on time step 152 (time=3.04), 0.857084 s/step
# on time step 158 (time=3.16), 0.794391 s/step
# on time step 163 (time=3.26), 0.913213 s/step
# on time step 168 (time=3.36), 0.868004 s/step
# on time step 173 (time=3.46), 0.841881 s/step
# on time step 178 (time=3.56), 0.904908 s/step
# on time step 184 (time=3.68), 0.707536 s/step
# on time step 189 (time=3.78), 0.858742 s/step
# on time step 194 (time=3.88), 0.864419 s/step
# on time step 199 (time=3.98), 0.862963 s/step
# on time step 204 (time=4.08), 0.84483 s/step
# on time step 209 (time=4.18), 0.81991 s/step
# on time step 215 (time=4.3), 0.690985 s/step
# on time step 221 (time=4.42), 0.730689 s/step
# on time step 227 (time=4.54), 0.687517 s/step
# on time step 232 (time=4.64), 0.838257 s/step
# on time step 238 (time=4.76), 0.766647 s/step
# on time step 244 (time=4.88), 0.724228 s/step
# on time step 250 (time=5), 0.742432 s/step
# on time step 256 (time=5.12), 0.733222 s/step
# on time step 262 (time=5.24), 0.695491 s/step
# on time step 267 (time=5.34), 0.813056 s/step
# on time step 272 (time=5.44), 0.822308 s/step
# on time step 277 (time=5.54), 0.888969 s/step
# on time step 282 (time=5.64), 0.897178 s/step
# on time step 287 (time=5.74), 0.88277 s/step
# on time step 293 (time=5.86), 0.741531 s/step
# on time step 299 (time=5.98), 0.767409 s/step
# on time step 304 (time=6.08), 0.859865 s/step
# on time step 309 (time=6.18), 0.97857 s/step
# on time step 314 (time=6.28), 0.958571 s/step
# on time step 318 (time=6.36), 1.08582 s/step
# on time step 322 (time=6.44), 1.00402 s/step
# on time step 327 (time=6.54), 0.912021 s/step
# on time step 332 (time=6.64), 0.83674 s/step
# on time step 337 (time=6.74), 0.877485 s/step
# on time step 342 (time=6.84), 0.902238 s/step
# on time step 347 (time=6.94), 0.871154 s/step
# on time step 352 (time=7.04), 0.902182 s/step
# on time step 357 (time=7.14), 0.897584 s/step
# on time step 362 (time=7.24), 0.879699 s/step
# on time step 367 (time=7.34), 0.906051 s/step
# on time step 372 (time=7.44), 0.916688 s/step
# on time step 377 (time=7.54), 0.957526 s/step
# on time step 382 (time=7.64), 0.967322 s/step
# on time step 387 (time=7.74), 0.966811 s/step
# on time step 392 (time=7.84), 0.938443 s/step
# on time step 398 (time=7.96), 0.802188 s/step
# on time step 403 (time=8.06), 0.811862 s/step
# on time step 408 (time=8.16), 0.815625 s/step
# on time step 413 (time=8.26), 0.826943 s/step
# on time step 419 (time=8.38), 0.792267 s/step
# on time step 425 (time=8.5), 0.767845 s/step
# on time step 431 (time=8.62), 0.716105 s/step
# on time step 437 (time=8.74), 0.770835 s/step
# on time step 443 (time=8.86), 0.764914 s/step
# on time step 449 (time=8.98), 0.753138 s/step
# on time step 455 (time=9.1), 0.723708 s/step
# on time step 463 (time=9.26), 0.569016 s/step
# on time step 468 (time=9.36), 0.882401 s/step
# on time step 474 (time=9.48), 0.717884 s/step
# on time step 480 (time=9.6), 0.782327 s/step
# on time step 486 (time=9.72), 0.777011 s/step
# on time step 493 (time=9.86), 0.598661 s/step
# on time step 500 (time=10), 0.580268 s/step
# field decay(t = 10.02): 2.4498687895519234e-09 / 2.4498687895519234e-09 = 1.0
# on time step 506 (time=10.12), 0.71492 s/step
# on time step 511 (time=10.22), 0.93196 s/step
# on time step 516 (time=10.32), 0.806425 s/step
# on time step 523 (time=10.46), 0.645926 s/step
# on time step 529 (time=10.58), 0.768012 s/step
# on time step 535 (time=10.7), 0.710584 s/step
# on time step 542 (time=10.84), 0.585514 s/step
# on time step 548 (time=10.96), 0.792063 s/step
# on time step 554 (time=11.08), 0.709893 s/step
# on time step 559 (time=11.18), 0.915938 s/step
# on time step 565 (time=11.3), 0.752269 s/step
# on time step 570 (time=11.4), 0.879912 s/step
# on time step 576 (time=11.52), 0.787453 s/step
# on time step 583 (time=11.66), 0.600861 s/step
# on time step 589 (time=11.78), 0.738716 s/step
# on time step 594 (time=11.88), 0.934134 s/step
# on time step 599 (time=11.98), 0.952293 s/step
# on time step 604 (time=12.08), 0.986519 s/step
# on time step 608 (time=12.16), 1.01693 s/step
# on time step 612 (time=12.24), 1.03109 s/step
# on time step 616 (time=12.32), 1.03379 s/step
# on time step 620 (time=12.4), 1.02439 s/step
# on time step 625 (time=12.5), 0.945968 s/step
# on time step 630 (time=12.6), 0.82846 s/step
# on time step 636 (time=12.72), 0.812717 s/step
# on time step 641 (time=12.82), 0.915108 s/step
# on time step 646 (time=12.92), 0.924791 s/step
# on time step 651 (time=13.02), 0.921039 s/step
# on time step 656 (time=13.12), 0.894348 s/step
# on time step 661 (time=13.22), 0.807383 s/step
# on time step 666 (time=13.32), 0.867973 s/step
# on time step 670 (time=13.4), 1.02097 s/step
# on time step 675 (time=13.5), 0.949 s/step
# on time step 680 (time=13.6), 0.93312 s/step
# on time step 684 (time=13.68), 1.03571 s/step
# on time step 690 (time=13.8), 0.744838 s/step
# on time step 696 (time=13.92), 0.762679 s/step
# on time step 702 (time=14.04), 0.820978 s/step
# on time step 707 (time=14.14), 0.925191 s/step
# on time step 712 (time=14.24), 0.809436 s/step
# on time step 719 (time=14.38), 0.635141 s/step
# on time step 725 (time=14.5), 0.679503 s/step
# on time step 730 (time=14.6), 0.860315 s/step
# on time step 735 (time=14.7), 0.874802 s/step
# on time step 740 (time=14.8), 0.869096 s/step
# on time step 745 (time=14.9), 0.873064 s/step
# on time step 750 (time=15), 0.829754 s/step
# on time step 755 (time=15.1), 0.931042 s/step
# on time step 760 (time=15.2), 0.930185 s/step
# on time step 765 (time=15.3), 0.9234 s/step
# on time step 770 (time=15.4), 0.823893 s/step
# on time step 775 (time=15.5), 0.93329 s/step
# on time step 782 (time=15.64), 0.644776 s/step
# on time step 787 (time=15.74), 0.862747 s/step
# on time step 793 (time=15.86), 0.683803 s/step
# on time step 799 (time=15.98), 0.722605 s/step
# on time step 802 (time=16.04), 1.3557 s/step
# on time step 805 (time=16.1), 1.45115 s/step
# on time step 810 (time=16.2), 0.984259 s/step
# on time step 813 (time=16.26), 1.36377 s/step
# on time step 816 (time=16.32), 1.34988 s/step
# on time step 820 (time=16.4), 1.33325 s/step
# on time step 823 (time=16.46), 1.33958 s/step
# on time step 826 (time=16.52), 1.33723 s/step
# on time step 829 (time=16.58), 1.39721 s/step
# on time step 832 (time=16.64), 1.37665 s/step
# on time step 836 (time=16.72), 1.31932 s/step
# on time step 840 (time=16.8), 1.33466 s/step
# on time step 843 (time=16.86), 1.3863 s/step
# on time step 846 (time=16.92), 1.38103 s/step
# on time step 849 (time=16.98), 1.54363 s/step
# on time step 852 (time=17.04), 1.48866 s/step
# on time step 855 (time=17.1), 1.49584 s/step
# on time step 858 (time=17.16), 1.33761 s/step
# on time step 862 (time=17.24), 1.09179 s/step
# on time step 865 (time=17.3), 1.37762 s/step
# on time step 868 (time=17.36), 1.37593 s/step
# on time step 871 (time=17.42), 1.48655 s/step
# on time step 874 (time=17.48), 1.4817 s/step
# on time step 877 (time=17.54), 1.38683 s/step
# on time step 880 (time=17.6), 1.39141 s/step
# on time step 883 (time=17.66), 1.40643 s/step
# on time step 886 (time=17.72), 1.37612 s/step
# on time step 889 (time=17.78), 1.39113 s/step
# on time step 892 (time=17.84), 1.38808 s/step
# on time step 895 (time=17.9), 1.38826 s/step
# on time step 898 (time=17.96), 1.3986 s/step
# on time step 901 (time=18.02), 1.40562 s/step
# on time step 904 (time=18.08), 1.40329 s/step
# on time step 907 (time=18.14), 1.41185 s/step
# on time step 910 (time=18.2), 1.37001 s/step
# on time step 913 (time=18.26), 1.38974 s/step
# on time step 916 (time=18.32), 1.39123 s/step
# on time step 919 (time=18.38), 1.38078 s/step
# on time step 922 (time=18.44), 1.39467 s/step
# on time step 925 (time=18.5), 1.37664 s/step
# on time step 929 (time=18.58), 1.11936 s/step
# on time step 932 (time=18.64), 1.38003 s/step
# on time step 936 (time=18.72), 1.28857 s/step
# on time step 939 (time=18.78), 1.35818 s/step
# on time step 942 (time=18.84), 1.41516 s/step
# on time step 945 (time=18.9), 1.41291 s/step
# on time step 948 (time=18.96), 1.38175 s/step
# on time step 951 (time=19.02), 1.553 s/step
# on time step 955 (time=19.1), 1.17022 s/step
# on time step 959 (time=19.18), 1.33903 s/step
# on time step 963 (time=19.26), 1.32985 s/step
# on time step 966 (time=19.32), 1.3708 s/step
# on time step 969 (time=19.38), 1.41653 s/step
# on time step 972 (time=19.44), 1.40667 s/step
# on time step 975 (time=19.5), 1.40312 s/step
# on time step 979 (time=19.58), 1.23299 s/step
# on time step 984 (time=19.68), 0.986933 s/step
# on time step 988 (time=19.76), 1.10779 s/step
# on time step 991 (time=19.82), 1.44302 s/step
# on time step 995 (time=19.9), 1.17152 s/step
# on time step 999 (time=19.98), 1.20769 s/step
# field decay(t = 20.04): 0.00013672593126188228 / 0.00013672593126188228 = 1.0
# on time step 1003 (time=20.06), 1.22654 s/step
# on time step 1007 (time=20.14), 1.2011 s/step
# on time step 1010 (time=20.2), 1.59771 s/step
# on time step 1014 (time=20.28), 1.31696 s/step
# on time step 1017 (time=20.34), 1.47782 s/step
# on time step 1020 (time=20.4), 1.38614 s/step
# on time step 1023 (time=20.46), 1.47985 s/step
# on time step 1026 (time=20.52), 1.39415 s/step
# on time step 1029 (time=20.58), 1.52869 s/step
# on time step 1032 (time=20.64), 1.53011 s/step
# on time step 1035 (time=20.7), 1.46781 s/step
# on time step 1038 (time=20.76), 1.36607 s/step
# on time step 1041 (time=20.82), 1.50144 s/step
# on time step 1044 (time=20.88), 1.54769 s/step
# on time step 1047 (time=20.94), 1.35219 s/step
# on time step 1051 (time=21.02), 1.33025 s/step
# on time step 1054 (time=21.08), 1.57212 s/step
# on time step 1057 (time=21.14), 1.50758 s/step
# on time step 1061 (time=21.22), 1.37366 s/step
# on time step 1064 (time=21.28), 1.52661 s/step
# on time step 1067 (time=21.34), 1.50457 s/step
# on time step 1070 (time=21.4), 1.5702 s/step
# on time step 1073 (time=21.46), 1.52398 s/step
# on time step 1076 (time=21.52), 1.44815 s/step
# on time step 1079 (time=21.58), 1.45812 s/step
# on time step 1082 (time=21.64), 1.38754 s/step
# on time step 1086 (time=21.72), 1.26262 s/step
# on time step 1089 (time=21.78), 1.35155 s/step
# on time step 1092 (time=21.84), 1.35828 s/step
# on time step 1095 (time=21.9), 1.48311 s/step
# on time step 1098 (time=21.96), 1.38665 s/step
# on time step 1101 (time=22.02), 1.53741 s/step
# on time step 1105 (time=22.1), 1.1484 s/step
# on time step 1108 (time=22.16), 1.55276 s/step
# on time step 1111 (time=22.22), 1.56339 s/step
# on time step 1114 (time=22.28), 1.53979 s/step
# on time step 1117 (time=22.34), 1.57481 s/step
# on time step 1120 (time=22.4), 1.55023 s/step
# on time step 1123 (time=22.46), 1.39341 s/step
# on time step 1126 (time=22.52), 1.36668 s/step
# on time step 1130 (time=22.6), 1.11928 s/step
# on time step 1134 (time=22.68), 1.20279 s/step
# on time step 1138 (time=22.76), 1.0607 s/step
# on time step 1142 (time=22.84), 1.15947 s/step
# on time step 1145 (time=22.9), 1.54519 s/step
# on time step 1148 (time=22.96), 1.38643 s/step
# on time step 1151 (time=23.02), 1.36294 s/step
# on time step 1155 (time=23.1), 1.19411 s/step
# on time step 1158 (time=23.16), 1.36143 s/step
# on time step 1161 (time=23.22), 1.44107 s/step
# on time step 1164 (time=23.28), 1.51221 s/step
# on time step 1168 (time=23.36), 1.24758 s/step
# on time step 1173 (time=23.46), 0.930642 s/step
# on time step 1177 (time=23.54), 1.00183 s/step
# on time step 1181 (time=23.62), 1.25869 s/step
# on time step 1184 (time=23.68), 1.40049 s/step
# on time step 1187 (time=23.74), 1.37733 s/step
# on time step 1190 (time=23.8), 1.40845 s/step
# on time step 1193 (time=23.86), 1.46055 s/step
# on time step 1196 (time=23.92), 1.43411 s/step
# on time step 1199 (time=23.98), 1.4492 s/step
# on time step 1202 (time=24.04), 1.42619 s/step
# on time step 1205 (time=24.1), 1.46494 s/step
# on time step 1208 (time=24.16), 1.46604 s/step
# on time step 1211 (time=24.22), 1.49519 s/step
# on time step 1215 (time=24.3), 1.11104 s/step
# on time step 1219 (time=24.38), 1.23201 s/step
# on time step 1223 (time=24.46), 1.19908 s/step
# on time step 1226 (time=24.52), 1.60687 s/step
# on time step 1229 (time=24.58), 1.49213 s/step
# on time step 1233 (time=24.66), 1.21958 s/step
# on time step 1237 (time=24.74), 1.22427 s/step
# on time step 1240 (time=24.8), 1.33379 s/step
# on time step 1243 (time=24.86), 1.359 s/step
# on time step 1247 (time=24.94), 1.32015 s/step
# on time step 1251 (time=25.02), 1.1529 s/step
# on time step 1256 (time=25.12), 1.01448 s/step
# on time step 1260 (time=25.2), 1.10851 s/step
# on time step 1263 (time=25.26), 1.49646 s/step
# on time step 1266 (time=25.32), 1.335 s/step
# on time step 1269 (time=25.38), 1.38645 s/step
# on time step 1272 (time=25.44), 1.46457 s/step
# on time step 1275 (time=25.5), 1.50922 s/step
# on time step 1279 (time=25.58), 1.2462 s/step
# on time step 1283 (time=25.66), 1.15683 s/step
# on time step 1287 (time=25.74), 1.11083 s/step
# on time step 1291 (time=25.82), 1.08495 s/step
# on time step 1295 (time=25.9), 1.1331 s/step
# on time step 1299 (time=25.98), 1.2575 s/step
# on time step 1302 (time=26.04), 1.39251 s/step
# on time step 1305 (time=26.1), 1.41563 s/step
# on time step 1309 (time=26.18), 1.08741 s/step
# on time step 1314 (time=26.28), 0.949466 s/step
# on time step 1318 (time=26.36), 1.27385 s/step
# on time step 1321 (time=26.42), 1.4367 s/step
# on time step 1324 (time=26.48), 1.47898 s/step
# on time step 1327 (time=26.54), 1.47448 s/step
# on time step 1330 (time=26.6), 1.522 s/step
# on time step 1333 (time=26.66), 1.51247 s/step
# on time step 1336 (time=26.72), 1.43059 s/step
# on time step 1339 (time=26.78), 1.49912 s/step
# on time step 1342 (time=26.84), 1.50389 s/step
# on time step 1346 (time=26.92), 1.27478 s/step
# on time step 1349 (time=26.98), 1.34685 s/step
# on time step 1353 (time=27.06), 1.34502 s/step
# on time step 1356 (time=27.12), 1.50879 s/step
# on time step 1359 (time=27.18), 1.58956 s/step
# on time step 1362 (time=27.24), 1.57333 s/step
# on time step 1365 (time=27.3), 1.50397 s/step
# on time step 1368 (time=27.36), 1.54503 s/step
# on time step 1372 (time=27.44), 1.24339 s/step
# on time step 1375 (time=27.5), 1.33654 s/step
# on time step 1379 (time=27.58), 1.33819 s/step
# on time step 1383 (time=27.66), 1.18753 s/step
# on time step 1386 (time=27.72), 1.42098 s/step
# on time step 1389 (time=27.78), 1.45204 s/step
# on time step 1392 (time=27.84), 1.46826 s/step
# on time step 1396 (time=27.92), 1.25492 s/step
# on time step 1399 (time=27.98), 1.5118 s/step
# on time step 1402 (time=28.04), 1.5281 s/step
# on time step 1405 (time=28.1), 1.49036 s/step
# on time step 1408 (time=28.16), 1.48419 s/step
# on time step 1411 (time=28.22), 1.49802 s/step
# on time step 1415 (time=28.3), 1.08947 s/step
# on time step 1419 (time=28.38), 1.20365 s/step
# on time step 1423 (time=28.46), 1.19072 s/step
# on time step 1426 (time=28.52), 1.6087 s/step
# on time step 1430 (time=28.6), 1.09645 s/step
# on time step 1433 (time=28.66), 1.52135 s/step
# on time step 1436 (time=28.72), 1.5041 s/step
# on time step 1439 (time=28.78), 1.50864 s/step
# on time step 1442 (time=28.84), 1.55583 s/step
# on time step 1445 (time=28.9), 1.46899 s/step
# on time step 1448 (time=28.96), 1.44552 s/step
# on time step 1451 (time=29.02), 1.47525 s/step
# on time step 1454 (time=29.08), 1.59375 s/step
# on time step 1457 (time=29.14), 1.54194 s/step
# on time step 1460 (time=29.2), 1.65822 s/step
# on time step 1463 (time=29.26), 1.52501 s/step
# on time step 1466 (time=29.32), 1.44841 s/step
# on time step 1470 (time=29.4), 1.22116 s/step
# on time step 1474 (time=29.48), 1.33979 s/step
# on time step 1477 (time=29.54), 1.3925 s/step
# on time step 1480 (time=29.6), 1.59014 s/step
# on time step 1483 (time=29.66), 1.5922 s/step
# on time step 1486 (time=29.72), 1.35016 s/step
# on time step 1490 (time=29.8), 1.20106 s/step
# on time step 1494 (time=29.88), 1.05383 s/step
# on time step 1498 (time=29.96), 1.06854 s/step
# on time step 1502 (time=30.04), 1.08357 s/step
# field decay(t = 30.060000000000002): 0.056212589417844815 / 0.056212589417844815 = 1.0
# on time step 1506 (time=30.12), 1.2835 s/step
# on time step 1510 (time=30.2), 1.21289 s/step
# on time step 1514 (time=30.28), 1.23483 s/step
# on time step 1518 (time=30.36), 1.01623 s/step
# on time step 1521 (time=30.42), 1.4088 s/step
# on time step 1525 (time=30.5), 1.19441 s/step
# on time step 1528 (time=30.56), 1.51628 s/step
# on time step 1531 (time=30.62), 1.57555 s/step
# on time step 1535 (time=30.7), 1.26456 s/step
# on time step 1538 (time=30.76), 1.44734 s/step
# on time step 1542 (time=30.84), 1.16851 s/step
# on time step 1546 (time=30.92), 1.27231 s/step
# on time step 1550 (time=31), 1.03599 s/step
# on time step 1553 (time=31.06), 1.53562 s/step
# on time step 1557 (time=31.14), 1.32176 s/step
# on time step 1561 (time=31.22), 1.09205 s/step
# on time step 1565 (time=31.3), 1.12946 s/step
# on time step 1568 (time=31.36), 1.35507 s/step
# on time step 1572 (time=31.44), 1.09606 s/step
# on time step 1575 (time=31.5), 1.47313 s/step
# on time step 1578 (time=31.56), 1.36791 s/step
# on time step 1581 (time=31.62), 1.44446 s/step
# on time step 1584 (time=31.68), 1.46197 s/step
# on time step 1588 (time=31.76), 1.14114 s/step
# on time step 1591 (time=31.82), 1.34729 s/step
# on time step 1594 (time=31.88), 1.53006 s/step
# on time step 1597 (time=31.94), 1.55049 s/step
# on time step 1600 (time=32), 1.58001 s/step
# on time step 1603 (time=32.06), 1.54845 s/step
# on time step 1606 (time=32.12), 1.53245 s/step
# on time step 1610 (time=32.2), 1.01375 s/step
# on time step 1614 (time=32.28), 1.08772 s/step
# on time step 1618 (time=32.36), 1.10715 s/step
# on time step 1622 (time=32.44), 1.14239 s/step
# on time step 1625 (time=32.5), 1.59481 s/step
# on time step 1629 (time=32.58), 1.22186 s/step
# on time step 1633 (time=32.66), 1.27003 s/step
# on time step 1636 (time=32.72), 1.49908 s/step
# on time step 1639 (time=32.78), 1.54716 s/step
# on time step 1643 (time=32.86), 1.0906 s/step
# on time step 1647 (time=32.94), 1.22651 s/step
# on time step 1651 (time=33.02), 1.24582 s/step
# on time step 1654 (time=33.08), 1.53134 s/step
# on time step 1657 (time=33.14), 1.55673 s/step
# on time step 1661 (time=33.22), 1.25149 s/step
# on time step 1665 (time=33.3), 1.31885 s/step
# on time step 1669 (time=33.38), 1.17986 s/step
# on time step 1673 (time=33.46), 1.14527 s/step
# on time step 1677 (time=33.54), 1.10888 s/step
# on time step 1680 (time=33.6), 1.35871 s/step
# on time step 1684 (time=33.68), 1.2465 s/step
# on time step 1688 (time=33.76), 1.30996 s/step
# on time step 1692 (time=33.84), 1.1774 s/step
# on time step 1696 (time=33.92), 1.12114 s/step
# on time step 1700 (time=34), 1.20664 s/step
# on time step 1704 (time=34.08), 1.29644 s/step
# on time step 1707 (time=34.14), 1.50898 s/step
# on time step 1711 (time=34.22), 1.05396 s/step
# on time step 1714 (time=34.28), 1.56006 s/step
# on time step 1717 (time=34.34), 1.63819 s/step
# on time step 1720 (time=34.4), 1.47113 s/step
# on time step 1723 (time=34.46), 1.60674 s/step
# on time step 1727 (time=34.54), 1.26849 s/step
# on time step 1732 (time=34.64), 0.996037 s/step
# on time step 1736 (time=34.72), 1.11362 s/step
# on time step 1740 (time=34.8), 1.37239 s/step
# on time step 1744 (time=34.88), 1.10019 s/step
# on time step 1748 (time=34.96), 1.10667 s/step
# on time step 1752 (time=35.04), 1.23653 s/step
# on time step 1756 (time=35.12), 1.03028 s/step
# on time step 1761 (time=35.22), 0.945495 s/step
# on time step 1765 (time=35.3), 1.00823 s/step
# on time step 1769 (time=35.38), 1.23823 s/step
# on time step 1772 (time=35.44), 1.42803 s/step
# on time step 1775 (time=35.5), 1.33973 s/step
# on time step 1779 (time=35.58), 1.12473 s/step
# on time step 1782 (time=35.64), 1.54328 s/step
# on time step 1785 (time=35.7), 1.46599 s/step
# on time step 1789 (time=35.78), 1.25292 s/step
# on time step 1793 (time=35.86), 1.18861 s/step
# on time step 1797 (time=35.94), 1.14277 s/step
# on time step 1800 (time=36), 1.46798 s/step
# on time step 1803 (time=36.06), 1.4151 s/step
# on time step 1806 (time=36.12), 1.49802 s/step
# on time step 1809 (time=36.18), 1.50505 s/step
# on time step 1812 (time=36.24), 1.53663 s/step
# on time step 1815 (time=36.3), 1.48751 s/step
# on time step 1818 (time=36.36), 1.44741 s/step
# on time step 1821 (time=36.42), 1.54355 s/step
# on time step 1824 (time=36.48), 1.49319 s/step
# on time step 1828 (time=36.56), 1.16982 s/step
# on time step 1831 (time=36.62), 1.52253 s/step
# on time step 1834 (time=36.68), 1.42946 s/step
# on time step 1837 (time=36.74), 1.51365 s/step
# on time step 1840 (time=36.8), 1.41366 s/step
# on time step 1843 (time=36.86), 1.41878 s/step
# on time step 1846 (time=36.92), 1.53365 s/step
# on time step 1850 (time=37), 1.19729 s/step
# on time step 1854 (time=37.08), 1.16733 s/step
# on time step 1857 (time=37.14), 1.33463 s/step
# on time step 1861 (time=37.22), 1.28472 s/step
# on time step 1865 (time=37.3), 1.14184 s/step
# on time step 1869 (time=37.38), 1.26121 s/step
# on time step 1873 (time=37.46), 1.33404 s/step
# on time step 1876 (time=37.52), 1.35014 s/step
# on time step 1879 (time=37.58), 1.39365 s/step
# on time step 1882 (time=37.64), 1.39886 s/step
# on time step 1885 (time=37.7), 1.43885 s/step
# on time step 1889 (time=37.78), 1.29595 s/step
# on time step 1893 (time=37.86), 1.06304 s/step
# on time step 1897 (time=37.94), 1.11876 s/step
# on time step 1901 (time=38.02), 1.12369 s/step
# on time step 1904 (time=38.08), 1.45034 s/step
# on time step 1907 (time=38.14), 1.45245 s/step
# on time step 1911 (time=38.22), 1.08946 s/step
# on time step 1914 (time=38.28), 1.36905 s/step
# on time step 1918 (time=38.36), 1.13882 s/step
# on time step 1921 (time=38.42), 1.36879 s/step
# on time step 1924 (time=38.48), 1.43498 s/step
# on time step 1928 (time=38.56), 1.08495 s/step
# on time step 1933 (time=38.66), 0.983207 s/step
# on time step 1936 (time=38.72), 1.37272 s/step
# on time step 1939 (time=38.78), 1.44428 s/step
# on time step 1943 (time=38.86), 1.07783 s/step
# on time step 1946 (time=38.92), 1.44657 s/step
# on time step 1950 (time=39), 1.27797 s/step
# on time step 1954 (time=39.08), 1.13966 s/step
# on time step 1958 (time=39.16), 1.12348 s/step
# on time step 1962 (time=39.24), 1.06811 s/step
# on time step 1967 (time=39.34), 0.941422 s/step
# on time step 1970 (time=39.4), 1.4797 s/step
# on time step 1974 (time=39.48), 1.10613 s/step
# on time step 1978 (time=39.56), 1.31588 s/step
# on time step 1981 (time=39.62), 1.42586 s/step
# on time step 1984 (time=39.68), 1.48551 s/step
# on time step 1987 (time=39.74), 1.48424 s/step
# on time step 1990 (time=39.8), 1.43063 s/step
# on time step 1993 (time=39.86), 1.54293 s/step
# on time step 1997 (time=39.94), 1.35869 s/step
# on time step 2001 (time=40.02), 1.22995 s/step
# field decay(t = 40.06): 0.14003388159338637 / 0.14003388159338637 = 1.0
# on time step 2005 (time=40.1), 1.19314 s/step
# on time step 2009 (time=40.18), 1.02321 s/step
# on time step 2013 (time=40.26), 1.35054 s/step
# on time step 2017 (time=40.34), 1.28892 s/step
# on time step 2021 (time=40.42), 1.14231 s/step
# on time step 2024 (time=40.48), 1.52795 s/step
# on time step 2027 (time=40.54), 1.53422 s/step
# on time step 2030 (time=40.6), 1.41505 s/step
# on time step 2033 (time=40.66), 1.37637 s/step
# on time step 2037 (time=40.74), 1.31319 s/step
# on time step 2040 (time=40.8), 1.40584 s/step
# on time step 2043 (time=40.86), 1.39922 s/step
# on time step 2046 (time=40.92), 1.47599 s/step
# on time step 2049 (time=40.98), 1.37736 s/step
# on time step 2053 (time=41.06), 1.1083 s/step
# on time step 2056 (time=41.12), 1.42065 s/step
# on time step 2060 (time=41.2), 1.2409 s/step
# on time step 2064 (time=41.28), 1.14597 s/step
# on time step 2068 (time=41.36), 1.20709 s/step
# on time step 2072 (time=41.44), 1.32794 s/step
# on time step 2075 (time=41.5), 1.36544 s/step
# on time step 2079 (time=41.58), 1.24554 s/step
# on time step 2083 (time=41.66), 1.29294 s/step
# on time step 2087 (time=41.74), 1.30417 s/step
# on time step 2091 (time=41.82), 1.31838 s/step
# on time step 2094 (time=41.88), 1.41379 s/step
# on time step 2097 (time=41.94), 1.36814 s/step
# on time step 2101 (time=42.02), 1.32291 s/step
# on time step 2105 (time=42.1), 1.27469 s/step
# on time step 2108 (time=42.16), 1.37338 s/step
# on time step 2112 (time=42.24), 1.25012 s/step
# on time step 2116 (time=42.32), 1.15679 s/step
# on time step 2119 (time=42.38), 1.41566 s/step
# on time step 2122 (time=42.44), 1.48393 s/step
# on time step 2125 (time=42.5), 1.45998 s/step
# on time step 2128 (time=42.56), 1.51803 s/step
# on time step 2131 (time=42.62), 1.55666 s/step
# on time step 2134 (time=42.68), 1.43165 s/step
# on time step 2138 (time=42.76), 1.33284 s/step
# on time step 2142 (time=42.84), 1.12832 s/step
# on time step 2146 (time=42.92), 1.20049 s/step
# on time step 2150 (time=43), 1.24442 s/step
# on time step 2154 (time=43.08), 1.26272 s/step
# on time step 2158 (time=43.16), 1.23212 s/step
# on time step 2161 (time=43.22), 1.47863 s/step
# on time step 2165 (time=43.3), 1.08931 s/step
# on time step 2168 (time=43.36), 1.39613 s/step
# on time step 2171 (time=43.42), 1.51763 s/step
# on time step 2174 (time=43.48), 1.52563 s/step
# on time step 2177 (time=43.54), 1.57641 s/step
# on time step 2180 (time=43.6), 1.36671 s/step
# on time step 2184 (time=43.68), 1.19625 s/step
# on time step 2188 (time=43.76), 1.16977 s/step
# on time step 2192 (time=43.84), 1.20492 s/step
# on time step 2196 (time=43.92), 1.14164 s/step
# on time step 2199 (time=43.98), 1.59777 s/step
# on time step 2202 (time=44.04), 1.4149 s/step
# on time step 2206 (time=44.12), 1.23859 s/step
# on time step 2210 (time=44.2), 1.2114 s/step
# on time step 2213 (time=44.26), 1.37668 s/step
# on time step 2216 (time=44.32), 1.35462 s/step
# on time step 2220 (time=44.4), 1.10669 s/step
# on time step 2223 (time=44.46), 1.48591 s/step
# on time step 2226 (time=44.52), 1.47699 s/step
# on time step 2229 (time=44.58), 1.47736 s/step
# on time step 2232 (time=44.64), 1.45969 s/step
# on time step 2235 (time=44.7), 1.48426 s/step
# on time step 2238 (time=44.76), 1.44355 s/step
# on time step 2241 (time=44.82), 1.36791 s/step
# on time step 2244 (time=44.88), 1.42628 s/step
# on time step 2247 (time=44.94), 1.38431 s/step
# on time step 2251 (time=45.02), 1.0161 s/step
# on time step 2255 (time=45.1), 1.26701 s/step
# on time step 2258 (time=45.16), 1.4059 s/step
# on time step 2262 (time=45.24), 1.02497 s/step
# on time step 2266 (time=45.32), 1.35895 s/step
# on time step 2269 (time=45.38), 1.43036 s/step
# on time step 2272 (time=45.44), 1.41134 s/step
# on time step 2275 (time=45.5), 1.37045 s/step
# on time step 2278 (time=45.56), 1.40419 s/step
# on time step 2282 (time=45.64), 1.32444 s/step
# on time step 2285 (time=45.7), 1.41862 s/step
# on time step 2288 (time=45.76), 1.41108 s/step
# on time step 2293 (time=45.86), 0.964097 s/step
# on time step 2296 (time=45.92), 1.38089 s/step
# on time step 2300 (time=46), 1.08577 s/step
# on time step 2303 (time=46.06), 1.37931 s/step
# on time step 2306 (time=46.12), 1.49889 s/step
# on time step 2309 (time=46.18), 1.52683 s/step
# on time step 2312 (time=46.24), 1.61149 s/step
# on time step 2316 (time=46.32), 1.23945 s/step
# on time step 2319 (time=46.38), 1.43912 s/step
# on time step 2322 (time=46.44), 1.44326 s/step
# on time step 2325 (time=46.5), 1.47679 s/step
# on time step 2328 (time=46.56), 1.45245 s/step
# on time step 2331 (time=46.62), 1.45765 s/step
# on time step 2334 (time=46.68), 1.59875 s/step
# on time step 2337 (time=46.74), 1.51456 s/step
# on time step 2340 (time=46.8), 1.52929 s/step
# on time step 2343 (time=46.86), 1.60996 s/step
# on time step 2346 (time=46.92), 1.41443 s/step
# on time step 2350 (time=47), 1.20568 s/step
# on time step 2354 (time=47.08), 1.29972 s/step
# on time step 2358 (time=47.16), 1.31786 s/step
# on time step 2361 (time=47.22), 1.48419 s/step
# on time step 2365 (time=47.3), 1.29782 s/step
# on time step 2368 (time=47.36), 1.61651 s/step
# on time step 2371 (time=47.42), 1.5412 s/step
# on time step 2374 (time=47.48), 1.62635 s/step
# on time step 2377 (time=47.54), 1.38628 s/step
# on time step 2380 (time=47.6), 1.62146 s/step
# on time step 2383 (time=47.66), 1.59365 s/step
# on time step 2386 (time=47.72), 1.59287 s/step
# on time step 2389 (time=47.78), 1.5309 s/step
# on time step 2393 (time=47.86), 1.25858 s/step
# on time step 2397 (time=47.94), 1.21931 s/step
# on time step 2401 (time=48.02), 1.22807 s/step
# on time step 2405 (time=48.1), 1.24295 s/step
# on time step 2409 (time=48.18), 1.33453 s/step
# on time step 2413 (time=48.26), 1.19881 s/step
# on time step 2416 (time=48.32), 1.55108 s/step
# on time step 2419 (time=48.38), 1.61425 s/step
# on time step 2422 (time=48.44), 1.65023 s/step
# on time step 2425 (time=48.5), 1.62247 s/step
# on time step 2428 (time=48.56), 1.60837 s/step
# on time step 2431 (time=48.62), 1.56653 s/step
# KeyboardInterrupt

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000399828 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 8.0373 s
# -----------
# on time step 1 (time=0.02), 8.24205 s/step
# on time step 24 (time=0.48), 0.176993 s/step
# on time step 46 (time=0.92), 0.182817 s/step
# on time step 68 (time=1.36), 0.182239 s/step
# on time step 90 (time=1.8), 0.187121 s/step
# on time step 113 (time=2.26), 0.180201 s/step
# on time step 136 (time=2.72), 0.17785 s/step
# on time step 159 (time=3.18), 0.178115 s/step
# on time step 181 (time=3.62), 0.183584 s/step
# on time step 204 (time=4.08), 0.177774 s/step
# on time step 226 (time=4.52), 0.184646 s/step
# on time step 249 (time=4.98), 0.180331 s/step
# on time step 271 (time=5.42), 0.183658 s/step
# on time step 294 (time=5.88), 0.17479 s/step
# on time step 317 (time=6.34), 0.175502 s/step
# on time step 340 (time=6.8), 0.177712 s/step
# on time step 362 (time=7.24), 0.186256 s/step
# on time step 385 (time=7.7), 0.175457 s/step
# on time step 408 (time=8.16), 0.176973 s/step
# on time step 431 (time=8.62), 0.175147 s/step
# on time step 453 (time=9.06), 0.18283 s/step
# on time step 476 (time=9.52), 0.175346 s/step
# on time step 499 (time=9.98), 0.17694 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 522 (time=10.44), 0.181174 s/step
# on time step 545 (time=10.9), 0.177529 s/step
# on time step 568 (time=11.36), 0.175494 s/step
# on time step 591 (time=11.82), 0.17791 s/step
# on time step 614 (time=12.28), 0.178658 s/step
# on time step 637 (time=12.74), 0.17495 s/step
# on time step 660 (time=13.2), 0.175474 s/step
# on time step 683 (time=13.66), 0.176065 s/step
# on time step 706 (time=14.12), 0.18036 s/step
# on time step 729 (time=14.58), 0.177267 s/step
# on time step 752 (time=15.04), 0.174826 s/step
# on time step 775 (time=15.5), 0.17832 s/step
# on time step 798 (time=15.96), 0.176059 s/step
# on time step 821 (time=16.42), 0.174296 s/step
# on time step 844 (time=16.88), 0.176658 s/step
# on time step 867 (time=17.34), 0.180055 s/step
# on time step 890 (time=17.8), 0.176463 s/step
# on time step 913 (time=18.26), 0.175344 s/step
# on time step 936 (time=18.72), 0.181517 s/step
# on time step 959 (time=19.18), 0.177223 s/step
# on time step 982 (time=19.64), 0.17789 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1005 (time=20.1), 0.175602 s/step
# on time step 1027 (time=20.54), 0.184792 s/step
# on time step 1050 (time=21), 0.176746 s/step
# on time step 1073 (time=21.46), 0.17896 s/step
# on time step 1096 (time=21.92), 0.175551 s/step
# on time step 1118 (time=22.36), 0.182673 s/step
# on time step 1141 (time=22.82), 0.175434 s/step
# on time step 1164 (time=23.28), 0.177873 s/step
# on time step 1187 (time=23.74), 0.175771 s/step
# on time step 1209 (time=24.18), 0.181959 s/step
# on time step 1232 (time=24.64), 0.174015 s/step
# on time step 1255 (time=25.1), 0.175905 s/step
# on time step 1278 (time=25.56), 0.181004 s/step
# on time step 1301 (time=26.02), 0.177557 s/step
# on time step 1324 (time=26.48), 0.17495 s/step
# on time step 1347 (time=26.94), 0.178153 s/step
# on time step 1369 (time=27.38), 0.183905 s/step
# on time step 1392 (time=27.84), 0.177187 s/step
# on time step 1415 (time=28.3), 0.175892 s/step
# on time step 1438 (time=28.76), 0.176872 s/step
# on time step 1460 (time=29.2), 0.181915 s/step
# on time step 1483 (time=29.66), 0.177154 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000660896 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 72.0097% done, 1.55509 s remaining
# subpixel-averaging is 67.3154% done, 1.94233 s remaining
# subpixel-averaging is 71.6859% done, 1.58033 s remaining
# time for set_epsilon = 30.7744 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 8.11629 s/step
# on time step 21 (time=0.42), 0.200317 s/step
# on time step 41 (time=0.82), 0.201296 s/step
# on time step 62 (time=1.24), 0.199139 s/step
# on time step 82 (time=1.64), 0.202301 s/step
# on time step 102 (time=2.04), 0.200592 s/step
# on time step 122 (time=2.44), 0.201524 s/step
# on time step 143 (time=2.86), 0.199564 s/step
# on time step 163 (time=3.26), 0.20813 s/step
# on time step 183 (time=3.66), 0.201018 s/step
# on time step 203 (time=4.06), 0.202274 s/step
# on time step 223 (time=4.46), 0.201196 s/step
# on time step 243 (time=4.86), 0.202321 s/step
# on time step 264 (time=5.28), 0.199188 s/step
# on time step 284 (time=5.68), 0.201225 s/step
# on time step 305 (time=6.1), 0.19887 s/step
# on time step 324 (time=6.48), 0.212441 s/step
# on time step 344 (time=6.88), 0.208928 s/step
# on time step 364 (time=7.28), 0.203808 s/step
# on time step 386 (time=7.72), 0.188467 s/step
# on time step 408 (time=8.16), 0.189847 s/step
# on time step 430 (time=8.6), 0.188599 s/step
# on time step 450 (time=9), 0.203321 s/step
# on time step 470 (time=9.4), 0.200469 s/step
# on time step 492 (time=9.84), 0.18933 s/step
# field decay(t = 10.02): 6.608827229655589e-05 / 6.608827229655589e-05 = 1.0
# on time step 513 (time=10.26), 0.190534 s/step
# on time step 535 (time=10.7), 0.188246 s/step
# on time step 557 (time=11.14), 0.188596 s/step
# on time step 578 (time=11.56), 0.193561 s/step
# on time step 600 (time=12), 0.188339 s/step
# on time step 622 (time=12.44), 0.187977 s/step
# on time step 644 (time=12.88), 0.187829 s/step
# on time step 666 (time=13.32), 0.196399 s/step
# on time step 688 (time=13.76), 0.188277 s/step
# on time step 710 (time=14.2), 0.189551 s/step
# on time step 732 (time=14.64), 0.186244 s/step
# on time step 754 (time=15.08), 0.187646 s/step
# on time step 775 (time=15.5), 0.194474 s/step
# on time step 797 (time=15.94), 0.187381 s/step
# on time step 819 (time=16.38), 0.186415 s/step
# on time step 841 (time=16.82), 0.186973 s/step
# on time step 863 (time=17.26), 0.185733 s/step
# on time step 884 (time=17.68), 0.194507 s/step
# on time step 906 (time=18.12), 0.186381 s/step
# on time step 928 (time=18.56), 0.189742 s/step
# on time step 950 (time=19), 0.188757 s/step
# on time step 971 (time=19.42), 0.190672 s/step
# on time step 992 (time=19.84), 0.1935 s/step
# field decay(t = 20.04): 0.02511224628581102 / 0.02511224628581102 = 1.0
# on time step 1014 (time=20.28), 0.187951 s/step
# on time step 1036 (time=20.72), 0.18856 s/step
# on time step 1058 (time=21.16), 0.18711 s/step
# on time step 1080 (time=21.6), 0.195355 s/step
# on time step 1102 (time=22.04), 0.186308 s/step
# on time step 1124 (time=22.48), 0.189005 s/step
# on time step 1146 (time=22.92), 0.187404 s/step
# on time step 1168 (time=23.36), 0.18816 s/step
# on time step 1189 (time=23.78), 0.194291 s/step
# on time step 1211 (time=24.22), 0.188085 s/step
# on time step 1233 (time=24.66), 0.186426 s/step
# on time step 1254 (time=25.08), 0.191317 s/step
# on time step 1276 (time=25.52), 0.188511 s/step
# on time step 1297 (time=25.94), 0.196725 s/step
# on time step 1319 (time=26.38), 0.188018 s/step
# on time step 1341 (time=26.82), 0.18992 s/step
# on time step 1363 (time=27.26), 0.188294 s/step
# on time step 1385 (time=27.7), 0.189652 s/step
# on time step 1406 (time=28.12), 0.194279 s/step
# on time step 1428 (time=28.56), 0.18949 s/step
# on time step 1450 (time=29), 0.188004 s/step
# on time step 1471 (time=29.42), 0.192014 s/step
# on time step 1493 (time=29.86), 0.189802 s/step
# field decay(t = 30.060000000000002): 0.026110424250372 / 0.026110424250372 = 1.0
# on time step 1514 (time=30.28), 0.196789 s/step
# on time step 1536 (time=30.72), 0.187993 s/step
# on time step 1558 (time=31.16), 0.188867 s/step
# on time step 1579 (time=31.58), 0.191079 s/step
# on time step 1601 (time=32.02), 0.185914 s/step
# on time step 1622 (time=32.44), 0.195443 s/step
# on time step 1644 (time=32.88), 0.186968 s/step
# on time step 1665 (time=33.3), 0.190828 s/step
# on time step 1687 (time=33.74), 0.187866 s/step
# on time step 1709 (time=34.18), 0.189017 s/step
# on time step 1730 (time=34.6), 0.1953 s/step
# on time step 1750 (time=35), 0.208237 s/step
# on time step 1770 (time=35.4), 0.208608 s/step
# on time step 1790 (time=35.8), 0.201096 s/step
# on time step 1811 (time=36.22), 0.191007 s/step
# on time step 1833 (time=36.66), 0.189688 s/step
# on time step 1854 (time=37.08), 0.195218 s/step
# on time step 1875 (time=37.5), 0.191016 s/step
# on time step 1897 (time=37.94), 0.18688 s/step
# on time step 1919 (time=38.38), 0.189327 s/step
# on time step 1941 (time=38.82), 0.187881 s/step
# on time step 1962 (time=39.24), 0.197126 s/step
# on time step 1984 (time=39.68), 0.187684 s/step
# field decay(t = 40.06): 0.0042274980974485775 / 0.026110424250372 = 0.1619084415063975
# on time step 2006 (time=40.12), 0.187856 s/step
# on time step 2028 (time=40.56), 0.186734 s/step
# on time step 2049 (time=40.98), 0.190531 s/step
# on time step 2070 (time=41.4), 0.194012 s/step
# on time step 2092 (time=41.84), 0.189399 s/step
# on time step 2114 (time=42.28), 0.1871 s/step
# on time step 2136 (time=42.72), 0.188308 s/step
# on time step 2158 (time=43.16), 0.187177 s/step
# on time step 2179 (time=43.58), 0.196324 s/step
# on time step 2201 (time=44.02), 0.189291 s/step
# on time step 2223 (time=44.46), 0.188236 s/step
# on time step 2245 (time=44.9), 0.186875 s/step
# on time step 2267 (time=45.34), 0.189029 s/step
# on time step 2288 (time=45.76), 0.19534 s/step
# on time step 2309 (time=46.18), 0.19939 s/step
# on time step 2330 (time=46.6), 0.195721 s/step
# on time step 2352 (time=47.04), 0.189808 s/step
# on time step 2374 (time=47.48), 0.186507 s/step
# on time step 2395 (time=47.9), 0.196093 s/step
# on time step 2417 (time=48.34), 0.186939 s/step
# on time step 2439 (time=48.78), 0.188765 s/step
# on time step 2461 (time=49.22), 0.189477 s/step
# on time step 2483 (time=49.66), 0.189094 s/step
# on time step 2502 (time=50.04), 0.21398 s/step
# field decay(t = 50.08): 0.001881004594818308 / 0.026110424250372 = 0.07204036888797427
# on time step 2521 (time=50.42), 0.215729 s/step
# on time step 2541 (time=50.82), 0.206914 s/step
# on time step 2562 (time=51.24), 0.197612 s/step
# on time step 2584 (time=51.68), 0.188607 s/step
# on time step 2605 (time=52.1), 0.192071 s/step
# on time step 2627 (time=52.54), 0.189114 s/step
# on time step 2648 (time=52.96), 0.196619 s/step
# on time step 2668 (time=53.36), 0.206352 s/step
# on time step 2689 (time=53.78), 0.19734 s/step
# on time step 2710 (time=54.2), 0.192751 s/step
# on time step 2731 (time=54.62), 0.190725 s/step
# on time step 2753 (time=55.06), 0.186489 s/step
# on time step 2774 (time=55.48), 0.197076 s/step
# on time step 2795 (time=55.9), 0.192378 s/step
# on time step 2815 (time=56.3), 0.207184 s/step
# on time step 2834 (time=56.68), 0.211545 s/step
# on time step 2853 (time=57.06), 0.212053 s/step
# on time step 2872 (time=57.44), 0.215752 s/step
# on time step 2891 (time=57.82), 0.212835 s/step
# on time step 2911 (time=58.22), 0.207452 s/step
# on time step 2931 (time=58.62), 0.206515 s/step
# on time step 2951 (time=59.02), 0.204729 s/step
# on time step 2970 (time=59.4), 0.221445 s/step
# on time step 2990 (time=59.8), 0.207076 s/step
# field decay(t = 60.1): 0.00039166601503237784 / 0.026110424250372 = 0.015000369633090037
# on time step 3009 (time=60.18), 0.211816 s/step
# on time step 3028 (time=60.56), 0.211171 s/step
# on time step 3048 (time=60.96), 0.204942 s/step
# on time step 3067 (time=61.34), 0.214052 s/step
# on time step 3086 (time=61.72), 0.213248 s/step
# on time step 3105 (time=62.1), 0.218309 s/step
# on time step 3124 (time=62.48), 0.215721 s/step
# on time step 3143 (time=62.86), 0.214524 s/step
# on time step 3162 (time=63.24), 0.213122 s/step
# on time step 3181 (time=63.62), 0.212237 s/step
# on time step 3200 (time=64), 0.214881 s/step
# on time step 3219 (time=64.38), 0.212021 s/step
# on time step 3239 (time=64.78), 0.208317 s/step
# on time step 3258 (time=65.16), 0.217761 s/step
# on time step 3278 (time=65.56), 0.20663 s/step
# on time step 3298 (time=65.96), 0.206712 s/step
# on time step 3318 (time=66.36), 0.205334 s/step
# on time step 3338 (time=66.76), 0.206901 s/step
# on time step 3358 (time=67.16), 0.205317 s/step
# on time step 3378 (time=67.56), 0.207657 s/step
# on time step 3398 (time=67.96), 0.207194 s/step
# on time step 3418 (time=68.36), 0.206354 s/step
# on time step 3438 (time=68.76), 0.217175 s/step
# on time step 3458 (time=69.16), 0.206544 s/step
# on time step 3477 (time=69.54), 0.211171 s/step
# on time step 3496 (time=69.92), 0.210995 s/step
# field decay(t = 70.12): 0.0002421678740895278 / 0.026110424250372 = 0.009274758302178011
# on time step 3515 (time=70.3), 0.212225 s/step
# on time step 3535 (time=70.7), 0.20795 s/step
# on time step 3555 (time=71.1), 0.205768 s/step
# on time step 3575 (time=71.5), 0.207451 s/step
# on time step 3595 (time=71.9), 0.208789 s/step
# on time step 3615 (time=72.3), 0.209599 s/step
# on time step 3635 (time=72.7), 0.208394 s/step
# on time step 3654 (time=73.08), 0.218107 s/step
# on time step 3673 (time=73.46), 0.212275 s/step
# on time step 3693 (time=73.86), 0.208762 s/step
# on time step 3713 (time=74.26), 0.20795 s/step
# on time step 3733 (time=74.66), 0.207184 s/step
# on time step 3753 (time=75.06), 0.209464 s/step
# on time step 3773 (time=75.46), 0.206841 s/step
# on time step 3793 (time=75.86), 0.207569 s/step
# on time step 3813 (time=76.26), 0.206589 s/step
# on time step 3832 (time=76.64), 0.210897 s/step
# on time step 3851 (time=77.02), 0.219123 s/step
# on time step 3870 (time=77.4), 0.223391 s/step
# on time step 3889 (time=77.78), 0.212561 s/step
# on time step 3908 (time=78.16), 0.211416 s/step
# on time step 3928 (time=78.56), 0.206055 s/step
# on time step 3947 (time=78.94), 0.213682 s/step
# on time step 3966 (time=79.32), 0.210873 s/step
# on time step 3986 (time=79.72), 0.206091 s/step
# on time step 4005 (time=80.1), 0.212611 s/step
# field decay(t = 80.14): 9.967630416048819e-05 / 0.026110424250372 = 0.003817490792363057
# on time step 4025 (time=80.5), 0.207476 s/step
# on time step 4045 (time=80.9), 0.207802 s/step
# on time step 4065 (time=81.3), 0.205232 s/step
# on time step 4085 (time=81.7), 0.209332 s/step
# on time step 4104 (time=82.08), 0.21714 s/step
# on time step 4124 (time=82.48), 0.209027 s/step
# on time step 4144 (time=82.88), 0.206834 s/step
# on time step 4164 (time=83.28), 0.208189 s/step
# on time step 4184 (time=83.68), 0.206929 s/step
# on time step 4204 (time=84.08), 0.207992 s/step
# on time step 4224 (time=84.48), 0.209513 s/step
# on time step 4244 (time=84.88), 0.209649 s/step
# on time step 4264 (time=85.28), 0.209636 s/step
# on time step 4284 (time=85.68), 0.216212 s/step
# on time step 4304 (time=86.08), 0.205846 s/step
# on time step 4324 (time=86.48), 0.209197 s/step
# on time step 4344 (time=86.88), 0.205089 s/step
# on time step 4364 (time=87.28), 0.2079 s/step
# on time step 4384 (time=87.68), 0.206761 s/step
# on time step 4404 (time=88.08), 0.207258 s/step
# on time step 4424 (time=88.48), 0.205478 s/step
# on time step 4444 (time=88.88), 0.209665 s/step
# on time step 4464 (time=89.28), 0.216388 s/step
# on time step 4484 (time=89.68), 0.207293 s/step
# on time step 4504 (time=90.08), 0.206083 s/step
# field decay(t = 90.16): 9.353550808260108e-05 / 0.026110424250372 = 0.0035823051814743473
# on time step 4524 (time=90.48), 0.207528 s/step
# on time step 4544 (time=90.88), 0.208639 s/step
# on time step 4564 (time=91.28), 0.205968 s/step
# on time step 4584 (time=91.68), 0.207917 s/step
# on time step 4604 (time=92.08), 0.206 s/step
# on time step 4623 (time=92.46), 0.210985 s/step
# on time step 4643 (time=92.86), 0.208741 s/step
# on time step 4662 (time=93.24), 0.220076 s/step
# on time step 4681 (time=93.62), 0.216159 s/step
# on time step 4700 (time=94), 0.214434 s/step
# on time step 4719 (time=94.38), 0.212458 s/step
# on time step 4739 (time=94.78), 0.209624 s/step
# on time step 4758 (time=95.16), 0.212566 s/step
# on time step 4777 (time=95.54), 0.218422 s/step
# on time step 4796 (time=95.92), 0.2196 s/step
# on time step 4816 (time=96.32), 0.207002 s/step
# on time step 4835 (time=96.7), 0.214943 s/step
# on time step 4854 (time=97.08), 0.213541 s/step
# on time step 4873 (time=97.46), 0.215879 s/step
# on time step 4894 (time=97.88), 0.195483 s/step
# on time step 4914 (time=98.28), 0.200518 s/step
# on time step 4935 (time=98.7), 0.192316 s/step
# on time step 4957 (time=99.14), 0.189577 s/step
# on time step 4978 (time=99.56), 0.190965 s/step
# on time step 4999 (time=99.98), 0.190603 s/step
# field decay(t = 100.18): 1.778958570377327e-05 / 0.026110424250372 = 0.000681321204634192
# run 0 finished at t = 100.18 (5009 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
convenional=[]
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])

    convenional = np.append(convenional,0.25)
if mp.am_master():
    plt.figure(dpi=300)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    plt.plot(wl, convenional, 'k--')
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical efficiency (in-pixel)")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
print(np.mean(Tr[0:66]))
print(np.mean(Tg[66:160]))
print(np.mean(Tb[160:300]))
print(max(Tr[0:66]))
print(max(Tg[66:160]))
print(max(Tb[160:300]))
print(max((Tr - Tg)[0:66]))
print(max((Tg - Tr)[66:160]))
print(max((Tb - Tr)[160:300]))
print(np.mean(Tr[66:300]))
print((sum(Tg[0:66]) + sum(Tg[160:300]))/206)
print(np.mean(Tb[0:160]))
# Out:
# 0.5856546175251732
# 0.3229743838639888
# 0.38838945636620964
# 0.7538464980443024
# 0.4077309341583092
# 0.6312898975961911
# 0.7196715108630941
# 0.36301324779174404
# 0.5762401146865622
# 0.09051417021827829
# 0.07766544737320759
# 0.05263531326937979

# %%
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

#moniter 설정
refl = []
tran_total = []
straight_refl_data = []
total_flux = []
flux_freqs = []

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)

for i in range(31):
    refl = np.append(refl, opt.sim.add_flux(1/wavelengths[i], 0, 1, refl_fr))
    tran_total = np.append(tran_total, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_t))
    
# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장


for i in range(31):
    straight_refl_data =  np.append(straight_refl_data,mp.get_fluxes(refl[i]))
    total_flux = np.append(total_flux,mp.get_fluxes(tran_total[i]))
    flux_freqs = np.append(flux_freqs,mp.get_flux_freqs(tran_total[i]))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000602961 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 8.23329 s
# -----------
# on time step 1 (time=0.02), 8.50396 s/step
# on time step 19 (time=0.38), 0.227166 s/step
# on time step 37 (time=0.74), 0.226094 s/step
# on time step 56 (time=1.12), 0.219123 s/step
# on time step 74 (time=1.48), 0.223475 s/step
# on time step 92 (time=1.84), 0.222393 s/step
# on time step 110 (time=2.2), 0.224013 s/step
# on time step 128 (time=2.56), 0.227011 s/step
# on time step 146 (time=2.92), 0.232229 s/step
# on time step 166 (time=3.32), 0.203413 s/step
# on time step 186 (time=3.72), 0.201469 s/step
# on time step 205 (time=4.1), 0.214605 s/step
# on time step 225 (time=4.5), 0.206411 s/step
# on time step 245 (time=4.9), 0.204406 s/step
# on time step 264 (time=5.28), 0.218001 s/step
# on time step 284 (time=5.68), 0.207804 s/step
# on time step 304 (time=6.08), 0.204106 s/step
# on time step 323 (time=6.46), 0.214259 s/step
# on time step 343 (time=6.86), 0.208749 s/step
# on time step 362 (time=7.24), 0.22069 s/step
# on time step 381 (time=7.62), 0.210702 s/step
# on time step 400 (time=8), 0.211971 s/step
# on time step 419 (time=8.38), 0.21699 s/step
# on time step 438 (time=8.76), 0.213402 s/step
# on time step 458 (time=9.16), 0.208675 s/step
# on time step 478 (time=9.56), 0.208668 s/step
# on time step 494 (time=9.88), 0.259019 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 512 (time=10.24), 0.228309 s/step
# on time step 530 (time=10.6), 0.228062 s/step
# on time step 549 (time=10.98), 0.221386 s/step
# on time step 568 (time=11.36), 0.216493 s/step
# on time step 588 (time=11.76), 0.208592 s/step
# on time step 607 (time=12.14), 0.210887 s/step
# on time step 626 (time=12.52), 0.218909 s/step
# on time step 644 (time=12.88), 0.229242 s/step
# on time step 662 (time=13.24), 0.233196 s/step
# on time step 680 (time=13.6), 0.223504 s/step
# on time step 698 (time=13.96), 0.22722 s/step
# on time step 715 (time=14.3), 0.246447 s/step
# on time step 732 (time=14.64), 0.248256 s/step
# on time step 748 (time=14.96), 0.265387 s/step
# on time step 765 (time=15.3), 0.243477 s/step
# on time step 781 (time=15.62), 0.251162 s/step
# on time step 798 (time=15.96), 0.249866 s/step
# on time step 814 (time=16.28), 0.257412 s/step
# on time step 831 (time=16.62), 0.23699 s/step
# on time step 850 (time=17), 0.219522 s/step
# on time step 869 (time=17.38), 0.221727 s/step
# on time step 887 (time=17.74), 0.230482 s/step
# on time step 905 (time=18.1), 0.223563 s/step
# on time step 924 (time=18.48), 0.226403 s/step
# on time step 943 (time=18.86), 0.215125 s/step
# on time step 961 (time=19.22), 0.226291 s/step
# on time step 977 (time=19.54), 0.250729 s/step
# on time step 996 (time=19.92), 0.21081 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1015 (time=20.3), 0.217211 s/step
# on time step 1033 (time=20.66), 0.233595 s/step
# on time step 1051 (time=21.02), 0.226313 s/step
# on time step 1070 (time=21.4), 0.217007 s/step
# on time step 1089 (time=21.78), 0.214841 s/step
# on time step 1106 (time=22.12), 0.241048 s/step
# on time step 1123 (time=22.46), 0.235503 s/step
# on time step 1143 (time=22.86), 0.212616 s/step
# on time step 1161 (time=23.22), 0.229244 s/step
# on time step 1179 (time=23.58), 0.224514 s/step
# on time step 1195 (time=23.9), 0.25808 s/step
# on time step 1212 (time=24.24), 0.242445 s/step
# on time step 1231 (time=24.62), 0.219382 s/step
# on time step 1250 (time=25), 0.216386 s/step
# on time step 1270 (time=25.4), 0.213681 s/step
# on time step 1290 (time=25.8), 0.206384 s/step
# on time step 1310 (time=26.2), 0.208019 s/step
# on time step 1329 (time=26.58), 0.211607 s/step
# on time step 1349 (time=26.98), 0.209478 s/step
# on time step 1368 (time=27.36), 0.212111 s/step
# on time step 1388 (time=27.76), 0.205075 s/step
# on time step 1408 (time=28.16), 0.204499 s/step
# on time step 1428 (time=28.56), 0.202617 s/step
# on time step 1447 (time=28.94), 0.21396 s/step
# on time step 1466 (time=29.32), 0.221277 s/step
# on time step 1482 (time=29.64), 0.250668 s/step
# on time step 1499 (time=29.98), 0.240645 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

refl = []
tran = []
for i in range(31):
    refl = np.append(refl, opt.sim.add_flux(1/wavelengths[i], 0, 1, refl_fr))
    tran = np.append(tran, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_t))


#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = []
tran_green = []
tran_blue = []
tran_green0 = []

for i in range(31):
    tran_red = np.append(tran_red, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r))
    tran_green = np.append(tran_green, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g))
    tran_blue = np.append(tran_blue, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b))
    tran_green0 = np.append(tran_green0, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0))

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = []
tran_green_1 = []
tran_blue_1 = []
tran_green0_1 = []

for i in range(31):
    tran_red_1 = np.append(tran_red_1, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r_1))
    tran_green_1 = np.append(tran_green_1, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g_1))
    tran_blue_1 = np.append(tran_blue_1, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b_1))
    tran_green0_1 = np.append(tran_green0_1, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0_1))
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = []
tran_green_2 = []
tran_blue_2 = []
tran_green0_2 = []

for i in range(31):
    tran_red_2 = np.append(tran_red_2, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r_2))
    tran_green_2 = np.append(tran_green_2, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g_2))
    tran_blue_2 = np.append(tran_blue_2, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b_2))
    tran_green0_2 = np.append(tran_green0_2, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0_2))
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = []
tran_green_3 = []
tran_blue_3 = []
tran_green0_3 = []

for i in range(31):
    tran_red_3 = np.append(tran_red_3, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r_3))
    tran_green_3 = np.append(tran_green_3, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g_3))
    tran_blue_3 = np.append(tran_blue_3, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b_3))
    tran_green0_3 = np.append(tran_green0_3, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0_3))
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = []
tran_green_4 = []
tran_blue_4 = []
tran_green0_4 = []


for i in range(31):
    tran_red_4 = np.append(tran_red_4, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r_4))
    tran_green_4 = np.append(tran_green_4, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g_4))
    tran_blue_4 = np.append(tran_blue_4, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b_4))
    tran_green0_4 = np.append(tran_green0_4, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0_4))
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = []
tran_green_5 = []
tran_blue_5 = []
tran_green0_5 = []


for i in range(31):
    tran_red_5 = np.append(tran_red_5, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r_5))
    tran_green_5 = np.append(tran_green_5, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g_5))
    tran_blue_5 = np.append(tran_blue_5, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b_5))
    tran_green0_5 = np.append(tran_green0_5, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0_5))
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = []
tran_green_6 = []
tran_blue_6 = []
tran_green0_6 = []


for i in range(31):
    tran_red_6 = np.append(tran_red_6, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r_6))
    tran_green_6 = np.append(tran_green_6, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g_6))
    tran_blue_6 = np.append(tran_blue_6, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b_6))
    tran_green0_6 = np.append(tran_green0_6, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0_6))
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = []
tran_green_7 = []
tran_blue_7 = []
tran_green0_7 = []


for i in range(31):
    tran_red_7 = np.append(tran_red_7, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r_7))
    tran_green_7 = np.append(tran_green_7, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g_7))
    tran_blue_7 = np.append(tran_blue_7, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b_7))
    tran_green0_7 = np.append(tran_green0_7, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0_7))
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = []
tran_green_8 = []
tran_blue_8 = []
tran_green0_8 = []


for i in range(31):
    tran_red_8 = np.append(tran_red_8, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_r_8))
    tran_green_8 = np.append(tran_green_8, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g_8))
    tran_blue_8 = np.append(tran_blue_8, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_b_8))
    tran_green0_8 = np.append(tran_green0_8, opt.sim.add_flux(1/wavelengths[i], 0, 1, tran_g0_8))


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

sc_refl_flux = []
tran_flux = []


red_flux = []
green_flux = []
blue_flux = []
green_flux0 = []

red_flux_1 = []
green_flux_1 = []
blue_flux_1 = []
green_flux0_1 = []

red_flux_2 = []
green_flux_2 = []
blue_flux_2 = []
green_flux0_2 = []

red_flux_3 = []
green_flux_3 = []
blue_flux_3 = []
green_flux0_3 = []

red_flux_4 = []
green_flux_4 = []
blue_flux_4 = []
green_flux0_4 = []

red_flux_5 = []
green_flux_5 = []
blue_flux_5 = []
green_flux0_5 = []

red_flux_6 = []
green_flux_6 = []
blue_flux_6 = []
green_flux0_6 = []

red_flux_7 = []
green_flux_7 = []
blue_flux_7 = []
green_flux0_7 = []

red_flux_8 = []
green_flux_8 = []
blue_flux_8 = []
green_flux0_8 = []


# 데이터 저장

for i in range(31):
    sc_refl_flux = np.append(sc_refl_flux,mp.get_fluxes(refl[i]))
    tran_flux = np.append(tran_flux,mp.get_fluxes(tran[i]))


    red_flux = np.append(red_flux,mp.get_fluxes(tran_red[i]))
    green_flux = np.append(green_flux,mp.get_fluxes(tran_green[i]))
    blue_flux = np.append(blue_flux,mp.get_fluxes(tran_blue[i]))
    green_flux0 = np.append(green_flux0,mp.get_fluxes(tran_green0[i]))
    
    red_flux_1 = np.append(red_flux_1,mp.get_fluxes(tran_red_1[i]))
    green_flux_1 = np.append(green_flux_1,mp.get_fluxes(tran_green_1[i]))
    blue_flux_1 = np.append(blue_flux_1,mp.get_fluxes(tran_blue_1[i]))
    green_flux0_1 = np.append(green_flux0_1,mp.get_fluxes(tran_green0_1[i]))
    
    red_flux_2 = np.append(red_flux_2,mp.get_fluxes(tran_red_2[i]))
    green_flux_2 = np.append(green_flux_2,mp.get_fluxes(tran_green_2[i]))
    blue_flux_2 = np.append(blue_flux_2,mp.get_fluxes(tran_blue_2[i]))
    green_flux0_2 = np.append(green_flux0_2,mp.get_fluxes(tran_green0_2[i]))
    
    red_flux_3 = np.append(red_flux_3,mp.get_fluxes(tran_red_3[i]))
    green_flux_3 = np.append(green_flux_3,mp.get_fluxes(tran_green_3[i]))
    blue_flux_3 = np.append(blue_flux_3,mp.get_fluxes(tran_blue_3[i]))
    green_flux0_3 = np.append(green_flux0_3,mp.get_fluxes(tran_green0_3[i]))
    
    red_flux_4 = np.append(red_flux_4,mp.get_fluxes(tran_red_4[i]))
    green_flux_4 = np.append(green_flux_4,mp.get_fluxes(tran_green_4[i]))
    blue_flux_4 = np.append(blue_flux_4,mp.get_fluxes(tran_blue_4[i]))
    green_flux0_4 = np.append(green_flux0_4,mp.get_fluxes(tran_green0_4[i]))
    
    red_flux_5 = np.append(red_flux_5,mp.get_fluxes(tran_red_5[i]))
    green_flux_5 = np.append(green_flux_5,mp.get_fluxes(tran_green_5[i]))
    blue_flux_5 = np.append(blue_flux_5,mp.get_fluxes(tran_blue_5[i]))
    green_flux0_5 = np.append(green_flux0_5,mp.get_fluxes(tran_green0_5[i]))
    
    red_flux_6 = np.append(red_flux_6,mp.get_fluxes(tran_red_6[i]))
    green_flux_6 = np.append(green_flux_6,mp.get_fluxes(tran_green_6[i]))
    blue_flux_6 = np.append(blue_flux_6,mp.get_fluxes(tran_blue_6[i]))
    green_flux0_6 = np.append(green_flux0_6,mp.get_fluxes(tran_green0_6[i]))
    
    red_flux_7 = np.append(red_flux_7,mp.get_fluxes(tran_red_7[i]))
    green_flux_7 = np.append(green_flux_7,mp.get_fluxes(tran_green_7[i]))
    blue_flux_7 = np.append(blue_flux_7,mp.get_fluxes(tran_blue_7[i]))
    green_flux0_7 = np.append(green_flux0_7,mp.get_fluxes(tran_green0_7[i]))
    
    red_flux_8 = np.append(red_flux_8,mp.get_fluxes(tran_red_8[i]))
    green_flux_8 = np.append(green_flux_8,mp.get_fluxes(tran_green_8[i]))
    blue_flux_8 = np.append(blue_flux_8,mp.get_fluxes(tran_blue_8[i]))
    green_flux0_8 = np.append(green_flux0_8,mp.get_fluxes(tran_green0_8[i]))
    
refl_flux= sc_refl_flux-straight_refl_data
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00109196 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 70.0903% done, 1.70746 s remaining
# subpixel-averaging is 69.5585% done, 1.75059 s remaining
# subpixel-averaging is 69.8591% done, 1.72586 s remaining
# time for set_epsilon = 31.0707 s
# -----------
# on time step 1 (time=0.02), 8.38141 s/step
# on time step 17 (time=0.34), 0.262204 s/step
# on time step 32 (time=0.64), 0.267596 s/step
# on time step 48 (time=0.96), 0.250671 s/step
# on time step 65 (time=1.3), 0.245597 s/step
# on time step 82 (time=1.64), 0.243888 s/step
# on time step 99 (time=1.98), 0.246433 s/step
# on time step 116 (time=2.32), 0.247977 s/step
# on time step 133 (time=2.66), 0.241361 s/step
# on time step 149 (time=2.98), 0.256296 s/step
# on time step 165 (time=3.3), 0.254104 s/step
# on time step 180 (time=3.6), 0.280465 s/step
# on time step 196 (time=3.92), 0.25114 s/step
# on time step 212 (time=4.24), 0.260518 s/step
# on time step 229 (time=4.58), 0.244274 s/step
# on time step 246 (time=4.92), 0.241535 s/step
# on time step 262 (time=5.24), 0.25958 s/step
# on time step 277 (time=5.54), 0.276805 s/step
# on time step 294 (time=5.88), 0.247978 s/step
# on time step 311 (time=6.22), 0.24461 s/step
# on time step 328 (time=6.56), 0.2476 s/step
# on time step 343 (time=6.86), 0.276073 s/step
# on time step 359 (time=7.18), 0.250892 s/step
# on time step 376 (time=7.52), 0.240405 s/step
# on time step 392 (time=7.84), 0.266052 s/step
# on time step 408 (time=8.16), 0.256251 s/step
# on time step 424 (time=8.48), 0.262362 s/step
# on time step 440 (time=8.8), 0.26873 s/step
# on time step 456 (time=9.12), 0.252742 s/step
# on time step 473 (time=9.46), 0.242787 s/step
# on time step 490 (time=9.8), 0.24489 s/step
# field decay(t = 10.02): 6.608827229655589e-05 / 6.608827229655589e-05 = 1.0
# on time step 507 (time=10.14), 0.248769 s/step
# on time step 523 (time=10.46), 0.253722 s/step
# on time step 539 (time=10.78), 0.252394 s/step
# on time step 554 (time=11.08), 0.271157 s/step
# on time step 569 (time=11.38), 0.268135 s/step
# on time step 584 (time=11.68), 0.269264 s/step
# on time step 599 (time=11.98), 0.275465 s/step
# on time step 613 (time=12.26), 0.288488 s/step
# on time step 629 (time=12.58), 0.262524 s/step
# on time step 645 (time=12.9), 0.263024 s/step
# on time step 660 (time=13.2), 0.275923 s/step
# on time step 676 (time=13.52), 0.25398 s/step
# on time step 690 (time=13.8), 0.289661 s/step
# on time step 705 (time=14.1), 0.266858 s/step
# on time step 721 (time=14.42), 0.255973 s/step
# on time step 738 (time=14.76), 0.249736 s/step
# on time step 755 (time=15.1), 0.243375 s/step
# on time step 770 (time=15.4), 0.273162 s/step
# on time step 786 (time=15.72), 0.263538 s/step
# on time step 801 (time=16.02), 0.270599 s/step
# on time step 817 (time=16.34), 0.256107 s/step
# on time step 833 (time=16.66), 0.256953 s/step
# on time step 849 (time=16.98), 0.262046 s/step
# on time step 864 (time=17.28), 0.273859 s/step
# on time step 881 (time=17.62), 0.241764 s/step
# on time step 897 (time=17.94), 0.258931 s/step
# on time step 912 (time=18.24), 0.270585 s/step
# on time step 927 (time=18.54), 0.270094 s/step
# on time step 943 (time=18.86), 0.258748 s/step
# on time step 959 (time=19.18), 0.254202 s/step
# on time step 975 (time=19.5), 0.257459 s/step
# on time step 990 (time=19.8), 0.277116 s/step
# field decay(t = 20.04): 0.02511224628581102 / 0.02511224628581102 = 1.0
# on time step 1005 (time=20.1), 0.28108 s/step
# on time step 1020 (time=20.4), 0.27817 s/step
# on time step 1035 (time=20.7), 0.284712 s/step
# on time step 1049 (time=20.98), 0.290077 s/step
# on time step 1064 (time=21.28), 0.274483 s/step
# on time step 1080 (time=21.6), 0.269145 s/step
# on time step 1098 (time=21.96), 0.242529 s/step
# on time step 1114 (time=22.28), 0.251064 s/step
# on time step 1130 (time=22.6), 0.263806 s/step
# on time step 1144 (time=22.88), 0.289207 s/step
# on time step 1159 (time=23.18), 0.271386 s/step
# on time step 1174 (time=23.48), 0.276025 s/step
# on time step 1190 (time=23.8), 0.261043 s/step
# on time step 1206 (time=24.12), 0.266583 s/step
# on time step 1221 (time=24.42), 0.274182 s/step
# on time step 1236 (time=24.72), 0.267916 s/step
# on time step 1251 (time=25.02), 0.280432 s/step
# on time step 1266 (time=25.32), 0.273477 s/step
# on time step 1281 (time=25.62), 0.27169 s/step
# on time step 1297 (time=25.94), 0.267165 s/step
# on time step 1313 (time=26.26), 0.255217 s/step
# on time step 1328 (time=26.56), 0.268628 s/step
# on time step 1342 (time=26.84), 0.288782 s/step
# on time step 1356 (time=27.12), 0.300416 s/step
# on time step 1371 (time=27.42), 0.26941 s/step
# on time step 1387 (time=27.74), 0.258465 s/step
# on time step 1404 (time=28.08), 0.258236 s/step
# on time step 1420 (time=28.4), 0.257439 s/step
# on time step 1436 (time=28.72), 0.257879 s/step
# on time step 1452 (time=29.04), 0.256647 s/step
# on time step 1469 (time=29.38), 0.239644 s/step
# on time step 1486 (time=29.72), 0.247379 s/step
# field decay(t = 30.060000000000002): 0.026110424250372 / 0.026110424250372 = 1.0
# on time step 1503 (time=30.06), 0.245778 s/step
# on time step 1520 (time=30.4), 0.251237 s/step
# on time step 1536 (time=30.72), 0.255456 s/step
# on time step 1551 (time=31.02), 0.278871 s/step
# on time step 1566 (time=31.32), 0.287556 s/step
# on time step 1581 (time=31.62), 0.274081 s/step
# on time step 1596 (time=31.92), 0.272276 s/step
# on time step 1612 (time=32.24), 0.263576 s/step
# on time step 1628 (time=32.56), 0.264188 s/step
# on time step 1644 (time=32.88), 0.251825 s/step
# on time step 1660 (time=33.2), 0.262505 s/step
# on time step 1677 (time=33.54), 0.242686 s/step
# on time step 1694 (time=33.88), 0.247898 s/step
# on time step 1710 (time=34.2), 0.251369 s/step
# on time step 1727 (time=34.54), 0.237033 s/step
# on time step 1743 (time=34.86), 0.250651 s/step
# on time step 1760 (time=35.2), 0.246307 s/step
# on time step 1776 (time=35.52), 0.253424 s/step
# on time step 1792 (time=35.84), 0.250041 s/step
# on time step 1809 (time=36.18), 0.245078 s/step
# on time step 1826 (time=36.52), 0.237815 s/step
# on time step 1843 (time=36.86), 0.246668 s/step
# on time step 1858 (time=37.16), 0.267229 s/step
# on time step 1874 (time=37.48), 0.261512 s/step
# on time step 1890 (time=37.8), 0.260092 s/step
# on time step 1904 (time=38.08), 0.287832 s/step
# on time step 1919 (time=38.38), 0.27419 s/step
# on time step 1935 (time=38.7), 0.260881 s/step
# on time step 1951 (time=39.02), 0.260531 s/step
# on time step 1967 (time=39.34), 0.26379 s/step
# on time step 1983 (time=39.66), 0.264799 s/step
# on time step 1999 (time=39.98), 0.256904 s/step
# field decay(t = 40.06): 0.0042274980974485775 / 0.026110424250372 = 0.1619084415063975
# on time step 2015 (time=40.3), 0.255868 s/step
# on time step 2029 (time=40.58), 0.28601 s/step
# on time step 2043 (time=40.86), 0.297953 s/step
# on time step 2057 (time=41.14), 0.296691 s/step
# on time step 2070 (time=41.4), 0.310603 s/step
# on time step 2084 (time=41.68), 0.287321 s/step
# on time step 2100 (time=42), 0.267086 s/step
# on time step 2116 (time=42.32), 0.2627 s/step
# on time step 2132 (time=42.64), 0.262772 s/step
# on time step 2148 (time=42.96), 0.26418 s/step
# on time step 2164 (time=43.28), 0.260596 s/step
# on time step 2180 (time=43.6), 0.261577 s/step
# on time step 2196 (time=43.92), 0.260169 s/step
# on time step 2212 (time=44.24), 0.253445 s/step
# on time step 2228 (time=44.56), 0.264597 s/step
# on time step 2244 (time=44.88), 0.26338 s/step
# on time step 2260 (time=45.2), 0.25888 s/step
# on time step 2276 (time=45.52), 0.261372 s/step
# on time step 2292 (time=45.84), 0.258744 s/step
# on time step 2308 (time=46.16), 0.258151 s/step
# on time step 2324 (time=46.48), 0.264168 s/step
# on time step 2340 (time=46.8), 0.272505 s/step
# on time step 2355 (time=47.1), 0.272845 s/step
# on time step 2370 (time=47.4), 0.269661 s/step
# on time step 2385 (time=47.7), 0.275446 s/step
# on time step 2400 (time=48), 0.285318 s/step
# on time step 2415 (time=48.3), 0.283448 s/step
# on time step 2430 (time=48.6), 0.294325 s/step
# on time step 2444 (time=48.88), 0.290137 s/step
# on time step 2458 (time=49.16), 0.287862 s/step
# on time step 2472 (time=49.44), 0.293748 s/step
# on time step 2486 (time=49.72), 0.29619 s/step
# on time step 2501 (time=50.02), 0.282579 s/step
# field decay(t = 50.08): 0.001881004594818308 / 0.026110424250372 = 0.07204036888797427
# on time step 2515 (time=50.3), 0.299254 s/step
# on time step 2529 (time=50.58), 0.292571 s/step
# on time step 2544 (time=50.88), 0.282222 s/step
# on time step 2558 (time=51.16), 0.289012 s/step
# on time step 2573 (time=51.46), 0.286498 s/step
# on time step 2584 (time=51.68), 0.383235 s/step
# on time step 2598 (time=51.96), 0.294217 s/step
# on time step 2612 (time=52.24), 0.296899 s/step
# on time step 2626 (time=52.52), 0.295563 s/step
# on time step 2640 (time=52.8), 0.301949 s/step
# on time step 2654 (time=53.08), 0.303364 s/step
# on time step 2668 (time=53.36), 0.298489 s/step
# on time step 2682 (time=53.64), 0.294144 s/step
# on time step 2698 (time=53.96), 0.251266 s/step
# on time step 2713 (time=54.26), 0.266889 s/step
# on time step 2729 (time=54.58), 0.254813 s/step
# on time step 2745 (time=54.9), 0.254957 s/step
# on time step 2761 (time=55.22), 0.255517 s/step
# on time step 2777 (time=55.54), 0.252521 s/step
# on time step 2793 (time=55.86), 0.256416 s/step
# on time step 2809 (time=56.18), 0.253388 s/step
# on time step 2825 (time=56.5), 0.256243 s/step
# on time step 2841 (time=56.82), 0.26116 s/step
# on time step 2856 (time=57.12), 0.279601 s/step
# on time step 2873 (time=57.46), 0.247992 s/step
# on time step 2888 (time=57.76), 0.271087 s/step
# on time step 2903 (time=58.06), 0.267927 s/step
# on time step 2918 (time=58.36), 0.267299 s/step
# on time step 2934 (time=58.68), 0.258674 s/step
# on time step 2950 (time=59), 0.257907 s/step
# on time step 2966 (time=59.32), 0.263545 s/step
# on time step 2981 (time=59.62), 0.27956 s/step
# on time step 2997 (time=59.94), 0.261734 s/step
# field decay(t = 60.1): 0.00039166601503237784 / 0.026110424250372 = 0.015000369633090037
# on time step 3012 (time=60.24), 0.271621 s/step
# on time step 3028 (time=60.56), 0.26176 s/step
# on time step 3043 (time=60.86), 0.266936 s/step
# on time step 3059 (time=61.18), 0.257725 s/step
# on time step 3075 (time=61.5), 0.255454 s/step
# on time step 3090 (time=61.8), 0.277521 s/step
# on time step 3106 (time=62.12), 0.26123 s/step
# on time step 3122 (time=62.44), 0.250818 s/step
# on time step 3138 (time=62.76), 0.250343 s/step
# on time step 3153 (time=63.06), 0.278412 s/step
# on time step 3168 (time=63.36), 0.277449 s/step
# on time step 3185 (time=63.7), 0.248912 s/step
# on time step 3202 (time=64.04), 0.24811 s/step
# on time step 3219 (time=64.38), 0.247202 s/step
# on time step 3235 (time=64.7), 0.251948 s/step
# on time step 3252 (time=65.04), 0.239636 s/step
# on time step 3269 (time=65.38), 0.244285 s/step
# on time step 3286 (time=65.72), 0.245033 s/step
# on time step 3303 (time=66.06), 0.247565 s/step
# on time step 3320 (time=66.4), 0.246506 s/step
# on time step 3337 (time=66.74), 0.245332 s/step
# on time step 3353 (time=67.06), 0.250898 s/step
# on time step 3369 (time=67.38), 0.250229 s/step
# on time step 3386 (time=67.72), 0.245667 s/step
# on time step 3402 (time=68.04), 0.251022 s/step
# on time step 3420 (time=68.4), 0.245779 s/step
# on time step 3437 (time=68.74), 0.237021 s/step
# on time step 3454 (time=69.08), 0.249292 s/step
# on time step 3471 (time=69.42), 0.245386 s/step
# on time step 3488 (time=69.76), 0.248492 s/step
# on time step 3505 (time=70.1), 0.241211 s/step
# field decay(t = 70.12): 0.0002421678740895278 / 0.026110424250372 = 0.009274758302178011
# on time step 3522 (time=70.44), 0.247219 s/step
# on time step 3539 (time=70.78), 0.242208 s/step
# on time step 3556 (time=71.12), 0.24701 s/step
# on time step 3573 (time=71.46), 0.247495 s/step
# on time step 3590 (time=71.8), 0.242892 s/step
# on time step 3607 (time=72.14), 0.245637 s/step
# on time step 3624 (time=72.48), 0.247505 s/step
# on time step 3641 (time=72.82), 0.246789 s/step
# on time step 3658 (time=73.16), 0.245285 s/step
# on time step 3675 (time=73.5), 0.247815 s/step
# on time step 3692 (time=73.84), 0.244339 s/step
# on time step 3708 (time=74.16), 0.25075 s/step
# on time step 3725 (time=74.5), 0.240801 s/step
# on time step 3742 (time=74.84), 0.241053 s/step
# on time step 3759 (time=75.18), 0.244868 s/step
# on time step 3775 (time=75.5), 0.252209 s/step
# on time step 3791 (time=75.82), 0.250266 s/step
# on time step 3808 (time=76.16), 0.248312 s/step
# on time step 3825 (time=76.5), 0.244584 s/step
# on time step 3841 (time=76.82), 0.254473 s/step
# on time step 3858 (time=77.16), 0.24199 s/step
# on time step 3875 (time=77.5), 0.24689 s/step
# on time step 3892 (time=77.84), 0.247243 s/step
# on time step 3908 (time=78.16), 0.250676 s/step
# on time step 3925 (time=78.5), 0.247509 s/step
# on time step 3942 (time=78.84), 0.248909 s/step
# on time step 3959 (time=79.18), 0.237087 s/step
# on time step 3976 (time=79.52), 0.24232 s/step
# on time step 3993 (time=79.86), 0.248198 s/step
# field decay(t = 80.14): 9.967630416048819e-05 / 0.026110424250372 = 0.003817490792363057
# on time step 4010 (time=80.2), 0.247394 s/step
# on time step 4027 (time=80.54), 0.245137 s/step
# on time step 4044 (time=80.88), 0.244835 s/step
# on time step 4061 (time=81.22), 0.248064 s/step
# on time step 4078 (time=81.56), 0.246573 s/step
# on time step 4095 (time=81.9), 0.247558 s/step
# on time step 4112 (time=82.24), 0.242192 s/step
# on time step 4128 (time=82.56), 0.250401 s/step
# on time step 4145 (time=82.9), 0.247512 s/step
# on time step 4162 (time=83.24), 0.247455 s/step
# on time step 4179 (time=83.58), 0.241373 s/step
# on time step 4196 (time=83.92), 0.24412 s/step
# on time step 4213 (time=84.26), 0.242692 s/step
# on time step 4230 (time=84.6), 0.248963 s/step
# on time step 4247 (time=84.94), 0.240571 s/step
# on time step 4264 (time=85.28), 0.245338 s/step
# on time step 4281 (time=85.62), 0.248756 s/step
# on time step 4298 (time=85.96), 0.243866 s/step
# on time step 4315 (time=86.3), 0.247068 s/step
# on time step 4332 (time=86.64), 0.245056 s/step
# on time step 4349 (time=86.98), 0.245697 s/step
# on time step 4366 (time=87.32), 0.245211 s/step
# on time step 4383 (time=87.66), 0.246864 s/step
# on time step 4400 (time=88), 0.247136 s/step
# on time step 4417 (time=88.34), 0.242826 s/step
# on time step 4434 (time=88.68), 0.247902 s/step
# on time step 4451 (time=89.02), 0.241404 s/step
# on time step 4467 (time=89.34), 0.250675 s/step
# on time step 4484 (time=89.68), 0.244969 s/step
# on time step 4500 (time=90), 0.251122 s/step
# field decay(t = 90.16): 9.353550808260108e-05 / 0.026110424250372 = 0.0035823051814743473
# on time step 4517 (time=90.34), 0.239191 s/step
# on time step 4534 (time=90.68), 0.245898 s/step
# on time step 4551 (time=91.02), 0.243536 s/step
# on time step 4567 (time=91.34), 0.250384 s/step
# on time step 4584 (time=91.68), 0.247821 s/step
# on time step 4601 (time=92.02), 0.247071 s/step
# on time step 4618 (time=92.36), 0.241521 s/step
# on time step 4634 (time=92.68), 0.250988 s/step
# on time step 4650 (time=93), 0.259213 s/step
# on time step 4667 (time=93.34), 0.248641 s/step
# on time step 4684 (time=93.68), 0.247112 s/step
# on time step 4701 (time=94.02), 0.242024 s/step
# on time step 4718 (time=94.36), 0.246705 s/step
# on time step 4735 (time=94.7), 0.248171 s/step
# on time step 4752 (time=95.04), 0.245594 s/step
# on time step 4769 (time=95.38), 0.236137 s/step
# on time step 4786 (time=95.72), 0.24479 s/step
# on time step 4803 (time=96.06), 0.247732 s/step
# on time step 4820 (time=96.4), 0.248731 s/step
# on time step 4837 (time=96.74), 0.243504 s/step
# on time step 4853 (time=97.06), 0.250622 s/step
# on time step 4870 (time=97.4), 0.246374 s/step
# on time step 4886 (time=97.72), 0.251297 s/step
# on time step 4903 (time=98.06), 0.247183 s/step
# on time step 4920 (time=98.4), 0.246838 s/step
# on time step 4937 (time=98.74), 0.2416 s/step
# on time step 4954 (time=99.08), 0.247132 s/step
# on time step 4971 (time=99.42), 0.244825 s/step
# on time step 4988 (time=99.76), 0.246843 s/step
# on time step 5004 (time=100.08), 0.250362 s/step
# field decay(t = 100.18): 1.778958570377327e-05 / 0.026110424250372 = 0.000681321204634192
# run 0 finished at t = 100.18 (5009 timesteps)

# %%
print(blue_flux[5] / tran_flux[5])
print(blue_flux_1[5] / tran_flux[5])
print(blue_flux_2[5] / tran_flux[5])
print(blue_flux_3[5] / tran_flux[5])
print(blue_flux_4[5] / tran_flux[5])
print(blue_flux_5[5] / tran_flux[5])
print(blue_flux_6[5] / tran_flux[5])
print(blue_flux_7[5] / tran_flux[5])
print(blue_flux_8[5] / tran_flux[5])
# Out:
# 0.6086085638800414
# 0.0008857928167966513
# 0.0033506992708859265
# 0.00070536960535979
# 0.0044807820919590645
# 0.003350699270885919
# 0.0008332027798973082
# 0.004480782091959073
# 0.0008857928167966531

# %%
print(green_flux[15] / tran_flux[15])
print(green_flux_1[15] / tran_flux[15])
print(green_flux_2[15] / tran_flux[15])
print(green_flux_3[15] / tran_flux[15])
print(green_flux_4[15] / tran_flux[15])
print(green_flux_5[15] / tran_flux[15])
print(green_flux_6[15] / tran_flux[15])
print(green_flux_7[15] / tran_flux[15])
print(green_flux_8[15] / tran_flux[15])
# Out:
# 0.3934719176662677
# 0.0007104519282435366
# 0.0018227163362200343
# 0.00022532132571504026
# 0.002121352044665922
# 0.002516175071842103
# 0.00045225875935578483
# 0.0031716581040720925
# 0.0012067527571674934

# %%
print(red_flux[25] / tran_flux[25])
print(red_flux_1[25] / tran_flux[25])
print(red_flux_2[25] / tran_flux[25])
print(red_flux_3[25] / tran_flux[25])
print(red_flux_4[25] / tran_flux[25])
print(red_flux_5[25] / tran_flux[25])
print(red_flux_6[25] / tran_flux[25])
print(red_flux_7[25] / tran_flux[25])
print(red_flux_8[25] / tran_flux[25])
# Out:
# 0.7539381127184075
# 0.0006282320246749268
# 0.00383574661370242
# 0.0006850414843264298
# 0.003485279534143415
# 0.0038357466137024197
# 0.00034887804149313944
# 0.0034852795341434144
# 0.0006282320246749247
