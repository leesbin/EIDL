# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=5)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 0 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * design_region_width_x)) + 1
Ny = int(round(design_region_resolution * design_region_width_y)) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, SiN, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00102687 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 59.638% done, 2.70798 s remaining
# subpixel-averaging is 62.598% done, 2.39012 s remaining
# subpixel-averaging is 63.2223% done, 2.32739 s remaining
# time for set_epsilon = 32.9798 s
# -----------
# on time step 1 (time=0.02), 7.85532 s/step
# on time step 24 (time=0.48), 0.181068 s/step
# on time step 46 (time=0.92), 0.182347 s/step
# on time step 69 (time=1.38), 0.180876 s/step
# on time step 92 (time=1.84), 0.180656 s/step
# on time step 115 (time=2.3), 0.180377 s/step
# on time step 137 (time=2.74), 0.182628 s/step
# on time step 159 (time=3.18), 0.188627 s/step
# on time step 181 (time=3.62), 0.183433 s/step
# on time step 203 (time=4.06), 0.184529 s/step
# on time step 225 (time=4.5), 0.185028 s/step
# on time step 247 (time=4.94), 0.186386 s/step
# on time step 269 (time=5.38), 0.188629 s/step
# on time step 292 (time=5.84), 0.180256 s/step
# on time step 314 (time=6.28), 0.181948 s/step
# on time step 336 (time=6.72), 0.186006 s/step
# on time step 358 (time=7.16), 0.183694 s/step
# on time step 380 (time=7.6), 0.185175 s/step
# on time step 402 (time=8.04), 0.190315 s/step
# on time step 424 (time=8.48), 0.186419 s/step
# on time step 446 (time=8.92), 0.188612 s/step
# on time step 468 (time=9.36), 0.187433 s/step
# on time step 491 (time=9.82), 0.181345 s/step
# field decay(t = 10.02): 1.8533633925333784e-07 / 1.8533633925333784e-07 = 1.0
# on time step 513 (time=10.26), 0.182005 s/step
# on time step 536 (time=10.72), 0.179746 s/step
# on time step 559 (time=11.18), 0.18153 s/step
# on time step 582 (time=11.64), 0.181135 s/step
# on time step 605 (time=12.1), 0.18072 s/step
# on time step 628 (time=12.56), 0.181637 s/step
# on time step 651 (time=13.02), 0.18071 s/step
# on time step 674 (time=13.48), 0.1805 s/step
# on time step 697 (time=13.94), 0.181124 s/step
# on time step 720 (time=14.4), 0.181193 s/step
# on time step 742 (time=14.84), 0.183387 s/step
# on time step 765 (time=15.3), 0.180069 s/step
# on time step 788 (time=15.76), 0.179774 s/step
# on time step 811 (time=16.22), 0.180045 s/step
# on time step 834 (time=16.68), 0.180721 s/step
# on time step 857 (time=17.14), 0.181189 s/step
# on time step 880 (time=17.6), 0.180997 s/step
# on time step 902 (time=18.04), 0.18193 s/step
# on time step 925 (time=18.5), 0.180483 s/step
# on time step 947 (time=18.94), 0.181901 s/step
# on time step 970 (time=19.4), 0.181554 s/step
# on time step 993 (time=19.86), 0.180766 s/step
# field decay(t = 20.04): 0.022111779331523973 / 0.022111779331523973 = 1.0
# on time step 1015 (time=20.3), 0.183648 s/step
# on time step 1038 (time=20.76), 0.180404 s/step
# on time step 1060 (time=21.2), 0.183332 s/step
# on time step 1083 (time=21.66), 0.18021 s/step
# on time step 1106 (time=22.12), 0.180057 s/step
# on time step 1129 (time=22.58), 0.179547 s/step
# on time step 1152 (time=23.04), 0.179776 s/step
# on time step 1175 (time=23.5), 0.181099 s/step
# on time step 1198 (time=23.96), 0.18096 s/step
# on time step 1221 (time=24.42), 0.180772 s/step
# on time step 1244 (time=24.88), 0.181527 s/step
# on time step 1266 (time=25.32), 0.184358 s/step
# on time step 1288 (time=25.76), 0.182017 s/step
# on time step 1310 (time=26.2), 0.184765 s/step
# on time step 1332 (time=26.64), 0.185717 s/step
# on time step 1354 (time=27.08), 0.181946 s/step
# on time step 1377 (time=27.54), 0.180748 s/step
# on time step 1400 (time=28), 0.181727 s/step
# on time step 1423 (time=28.46), 0.180422 s/step
# on time step 1446 (time=28.92), 0.180894 s/step
# on time step 1469 (time=29.38), 0.181247 s/step
# on time step 1491 (time=29.82), 0.184834 s/step
# field decay(t = 30.060000000000002): 0.07262087494996683 / 0.07262087494996683 = 1.0
# on time step 1513 (time=30.26), 0.184746 s/step
# on time step 1536 (time=30.72), 0.181442 s/step
# on time step 1559 (time=31.18), 0.180923 s/step
# on time step 1581 (time=31.62), 0.18197 s/step
# on time step 1604 (time=32.08), 0.18153 s/step
# on time step 1627 (time=32.54), 0.180749 s/step
# on time step 1650 (time=33), 0.180447 s/step
# on time step 1673 (time=33.46), 0.181503 s/step
# on time step 1696 (time=33.92), 0.180645 s/step
# on time step 1719 (time=34.38), 0.180444 s/step
# on time step 1742 (time=34.84), 0.181382 s/step
# on time step 1765 (time=35.3), 0.180434 s/step
# on time step 1788 (time=35.76), 0.180631 s/step
# on time step 1811 (time=36.22), 0.181162 s/step
# on time step 1834 (time=36.68), 0.18109 s/step
# on time step 1857 (time=37.14), 0.180321 s/step
# on time step 1880 (time=37.6), 0.180678 s/step
# on time step 1903 (time=38.06), 0.180726 s/step
# on time step 1926 (time=38.52), 0.179867 s/step
# on time step 1949 (time=38.98), 0.180212 s/step
# on time step 1972 (time=39.44), 0.179435 s/step
# on time step 1995 (time=39.9), 0.17947 s/step
# field decay(t = 40.06): 0.00380584749428311 / 0.07262087494996683 = 0.05240707299251354
# on time step 2018 (time=40.36), 0.180956 s/step
# on time step 2041 (time=40.82), 0.181207 s/step
# on time step 2064 (time=41.28), 0.180203 s/step
# on time step 2086 (time=41.72), 0.183309 s/step
# on time step 2109 (time=42.18), 0.18103 s/step
# on time step 2131 (time=42.62), 0.182617 s/step
# on time step 2154 (time=43.08), 0.180996 s/step
# on time step 2177 (time=43.54), 0.181445 s/step
# on time step 2200 (time=44), 0.180568 s/step
# on time step 2222 (time=44.44), 0.184772 s/step
# on time step 2245 (time=44.9), 0.181409 s/step
# on time step 2268 (time=45.36), 0.180346 s/step
# on time step 2291 (time=45.82), 0.181404 s/step
# on time step 2314 (time=46.28), 0.180769 s/step
# on time step 2337 (time=46.74), 0.180535 s/step
# on time step 2359 (time=47.18), 0.18465 s/step
# on time step 2382 (time=47.64), 0.18155 s/step
# on time step 2405 (time=48.1), 0.180578 s/step
# on time step 2428 (time=48.56), 0.180924 s/step
# on time step 2450 (time=49), 0.1825 s/step
# on time step 2473 (time=49.46), 0.179354 s/step
# on time step 2494 (time=49.88), 0.192697 s/step
# field decay(t = 50.08): 0.00034156884980238704 / 0.07262087494996683 = 0.004703452692324565
# on time step 2515 (time=50.3), 0.196487 s/step
# on time step 2538 (time=50.76), 0.181086 s/step
# on time step 2561 (time=51.22), 0.180474 s/step
# on time step 2584 (time=51.68), 0.180084 s/step
# on time step 2607 (time=52.14), 0.180538 s/step
# on time step 2630 (time=52.6), 0.18102 s/step
# on time step 2653 (time=53.06), 0.179818 s/step
# on time step 2676 (time=53.52), 0.180118 s/step
# on time step 2699 (time=53.98), 0.180029 s/step
# on time step 2722 (time=54.44), 0.180334 s/step
# on time step 2745 (time=54.9), 0.179929 s/step
# on time step 2768 (time=55.36), 0.180219 s/step
# on time step 2791 (time=55.82), 0.180142 s/step
# on time step 2814 (time=56.28), 0.180003 s/step
# on time step 2837 (time=56.74), 0.179927 s/step
# on time step 2860 (time=57.2), 0.180536 s/step
# on time step 2882 (time=57.64), 0.1856 s/step
# on time step 2904 (time=58.08), 0.186635 s/step
# on time step 2927 (time=58.54), 0.180909 s/step
# on time step 2950 (time=59), 0.180463 s/step
# on time step 2973 (time=59.46), 0.181277 s/step
# on time step 2995 (time=59.9), 0.182673 s/step
# field decay(t = 60.1): 3.858119613561425e-05 / 0.07262087494996683 = 0.0005312686767020544
# run 0 finished at t = 60.1 (3005 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000648022 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 63.523% done, 2.29706 s remaining
# subpixel-averaging is 62.4361% done, 2.40703 s remaining
# subpixel-averaging is 63.153% done, 2.33434 s remaining
# time for set_epsilon = 32.2281 s
# -----------
# on time step 1 (time=0.02), 7.85944 s/step
# on time step 24 (time=0.48), 0.18142 s/step
# on time step 47 (time=0.94), 0.180679 s/step
# on time step 70 (time=1.4), 0.180904 s/step
# on time step 92 (time=1.84), 0.181874 s/step
# on time step 115 (time=2.3), 0.181641 s/step
# on time step 138 (time=2.76), 0.181267 s/step
# on time step 160 (time=3.2), 0.18187 s/step
# on time step 183 (time=3.66), 0.180976 s/step
# on time step 206 (time=4.12), 0.1811 s/step
# on time step 229 (time=4.58), 0.181626 s/step
# on time step 252 (time=5.04), 0.180945 s/step
# on time step 275 (time=5.5), 0.181544 s/step
# on time step 297 (time=5.94), 0.185337 s/step
# on time step 320 (time=6.4), 0.181657 s/step
# on time step 343 (time=6.86), 0.181027 s/step
# on time step 366 (time=7.32), 0.181571 s/step
# on time step 389 (time=7.78), 0.180798 s/step
# on time step 412 (time=8.24), 0.180752 s/step
# on time step 435 (time=8.7), 0.181066 s/step
# on time step 458 (time=9.16), 0.179954 s/step
# on time step 481 (time=9.62), 0.180707 s/step
# field decay(t = 10.02): 5.454739493286558e-09 / 5.454739493286558e-09 = 1.0
# on time step 503 (time=10.06), 0.183391 s/step
# on time step 526 (time=10.52), 0.181771 s/step
# on time step 548 (time=10.96), 0.184086 s/step
# on time step 570 (time=11.4), 0.183379 s/step
# on time step 593 (time=11.86), 0.180461 s/step
# on time step 616 (time=12.32), 0.180142 s/step
# on time step 639 (time=12.78), 0.180798 s/step
# on time step 662 (time=13.24), 0.18042 s/step
# on time step 684 (time=13.68), 0.190965 s/step
# on time step 706 (time=14.12), 0.188241 s/step
# on time step 729 (time=14.58), 0.180233 s/step
# on time step 752 (time=15.04), 0.179947 s/step
# on time step 775 (time=15.5), 0.180473 s/step
# on time step 797 (time=15.94), 0.185121 s/step
# on time step 820 (time=16.4), 0.181626 s/step
# on time step 843 (time=16.86), 0.180674 s/step
# on time step 865 (time=17.3), 0.183434 s/step
# on time step 888 (time=17.76), 0.180604 s/step
# on time step 911 (time=18.22), 0.180335 s/step
# on time step 934 (time=18.68), 0.181111 s/step
# on time step 957 (time=19.14), 0.180204 s/step
# on time step 980 (time=19.6), 0.180889 s/step
# field decay(t = 20.04): 0.0002907718569475767 / 0.0002907718569475767 = 1.0
# on time step 1002 (time=20.04), 0.183039 s/step
# on time step 1025 (time=20.5), 0.181238 s/step
# on time step 1048 (time=20.96), 0.17985 s/step
# on time step 1071 (time=21.42), 0.181184 s/step
# on time step 1094 (time=21.88), 0.18085 s/step
# on time step 1117 (time=22.34), 0.181053 s/step
# on time step 1140 (time=22.8), 0.181109 s/step
# on time step 1163 (time=23.26), 0.181001 s/step
# on time step 1186 (time=23.72), 0.181437 s/step
# on time step 1209 (time=24.18), 0.18158 s/step
# on time step 1232 (time=24.64), 0.180662 s/step
# on time step 1255 (time=25.1), 0.18163 s/step
# on time step 1278 (time=25.56), 0.180051 s/step
# on time step 1301 (time=26.02), 0.179908 s/step
# on time step 1324 (time=26.48), 0.181002 s/step
# on time step 1347 (time=26.94), 0.180174 s/step
# on time step 1370 (time=27.4), 0.18004 s/step
# on time step 1393 (time=27.86), 0.180139 s/step
# on time step 1416 (time=28.32), 0.180256 s/step
# on time step 1439 (time=28.78), 0.180864 s/step
# on time step 1461 (time=29.22), 0.182859 s/step
# on time step 1483 (time=29.66), 0.185845 s/step
# field decay(t = 30.060000000000002): 0.05899836712535801 / 0.05899836712535801 = 1.0
# on time step 1506 (time=30.12), 0.180955 s/step
# on time step 1529 (time=30.58), 0.181038 s/step
# on time step 1552 (time=31.04), 0.181356 s/step
# on time step 1575 (time=31.5), 0.180823 s/step
# on time step 1597 (time=31.94), 0.184348 s/step
# on time step 1619 (time=32.38), 0.18419 s/step
# on time step 1641 (time=32.82), 0.182417 s/step
# on time step 1664 (time=33.28), 0.180828 s/step
# on time step 1686 (time=33.72), 0.181902 s/step
# on time step 1709 (time=34.18), 0.180922 s/step
# on time step 1732 (time=34.64), 0.180877 s/step
# on time step 1754 (time=35.08), 0.182511 s/step
# on time step 1777 (time=35.54), 0.180326 s/step
# on time step 1800 (time=36), 0.180277 s/step
# on time step 1822 (time=36.44), 0.184563 s/step
# on time step 1844 (time=36.88), 0.181958 s/step
# on time step 1867 (time=37.34), 0.179834 s/step
# on time step 1890 (time=37.8), 0.180429 s/step
# on time step 1913 (time=38.26), 0.180323 s/step
# on time step 1936 (time=38.72), 0.179714 s/step
# on time step 1959 (time=39.18), 0.180686 s/step
# on time step 1982 (time=39.64), 0.180479 s/step
# field decay(t = 40.06): 0.10928052224560256 / 0.10928052224560256 = 1.0
# on time step 2005 (time=40.1), 0.180051 s/step
# on time step 2027 (time=40.54), 0.183352 s/step
# on time step 2049 (time=40.98), 0.18746 s/step
# on time step 2070 (time=41.4), 0.193375 s/step
# on time step 2091 (time=41.82), 0.19108 s/step
# on time step 2113 (time=42.26), 0.186004 s/step
# on time step 2135 (time=42.7), 0.187278 s/step
# on time step 2157 (time=43.14), 0.184063 s/step
# on time step 2180 (time=43.6), 0.181159 s/step
# on time step 2203 (time=44.06), 0.180732 s/step
# on time step 2226 (time=44.52), 0.181168 s/step
# on time step 2249 (time=44.98), 0.180612 s/step
# on time step 2272 (time=45.44), 0.180245 s/step
# on time step 2295 (time=45.9), 0.180274 s/step
# on time step 2317 (time=46.34), 0.182364 s/step
# on time step 2340 (time=46.8), 0.180559 s/step
# on time step 2363 (time=47.26), 0.180761 s/step
# on time step 2386 (time=47.72), 0.181538 s/step
# on time step 2408 (time=48.16), 0.182911 s/step
# on time step 2431 (time=48.62), 0.181074 s/step
# on time step 2454 (time=49.08), 0.181384 s/step
# on time step 2477 (time=49.54), 0.181382 s/step
# on time step 2499 (time=49.98), 0.183252 s/step
# field decay(t = 50.08): 0.053127293933612534 / 0.10928052224560256 = 0.48615519803439056
# on time step 2521 (time=50.42), 0.185835 s/step
# on time step 2543 (time=50.86), 0.189208 s/step
# on time step 2564 (time=51.28), 0.196327 s/step
# on time step 2584 (time=51.68), 0.20066 s/step
# on time step 2606 (time=52.12), 0.184645 s/step
# on time step 2628 (time=52.56), 0.18224 s/step
# on time step 2651 (time=53.02), 0.181089 s/step
# on time step 2674 (time=53.48), 0.181234 s/step
# on time step 2697 (time=53.94), 0.180883 s/step
# on time step 2720 (time=54.4), 0.181002 s/step
# on time step 2743 (time=54.86), 0.18151 s/step
# on time step 2766 (time=55.32), 0.180592 s/step
# on time step 2788 (time=55.76), 0.184079 s/step
# on time step 2811 (time=56.22), 0.181218 s/step
# on time step 2834 (time=56.68), 0.18046 s/step
# on time step 2857 (time=57.14), 0.180423 s/step
# on time step 2880 (time=57.6), 0.180632 s/step
# on time step 2903 (time=58.06), 0.180345 s/step
# on time step 2926 (time=58.52), 0.180585 s/step
# on time step 2949 (time=58.98), 0.181059 s/step
# on time step 2972 (time=59.44), 0.180777 s/step
# on time step 2995 (time=59.9), 0.180401 s/step
# field decay(t = 60.1): 0.0008130413677541701 / 0.10928052224560256 = 0.007439947678204721
# on time step 3017 (time=60.34), 0.182348 s/step
# on time step 3039 (time=60.78), 0.187111 s/step
# on time step 3060 (time=61.2), 0.196633 s/step
# on time step 3081 (time=61.62), 0.192487 s/step
# on time step 3103 (time=62.06), 0.189907 s/step
# on time step 3124 (time=62.48), 0.194767 s/step
# on time step 3145 (time=62.9), 0.200043 s/step
# on time step 3166 (time=63.32), 0.196568 s/step
# on time step 3188 (time=63.76), 0.185862 s/step
# on time step 3209 (time=64.18), 0.191669 s/step
# on time step 3231 (time=64.62), 0.188184 s/step
# on time step 3254 (time=65.08), 0.180226 s/step
# on time step 3276 (time=65.52), 0.183421 s/step
# on time step 3298 (time=65.96), 0.183041 s/step
# on time step 3320 (time=66.4), 0.184929 s/step
# on time step 3342 (time=66.84), 0.182568 s/step
# on time step 3364 (time=67.28), 0.183202 s/step
# on time step 3387 (time=67.74), 0.18096 s/step
# on time step 3409 (time=68.18), 0.18347 s/step
# on time step 3431 (time=68.62), 0.187899 s/step
# on time step 3453 (time=69.06), 0.184471 s/step
# on time step 3475 (time=69.5), 0.186328 s/step
# on time step 3496 (time=69.92), 0.199417 s/step
# field decay(t = 70.12): 0.00011359892937642534 / 0.10928052224560256 = 0.0010395167138853654
# on time step 3519 (time=70.38), 0.18143 s/step
# on time step 3542 (time=70.84), 0.180998 s/step
# on time step 3565 (time=71.3), 0.181201 s/step
# on time step 3588 (time=71.76), 0.180468 s/step
# on time step 3611 (time=72.22), 0.181167 s/step
# on time step 3633 (time=72.66), 0.18373 s/step
# on time step 3656 (time=73.12), 0.181195 s/step
# on time step 3678 (time=73.56), 0.185075 s/step
# on time step 3700 (time=74), 0.189386 s/step
# on time step 3722 (time=74.44), 0.189226 s/step
# on time step 3744 (time=74.88), 0.188318 s/step
# on time step 3766 (time=75.32), 0.188364 s/step
# on time step 3788 (time=75.76), 0.18878 s/step
# on time step 3810 (time=76.2), 0.187382 s/step
# on time step 3832 (time=76.64), 0.182058 s/step
# on time step 3855 (time=77.1), 0.180897 s/step
# on time step 3877 (time=77.54), 0.181978 s/step
# on time step 3899 (time=77.98), 0.181918 s/step
# on time step 3922 (time=78.44), 0.181514 s/step
# on time step 3945 (time=78.9), 0.180985 s/step
# on time step 3967 (time=79.34), 0.182022 s/step
# on time step 3989 (time=79.78), 0.181842 s/step
# field decay(t = 80.14): 2.772337369811425e-05 / 0.10928052224560256 = 0.0002536899817865744
# run 0 finished at t = 80.14 (4007 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000663996 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 63.2223% done, 2.32719 s remaining
# subpixel-averaging is 62.413% done, 2.40969 s remaining
# subpixel-averaging is 61.673% done, 2.48603 s remaining
# time for set_epsilon = 32.4647 s
# -----------
# on time step 1 (time=0.02), 7.94198 s/step
# on time step 24 (time=0.48), 0.180052 s/step
# on time step 47 (time=0.94), 0.181758 s/step
# on time step 70 (time=1.4), 0.181106 s/step
# on time step 93 (time=1.86), 0.181295 s/step
# on time step 116 (time=2.32), 0.181164 s/step
# on time step 139 (time=2.78), 0.180485 s/step
# on time step 161 (time=3.22), 0.183 s/step
# on time step 183 (time=3.66), 0.187066 s/step
# on time step 205 (time=4.1), 0.182037 s/step
# on time step 228 (time=4.56), 0.181608 s/step
# on time step 250 (time=5), 0.182348 s/step
# on time step 273 (time=5.46), 0.181095 s/step
# on time step 294 (time=5.88), 0.191343 s/step
# on time step 316 (time=6.32), 0.182036 s/step
# on time step 339 (time=6.78), 0.18126 s/step
# on time step 362 (time=7.24), 0.180096 s/step
# on time step 385 (time=7.7), 0.179701 s/step
# on time step 408 (time=8.16), 0.180749 s/step
# on time step 431 (time=8.62), 0.180428 s/step
# on time step 453 (time=9.06), 0.185962 s/step
# on time step 475 (time=9.5), 0.182472 s/step
# on time step 497 (time=9.94), 0.189105 s/step
# field decay(t = 10.02): 5.688061507660079e-09 / 5.688061507660079e-09 = 1.0
# on time step 520 (time=10.4), 0.179824 s/step
# on time step 543 (time=10.86), 0.180473 s/step
# on time step 566 (time=11.32), 0.179774 s/step
# on time step 589 (time=11.78), 0.180459 s/step
# on time step 612 (time=12.24), 0.180844 s/step
# on time step 635 (time=12.7), 0.180114 s/step
# on time step 658 (time=13.16), 0.179769 s/step
# on time step 681 (time=13.62), 0.180759 s/step
# on time step 703 (time=14.06), 0.18217 s/step
# on time step 724 (time=14.48), 0.194989 s/step
# on time step 747 (time=14.94), 0.180436 s/step
# on time step 770 (time=15.4), 0.179861 s/step
# on time step 793 (time=15.86), 0.179896 s/step
# on time step 815 (time=16.3), 0.18855 s/step
# on time step 837 (time=16.74), 0.187372 s/step
# on time step 859 (time=17.18), 0.182068 s/step
# on time step 881 (time=17.62), 0.183149 s/step
# on time step 904 (time=18.08), 0.181434 s/step
# on time step 926 (time=18.52), 0.182249 s/step
# on time step 949 (time=18.98), 0.180238 s/step
# on time step 972 (time=19.44), 0.180647 s/step
# on time step 995 (time=19.9), 0.181015 s/step
# field decay(t = 20.04): 0.00015812619263710922 / 0.00015812619263710922 = 1.0
# on time step 1018 (time=20.36), 0.181561 s/step
# on time step 1041 (time=20.82), 0.181012 s/step
# on time step 1064 (time=21.28), 0.179797 s/step
# on time step 1087 (time=21.74), 0.179722 s/step
# on time step 1109 (time=22.18), 0.182892 s/step
# on time step 1132 (time=22.64), 0.180136 s/step
# on time step 1155 (time=23.1), 0.17997 s/step
# on time step 1178 (time=23.56), 0.180959 s/step
# on time step 1201 (time=24.02), 0.179668 s/step
# on time step 1224 (time=24.48), 0.180036 s/step
# on time step 1246 (time=24.92), 0.182189 s/step
# on time step 1269 (time=25.38), 0.179975 s/step
# on time step 1292 (time=25.84), 0.180499 s/step
# on time step 1315 (time=26.3), 0.180591 s/step
# on time step 1337 (time=26.74), 0.183263 s/step
# on time step 1359 (time=27.18), 0.186624 s/step
# on time step 1381 (time=27.62), 0.186282 s/step
# on time step 1403 (time=28.06), 0.186264 s/step
# on time step 1425 (time=28.5), 0.189338 s/step
# on time step 1447 (time=28.94), 0.183407 s/step
# on time step 1469 (time=29.38), 0.184739 s/step
# on time step 1491 (time=29.82), 0.181927 s/step
# field decay(t = 30.060000000000002): 0.021614559305783113 / 0.021614559305783113 = 1.0
# on time step 1513 (time=30.26), 0.188734 s/step
# on time step 1535 (time=30.7), 0.189293 s/step
# on time step 1557 (time=31.14), 0.186861 s/step
# on time step 1579 (time=31.58), 0.187002 s/step
# on time step 1601 (time=32.02), 0.186444 s/step
# on time step 1623 (time=32.46), 0.183631 s/step
# on time step 1645 (time=32.9), 0.189532 s/step
# on time step 1667 (time=33.34), 0.18623 s/step
# on time step 1689 (time=33.78), 0.1854 s/step
# on time step 1711 (time=34.22), 0.183536 s/step
# on time step 1732 (time=34.64), 0.191472 s/step
# on time step 1753 (time=35.06), 0.197397 s/step
# on time step 1774 (time=35.48), 0.191228 s/step
# on time step 1797 (time=35.94), 0.179844 s/step
# on time step 1819 (time=36.38), 0.184568 s/step
# on time step 1841 (time=36.82), 0.189513 s/step
# on time step 1863 (time=37.26), 0.189045 s/step
# on time step 1884 (time=37.68), 0.19527 s/step
# on time step 1906 (time=38.12), 0.187219 s/step
# on time step 1928 (time=38.56), 0.184026 s/step
# on time step 1950 (time=39), 0.186279 s/step
# on time step 1972 (time=39.44), 0.183199 s/step
# on time step 1994 (time=39.88), 0.186199 s/step
# field decay(t = 40.06): 0.028457690674203732 / 0.028457690674203732 = 1.0
# on time step 2016 (time=40.32), 0.185695 s/step
# on time step 2039 (time=40.78), 0.181667 s/step
# on time step 2061 (time=41.22), 0.185499 s/step
# on time step 2083 (time=41.66), 0.186419 s/step
# on time step 2106 (time=42.12), 0.179136 s/step
# on time step 2129 (time=42.58), 0.180047 s/step
# on time step 2150 (time=43), 0.191872 s/step
# on time step 2171 (time=43.42), 0.192853 s/step
# on time step 2192 (time=43.84), 0.19655 s/step
# on time step 2213 (time=44.26), 0.199198 s/step
# on time step 2233 (time=44.66), 0.200641 s/step
# on time step 2255 (time=45.1), 0.183022 s/step
# on time step 2278 (time=45.56), 0.179202 s/step
# on time step 2301 (time=46.02), 0.179273 s/step
# on time step 2324 (time=46.48), 0.180339 s/step
# on time step 2345 (time=46.9), 0.191281 s/step
# on time step 2367 (time=47.34), 0.185189 s/step
# on time step 2390 (time=47.8), 0.179794 s/step
# on time step 2413 (time=48.26), 0.181085 s/step
# on time step 2435 (time=48.7), 0.186124 s/step
# on time step 2457 (time=49.14), 0.188009 s/step
# on time step 2479 (time=49.58), 0.1897 s/step
# on time step 2501 (time=50.02), 0.18668 s/step
# field decay(t = 50.08): 0.011394740975352239 / 0.028457690674203732 = 0.40040989642498714
# on time step 2522 (time=50.44), 0.193243 s/step
# on time step 2543 (time=50.86), 0.192462 s/step
# on time step 2564 (time=51.28), 0.190752 s/step
# on time step 2587 (time=51.74), 0.180935 s/step
# on time step 2609 (time=52.18), 0.19005 s/step
# on time step 2630 (time=52.6), 0.197011 s/step
# on time step 2651 (time=53.02), 0.195533 s/step
# on time step 2672 (time=53.44), 0.196179 s/step
# on time step 2694 (time=53.88), 0.189189 s/step
# on time step 2716 (time=54.32), 0.188609 s/step
# on time step 2738 (time=54.76), 0.18424 s/step
# on time step 2760 (time=55.2), 0.186129 s/step
# on time step 2781 (time=55.62), 0.196557 s/step
# on time step 2801 (time=56.02), 0.201131 s/step
# on time step 2822 (time=56.44), 0.19642 s/step
# on time step 2843 (time=56.86), 0.194021 s/step
# on time step 2864 (time=57.28), 0.193121 s/step
# on time step 2886 (time=57.72), 0.18974 s/step
# on time step 2907 (time=58.14), 0.195177 s/step
# on time step 2929 (time=58.58), 0.189407 s/step
# on time step 2951 (time=59.02), 0.186665 s/step
# on time step 2973 (time=59.46), 0.18346 s/step
# on time step 2995 (time=59.9), 0.188467 s/step
# field decay(t = 60.1): 0.0006322327903037337 / 0.028457690674203732 = 0.02221658804088551
# on time step 3017 (time=60.34), 0.187545 s/step
# on time step 3039 (time=60.78), 0.18406 s/step
# on time step 3060 (time=61.2), 0.192878 s/step
# on time step 3082 (time=61.64), 0.188574 s/step
# on time step 3104 (time=62.08), 0.190709 s/step
# on time step 3125 (time=62.5), 0.192762 s/step
# on time step 3146 (time=62.92), 0.196197 s/step
# on time step 3167 (time=63.34), 0.195183 s/step
# on time step 3188 (time=63.76), 0.196329 s/step
# on time step 3209 (time=64.18), 0.195484 s/step
# on time step 3231 (time=64.62), 0.186981 s/step
# on time step 3253 (time=65.06), 0.183449 s/step
# on time step 3275 (time=65.5), 0.183978 s/step
# on time step 3297 (time=65.94), 0.189764 s/step
# on time step 3320 (time=66.4), 0.178649 s/step
# on time step 3343 (time=66.86), 0.181339 s/step
# on time step 3364 (time=67.28), 0.193161 s/step
# on time step 3385 (time=67.7), 0.19362 s/step
# on time step 3406 (time=68.12), 0.197553 s/step
# on time step 3429 (time=68.58), 0.180235 s/step
# on time step 3452 (time=69.04), 0.181917 s/step
# on time step 3473 (time=69.46), 0.194762 s/step
# on time step 3494 (time=69.88), 0.195779 s/step
# field decay(t = 70.12): 5.7840373662357866e-05 / 0.028457690674203732 = 0.0020325041242643376
# on time step 3516 (time=70.32), 0.188037 s/step
# on time step 3538 (time=70.76), 0.185789 s/step
# on time step 3560 (time=71.2), 0.183008 s/step
# on time step 3581 (time=71.62), 0.190815 s/step
# on time step 3602 (time=72.04), 0.19727 s/step
# on time step 3624 (time=72.48), 0.186548 s/step
# on time step 3646 (time=72.92), 0.190378 s/step
# on time step 3668 (time=73.36), 0.185752 s/step
# on time step 3690 (time=73.8), 0.187735 s/step
# on time step 3712 (time=74.24), 0.182667 s/step
# on time step 3735 (time=74.7), 0.180574 s/step
# on time step 3758 (time=75.16), 0.180165 s/step
# on time step 3781 (time=75.62), 0.180881 s/step
# on time step 3804 (time=76.08), 0.179376 s/step
# on time step 3827 (time=76.54), 0.179018 s/step
# on time step 3850 (time=77), 0.181112 s/step
# on time step 3873 (time=77.46), 0.179575 s/step
# on time step 3896 (time=77.92), 0.179505 s/step
# on time step 3919 (time=78.38), 0.180706 s/step
# on time step 3942 (time=78.84), 0.180128 s/step
# on time step 3964 (time=79.28), 0.182202 s/step
# on time step 3986 (time=79.72), 0.18794 s/step
# field decay(t = 80.14): 4.643976867874654e-05 / 0.028457690674203732 = 0.0016318881672588834
# on time step 4007 (time=80.14), 0.191689 s/step
# on time step 4030 (time=80.6), 0.180131 s/step
# on time step 4052 (time=81.04), 0.183262 s/step
# on time step 4074 (time=81.48), 0.182978 s/step
# on time step 4096 (time=81.92), 0.183852 s/step
# on time step 4119 (time=82.38), 0.181395 s/step
# on time step 4141 (time=82.82), 0.186332 s/step
# on time step 4163 (time=83.26), 0.183336 s/step
# on time step 4184 (time=83.68), 0.196491 s/step
# on time step 4207 (time=84.14), 0.18139 s/step
# on time step 4229 (time=84.58), 0.187335 s/step
# on time step 4250 (time=85), 0.19438 s/step
# on time step 4272 (time=85.44), 0.188194 s/step
# on time step 4293 (time=85.86), 0.192536 s/step
# on time step 4315 (time=86.3), 0.18367 s/step
# on time step 4336 (time=86.72), 0.198879 s/step
# on time step 4358 (time=87.16), 0.185689 s/step
# on time step 4379 (time=87.58), 0.198419 s/step
# on time step 4400 (time=88), 0.197662 s/step
# on time step 4421 (time=88.42), 0.197116 s/step
# on time step 4442 (time=88.84), 0.194234 s/step
# on time step 4463 (time=89.26), 0.199479 s/step
# on time step 4484 (time=89.68), 0.191456 s/step
# on time step 4505 (time=90.1), 0.190651 s/step
# field decay(t = 90.16): 3.638285293146252e-06 / 0.028457690674203732 = 0.0001278489296548675
# run 0 finished at t = 90.16 (4508 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000357866 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 7.59825 s
# -----------
# on time step 1 (time=0.02), 7.93728 s/step
# on time step 26 (time=0.52), 0.160211 s/step
# on time step 50 (time=1), 0.166699 s/step
# on time step 74 (time=1.48), 0.169381 s/step
# on time step 99 (time=1.98), 0.164185 s/step
# on time step 123 (time=2.46), 0.170257 s/step
# on time step 146 (time=2.92), 0.180631 s/step
# on time step 170 (time=3.4), 0.169942 s/step
# on time step 195 (time=3.9), 0.162893 s/step
# on time step 218 (time=4.36), 0.176117 s/step
# on time step 242 (time=4.84), 0.169252 s/step
# on time step 262 (time=5.24), 0.200352 s/step
# on time step 283 (time=5.66), 0.191213 s/step
# on time step 305 (time=6.1), 0.18272 s/step
# on time step 330 (time=6.6), 0.165568 s/step
# on time step 354 (time=7.08), 0.168052 s/step
# on time step 378 (time=7.56), 0.171032 s/step
# on time step 397 (time=7.94), 0.214358 s/step
# on time step 418 (time=8.36), 0.197949 s/step
# on time step 441 (time=8.82), 0.176874 s/step
# on time step 466 (time=9.32), 0.163613 s/step
# on time step 487 (time=9.74), 0.194407 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 512 (time=10.24), 0.161673 s/step
# on time step 537 (time=10.74), 0.162785 s/step
# on time step 560 (time=11.2), 0.178403 s/step
# on time step 584 (time=11.68), 0.171936 s/step
# on time step 603 (time=12.06), 0.215291 s/step
# on time step 627 (time=12.54), 0.171278 s/step
# on time step 651 (time=13.02), 0.172274 s/step
# on time step 675 (time=13.5), 0.17254 s/step
# on time step 697 (time=13.94), 0.185213 s/step
# on time step 722 (time=14.44), 0.165543 s/step
# on time step 746 (time=14.92), 0.166974 s/step
# on time step 771 (time=15.42), 0.163 s/step
# on time step 794 (time=15.88), 0.178664 s/step
# on time step 811 (time=16.22), 0.238119 s/step
# on time step 833 (time=16.66), 0.188706 s/step
# on time step 857 (time=17.14), 0.16884 s/step
# on time step 882 (time=17.64), 0.167338 s/step
# on time step 906 (time=18.12), 0.169659 s/step
# on time step 929 (time=18.58), 0.17411 s/step
# on time step 952 (time=19.04), 0.176244 s/step
# on time step 974 (time=19.48), 0.187423 s/step
# on time step 998 (time=19.96), 0.168743 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1020 (time=20.4), 0.189979 s/step
# on time step 1038 (time=20.76), 0.22695 s/step
# on time step 1061 (time=21.22), 0.179416 s/step
# on time step 1085 (time=21.7), 0.167624 s/step
# on time step 1110 (time=22.2), 0.163515 s/step
# on time step 1134 (time=22.68), 0.175072 s/step
# on time step 1156 (time=23.12), 0.186888 s/step
# on time step 1179 (time=23.58), 0.175203 s/step
# on time step 1202 (time=24.04), 0.179456 s/step
# on time step 1220 (time=24.4), 0.233538 s/step
# on time step 1243 (time=24.86), 0.1799 s/step
# on time step 1265 (time=25.3), 0.181974 s/step
# on time step 1289 (time=25.78), 0.16773 s/step
# on time step 1312 (time=26.24), 0.177009 s/step
# on time step 1335 (time=26.7), 0.174429 s/step
# on time step 1359 (time=27.18), 0.168161 s/step
# on time step 1379 (time=27.58), 0.205722 s/step
# on time step 1396 (time=27.92), 0.242354 s/step
# on time step 1413 (time=28.26), 0.24659 s/step
# on time step 1437 (time=28.74), 0.175226 s/step
# on time step 1460 (time=29.2), 0.176706 s/step
# on time step 1484 (time=29.68), 0.167641 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000665903 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 59.9155% done, 2.67705 s remaining
# subpixel-averaging is 42.5028% done, 5.41221 s remaining
# subpixel-averaging is 85.9075% done, 0.656295 s remaining
# subpixel-averaging is 60.008% done, 2.66615 s remaining
# time for set_epsilon = 36.523 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 10.9845 s/step
# on time step 20 (time=0.4), 0.212442 s/step
# on time step 36 (time=0.72), 0.261366 s/step
# on time step 55 (time=1.1), 0.217651 s/step
# on time step 74 (time=1.48), 0.220634 s/step
# on time step 90 (time=1.8), 0.272843 s/step
# on time step 110 (time=2.2), 0.207345 s/step
# on time step 131 (time=2.62), 0.191717 s/step
# on time step 148 (time=2.96), 0.239846 s/step
# on time step 165 (time=3.3), 0.249026 s/step
# on time step 179 (time=3.58), 0.287106 s/step
# on time step 193 (time=3.86), 0.298042 s/step
# on time step 208 (time=4.16), 0.268916 s/step
# on time step 226 (time=4.52), 0.231069 s/step
# on time step 247 (time=4.94), 0.197209 s/step
# on time step 269 (time=5.38), 0.189631 s/step
# on time step 290 (time=5.8), 0.198674 s/step
# on time step 312 (time=6.24), 0.189218 s/step
# on time step 330 (time=6.6), 0.225278 s/step
# on time step 346 (time=6.92), 0.25197 s/step
# on time step 367 (time=7.34), 0.196003 s/step
# on time step 384 (time=7.68), 0.241316 s/step
# on time step 402 (time=8.04), 0.231095 s/step
# on time step 422 (time=8.44), 0.206288 s/step
# on time step 443 (time=8.86), 0.196219 s/step
# on time step 463 (time=9.26), 0.212342 s/step
# on time step 480 (time=9.6), 0.246943 s/step
# on time step 496 (time=9.92), 0.263021 s/step
# field decay(t = 10.02): 0.0011444529562738123 / 0.0011444529562738123 = 1.0
# on time step 516 (time=10.32), 0.203292 s/step
# on time step 536 (time=10.72), 0.201038 s/step
# on time step 557 (time=11.14), 0.198576 s/step
# on time step 576 (time=11.52), 0.230185 s/step
# on time step 592 (time=11.84), 0.256391 s/step
# on time step 610 (time=12.2), 0.224657 s/step
# on time step 626 (time=12.52), 0.250259 s/step
# on time step 642 (time=12.84), 0.258562 s/step
# on time step 662 (time=13.24), 0.208594 s/step
# on time step 681 (time=13.62), 0.210849 s/step
# on time step 700 (time=14), 0.211281 s/step
# on time step 720 (time=14.4), 0.200503 s/step
# on time step 741 (time=14.82), 0.191278 s/step
# on time step 762 (time=15.24), 0.199011 s/step
# on time step 782 (time=15.64), 0.203863 s/step
# on time step 800 (time=16), 0.234504 s/step
# on time step 816 (time=16.32), 0.250855 s/step
# on time step 836 (time=16.72), 0.202494 s/step
# on time step 857 (time=17.14), 0.193986 s/step
# on time step 877 (time=17.54), 0.201317 s/step
# on time step 897 (time=17.94), 0.203285 s/step
# on time step 918 (time=18.36), 0.202165 s/step
# on time step 939 (time=18.78), 0.194758 s/step
# on time step 959 (time=19.18), 0.204763 s/step
# on time step 975 (time=19.5), 0.253405 s/step
# on time step 991 (time=19.82), 0.255877 s/step
# field decay(t = 20.04): 0.07054089335970813 / 0.07054089335970813 = 1.0
# on time step 1012 (time=20.24), 0.195501 s/step
# on time step 1031 (time=20.62), 0.210567 s/step
# on time step 1046 (time=20.92), 0.282707 s/step
# on time step 1061 (time=21.22), 0.267571 s/step
# on time step 1076 (time=21.52), 0.275241 s/step
# on time step 1091 (time=21.82), 0.280645 s/step
# on time step 1109 (time=22.18), 0.227647 s/step
# on time step 1124 (time=22.48), 0.275086 s/step
# on time step 1143 (time=22.86), 0.218539 s/step
# on time step 1164 (time=23.28), 0.194097 s/step
# on time step 1185 (time=23.7), 0.19729 s/step
# on time step 1206 (time=24.12), 0.201554 s/step
# on time step 1227 (time=24.54), 0.191984 s/step
# on time step 1248 (time=24.96), 0.193446 s/step
# on time step 1269 (time=25.38), 0.192402 s/step
# on time step 1286 (time=25.72), 0.240574 s/step
# on time step 1302 (time=26.04), 0.264911 s/step
# on time step 1320 (time=26.4), 0.23031 s/step
# on time step 1341 (time=26.82), 0.196501 s/step
# on time step 1361 (time=27.22), 0.204688 s/step
# on time step 1382 (time=27.64), 0.199336 s/step
# on time step 1400 (time=28), 0.232207 s/step
# on time step 1418 (time=28.36), 0.231234 s/step
# on time step 1435 (time=28.7), 0.236955 s/step
# on time step 1454 (time=29.08), 0.217228 s/step
# on time step 1475 (time=29.5), 0.201468 s/step
# on time step 1491 (time=29.82), 0.259521 s/step
# field decay(t = 30.060000000000002): 0.00014814299723563143 / 0.07054089335970813 = 0.0021001009510924116
# on time step 1506 (time=30.12), 0.276744 s/step
# on time step 1523 (time=30.46), 0.245872 s/step
# on time step 1542 (time=30.84), 0.215811 s/step
# on time step 1560 (time=31.2), 0.223324 s/step
# on time step 1577 (time=31.54), 0.245798 s/step
# on time step 1596 (time=31.92), 0.215294 s/step
# on time step 1616 (time=32.32), 0.201585 s/step
# on time step 1636 (time=32.72), 0.200294 s/step
# on time step 1656 (time=33.12), 0.201529 s/step
# on time step 1675 (time=33.5), 0.211046 s/step
# on time step 1690 (time=33.8), 0.268386 s/step
# on time step 1708 (time=34.16), 0.227804 s/step
# on time step 1728 (time=34.56), 0.210716 s/step
# on time step 1749 (time=34.98), 0.195552 s/step
# on time step 1768 (time=35.36), 0.217566 s/step
# on time step 1785 (time=35.7), 0.237371 s/step
# on time step 1803 (time=36.06), 0.226886 s/step
# on time step 1819 (time=36.38), 0.255517 s/step
# on time step 1834 (time=36.68), 0.268715 s/step
# on time step 1847 (time=36.94), 0.310964 s/step
# on time step 1866 (time=37.32), 0.219516 s/step
# on time step 1885 (time=37.7), 0.218746 s/step
# on time step 1902 (time=38.04), 0.236443 s/step
# on time step 1921 (time=38.42), 0.2157 s/step
# on time step 1938 (time=38.76), 0.246051 s/step
# on time step 1958 (time=39.16), 0.205687 s/step
# on time step 1976 (time=39.52), 0.222925 s/step
# on time step 1993 (time=39.86), 0.239189 s/step
# field decay(t = 40.06): 7.422000179670312e-05 / 0.07054089335970813 = 0.0010521556824951758
# on time step 2009 (time=40.18), 0.265657 s/step
# on time step 2028 (time=40.56), 0.216069 s/step
# on time step 2049 (time=40.98), 0.191706 s/step
# on time step 2070 (time=41.4), 0.199276 s/step
# on time step 2091 (time=41.82), 0.199805 s/step
# on time step 2107 (time=42.14), 0.257093 s/step
# on time step 2125 (time=42.5), 0.233474 s/step
# on time step 2144 (time=42.88), 0.21089 s/step
# on time step 2161 (time=43.22), 0.246168 s/step
# on time step 2175 (time=43.5), 0.292929 s/step
# on time step 2193 (time=43.86), 0.230507 s/step
# on time step 2213 (time=44.26), 0.201307 s/step
# on time step 2234 (time=44.68), 0.19764 s/step
# on time step 2255 (time=45.1), 0.193082 s/step
# on time step 2276 (time=45.52), 0.190816 s/step
# on time step 2298 (time=45.96), 0.189117 s/step
# on time step 2317 (time=46.34), 0.220254 s/step
# on time step 2335 (time=46.7), 0.224811 s/step
# on time step 2351 (time=47.02), 0.26109 s/step
# on time step 2369 (time=47.38), 0.228529 s/step
# on time step 2385 (time=47.7), 0.2556 s/step
# on time step 2405 (time=48.1), 0.202362 s/step
# on time step 2422 (time=48.44), 0.239892 s/step
# on time step 2439 (time=48.78), 0.243958 s/step
# on time step 2458 (time=49.16), 0.217364 s/step
# on time step 2476 (time=49.52), 0.23279 s/step
# on time step 2492 (time=49.84), 0.254879 s/step
# field decay(t = 50.08): 3.5743186846775126e-05 / 0.07054089335970813 = 0.0005067016470079337
# run 0 finished at t = 50.08 (2504 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])
if mp.am_master():
    plt.figure(dpi=300)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical efficiency (in-pixel)")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")
