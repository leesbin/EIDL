# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=11.8)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 1 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * design_region_width_x)) + 1
Ny = int(round(design_region_resolution * design_region_width_y)) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, TiO2, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000677109 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.5009% done, 1.59455 s remaining
# subpixel-averaging is 71.2697% done, 1.61299 s remaining
# subpixel-averaging is 71.1772% done, 1.61991 s remaining
# time for set_epsilon = 30.2305 s
# -----------
# on time step 1 (time=0.02), 8.14189 s/step
# on time step 22 (time=0.44), 0.19515 s/step
# on time step 43 (time=0.86), 0.198971 s/step
# on time step 63 (time=1.26), 0.201985 s/step
# on time step 85 (time=1.7), 0.184725 s/step
# on time step 107 (time=2.14), 0.185883 s/step
# on time step 129 (time=2.58), 0.186759 s/step
# on time step 151 (time=3.02), 0.185016 s/step
# on time step 173 (time=3.46), 0.18803 s/step
# on time step 195 (time=3.9), 0.183696 s/step
# on time step 216 (time=4.32), 0.19048 s/step
# on time step 237 (time=4.74), 0.190559 s/step
# on time step 258 (time=5.16), 0.19385 s/step
# on time step 279 (time=5.58), 0.191991 s/step
# on time step 300 (time=6), 0.190551 s/step
# on time step 322 (time=6.44), 0.185138 s/step
# on time step 344 (time=6.88), 0.185218 s/step
# on time step 366 (time=7.32), 0.184049 s/step
# on time step 388 (time=7.76), 0.1872 s/step
# on time step 410 (time=8.2), 0.189472 s/step
# on time step 432 (time=8.64), 0.187748 s/step
# on time step 454 (time=9.08), 0.188195 s/step
# on time step 476 (time=9.52), 0.188752 s/step
# on time step 497 (time=9.94), 0.192516 s/step
# field decay(t = 10.02): 4.459506381708074e-08 / 4.459506381708074e-08 = 1.0
# on time step 519 (time=10.38), 0.188557 s/step
# on time step 541 (time=10.82), 0.18815 s/step
# on time step 563 (time=11.26), 0.186254 s/step
# on time step 585 (time=11.7), 0.189816 s/step
# on time step 606 (time=12.12), 0.191882 s/step
# on time step 627 (time=12.54), 0.198553 s/step
# on time step 648 (time=12.96), 0.194864 s/step
# on time step 669 (time=13.38), 0.193451 s/step
# on time step 691 (time=13.82), 0.188749 s/step
# on time step 713 (time=14.26), 0.186501 s/step
# on time step 735 (time=14.7), 0.184723 s/step
# on time step 757 (time=15.14), 0.189114 s/step
# on time step 780 (time=15.6), 0.181358 s/step
# on time step 803 (time=16.06), 0.17987 s/step
# on time step 826 (time=16.52), 0.178432 s/step
# on time step 849 (time=16.98), 0.179489 s/step
# on time step 871 (time=17.42), 0.183017 s/step
# on time step 894 (time=17.88), 0.178395 s/step
# on time step 917 (time=18.34), 0.180181 s/step
# on time step 939 (time=18.78), 0.182955 s/step
# on time step 961 (time=19.22), 0.184533 s/step
# on time step 984 (time=19.68), 0.180355 s/step
# field decay(t = 20.04): 0.009857662899264577 / 0.009857662899264577 = 1.0
# on time step 1007 (time=20.14), 0.179972 s/step
# on time step 1030 (time=20.6), 0.180429 s/step
# on time step 1052 (time=21.04), 0.183311 s/step
# on time step 1074 (time=21.48), 0.182937 s/step
# on time step 1096 (time=21.92), 0.18301 s/step
# on time step 1118 (time=22.36), 0.185396 s/step
# on time step 1141 (time=22.82), 0.181085 s/step
# on time step 1164 (time=23.28), 0.180926 s/step
# on time step 1187 (time=23.74), 0.179064 s/step
# on time step 1210 (time=24.2), 0.1803 s/step
# on time step 1233 (time=24.66), 0.178794 s/step
# on time step 1256 (time=25.12), 0.178383 s/step
# on time step 1279 (time=25.58), 0.179846 s/step
# on time step 1302 (time=26.04), 0.179251 s/step
# on time step 1324 (time=26.48), 0.182188 s/step
# on time step 1346 (time=26.92), 0.181852 s/step
# on time step 1369 (time=27.38), 0.179588 s/step
# on time step 1392 (time=27.84), 0.181226 s/step
# on time step 1415 (time=28.3), 0.180188 s/step
# on time step 1438 (time=28.76), 0.180269 s/step
# on time step 1461 (time=29.22), 0.180668 s/step
# on time step 1484 (time=29.68), 0.179267 s/step
# field decay(t = 30.060000000000002): 0.059563625460516856 / 0.059563625460516856 = 1.0
# on time step 1507 (time=30.14), 0.181948 s/step
# on time step 1529 (time=30.58), 0.183356 s/step
# on time step 1551 (time=31.02), 0.184836 s/step
# on time step 1573 (time=31.46), 0.182918 s/step
# on time step 1596 (time=31.92), 0.181583 s/step
# on time step 1619 (time=32.38), 0.181004 s/step
# on time step 1641 (time=32.82), 0.183335 s/step
# on time step 1664 (time=33.28), 0.179777 s/step
# on time step 1686 (time=33.72), 0.184859 s/step
# on time step 1708 (time=34.16), 0.185052 s/step
# on time step 1730 (time=34.6), 0.18205 s/step
# on time step 1753 (time=35.06), 0.181389 s/step
# on time step 1776 (time=35.52), 0.182071 s/step
# on time step 1798 (time=35.96), 0.186465 s/step
# on time step 1820 (time=36.4), 0.186681 s/step
# on time step 1842 (time=36.84), 0.185473 s/step
# on time step 1864 (time=37.28), 0.186838 s/step
# on time step 1886 (time=37.72), 0.182992 s/step
# on time step 1908 (time=38.16), 0.18498 s/step
# on time step 1930 (time=38.6), 0.185038 s/step
# on time step 1952 (time=39.04), 0.182975 s/step
# on time step 1974 (time=39.48), 0.182593 s/step
# on time step 1997 (time=39.94), 0.181106 s/step
# field decay(t = 40.06): 0.01683695781023277 / 0.059563625460516856 = 0.2826718098513587
# on time step 2019 (time=40.38), 0.183729 s/step
# on time step 2042 (time=40.84), 0.181615 s/step
# on time step 2065 (time=41.3), 0.178942 s/step
# on time step 2088 (time=41.76), 0.181019 s/step
# on time step 2111 (time=42.22), 0.180603 s/step
# on time step 2134 (time=42.68), 0.17952 s/step
# on time step 2156 (time=43.12), 0.182705 s/step
# on time step 2178 (time=43.56), 0.183245 s/step
# on time step 2201 (time=44.02), 0.180097 s/step
# on time step 2224 (time=44.48), 0.180386 s/step
# on time step 2247 (time=44.94), 0.180232 s/step
# on time step 2269 (time=45.38), 0.183139 s/step
# on time step 2291 (time=45.82), 0.182342 s/step
# on time step 2314 (time=46.28), 0.180018 s/step
# on time step 2336 (time=46.72), 0.1839 s/step
# on time step 2359 (time=47.18), 0.178376 s/step
# on time step 2382 (time=47.64), 0.180782 s/step
# on time step 2405 (time=48.1), 0.177998 s/step
# on time step 2428 (time=48.56), 0.180124 s/step
# on time step 2451 (time=49.02), 0.180303 s/step
# on time step 2474 (time=49.48), 0.181461 s/step
# on time step 2497 (time=49.94), 0.178257 s/step
# field decay(t = 50.08): 0.00247881118045616 / 0.059563625460516856 = 0.041616190439906955
# on time step 2520 (time=50.4), 0.178795 s/step
# on time step 2543 (time=50.86), 0.177953 s/step
# on time step 2566 (time=51.32), 0.177269 s/step
# on time step 2589 (time=51.78), 0.177661 s/step
# on time step 2612 (time=52.24), 0.178645 s/step
# on time step 2635 (time=52.7), 0.179569 s/step
# on time step 2658 (time=53.16), 0.178102 s/step
# on time step 2681 (time=53.62), 0.177898 s/step
# on time step 2704 (time=54.08), 0.177859 s/step
# on time step 2727 (time=54.54), 0.178269 s/step
# on time step 2750 (time=55), 0.177732 s/step
# on time step 2773 (time=55.46), 0.179377 s/step
# on time step 2796 (time=55.92), 0.177966 s/step
# on time step 2819 (time=56.38), 0.1778 s/step
# on time step 2842 (time=56.84), 0.177831 s/step
# on time step 2865 (time=57.3), 0.177907 s/step
# on time step 2888 (time=57.76), 0.177898 s/step
# on time step 2911 (time=58.22), 0.178008 s/step
# on time step 2934 (time=58.68), 0.178102 s/step
# on time step 2957 (time=59.14), 0.178061 s/step
# on time step 2980 (time=59.6), 0.178592 s/step
# on time step 3003 (time=60.06), 0.177502 s/step
# field decay(t = 60.1): 0.0012437942265229199 / 0.059563625460516856 = 0.020881775024715346
# on time step 3026 (time=60.52), 0.180934 s/step
# on time step 3049 (time=60.98), 0.17785 s/step
# on time step 3072 (time=61.44), 0.177722 s/step
# on time step 3095 (time=61.9), 0.177697 s/step
# on time step 3118 (time=62.36), 0.17784 s/step
# on time step 3141 (time=62.82), 0.177559 s/step
# on time step 3164 (time=63.28), 0.179035 s/step
# on time step 3187 (time=63.74), 0.181057 s/step
# on time step 3210 (time=64.2), 0.17757 s/step
# on time step 3233 (time=64.66), 0.180203 s/step
# on time step 3256 (time=65.12), 0.180895 s/step
# on time step 3279 (time=65.58), 0.179246 s/step
# on time step 3302 (time=66.04), 0.181245 s/step
# on time step 3325 (time=66.5), 0.177354 s/step
# on time step 3348 (time=66.96), 0.177752 s/step
# on time step 3371 (time=67.42), 0.179058 s/step
# on time step 3394 (time=67.88), 0.178496 s/step
# on time step 3417 (time=68.34), 0.180651 s/step
# on time step 3440 (time=68.8), 0.177929 s/step
# on time step 3463 (time=69.26), 0.177902 s/step
# on time step 3486 (time=69.72), 0.177714 s/step
# field decay(t = 70.12): 0.0013683226045126725 / 0.059563625460516856 = 0.022972453304067213
# on time step 3509 (time=70.18), 0.177464 s/step
# on time step 3532 (time=70.64), 0.178189 s/step
# on time step 3555 (time=71.1), 0.17905 s/step
# on time step 3578 (time=71.56), 0.179457 s/step
# on time step 3601 (time=72.02), 0.181205 s/step
# on time step 3624 (time=72.48), 0.178365 s/step
# on time step 3647 (time=72.94), 0.178771 s/step
# on time step 3670 (time=73.4), 0.178008 s/step
# on time step 3693 (time=73.86), 0.17908 s/step
# on time step 3716 (time=74.32), 0.178791 s/step
# on time step 3739 (time=74.78), 0.177326 s/step
# on time step 3762 (time=75.24), 0.181325 s/step
# on time step 3785 (time=75.7), 0.179652 s/step
# on time step 3808 (time=76.16), 0.177876 s/step
# on time step 3831 (time=76.62), 0.1785 s/step
# on time step 3854 (time=77.08), 0.178573 s/step
# on time step 3877 (time=77.54), 0.177829 s/step
# on time step 3900 (time=78), 0.178581 s/step
# on time step 3923 (time=78.46), 0.178134 s/step
# on time step 3946 (time=78.92), 0.177836 s/step
# on time step 3969 (time=79.38), 0.177851 s/step
# on time step 3992 (time=79.84), 0.178062 s/step
# field decay(t = 80.14): 0.0004555113743998911 / 0.059563625460516856 = 0.007647475634300291
# on time step 4015 (time=80.3), 0.177716 s/step
# on time step 4038 (time=80.76), 0.17771 s/step
# on time step 4061 (time=81.22), 0.177855 s/step
# on time step 4084 (time=81.68), 0.177055 s/step
# on time step 4107 (time=82.14), 0.17811 s/step
# on time step 4130 (time=82.6), 0.177906 s/step
# on time step 4153 (time=83.06), 0.177658 s/step
# on time step 4176 (time=83.52), 0.177696 s/step
# on time step 4199 (time=83.98), 0.177721 s/step
# on time step 4222 (time=84.44), 0.181378 s/step
# on time step 4245 (time=84.9), 0.181392 s/step
# on time step 4268 (time=85.36), 0.180959 s/step
# on time step 4291 (time=85.82), 0.177612 s/step
# on time step 4314 (time=86.28), 0.177551 s/step
# on time step 4337 (time=86.74), 0.178853 s/step
# on time step 4360 (time=87.2), 0.179003 s/step
# on time step 4383 (time=87.66), 0.181565 s/step
# on time step 4406 (time=88.12), 0.177975 s/step
# on time step 4429 (time=88.58), 0.178216 s/step
# on time step 4452 (time=89.04), 0.178296 s/step
# on time step 4475 (time=89.5), 0.178445 s/step
# on time step 4498 (time=89.96), 0.178838 s/step
# field decay(t = 90.16): 0.0004944286324291779 / 0.059563625460516856 = 0.00830084852301211
# on time step 4521 (time=90.42), 0.177973 s/step
# on time step 4544 (time=90.88), 0.178493 s/step
# on time step 4567 (time=91.34), 0.178024 s/step
# on time step 4590 (time=91.8), 0.180138 s/step
# on time step 4613 (time=92.26), 0.179184 s/step
# on time step 4636 (time=92.72), 0.178979 s/step
# on time step 4659 (time=93.18), 0.181698 s/step
# on time step 4681 (time=93.62), 0.1819 s/step
# on time step 4704 (time=94.08), 0.180935 s/step
# on time step 4727 (time=94.54), 0.179908 s/step
# on time step 4750 (time=95), 0.178918 s/step
# on time step 4773 (time=95.46), 0.181268 s/step
# on time step 4796 (time=95.92), 0.178458 s/step
# on time step 4819 (time=96.38), 0.177577 s/step
# on time step 4842 (time=96.84), 0.179695 s/step
# on time step 4865 (time=97.3), 0.177354 s/step
# on time step 4888 (time=97.76), 0.177864 s/step
# on time step 4911 (time=98.22), 0.178479 s/step
# on time step 4934 (time=98.68), 0.179297 s/step
# on time step 4957 (time=99.14), 0.178469 s/step
# on time step 4980 (time=99.6), 0.178747 s/step
# on time step 5003 (time=100.06), 0.180249 s/step
# field decay(t = 100.18): 0.00018033152455169992 / 0.059563625460516856 = 0.0030275444645530667
# on time step 5026 (time=100.52), 0.179573 s/step
# on time step 5049 (time=100.98), 0.178903 s/step
# on time step 5072 (time=101.44), 0.178566 s/step
# on time step 5095 (time=101.9), 0.178837 s/step
# on time step 5118 (time=102.36), 0.180849 s/step
# on time step 5141 (time=102.82), 0.180175 s/step
# on time step 5164 (time=103.28), 0.178692 s/step
# on time step 5187 (time=103.74), 0.178927 s/step
# on time step 5210 (time=104.2), 0.179125 s/step
# on time step 5233 (time=104.66), 0.177739 s/step
# on time step 5256 (time=105.12), 0.177482 s/step
# on time step 5279 (time=105.58), 0.176818 s/step
# on time step 5302 (time=106.04), 0.178644 s/step
# on time step 5325 (time=106.5), 0.179769 s/step
# on time step 5348 (time=106.96), 0.178915 s/step
# on time step 5371 (time=107.42), 0.178354 s/step
# on time step 5394 (time=107.88), 0.17697 s/step
# on time step 5417 (time=108.34), 0.178378 s/step
# on time step 5440 (time=108.8), 0.1777 s/step
# on time step 5463 (time=109.26), 0.178521 s/step
# on time step 5486 (time=109.72), 0.178145 s/step
# on time step 5509 (time=110.18), 0.178916 s/step
# field decay(t = 110.2): 6.555753959472949e-05 / 0.059563625460516856 = 0.001100630444971585
# on time step 5532 (time=110.64), 0.178448 s/step
# on time step 5555 (time=111.1), 0.177991 s/step
# on time step 5578 (time=111.56), 0.177738 s/step
# on time step 5601 (time=112.02), 0.178681 s/step
# on time step 5624 (time=112.48), 0.178583 s/step
# on time step 5647 (time=112.94), 0.17871 s/step
# on time step 5670 (time=113.4), 0.180022 s/step
# on time step 5693 (time=113.86), 0.179358 s/step
# on time step 5716 (time=114.32), 0.178175 s/step
# on time step 5739 (time=114.78), 0.17856 s/step
# on time step 5762 (time=115.24), 0.178772 s/step
# on time step 5785 (time=115.7), 0.178718 s/step
# on time step 5808 (time=116.16), 0.17863 s/step
# on time step 5831 (time=116.62), 0.180109 s/step
# on time step 5853 (time=117.06), 0.181872 s/step
# on time step 5876 (time=117.52), 0.179388 s/step
# on time step 5899 (time=117.98), 0.179654 s/step
# on time step 5922 (time=118.44), 0.178663 s/step
# on time step 5945 (time=118.9), 0.178783 s/step
# on time step 5968 (time=119.36), 0.177733 s/step
# on time step 5991 (time=119.82), 0.177244 s/step
# field decay(t = 120.22): 6.40802966293681e-05 / 0.059563625460516856 = 0.0010758293527959482
# on time step 6014 (time=120.28), 0.178878 s/step
# on time step 6037 (time=120.74), 0.178903 s/step
# on time step 6060 (time=121.2), 0.181413 s/step
# on time step 6083 (time=121.66), 0.179249 s/step
# on time step 6106 (time=122.12), 0.178822 s/step
# on time step 6129 (time=122.58), 0.178897 s/step
# on time step 6152 (time=123.04), 0.178553 s/step
# on time step 6175 (time=123.5), 0.1791 s/step
# on time step 6198 (time=123.96), 0.179565 s/step
# on time step 6221 (time=124.42), 0.177772 s/step
# on time step 6244 (time=124.88), 0.177641 s/step
# on time step 6267 (time=125.34), 0.178153 s/step
# on time step 6290 (time=125.8), 0.177803 s/step
# on time step 6313 (time=126.26), 0.177624 s/step
# on time step 6336 (time=126.72), 0.180181 s/step
# on time step 6359 (time=127.18), 0.178826 s/step
# on time step 6382 (time=127.64), 0.179668 s/step
# on time step 6405 (time=128.1), 0.178873 s/step
# on time step 6428 (time=128.56), 0.181832 s/step
# on time step 6450 (time=129), 0.181891 s/step
# on time step 6473 (time=129.46), 0.181772 s/step
# on time step 6496 (time=129.92), 0.180345 s/step
# field decay(t = 130.24): 3.7658295992721325e-05 / 0.059563625460516856 = 0.0006322364648149903
# run 0 finished at t = 130.24 (6512 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000636816 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 72.3796% done, 1.52645 s remaining
# subpixel-averaging is 68.6566% done, 1.82641 s remaining
# subpixel-averaging is 72.3334% done, 1.53053 s remaining
# time for set_epsilon = 30.4725 s
# -----------
# on time step 1 (time=0.02), 7.95137 s/step
# on time step 24 (time=0.48), 0.176923 s/step
# on time step 47 (time=0.94), 0.177012 s/step
# on time step 70 (time=1.4), 0.177868 s/step
# on time step 93 (time=1.86), 0.176807 s/step
# on time step 116 (time=2.32), 0.176243 s/step
# on time step 139 (time=2.78), 0.177796 s/step
# on time step 162 (time=3.24), 0.178507 s/step
# on time step 185 (time=3.7), 0.1778 s/step
# on time step 208 (time=4.16), 0.176503 s/step
# on time step 231 (time=4.62), 0.177228 s/step
# on time step 254 (time=5.08), 0.177567 s/step
# on time step 277 (time=5.54), 0.177803 s/step
# on time step 300 (time=6), 0.177219 s/step
# on time step 323 (time=6.46), 0.179015 s/step
# on time step 346 (time=6.92), 0.179402 s/step
# on time step 369 (time=7.38), 0.17681 s/step
# on time step 392 (time=7.84), 0.177021 s/step
# on time step 415 (time=8.3), 0.17681 s/step
# on time step 438 (time=8.76), 0.178176 s/step
# on time step 461 (time=9.22), 0.17812 s/step
# on time step 484 (time=9.68), 0.177801 s/step
# field decay(t = 10.02): 3.811691832281367e-09 / 3.811691832281367e-09 = 1.0
# on time step 507 (time=10.14), 0.178104 s/step
# on time step 530 (time=10.6), 0.177711 s/step
# on time step 553 (time=11.06), 0.177605 s/step
# on time step 576 (time=11.52), 0.180496 s/step
# on time step 599 (time=11.98), 0.177255 s/step
# on time step 622 (time=12.44), 0.180243 s/step
# on time step 645 (time=12.9), 0.179192 s/step
# on time step 668 (time=13.36), 0.179708 s/step
# on time step 690 (time=13.8), 0.182704 s/step
# on time step 713 (time=14.26), 0.180054 s/step
# on time step 736 (time=14.72), 0.181063 s/step
# on time step 759 (time=15.18), 0.18028 s/step
# on time step 782 (time=15.64), 0.176997 s/step
# on time step 805 (time=16.1), 0.176888 s/step
# on time step 828 (time=16.56), 0.176679 s/step
# on time step 851 (time=17.02), 0.177273 s/step
# on time step 874 (time=17.48), 0.178097 s/step
# on time step 897 (time=17.94), 0.178186 s/step
# on time step 920 (time=18.4), 0.178516 s/step
# on time step 943 (time=18.86), 0.178062 s/step
# on time step 966 (time=19.32), 0.178926 s/step
# on time step 989 (time=19.78), 0.178234 s/step
# field decay(t = 20.04): 0.00021631431707370844 / 0.00021631431707370844 = 1.0
# on time step 1012 (time=20.24), 0.178553 s/step
# on time step 1035 (time=20.7), 0.177938 s/step
# on time step 1058 (time=21.16), 0.178542 s/step
# on time step 1081 (time=21.62), 0.17841 s/step
# on time step 1104 (time=22.08), 0.177349 s/step
# on time step 1127 (time=22.54), 0.179483 s/step
# on time step 1150 (time=23), 0.178632 s/step
# on time step 1173 (time=23.46), 0.178127 s/step
# on time step 1196 (time=23.92), 0.177504 s/step
# on time step 1219 (time=24.38), 0.177252 s/step
# on time step 1242 (time=24.84), 0.178252 s/step
# on time step 1265 (time=25.3), 0.177098 s/step
# on time step 1288 (time=25.76), 0.178053 s/step
# on time step 1311 (time=26.22), 0.179529 s/step
# on time step 1334 (time=26.68), 0.177984 s/step
# on time step 1357 (time=27.14), 0.179523 s/step
# on time step 1380 (time=27.6), 0.177881 s/step
# on time step 1403 (time=28.06), 0.178041 s/step
# on time step 1426 (time=28.52), 0.178496 s/step
# on time step 1449 (time=28.98), 0.177411 s/step
# on time step 1472 (time=29.44), 0.177105 s/step
# on time step 1495 (time=29.9), 0.177379 s/step
# field decay(t = 30.060000000000002): 0.050135864372529516 / 0.050135864372529516 = 1.0
# on time step 1518 (time=30.36), 0.178473 s/step
# on time step 1541 (time=30.82), 0.177967 s/step
# on time step 1564 (time=31.28), 0.181222 s/step
# on time step 1587 (time=31.74), 0.17731 s/step
# on time step 1610 (time=32.2), 0.176797 s/step
# on time step 1633 (time=32.66), 0.17739 s/step
# on time step 1656 (time=33.12), 0.176694 s/step
# on time step 1679 (time=33.58), 0.179655 s/step
# on time step 1702 (time=34.04), 0.177063 s/step
# on time step 1725 (time=34.5), 0.177181 s/step
# on time step 1748 (time=34.96), 0.176917 s/step
# on time step 1771 (time=35.42), 0.177293 s/step
# on time step 1794 (time=35.88), 0.176858 s/step
# on time step 1817 (time=36.34), 0.176995 s/step
# on time step 1840 (time=36.8), 0.177094 s/step
# on time step 1863 (time=37.26), 0.176613 s/step
# on time step 1886 (time=37.72), 0.176361 s/step
# on time step 1909 (time=38.18), 0.176813 s/step
# on time step 1932 (time=38.64), 0.177679 s/step
# on time step 1955 (time=39.1), 0.177074 s/step
# on time step 1978 (time=39.56), 0.178833 s/step
# on time step 2001 (time=40.02), 0.177258 s/step
# field decay(t = 40.06): 0.09192670966161487 / 0.09192670966161487 = 1.0
# on time step 2024 (time=40.48), 0.177398 s/step
# on time step 2047 (time=40.94), 0.17786 s/step
# on time step 2070 (time=41.4), 0.177323 s/step
# on time step 2093 (time=41.86), 0.177289 s/step
# on time step 2116 (time=42.32), 0.177088 s/step
# on time step 2139 (time=42.78), 0.176753 s/step
# on time step 2162 (time=43.24), 0.176963 s/step
# on time step 2185 (time=43.7), 0.177706 s/step
# on time step 2208 (time=44.16), 0.177293 s/step
# on time step 2231 (time=44.62), 0.176866 s/step
# on time step 2254 (time=45.08), 0.176699 s/step
# on time step 2277 (time=45.54), 0.177146 s/step
# on time step 2300 (time=46), 0.176452 s/step
# on time step 2323 (time=46.46), 0.176413 s/step
# on time step 2346 (time=46.92), 0.176699 s/step
# on time step 2369 (time=47.38), 0.178349 s/step
# on time step 2392 (time=47.84), 0.178704 s/step
# on time step 2415 (time=48.3), 0.177995 s/step
# on time step 2438 (time=48.76), 0.177798 s/step
# on time step 2461 (time=49.22), 0.177624 s/step
# on time step 2484 (time=49.68), 0.177242 s/step
# field decay(t = 50.08): 0.03372225378665792 / 0.09192670966161487 = 0.36683847285289123
# on time step 2507 (time=50.14), 0.178644 s/step
# on time step 2530 (time=50.6), 0.176896 s/step
# on time step 2553 (time=51.06), 0.176931 s/step
# on time step 2576 (time=51.52), 0.177774 s/step
# on time step 2599 (time=51.98), 0.177429 s/step
# on time step 2622 (time=52.44), 0.176381 s/step
# on time step 2645 (time=52.9), 0.17675 s/step
# on time step 2668 (time=53.36), 0.177883 s/step
# on time step 2691 (time=53.82), 0.178146 s/step
# on time step 2714 (time=54.28), 0.17815 s/step
# on time step 2737 (time=54.74), 0.178664 s/step
# on time step 2760 (time=55.2), 0.178133 s/step
# on time step 2783 (time=55.66), 0.180151 s/step
# on time step 2806 (time=56.12), 0.180974 s/step
# on time step 2829 (time=56.58), 0.18105 s/step
# on time step 2852 (time=57.04), 0.179756 s/step
# on time step 2875 (time=57.5), 0.180018 s/step
# on time step 2898 (time=57.96), 0.178619 s/step
# on time step 2921 (time=58.42), 0.178999 s/step
# on time step 2944 (time=58.88), 0.177772 s/step
# on time step 2967 (time=59.34), 0.177305 s/step
# on time step 2990 (time=59.8), 0.17974 s/step
# field decay(t = 60.1): 0.004436530039670887 / 0.09192670966161487 = 0.048261599441575743
# on time step 3013 (time=60.26), 0.179581 s/step
# on time step 3036 (time=60.72), 0.176599 s/step
# on time step 3059 (time=61.18), 0.177311 s/step
# on time step 3082 (time=61.64), 0.177142 s/step
# on time step 3105 (time=62.1), 0.177846 s/step
# on time step 3128 (time=62.56), 0.177376 s/step
# on time step 3151 (time=63.02), 0.176831 s/step
# on time step 3174 (time=63.48), 0.17726 s/step
# on time step 3197 (time=63.94), 0.177982 s/step
# on time step 3220 (time=64.4), 0.177516 s/step
# on time step 3243 (time=64.86), 0.177773 s/step
# on time step 3266 (time=65.32), 0.180769 s/step
# on time step 3289 (time=65.78), 0.177736 s/step
# on time step 3312 (time=66.24), 0.176381 s/step
# on time step 3335 (time=66.7), 0.179503 s/step
# on time step 3358 (time=67.16), 0.177866 s/step
# on time step 3381 (time=67.62), 0.177264 s/step
# on time step 3404 (time=68.08), 0.176967 s/step
# on time step 3427 (time=68.54), 0.176735 s/step
# on time step 3450 (time=69), 0.177121 s/step
# on time step 3473 (time=69.46), 0.176858 s/step
# on time step 3496 (time=69.92), 0.176822 s/step
# field decay(t = 70.12): 0.004633744028814378 / 0.09192670966161487 = 0.05040693880887652
# on time step 3519 (time=70.38), 0.177176 s/step
# on time step 3542 (time=70.84), 0.178364 s/step
# on time step 3565 (time=71.3), 0.177564 s/step
# on time step 3588 (time=71.76), 0.179101 s/step
# on time step 3611 (time=72.22), 0.17759 s/step
# on time step 3634 (time=72.68), 0.17894 s/step
# on time step 3657 (time=73.14), 0.180171 s/step
# on time step 3680 (time=73.6), 0.178814 s/step
# on time step 3703 (time=74.06), 0.179785 s/step
# on time step 3726 (time=74.52), 0.179862 s/step
# on time step 3749 (time=74.98), 0.178215 s/step
# on time step 3772 (time=75.44), 0.177909 s/step
# on time step 3795 (time=75.9), 0.177919 s/step
# on time step 3818 (time=76.36), 0.178069 s/step
# on time step 3841 (time=76.82), 0.177552 s/step
# on time step 3864 (time=77.28), 0.176786 s/step
# on time step 3887 (time=77.74), 0.177255 s/step
# on time step 3910 (time=78.2), 0.17761 s/step
# on time step 3933 (time=78.66), 0.177713 s/step
# on time step 3956 (time=79.12), 0.177798 s/step
# on time step 3979 (time=79.58), 0.177865 s/step
# on time step 4002 (time=80.04), 0.179489 s/step
# field decay(t = 80.14): 0.0032980340836071182 / 0.09192670966161487 = 0.03587677722554507
# on time step 4025 (time=80.5), 0.178075 s/step
# on time step 4048 (time=80.96), 0.177643 s/step
# on time step 4071 (time=81.42), 0.177083 s/step
# on time step 4094 (time=81.88), 0.178376 s/step
# on time step 4117 (time=82.34), 0.178558 s/step
# on time step 4140 (time=82.8), 0.177882 s/step
# on time step 4163 (time=83.26), 0.177687 s/step
# on time step 4186 (time=83.72), 0.178027 s/step
# on time step 4209 (time=84.18), 0.178235 s/step
# on time step 4232 (time=84.64), 0.180436 s/step
# on time step 4255 (time=85.1), 0.180817 s/step
# on time step 4278 (time=85.56), 0.178109 s/step
# on time step 4301 (time=86.02), 0.176689 s/step
# on time step 4324 (time=86.48), 0.178125 s/step
# on time step 4347 (time=86.94), 0.176869 s/step
# on time step 4370 (time=87.4), 0.17784 s/step
# on time step 4393 (time=87.86), 0.177484 s/step
# on time step 4416 (time=88.32), 0.17714 s/step
# on time step 4439 (time=88.78), 0.180019 s/step
# on time step 4462 (time=89.24), 0.176877 s/step
# on time step 4485 (time=89.7), 0.17724 s/step
# field decay(t = 90.16): 0.001182461908232276 / 0.09192670966161487 = 0.01286309400809575
# on time step 4508 (time=90.16), 0.176301 s/step
# on time step 4531 (time=90.62), 0.176159 s/step
# on time step 4554 (time=91.08), 0.177807 s/step
# on time step 4577 (time=91.54), 0.176322 s/step
# on time step 4600 (time=92), 0.177974 s/step
# on time step 4623 (time=92.46), 0.176951 s/step
# on time step 4646 (time=92.92), 0.179697 s/step
# on time step 4669 (time=93.38), 0.179774 s/step
# on time step 4692 (time=93.84), 0.180707 s/step
# on time step 4715 (time=94.3), 0.177006 s/step
# on time step 4738 (time=94.76), 0.176715 s/step
# on time step 4761 (time=95.22), 0.176958 s/step
# on time step 4784 (time=95.68), 0.176522 s/step
# on time step 4807 (time=96.14), 0.176812 s/step
# on time step 4830 (time=96.6), 0.17676 s/step
# on time step 4853 (time=97.06), 0.177666 s/step
# on time step 4876 (time=97.52), 0.178175 s/step
# on time step 4899 (time=97.98), 0.177763 s/step
# on time step 4922 (time=98.44), 0.177127 s/step
# on time step 4945 (time=98.9), 0.177379 s/step
# on time step 4968 (time=99.36), 0.177193 s/step
# on time step 4991 (time=99.82), 0.176653 s/step
# field decay(t = 100.18): 0.0012586235260737173 / 0.09192670966161487 = 0.013691597694584636
# on time step 5014 (time=100.28), 0.177901 s/step
# on time step 5037 (time=100.74), 0.177566 s/step
# on time step 5060 (time=101.2), 0.176374 s/step
# on time step 5083 (time=101.66), 0.176275 s/step
# on time step 5106 (time=102.12), 0.176268 s/step
# on time step 5129 (time=102.58), 0.17647 s/step
# on time step 5152 (time=103.04), 0.176765 s/step
# on time step 5175 (time=103.5), 0.176762 s/step
# on time step 5198 (time=103.96), 0.179132 s/step
# on time step 5221 (time=104.42), 0.177513 s/step
# on time step 5244 (time=104.88), 0.177534 s/step
# on time step 5267 (time=105.34), 0.17716 s/step
# on time step 5290 (time=105.8), 0.176792 s/step
# on time step 5313 (time=106.26), 0.178275 s/step
# on time step 5336 (time=106.72), 0.178865 s/step
# on time step 5359 (time=107.18), 0.17716 s/step
# on time step 5382 (time=107.64), 0.176994 s/step
# on time step 5405 (time=108.1), 0.177391 s/step
# on time step 5428 (time=108.56), 0.177691 s/step
# on time step 5451 (time=109.02), 0.177098 s/step
# on time step 5474 (time=109.48), 0.176783 s/step
# on time step 5497 (time=109.94), 0.177016 s/step
# field decay(t = 110.2): 0.00047640723658913206 / 0.09192670966161487 = 0.0051824680589874494
# on time step 5520 (time=110.4), 0.177309 s/step
# on time step 5543 (time=110.86), 0.17886 s/step
# on time step 5566 (time=111.32), 0.176818 s/step
# on time step 5589 (time=111.78), 0.178083 s/step
# on time step 5612 (time=112.24), 0.178979 s/step
# on time step 5635 (time=112.7), 0.17907 s/step
# on time step 5658 (time=113.16), 0.176747 s/step
# on time step 5681 (time=113.62), 0.176971 s/step
# on time step 5704 (time=114.08), 0.177357 s/step
# on time step 5727 (time=114.54), 0.176632 s/step
# on time step 5750 (time=115), 0.177126 s/step
# on time step 5773 (time=115.46), 0.176924 s/step
# on time step 5796 (time=115.92), 0.177105 s/step
# on time step 5819 (time=116.38), 0.177258 s/step
# on time step 5842 (time=116.84), 0.177398 s/step
# on time step 5865 (time=117.3), 0.176508 s/step
# on time step 5888 (time=117.76), 0.176088 s/step
# on time step 5911 (time=118.22), 0.176496 s/step
# on time step 5934 (time=118.68), 0.178768 s/step
# on time step 5957 (time=119.14), 0.180192 s/step
# on time step 5980 (time=119.6), 0.17677 s/step
# on time step 6003 (time=120.06), 0.178256 s/step
# field decay(t = 120.22): 5.1097665983871934e-05 / 0.09192670966161487 = 0.0005558522237113029
# run 0 finished at t = 120.22 (6011 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000648975 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 72.4721% done, 1.5199 s remaining
# subpixel-averaging is 72.0097% done, 1.55498 s remaining
# subpixel-averaging is 72.5415% done, 1.51429 s remaining
# time for set_epsilon = 29.8137 s
# -----------
# on time step 1 (time=0.02), 7.95999 s/step
# on time step 24 (time=0.48), 0.176768 s/step
# on time step 47 (time=0.94), 0.177556 s/step
# on time step 70 (time=1.4), 0.179939 s/step
# on time step 93 (time=1.86), 0.177098 s/step
# on time step 116 (time=2.32), 0.177846 s/step
# on time step 139 (time=2.78), 0.177657 s/step
# on time step 162 (time=3.24), 0.177454 s/step
# on time step 185 (time=3.7), 0.176959 s/step
# on time step 208 (time=4.16), 0.1789 s/step
# on time step 231 (time=4.62), 0.180211 s/step
# on time step 254 (time=5.08), 0.178152 s/step
# on time step 277 (time=5.54), 0.177046 s/step
# on time step 300 (time=6), 0.177101 s/step
# on time step 323 (time=6.46), 0.176992 s/step
# on time step 346 (time=6.92), 0.179057 s/step
# on time step 369 (time=7.38), 0.179532 s/step
# on time step 392 (time=7.84), 0.178487 s/step
# on time step 415 (time=8.3), 0.178055 s/step
# on time step 438 (time=8.76), 0.177875 s/step
# on time step 461 (time=9.22), 0.180141 s/step
# on time step 484 (time=9.68), 0.178189 s/step
# field decay(t = 10.02): 5.82175039652521e-09 / 5.82175039652521e-09 = 1.0
# on time step 507 (time=10.14), 0.177122 s/step
# on time step 530 (time=10.6), 0.176864 s/step
# on time step 553 (time=11.06), 0.179979 s/step
# on time step 576 (time=11.52), 0.178795 s/step
# on time step 599 (time=11.98), 0.179597 s/step
# on time step 622 (time=12.44), 0.177099 s/step
# on time step 645 (time=12.9), 0.176861 s/step
# on time step 668 (time=13.36), 0.178171 s/step
# on time step 691 (time=13.82), 0.177843 s/step
# on time step 714 (time=14.28), 0.180742 s/step
# on time step 737 (time=14.74), 0.180608 s/step
# on time step 760 (time=15.2), 0.180815 s/step
# on time step 783 (time=15.66), 0.180928 s/step
# on time step 806 (time=16.12), 0.177341 s/step
# on time step 829 (time=16.58), 0.177172 s/step
# on time step 852 (time=17.04), 0.179065 s/step
# on time step 875 (time=17.5), 0.176942 s/step
# on time step 898 (time=17.96), 0.177194 s/step
# on time step 921 (time=18.42), 0.177659 s/step
# on time step 944 (time=18.88), 0.17688 s/step
# on time step 967 (time=19.34), 0.176894 s/step
# on time step 990 (time=19.8), 0.177678 s/step
# field decay(t = 20.04): 0.0003282643931809633 / 0.0003282643931809633 = 1.0
# on time step 1013 (time=20.26), 0.17708 s/step
# on time step 1036 (time=20.72), 0.178077 s/step
# on time step 1059 (time=21.18), 0.177786 s/step
# on time step 1082 (time=21.64), 0.180431 s/step
# on time step 1105 (time=22.1), 0.177558 s/step
# on time step 1128 (time=22.56), 0.178778 s/step
# on time step 1151 (time=23.02), 0.180017 s/step
# on time step 1174 (time=23.48), 0.178951 s/step
# on time step 1197 (time=23.94), 0.177407 s/step
# on time step 1220 (time=24.4), 0.177971 s/step
# on time step 1243 (time=24.86), 0.177167 s/step
# on time step 1266 (time=25.32), 0.179694 s/step
# on time step 1289 (time=25.78), 0.178698 s/step
# on time step 1312 (time=26.24), 0.178135 s/step
# on time step 1335 (time=26.7), 0.178077 s/step
# on time step 1358 (time=27.16), 0.17781 s/step
# on time step 1381 (time=27.62), 0.1783 s/step
# on time step 1404 (time=28.08), 0.180158 s/step
# on time step 1427 (time=28.54), 0.179056 s/step
# on time step 1450 (time=29), 0.178081 s/step
# on time step 1473 (time=29.46), 0.178979 s/step
# on time step 1496 (time=29.92), 0.178487 s/step
# field decay(t = 30.060000000000002): 0.13411147629529194 / 0.13411147629529194 = 1.0
# on time step 1519 (time=30.38), 0.178566 s/step
# on time step 1542 (time=30.84), 0.177213 s/step
# on time step 1565 (time=31.3), 0.179107 s/step
# on time step 1588 (time=31.76), 0.179714 s/step
# on time step 1611 (time=32.22), 0.178435 s/step
# on time step 1634 (time=32.68), 0.177261 s/step
# on time step 1657 (time=33.14), 0.177539 s/step
# on time step 1680 (time=33.6), 0.177466 s/step
# on time step 1703 (time=34.06), 0.178199 s/step
# on time step 1726 (time=34.52), 0.178299 s/step
# on time step 1749 (time=34.98), 0.178428 s/step
# on time step 1772 (time=35.44), 0.178596 s/step
# on time step 1795 (time=35.9), 0.177952 s/step
# on time step 1818 (time=36.36), 0.178444 s/step
# on time step 1841 (time=36.82), 0.17848 s/step
# on time step 1864 (time=37.28), 0.178198 s/step
# on time step 1887 (time=37.74), 0.17828 s/step
# on time step 1910 (time=38.2), 0.178461 s/step
# on time step 1933 (time=38.66), 0.18097 s/step
# on time step 1956 (time=39.12), 0.179379 s/step
# on time step 1979 (time=39.58), 0.178109 s/step
# on time step 2002 (time=40.04), 0.17946 s/step
# field decay(t = 40.06): 0.2997361839469467 / 0.2997361839469467 = 1.0
# on time step 2025 (time=40.5), 0.179563 s/step
# on time step 2048 (time=40.96), 0.177211 s/step
# on time step 2071 (time=41.42), 0.178024 s/step
# on time step 2094 (time=41.88), 0.17827 s/step
# on time step 2117 (time=42.34), 0.176998 s/step
# on time step 2140 (time=42.8), 0.180008 s/step
# on time step 2163 (time=43.26), 0.180093 s/step
# on time step 2186 (time=43.72), 0.177323 s/step
# on time step 2209 (time=44.18), 0.177197 s/step
# on time step 2232 (time=44.64), 0.176783 s/step
# on time step 2255 (time=45.1), 0.176749 s/step
# on time step 2278 (time=45.56), 0.177367 s/step
# on time step 2301 (time=46.02), 0.177065 s/step
# on time step 2324 (time=46.48), 0.177212 s/step
# on time step 2347 (time=46.94), 0.177046 s/step
# on time step 2370 (time=47.4), 0.177665 s/step
# on time step 2393 (time=47.86), 0.177248 s/step
# on time step 2416 (time=48.32), 0.178086 s/step
# on time step 2439 (time=48.78), 0.177455 s/step
# on time step 2462 (time=49.24), 0.179902 s/step
# on time step 2485 (time=49.7), 0.179962 s/step
# field decay(t = 50.08): 0.11451965151051037 / 0.2997361839469467 = 0.38206815741265443
# on time step 2508 (time=50.16), 0.177949 s/step
# on time step 2531 (time=50.62), 0.178499 s/step
# on time step 2554 (time=51.08), 0.180886 s/step
# on time step 2577 (time=51.54), 0.178126 s/step
# on time step 2600 (time=52), 0.178293 s/step
# on time step 2623 (time=52.46), 0.177792 s/step
# on time step 2646 (time=52.92), 0.177555 s/step
# on time step 2669 (time=53.38), 0.177152 s/step
# on time step 2692 (time=53.84), 0.177198 s/step
# on time step 2715 (time=54.3), 0.178317 s/step
# on time step 2738 (time=54.76), 0.179652 s/step
# on time step 2761 (time=55.22), 0.178974 s/step
# on time step 2784 (time=55.68), 0.178438 s/step
# on time step 2807 (time=56.14), 0.177032 s/step
# on time step 2830 (time=56.6), 0.177101 s/step
# on time step 2853 (time=57.06), 0.17733 s/step
# on time step 2876 (time=57.52), 0.179735 s/step
# on time step 2899 (time=57.98), 0.177778 s/step
# on time step 2922 (time=58.44), 0.177612 s/step
# on time step 2945 (time=58.9), 0.177345 s/step
# on time step 2968 (time=59.36), 0.178823 s/step
# on time step 2991 (time=59.82), 0.178983 s/step
# field decay(t = 60.1): 0.016808171295677313 / 0.2997361839469467 = 0.05607655063311395
# on time step 3014 (time=60.28), 0.178484 s/step
# on time step 3037 (time=60.74), 0.17871 s/step
# on time step 3060 (time=61.2), 0.178725 s/step
# on time step 3083 (time=61.66), 0.178898 s/step
# on time step 3106 (time=62.12), 0.178187 s/step
# on time step 3129 (time=62.58), 0.179164 s/step
# on time step 3152 (time=63.04), 0.181123 s/step
# on time step 3175 (time=63.5), 0.178802 s/step
# on time step 3198 (time=63.96), 0.178149 s/step
# on time step 3221 (time=64.42), 0.178411 s/step
# on time step 3244 (time=64.88), 0.177756 s/step
# on time step 3267 (time=65.34), 0.177968 s/step
# on time step 3290 (time=65.8), 0.178652 s/step
# on time step 3313 (time=66.26), 0.17939 s/step
# on time step 3336 (time=66.72), 0.177501 s/step
# on time step 3359 (time=67.18), 0.177108 s/step
# on time step 3382 (time=67.64), 0.177531 s/step
# on time step 3405 (time=68.1), 0.177348 s/step
# on time step 3428 (time=68.56), 0.177722 s/step
# on time step 3451 (time=69.02), 0.177379 s/step
# on time step 3474 (time=69.48), 0.177232 s/step
# on time step 3497 (time=69.94), 0.177112 s/step
# field decay(t = 70.12): 0.006822636367930827 / 0.2997361839469467 = 0.022762137951080456
# on time step 3520 (time=70.4), 0.178946 s/step
# on time step 3543 (time=70.86), 0.177616 s/step
# on time step 3566 (time=71.32), 0.178106 s/step
# on time step 3589 (time=71.78), 0.177389 s/step
# on time step 3612 (time=72.24), 0.177105 s/step
# on time step 3635 (time=72.7), 0.17907 s/step
# on time step 3658 (time=73.16), 0.177927 s/step
# on time step 3681 (time=73.62), 0.177411 s/step
# on time step 3704 (time=74.08), 0.177269 s/step
# on time step 3727 (time=74.54), 0.177018 s/step
# on time step 3750 (time=75), 0.177464 s/step
# on time step 3773 (time=75.46), 0.180197 s/step
# on time step 3796 (time=75.92), 0.177259 s/step
# on time step 3819 (time=76.38), 0.176811 s/step
# on time step 3842 (time=76.84), 0.177158 s/step
# on time step 3865 (time=77.3), 0.176969 s/step
# on time step 3888 (time=77.76), 0.177828 s/step
# on time step 3911 (time=78.22), 0.1768 s/step
# on time step 3934 (time=78.68), 0.18007 s/step
# on time step 3957 (time=79.14), 0.177553 s/step
# on time step 3980 (time=79.6), 0.17725 s/step
# on time step 4003 (time=80.06), 0.178298 s/step
# field decay(t = 80.14): 0.001948262231743693 / 0.2997361839469467 = 0.006499923386255346
# on time step 4026 (time=80.52), 0.177461 s/step
# on time step 4049 (time=80.98), 0.178093 s/step
# on time step 4072 (time=81.44), 0.177708 s/step
# on time step 4095 (time=81.9), 0.178198 s/step
# on time step 4118 (time=82.36), 0.178431 s/step
# on time step 4141 (time=82.82), 0.17684 s/step
# on time step 4164 (time=83.28), 0.176752 s/step
# on time step 4187 (time=83.74), 0.177014 s/step
# on time step 4210 (time=84.2), 0.177036 s/step
# on time step 4233 (time=84.66), 0.179467 s/step
# on time step 4256 (time=85.12), 0.178704 s/step
# on time step 4279 (time=85.58), 0.179677 s/step
# on time step 4302 (time=86.04), 0.177854 s/step
# on time step 4325 (time=86.5), 0.177143 s/step
# on time step 4348 (time=86.96), 0.177111 s/step
# on time step 4371 (time=87.42), 0.178018 s/step
# on time step 4394 (time=87.88), 0.177607 s/step
# on time step 4417 (time=88.34), 0.177256 s/step
# on time step 4440 (time=88.8), 0.178138 s/step
# on time step 4463 (time=89.26), 0.177396 s/step
# on time step 4486 (time=89.72), 0.177081 s/step
# field decay(t = 90.16): 0.00048453070034516413 / 0.2997361839469467 = 0.0016165238843199729
# on time step 4509 (time=90.18), 0.177345 s/step
# on time step 4532 (time=90.64), 0.178558 s/step
# on time step 4555 (time=91.1), 0.179264 s/step
# on time step 4578 (time=91.56), 0.177382 s/step
# on time step 4601 (time=92.02), 0.178359 s/step
# on time step 4624 (time=92.48), 0.178403 s/step
# on time step 4647 (time=92.94), 0.178396 s/step
# on time step 4670 (time=93.4), 0.1783 s/step
# on time step 4693 (time=93.86), 0.177844 s/step
# on time step 4716 (time=94.32), 0.177931 s/step
# on time step 4739 (time=94.78), 0.178606 s/step
# on time step 4762 (time=95.24), 0.179025 s/step
# on time step 4785 (time=95.7), 0.178184 s/step
# on time step 4808 (time=96.16), 0.176975 s/step
# on time step 4831 (time=96.62), 0.177731 s/step
# on time step 4854 (time=97.08), 0.177316 s/step
# on time step 4877 (time=97.54), 0.176899 s/step
# on time step 4900 (time=98), 0.178425 s/step
# on time step 4923 (time=98.46), 0.17939 s/step
# on time step 4946 (time=98.92), 0.177529 s/step
# on time step 4969 (time=99.38), 0.177552 s/step
# on time step 4992 (time=99.84), 0.177313 s/step
# field decay(t = 100.18): 0.00016927639652399205 / 0.2997361839469467 = 0.0005647512899341976
# run 0 finished at t = 100.18 (5009 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000359058 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 7.53882 s
# -----------
# on time step 1 (time=0.02), 7.93835 s/step
# on time step 26 (time=0.52), 0.161931 s/step
# on time step 51 (time=1.02), 0.161384 s/step
# on time step 76 (time=1.52), 0.166032 s/step
# on time step 101 (time=2.02), 0.161542 s/step
# on time step 126 (time=2.52), 0.166947 s/step
# on time step 151 (time=3.02), 0.161669 s/step
# on time step 176 (time=3.52), 0.161079 s/step
# on time step 201 (time=4.02), 0.165969 s/step
# on time step 226 (time=4.52), 0.163168 s/step
# on time step 251 (time=5.02), 0.161984 s/step
# on time step 276 (time=5.52), 0.166146 s/step
# on time step 301 (time=6.02), 0.162394 s/step
# on time step 325 (time=6.5), 0.167626 s/step
# on time step 350 (time=7), 0.161278 s/step
# on time step 375 (time=7.5), 0.162046 s/step
# on time step 399 (time=7.98), 0.166852 s/step
# on time step 424 (time=8.48), 0.161054 s/step
# on time step 449 (time=8.98), 0.161469 s/step
# on time step 474 (time=9.48), 0.165643 s/step
# on time step 499 (time=9.98), 0.161404 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 523 (time=10.46), 0.167395 s/step
# on time step 548 (time=10.96), 0.161228 s/step
# on time step 573 (time=11.46), 0.161929 s/step
# on time step 598 (time=11.96), 0.164938 s/step
# on time step 623 (time=12.46), 0.16093 s/step
# on time step 648 (time=12.96), 0.165499 s/step
# on time step 673 (time=13.46), 0.161311 s/step
# on time step 698 (time=13.96), 0.16073 s/step
# on time step 723 (time=14.46), 0.165207 s/step
# on time step 748 (time=14.96), 0.161987 s/step
# on time step 773 (time=15.46), 0.161369 s/step
# on time step 798 (time=15.96), 0.16526 s/step
# on time step 823 (time=16.46), 0.161336 s/step
# on time step 848 (time=16.96), 0.165653 s/step
# on time step 873 (time=17.46), 0.161616 s/step
# on time step 898 (time=17.96), 0.164167 s/step
# on time step 922 (time=18.44), 0.168906 s/step
# on time step 947 (time=18.94), 0.164423 s/step
# on time step 972 (time=19.44), 0.168449 s/step
# on time step 997 (time=19.94), 0.161095 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1022 (time=20.44), 0.16206 s/step
# on time step 1047 (time=20.94), 0.165455 s/step
# on time step 1072 (time=21.44), 0.164396 s/step
# on time step 1097 (time=21.94), 0.164646 s/step
# on time step 1122 (time=22.44), 0.166267 s/step
# on time step 1147 (time=22.94), 0.16286 s/step
# on time step 1172 (time=23.44), 0.16504 s/step
# on time step 1197 (time=23.94), 0.160918 s/step
# on time step 1222 (time=24.44), 0.16169 s/step
# on time step 1247 (time=24.94), 0.16555 s/step
# on time step 1272 (time=25.44), 0.161557 s/step
# on time step 1297 (time=25.94), 0.165812 s/step
# on time step 1322 (time=26.44), 0.161322 s/step
# on time step 1347 (time=26.94), 0.161122 s/step
# on time step 1372 (time=27.44), 0.165755 s/step
# on time step 1397 (time=27.94), 0.1617 s/step
# on time step 1422 (time=28.44), 0.165782 s/step
# on time step 1447 (time=28.94), 0.161981 s/step
# on time step 1472 (time=29.44), 0.161576 s/step
# on time step 1496 (time=29.92), 0.16669 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000643969 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 72.4953% done, 1.51814 s remaining
# subpixel-averaging is 71.8015% done, 1.57113 s remaining
# subpixel-averaging is 72.4028% done, 1.5251 s remaining
# time for set_epsilon = 29.8272 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 7.94569 s/step
# on time step 23 (time=0.46), 0.182592 s/step
# on time step 45 (time=0.9), 0.183205 s/step
# on time step 67 (time=1.34), 0.182959 s/step
# on time step 89 (time=1.78), 0.18276 s/step
# on time step 111 (time=2.22), 0.189684 s/step
# on time step 133 (time=2.66), 0.184593 s/step
# on time step 155 (time=3.1), 0.183722 s/step
# on time step 177 (time=3.54), 0.182948 s/step
# on time step 198 (time=3.96), 0.192681 s/step
# on time step 220 (time=4.4), 0.184265 s/step
# on time step 242 (time=4.84), 0.18434 s/step
# on time step 264 (time=5.28), 0.184333 s/step
# on time step 286 (time=5.72), 0.186135 s/step
# on time step 307 (time=6.14), 0.190587 s/step
# on time step 329 (time=6.58), 0.182394 s/step
# on time step 351 (time=7.02), 0.182636 s/step
# on time step 373 (time=7.46), 0.183142 s/step
# on time step 395 (time=7.9), 0.185034 s/step
# on time step 416 (time=8.32), 0.190822 s/step
# on time step 438 (time=8.76), 0.185887 s/step
# on time step 460 (time=9.2), 0.183049 s/step
# on time step 482 (time=9.64), 0.183517 s/step
# field decay(t = 10.02): 0.00038522936840553504 / 0.00038522936840553504 = 1.0
# on time step 504 (time=10.08), 0.190382 s/step
# on time step 526 (time=10.52), 0.184818 s/step
# on time step 548 (time=10.96), 0.18402 s/step
# on time step 570 (time=11.4), 0.183612 s/step
# on time step 592 (time=11.84), 0.183621 s/step
# on time step 613 (time=12.26), 0.191332 s/step
# on time step 635 (time=12.7), 0.184108 s/step
# on time step 657 (time=13.14), 0.18612 s/step
# on time step 679 (time=13.58), 0.184292 s/step
# on time step 701 (time=14.02), 0.184123 s/step
# on time step 722 (time=14.44), 0.19112 s/step
# on time step 744 (time=14.88), 0.184174 s/step
# on time step 766 (time=15.32), 0.183687 s/step
# on time step 788 (time=15.76), 0.186062 s/step
# on time step 810 (time=16.2), 0.190862 s/step
# on time step 832 (time=16.64), 0.183687 s/step
# on time step 854 (time=17.08), 0.183799 s/step
# on time step 876 (time=17.52), 0.183706 s/step
# on time step 898 (time=17.96), 0.183155 s/step
# on time step 919 (time=18.38), 0.190944 s/step
# on time step 941 (time=18.82), 0.184663 s/step
# on time step 963 (time=19.26), 0.184206 s/step
# on time step 985 (time=19.7), 0.183652 s/step
# field decay(t = 20.04): 0.04661875344835085 / 0.04661875344835085 = 1.0
# on time step 1007 (time=20.14), 0.185946 s/step
# on time step 1028 (time=20.56), 0.191436 s/step
# on time step 1050 (time=21), 0.183343 s/step
# on time step 1072 (time=21.44), 0.183957 s/step
# on time step 1094 (time=21.88), 0.186577 s/step
# on time step 1116 (time=22.32), 0.190752 s/step
# on time step 1138 (time=22.76), 0.184043 s/step
# on time step 1160 (time=23.2), 0.183858 s/step
# on time step 1182 (time=23.64), 0.184318 s/step
# on time step 1204 (time=24.08), 0.184156 s/step
# on time step 1225 (time=24.5), 0.190844 s/step
# on time step 1247 (time=24.94), 0.184392 s/step
# on time step 1269 (time=25.38), 0.184208 s/step
# on time step 1291 (time=25.82), 0.183564 s/step
# on time step 1313 (time=26.26), 0.182984 s/step
# on time step 1334 (time=26.68), 0.191739 s/step
# on time step 1356 (time=27.12), 0.183281 s/step
# on time step 1378 (time=27.56), 0.182646 s/step
# on time step 1400 (time=28), 0.183539 s/step
# on time step 1422 (time=28.44), 0.190175 s/step
# on time step 1444 (time=28.88), 0.185712 s/step
# on time step 1466 (time=29.32), 0.185584 s/step
# on time step 1488 (time=29.76), 0.183022 s/step
# field decay(t = 30.060000000000002): 0.008214977769751807 / 0.04661875344835085 = 0.176216161138955
# on time step 1510 (time=30.2), 0.183103 s/step
# on time step 1532 (time=30.64), 0.188815 s/step
# on time step 1554 (time=31.08), 0.182271 s/step
# on time step 1576 (time=31.52), 0.183139 s/step
# on time step 1598 (time=31.96), 0.183474 s/step
# on time step 1620 (time=32.4), 0.190121 s/step
# on time step 1642 (time=32.84), 0.183868 s/step
# on time step 1664 (time=33.28), 0.184229 s/step
# on time step 1686 (time=33.72), 0.183733 s/step
# on time step 1708 (time=34.16), 0.184848 s/step
# on time step 1730 (time=34.6), 0.189558 s/step
# on time step 1752 (time=35.04), 0.186034 s/step
# on time step 1774 (time=35.48), 0.187044 s/step
# on time step 1796 (time=35.92), 0.185177 s/step
# on time step 1818 (time=36.36), 0.190416 s/step
# on time step 1840 (time=36.8), 0.187611 s/step
# on time step 1862 (time=37.24), 0.185067 s/step
# on time step 1884 (time=37.68), 0.182944 s/step
# on time step 1906 (time=38.12), 0.183329 s/step
# on time step 1927 (time=38.54), 0.19125 s/step
# on time step 1949 (time=38.98), 0.182939 s/step
# on time step 1971 (time=39.42), 0.182512 s/step
# on time step 1993 (time=39.86), 0.183569 s/step
# field decay(t = 40.06): 0.003065691030634734 / 0.04661875344835085 = 0.0657608967179105
# on time step 2015 (time=40.3), 0.185724 s/step
# on time step 2036 (time=40.72), 0.190558 s/step
# on time step 2058 (time=41.16), 0.185021 s/step
# on time step 2080 (time=41.6), 0.183646 s/step
# on time step 2102 (time=42.04), 0.183732 s/step
# on time step 2124 (time=42.48), 0.189124 s/step
# on time step 2146 (time=42.92), 0.183288 s/step
# on time step 2168 (time=43.36), 0.182862 s/step
# on time step 2190 (time=43.8), 0.183807 s/step
# on time step 2212 (time=44.24), 0.183993 s/step
# on time step 2233 (time=44.66), 0.1913 s/step
# on time step 2255 (time=45.1), 0.184103 s/step
# on time step 2277 (time=45.54), 0.183472 s/step
# on time step 2299 (time=45.98), 0.183717 s/step
# on time step 2321 (time=46.42), 0.183941 s/step
# on time step 2342 (time=46.84), 0.191586 s/step
# on time step 2364 (time=47.28), 0.183318 s/step
# on time step 2386 (time=47.72), 0.183339 s/step
# on time step 2408 (time=48.16), 0.18523 s/step
# on time step 2430 (time=48.6), 0.190608 s/step
# on time step 2452 (time=49.04), 0.184109 s/step
# on time step 2474 (time=49.48), 0.185425 s/step
# on time step 2496 (time=49.92), 0.183946 s/step
# field decay(t = 50.08): 0.0023896262865063115 / 0.04661875344835085 = 0.05125890569240103
# on time step 2518 (time=50.36), 0.185503 s/step
# on time step 2539 (time=50.78), 0.19095 s/step
# on time step 2561 (time=51.22), 0.182912 s/step
# on time step 2583 (time=51.66), 0.183618 s/step
# on time step 2605 (time=52.1), 0.182263 s/step
# on time step 2627 (time=52.54), 0.185272 s/step
# on time step 2648 (time=52.96), 0.190546 s/step
# on time step 2670 (time=53.4), 0.183062 s/step
# on time step 2692 (time=53.84), 0.186058 s/step
# on time step 2714 (time=54.28), 0.18379 s/step
# on time step 2736 (time=54.72), 0.190499 s/step
# on time step 2758 (time=55.16), 0.18347 s/step
# on time step 2780 (time=55.6), 0.182882 s/step
# on time step 2802 (time=56.04), 0.182618 s/step
# on time step 2824 (time=56.48), 0.182968 s/step
# on time step 2845 (time=56.9), 0.192106 s/step
# on time step 2867 (time=57.34), 0.185993 s/step
# on time step 2889 (time=57.78), 0.182665 s/step
# on time step 2911 (time=58.22), 0.182635 s/step
# on time step 2933 (time=58.66), 0.18546 s/step
# on time step 2955 (time=59.1), 0.18933 s/step
# on time step 2977 (time=59.54), 0.183047 s/step
# on time step 2999 (time=59.98), 0.183166 s/step
# field decay(t = 60.1): 0.002027438502438127 / 0.04661875344835085 = 0.043489762219496846
# on time step 3021 (time=60.42), 0.183926 s/step
# on time step 3043 (time=60.86), 0.189694 s/step
# on time step 3065 (time=61.3), 0.18302 s/step
# on time step 3087 (time=61.74), 0.183643 s/step
# on time step 3109 (time=62.18), 0.182934 s/step
# on time step 3131 (time=62.62), 0.183131 s/step
# on time step 3153 (time=63.06), 0.189505 s/step
# on time step 3175 (time=63.5), 0.183296 s/step
# on time step 3197 (time=63.94), 0.183002 s/step
# on time step 3219 (time=64.38), 0.182027 s/step
# on time step 3241 (time=64.82), 0.188924 s/step
# on time step 3263 (time=65.26), 0.182377 s/step
# on time step 3285 (time=65.7), 0.182917 s/step
# on time step 3307 (time=66.14), 0.184137 s/step
# on time step 3329 (time=66.58), 0.186159 s/step
# on time step 3350 (time=67), 0.191281 s/step
# on time step 3372 (time=67.44), 0.18308 s/step
# on time step 3394 (time=67.88), 0.182864 s/step
# on time step 3416 (time=68.32), 0.182848 s/step
# on time step 3438 (time=68.76), 0.188983 s/step
# on time step 3460 (time=69.2), 0.182289 s/step
# on time step 3482 (time=69.64), 0.184833 s/step
# on time step 3504 (time=70.08), 0.18423 s/step
# field decay(t = 70.12): 0.0006247024159672659 / 0.04661875344835085 = 0.013400238525454716
# on time step 3526 (time=70.52), 0.183641 s/step
# on time step 3547 (time=70.94), 0.192209 s/step
# on time step 3569 (time=71.38), 0.184391 s/step
# on time step 3591 (time=71.82), 0.18343 s/step
# on time step 3613 (time=72.26), 0.184682 s/step
# on time step 3635 (time=72.7), 0.183644 s/step
# on time step 3656 (time=73.12), 0.191096 s/step
# on time step 3678 (time=73.56), 0.183668 s/step
# on time step 3700 (time=74), 0.183632 s/step
# on time step 3722 (time=74.44), 0.182581 s/step
# on time step 3744 (time=74.88), 0.189532 s/step
# on time step 3766 (time=75.32), 0.183523 s/step
# on time step 3788 (time=75.76), 0.183688 s/step
# on time step 3810 (time=76.2), 0.183732 s/step
# on time step 3832 (time=76.64), 0.185886 s/step
# on time step 3853 (time=77.06), 0.191212 s/step
# on time step 3875 (time=77.5), 0.183941 s/step
# on time step 3897 (time=77.94), 0.185014 s/step
# on time step 3919 (time=78.38), 0.186297 s/step
# on time step 3941 (time=78.82), 0.184354 s/step
# on time step 3962 (time=79.24), 0.190929 s/step
# on time step 3984 (time=79.68), 0.18585 s/step
# on time step 4006 (time=80.12), 0.185866 s/step
# field decay(t = 80.14): 0.0003556942399299288 / 0.04661875344835085 = 0.007629853087427664
# on time step 4028 (time=80.56), 0.185071 s/step
# on time step 4050 (time=81), 0.189521 s/step
# on time step 4072 (time=81.44), 0.183254 s/step
# on time step 4094 (time=81.88), 0.183223 s/step
# on time step 4116 (time=82.32), 0.182661 s/step
# on time step 4138 (time=82.76), 0.182472 s/step
# on time step 4160 (time=83.2), 0.189618 s/step
# on time step 4182 (time=83.64), 0.18281 s/step
# on time step 4204 (time=84.08), 0.182714 s/step
# on time step 4226 (time=84.52), 0.18314 s/step
# on time step 4248 (time=84.96), 0.191574 s/step
# on time step 4270 (time=85.4), 0.187992 s/step
# on time step 4292 (time=85.84), 0.185782 s/step
# on time step 4314 (time=86.28), 0.188007 s/step
# on time step 4336 (time=86.72), 0.18551 s/step
# on time step 4357 (time=87.14), 0.196344 s/step
# on time step 4379 (time=87.58), 0.18834 s/step
# on time step 4400 (time=88), 0.191766 s/step
# on time step 4422 (time=88.44), 0.188903 s/step
# on time step 4444 (time=88.88), 0.184627 s/step
# on time step 4465 (time=89.3), 0.190591 s/step
# on time step 4487 (time=89.74), 0.186553 s/step
# field decay(t = 90.16): 3.488934076763289e-05 / 0.04661875344835085 = 0.0007483971189038113
# run 0 finished at t = 90.16 (4508 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])
if mp.am_master():
    plt.figure(dpi=900)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")
