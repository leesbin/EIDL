# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=11.8)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 1 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * (design_region_width_x-air_gap*2))) + 1
Ny = int(round(design_region_resolution * (design_region_width_y-air_gap*2))) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, TiO2, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00067687 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.0384% done, 1.63134 s remaining
# subpixel-averaging is 69.651% done, 1.74335 s remaining
# subpixel-averaging is 71.339% done, 1.60757 s remaining
# time for set_epsilon = 30.5663 s
# -----------
# on time step 1 (time=0.02), 8.11821 s/step
# on time step 21 (time=0.42), 0.210534 s/step
# on time step 39 (time=0.78), 0.233482 s/step
# on time step 56 (time=1.12), 0.235645 s/step
# on time step 74 (time=1.48), 0.233431 s/step
# on time step 91 (time=1.82), 0.236588 s/step
# on time step 108 (time=2.16), 0.236894 s/step
# on time step 126 (time=2.52), 0.232294 s/step
# on time step 144 (time=2.88), 0.233866 s/step
# on time step 162 (time=3.24), 0.233508 s/step
# on time step 180 (time=3.6), 0.233713 s/step
# on time step 197 (time=3.94), 0.236301 s/step
# on time step 215 (time=4.3), 0.232518 s/step
# on time step 233 (time=4.66), 0.234307 s/step
# on time step 251 (time=5.02), 0.233882 s/step
# on time step 269 (time=5.38), 0.235014 s/step
# on time step 286 (time=5.72), 0.238025 s/step
# on time step 303 (time=6.06), 0.242878 s/step
# on time step 321 (time=6.42), 0.233657 s/step
# on time step 338 (time=6.76), 0.236748 s/step
# on time step 356 (time=7.12), 0.233125 s/step
# on time step 377 (time=7.54), 0.195051 s/step
# on time step 395 (time=7.9), 0.234053 s/step
# on time step 411 (time=8.22), 0.251131 s/step
# on time step 429 (time=8.58), 0.233625 s/step
# on time step 446 (time=8.92), 0.241999 s/step
# on time step 462 (time=9.24), 0.252116 s/step
# on time step 478 (time=9.56), 0.256904 s/step
# on time step 494 (time=9.88), 0.251624 s/step
# field decay(t = 10.02): 4.7089468631989125e-08 / 4.7089468631989125e-08 = 1.0
# on time step 510 (time=10.2), 0.25794 s/step
# on time step 526 (time=10.52), 0.252213 s/step
# on time step 543 (time=10.86), 0.245113 s/step
# on time step 560 (time=11.2), 0.239562 s/step
# on time step 577 (time=11.54), 0.242019 s/step
# on time step 594 (time=11.88), 0.249481 s/step
# on time step 610 (time=12.2), 0.264831 s/step
# on time step 627 (time=12.54), 0.245934 s/step
# on time step 643 (time=12.86), 0.256579 s/step
# on time step 659 (time=13.18), 0.266165 s/step
# on time step 675 (time=13.5), 0.265892 s/step
# on time step 691 (time=13.82), 0.265454 s/step
# on time step 707 (time=14.14), 0.261866 s/step
# on time step 722 (time=14.44), 0.281882 s/step
# on time step 739 (time=14.78), 0.246393 s/step
# on time step 755 (time=15.1), 0.255827 s/step
# on time step 773 (time=15.46), 0.231652 s/step
# on time step 790 (time=15.8), 0.240682 s/step
# on time step 807 (time=16.14), 0.246448 s/step
# on time step 825 (time=16.5), 0.233358 s/step
# on time step 843 (time=16.86), 0.225129 s/step
# on time step 859 (time=17.18), 0.250048 s/step
# on time step 876 (time=17.52), 0.23785 s/step
# on time step 891 (time=17.82), 0.267083 s/step
# on time step 907 (time=18.14), 0.262103 s/step
# on time step 924 (time=18.48), 0.246892 s/step
# on time step 941 (time=18.82), 0.242039 s/step
# on time step 958 (time=19.16), 0.238526 s/step
# on time step 975 (time=19.5), 0.248797 s/step
# on time step 992 (time=19.84), 0.235301 s/step
# field decay(t = 20.04): 0.004191176971612662 / 0.004191176971612662 = 1.0
# on time step 1009 (time=20.18), 0.239932 s/step
# on time step 1027 (time=20.54), 0.232902 s/step
# on time step 1044 (time=20.88), 0.235944 s/step
# on time step 1061 (time=21.22), 0.241526 s/step
# on time step 1078 (time=21.56), 0.246953 s/step
# on time step 1094 (time=21.88), 0.250801 s/step
# on time step 1109 (time=22.18), 0.266966 s/step
# on time step 1124 (time=22.48), 0.269484 s/step
# on time step 1141 (time=22.82), 0.238594 s/step
# on time step 1158 (time=23.16), 0.236145 s/step
# on time step 1175 (time=23.5), 0.23607 s/step
# on time step 1192 (time=23.84), 0.23638 s/step
# on time step 1209 (time=24.18), 0.236569 s/step
# on time step 1226 (time=24.52), 0.235441 s/step
# on time step 1243 (time=24.86), 0.240474 s/step
# on time step 1260 (time=25.2), 0.236965 s/step
# on time step 1278 (time=25.56), 0.232963 s/step
# on time step 1296 (time=25.92), 0.232782 s/step
# on time step 1314 (time=26.28), 0.231439 s/step
# on time step 1332 (time=26.64), 0.233407 s/step
# on time step 1350 (time=27), 0.231487 s/step
# on time step 1368 (time=27.36), 0.232132 s/step
# on time step 1386 (time=27.72), 0.231296 s/step
# on time step 1407 (time=28.14), 0.193239 s/step
# on time step 1430 (time=28.6), 0.175437 s/step
# on time step 1453 (time=29.06), 0.175558 s/step
# on time step 1476 (time=29.52), 0.176504 s/step
# on time step 1499 (time=29.98), 0.174609 s/step
# field decay(t = 30.060000000000002): 0.14828354344117792 / 0.14828354344117792 = 1.0
# on time step 1522 (time=30.44), 0.180644 s/step
# on time step 1544 (time=30.88), 0.189472 s/step
# on time step 1566 (time=31.32), 0.182893 s/step
# on time step 1588 (time=31.76), 0.185091 s/step
# on time step 1611 (time=32.22), 0.179881 s/step
# on time step 1634 (time=32.68), 0.174262 s/step
# on time step 1658 (time=33.16), 0.172676 s/step
# on time step 1682 (time=33.64), 0.17321 s/step
# on time step 1705 (time=34.1), 0.17859 s/step
# on time step 1728 (time=34.56), 0.174204 s/step
# on time step 1751 (time=35.02), 0.178254 s/step
# on time step 1774 (time=35.48), 0.181381 s/step
# on time step 1797 (time=35.94), 0.179357 s/step
# on time step 1819 (time=36.38), 0.187663 s/step
# on time step 1842 (time=36.84), 0.180857 s/step
# on time step 1865 (time=37.3), 0.181807 s/step
# on time step 1886 (time=37.72), 0.192581 s/step
# on time step 1909 (time=38.18), 0.179869 s/step
# on time step 1931 (time=38.62), 0.181881 s/step
# on time step 1954 (time=39.08), 0.181976 s/step
# on time step 1976 (time=39.52), 0.189072 s/step
# on time step 1998 (time=39.96), 0.189153 s/step
# field decay(t = 40.06): 0.15137442893640624 / 0.15137442893640624 = 1.0
# on time step 2020 (time=40.4), 0.187526 s/step
# on time step 2042 (time=40.84), 0.184119 s/step
# on time step 2064 (time=41.28), 0.185708 s/step
# on time step 2085 (time=41.7), 0.19629 s/step
# on time step 2108 (time=42.16), 0.180157 s/step
# on time step 2132 (time=42.64), 0.173634 s/step
# on time step 2155 (time=43.1), 0.178968 s/step
# on time step 2178 (time=43.56), 0.175694 s/step
# on time step 2201 (time=44.02), 0.174764 s/step
# on time step 2224 (time=44.48), 0.180233 s/step
# on time step 2247 (time=44.94), 0.176803 s/step
# on time step 2270 (time=45.4), 0.176173 s/step
# on time step 2293 (time=45.86), 0.177829 s/step
# on time step 2315 (time=46.3), 0.187619 s/step
# on time step 2338 (time=46.76), 0.17964 s/step
# on time step 2360 (time=47.2), 0.183742 s/step
# on time step 2382 (time=47.64), 0.183777 s/step
# on time step 2405 (time=48.1), 0.175736 s/step
# on time step 2428 (time=48.56), 0.177566 s/step
# on time step 2451 (time=49.02), 0.175509 s/step
# on time step 2474 (time=49.48), 0.177904 s/step
# on time step 2496 (time=49.92), 0.183772 s/step
# field decay(t = 50.08): 0.02168794107958247 / 0.15137442893640624 = 0.14327347909397414
# on time step 2519 (time=50.38), 0.178113 s/step
# on time step 2542 (time=50.84), 0.173968 s/step
# on time step 2565 (time=51.3), 0.174433 s/step
# on time step 2588 (time=51.76), 0.173929 s/step
# on time step 2611 (time=52.22), 0.17454 s/step
# on time step 2634 (time=52.68), 0.177184 s/step
# on time step 2657 (time=53.14), 0.175697 s/step
# on time step 2680 (time=53.6), 0.179677 s/step
# on time step 2702 (time=54.04), 0.181855 s/step
# on time step 2724 (time=54.48), 0.183755 s/step
# on time step 2745 (time=54.9), 0.19063 s/step
# on time step 2767 (time=55.34), 0.186001 s/step
# on time step 2790 (time=55.8), 0.17708 s/step
# on time step 2812 (time=56.24), 0.186717 s/step
# on time step 2835 (time=56.7), 0.17681 s/step
# on time step 2858 (time=57.16), 0.177368 s/step
# on time step 2880 (time=57.6), 0.182197 s/step
# on time step 2903 (time=58.06), 0.17514 s/step
# on time step 2926 (time=58.52), 0.176789 s/step
# on time step 2949 (time=58.98), 0.178642 s/step
# on time step 2971 (time=59.42), 0.185654 s/step
# on time step 2993 (time=59.86), 0.183303 s/step
# field decay(t = 60.1): 0.013585656116586598 / 0.15137442893640624 = 0.08974868616874554
# on time step 3016 (time=60.32), 0.178037 s/step
# on time step 3039 (time=60.78), 0.177761 s/step
# on time step 3061 (time=61.22), 0.187428 s/step
# on time step 3084 (time=61.68), 0.17901 s/step
# on time step 3107 (time=62.14), 0.176876 s/step
# on time step 3130 (time=62.6), 0.177275 s/step
# on time step 3153 (time=63.06), 0.174757 s/step
# on time step 3176 (time=63.52), 0.17751 s/step
# on time step 3198 (time=63.96), 0.182178 s/step
# on time step 3221 (time=64.42), 0.177963 s/step
# on time step 3244 (time=64.88), 0.177253 s/step
# on time step 3267 (time=65.34), 0.1749 s/step
# on time step 3290 (time=65.8), 0.17806 s/step
# on time step 3313 (time=66.26), 0.175712 s/step
# on time step 3336 (time=66.72), 0.175702 s/step
# on time step 3359 (time=67.18), 0.174471 s/step
# on time step 3382 (time=67.64), 0.17568 s/step
# on time step 3405 (time=68.1), 0.177597 s/step
# on time step 3427 (time=68.54), 0.184443 s/step
# on time step 3450 (time=69), 0.175869 s/step
# on time step 3474 (time=69.48), 0.172716 s/step
# on time step 3498 (time=69.96), 0.173235 s/step
# field decay(t = 70.12): 0.012124849889103074 / 0.15137442893640624 = 0.08009840218255643
# on time step 3520 (time=70.4), 0.181962 s/step
# on time step 3542 (time=70.84), 0.182466 s/step
# on time step 3565 (time=71.3), 0.180429 s/step
# on time step 3587 (time=71.74), 0.183083 s/step
# on time step 3609 (time=72.18), 0.187346 s/step
# on time step 3632 (time=72.64), 0.175591 s/step
# on time step 3655 (time=73.1), 0.177325 s/step
# on time step 3678 (time=73.56), 0.17963 s/step
# on time step 3700 (time=74), 0.186156 s/step
# on time step 3722 (time=74.44), 0.187837 s/step
# on time step 3746 (time=74.92), 0.173613 s/step
# on time step 3769 (time=75.38), 0.174915 s/step
# on time step 3792 (time=75.84), 0.176381 s/step
# on time step 3815 (time=76.3), 0.174629 s/step
# on time step 3839 (time=76.78), 0.173747 s/step
# on time step 3862 (time=77.24), 0.174003 s/step
# on time step 3885 (time=77.7), 0.173959 s/step
# on time step 3908 (time=78.16), 0.175641 s/step
# on time step 3931 (time=78.62), 0.175617 s/step
# on time step 3954 (time=79.08), 0.177618 s/step
# on time step 3977 (time=79.54), 0.175107 s/step
# on time step 4000 (time=80), 0.176781 s/step
# field decay(t = 80.14): 0.00015470054329707044 / 0.15137442893640624 = 0.0010219727624013798
# on time step 4023 (time=80.46), 0.177834 s/step
# on time step 4046 (time=80.92), 0.178374 s/step
# on time step 4069 (time=81.38), 0.179591 s/step
# on time step 4091 (time=81.82), 0.183632 s/step
# on time step 4112 (time=82.24), 0.190689 s/step
# on time step 4134 (time=82.68), 0.184794 s/step
# on time step 4156 (time=83.12), 0.182775 s/step
# on time step 4178 (time=83.56), 0.186495 s/step
# on time step 4200 (time=84), 0.182835 s/step
# on time step 4223 (time=84.46), 0.176626 s/step
# on time step 4246 (time=84.92), 0.179674 s/step
# on time step 4269 (time=85.38), 0.178706 s/step
# on time step 4293 (time=85.86), 0.173777 s/step
# on time step 4317 (time=86.34), 0.172966 s/step
# on time step 4340 (time=86.8), 0.178177 s/step
# on time step 4363 (time=87.26), 0.175599 s/step
# on time step 4386 (time=87.72), 0.179294 s/step
# on time step 4409 (time=88.18), 0.18097 s/step
# on time step 4432 (time=88.64), 0.176393 s/step
# on time step 4455 (time=89.1), 0.174938 s/step
# on time step 4478 (time=89.56), 0.175212 s/step
# on time step 4501 (time=90.02), 0.174521 s/step
# field decay(t = 90.16): 4.523793627175786e-05 / 0.15137442893640624 = 0.00029884794010197536
# run 0 finished at t = 90.16 (4508 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000638008 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 72.634% done, 1.50719 s remaining
# subpixel-averaging is 71.6165% done, 1.58532 s remaining
# subpixel-averaging is 72.0328% done, 1.55362 s remaining
# time for set_epsilon = 29.8859 s
# -----------
# on time step 1 (time=0.02), 7.94816 s/step
# on time step 24 (time=0.48), 0.174285 s/step
# on time step 47 (time=0.94), 0.176257 s/step
# on time step 70 (time=1.4), 0.178391 s/step
# on time step 94 (time=1.88), 0.173063 s/step
# on time step 118 (time=2.36), 0.173544 s/step
# on time step 142 (time=2.84), 0.173628 s/step
# on time step 166 (time=3.32), 0.172646 s/step
# on time step 189 (time=3.78), 0.177268 s/step
# on time step 212 (time=4.24), 0.178163 s/step
# on time step 235 (time=4.7), 0.181173 s/step
# on time step 258 (time=5.16), 0.17753 s/step
# on time step 281 (time=5.62), 0.18089 s/step
# on time step 304 (time=6.08), 0.17534 s/step
# on time step 327 (time=6.54), 0.17423 s/step
# on time step 350 (time=7), 0.179686 s/step
# on time step 373 (time=7.46), 0.180447 s/step
# on time step 396 (time=7.92), 0.178861 s/step
# on time step 419 (time=8.38), 0.177934 s/step
# on time step 442 (time=8.84), 0.177341 s/step
# on time step 465 (time=9.3), 0.174606 s/step
# on time step 488 (time=9.76), 0.177746 s/step
# field decay(t = 10.02): 4.161825613836189e-09 / 4.161825613836189e-09 = 1.0
# on time step 511 (time=10.22), 0.175792 s/step
# on time step 534 (time=10.68), 0.175113 s/step
# on time step 556 (time=11.12), 0.185152 s/step
# on time step 579 (time=11.58), 0.181174 s/step
# on time step 601 (time=12.02), 0.186225 s/step
# on time step 623 (time=12.46), 0.185994 s/step
# on time step 646 (time=12.92), 0.181068 s/step
# on time step 669 (time=13.38), 0.178445 s/step
# on time step 692 (time=13.84), 0.174596 s/step
# on time step 715 (time=14.3), 0.177378 s/step
# on time step 738 (time=14.76), 0.174108 s/step
# on time step 761 (time=15.22), 0.174457 s/step
# on time step 784 (time=15.68), 0.175897 s/step
# on time step 807 (time=16.14), 0.174013 s/step
# on time step 830 (time=16.6), 0.175096 s/step
# on time step 853 (time=17.06), 0.176889 s/step
# on time step 876 (time=17.52), 0.175277 s/step
# on time step 899 (time=17.98), 0.17856 s/step
# on time step 921 (time=18.42), 0.182298 s/step
# on time step 944 (time=18.88), 0.181288 s/step
# on time step 967 (time=19.34), 0.180093 s/step
# on time step 989 (time=19.78), 0.183552 s/step
# field decay(t = 20.04): 0.0002542627095983387 / 0.0002542627095983387 = 1.0
# on time step 1012 (time=20.24), 0.179225 s/step
# on time step 1035 (time=20.7), 0.175141 s/step
# on time step 1058 (time=21.16), 0.176276 s/step
# on time step 1081 (time=21.62), 0.174845 s/step
# on time step 1104 (time=22.08), 0.179993 s/step
# on time step 1125 (time=22.5), 0.192534 s/step
# on time step 1147 (time=22.94), 0.184427 s/step
# on time step 1169 (time=23.38), 0.184968 s/step
# on time step 1191 (time=23.82), 0.184761 s/step
# on time step 1213 (time=24.26), 0.187059 s/step
# on time step 1235 (time=24.7), 0.188389 s/step
# on time step 1257 (time=25.14), 0.185198 s/step
# on time step 1279 (time=25.58), 0.18197 s/step
# on time step 1301 (time=26.02), 0.187338 s/step
# on time step 1323 (time=26.46), 0.184228 s/step
# on time step 1346 (time=26.92), 0.177356 s/step
# on time step 1369 (time=27.38), 0.179423 s/step
# on time step 1391 (time=27.82), 0.181855 s/step
# on time step 1414 (time=28.28), 0.18025 s/step
# on time step 1437 (time=28.74), 0.179888 s/step
# on time step 1459 (time=29.18), 0.182885 s/step
# on time step 1482 (time=29.64), 0.180009 s/step
# field decay(t = 30.060000000000002): 0.0696924118363579 / 0.0696924118363579 = 1.0
# on time step 1505 (time=30.1), 0.180491 s/step
# on time step 1528 (time=30.56), 0.180345 s/step
# on time step 1551 (time=31.02), 0.179453 s/step
# on time step 1574 (time=31.48), 0.177728 s/step
# on time step 1597 (time=31.94), 0.178283 s/step
# on time step 1620 (time=32.4), 0.178506 s/step
# on time step 1644 (time=32.88), 0.173828 s/step
# on time step 1667 (time=33.34), 0.179356 s/step
# on time step 1690 (time=33.8), 0.179849 s/step
# on time step 1713 (time=34.26), 0.180174 s/step
# on time step 1736 (time=34.72), 0.180413 s/step
# on time step 1758 (time=35.16), 0.185504 s/step
# on time step 1780 (time=35.6), 0.18622 s/step
# on time step 1803 (time=36.06), 0.179548 s/step
# on time step 1826 (time=36.52), 0.176329 s/step
# on time step 1849 (time=36.98), 0.174101 s/step
# on time step 1872 (time=37.44), 0.179867 s/step
# on time step 1893 (time=37.86), 0.192025 s/step
# on time step 1914 (time=38.28), 0.192335 s/step
# on time step 1936 (time=38.72), 0.18988 s/step
# on time step 1958 (time=39.16), 0.187181 s/step
# on time step 1981 (time=39.62), 0.174671 s/step
# field decay(t = 40.06): 0.15649572570773365 / 0.15649572570773365 = 1.0
# on time step 2004 (time=40.08), 0.174527 s/step
# on time step 2027 (time=40.54), 0.176696 s/step
# on time step 2049 (time=40.98), 0.182959 s/step
# on time step 2071 (time=41.42), 0.183903 s/step
# on time step 2093 (time=41.86), 0.184784 s/step
# on time step 2116 (time=42.32), 0.176218 s/step
# on time step 2139 (time=42.78), 0.176435 s/step
# on time step 2162 (time=43.24), 0.175283 s/step
# on time step 2184 (time=43.68), 0.185515 s/step
# on time step 2206 (time=44.12), 0.187316 s/step
# on time step 2228 (time=44.56), 0.18867 s/step
# on time step 2249 (time=44.98), 0.193761 s/step
# on time step 2271 (time=45.42), 0.182028 s/step
# on time step 2294 (time=45.88), 0.177364 s/step
# on time step 2316 (time=46.32), 0.185235 s/step
# on time step 2339 (time=46.78), 0.179548 s/step
# on time step 2363 (time=47.26), 0.17376 s/step
# on time step 2386 (time=47.72), 0.18226 s/step
# on time step 2407 (time=48.14), 0.191361 s/step
# on time step 2428 (time=48.56), 0.197949 s/step
# on time step 2450 (time=49), 0.183038 s/step
# on time step 2473 (time=49.46), 0.180979 s/step
# on time step 2496 (time=49.92), 0.176895 s/step
# field decay(t = 50.08): 0.08824951733083333 / 0.15649572570773365 = 0.5639100808136145
# on time step 2520 (time=50.4), 0.173331 s/step
# on time step 2544 (time=50.88), 0.173295 s/step
# on time step 2567 (time=51.34), 0.181392 s/step
# on time step 2589 (time=51.78), 0.181821 s/step
# on time step 2610 (time=52.2), 0.191615 s/step
# on time step 2633 (time=52.66), 0.178995 s/step
# on time step 2655 (time=53.1), 0.186149 s/step
# on time step 2678 (time=53.56), 0.17703 s/step
# on time step 2700 (time=54), 0.185468 s/step
# on time step 2723 (time=54.46), 0.181182 s/step
# on time step 2745 (time=54.9), 0.185078 s/step
# on time step 2767 (time=55.34), 0.184156 s/step
# on time step 2789 (time=55.78), 0.183313 s/step
# on time step 2812 (time=56.24), 0.177109 s/step
# on time step 2835 (time=56.7), 0.180699 s/step
# on time step 2858 (time=57.16), 0.179646 s/step
# on time step 2881 (time=57.62), 0.178704 s/step
# on time step 2904 (time=58.08), 0.178844 s/step
# on time step 2927 (time=58.54), 0.179418 s/step
# on time step 2950 (time=59), 0.175052 s/step
# on time step 2974 (time=59.48), 0.173571 s/step
# on time step 2997 (time=59.94), 0.175094 s/step
# field decay(t = 60.1): 0.004529684485103362 / 0.15649572570773365 = 0.028944461355851048
# on time step 3020 (time=60.4), 0.17466 s/step
# on time step 3043 (time=60.86), 0.17511 s/step
# on time step 3067 (time=61.34), 0.173442 s/step
# on time step 3091 (time=61.82), 0.172948 s/step
# on time step 3114 (time=62.28), 0.175373 s/step
# on time step 3137 (time=62.74), 0.173945 s/step
# on time step 3161 (time=63.22), 0.173391 s/step
# on time step 3185 (time=63.7), 0.172987 s/step
# on time step 3208 (time=64.16), 0.176909 s/step
# on time step 3231 (time=64.62), 0.176689 s/step
# on time step 3254 (time=65.08), 0.177937 s/step
# on time step 3277 (time=65.54), 0.179458 s/step
# on time step 3300 (time=66), 0.179604 s/step
# on time step 3323 (time=66.46), 0.179616 s/step
# on time step 3345 (time=66.9), 0.182262 s/step
# on time step 3368 (time=67.36), 0.176222 s/step
# on time step 3391 (time=67.82), 0.177696 s/step
# on time step 3414 (time=68.28), 0.175324 s/step
# on time step 3438 (time=68.76), 0.173777 s/step
# on time step 3461 (time=69.22), 0.175743 s/step
# on time step 3484 (time=69.68), 0.175026 s/step
# field decay(t = 70.12): 0.00036195791603479017 / 0.15649572570773365 = 0.0023128933036214105
# on time step 3508 (time=70.16), 0.173585 s/step
# on time step 3532 (time=70.64), 0.173028 s/step
# on time step 3556 (time=71.12), 0.17335 s/step
# on time step 3580 (time=71.6), 0.172872 s/step
# on time step 3604 (time=72.08), 0.172712 s/step
# on time step 3628 (time=72.56), 0.173138 s/step
# on time step 3651 (time=73.02), 0.176792 s/step
# on time step 3674 (time=73.48), 0.17459 s/step
# on time step 3698 (time=73.96), 0.173547 s/step
# on time step 3721 (time=74.42), 0.174277 s/step
# on time step 3744 (time=74.88), 0.174122 s/step
# on time step 3767 (time=75.34), 0.174089 s/step
# on time step 3790 (time=75.8), 0.174595 s/step
# on time step 3813 (time=76.26), 0.174737 s/step
# on time step 3836 (time=76.72), 0.174616 s/step
# on time step 3859 (time=77.18), 0.174408 s/step
# on time step 3882 (time=77.64), 0.174693 s/step
# on time step 3905 (time=78.1), 0.174544 s/step
# on time step 3929 (time=78.58), 0.173179 s/step
# on time step 3953 (time=79.06), 0.17345 s/step
# on time step 3977 (time=79.54), 0.173515 s/step
# on time step 4000 (time=80), 0.174948 s/step
# field decay(t = 80.14): 0.0004136971098344512 / 0.15649572570773365 = 0.0026435042105051386
# on time step 4024 (time=80.48), 0.173457 s/step
# on time step 4047 (time=80.94), 0.17827 s/step
# on time step 4069 (time=81.38), 0.18991 s/step
# on time step 4092 (time=81.84), 0.180823 s/step
# on time step 4115 (time=82.3), 0.176842 s/step
# on time step 4138 (time=82.76), 0.178139 s/step
# on time step 4160 (time=83.2), 0.187807 s/step
# on time step 4183 (time=83.66), 0.180817 s/step
# on time step 4206 (time=84.12), 0.178132 s/step
# on time step 4229 (time=84.58), 0.176826 s/step
# on time step 4252 (time=85.04), 0.175845 s/step
# on time step 4275 (time=85.5), 0.175795 s/step
# on time step 4298 (time=85.96), 0.174363 s/step
# on time step 4321 (time=86.42), 0.177012 s/step
# on time step 4344 (time=86.88), 0.178036 s/step
# on time step 4367 (time=87.34), 0.176574 s/step
# on time step 4390 (time=87.8), 0.178427 s/step
# on time step 4413 (time=88.26), 0.176821 s/step
# on time step 4435 (time=88.7), 0.182971 s/step
# on time step 4458 (time=89.16), 0.179438 s/step
# on time step 4482 (time=89.64), 0.172961 s/step
# on time step 4506 (time=90.12), 0.1727 s/step
# field decay(t = 90.16): 0.0002239688834757958 / 0.15649572570773365 = 0.0014311501637691553
# on time step 4530 (time=90.6), 0.172711 s/step
# on time step 4554 (time=91.08), 0.172428 s/step
# on time step 4578 (time=91.56), 0.172085 s/step
# on time step 4602 (time=92.04), 0.172695 s/step
# on time step 4624 (time=92.48), 0.187969 s/step
# on time step 4646 (time=92.92), 0.187683 s/step
# on time step 4667 (time=93.34), 0.190557 s/step
# on time step 4689 (time=93.78), 0.188871 s/step
# on time step 4711 (time=94.22), 0.190175 s/step
# on time step 4733 (time=94.66), 0.18844 s/step
# on time step 4755 (time=95.1), 0.188808 s/step
# on time step 4776 (time=95.52), 0.190629 s/step
# on time step 4797 (time=95.94), 0.191624 s/step
# on time step 4819 (time=96.38), 0.188709 s/step
# on time step 4841 (time=96.82), 0.188949 s/step
# on time step 4863 (time=97.26), 0.186549 s/step
# on time step 4885 (time=97.7), 0.187717 s/step
# on time step 4907 (time=98.14), 0.187743 s/step
# on time step 4929 (time=98.58), 0.188669 s/step
# on time step 4951 (time=99.02), 0.189552 s/step
# on time step 4973 (time=99.46), 0.189407 s/step
# on time step 4995 (time=99.9), 0.188192 s/step
# field decay(t = 100.18): 9.502911585224096e-05 / 0.15649572570773365 = 0.0006072313823427629
# run 0 finished at t = 100.18 (5009 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000651836 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.4315% done, 1.59999 s remaining
# subpixel-averaging is 70.3678% done, 1.68499 s remaining
# subpixel-averaging is 71.2465% done, 1.61465 s remaining
# time for set_epsilon = 30.4022 s
# -----------
# on time step 1 (time=0.02), 8.05669 s/step
# on time step 23 (time=0.46), 0.190176 s/step
# on time step 45 (time=0.9), 0.189448 s/step
# on time step 67 (time=1.34), 0.188265 s/step
# on time step 89 (time=1.78), 0.188642 s/step
# on time step 111 (time=2.22), 0.188416 s/step
# on time step 133 (time=2.66), 0.188525 s/step
# on time step 155 (time=3.1), 0.188468 s/step
# on time step 177 (time=3.54), 0.188039 s/step
# on time step 199 (time=3.98), 0.188333 s/step
# on time step 221 (time=4.42), 0.188404 s/step
# on time step 243 (time=4.86), 0.188455 s/step
# on time step 265 (time=5.3), 0.188179 s/step
# on time step 287 (time=5.74), 0.188279 s/step
# on time step 309 (time=6.18), 0.188301 s/step
# on time step 331 (time=6.62), 0.189853 s/step
# on time step 353 (time=7.06), 0.189378 s/step
# on time step 375 (time=7.5), 0.187828 s/step
# on time step 397 (time=7.94), 0.188993 s/step
# on time step 419 (time=8.38), 0.188038 s/step
# on time step 441 (time=8.82), 0.188084 s/step
# on time step 463 (time=9.26), 0.188989 s/step
# on time step 485 (time=9.7), 0.189646 s/step
# field decay(t = 10.02): 5.9358237840695075e-09 / 5.9358237840695075e-09 = 1.0
# on time step 506 (time=10.12), 0.191034 s/step
# on time step 528 (time=10.56), 0.1879 s/step
# on time step 549 (time=10.98), 0.191104 s/step
# on time step 571 (time=11.42), 0.190094 s/step
# on time step 593 (time=11.86), 0.188655 s/step
# on time step 615 (time=12.3), 0.188534 s/step
# on time step 637 (time=12.74), 0.189056 s/step
# on time step 659 (time=13.18), 0.18907 s/step
# on time step 681 (time=13.62), 0.188086 s/step
# on time step 703 (time=14.06), 0.188748 s/step
# on time step 724 (time=14.48), 0.191509 s/step
# on time step 745 (time=14.9), 0.191256 s/step
# on time step 767 (time=15.34), 0.189971 s/step
# on time step 789 (time=15.78), 0.189025 s/step
# on time step 811 (time=16.22), 0.187711 s/step
# on time step 833 (time=16.66), 0.188627 s/step
# on time step 854 (time=17.08), 0.192785 s/step
# on time step 876 (time=17.52), 0.19011 s/step
# on time step 898 (time=17.96), 0.186779 s/step
# on time step 920 (time=18.4), 0.188153 s/step
# on time step 942 (time=18.84), 0.181831 s/step
# on time step 965 (time=19.3), 0.18026 s/step
# on time step 987 (time=19.74), 0.185122 s/step
# field decay(t = 20.04): 0.00031429930042330297 / 0.00031429930042330297 = 1.0
# on time step 1009 (time=20.18), 0.182051 s/step
# on time step 1031 (time=20.62), 0.181935 s/step
# on time step 1053 (time=21.06), 0.186331 s/step
# on time step 1076 (time=21.52), 0.181169 s/step
# on time step 1099 (time=21.98), 0.177277 s/step
# on time step 1122 (time=22.44), 0.176957 s/step
# on time step 1145 (time=22.9), 0.176155 s/step
# on time step 1168 (time=23.36), 0.174856 s/step
# on time step 1191 (time=23.82), 0.175165 s/step
# on time step 1214 (time=24.28), 0.175064 s/step
# on time step 1237 (time=24.74), 0.175919 s/step
# on time step 1260 (time=25.2), 0.175775 s/step
# on time step 1283 (time=25.66), 0.175904 s/step
# on time step 1306 (time=26.12), 0.175206 s/step
# on time step 1329 (time=26.58), 0.174911 s/step
# on time step 1352 (time=27.04), 0.175399 s/step
# on time step 1375 (time=27.5), 0.175968 s/step
# on time step 1398 (time=27.96), 0.174702 s/step
# on time step 1421 (time=28.42), 0.17503 s/step
# on time step 1444 (time=28.88), 0.176828 s/step
# on time step 1467 (time=29.34), 0.175366 s/step
# on time step 1490 (time=29.8), 0.176989 s/step
# field decay(t = 30.060000000000002): 0.1228620272112961 / 0.1228620272112961 = 1.0
# on time step 1513 (time=30.26), 0.176235 s/step
# on time step 1536 (time=30.72), 0.175451 s/step
# on time step 1559 (time=31.18), 0.175209 s/step
# on time step 1582 (time=31.64), 0.175122 s/step
# on time step 1605 (time=32.1), 0.175271 s/step
# on time step 1628 (time=32.56), 0.175324 s/step
# on time step 1651 (time=33.02), 0.176083 s/step
# on time step 1674 (time=33.48), 0.175123 s/step
# on time step 1697 (time=33.94), 0.174875 s/step
# on time step 1720 (time=34.4), 0.175134 s/step
# on time step 1743 (time=34.86), 0.174611 s/step
# on time step 1766 (time=35.32), 0.176746 s/step
# on time step 1789 (time=35.78), 0.178741 s/step
# on time step 1812 (time=36.24), 0.175981 s/step
# on time step 1835 (time=36.7), 0.177166 s/step
# on time step 1858 (time=37.16), 0.177585 s/step
# on time step 1881 (time=37.62), 0.176518 s/step
# on time step 1904 (time=38.08), 0.175882 s/step
# on time step 1927 (time=38.54), 0.176764 s/step
# on time step 1950 (time=39), 0.176422 s/step
# on time step 1973 (time=39.46), 0.177075 s/step
# on time step 1995 (time=39.9), 0.185037 s/step
# field decay(t = 40.06): 0.30574855546318513 / 0.30574855546318513 = 1.0
# on time step 2017 (time=40.34), 0.188381 s/step
# on time step 2040 (time=40.8), 0.181204 s/step
# on time step 2061 (time=41.22), 0.191291 s/step
# on time step 2082 (time=41.64), 0.198018 s/step
# on time step 2103 (time=42.06), 0.194243 s/step
# on time step 2124 (time=42.48), 0.195377 s/step
# on time step 2146 (time=42.92), 0.187667 s/step
# on time step 2168 (time=43.36), 0.182355 s/step
# on time step 2190 (time=43.8), 0.184687 s/step
# on time step 2212 (time=44.24), 0.187281 s/step
# on time step 2234 (time=44.68), 0.185258 s/step
# on time step 2256 (time=45.12), 0.189258 s/step
# on time step 2278 (time=45.56), 0.183085 s/step
# on time step 2300 (time=46), 0.18846 s/step
# on time step 2321 (time=46.42), 0.191791 s/step
# on time step 2342 (time=46.84), 0.192796 s/step
# on time step 2364 (time=47.28), 0.184305 s/step
# on time step 2384 (time=47.68), 0.202733 s/step
# on time step 2406 (time=48.12), 0.184097 s/step
# on time step 2428 (time=48.56), 0.182165 s/step
# on time step 2451 (time=49.02), 0.178469 s/step
# on time step 2474 (time=49.48), 0.181084 s/step
# on time step 2496 (time=49.92), 0.182459 s/step
# field decay(t = 50.08): 0.1798206153763875 / 0.30574855546318513 = 0.5881323465419921
# on time step 2518 (time=50.36), 0.186191 s/step
# on time step 2540 (time=50.8), 0.189041 s/step
# on time step 2562 (time=51.24), 0.186608 s/step
# on time step 2585 (time=51.7), 0.177506 s/step
# on time step 2608 (time=52.16), 0.182185 s/step
# on time step 2631 (time=52.62), 0.179853 s/step
# on time step 2653 (time=53.06), 0.184361 s/step
# on time step 2675 (time=53.5), 0.184383 s/step
# on time step 2697 (time=53.94), 0.187689 s/step
# on time step 2718 (time=54.36), 0.194771 s/step
# on time step 2740 (time=54.8), 0.190068 s/step
# on time step 2762 (time=55.24), 0.182597 s/step
# on time step 2784 (time=55.68), 0.183378 s/step
# on time step 2806 (time=56.12), 0.189944 s/step
# on time step 2828 (time=56.56), 0.19032 s/step
# on time step 2850 (time=57), 0.189954 s/step
# on time step 2872 (time=57.44), 0.186913 s/step
# on time step 2894 (time=57.88), 0.188235 s/step
# on time step 2915 (time=58.3), 0.191121 s/step
# on time step 2936 (time=58.72), 0.196007 s/step
# on time step 2955 (time=59.1), 0.210649 s/step
# on time step 2977 (time=59.54), 0.188766 s/step
# on time step 2998 (time=59.96), 0.196049 s/step
# field decay(t = 60.1): 0.00948252669845767 / 0.30574855546318513 = 0.031014134094901558
# on time step 3019 (time=60.38), 0.195845 s/step
# on time step 3040 (time=60.8), 0.192589 s/step
# on time step 3061 (time=61.22), 0.19539 s/step
# on time step 3082 (time=61.64), 0.1914 s/step
# on time step 3103 (time=62.06), 0.193795 s/step
# on time step 3124 (time=62.48), 0.191251 s/step
# on time step 3147 (time=62.94), 0.180416 s/step
# on time step 3170 (time=63.4), 0.178341 s/step
# on time step 3192 (time=63.84), 0.184876 s/step
# on time step 3215 (time=64.3), 0.179482 s/step
# on time step 3237 (time=64.74), 0.184702 s/step
# on time step 3260 (time=65.2), 0.178138 s/step
# on time step 3282 (time=65.64), 0.182063 s/step
# on time step 3304 (time=66.08), 0.188491 s/step
# on time step 3327 (time=66.54), 0.176627 s/step
# on time step 3349 (time=66.98), 0.186763 s/step
# on time step 3371 (time=67.42), 0.18887 s/step
# on time step 3392 (time=67.84), 0.190565 s/step
# on time step 3414 (time=68.28), 0.187426 s/step
# on time step 3436 (time=68.72), 0.1901 s/step
# on time step 3458 (time=69.16), 0.19033 s/step
# on time step 3480 (time=69.6), 0.185655 s/step
# on time step 3501 (time=70.02), 0.191741 s/step
# field decay(t = 70.12): 0.001934079206149456 / 0.30574855546318513 = 0.006325718213842343
# on time step 3523 (time=70.46), 0.181954 s/step
# on time step 3546 (time=70.92), 0.178863 s/step
# on time step 3569 (time=71.38), 0.179349 s/step
# on time step 3592 (time=71.84), 0.178004 s/step
# on time step 3615 (time=72.3), 0.181584 s/step
# on time step 3638 (time=72.76), 0.180051 s/step
# on time step 3661 (time=73.22), 0.180235 s/step
# on time step 3683 (time=73.66), 0.183273 s/step
# on time step 3706 (time=74.12), 0.17813 s/step
# on time step 3728 (time=74.56), 0.183759 s/step
# on time step 3749 (time=74.98), 0.192358 s/step
# on time step 3770 (time=75.4), 0.198566 s/step
# on time step 3791 (time=75.82), 0.194075 s/step
# on time step 3813 (time=76.26), 0.182027 s/step
# on time step 3835 (time=76.7), 0.181915 s/step
# on time step 3857 (time=77.14), 0.183658 s/step
# on time step 3880 (time=77.6), 0.179617 s/step
# on time step 3903 (time=78.06), 0.179941 s/step
# on time step 3925 (time=78.5), 0.184961 s/step
# on time step 3946 (time=78.92), 0.193816 s/step
# on time step 3967 (time=79.34), 0.195417 s/step
# on time step 3990 (time=79.8), 0.181396 s/step
# field decay(t = 80.14): 0.00028075080088666284 / 0.30574855546318513 = 0.0009182408088939206
# run 0 finished at t = 80.14 (4007 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000360966 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 7.6693 s
# -----------
# on time step 1 (time=0.02), 8.04725 s/step
# on time step 24 (time=0.48), 0.174695 s/step
# on time step 46 (time=0.92), 0.182056 s/step
# on time step 68 (time=1.36), 0.185516 s/step
# on time step 91 (time=1.82), 0.176029 s/step
# on time step 115 (time=2.3), 0.167081 s/step
# on time step 138 (time=2.76), 0.174398 s/step
# on time step 161 (time=3.22), 0.177494 s/step
# on time step 184 (time=3.68), 0.176389 s/step
# on time step 208 (time=4.16), 0.170068 s/step
# on time step 232 (time=4.64), 0.170364 s/step
# on time step 256 (time=5.12), 0.17186 s/step
# on time step 280 (time=5.6), 0.167028 s/step
# on time step 304 (time=6.08), 0.170151 s/step
# on time step 326 (time=6.52), 0.185315 s/step
# on time step 351 (time=7.02), 0.165611 s/step
# on time step 376 (time=7.52), 0.161762 s/step
# on time step 400 (time=8), 0.169178 s/step
# on time step 423 (time=8.46), 0.177599 s/step
# on time step 447 (time=8.94), 0.173121 s/step
# on time step 469 (time=9.38), 0.187052 s/step
# on time step 492 (time=9.84), 0.180874 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 515 (time=10.3), 0.181281 s/step
# on time step 539 (time=10.78), 0.167585 s/step
# on time step 561 (time=11.22), 0.183856 s/step
# on time step 585 (time=11.7), 0.172613 s/step
# on time step 608 (time=12.16), 0.178048 s/step
# on time step 632 (time=12.64), 0.168545 s/step
# on time step 657 (time=13.14), 0.162293 s/step
# on time step 682 (time=13.64), 0.163929 s/step
# on time step 704 (time=14.08), 0.183871 s/step
# on time step 726 (time=14.52), 0.186983 s/step
# on time step 749 (time=14.98), 0.173967 s/step
# on time step 773 (time=15.46), 0.171949 s/step
# on time step 797 (time=15.94), 0.168248 s/step
# on time step 820 (time=16.4), 0.174708 s/step
# on time step 844 (time=16.88), 0.169233 s/step
# on time step 867 (time=17.34), 0.175111 s/step
# on time step 891 (time=17.82), 0.171981 s/step
# on time step 914 (time=18.28), 0.177484 s/step
# on time step 937 (time=18.74), 0.179315 s/step
# on time step 961 (time=19.22), 0.167001 s/step
# on time step 984 (time=19.68), 0.175502 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1008 (time=20.16), 0.176461 s/step
# on time step 1030 (time=20.6), 0.18387 s/step
# on time step 1054 (time=21.08), 0.17389 s/step
# on time step 1078 (time=21.56), 0.170823 s/step
# on time step 1102 (time=22.04), 0.172334 s/step
# on time step 1126 (time=22.52), 0.171591 s/step
# on time step 1151 (time=23.02), 0.164086 s/step
# on time step 1175 (time=23.5), 0.171739 s/step
# on time step 1199 (time=23.98), 0.17093 s/step
# on time step 1223 (time=24.46), 0.173019 s/step
# on time step 1246 (time=24.92), 0.177824 s/step
# on time step 1271 (time=25.42), 0.163126 s/step
# on time step 1296 (time=25.92), 0.168803 s/step
# on time step 1319 (time=26.38), 0.177962 s/step
# on time step 1341 (time=26.82), 0.183934 s/step
# on time step 1363 (time=27.26), 0.184175 s/step
# on time step 1385 (time=27.7), 0.1896 s/step
# on time step 1406 (time=28.12), 0.192284 s/step
# on time step 1429 (time=28.58), 0.179225 s/step
# on time step 1451 (time=29.02), 0.183183 s/step
# on time step 1474 (time=29.48), 0.175888 s/step
# on time step 1497 (time=29.94), 0.180934 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000651121 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 70.5528% done, 1.67007 s remaining
# subpixel-averaging is 70.2522% done, 1.69394 s remaining
# subpixel-averaging is 71.7553% done, 1.57493 s remaining
# time for set_epsilon = 30.386 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 8.0281 s/step
# on time step 23 (time=0.46), 0.186934 s/step
# on time step 44 (time=0.88), 0.201085 s/step
# on time step 63 (time=1.26), 0.210807 s/step
# on time step 84 (time=1.68), 0.19161 s/step
# on time step 104 (time=2.08), 0.201749 s/step
# on time step 125 (time=2.5), 0.193774 s/step
# on time step 145 (time=2.9), 0.205867 s/step
# on time step 166 (time=3.32), 0.191881 s/step
# on time step 187 (time=3.74), 0.193634 s/step
# on time step 208 (time=4.16), 0.196129 s/step
# on time step 229 (time=4.58), 0.197762 s/step
# on time step 248 (time=4.96), 0.213402 s/step
# on time step 269 (time=5.38), 0.19287 s/step
# on time step 290 (time=5.8), 0.196322 s/step
# on time step 311 (time=6.22), 0.196713 s/step
# on time step 331 (time=6.62), 0.20781 s/step
# on time step 351 (time=7.02), 0.203413 s/step
# on time step 370 (time=7.4), 0.211656 s/step
# on time step 390 (time=7.8), 0.20033 s/step
# on time step 410 (time=8.2), 0.208189 s/step
# on time step 429 (time=8.58), 0.213546 s/step
# on time step 450 (time=9), 0.198133 s/step
# on time step 470 (time=9.4), 0.20555 s/step
# on time step 492 (time=9.84), 0.18833 s/step
# field decay(t = 10.02): 0.0004251545958112606 / 0.0004251545958112606 = 1.0
# on time step 514 (time=10.28), 0.185125 s/step
# on time step 536 (time=10.72), 0.184094 s/step
# on time step 558 (time=11.16), 0.1916 s/step
# on time step 579 (time=11.58), 0.193011 s/step
# on time step 600 (time=12), 0.194062 s/step
# on time step 619 (time=12.38), 0.211285 s/step
# on time step 638 (time=12.76), 0.22144 s/step
# on time step 658 (time=13.16), 0.205609 s/step
# on time step 678 (time=13.56), 0.203007 s/step
# on time step 698 (time=13.96), 0.207999 s/step
# on time step 718 (time=14.36), 0.20112 s/step
# on time step 739 (time=14.78), 0.192137 s/step
# on time step 761 (time=15.22), 0.184676 s/step
# on time step 783 (time=15.66), 0.183591 s/step
# on time step 805 (time=16.1), 0.183988 s/step
# on time step 826 (time=16.52), 0.191349 s/step
# on time step 846 (time=16.92), 0.20305 s/step
# on time step 867 (time=17.34), 0.194645 s/step
# on time step 887 (time=17.74), 0.202259 s/step
# on time step 907 (time=18.14), 0.206308 s/step
# on time step 929 (time=18.58), 0.188397 s/step
# on time step 950 (time=19), 0.195154 s/step
# on time step 971 (time=19.42), 0.198722 s/step
# on time step 993 (time=19.86), 0.189155 s/step
# field decay(t = 20.04): 0.045829427890496315 / 0.045829427890496315 = 1.0
# on time step 1015 (time=20.3), 0.184112 s/step
# on time step 1036 (time=20.72), 0.197576 s/step
# on time step 1057 (time=21.14), 0.199183 s/step
# on time step 1078 (time=21.56), 0.194633 s/step
# on time step 1098 (time=21.96), 0.203096 s/step
# on time step 1119 (time=22.38), 0.190895 s/step
# on time step 1141 (time=22.82), 0.185398 s/step
# on time step 1162 (time=23.24), 0.193866 s/step
# on time step 1182 (time=23.64), 0.200784 s/step
# on time step 1201 (time=24.02), 0.21069 s/step
# on time step 1221 (time=24.42), 0.20246 s/step
# on time step 1242 (time=24.84), 0.197001 s/step
# on time step 1263 (time=25.26), 0.192465 s/step
# on time step 1284 (time=25.68), 0.194605 s/step
# on time step 1304 (time=26.08), 0.201767 s/step
# on time step 1325 (time=26.5), 0.193214 s/step
# on time step 1346 (time=26.92), 0.192251 s/step
# on time step 1366 (time=27.32), 0.209285 s/step
# on time step 1387 (time=27.74), 0.195867 s/step
# on time step 1409 (time=28.18), 0.185346 s/step
# on time step 1431 (time=28.62), 0.185211 s/step
# on time step 1453 (time=29.06), 0.185266 s/step
# on time step 1475 (time=29.5), 0.184409 s/step
# on time step 1496 (time=29.92), 0.192737 s/step
# field decay(t = 30.060000000000002): 0.006986786172321858 / 0.045829427890496315 = 0.15245196141256465
# on time step 1518 (time=30.36), 0.186845 s/step
# on time step 1539 (time=30.78), 0.193366 s/step
# on time step 1560 (time=31.2), 0.192399 s/step
# on time step 1581 (time=31.62), 0.19113 s/step
# on time step 1602 (time=32.04), 0.200428 s/step
# on time step 1622 (time=32.44), 0.201997 s/step
# on time step 1644 (time=32.88), 0.189148 s/step
# on time step 1666 (time=33.32), 0.188177 s/step
# on time step 1688 (time=33.76), 0.184418 s/step
# on time step 1710 (time=34.2), 0.192311 s/step
# on time step 1732 (time=34.64), 0.183358 s/step
# on time step 1754 (time=35.08), 0.183026 s/step
# on time step 1776 (time=35.52), 0.185496 s/step
# on time step 1798 (time=35.96), 0.186693 s/step
# on time step 1819 (time=36.38), 0.190728 s/step
# on time step 1841 (time=36.82), 0.185955 s/step
# on time step 1863 (time=37.26), 0.184164 s/step
# on time step 1885 (time=37.7), 0.183221 s/step
# on time step 1907 (time=38.14), 0.18326 s/step
# on time step 1928 (time=38.56), 0.190984 s/step
# on time step 1950 (time=39), 0.183333 s/step
# on time step 1972 (time=39.44), 0.183636 s/step
# on time step 1994 (time=39.88), 0.183556 s/step
# field decay(t = 40.06): 0.005508649643813619 / 0.045829427890496315 = 0.12019896161426775
# on time step 2016 (time=40.32), 0.19115 s/step
# on time step 2036 (time=40.72), 0.202782 s/step
# on time step 2057 (time=41.14), 0.198427 s/step
# on time step 2077 (time=41.54), 0.206007 s/step
# on time step 2098 (time=41.96), 0.191168 s/step
# on time step 2119 (time=42.38), 0.195206 s/step
# on time step 2141 (time=42.82), 0.183549 s/step
# on time step 2162 (time=43.24), 0.19049 s/step
# on time step 2184 (time=43.68), 0.186856 s/step
# on time step 2206 (time=44.12), 0.183999 s/step
# on time step 2228 (time=44.56), 0.182921 s/step
# on time step 2250 (time=45), 0.192637 s/step
# on time step 2272 (time=45.44), 0.18593 s/step
# on time step 2294 (time=45.88), 0.186151 s/step
# on time step 2316 (time=46.32), 0.184526 s/step
# on time step 2338 (time=46.76), 0.18406 s/step
# on time step 2359 (time=47.18), 0.190477 s/step
# on time step 2381 (time=47.62), 0.184921 s/step
# on time step 2403 (time=48.06), 0.183619 s/step
# on time step 2425 (time=48.5), 0.18359 s/step
# on time step 2447 (time=48.94), 0.183547 s/step
# on time step 2468 (time=49.36), 0.190579 s/step
# on time step 2490 (time=49.8), 0.184655 s/step
# field decay(t = 50.08): 0.0012595228902488285 / 0.045829427890496315 = 0.02748284122721979
# on time step 2512 (time=50.24), 0.18408 s/step
# on time step 2534 (time=50.68), 0.183216 s/step
# on time step 2556 (time=51.12), 0.192837 s/step
# on time step 2578 (time=51.56), 0.18515 s/step
# on time step 2600 (time=52), 0.183038 s/step
# on time step 2622 (time=52.44), 0.183484 s/step
# on time step 2644 (time=52.88), 0.183298 s/step
# on time step 2666 (time=53.32), 0.189382 s/step
# on time step 2687 (time=53.74), 0.198326 s/step
# on time step 2708 (time=54.16), 0.193043 s/step
# on time step 2730 (time=54.6), 0.190805 s/step
# on time step 2750 (time=55), 0.200992 s/step
# on time step 2772 (time=55.44), 0.195934 s/step
# on time step 2792 (time=55.84), 0.201776 s/step
# on time step 2812 (time=56.24), 0.207558 s/step
# on time step 2833 (time=56.66), 0.198603 s/step
# on time step 2855 (time=57.1), 0.183332 s/step
# on time step 2877 (time=57.54), 0.185716 s/step
# on time step 2898 (time=57.96), 0.204 s/step
# on time step 2919 (time=58.38), 0.196019 s/step
# on time step 2941 (time=58.82), 0.188263 s/step
# on time step 2963 (time=59.26), 0.1897 s/step
# on time step 2984 (time=59.68), 0.193044 s/step
# field decay(t = 60.1): 0.0010468262067464494 / 0.045829427890496315 = 0.02284179085210729
# on time step 3006 (time=60.12), 0.192783 s/step
# on time step 3027 (time=60.54), 0.197609 s/step
# on time step 3047 (time=60.94), 0.202533 s/step
# on time step 3068 (time=61.36), 0.191858 s/step
# on time step 3089 (time=61.78), 0.196457 s/step
# on time step 3110 (time=62.2), 0.195888 s/step
# on time step 3132 (time=62.64), 0.195848 s/step
# on time step 3154 (time=63.08), 0.188014 s/step
# on time step 3176 (time=63.52), 0.186283 s/step
# on time step 3198 (time=63.96), 0.187866 s/step
# on time step 3219 (time=64.38), 0.193692 s/step
# on time step 3240 (time=64.8), 0.202883 s/step
# on time step 3261 (time=65.22), 0.19054 s/step
# on time step 3282 (time=65.64), 0.194948 s/step
# on time step 3303 (time=66.06), 0.196333 s/step
# on time step 3325 (time=66.5), 0.189794 s/step
# on time step 3346 (time=66.92), 0.197292 s/step
# on time step 3367 (time=67.34), 0.194557 s/step
# on time step 3388 (time=67.76), 0.193297 s/step
# on time step 3410 (time=68.2), 0.188899 s/step
# on time step 3431 (time=68.62), 0.190686 s/step
# on time step 3453 (time=69.06), 0.187741 s/step
# on time step 3474 (time=69.48), 0.19608 s/step
# on time step 3495 (time=69.9), 0.198345 s/step
# field decay(t = 70.12): 8.129208142994416e-05 / 0.045829427890496315 = 0.0017737965576219154
# on time step 3516 (time=70.32), 0.198239 s/step
# on time step 3538 (time=70.76), 0.185003 s/step
# on time step 3560 (time=71.2), 0.187708 s/step
# on time step 3582 (time=71.64), 0.191406 s/step
# on time step 3604 (time=72.08), 0.187455 s/step
# on time step 3626 (time=72.52), 0.187053 s/step
# on time step 3648 (time=72.96), 0.186282 s/step
# on time step 3669 (time=73.38), 0.194439 s/step
# on time step 3690 (time=73.8), 0.205543 s/step
# on time step 3712 (time=74.24), 0.186938 s/step
# on time step 3734 (time=74.68), 0.186438 s/step
# on time step 3756 (time=75.12), 0.186442 s/step
# on time step 3778 (time=75.56), 0.184298 s/step
# on time step 3799 (time=75.98), 0.190693 s/step
# on time step 3821 (time=76.42), 0.184774 s/step
# on time step 3842 (time=76.84), 0.192361 s/step
# on time step 3863 (time=77.26), 0.193052 s/step
# on time step 3885 (time=77.7), 0.187175 s/step
# on time step 3906 (time=78.12), 0.194223 s/step
# on time step 3928 (time=78.56), 0.184755 s/step
# on time step 3950 (time=79), 0.183624 s/step
# on time step 3972 (time=79.44), 0.187909 s/step
# on time step 3994 (time=79.88), 0.186962 s/step
# field decay(t = 80.14): 0.00013904036056596063 / 0.045829427890496315 = 0.0030338663816223102
# on time step 4014 (time=80.28), 0.211486 s/step
# on time step 4036 (time=80.72), 0.186888 s/step
# on time step 4057 (time=81.14), 0.191516 s/step
# on time step 4076 (time=81.52), 0.212717 s/step
# on time step 4097 (time=81.94), 0.195748 s/step
# on time step 4119 (time=82.38), 0.189028 s/step
# on time step 4140 (time=82.8), 0.196051 s/step
# on time step 4161 (time=83.22), 0.194891 s/step
# on time step 4182 (time=83.64), 0.190593 s/step
# on time step 4204 (time=84.08), 0.187113 s/step
# on time step 4225 (time=84.5), 0.191788 s/step
# on time step 4246 (time=84.92), 0.19151 s/step
# on time step 4267 (time=85.34), 0.198081 s/step
# on time step 4288 (time=85.76), 0.192236 s/step
# on time step 4309 (time=86.18), 0.194299 s/step
# on time step 4330 (time=86.6), 0.191578 s/step
# on time step 4351 (time=87.02), 0.192994 s/step
# on time step 4373 (time=87.46), 0.18928 s/step
# on time step 4394 (time=87.88), 0.198774 s/step
# on time step 4416 (time=88.32), 0.188815 s/step
# on time step 4437 (time=88.74), 0.19853 s/step
# on time step 4458 (time=89.16), 0.192078 s/step
# on time step 4480 (time=89.6), 0.187534 s/step
# on time step 4501 (time=90.02), 0.199154 s/step
# field decay(t = 90.16): 0.00010771819602996445 / 0.045829427890496315 = 0.002350415464215342
# on time step 4522 (time=90.44), 0.196479 s/step
# on time step 4543 (time=90.86), 0.191071 s/step
# on time step 4565 (time=91.3), 0.184583 s/step
# on time step 4587 (time=91.74), 0.184382 s/step
# on time step 4608 (time=92.16), 0.190872 s/step
# on time step 4630 (time=92.6), 0.183312 s/step
# on time step 4651 (time=93.02), 0.1926 s/step
# on time step 4673 (time=93.46), 0.187395 s/step
# on time step 4695 (time=93.9), 0.187178 s/step
# on time step 4716 (time=94.32), 0.19228 s/step
# on time step 4738 (time=94.76), 0.185632 s/step
# on time step 4760 (time=95.2), 0.184455 s/step
# on time step 4782 (time=95.64), 0.185968 s/step
# on time step 4804 (time=96.08), 0.18693 s/step
# on time step 4825 (time=96.5), 0.195104 s/step
# on time step 4846 (time=96.92), 0.193946 s/step
# on time step 4868 (time=97.36), 0.188733 s/step
# on time step 4889 (time=97.78), 0.192065 s/step
# on time step 4909 (time=98.18), 0.202905 s/step
# on time step 4930 (time=98.6), 0.196192 s/step
# on time step 4951 (time=99.02), 0.196828 s/step
# on time step 4973 (time=99.46), 0.187832 s/step
# on time step 4995 (time=99.9), 0.186218 s/step
# field decay(t = 100.18): 8.216824166968921e-05 / 0.045829427890496315 = 0.0017929144100602772
# on time step 5017 (time=100.34), 0.186596 s/step
# on time step 5038 (time=100.76), 0.191167 s/step
# on time step 5058 (time=101.16), 0.200908 s/step
# on time step 5080 (time=101.6), 0.18944 s/step
# on time step 5102 (time=102.04), 0.188763 s/step
# on time step 5123 (time=102.46), 0.191836 s/step
# on time step 5145 (time=102.9), 0.186639 s/step
# on time step 5166 (time=103.32), 0.193025 s/step
# on time step 5187 (time=103.74), 0.191335 s/step
# on time step 5208 (time=104.16), 0.191783 s/step
# on time step 5230 (time=104.6), 0.189681 s/step
# on time step 5251 (time=105.02), 0.191312 s/step
# on time step 5272 (time=105.44), 0.196625 s/step
# on time step 5292 (time=105.84), 0.206668 s/step
# on time step 5314 (time=106.28), 0.190048 s/step
# on time step 5335 (time=106.7), 0.190534 s/step
# on time step 5355 (time=107.1), 0.204299 s/step
# on time step 5375 (time=107.5), 0.204742 s/step
# on time step 5395 (time=107.9), 0.201729 s/step
# on time step 5415 (time=108.3), 0.207798 s/step
# on time step 5435 (time=108.7), 0.203844 s/step
# on time step 5455 (time=109.1), 0.204133 s/step
# on time step 5477 (time=109.54), 0.188344 s/step
# on time step 5498 (time=109.96), 0.192784 s/step
# field decay(t = 110.2): 1.2469565799689007e-05 / 0.045829427890496315 = 0.00027208643820480317
# run 0 finished at t = 110.2 (5510 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])
if mp.am_master():
    plt.figure(dpi=900)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")
