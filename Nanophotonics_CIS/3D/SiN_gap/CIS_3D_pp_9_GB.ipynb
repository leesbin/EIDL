# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=5)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 1 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * (design_region_width_x-air_gap*2))) + 1
Ny = int(round(design_region_resolution * (design_region_width_y-air_gap*2))) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1


# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, SiN, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000699997 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 69.1653% done, 1.78363 s remaining
# subpixel-averaging is 69.9053% done, 1.72264 s remaining
# subpixel-averaging is 70.2291% done, 1.69597 s remaining
# time for set_epsilon = 31.2035 s
# -----------
# on time step 1 (time=0.02), 8.40443 s/step
# on time step 17 (time=0.34), 0.256323 s/step
# on time step 33 (time=0.66), 0.255151 s/step
# on time step 49 (time=0.98), 0.250961 s/step
# on time step 65 (time=1.3), 0.253383 s/step
# on time step 81 (time=1.62), 0.252036 s/step
# on time step 97 (time=1.94), 0.252392 s/step
# on time step 114 (time=2.28), 0.249077 s/step
# on time step 130 (time=2.6), 0.254968 s/step
# on time step 146 (time=2.92), 0.251469 s/step
# on time step 163 (time=3.26), 0.248098 s/step
# on time step 183 (time=3.66), 0.200317 s/step
# on time step 200 (time=4), 0.248771 s/step
# on time step 216 (time=4.32), 0.251686 s/step
# on time step 233 (time=4.66), 0.248738 s/step
# on time step 249 (time=4.98), 0.251778 s/step
# on time step 265 (time=5.3), 0.251254 s/step
# on time step 281 (time=5.62), 0.253857 s/step
# on time step 297 (time=5.94), 0.25212 s/step
# on time step 313 (time=6.26), 0.251762 s/step
# on time step 330 (time=6.6), 0.248594 s/step
# on time step 346 (time=6.92), 0.254181 s/step
# on time step 362 (time=7.24), 0.251734 s/step
# on time step 378 (time=7.56), 0.251808 s/step
# on time step 394 (time=7.88), 0.251953 s/step
# on time step 410 (time=8.2), 0.256506 s/step
# on time step 427 (time=8.54), 0.245294 s/step
# on time step 443 (time=8.86), 0.25971 s/step
# on time step 458 (time=9.16), 0.280322 s/step
# on time step 474 (time=9.48), 0.262745 s/step
# on time step 491 (time=9.82), 0.245643 s/step
# field decay(t = 10.02): 4.126440830207119e-07 / 4.126440830207119e-07 = 1.0
# on time step 508 (time=10.16), 0.236975 s/step
# on time step 528 (time=10.56), 0.204853 s/step
# on time step 544 (time=10.88), 0.260916 s/step
# on time step 560 (time=11.2), 0.257288 s/step
# on time step 576 (time=11.52), 0.264519 s/step
# on time step 592 (time=11.84), 0.257747 s/step
# on time step 608 (time=12.16), 0.25564 s/step
# on time step 624 (time=12.48), 0.251177 s/step
# on time step 641 (time=12.82), 0.247431 s/step
# on time step 658 (time=13.16), 0.244978 s/step
# on time step 675 (time=13.5), 0.246894 s/step
# on time step 692 (time=13.84), 0.245078 s/step
# on time step 709 (time=14.18), 0.245432 s/step
# on time step 726 (time=14.52), 0.246903 s/step
# on time step 743 (time=14.86), 0.245811 s/step
# on time step 760 (time=15.2), 0.247523 s/step
# on time step 777 (time=15.54), 0.24546 s/step
# on time step 794 (time=15.88), 0.247871 s/step
# on time step 811 (time=16.22), 0.24487 s/step
# on time step 830 (time=16.6), 0.212005 s/step
# on time step 852 (time=17.04), 0.189857 s/step
# on time step 874 (time=17.48), 0.1845 s/step
# on time step 896 (time=17.92), 0.184471 s/step
# on time step 918 (time=18.36), 0.188577 s/step
# on time step 939 (time=18.78), 0.190882 s/step
# on time step 960 (time=19.2), 0.195944 s/step
# on time step 982 (time=19.64), 0.190076 s/step
# field decay(t = 20.04): 0.12924924817365843 / 0.12924924817365843 = 1.0
# on time step 1004 (time=20.08), 0.183023 s/step
# on time step 1027 (time=20.54), 0.181135 s/step
# on time step 1049 (time=20.98), 0.183319 s/step
# on time step 1071 (time=21.42), 0.186301 s/step
# on time step 1094 (time=21.88), 0.181123 s/step
# on time step 1116 (time=22.32), 0.182299 s/step
# on time step 1137 (time=22.74), 0.190879 s/step
# on time step 1160 (time=23.2), 0.179631 s/step
# on time step 1183 (time=23.66), 0.179778 s/step
# on time step 1205 (time=24.1), 0.187524 s/step
# on time step 1227 (time=24.54), 0.184847 s/step
# on time step 1249 (time=24.98), 0.187518 s/step
# on time step 1271 (time=25.42), 0.188032 s/step
# on time step 1293 (time=25.86), 0.182683 s/step
# on time step 1315 (time=26.3), 0.186503 s/step
# on time step 1337 (time=26.74), 0.185859 s/step
# on time step 1359 (time=27.18), 0.188353 s/step
# on time step 1381 (time=27.62), 0.185374 s/step
# on time step 1403 (time=28.06), 0.183256 s/step
# on time step 1425 (time=28.5), 0.183581 s/step
# on time step 1447 (time=28.94), 0.186538 s/step
# on time step 1469 (time=29.38), 0.187285 s/step
# on time step 1490 (time=29.8), 0.190736 s/step
# field decay(t = 30.060000000000002): 0.5646738222527186 / 0.5646738222527186 = 1.0
# on time step 1512 (time=30.24), 0.186211 s/step
# on time step 1534 (time=30.68), 0.18706 s/step
# on time step 1556 (time=31.12), 0.182552 s/step
# on time step 1578 (time=31.56), 0.186003 s/step
# on time step 1600 (time=32), 0.18384 s/step
# on time step 1623 (time=32.46), 0.179721 s/step
# on time step 1646 (time=32.92), 0.17726 s/step
# on time step 1669 (time=33.38), 0.180384 s/step
# on time step 1692 (time=33.84), 0.180388 s/step
# on time step 1715 (time=34.3), 0.177642 s/step
# on time step 1737 (time=34.74), 0.184791 s/step
# on time step 1760 (time=35.2), 0.179145 s/step
# on time step 1783 (time=35.66), 0.181048 s/step
# on time step 1806 (time=36.12), 0.181461 s/step
# on time step 1828 (time=36.56), 0.184304 s/step
# on time step 1850 (time=37), 0.185558 s/step
# on time step 1872 (time=37.44), 0.187362 s/step
# on time step 1893 (time=37.86), 0.190503 s/step
# on time step 1915 (time=38.3), 0.189681 s/step
# on time step 1936 (time=38.72), 0.191142 s/step
# on time step 1957 (time=39.14), 0.192899 s/step
# on time step 1979 (time=39.58), 0.190772 s/step
# on time step 2000 (time=40), 0.196178 s/step
# field decay(t = 40.06): 0.07547163699224003 / 0.5646738222527186 = 0.13365527853080264
# on time step 2022 (time=40.44), 0.185849 s/step
# on time step 2045 (time=40.9), 0.18084 s/step
# on time step 2067 (time=41.34), 0.189934 s/step
# on time step 2089 (time=41.78), 0.186639 s/step
# on time step 2112 (time=42.24), 0.179104 s/step
# on time step 2134 (time=42.68), 0.181873 s/step
# on time step 2157 (time=43.14), 0.179977 s/step
# on time step 2180 (time=43.6), 0.17862 s/step
# on time step 2203 (time=44.06), 0.179531 s/step
# on time step 2225 (time=44.5), 0.181995 s/step
# on time step 2248 (time=44.96), 0.178941 s/step
# on time step 2271 (time=45.42), 0.178519 s/step
# on time step 2294 (time=45.88), 0.178797 s/step
# on time step 2317 (time=46.34), 0.179617 s/step
# on time step 2340 (time=46.8), 0.1811 s/step
# on time step 2363 (time=47.26), 0.180173 s/step
# on time step 2385 (time=47.7), 0.182453 s/step
# on time step 2408 (time=48.16), 0.181438 s/step
# on time step 2431 (time=48.62), 0.179873 s/step
# on time step 2454 (time=49.08), 0.18053 s/step
# on time step 2476 (time=49.52), 0.182122 s/step
# on time step 2498 (time=49.96), 0.183159 s/step
# field decay(t = 50.08): 0.001529165824552319 / 0.5646738222527186 = 0.002708051558777492
# on time step 2520 (time=50.4), 0.18331 s/step
# on time step 2543 (time=50.86), 0.181794 s/step
# on time step 2566 (time=51.32), 0.180439 s/step
# on time step 2589 (time=51.78), 0.180524 s/step
# on time step 2612 (time=52.24), 0.180948 s/step
# on time step 2635 (time=52.7), 0.179922 s/step
# on time step 2657 (time=53.14), 0.182432 s/step
# on time step 2679 (time=53.58), 0.182457 s/step
# on time step 2701 (time=54.02), 0.182814 s/step
# on time step 2724 (time=54.48), 0.178575 s/step
# on time step 2747 (time=54.94), 0.179949 s/step
# on time step 2770 (time=55.4), 0.180339 s/step
# on time step 2793 (time=55.86), 0.181424 s/step
# on time step 2816 (time=56.32), 0.17831 s/step
# on time step 2839 (time=56.78), 0.181172 s/step
# on time step 2862 (time=57.24), 0.17929 s/step
# on time step 2885 (time=57.7), 0.178393 s/step
# on time step 2908 (time=58.16), 0.178776 s/step
# on time step 2931 (time=58.62), 0.178601 s/step
# on time step 2954 (time=59.08), 0.178595 s/step
# on time step 2977 (time=59.54), 0.178484 s/step
# on time step 3000 (time=60), 0.178396 s/step
# field decay(t = 60.1): 0.0002055037857932286 / 0.5646738222527186 = 0.00036393361564626567
# run 0 finished at t = 60.1 (3005 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000642776 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 69.1653% done, 1.78339 s remaining
# subpixel-averaging is 71.9634% done, 1.55887 s remaining
# subpixel-averaging is 69.3735% done, 1.76597 s remaining
# time for set_epsilon = 31.1992 s
# -----------
# on time step 1 (time=0.02), 8.0568 s/step
# on time step 24 (time=0.48), 0.178871 s/step
# on time step 47 (time=0.94), 0.178534 s/step
# on time step 70 (time=1.4), 0.180922 s/step
# on time step 93 (time=1.86), 0.178987 s/step
# on time step 116 (time=2.32), 0.180881 s/step
# on time step 138 (time=2.76), 0.182387 s/step
# on time step 161 (time=3.22), 0.178757 s/step
# on time step 184 (time=3.68), 0.180852 s/step
# on time step 207 (time=4.14), 0.18045 s/step
# on time step 230 (time=4.6), 0.180308 s/step
# on time step 253 (time=5.06), 0.18003 s/step
# on time step 276 (time=5.52), 0.180514 s/step
# on time step 299 (time=5.98), 0.180845 s/step
# on time step 322 (time=6.44), 0.18071 s/step
# on time step 345 (time=6.9), 0.179677 s/step
# on time step 368 (time=7.36), 0.178683 s/step
# on time step 391 (time=7.82), 0.179486 s/step
# on time step 414 (time=8.28), 0.181179 s/step
# on time step 437 (time=8.74), 0.178932 s/step
# on time step 460 (time=9.2), 0.17823 s/step
# on time step 483 (time=9.66), 0.178624 s/step
# field decay(t = 10.02): 4.073715626934256e-09 / 4.073715626934256e-09 = 1.0
# on time step 506 (time=10.12), 0.180126 s/step
# on time step 529 (time=10.58), 0.179359 s/step
# on time step 552 (time=11.04), 0.178594 s/step
# on time step 575 (time=11.5), 0.18039 s/step
# on time step 597 (time=11.94), 0.182131 s/step
# on time step 620 (time=12.4), 0.180964 s/step
# on time step 642 (time=12.84), 0.181883 s/step
# on time step 665 (time=13.3), 0.178803 s/step
# on time step 688 (time=13.76), 0.1815 s/step
# on time step 711 (time=14.22), 0.181404 s/step
# on time step 734 (time=14.68), 0.181555 s/step
# on time step 757 (time=15.14), 0.181805 s/step
# on time step 780 (time=15.6), 0.180018 s/step
# on time step 803 (time=16.06), 0.178896 s/step
# on time step 826 (time=16.52), 0.178707 s/step
# on time step 848 (time=16.96), 0.182015 s/step
# on time step 871 (time=17.42), 0.180454 s/step
# on time step 894 (time=17.88), 0.178371 s/step
# on time step 917 (time=18.34), 0.180563 s/step
# on time step 940 (time=18.8), 0.178409 s/step
# on time step 963 (time=19.26), 0.181651 s/step
# on time step 986 (time=19.72), 0.179281 s/step
# field decay(t = 20.04): 0.00013089272556593176 / 0.00013089272556593176 = 1.0
# on time step 1009 (time=20.18), 0.17866 s/step
# on time step 1032 (time=20.64), 0.178539 s/step
# on time step 1055 (time=21.1), 0.179574 s/step
# on time step 1078 (time=21.56), 0.178912 s/step
# on time step 1101 (time=22.02), 0.178781 s/step
# on time step 1124 (time=22.48), 0.178515 s/step
# on time step 1147 (time=22.94), 0.180921 s/step
# on time step 1170 (time=23.4), 0.180522 s/step
# on time step 1193 (time=23.86), 0.180646 s/step
# on time step 1215 (time=24.3), 0.182823 s/step
# on time step 1238 (time=24.76), 0.181245 s/step
# on time step 1261 (time=25.22), 0.181547 s/step
# on time step 1284 (time=25.68), 0.179224 s/step
# on time step 1307 (time=26.14), 0.180442 s/step
# on time step 1330 (time=26.6), 0.181465 s/step
# on time step 1352 (time=27.04), 0.181959 s/step
# on time step 1375 (time=27.5), 0.181412 s/step
# on time step 1398 (time=27.96), 0.178891 s/step
# on time step 1421 (time=28.42), 0.178399 s/step
# on time step 1444 (time=28.88), 0.17871 s/step
# on time step 1467 (time=29.34), 0.179203 s/step
# on time step 1490 (time=29.8), 0.181439 s/step
# field decay(t = 30.060000000000002): 0.023115178650439033 / 0.023115178650439033 = 1.0
# on time step 1512 (time=30.24), 0.181894 s/step
# on time step 1535 (time=30.7), 0.180389 s/step
# on time step 1558 (time=31.16), 0.181642 s/step
# on time step 1580 (time=31.6), 0.182027 s/step
# on time step 1603 (time=32.06), 0.181656 s/step
# on time step 1626 (time=32.52), 0.17992 s/step
# on time step 1649 (time=32.98), 0.178061 s/step
# on time step 1672 (time=33.44), 0.179856 s/step
# on time step 1695 (time=33.9), 0.17928 s/step
# on time step 1718 (time=34.36), 0.178514 s/step
# on time step 1741 (time=34.82), 0.179491 s/step
# on time step 1764 (time=35.28), 0.180133 s/step
# on time step 1787 (time=35.74), 0.17898 s/step
# on time step 1810 (time=36.2), 0.180398 s/step
# on time step 1833 (time=36.66), 0.180806 s/step
# on time step 1855 (time=37.1), 0.182349 s/step
# on time step 1877 (time=37.54), 0.18194 s/step
# on time step 1900 (time=38), 0.180943 s/step
# on time step 1922 (time=38.44), 0.18312 s/step
# on time step 1945 (time=38.9), 0.18156 s/step
# on time step 1968 (time=39.36), 0.1813 s/step
# on time step 1991 (time=39.82), 0.181204 s/step
# field decay(t = 40.06): 0.1354098769289805 / 0.1354098769289805 = 1.0
# on time step 2013 (time=40.26), 0.18258 s/step
# on time step 2036 (time=40.72), 0.181023 s/step
# on time step 2059 (time=41.18), 0.181239 s/step
# on time step 2081 (time=41.62), 0.182687 s/step
# on time step 2103 (time=42.06), 0.183174 s/step
# on time step 2125 (time=42.5), 0.182502 s/step
# on time step 2147 (time=42.94), 0.183289 s/step
# on time step 2170 (time=43.4), 0.180044 s/step
# on time step 2192 (time=43.84), 0.182758 s/step
# on time step 2213 (time=44.26), 0.196249 s/step
# on time step 2235 (time=44.7), 0.18516 s/step
# on time step 2258 (time=45.16), 0.181134 s/step
# on time step 2281 (time=45.62), 0.180288 s/step
# on time step 2304 (time=46.08), 0.179964 s/step
# on time step 2327 (time=46.54), 0.179652 s/step
# on time step 2349 (time=46.98), 0.189044 s/step
# on time step 2371 (time=47.42), 0.18556 s/step
# on time step 2393 (time=47.86), 0.188463 s/step
# on time step 2414 (time=48.28), 0.198338 s/step
# on time step 2436 (time=48.72), 0.185769 s/step
# on time step 2458 (time=49.16), 0.183382 s/step
# on time step 2480 (time=49.6), 0.183863 s/step
# on time step 2501 (time=50.02), 0.196836 s/step
# field decay(t = 50.08): 0.12560817617529063 / 0.1354098769289805 = 0.9276145804428237
# on time step 2523 (time=50.46), 0.187922 s/step
# on time step 2543 (time=50.86), 0.201364 s/step
# on time step 2564 (time=51.28), 0.196737 s/step
# on time step 2585 (time=51.7), 0.192402 s/step
# on time step 2607 (time=52.14), 0.187907 s/step
# on time step 2628 (time=52.56), 0.190868 s/step
# on time step 2651 (time=53.02), 0.178255 s/step
# on time step 2674 (time=53.48), 0.1778 s/step
# on time step 2697 (time=53.94), 0.177401 s/step
# on time step 2720 (time=54.4), 0.182263 s/step
# on time step 2743 (time=54.86), 0.18066 s/step
# on time step 2765 (time=55.3), 0.188732 s/step
# on time step 2787 (time=55.74), 0.184043 s/step
# on time step 2810 (time=56.2), 0.180422 s/step
# on time step 2833 (time=56.66), 0.177736 s/step
# on time step 2856 (time=57.12), 0.180867 s/step
# on time step 2878 (time=57.56), 0.182767 s/step
# on time step 2901 (time=58.02), 0.178547 s/step
# on time step 2924 (time=58.48), 0.177695 s/step
# on time step 2947 (time=58.94), 0.179726 s/step
# on time step 2970 (time=59.4), 0.180324 s/step
# on time step 2993 (time=59.86), 0.181115 s/step
# field decay(t = 60.1): 0.007389995762711698 / 0.1354098769289805 = 0.05457501277094867
# on time step 3016 (time=60.32), 0.179525 s/step
# on time step 3038 (time=60.76), 0.182188 s/step
# on time step 3061 (time=61.22), 0.179091 s/step
# on time step 3084 (time=61.68), 0.177567 s/step
# on time step 3107 (time=62.14), 0.17974 s/step
# on time step 3130 (time=62.6), 0.180274 s/step
# on time step 3153 (time=63.06), 0.179296 s/step
# on time step 3176 (time=63.52), 0.177453 s/step
# on time step 3198 (time=63.96), 0.184938 s/step
# on time step 3220 (time=64.4), 0.184058 s/step
# on time step 3242 (time=64.84), 0.184356 s/step
# on time step 3265 (time=65.3), 0.17774 s/step
# on time step 3288 (time=65.76), 0.180214 s/step
# on time step 3310 (time=66.2), 0.18201 s/step
# on time step 3332 (time=66.64), 0.182568 s/step
# on time step 3355 (time=67.1), 0.179235 s/step
# on time step 3378 (time=67.56), 0.180168 s/step
# on time step 3401 (time=68.02), 0.180523 s/step
# on time step 3424 (time=68.48), 0.179454 s/step
# on time step 3447 (time=68.94), 0.180177 s/step
# on time step 3470 (time=69.4), 0.181334 s/step
# on time step 3493 (time=69.86), 0.180183 s/step
# field decay(t = 70.12): 0.00034512947778417134 / 0.1354098769289805 = 0.002548776245954231
# on time step 3515 (time=70.3), 0.182041 s/step
# on time step 3538 (time=70.76), 0.178339 s/step
# on time step 3561 (time=71.22), 0.179918 s/step
# on time step 3584 (time=71.68), 0.180543 s/step
# on time step 3607 (time=72.14), 0.17916 s/step
# on time step 3630 (time=72.6), 0.178537 s/step
# on time step 3653 (time=73.06), 0.178249 s/step
# on time step 3676 (time=73.52), 0.181139 s/step
# on time step 3699 (time=73.98), 0.177788 s/step
# on time step 3722 (time=74.44), 0.177766 s/step
# on time step 3745 (time=74.9), 0.177596 s/step
# on time step 3768 (time=75.36), 0.178872 s/step
# on time step 3790 (time=75.8), 0.183743 s/step
# on time step 3813 (time=76.26), 0.178147 s/step
# on time step 3835 (time=76.7), 0.186299 s/step
# on time step 3858 (time=77.16), 0.182425 s/step
# on time step 3879 (time=77.58), 0.190871 s/step
# on time step 3901 (time=78.02), 0.183571 s/step
# on time step 3923 (time=78.46), 0.184807 s/step
# on time step 3945 (time=78.9), 0.186559 s/step
# on time step 3968 (time=79.36), 0.178278 s/step
# on time step 3990 (time=79.8), 0.186844 s/step
# field decay(t = 80.14): 6.167341496832065e-06 / 0.1354098769289805 = 4.554572854435648e-05
# run 0 finished at t = 80.14 (4007 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000673056 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 73.0503% done, 1.47592 s remaining
# subpixel-averaging is 71.524% done, 1.59301 s remaining
# subpixel-averaging is 72.8653% done, 1.48981 s remaining
# time for set_epsilon = 30.1418 s
# -----------
# on time step 1 (time=0.02), 8.02874 s/step
# on time step 23 (time=0.46), 0.185375 s/step
# on time step 45 (time=0.9), 0.184459 s/step
# on time step 67 (time=1.34), 0.185204 s/step
# on time step 89 (time=1.78), 0.185043 s/step
# on time step 112 (time=2.24), 0.181341 s/step
# on time step 134 (time=2.68), 0.182709 s/step
# on time step 156 (time=3.12), 0.18261 s/step
# on time step 178 (time=3.56), 0.18412 s/step
# on time step 200 (time=4), 0.188039 s/step
# on time step 223 (time=4.46), 0.181555 s/step
# on time step 246 (time=4.92), 0.180845 s/step
# on time step 269 (time=5.38), 0.180052 s/step
# on time step 291 (time=5.82), 0.184151 s/step
# on time step 313 (time=6.26), 0.188764 s/step
# on time step 335 (time=6.7), 0.18351 s/step
# on time step 357 (time=7.14), 0.182947 s/step
# on time step 379 (time=7.58), 0.18557 s/step
# on time step 401 (time=8.02), 0.182722 s/step
# on time step 422 (time=8.44), 0.191553 s/step
# on time step 444 (time=8.88), 0.189125 s/step
# on time step 466 (time=9.32), 0.183271 s/step
# on time step 488 (time=9.76), 0.183904 s/step
# field decay(t = 10.02): 5.972540250980463e-09 / 5.972540250980463e-09 = 1.0
# on time step 510 (time=10.2), 0.183474 s/step
# on time step 533 (time=10.66), 0.179291 s/step
# on time step 556 (time=11.12), 0.179794 s/step
# on time step 579 (time=11.58), 0.178409 s/step
# on time step 602 (time=12.04), 0.181543 s/step
# on time step 625 (time=12.5), 0.180822 s/step
# on time step 647 (time=12.94), 0.185325 s/step
# on time step 670 (time=13.4), 0.178815 s/step
# on time step 693 (time=13.86), 0.179248 s/step
# on time step 716 (time=14.32), 0.179961 s/step
# on time step 739 (time=14.78), 0.17827 s/step
# on time step 762 (time=15.24), 0.17895 s/step
# on time step 785 (time=15.7), 0.178592 s/step
# on time step 808 (time=16.16), 0.178263 s/step
# on time step 831 (time=16.62), 0.178898 s/step
# on time step 854 (time=17.08), 0.178547 s/step
# on time step 877 (time=17.54), 0.178735 s/step
# on time step 900 (time=18), 0.178856 s/step
# on time step 923 (time=18.46), 0.179053 s/step
# on time step 946 (time=18.92), 0.178563 s/step
# on time step 969 (time=19.38), 0.181552 s/step
# on time step 991 (time=19.82), 0.188004 s/step
# field decay(t = 20.04): 0.00016071637312920715 / 0.00016071637312920715 = 1.0
# on time step 1013 (time=20.26), 0.186936 s/step
# on time step 1036 (time=20.72), 0.180518 s/step
# on time step 1059 (time=21.18), 0.179939 s/step
# on time step 1082 (time=21.64), 0.180948 s/step
# on time step 1105 (time=22.1), 0.178811 s/step
# on time step 1128 (time=22.56), 0.177674 s/step
# on time step 1151 (time=23.02), 0.180455 s/step
# on time step 1174 (time=23.48), 0.179365 s/step
# on time step 1197 (time=23.94), 0.180953 s/step
# on time step 1220 (time=24.4), 0.17817 s/step
# on time step 1243 (time=24.86), 0.180117 s/step
# on time step 1266 (time=25.32), 0.177594 s/step
# on time step 1289 (time=25.78), 0.178267 s/step
# on time step 1312 (time=26.24), 0.17859 s/step
# on time step 1334 (time=26.68), 0.182787 s/step
# on time step 1356 (time=27.12), 0.187998 s/step
# on time step 1379 (time=27.58), 0.181273 s/step
# on time step 1402 (time=28.04), 0.178993 s/step
# on time step 1425 (time=28.5), 0.17916 s/step
# on time step 1448 (time=28.96), 0.179017 s/step
# on time step 1471 (time=29.42), 0.178169 s/step
# on time step 1494 (time=29.88), 0.180522 s/step
# field decay(t = 30.060000000000002): 0.027644008381904554 / 0.027644008381904554 = 1.0
# on time step 1517 (time=30.34), 0.180634 s/step
# on time step 1540 (time=30.8), 0.179758 s/step
# on time step 1563 (time=31.26), 0.179612 s/step
# on time step 1586 (time=31.72), 0.178124 s/step
# on time step 1609 (time=32.18), 0.178041 s/step
# on time step 1632 (time=32.64), 0.177718 s/step
# on time step 1655 (time=33.1), 0.178151 s/step
# on time step 1678 (time=33.56), 0.177306 s/step
# on time step 1701 (time=34.02), 0.17753 s/step
# on time step 1724 (time=34.48), 0.178258 s/step
# on time step 1747 (time=34.94), 0.178217 s/step
# on time step 1770 (time=35.4), 0.178788 s/step
# on time step 1793 (time=35.86), 0.177563 s/step
# on time step 1816 (time=36.32), 0.178385 s/step
# on time step 1839 (time=36.78), 0.177681 s/step
# on time step 1862 (time=37.24), 0.178037 s/step
# on time step 1885 (time=37.7), 0.178038 s/step
# on time step 1908 (time=38.16), 0.179637 s/step
# on time step 1931 (time=38.62), 0.179216 s/step
# on time step 1954 (time=39.08), 0.179962 s/step
# on time step 1977 (time=39.54), 0.180536 s/step
# on time step 2000 (time=40), 0.178454 s/step
# field decay(t = 40.06): 0.0552062789104926 / 0.0552062789104926 = 1.0
# on time step 2023 (time=40.46), 0.178901 s/step
# on time step 2046 (time=40.92), 0.177513 s/step
# on time step 2069 (time=41.38), 0.17774 s/step
# on time step 2092 (time=41.84), 0.177944 s/step
# on time step 2115 (time=42.3), 0.177964 s/step
# on time step 2138 (time=42.76), 0.178458 s/step
# on time step 2161 (time=43.22), 0.177657 s/step
# on time step 2184 (time=43.68), 0.179655 s/step
# on time step 2207 (time=44.14), 0.179321 s/step
# on time step 2230 (time=44.6), 0.178614 s/step
# on time step 2253 (time=45.06), 0.180334 s/step
# on time step 2276 (time=45.52), 0.180313 s/step
# on time step 2299 (time=45.98), 0.180631 s/step
# on time step 2322 (time=46.44), 0.181 s/step
# on time step 2345 (time=46.9), 0.180285 s/step
# on time step 2368 (time=47.36), 0.179293 s/step
# on time step 2390 (time=47.8), 0.182295 s/step
# on time step 2411 (time=48.22), 0.192283 s/step
# on time step 2433 (time=48.66), 0.184236 s/step
# on time step 2456 (time=49.12), 0.181216 s/step
# on time step 2479 (time=49.58), 0.179422 s/step
# on time step 2502 (time=50.04), 0.180705 s/step
# field decay(t = 50.08): 0.05173035395423573 / 0.0552062789104926 = 0.937037506876845
# on time step 2525 (time=50.5), 0.179177 s/step
# on time step 2548 (time=50.96), 0.177982 s/step
# on time step 2571 (time=51.42), 0.179235 s/step
# on time step 2594 (time=51.88), 0.18086 s/step
# on time step 2616 (time=52.32), 0.18187 s/step
# on time step 2639 (time=52.78), 0.17832 s/step
# on time step 2662 (time=53.24), 0.180078 s/step
# on time step 2685 (time=53.7), 0.179874 s/step
# on time step 2708 (time=54.16), 0.179857 s/step
# on time step 2731 (time=54.62), 0.180458 s/step
# on time step 2754 (time=55.08), 0.178725 s/step
# on time step 2777 (time=55.54), 0.179126 s/step
# on time step 2800 (time=56), 0.177689 s/step
# on time step 2823 (time=56.46), 0.177852 s/step
# on time step 2846 (time=56.92), 0.179441 s/step
# on time step 2869 (time=57.38), 0.177242 s/step
# on time step 2892 (time=57.84), 0.180228 s/step
# on time step 2915 (time=58.3), 0.180848 s/step
# on time step 2937 (time=58.74), 0.185331 s/step
# on time step 2959 (time=59.18), 0.182673 s/step
# on time step 2982 (time=59.64), 0.180849 s/step
# on time step 3004 (time=60.08), 0.182326 s/step
# field decay(t = 60.1): 0.011723356639820576 / 0.0552062789104926 = 0.21235549417898575
# on time step 3026 (time=60.52), 0.184774 s/step
# on time step 3049 (time=60.98), 0.179973 s/step
# on time step 3071 (time=61.42), 0.18329 s/step
# on time step 3093 (time=61.86), 0.181922 s/step
# on time step 3116 (time=62.32), 0.178014 s/step
# on time step 3139 (time=62.78), 0.177077 s/step
# on time step 3161 (time=63.22), 0.183607 s/step
# on time step 3183 (time=63.66), 0.187187 s/step
# on time step 3206 (time=64.12), 0.180673 s/step
# on time step 3229 (time=64.58), 0.177313 s/step
# on time step 3252 (time=65.04), 0.180413 s/step
# on time step 3275 (time=65.5), 0.178991 s/step
# on time step 3298 (time=65.96), 0.180411 s/step
# on time step 3321 (time=66.42), 0.180147 s/step
# on time step 3344 (time=66.88), 0.179599 s/step
# on time step 3367 (time=67.34), 0.179522 s/step
# on time step 3390 (time=67.8), 0.180753 s/step
# on time step 3413 (time=68.26), 0.179465 s/step
# on time step 3436 (time=68.72), 0.179726 s/step
# on time step 3459 (time=69.18), 0.179923 s/step
# on time step 3482 (time=69.64), 0.181032 s/step
# on time step 3504 (time=70.08), 0.183055 s/step
# field decay(t = 70.12): 2.6287180246261582e-05 / 0.0552062789104926 = 0.0004761628706923298
# run 0 finished at t = 70.12 (3506 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000358105 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 8.5836 s
# -----------
# on time step 1 (time=0.02), 8.19718 s/step
# on time step 25 (time=0.5), 0.170233 s/step
# on time step 50 (time=1), 0.162774 s/step
# on time step 74 (time=1.48), 0.168694 s/step
# on time step 98 (time=1.96), 0.168467 s/step
# on time step 122 (time=2.44), 0.167888 s/step
# on time step 146 (time=2.92), 0.170986 s/step
# on time step 170 (time=3.4), 0.167314 s/step
# on time step 195 (time=3.9), 0.16255 s/step
# on time step 220 (time=4.4), 0.165536 s/step
# on time step 245 (time=4.9), 0.160808 s/step
# on time step 270 (time=5.4), 0.166304 s/step
# on time step 295 (time=5.9), 0.161279 s/step
# on time step 320 (time=6.4), 0.16102 s/step
# on time step 345 (time=6.9), 0.165213 s/step
# on time step 370 (time=7.4), 0.161175 s/step
# on time step 395 (time=7.9), 0.161216 s/step
# on time step 420 (time=8.4), 0.165784 s/step
# on time step 445 (time=8.9), 0.161218 s/step
# on time step 469 (time=9.38), 0.167273 s/step
# on time step 494 (time=9.88), 0.162656 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 519 (time=10.38), 0.164445 s/step
# on time step 543 (time=10.86), 0.167707 s/step
# on time step 568 (time=11.36), 0.160615 s/step
# on time step 593 (time=11.86), 0.160415 s/step
# on time step 618 (time=12.36), 0.165673 s/step
# on time step 643 (time=12.86), 0.161414 s/step
# on time step 667 (time=13.34), 0.172053 s/step
# on time step 691 (time=13.82), 0.168808 s/step
# on time step 715 (time=14.3), 0.170447 s/step
# on time step 738 (time=14.76), 0.17716 s/step
# on time step 763 (time=15.26), 0.162854 s/step
# on time step 788 (time=15.76), 0.165069 s/step
# on time step 812 (time=16.24), 0.168863 s/step
# on time step 837 (time=16.74), 0.164768 s/step
# on time step 861 (time=17.22), 0.169924 s/step
# on time step 885 (time=17.7), 0.172247 s/step
# on time step 910 (time=18.2), 0.165922 s/step
# on time step 935 (time=18.7), 0.164535 s/step
# on time step 958 (time=19.16), 0.174122 s/step
# on time step 982 (time=19.64), 0.166779 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1006 (time=20.12), 0.167775 s/step
# on time step 1030 (time=20.6), 0.171414 s/step
# on time step 1054 (time=21.08), 0.166984 s/step
# on time step 1079 (time=21.58), 0.162885 s/step
# on time step 1103 (time=22.06), 0.169086 s/step
# on time step 1128 (time=22.56), 0.16329 s/step
# on time step 1152 (time=23.04), 0.168287 s/step
# on time step 1176 (time=23.52), 0.169285 s/step
# on time step 1201 (time=24.02), 0.163757 s/step
# on time step 1225 (time=24.5), 0.168546 s/step
# on time step 1250 (time=25), 0.164128 s/step
# on time step 1275 (time=25.5), 0.165217 s/step
# on time step 1299 (time=25.98), 0.16729 s/step
# on time step 1324 (time=26.48), 0.162514 s/step
# on time step 1349 (time=26.98), 0.164004 s/step
# on time step 1373 (time=27.46), 0.166755 s/step
# on time step 1398 (time=27.96), 0.163135 s/step
# on time step 1423 (time=28.46), 0.165655 s/step
# on time step 1448 (time=28.96), 0.163291 s/step
# on time step 1473 (time=29.46), 0.161985 s/step
# on time step 1497 (time=29.94), 0.167103 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# Initializing structure...
# time for choose_chunkdivision = 0.000653028 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 73.3509% done, 1.45328 s remaining
# subpixel-averaging is 71.7322% done, 1.57654 s remaining
# subpixel-averaging is 70.0903% done, 1.70755 s remaining
# time for set_epsilon = 30.3521 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 8.01688 s/step
# on time step 23 (time=0.46), 0.183037 s/step
# on time step 45 (time=0.9), 0.183608 s/step
# on time step 67 (time=1.34), 0.186307 s/step
# on time step 89 (time=1.78), 0.188604 s/step
# on time step 110 (time=2.2), 0.197085 s/step
# on time step 131 (time=2.62), 0.192479 s/step
# on time step 153 (time=3.06), 0.185023 s/step
# on time step 175 (time=3.5), 0.18712 s/step
# on time step 197 (time=3.94), 0.182813 s/step
# on time step 219 (time=4.38), 0.189546 s/step
# on time step 240 (time=4.8), 0.192323 s/step
# on time step 261 (time=5.22), 0.192527 s/step
# on time step 283 (time=5.66), 0.188657 s/step
# on time step 305 (time=6.1), 0.188999 s/step
# on time step 325 (time=6.5), 0.20128 s/step
# on time step 347 (time=6.94), 0.186015 s/step
# on time step 368 (time=7.36), 0.192527 s/step
# on time step 390 (time=7.8), 0.187271 s/step
# on time step 412 (time=8.24), 0.18551 s/step
# on time step 433 (time=8.66), 0.19576 s/step
# on time step 455 (time=9.1), 0.189749 s/step
# on time step 477 (time=9.54), 0.188708 s/step
# on time step 499 (time=9.98), 0.187366 s/step
# field decay(t = 10.02): 0.0021755442601229654 / 0.0021755442601229654 = 1.0
# on time step 520 (time=10.4), 0.190507 s/step
# on time step 541 (time=10.82), 0.19624 s/step
# on time step 563 (time=11.26), 0.182967 s/step
# on time step 585 (time=11.7), 0.185841 s/step
# on time step 607 (time=12.14), 0.182977 s/step
# on time step 629 (time=12.58), 0.188515 s/step
# on time step 650 (time=13), 0.19347 s/step
# on time step 672 (time=13.44), 0.190285 s/step
# on time step 694 (time=13.88), 0.189379 s/step
# on time step 716 (time=14.32), 0.18605 s/step
# on time step 737 (time=14.74), 0.190657 s/step
# on time step 758 (time=15.16), 0.198716 s/step
# on time step 780 (time=15.6), 0.186087 s/step
# on time step 801 (time=16.02), 0.192379 s/step
# on time step 822 (time=16.44), 0.191494 s/step
# on time step 844 (time=16.88), 0.18917 s/step
# on time step 865 (time=17.3), 0.193901 s/step
# on time step 886 (time=17.72), 0.197416 s/step
# on time step 908 (time=18.16), 0.18783 s/step
# on time step 930 (time=18.6), 0.188615 s/step
# on time step 952 (time=19.04), 0.183752 s/step
# on time step 973 (time=19.46), 0.194154 s/step
# on time step 994 (time=19.88), 0.191079 s/step
# field decay(t = 20.04): 0.20238461326910623 / 0.20238461326910623 = 1.0
# on time step 1016 (time=20.32), 0.187611 s/step
# on time step 1038 (time=20.76), 0.18552 s/step
# on time step 1060 (time=21.2), 0.184604 s/step
# on time step 1082 (time=21.64), 0.188483 s/step
# on time step 1104 (time=22.08), 0.182041 s/step
# on time step 1126 (time=22.52), 0.181846 s/step
# on time step 1149 (time=22.98), 0.181364 s/step
# on time step 1170 (time=23.4), 0.190841 s/step
# on time step 1192 (time=23.84), 0.183116 s/step
# on time step 1214 (time=24.28), 0.181839 s/step
# on time step 1236 (time=24.72), 0.18198 s/step
# on time step 1258 (time=25.16), 0.183642 s/step
# on time step 1280 (time=25.6), 0.189562 s/step
# on time step 1302 (time=26.04), 0.187732 s/step
# on time step 1323 (time=26.46), 0.19228 s/step
# on time step 1345 (time=26.9), 0.186999 s/step
# on time step 1367 (time=27.34), 0.187264 s/step
# on time step 1389 (time=27.78), 0.189566 s/step
# on time step 1411 (time=28.22), 0.187821 s/step
# on time step 1433 (time=28.66), 0.186952 s/step
# on time step 1455 (time=29.1), 0.185242 s/step
# on time step 1477 (time=29.54), 0.189107 s/step
# on time step 1499 (time=29.98), 0.182652 s/step
# field decay(t = 30.060000000000002): 0.006911071439772438 / 0.20238461326910623 = 0.03414820587463802
# on time step 1521 (time=30.42), 0.183608 s/step
# on time step 1542 (time=30.84), 0.191347 s/step
# on time step 1564 (time=31.28), 0.18963 s/step
# on time step 1585 (time=31.7), 0.192237 s/step
# on time step 1607 (time=32.14), 0.186803 s/step
# on time step 1629 (time=32.58), 0.186327 s/step
# on time step 1651 (time=33.02), 0.185711 s/step
# on time step 1673 (time=33.46), 0.185987 s/step
# on time step 1694 (time=33.88), 0.19287 s/step
# on time step 1715 (time=34.3), 0.19889 s/step
# on time step 1737 (time=34.74), 0.187743 s/step
# on time step 1759 (time=35.18), 0.185944 s/step
# on time step 1780 (time=35.6), 0.191229 s/step
# on time step 1800 (time=36), 0.204406 s/step
# on time step 1822 (time=36.44), 0.1877 s/step
# on time step 1844 (time=36.88), 0.189098 s/step
# on time step 1866 (time=37.32), 0.186088 s/step
# on time step 1888 (time=37.76), 0.18768 s/step
# on time step 1909 (time=38.18), 0.196058 s/step
# on time step 1931 (time=38.62), 0.189048 s/step
# on time step 1953 (time=39.06), 0.188312 s/step
# on time step 1974 (time=39.48), 0.196274 s/step
# on time step 1995 (time=39.9), 0.193142 s/step
# field decay(t = 40.06): 0.0009840843335057665 / 0.20238461326910623 = 0.004862446396541282
# on time step 2016 (time=40.32), 0.198301 s/step
# on time step 2038 (time=40.76), 0.185216 s/step
# on time step 2059 (time=41.18), 0.194883 s/step
# on time step 2080 (time=41.6), 0.195219 s/step
# on time step 2102 (time=42.04), 0.187159 s/step
# on time step 2124 (time=42.48), 0.195611 s/step
# on time step 2146 (time=42.92), 0.190597 s/step
# on time step 2168 (time=43.36), 0.187849 s/step
# on time step 2189 (time=43.78), 0.193172 s/step
# on time step 2210 (time=44.2), 0.193112 s/step
# on time step 2232 (time=44.64), 0.192421 s/step
# on time step 2254 (time=45.08), 0.18544 s/step
# on time step 2276 (time=45.52), 0.184045 s/step
# on time step 2298 (time=45.96), 0.183537 s/step
# on time step 2320 (time=46.4), 0.187274 s/step
# on time step 2341 (time=46.82), 0.196419 s/step
# on time step 2363 (time=47.26), 0.186755 s/step
# on time step 2385 (time=47.7), 0.186459 s/step
# on time step 2407 (time=48.14), 0.186143 s/step
# on time step 2428 (time=48.56), 0.197466 s/step
# on time step 2449 (time=48.98), 0.1982 s/step
# on time step 2470 (time=49.4), 0.191178 s/step
# on time step 2491 (time=49.82), 0.1934 s/step
# field decay(t = 50.08): 2.9308893888565836e-05 / 0.20238461326910623 = 0.00014481779723834274
# run 0 finished at t = 50.08 (2504 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])
if mp.am_master():
    plt.figure(dpi=300)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical efficiency (in-pixel)")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")
