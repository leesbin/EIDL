# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=11.8)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 0 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * design_region_width_x)) + 1
Ny = int(round(design_region_resolution * design_region_width_y)) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, TiO2, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000692844 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 59.2449% done, 2.75235 s remaining
# subpixel-averaging is 56.9094% done, 3.02888 s remaining
# subpixel-averaging is 59.4762% done, 2.72633 s remaining
# time for set_epsilon = 34.3262 s
# -----------
# on time step 1 (time=0.02), 8.37059 s/step
# on time step 17 (time=0.34), 0.25853 s/step
# on time step 33 (time=0.66), 0.259375 s/step
# on time step 49 (time=0.98), 0.26106 s/step
# on time step 65 (time=1.3), 0.258923 s/step
# on time step 81 (time=1.62), 0.260907 s/step
# on time step 97 (time=1.94), 0.259451 s/step
# on time step 113 (time=2.26), 0.259576 s/step
# on time step 131 (time=2.62), 0.231048 s/step
# on time step 148 (time=2.96), 0.245569 s/step
# on time step 164 (time=3.28), 0.26156 s/step
# on time step 180 (time=3.6), 0.258707 s/step
# on time step 196 (time=3.92), 0.258759 s/step
# on time step 212 (time=4.24), 0.262779 s/step
# on time step 228 (time=4.56), 0.259658 s/step
# on time step 244 (time=4.88), 0.258959 s/step
# on time step 260 (time=5.2), 0.259414 s/step
# on time step 276 (time=5.52), 0.258379 s/step
# on time step 292 (time=5.84), 0.259483 s/step
# on time step 308 (time=6.16), 0.259885 s/step
# on time step 324 (time=6.48), 0.260503 s/step
# on time step 340 (time=6.8), 0.257687 s/step
# on time step 356 (time=7.12), 0.256992 s/step
# on time step 372 (time=7.44), 0.259482 s/step
# on time step 388 (time=7.76), 0.258184 s/step
# on time step 404 (time=8.08), 0.258928 s/step
# on time step 420 (time=8.4), 0.259642 s/step
# on time step 436 (time=8.72), 0.262678 s/step
# on time step 450 (time=9), 0.293823 s/step
# on time step 464 (time=9.28), 0.29876 s/step
# on time step 480 (time=9.6), 0.259711 s/step
# on time step 498 (time=9.96), 0.224965 s/step
# field decay(t = 10.02): 3.9692617858756676e-10 / 3.9692617858756676e-10 = 1.0
# on time step 515 (time=10.3), 0.245023 s/step
# on time step 531 (time=10.62), 0.259701 s/step
# on time step 547 (time=10.94), 0.258198 s/step
# on time step 563 (time=11.26), 0.259761 s/step
# on time step 579 (time=11.58), 0.260608 s/step
# on time step 595 (time=11.9), 0.259521 s/step
# on time step 611 (time=12.22), 0.259313 s/step
# on time step 627 (time=12.54), 0.259291 s/step
# on time step 643 (time=12.86), 0.259588 s/step
# on time step 658 (time=13.16), 0.281738 s/step
# on time step 672 (time=13.44), 0.287887 s/step
# on time step 686 (time=13.72), 0.28657 s/step
# on time step 700 (time=14), 0.289688 s/step
# on time step 714 (time=14.28), 0.286736 s/step
# on time step 728 (time=14.56), 0.291733 s/step
# on time step 742 (time=14.84), 0.286563 s/step
# on time step 757 (time=15.14), 0.289173 s/step
# on time step 772 (time=15.44), 0.273538 s/step
# on time step 787 (time=15.74), 0.273421 s/step
# on time step 801 (time=16.02), 0.29101 s/step
# on time step 815 (time=16.3), 0.292404 s/step
# on time step 829 (time=16.58), 0.289558 s/step
# on time step 843 (time=16.86), 0.294936 s/step
# on time step 861 (time=17.22), 0.232908 s/step
# on time step 876 (time=17.52), 0.284475 s/step
# on time step 891 (time=17.82), 0.282396 s/step
# on time step 906 (time=18.12), 0.282603 s/step
# on time step 920 (time=18.4), 0.286259 s/step
# on time step 934 (time=18.68), 0.28737 s/step
# on time step 948 (time=18.96), 0.28771 s/step
# on time step 962 (time=19.24), 0.287925 s/step
# on time step 976 (time=19.52), 0.28879 s/step
# on time step 990 (time=19.8), 0.289162 s/step
# field decay(t = 20.04): 0.002255901140165393 / 0.002255901140165393 = 1.0
# on time step 1004 (time=20.08), 0.288186 s/step
# on time step 1018 (time=20.36), 0.287167 s/step
# on time step 1032 (time=20.64), 0.28963 s/step
# on time step 1046 (time=20.92), 0.287508 s/step
# on time step 1060 (time=21.2), 0.287999 s/step
# on time step 1074 (time=21.48), 0.287353 s/step
# on time step 1088 (time=21.76), 0.285985 s/step
# on time step 1102 (time=22.04), 0.285754 s/step
# on time step 1117 (time=22.34), 0.283182 s/step
# on time step 1131 (time=22.62), 0.286239 s/step
# on time step 1146 (time=22.92), 0.285687 s/step
# on time step 1161 (time=23.22), 0.28522 s/step
# on time step 1176 (time=23.52), 0.283476 s/step
# on time step 1191 (time=23.82), 0.280866 s/step
# on time step 1206 (time=24.12), 0.281385 s/step
# on time step 1221 (time=24.42), 0.282633 s/step
# on time step 1236 (time=24.72), 0.282454 s/step
# on time step 1250 (time=25), 0.287184 s/step
# on time step 1265 (time=25.3), 0.283031 s/step
# on time step 1279 (time=25.58), 0.29022 s/step
# on time step 1293 (time=25.86), 0.287061 s/step
# on time step 1307 (time=26.14), 0.287133 s/step
# on time step 1321 (time=26.42), 0.285923 s/step
# on time step 1336 (time=26.72), 0.281337 s/step
# on time step 1351 (time=27.02), 0.285405 s/step
# on time step 1365 (time=27.3), 0.305536 s/step
# on time step 1380 (time=27.6), 0.280666 s/step
# on time step 1395 (time=27.9), 0.280504 s/step
# on time step 1410 (time=28.2), 0.283574 s/step
# on time step 1425 (time=28.5), 0.285104 s/step
# on time step 1440 (time=28.8), 0.2832 s/step
# on time step 1456 (time=29.12), 0.252428 s/step
# on time step 1476 (time=29.52), 0.207678 s/step
# on time step 1496 (time=29.92), 0.204706 s/step
# field decay(t = 30.060000000000002): 0.06881261563393251 / 0.06881261563393251 = 1.0
# on time step 1516 (time=30.32), 0.206233 s/step
# on time step 1536 (time=30.72), 0.206741 s/step
# on time step 1556 (time=31.12), 0.205871 s/step
# on time step 1576 (time=31.52), 0.208871 s/step
# on time step 1596 (time=31.92), 0.206674 s/step
# on time step 1616 (time=32.32), 0.206208 s/step
# on time step 1636 (time=32.72), 0.20396 s/step
# on time step 1656 (time=33.12), 0.20788 s/step
# on time step 1676 (time=33.52), 0.206423 s/step
# on time step 1696 (time=33.92), 0.204126 s/step
# on time step 1716 (time=34.32), 0.204591 s/step
# on time step 1736 (time=34.72), 0.20432 s/step
# on time step 1756 (time=35.12), 0.20343 s/step
# on time step 1776 (time=35.52), 0.202699 s/step
# on time step 1796 (time=35.92), 0.202891 s/step
# on time step 1816 (time=36.32), 0.202786 s/step
# on time step 1836 (time=36.72), 0.203422 s/step
# on time step 1856 (time=37.12), 0.202115 s/step
# on time step 1876 (time=37.52), 0.203413 s/step
# on time step 1896 (time=37.92), 0.20562 s/step
# on time step 1916 (time=38.32), 0.208689 s/step
# on time step 1936 (time=38.72), 0.208249 s/step
# on time step 1956 (time=39.12), 0.205421 s/step
# on time step 1976 (time=39.52), 0.203651 s/step
# on time step 1996 (time=39.92), 0.203195 s/step
# field decay(t = 40.06): 0.05906250948598382 / 0.06881261563393251 = 0.858309322235082
# on time step 2016 (time=40.32), 0.203769 s/step
# on time step 2036 (time=40.72), 0.206468 s/step
# on time step 2056 (time=41.12), 0.201748 s/step
# on time step 2076 (time=41.52), 0.205221 s/step
# on time step 2096 (time=41.92), 0.207182 s/step
# on time step 2116 (time=42.32), 0.208342 s/step
# on time step 2136 (time=42.72), 0.207843 s/step
# on time step 2156 (time=43.12), 0.207524 s/step
# on time step 2176 (time=43.52), 0.20902 s/step
# on time step 2196 (time=43.92), 0.206952 s/step
# on time step 2216 (time=44.32), 0.205699 s/step
# on time step 2236 (time=44.72), 0.206495 s/step
# on time step 2256 (time=45.12), 0.202325 s/step
# on time step 2276 (time=45.52), 0.202481 s/step
# on time step 2296 (time=45.92), 0.204189 s/step
# on time step 2316 (time=46.32), 0.203458 s/step
# on time step 2336 (time=46.72), 0.205375 s/step
# on time step 2356 (time=47.12), 0.202783 s/step
# on time step 2376 (time=47.52), 0.204779 s/step
# on time step 2396 (time=47.92), 0.206711 s/step
# on time step 2416 (time=48.32), 0.206709 s/step
# on time step 2436 (time=48.72), 0.206479 s/step
# on time step 2456 (time=49.12), 0.205603 s/step
# on time step 2476 (time=49.52), 0.206281 s/step
# on time step 2496 (time=49.92), 0.206762 s/step
# field decay(t = 50.08): 0.0042158168295143355 / 0.06881261563393251 = 0.06126517340863082
# on time step 2516 (time=50.32), 0.205992 s/step
# on time step 2536 (time=50.72), 0.205388 s/step
# on time step 2556 (time=51.12), 0.203543 s/step
# on time step 2576 (time=51.52), 0.204133 s/step
# on time step 2596 (time=51.92), 0.206602 s/step
# on time step 2616 (time=52.32), 0.208701 s/step
# on time step 2636 (time=52.72), 0.206913 s/step
# on time step 2656 (time=53.12), 0.209588 s/step
# on time step 2676 (time=53.52), 0.207709 s/step
# on time step 2696 (time=53.92), 0.207674 s/step
# on time step 2716 (time=54.32), 0.205586 s/step
# on time step 2736 (time=54.72), 0.205956 s/step
# on time step 2756 (time=55.12), 0.203505 s/step
# on time step 2776 (time=55.52), 0.203454 s/step
# on time step 2796 (time=55.92), 0.203507 s/step
# on time step 2816 (time=56.32), 0.203533 s/step
# on time step 2836 (time=56.72), 0.20357 s/step
# on time step 2856 (time=57.12), 0.203555 s/step
# on time step 2876 (time=57.52), 0.203566 s/step
# on time step 2896 (time=57.92), 0.203302 s/step
# on time step 2916 (time=58.32), 0.204791 s/step
# on time step 2936 (time=58.72), 0.205944 s/step
# on time step 2956 (time=59.12), 0.206209 s/step
# on time step 2976 (time=59.52), 0.205791 s/step
# on time step 2996 (time=59.92), 0.206058 s/step
# field decay(t = 60.1): 0.0007422113640138334 / 0.06881261563393251 = 0.01078597808230731
# on time step 3016 (time=60.32), 0.206593 s/step
# on time step 3036 (time=60.72), 0.207256 s/step
# on time step 3056 (time=61.12), 0.208348 s/step
# on time step 3076 (time=61.52), 0.20666 s/step
# on time step 3096 (time=61.92), 0.206394 s/step
# on time step 3116 (time=62.32), 0.208237 s/step
# on time step 3136 (time=62.72), 0.208377 s/step
# on time step 3156 (time=63.12), 0.209765 s/step
# on time step 3176 (time=63.52), 0.207946 s/step
# on time step 3196 (time=63.92), 0.207707 s/step
# on time step 3216 (time=64.32), 0.207839 s/step
# on time step 3236 (time=64.72), 0.204054 s/step
# on time step 3256 (time=65.12), 0.207771 s/step
# on time step 3276 (time=65.52), 0.204915 s/step
# on time step 3296 (time=65.92), 0.205378 s/step
# on time step 3316 (time=66.32), 0.208492 s/step
# on time step 3336 (time=66.72), 0.208253 s/step
# on time step 3356 (time=67.12), 0.208002 s/step
# on time step 3376 (time=67.52), 0.208287 s/step
# on time step 3396 (time=67.92), 0.207772 s/step
# on time step 3416 (time=68.32), 0.207704 s/step
# on time step 3436 (time=68.72), 0.208834 s/step
# on time step 3456 (time=69.12), 0.208948 s/step
# on time step 3476 (time=69.52), 0.208201 s/step
# on time step 3495 (time=69.9), 0.210636 s/step
# field decay(t = 70.12): 0.00033468549262976433 / 0.06881261563393251 = 0.004863722873291362
# on time step 3515 (time=70.3), 0.20744 s/step
# on time step 3535 (time=70.7), 0.209333 s/step
# on time step 3555 (time=71.1), 0.208398 s/step
# on time step 3575 (time=71.5), 0.210061 s/step
# on time step 3595 (time=71.9), 0.208426 s/step
# on time step 3615 (time=72.3), 0.207018 s/step
# on time step 3635 (time=72.7), 0.205568 s/step
# on time step 3655 (time=73.1), 0.204409 s/step
# on time step 3675 (time=73.5), 0.205026 s/step
# on time step 3695 (time=73.9), 0.206641 s/step
# on time step 3715 (time=74.3), 0.208687 s/step
# on time step 3735 (time=74.7), 0.207357 s/step
# on time step 3755 (time=75.1), 0.206311 s/step
# on time step 3775 (time=75.5), 0.204318 s/step
# on time step 3795 (time=75.9), 0.204407 s/step
# on time step 3815 (time=76.3), 0.204635 s/step
# on time step 3835 (time=76.7), 0.204896 s/step
# on time step 3855 (time=77.1), 0.208848 s/step
# on time step 3875 (time=77.5), 0.210048 s/step
# on time step 3895 (time=77.9), 0.204867 s/step
# on time step 3915 (time=78.3), 0.204822 s/step
# on time step 3935 (time=78.7), 0.207328 s/step
# on time step 3955 (time=79.1), 0.208287 s/step
# on time step 3975 (time=79.5), 0.208627 s/step
# on time step 3995 (time=79.9), 0.208613 s/step
# field decay(t = 80.14): 0.0001610902747684551 / 0.06881261563393251 = 0.0023409991508740024
# on time step 4015 (time=80.3), 0.207311 s/step
# on time step 4035 (time=80.7), 0.205369 s/step
# on time step 4055 (time=81.1), 0.205072 s/step
# on time step 4075 (time=81.5), 0.208446 s/step
# on time step 4095 (time=81.9), 0.206603 s/step
# on time step 4115 (time=82.3), 0.207592 s/step
# on time step 4135 (time=82.7), 0.209389 s/step
# on time step 4155 (time=83.1), 0.209592 s/step
# on time step 4175 (time=83.5), 0.208714 s/step
# on time step 4195 (time=83.9), 0.20783 s/step
# on time step 4215 (time=84.3), 0.207668 s/step
# on time step 4235 (time=84.7), 0.208794 s/step
# on time step 4255 (time=85.1), 0.210589 s/step
# on time step 4275 (time=85.5), 0.209843 s/step
# on time step 4295 (time=85.9), 0.208156 s/step
# on time step 4315 (time=86.3), 0.208326 s/step
# on time step 4335 (time=86.7), 0.208941 s/step
# on time step 4355 (time=87.1), 0.210184 s/step
# on time step 4375 (time=87.5), 0.209844 s/step
# on time step 4395 (time=87.9), 0.208754 s/step
# on time step 4415 (time=88.3), 0.205129 s/step
# on time step 4435 (time=88.7), 0.205446 s/step
# on time step 4455 (time=89.1), 0.20504 s/step
# on time step 4475 (time=89.5), 0.204918 s/step
# on time step 4495 (time=89.9), 0.202968 s/step
# field decay(t = 90.16): 0.00024802727549444757 / 0.06881261563393251 = 0.0036043866841786155
# on time step 4515 (time=90.3), 0.204086 s/step
# on time step 4535 (time=90.7), 0.207281 s/step
# on time step 4555 (time=91.1), 0.208872 s/step
# on time step 4575 (time=91.5), 0.208859 s/step
# on time step 4595 (time=91.9), 0.206892 s/step
# on time step 4615 (time=92.3), 0.206186 s/step
# on time step 4635 (time=92.7), 0.209361 s/step
# on time step 4655 (time=93.1), 0.207871 s/step
# on time step 4675 (time=93.5), 0.204532 s/step
# on time step 4695 (time=93.9), 0.205681 s/step
# on time step 4715 (time=94.3), 0.206349 s/step
# on time step 4735 (time=94.7), 0.204817 s/step
# on time step 4755 (time=95.1), 0.207372 s/step
# on time step 4775 (time=95.5), 0.207131 s/step
# on time step 4795 (time=95.9), 0.208 s/step
# on time step 4815 (time=96.3), 0.207355 s/step
# on time step 4835 (time=96.7), 0.209641 s/step
# on time step 4855 (time=97.1), 0.207496 s/step
# on time step 4875 (time=97.5), 0.2077 s/step
# on time step 4895 (time=97.9), 0.207573 s/step
# on time step 4915 (time=98.3), 0.209997 s/step
# on time step 4935 (time=98.7), 0.207897 s/step
# on time step 4955 (time=99.1), 0.206153 s/step
# on time step 4975 (time=99.5), 0.20828 s/step
# on time step 4995 (time=99.9), 0.20811 s/step
# field decay(t = 100.18): 0.00022769042523803587 / 0.06881261563393251 = 0.00330884712258719
# on time step 5015 (time=100.3), 0.208266 s/step
# on time step 5035 (time=100.7), 0.208703 s/step
# on time step 5055 (time=101.1), 0.209173 s/step
# on time step 5075 (time=101.5), 0.209746 s/step
# on time step 5095 (time=101.9), 0.207612 s/step
# on time step 5115 (time=102.3), 0.207 s/step
# on time step 5134 (time=102.68), 0.210532 s/step
# on time step 5154 (time=103.08), 0.205256 s/step
# on time step 5174 (time=103.48), 0.208966 s/step
# on time step 5194 (time=103.88), 0.208803 s/step
# on time step 5214 (time=104.28), 0.207957 s/step
# on time step 5234 (time=104.68), 0.208522 s/step
# on time step 5254 (time=105.08), 0.205609 s/step
# on time step 5274 (time=105.48), 0.204842 s/step
# on time step 5294 (time=105.88), 0.204857 s/step
# on time step 5314 (time=106.28), 0.204511 s/step
# on time step 5334 (time=106.68), 0.204877 s/step
# on time step 5354 (time=107.08), 0.206171 s/step
# on time step 5374 (time=107.48), 0.208361 s/step
# on time step 5394 (time=107.88), 0.207463 s/step
# on time step 5414 (time=108.28), 0.208041 s/step
# on time step 5434 (time=108.68), 0.204039 s/step
# on time step 5454 (time=109.08), 0.203563 s/step
# on time step 5474 (time=109.48), 0.204106 s/step
# on time step 5494 (time=109.88), 0.20269 s/step
# field decay(t = 110.2): 0.00011627788250977514 / 0.06881261563393251 = 0.00168977565288823
# on time step 5514 (time=110.28), 0.205301 s/step
# on time step 5534 (time=110.68), 0.205269 s/step
# on time step 5554 (time=111.08), 0.207483 s/step
# on time step 5574 (time=111.48), 0.207239 s/step
# on time step 5594 (time=111.88), 0.207972 s/step
# on time step 5614 (time=112.28), 0.208663 s/step
# on time step 5634 (time=112.68), 0.208145 s/step
# on time step 5654 (time=113.08), 0.207923 s/step
# on time step 5674 (time=113.48), 0.207497 s/step
# on time step 5694 (time=113.88), 0.206899 s/step
# on time step 5714 (time=114.28), 0.206393 s/step
# on time step 5734 (time=114.68), 0.204853 s/step
# on time step 5754 (time=115.08), 0.205526 s/step
# on time step 5774 (time=115.48), 0.20445 s/step
# on time step 5794 (time=115.88), 0.203846 s/step
# on time step 5814 (time=116.28), 0.204327 s/step
# on time step 5834 (time=116.68), 0.203242 s/step
# on time step 5854 (time=117.08), 0.203999 s/step
# on time step 5874 (time=117.48), 0.202402 s/step
# on time step 5894 (time=117.88), 0.202938 s/step
# on time step 5914 (time=118.28), 0.203267 s/step
# on time step 5934 (time=118.68), 0.203169 s/step
# on time step 5954 (time=119.08), 0.203386 s/step
# on time step 5974 (time=119.48), 0.202857 s/step
# on time step 5994 (time=119.88), 0.202678 s/step
# field decay(t = 120.22): 4.413668084632568e-05 / 0.06881261563393251 = 0.0006414039117641277
# run 0 finished at t = 120.22 (6011 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000677109 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 57.395% done, 2.96963 s remaining
# subpixel-averaging is 57.025% done, 3.01548 s remaining
# subpixel-averaging is 59.2218% done, 2.75436 s remaining
# time for set_epsilon = 35.0083 s
# -----------
# on time step 1 (time=0.02), 8.21061 s/step
# on time step 21 (time=0.42), 0.201481 s/step
# on time step 41 (time=0.82), 0.201496 s/step
# on time step 61 (time=1.22), 0.203391 s/step
# on time step 81 (time=1.62), 0.204159 s/step
# on time step 101 (time=2.02), 0.203553 s/step
# on time step 121 (time=2.42), 0.203875 s/step
# on time step 141 (time=2.82), 0.201929 s/step
# on time step 161 (time=3.22), 0.200906 s/step
# on time step 181 (time=3.62), 0.202427 s/step
# on time step 201 (time=4.02), 0.205963 s/step
# on time step 221 (time=4.42), 0.205556 s/step
# on time step 241 (time=4.82), 0.201604 s/step
# on time step 261 (time=5.22), 0.206215 s/step
# on time step 281 (time=5.62), 0.204169 s/step
# on time step 301 (time=6.02), 0.203884 s/step
# on time step 321 (time=6.42), 0.205176 s/step
# on time step 341 (time=6.82), 0.204625 s/step
# on time step 361 (time=7.22), 0.206366 s/step
# on time step 381 (time=7.62), 0.20324 s/step
# on time step 401 (time=8.02), 0.205273 s/step
# on time step 421 (time=8.42), 0.20461 s/step
# on time step 441 (time=8.82), 0.202919 s/step
# on time step 461 (time=9.22), 0.206458 s/step
# on time step 481 (time=9.62), 0.207856 s/step
# field decay(t = 10.02): 1.0367644511824117e-09 / 1.0367644511824117e-09 = 1.0
# on time step 501 (time=10.02), 0.206622 s/step
# on time step 521 (time=10.42), 0.206053 s/step
# on time step 541 (time=10.82), 0.206815 s/step
# on time step 561 (time=11.22), 0.207577 s/step
# on time step 581 (time=11.62), 0.208264 s/step
# on time step 601 (time=12.02), 0.2078 s/step
# on time step 621 (time=12.42), 0.205893 s/step
# on time step 641 (time=12.82), 0.202628 s/step
# on time step 661 (time=13.22), 0.205234 s/step
# on time step 681 (time=13.62), 0.20486 s/step
# on time step 701 (time=14.02), 0.205275 s/step
# on time step 721 (time=14.42), 0.204387 s/step
# on time step 741 (time=14.82), 0.207088 s/step
# on time step 761 (time=15.22), 0.206805 s/step
# on time step 781 (time=15.62), 0.206035 s/step
# on time step 801 (time=16.02), 0.206099 s/step
# on time step 821 (time=16.42), 0.203614 s/step
# on time step 841 (time=16.82), 0.203929 s/step
# on time step 861 (time=17.22), 0.201999 s/step
# on time step 881 (time=17.62), 0.202251 s/step
# on time step 901 (time=18.02), 0.202022 s/step
# on time step 921 (time=18.42), 0.204149 s/step
# on time step 941 (time=18.82), 0.204802 s/step
# on time step 961 (time=19.22), 0.206617 s/step
# on time step 981 (time=19.62), 0.202583 s/step
# on time step 1001 (time=20.02), 0.204682 s/step
# field decay(t = 20.04): 0.0001086331752866601 / 0.0001086331752866601 = 1.0
# on time step 1021 (time=20.42), 0.205888 s/step
# on time step 1041 (time=20.82), 0.205998 s/step
# on time step 1061 (time=21.22), 0.205608 s/step
# on time step 1081 (time=21.62), 0.20353 s/step
# on time step 1101 (time=22.02), 0.204636 s/step
# on time step 1121 (time=22.42), 0.203297 s/step
# on time step 1141 (time=22.82), 0.207295 s/step
# on time step 1161 (time=23.22), 0.207034 s/step
# on time step 1181 (time=23.62), 0.205012 s/step
# on time step 1201 (time=24.02), 0.20558 s/step
# on time step 1221 (time=24.42), 0.202047 s/step
# on time step 1241 (time=24.82), 0.20405 s/step
# on time step 1261 (time=25.22), 0.201877 s/step
# on time step 1281 (time=25.62), 0.202416 s/step
# on time step 1301 (time=26.02), 0.20399 s/step
# on time step 1321 (time=26.42), 0.203018 s/step
# on time step 1341 (time=26.82), 0.202233 s/step
# on time step 1361 (time=27.22), 0.206147 s/step
# on time step 1381 (time=27.62), 0.2054 s/step
# on time step 1401 (time=28.02), 0.20588 s/step
# on time step 1421 (time=28.42), 0.204213 s/step
# on time step 1441 (time=28.82), 0.203968 s/step
# on time step 1461 (time=29.22), 0.207327 s/step
# on time step 1481 (time=29.62), 0.208052 s/step
# on time step 1501 (time=30.02), 0.207182 s/step
# field decay(t = 30.060000000000002): 0.0437451715856635 / 0.0437451715856635 = 1.0
# on time step 1521 (time=30.42), 0.204052 s/step
# on time step 1541 (time=30.82), 0.206162 s/step
# on time step 1561 (time=31.22), 0.203859 s/step
# on time step 1581 (time=31.62), 0.205468 s/step
# on time step 1601 (time=32.02), 0.205002 s/step
# on time step 1621 (time=32.42), 0.203635 s/step
# on time step 1641 (time=32.82), 0.20374 s/step
# on time step 1661 (time=33.22), 0.202036 s/step
# on time step 1681 (time=33.62), 0.20334 s/step
# on time step 1701 (time=34.02), 0.201591 s/step
# on time step 1721 (time=34.42), 0.202602 s/step
# on time step 1741 (time=34.82), 0.202685 s/step
# on time step 1761 (time=35.22), 0.201858 s/step
# on time step 1781 (time=35.62), 0.202488 s/step
# on time step 1801 (time=36.02), 0.201581 s/step
# on time step 1821 (time=36.42), 0.203085 s/step
# on time step 1841 (time=36.82), 0.201821 s/step
# on time step 1861 (time=37.22), 0.202467 s/step
# on time step 1881 (time=37.62), 0.201775 s/step
# on time step 1901 (time=38.02), 0.202158 s/step
# on time step 1921 (time=38.42), 0.204077 s/step
# on time step 1941 (time=38.82), 0.202184 s/step
# on time step 1961 (time=39.22), 0.202237 s/step
# on time step 1981 (time=39.62), 0.205036 s/step
# on time step 2001 (time=40.02), 0.204349 s/step
# field decay(t = 40.06): 0.127584397672758 / 0.127584397672758 = 1.0
# on time step 2021 (time=40.42), 0.207632 s/step
# on time step 2041 (time=40.82), 0.205435 s/step
# on time step 2061 (time=41.22), 0.205954 s/step
# on time step 2081 (time=41.62), 0.204182 s/step
# on time step 2101 (time=42.02), 0.204763 s/step
# on time step 2121 (time=42.42), 0.203554 s/step
# on time step 2141 (time=42.82), 0.202965 s/step
# on time step 2161 (time=43.22), 0.203881 s/step
# on time step 2181 (time=43.62), 0.204992 s/step
# on time step 2201 (time=44.02), 0.204007 s/step
# on time step 2221 (time=44.42), 0.203002 s/step
# on time step 2241 (time=44.82), 0.202927 s/step
# on time step 2261 (time=45.22), 0.206837 s/step
# on time step 2281 (time=45.62), 0.203114 s/step
# on time step 2301 (time=46.02), 0.202725 s/step
# on time step 2321 (time=46.42), 0.204751 s/step
# on time step 2341 (time=46.82), 0.204353 s/step
# on time step 2361 (time=47.22), 0.204844 s/step
# on time step 2381 (time=47.62), 0.203886 s/step
# on time step 2401 (time=48.02), 0.203297 s/step
# on time step 2421 (time=48.42), 0.205212 s/step
# on time step 2441 (time=48.82), 0.205186 s/step
# on time step 2461 (time=49.22), 0.208514 s/step
# on time step 2481 (time=49.62), 0.203784 s/step
# on time step 2501 (time=50.02), 0.203155 s/step
# field decay(t = 50.08): 0.0894297685824971 / 0.127584397672758 = 0.700945963721019
# on time step 2521 (time=50.42), 0.206273 s/step
# on time step 2541 (time=50.82), 0.206569 s/step
# on time step 2561 (time=51.22), 0.204086 s/step
# on time step 2581 (time=51.62), 0.203624 s/step
# on time step 2601 (time=52.02), 0.201248 s/step
# on time step 2621 (time=52.42), 0.201644 s/step
# on time step 2641 (time=52.82), 0.201523 s/step
# on time step 2661 (time=53.22), 0.203406 s/step
# on time step 2681 (time=53.62), 0.20349 s/step
# on time step 2701 (time=54.02), 0.2067 s/step
# on time step 2721 (time=54.42), 0.206439 s/step
# on time step 2741 (time=54.82), 0.203926 s/step
# on time step 2761 (time=55.22), 0.202388 s/step
# on time step 2781 (time=55.62), 0.205166 s/step
# on time step 2801 (time=56.02), 0.204739 s/step
# on time step 2821 (time=56.42), 0.20607 s/step
# on time step 2841 (time=56.82), 0.206702 s/step
# on time step 2861 (time=57.22), 0.205448 s/step
# on time step 2881 (time=57.62), 0.203522 s/step
# on time step 2901 (time=58.02), 0.205824 s/step
# on time step 2921 (time=58.42), 0.206792 s/step
# on time step 2941 (time=58.82), 0.206177 s/step
# on time step 2961 (time=59.22), 0.204297 s/step
# on time step 2981 (time=59.62), 0.204702 s/step
# on time step 3001 (time=60.02), 0.203106 s/step
# field decay(t = 60.1): 0.01323340252399258 / 0.127584397672758 = 0.10372273385602379
# on time step 3021 (time=60.42), 0.203168 s/step
# on time step 3041 (time=60.82), 0.203178 s/step
# on time step 3061 (time=61.22), 0.202768 s/step
# on time step 3081 (time=61.62), 0.205269 s/step
# on time step 3101 (time=62.02), 0.20423 s/step
# on time step 3121 (time=62.42), 0.20499 s/step
# on time step 3141 (time=62.82), 0.202437 s/step
# on time step 3161 (time=63.22), 0.202486 s/step
# on time step 3181 (time=63.62), 0.20269 s/step
# on time step 3201 (time=64.02), 0.202407 s/step
# on time step 3221 (time=64.42), 0.204803 s/step
# on time step 3241 (time=64.82), 0.205807 s/step
# on time step 3261 (time=65.22), 0.207654 s/step
# on time step 3281 (time=65.62), 0.204222 s/step
# on time step 3301 (time=66.02), 0.207632 s/step
# on time step 3321 (time=66.42), 0.207746 s/step
# on time step 3341 (time=66.82), 0.207578 s/step
# on time step 3361 (time=67.22), 0.204274 s/step
# on time step 3381 (time=67.62), 0.202704 s/step
# on time step 3401 (time=68.02), 0.202098 s/step
# on time step 3421 (time=68.42), 0.20194 s/step
# on time step 3441 (time=68.82), 0.204608 s/step
# on time step 3461 (time=69.22), 0.201998 s/step
# on time step 3481 (time=69.62), 0.204138 s/step
# on time step 3501 (time=70.02), 0.205027 s/step
# field decay(t = 70.12): 0.004257552967176565 / 0.127584397672758 = 0.033370482949622006
# on time step 3521 (time=70.42), 0.203789 s/step
# on time step 3541 (time=70.82), 0.202395 s/step
# on time step 3561 (time=71.22), 0.202361 s/step
# on time step 3581 (time=71.62), 0.202764 s/step
# on time step 3601 (time=72.02), 0.202865 s/step
# on time step 3621 (time=72.42), 0.200565 s/step
# on time step 3641 (time=72.82), 0.205516 s/step
# on time step 3661 (time=73.22), 0.206119 s/step
# on time step 3681 (time=73.62), 0.202512 s/step
# on time step 3701 (time=74.02), 0.201449 s/step
# on time step 3721 (time=74.42), 0.201652 s/step
# on time step 3741 (time=74.82), 0.201633 s/step
# on time step 3761 (time=75.22), 0.20224 s/step
# on time step 3781 (time=75.62), 0.203285 s/step
# on time step 3801 (time=76.02), 0.202938 s/step
# on time step 3821 (time=76.42), 0.204671 s/step
# on time step 3841 (time=76.82), 0.20486 s/step
# on time step 3861 (time=77.22), 0.206609 s/step
# on time step 3881 (time=77.62), 0.20498 s/step
# on time step 3901 (time=78.02), 0.20497 s/step
# on time step 3921 (time=78.42), 0.204528 s/step
# on time step 3941 (time=78.82), 0.207745 s/step
# on time step 3961 (time=79.22), 0.208006 s/step
# on time step 3981 (time=79.62), 0.206566 s/step
# on time step 4001 (time=80.02), 0.204539 s/step
# field decay(t = 80.14): 0.002745637993212946 / 0.127584397672758 = 0.021520170516893842
# on time step 4021 (time=80.42), 0.206067 s/step
# on time step 4041 (time=80.82), 0.204872 s/step
# on time step 4061 (time=81.22), 0.206582 s/step
# on time step 4081 (time=81.62), 0.207228 s/step
# on time step 4101 (time=82.02), 0.205443 s/step
# on time step 4121 (time=82.42), 0.205511 s/step
# on time step 4141 (time=82.82), 0.205356 s/step
# on time step 4161 (time=83.22), 0.2039 s/step
# on time step 4181 (time=83.62), 0.203758 s/step
# on time step 4201 (time=84.02), 0.204801 s/step
# on time step 4221 (time=84.42), 0.20658 s/step
# on time step 4241 (time=84.82), 0.206467 s/step
# on time step 4261 (time=85.22), 0.207783 s/step
# on time step 4281 (time=85.62), 0.20618 s/step
# on time step 4301 (time=86.02), 0.209266 s/step
# on time step 4321 (time=86.42), 0.208798 s/step
# on time step 4341 (time=86.82), 0.209688 s/step
# on time step 4361 (time=87.22), 0.206971 s/step
# on time step 4381 (time=87.62), 0.207481 s/step
# on time step 4401 (time=88.02), 0.203581 s/step
# on time step 4421 (time=88.42), 0.204605 s/step
# on time step 4441 (time=88.82), 0.204485 s/step
# on time step 4461 (time=89.22), 0.203781 s/step
# on time step 4481 (time=89.62), 0.203324 s/step
# on time step 4501 (time=90.02), 0.201609 s/step
# field decay(t = 90.16): 0.001221164830786555 / 0.127584397672758 = 0.009571427643674175
# on time step 4521 (time=90.42), 0.203036 s/step
# on time step 4541 (time=90.82), 0.207151 s/step
# on time step 4561 (time=91.22), 0.206485 s/step
# on time step 4581 (time=91.62), 0.204074 s/step
# on time step 4601 (time=92.02), 0.20252 s/step
# on time step 4621 (time=92.42), 0.20284 s/step
# on time step 4641 (time=92.82), 0.208234 s/step
# on time step 4661 (time=93.22), 0.206723 s/step
# on time step 4681 (time=93.62), 0.205077 s/step
# on time step 4701 (time=94.02), 0.204755 s/step
# on time step 4721 (time=94.42), 0.205795 s/step
# on time step 4741 (time=94.82), 0.203624 s/step
# on time step 4761 (time=95.22), 0.204404 s/step
# on time step 4781 (time=95.62), 0.20538 s/step
# on time step 4801 (time=96.02), 0.2064 s/step
# on time step 4821 (time=96.42), 0.207223 s/step
# on time step 4841 (time=96.82), 0.204205 s/step
# on time step 4861 (time=97.22), 0.2041 s/step
# on time step 4881 (time=97.62), 0.206805 s/step
# on time step 4901 (time=98.02), 0.207703 s/step
# on time step 4921 (time=98.42), 0.207087 s/step
# on time step 4941 (time=98.82), 0.208211 s/step
# on time step 4961 (time=99.22), 0.201648 s/step
# on time step 4981 (time=99.62), 0.20173 s/step
# on time step 5001 (time=100.02), 0.206173 s/step
# field decay(t = 100.18): 0.00018330011222118908 / 0.127584397672758 = 0.0014366969281881681
# on time step 5021 (time=100.42), 0.207113 s/step
# on time step 5041 (time=100.82), 0.204119 s/step
# on time step 5061 (time=101.22), 0.206203 s/step
# on time step 5081 (time=101.62), 0.20461 s/step
# on time step 5101 (time=102.02), 0.205985 s/step
# on time step 5121 (time=102.42), 0.20223 s/step
# on time step 5141 (time=102.82), 0.204054 s/step
# on time step 5161 (time=103.22), 0.203879 s/step
# on time step 5181 (time=103.62), 0.203278 s/step
# on time step 5201 (time=104.02), 0.203396 s/step
# on time step 5221 (time=104.42), 0.203716 s/step
# on time step 5241 (time=104.82), 0.203989 s/step
# on time step 5261 (time=105.22), 0.205164 s/step
# on time step 5281 (time=105.62), 0.203647 s/step
# on time step 5301 (time=106.02), 0.2036 s/step
# on time step 5321 (time=106.42), 0.204437 s/step
# on time step 5341 (time=106.82), 0.206279 s/step
# on time step 5361 (time=107.22), 0.205884 s/step
# on time step 5381 (time=107.62), 0.206106 s/step
# on time step 5401 (time=108.02), 0.20518 s/step
# on time step 5421 (time=108.42), 0.206448 s/step
# on time step 5441 (time=108.82), 0.206299 s/step
# on time step 5461 (time=109.22), 0.206592 s/step
# on time step 5481 (time=109.62), 0.20704 s/step
# on time step 5501 (time=110.02), 0.207028 s/step
# field decay(t = 110.2): 0.00011891856193807297 / 0.127584397672758 = 0.00093207762161552
# run 0 finished at t = 110.2 (5510 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000690937 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 59.7537% done, 2.69447 s remaining
# subpixel-averaging is 58.8981% done, 2.7921 s remaining
# subpixel-averaging is 59.7074% done, 2.70018 s remaining
# time for set_epsilon = 33.8928 s
# -----------
# on time step 1 (time=0.02), 8.2623 s/step
# on time step 21 (time=0.42), 0.207198 s/step
# on time step 41 (time=0.82), 0.208613 s/step
# on time step 61 (time=1.22), 0.205097 s/step
# on time step 81 (time=1.62), 0.207121 s/step
# on time step 101 (time=2.02), 0.206444 s/step
# on time step 121 (time=2.42), 0.207536 s/step
# on time step 141 (time=2.82), 0.209735 s/step
# on time step 161 (time=3.22), 0.207109 s/step
# on time step 181 (time=3.62), 0.206262 s/step
# on time step 201 (time=4.02), 0.207148 s/step
# on time step 221 (time=4.42), 0.202985 s/step
# on time step 241 (time=4.82), 0.204371 s/step
# on time step 261 (time=5.22), 0.202804 s/step
# on time step 281 (time=5.62), 0.202235 s/step
# on time step 301 (time=6.02), 0.203082 s/step
# on time step 321 (time=6.42), 0.205297 s/step
# on time step 341 (time=6.82), 0.204431 s/step
# on time step 361 (time=7.22), 0.203064 s/step
# on time step 381 (time=7.62), 0.202825 s/step
# on time step 401 (time=8.02), 0.203353 s/step
# on time step 421 (time=8.42), 0.204246 s/step
# on time step 441 (time=8.82), 0.203547 s/step
# on time step 461 (time=9.22), 0.202642 s/step
# on time step 481 (time=9.62), 0.20638 s/step
# field decay(t = 10.02): 3.1784534895042094e-09 / 3.1784534895042094e-09 = 1.0
# on time step 501 (time=10.02), 0.204627 s/step
# on time step 521 (time=10.42), 0.205015 s/step
# on time step 541 (time=10.82), 0.205844 s/step
# on time step 561 (time=11.22), 0.206105 s/step
# on time step 581 (time=11.62), 0.203588 s/step
# on time step 601 (time=12.02), 0.204096 s/step
# on time step 621 (time=12.42), 0.206136 s/step
# on time step 641 (time=12.82), 0.206355 s/step
# on time step 661 (time=13.22), 0.206489 s/step
# on time step 681 (time=13.62), 0.206293 s/step
# on time step 701 (time=14.02), 0.206943 s/step
# on time step 721 (time=14.42), 0.206722 s/step
# on time step 741 (time=14.82), 0.206114 s/step
# on time step 761 (time=15.22), 0.206132 s/step
# on time step 781 (time=15.62), 0.206783 s/step
# on time step 801 (time=16.02), 0.206459 s/step
# on time step 821 (time=16.42), 0.206152 s/step
# on time step 841 (time=16.82), 0.206631 s/step
# on time step 861 (time=17.22), 0.2072 s/step
# on time step 881 (time=17.62), 0.205815 s/step
# on time step 901 (time=18.02), 0.206771 s/step
# on time step 921 (time=18.42), 0.205461 s/step
# on time step 941 (time=18.82), 0.205234 s/step
# on time step 961 (time=19.22), 0.206479 s/step
# on time step 981 (time=19.62), 0.205492 s/step
# on time step 1001 (time=20.02), 0.20665 s/step
# field decay(t = 20.04): 0.0002037632362673919 / 0.0002037632362673919 = 1.0
# on time step 1021 (time=20.42), 0.203801 s/step
# on time step 1041 (time=20.82), 0.201984 s/step
# on time step 1061 (time=21.22), 0.203363 s/step
# on time step 1081 (time=21.62), 0.202975 s/step
# on time step 1101 (time=22.02), 0.202627 s/step
# on time step 1121 (time=22.42), 0.202536 s/step
# on time step 1141 (time=22.82), 0.201731 s/step
# on time step 1161 (time=23.22), 0.204073 s/step
# on time step 1181 (time=23.62), 0.203814 s/step
# on time step 1201 (time=24.02), 0.20347 s/step
# on time step 1221 (time=24.42), 0.202207 s/step
# on time step 1241 (time=24.82), 0.204367 s/step
# on time step 1261 (time=25.22), 0.208464 s/step
# on time step 1281 (time=25.62), 0.205392 s/step
# on time step 1301 (time=26.02), 0.205704 s/step
# on time step 1321 (time=26.42), 0.204843 s/step
# on time step 1341 (time=26.82), 0.207056 s/step
# on time step 1361 (time=27.22), 0.204403 s/step
# on time step 1381 (time=27.62), 0.203888 s/step
# on time step 1401 (time=28.02), 0.203182 s/step
# on time step 1421 (time=28.42), 0.202441 s/step
# on time step 1441 (time=28.82), 0.205132 s/step
# on time step 1461 (time=29.22), 0.205417 s/step
# on time step 1481 (time=29.62), 0.20472 s/step
# on time step 1501 (time=30.02), 0.203693 s/step
# field decay(t = 30.060000000000002): 0.0849304473255326 / 0.0849304473255326 = 1.0
# on time step 1521 (time=30.42), 0.205316 s/step
# on time step 1541 (time=30.82), 0.203195 s/step
# on time step 1561 (time=31.22), 0.205577 s/step
# on time step 1581 (time=31.62), 0.205115 s/step
# on time step 1601 (time=32.02), 0.203575 s/step
# on time step 1621 (time=32.42), 0.202142 s/step
# on time step 1641 (time=32.82), 0.206816 s/step
# on time step 1661 (time=33.22), 0.205859 s/step
# on time step 1681 (time=33.62), 0.204816 s/step
# on time step 1701 (time=34.02), 0.204863 s/step
# on time step 1721 (time=34.42), 0.204246 s/step
# on time step 1741 (time=34.82), 0.204157 s/step
# on time step 1761 (time=35.22), 0.204158 s/step
# on time step 1781 (time=35.62), 0.204044 s/step
# on time step 1801 (time=36.02), 0.204506 s/step
# on time step 1821 (time=36.42), 0.203933 s/step
# on time step 1841 (time=36.82), 0.205583 s/step
# on time step 1861 (time=37.22), 0.203734 s/step
# on time step 1881 (time=37.62), 0.205523 s/step
# on time step 1901 (time=38.02), 0.202929 s/step
# on time step 1921 (time=38.42), 0.203233 s/step
# on time step 1941 (time=38.82), 0.204008 s/step
# on time step 1961 (time=39.22), 0.205537 s/step
# on time step 1981 (time=39.62), 0.20286 s/step
# on time step 2001 (time=40.02), 0.205731 s/step
# field decay(t = 40.06): 0.19075908375899342 / 0.19075908375899342 = 1.0
# on time step 2021 (time=40.42), 0.20749 s/step
# on time step 2041 (time=40.82), 0.207078 s/step
# on time step 2061 (time=41.22), 0.204696 s/step
# on time step 2081 (time=41.62), 0.206514 s/step
# on time step 2101 (time=42.02), 0.206572 s/step
# on time step 2121 (time=42.42), 0.203014 s/step
# on time step 2141 (time=42.82), 0.202745 s/step
# on time step 2161 (time=43.22), 0.202088 s/step
# on time step 2181 (time=43.62), 0.202875 s/step
# on time step 2201 (time=44.02), 0.202388 s/step
# on time step 2221 (time=44.42), 0.206377 s/step
# on time step 2241 (time=44.82), 0.202862 s/step
# on time step 2261 (time=45.22), 0.20156 s/step
# on time step 2281 (time=45.62), 0.203573 s/step
# on time step 2301 (time=46.02), 0.202849 s/step
# on time step 2321 (time=46.42), 0.203344 s/step
# on time step 2341 (time=46.82), 0.205525 s/step
# on time step 2361 (time=47.22), 0.205353 s/step
# on time step 2381 (time=47.62), 0.203011 s/step
# on time step 2401 (time=48.02), 0.205596 s/step
# on time step 2421 (time=48.42), 0.206985 s/step
# on time step 2441 (time=48.82), 0.206176 s/step
# on time step 2461 (time=49.22), 0.204457 s/step
# on time step 2481 (time=49.62), 0.203739 s/step
# on time step 2501 (time=50.02), 0.207033 s/step
# field decay(t = 50.08): 0.08856957490547211 / 0.19075908375899342 = 0.4643006936297285
# on time step 2521 (time=50.42), 0.206634 s/step
# on time step 2541 (time=50.82), 0.20324 s/step
# on time step 2561 (time=51.22), 0.204878 s/step
# on time step 2581 (time=51.62), 0.202458 s/step
# on time step 2601 (time=52.02), 0.202123 s/step
# on time step 2621 (time=52.42), 0.20289 s/step
# on time step 2641 (time=52.82), 0.202626 s/step
# on time step 2661 (time=53.22), 0.202687 s/step
# on time step 2681 (time=53.62), 0.205742 s/step
# on time step 2701 (time=54.02), 0.202808 s/step
# on time step 2721 (time=54.42), 0.206661 s/step
# on time step 2741 (time=54.82), 0.204609 s/step
# on time step 2761 (time=55.22), 0.211349 s/step
# on time step 2781 (time=55.62), 0.208941 s/step
# on time step 2801 (time=56.02), 0.210038 s/step
# on time step 2821 (time=56.42), 0.209525 s/step
# on time step 2841 (time=56.82), 0.20707 s/step
# on time step 2861 (time=57.22), 0.204542 s/step
# on time step 2881 (time=57.62), 0.208077 s/step
# on time step 2901 (time=58.02), 0.205083 s/step
# on time step 2921 (time=58.42), 0.205071 s/step
# on time step 2941 (time=58.82), 0.207477 s/step
# on time step 2961 (time=59.22), 0.206907 s/step
# on time step 2981 (time=59.62), 0.207983 s/step
# on time step 3001 (time=60.02), 0.208494 s/step
# field decay(t = 60.1): 0.0004904018947272726 / 0.19075908375899342 = 0.0025707918336767143
# on time step 3021 (time=60.42), 0.210165 s/step
# on time step 3041 (time=60.82), 0.205602 s/step
# on time step 3061 (time=61.22), 0.207279 s/step
# on time step 3081 (time=61.62), 0.208224 s/step
# on time step 3101 (time=62.02), 0.208067 s/step
# on time step 3121 (time=62.42), 0.208716 s/step
# on time step 3141 (time=62.82), 0.207269 s/step
# on time step 3161 (time=63.22), 0.206859 s/step
# on time step 3181 (time=63.62), 0.206525 s/step
# on time step 3201 (time=64.02), 0.20826 s/step
# on time step 3221 (time=64.42), 0.207922 s/step
# on time step 3241 (time=64.82), 0.20534 s/step
# on time step 3261 (time=65.22), 0.205624 s/step
# on time step 3281 (time=65.62), 0.203887 s/step
# on time step 3301 (time=66.02), 0.203782 s/step
# on time step 3321 (time=66.42), 0.204696 s/step
# on time step 3341 (time=66.82), 0.206978 s/step
# on time step 3361 (time=67.22), 0.205555 s/step
# on time step 3381 (time=67.62), 0.205473 s/step
# on time step 3401 (time=68.02), 0.203686 s/step
# on time step 3421 (time=68.42), 0.205016 s/step
# on time step 3441 (time=68.82), 0.207367 s/step
# on time step 3461 (time=69.22), 0.208718 s/step
# on time step 3481 (time=69.62), 0.208487 s/step
# on time step 3501 (time=70.02), 0.207978 s/step
# field decay(t = 70.12): 0.0007314131261394605 / 0.19075908375899342 = 0.0038342243615697683
# on time step 3521 (time=70.42), 0.206955 s/step
# on time step 3541 (time=70.82), 0.204621 s/step
# on time step 3561 (time=71.22), 0.204634 s/step
# on time step 3581 (time=71.62), 0.208106 s/step
# on time step 3601 (time=72.02), 0.205457 s/step
# on time step 3621 (time=72.42), 0.206645 s/step
# on time step 3641 (time=72.82), 0.206429 s/step
# on time step 3661 (time=73.22), 0.20826 s/step
# on time step 3681 (time=73.62), 0.206783 s/step
# on time step 3701 (time=74.02), 0.207295 s/step
# on time step 3721 (time=74.42), 0.208211 s/step
# on time step 3741 (time=74.82), 0.208143 s/step
# on time step 3761 (time=75.22), 0.208003 s/step
# on time step 3781 (time=75.62), 0.207823 s/step
# on time step 3801 (time=76.02), 0.20524 s/step
# on time step 3821 (time=76.42), 0.204283 s/step
# on time step 3841 (time=76.82), 0.205483 s/step
# on time step 3861 (time=77.22), 0.20597 s/step
# on time step 3881 (time=77.62), 0.204255 s/step
# on time step 3901 (time=78.02), 0.208096 s/step
# on time step 3921 (time=78.42), 0.207454 s/step
# on time step 3941 (time=78.82), 0.207816 s/step
# on time step 3961 (time=79.22), 0.208236 s/step
# on time step 3981 (time=79.62), 0.205396 s/step
# on time step 4001 (time=80.02), 0.207569 s/step
# field decay(t = 80.14): 0.0012942509138700246 / 0.19075908375899342 = 0.0067847406706209165
# on time step 4021 (time=80.42), 0.207167 s/step
# on time step 4041 (time=80.82), 0.207132 s/step
# on time step 4061 (time=81.22), 0.206619 s/step
# on time step 4081 (time=81.62), 0.205427 s/step
# on time step 4101 (time=82.02), 0.206357 s/step
# on time step 4121 (time=82.42), 0.207177 s/step
# on time step 4141 (time=82.82), 0.205328 s/step
# on time step 4161 (time=83.22), 0.207002 s/step
# on time step 4181 (time=83.62), 0.20592 s/step
# on time step 4201 (time=84.02), 0.206039 s/step
# on time step 4221 (time=84.42), 0.207214 s/step
# on time step 4241 (time=84.82), 0.20651 s/step
# on time step 4261 (time=85.22), 0.206342 s/step
# on time step 4281 (time=85.62), 0.205111 s/step
# on time step 4301 (time=86.02), 0.208662 s/step
# on time step 4321 (time=86.42), 0.208992 s/step
# on time step 4341 (time=86.82), 0.207273 s/step
# on time step 4361 (time=87.22), 0.205407 s/step
# on time step 4381 (time=87.62), 0.20527 s/step
# on time step 4401 (time=88.02), 0.204126 s/step
# on time step 4421 (time=88.42), 0.203966 s/step
# on time step 4441 (time=88.82), 0.204893 s/step
# on time step 4461 (time=89.22), 0.204225 s/step
# on time step 4481 (time=89.62), 0.207139 s/step
# on time step 4501 (time=90.02), 0.20761 s/step
# field decay(t = 90.16): 0.0009296492585637919 / 0.19075908375899342 = 0.004873420653132924
# on time step 4521 (time=90.42), 0.20701 s/step
# on time step 4541 (time=90.82), 0.205431 s/step
# on time step 4561 (time=91.22), 0.206573 s/step
# on time step 4581 (time=91.62), 0.206913 s/step
# on time step 4601 (time=92.02), 0.208566 s/step
# on time step 4621 (time=92.42), 0.208304 s/step
# on time step 4641 (time=92.82), 0.205884 s/step
# on time step 4661 (time=93.22), 0.204445 s/step
# on time step 4681 (time=93.62), 0.20548 s/step
# on time step 4701 (time=94.02), 0.208106 s/step
# on time step 4721 (time=94.42), 0.206734 s/step
# on time step 4741 (time=94.82), 0.207404 s/step
# on time step 4761 (time=95.22), 0.204723 s/step
# on time step 4781 (time=95.62), 0.206546 s/step
# on time step 4801 (time=96.02), 0.209149 s/step
# on time step 4821 (time=96.42), 0.20969 s/step
# on time step 4841 (time=96.82), 0.207736 s/step
# on time step 4861 (time=97.22), 0.207382 s/step
# on time step 4881 (time=97.62), 0.207118 s/step
# on time step 4901 (time=98.02), 0.204523 s/step
# on time step 4921 (time=98.42), 0.207054 s/step
# on time step 4941 (time=98.82), 0.206606 s/step
# on time step 4961 (time=99.22), 0.203953 s/step
# on time step 4981 (time=99.62), 0.204524 s/step
# on time step 5001 (time=100.02), 0.203942 s/step
# field decay(t = 100.18): 0.00021353010382953711 / 0.19075908375899342 = 0.0011193705674289818
# on time step 5021 (time=100.42), 0.207622 s/step
# on time step 5041 (time=100.82), 0.207958 s/step
# on time step 5061 (time=101.22), 0.207031 s/step
# on time step 5081 (time=101.62), 0.205908 s/step
# on time step 5101 (time=102.02), 0.208578 s/step
# on time step 5121 (time=102.42), 0.210265 s/step
# on time step 5141 (time=102.82), 0.208193 s/step
# on time step 5161 (time=103.22), 0.204061 s/step
# on time step 5181 (time=103.62), 0.204493 s/step
# on time step 5201 (time=104.02), 0.204672 s/step
# on time step 5221 (time=104.42), 0.204917 s/step
# on time step 5241 (time=104.82), 0.206851 s/step
# on time step 5261 (time=105.22), 0.206844 s/step
# on time step 5281 (time=105.62), 0.207611 s/step
# on time step 5301 (time=106.02), 0.208011 s/step
# on time step 5321 (time=106.42), 0.204915 s/step
# on time step 5341 (time=106.82), 0.204343 s/step
# on time step 5361 (time=107.22), 0.206616 s/step
# on time step 5381 (time=107.62), 0.206357 s/step
# on time step 5401 (time=108.02), 0.207193 s/step
# on time step 5421 (time=108.42), 0.207528 s/step
# on time step 5441 (time=108.82), 0.207348 s/step
# on time step 5461 (time=109.22), 0.207365 s/step
# on time step 5481 (time=109.62), 0.207644 s/step
# on time step 5501 (time=110.02), 0.208393 s/step
# field decay(t = 110.2): 1.4381141857641836e-05 / 0.19075908375899342 = 7.538902774250628e-05
# run 0 finished at t = 110.2 (5510 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000430107 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 7.94954 s
# -----------
# on time step 1 (time=0.02), 8.4923 s/step
# on time step 11 (time=0.22), 0.418572 s/step
# on time step 20 (time=0.4), 0.446237 s/step
# on time step 30 (time=0.6), 0.417993 s/step
# on time step 39 (time=0.78), 0.451876 s/step
# on time step 49 (time=0.98), 0.422913 s/step
# on time step 58 (time=1.16), 0.446439 s/step
# on time step 68 (time=1.36), 0.421076 s/step
# on time step 77 (time=1.54), 0.448751 s/step
# on time step 88 (time=1.76), 0.390161 s/step
# on time step 98 (time=1.96), 0.405387 s/step
# on time step 108 (time=2.16), 0.407632 s/step
# on time step 120 (time=2.4), 0.357644 s/step
# on time step 131 (time=2.62), 0.376863 s/step
# on time step 143 (time=2.86), 0.357892 s/step
# on time step 154 (time=3.08), 0.379851 s/step
# on time step 165 (time=3.3), 0.376877 s/step
# on time step 177 (time=3.54), 0.36297 s/step
# on time step 188 (time=3.76), 0.38132 s/step
# on time step 199 (time=3.98), 0.375668 s/step
# on time step 211 (time=4.22), 0.359057 s/step
# on time step 222 (time=4.44), 0.371356 s/step
# on time step 234 (time=4.68), 0.368006 s/step
# on time step 246 (time=4.92), 0.35477 s/step
# on time step 257 (time=5.14), 0.37409 s/step
# on time step 269 (time=5.38), 0.360861 s/step
# on time step 280 (time=5.6), 0.373508 s/step
# on time step 291 (time=5.82), 0.372308 s/step
# on time step 303 (time=6.06), 0.356962 s/step
# on time step 314 (time=6.28), 0.377644 s/step
# on time step 325 (time=6.5), 0.37407 s/step
# on time step 337 (time=6.74), 0.351977 s/step
# on time step 348 (time=6.96), 0.375086 s/step
# on time step 360 (time=7.2), 0.373493 s/step
# on time step 372 (time=7.44), 0.354929 s/step
# on time step 383 (time=7.66), 0.376856 s/step
# on time step 395 (time=7.9), 0.356762 s/step
# on time step 406 (time=8.12), 0.377083 s/step
# on time step 417 (time=8.34), 0.364401 s/step
# on time step 431 (time=8.62), 0.286331 s/step
# on time step 445 (time=8.9), 0.298059 s/step
# on time step 459 (time=9.18), 0.297415 s/step
# on time step 473 (time=9.46), 0.298767 s/step
# on time step 487 (time=9.74), 0.302124 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 504 (time=10.08), 0.246292 s/step
# on time step 521 (time=10.42), 0.245231 s/step
# on time step 539 (time=10.78), 0.229712 s/step
# on time step 557 (time=11.14), 0.229844 s/step
# on time step 575 (time=11.5), 0.222825 s/step
# on time step 591 (time=11.82), 0.263562 s/step
# on time step 605 (time=12.1), 0.293285 s/step
# on time step 619 (time=12.38), 0.290762 s/step
# on time step 633 (time=12.66), 0.303219 s/step
# on time step 647 (time=12.94), 0.300742 s/step
# on time step 661 (time=13.22), 0.302358 s/step
# on time step 675 (time=13.5), 0.292286 s/step
# on time step 689 (time=13.78), 0.289807 s/step
# on time step 703 (time=14.06), 0.291558 s/step
# on time step 718 (time=14.36), 0.278657 s/step
# on time step 732 (time=14.64), 0.292536 s/step
# on time step 746 (time=14.92), 0.294398 s/step
# on time step 760 (time=15.2), 0.294182 s/step
# on time step 774 (time=15.48), 0.294354 s/step
# on time step 789 (time=15.78), 0.281208 s/step
# on time step 806 (time=16.12), 0.236443 s/step
# on time step 825 (time=16.5), 0.221245 s/step
# on time step 844 (time=16.88), 0.22021 s/step
# on time step 863 (time=17.26), 0.217648 s/step
# on time step 882 (time=17.64), 0.224718 s/step
# on time step 901 (time=18.02), 0.218393 s/step
# on time step 920 (time=18.4), 0.21734 s/step
# on time step 938 (time=18.76), 0.227653 s/step
# on time step 957 (time=19.14), 0.219562 s/step
# on time step 975 (time=19.5), 0.223867 s/step
# on time step 990 (time=19.8), 0.286826 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1005 (time=20.1), 0.276559 s/step
# on time step 1019 (time=20.38), 0.290666 s/step
# on time step 1033 (time=20.66), 0.289407 s/step
# on time step 1047 (time=20.94), 0.288971 s/step
# on time step 1062 (time=21.24), 0.286821 s/step
# on time step 1077 (time=21.54), 0.276109 s/step
# on time step 1091 (time=21.82), 0.288261 s/step
# on time step 1105 (time=22.1), 0.288117 s/step
# on time step 1119 (time=22.38), 0.288528 s/step
# on time step 1134 (time=22.68), 0.28705 s/step
# on time step 1149 (time=22.98), 0.275532 s/step
# on time step 1163 (time=23.26), 0.289535 s/step
# on time step 1177 (time=23.54), 0.291236 s/step
# on time step 1191 (time=23.82), 0.290979 s/step
# on time step 1206 (time=24.12), 0.290287 s/step
# on time step 1221 (time=24.42), 0.279016 s/step
# on time step 1235 (time=24.7), 0.290696 s/step
# on time step 1249 (time=24.98), 0.290565 s/step
# on time step 1263 (time=25.26), 0.291482 s/step
# on time step 1278 (time=25.56), 0.289563 s/step
# on time step 1293 (time=25.86), 0.278211 s/step
# on time step 1307 (time=26.14), 0.288227 s/step
# on time step 1321 (time=26.42), 0.288458 s/step
# on time step 1335 (time=26.7), 0.288823 s/step
# on time step 1350 (time=27), 0.287291 s/step
# on time step 1365 (time=27.3), 0.274363 s/step
# on time step 1379 (time=27.58), 0.288366 s/step
# on time step 1393 (time=27.86), 0.288017 s/step
# on time step 1407 (time=28.14), 0.288244 s/step
# on time step 1422 (time=28.44), 0.291876 s/step
# on time step 1435 (time=28.7), 0.311002 s/step
# on time step 1449 (time=28.98), 0.297824 s/step
# on time step 1462 (time=29.24), 0.312671 s/step
# on time step 1476 (time=29.52), 0.296958 s/step
# on time step 1491 (time=29.82), 0.282108 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000699043 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 60.6786% done, 2.59212 s remaining
# subpixel-averaging is 59.6843% done, 2.70233 s remaining
# subpixel-averaging is 60.1468% done, 2.65066 s remaining
# time for set_epsilon = 33.5096 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.8,2.8,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 8.33518 s/step
# on time step 13 (time=0.26), 0.339052 s/step
# on time step 25 (time=0.5), 0.357472 s/step
# on time step 37 (time=0.74), 0.357689 s/step
# on time step 49 (time=0.98), 0.33798 s/step
# on time step 61 (time=1.22), 0.357548 s/step
# on time step 73 (time=1.46), 0.357264 s/step
# on time step 85 (time=1.7), 0.338941 s/step
# on time step 97 (time=1.94), 0.354729 s/step
# on time step 109 (time=2.18), 0.356918 s/step
# on time step 121 (time=2.42), 0.338809 s/step
# on time step 133 (time=2.66), 0.358109 s/step
# on time step 145 (time=2.9), 0.357218 s/step
# on time step 157 (time=3.14), 0.338604 s/step
# on time step 169 (time=3.38), 0.35698 s/step
# on time step 181 (time=3.62), 0.35662 s/step
# on time step 193 (time=3.86), 0.339506 s/step
# on time step 205 (time=4.1), 0.360655 s/step
# on time step 216 (time=4.32), 0.364207 s/step
# on time step 228 (time=4.56), 0.344094 s/step
# on time step 240 (time=4.8), 0.359747 s/step
# on time step 252 (time=5.04), 0.358522 s/step
# on time step 264 (time=5.28), 0.342594 s/step
# on time step 275 (time=5.5), 0.36403 s/step
# on time step 287 (time=5.74), 0.342383 s/step
# on time step 299 (time=5.98), 0.360927 s/step
# on time step 310 (time=6.2), 0.365349 s/step
# on time step 322 (time=6.44), 0.343011 s/step
# on time step 334 (time=6.68), 0.361169 s/step
# on time step 346 (time=6.92), 0.36101 s/step
# on time step 358 (time=7.16), 0.341913 s/step
# on time step 369 (time=7.38), 0.364525 s/step
# on time step 381 (time=7.62), 0.360629 s/step
# on time step 393 (time=7.86), 0.342823 s/step
# on time step 404 (time=8.08), 0.364674 s/step
# on time step 415 (time=8.3), 0.363698 s/step
# on time step 427 (time=8.54), 0.342176 s/step
# on time step 438 (time=8.76), 0.364773 s/step
# on time step 450 (time=9), 0.361702 s/step
# on time step 462 (time=9.24), 0.345511 s/step
# on time step 473 (time=9.46), 0.365115 s/step
# on time step 485 (time=9.7), 0.341389 s/step
# on time step 496 (time=9.92), 0.36474 s/step
# field decay(t = 10.02): 2.6159994876419458e-05 / 2.6159994876419458e-05 = 1.0
# on time step 508 (time=10.16), 0.361472 s/step
# on time step 520 (time=10.4), 0.347576 s/step
# on time step 532 (time=10.64), 0.35986 s/step
# on time step 544 (time=10.88), 0.358597 s/step
# on time step 556 (time=11.12), 0.339149 s/step
# on time step 568 (time=11.36), 0.357405 s/step
# on time step 580 (time=11.6), 0.358989 s/step
# on time step 592 (time=11.84), 0.340695 s/step
# on time step 604 (time=12.08), 0.359193 s/step
# on time step 616 (time=12.32), 0.358003 s/step
# on time step 628 (time=12.56), 0.341727 s/step
# on time step 639 (time=12.78), 0.367297 s/step
# on time step 650 (time=13), 0.364223 s/step
# on time step 662 (time=13.24), 0.342955 s/step
# on time step 673 (time=13.46), 0.365622 s/step
# on time step 685 (time=13.7), 0.361084 s/step
# on time step 697 (time=13.94), 0.33912 s/step
# on time step 709 (time=14.18), 0.357771 s/step
# on time step 721 (time=14.42), 0.355947 s/step
# on time step 733 (time=14.66), 0.342817 s/step
# on time step 745 (time=14.9), 0.358527 s/step
# on time step 757 (time=15.14), 0.356441 s/step
# on time step 769 (time=15.38), 0.338083 s/step
# on time step 781 (time=15.62), 0.355984 s/step
# on time step 792 (time=15.84), 0.367969 s/step
# on time step 803 (time=16.06), 0.385924 s/step
# on time step 814 (time=16.28), 0.386392 s/step
# on time step 825 (time=16.5), 0.37294 s/step
# on time step 836 (time=16.72), 0.378134 s/step
# on time step 848 (time=16.96), 0.36075 s/step
# on time step 860 (time=17.2), 0.340304 s/step
# on time step 872 (time=17.44), 0.358427 s/step
# on time step 884 (time=17.68), 0.353423 s/step
# on time step 896 (time=17.92), 0.358752 s/step
# on time step 907 (time=18.14), 0.366366 s/step
# on time step 918 (time=18.36), 0.395087 s/step
# on time step 930 (time=18.6), 0.355779 s/step
# on time step 942 (time=18.84), 0.354902 s/step
# on time step 954 (time=19.08), 0.347685 s/step
# on time step 967 (time=19.34), 0.329962 s/step
# on time step 979 (time=19.58), 0.348714 s/step
# on time step 991 (time=19.82), 0.348131 s/step
# field decay(t = 20.04): 0.032295854442639944 / 0.032295854442639944 = 1.0
# on time step 1003 (time=20.06), 0.34026 s/step
# on time step 1014 (time=20.28), 0.381382 s/step
# on time step 1026 (time=20.52), 0.370412 s/step
# on time step 1038 (time=20.76), 0.336461 s/step
# on time step 1050 (time=21), 0.35138 s/step
# on time step 1062 (time=21.24), 0.359863 s/step
# on time step 1074 (time=21.48), 0.339494 s/step
# on time step 1085 (time=21.7), 0.385723 s/step
# on time step 1097 (time=21.94), 0.350283 s/step
# on time step 1108 (time=22.16), 0.379515 s/step
# on time step 1119 (time=22.38), 0.373076 s/step
# on time step 1131 (time=22.62), 0.340613 s/step
# on time step 1142 (time=22.84), 0.386086 s/step
# on time step 1154 (time=23.08), 0.351951 s/step
# on time step 1167 (time=23.34), 0.332079 s/step
# on time step 1179 (time=23.58), 0.350133 s/step
# on time step 1191 (time=23.82), 0.350832 s/step
# on time step 1204 (time=24.08), 0.333189 s/step
# on time step 1216 (time=24.32), 0.350624 s/step
# on time step 1228 (time=24.56), 0.351233 s/step
# on time step 1241 (time=24.82), 0.33082 s/step
# on time step 1253 (time=25.06), 0.348796 s/step
# on time step 1265 (time=25.3), 0.352209 s/step
# on time step 1277 (time=25.54), 0.356545 s/step
# on time step 1288 (time=25.76), 0.369804 s/step
# on time step 1299 (time=25.98), 0.368167 s/step
# on time step 1311 (time=26.22), 0.358912 s/step
# on time step 1321 (time=26.42), 0.403888 s/step
# on time step 1332 (time=26.64), 0.371501 s/step
# on time step 1343 (time=26.86), 0.369866 s/step
# on time step 1353 (time=27.06), 0.415702 s/step
# on time step 1364 (time=27.28), 0.391826 s/step
# on time step 1375 (time=27.5), 0.363757 s/step
# on time step 1387 (time=27.74), 0.348772 s/step
# on time step 1400 (time=28), 0.329389 s/step
# on time step 1412 (time=28.24), 0.350968 s/step
# on time step 1424 (time=28.48), 0.349506 s/step
# on time step 1437 (time=28.74), 0.331504 s/step
# on time step 1449 (time=28.98), 0.351479 s/step
# on time step 1461 (time=29.22), 0.351345 s/step
# on time step 1474 (time=29.48), 0.332949 s/step
# on time step 1486 (time=29.72), 0.351942 s/step
# on time step 1498 (time=29.96), 0.354952 s/step
# field decay(t = 30.060000000000002): 0.0022044447068275737 / 0.032295854442639944 = 0.0682578227104301
# on time step 1510 (time=30.2), 0.333585 s/step
# on time step 1522 (time=30.44), 0.352515 s/step
# on time step 1534 (time=30.68), 0.350775 s/step
# on time step 1547 (time=30.94), 0.331697 s/step
# on time step 1559 (time=31.18), 0.351053 s/step
# on time step 1571 (time=31.42), 0.351553 s/step
# on time step 1583 (time=31.66), 0.334577 s/step
# on time step 1595 (time=31.9), 0.349733 s/step
# on time step 1607 (time=32.14), 0.348609 s/step
# on time step 1620 (time=32.4), 0.345855 s/step
# on time step 1633 (time=32.66), 0.328469 s/step
# on time step 1645 (time=32.9), 0.348023 s/step
# on time step 1657 (time=33.14), 0.347958 s/step
# on time step 1670 (time=33.4), 0.330144 s/step
# on time step 1682 (time=33.64), 0.351095 s/step
# on time step 1694 (time=33.88), 0.347923 s/step
# on time step 1707 (time=34.14), 0.330264 s/step
# on time step 1719 (time=34.38), 0.346224 s/step
# on time step 1731 (time=34.62), 0.348647 s/step
# on time step 1744 (time=34.88), 0.328727 s/step
# on time step 1756 (time=35.12), 0.346419 s/step
# on time step 1768 (time=35.36), 0.348215 s/step
# on time step 1781 (time=35.62), 0.328406 s/step
# on time step 1793 (time=35.86), 0.348779 s/step
# on time step 1805 (time=36.1), 0.348717 s/step
# on time step 1818 (time=36.36), 0.349263 s/step
# on time step 1831 (time=36.62), 0.331498 s/step
# on time step 1843 (time=36.86), 0.350592 s/step
# on time step 1855 (time=37.1), 0.35061 s/step
# on time step 1868 (time=37.36), 0.332217 s/step
# on time step 1880 (time=37.6), 0.349589 s/step
# on time step 1892 (time=37.84), 0.349386 s/step
# on time step 1905 (time=38.1), 0.332553 s/step
# on time step 1917 (time=38.34), 0.350113 s/step
# on time step 1929 (time=38.58), 0.350531 s/step
# on time step 1942 (time=38.84), 0.331807 s/step
# on time step 1954 (time=39.08), 0.351294 s/step
# on time step 1966 (time=39.32), 0.351296 s/step
# on time step 1979 (time=39.58), 0.332115 s/step
# on time step 1991 (time=39.82), 0.349142 s/step
# field decay(t = 40.06): 0.0005399602997693407 / 0.032295854442639944 = 0.01671918297527486
# on time step 2003 (time=40.06), 0.350367 s/step
# on time step 2016 (time=40.32), 0.350012 s/step
# on time step 2029 (time=40.58), 0.3316 s/step
# on time step 2041 (time=40.82), 0.34976 s/step
# on time step 2053 (time=41.06), 0.351697 s/step
# on time step 2066 (time=41.32), 0.33203 s/step
# on time step 2078 (time=41.56), 0.351031 s/step
# on time step 2090 (time=41.8), 0.35138 s/step
# on time step 2103 (time=42.06), 0.330806 s/step
# on time step 2115 (time=42.3), 0.350474 s/step
# on time step 2127 (time=42.54), 0.350889 s/step
# on time step 2140 (time=42.8), 0.331641 s/step
# on time step 2152 (time=43.04), 0.352731 s/step
# on time step 2164 (time=43.28), 0.352877 s/step
# on time step 2177 (time=43.54), 0.329579 s/step
# on time step 2189 (time=43.78), 0.351297 s/step
# on time step 2201 (time=44.02), 0.350885 s/step
# on time step 2214 (time=44.28), 0.349585 s/step
# on time step 2227 (time=44.54), 0.331969 s/step
# on time step 2239 (time=44.78), 0.352009 s/step
# on time step 2251 (time=45.02), 0.350833 s/step
# on time step 2264 (time=45.28), 0.332127 s/step
# on time step 2276 (time=45.52), 0.351754 s/step
# on time step 2288 (time=45.76), 0.352229 s/step
# on time step 2301 (time=46.02), 0.330953 s/step
# on time step 2313 (time=46.26), 0.350231 s/step
# on time step 2325 (time=46.5), 0.350188 s/step
# on time step 2338 (time=46.76), 0.333302 s/step
# on time step 2350 (time=47), 0.351704 s/step
# on time step 2362 (time=47.24), 0.351761 s/step
# on time step 2375 (time=47.5), 0.331503 s/step
# on time step 2387 (time=47.74), 0.350979 s/step
# on time step 2399 (time=47.98), 0.351887 s/step
# on time step 2412 (time=48.24), 0.346957 s/step
# on time step 2425 (time=48.5), 0.328192 s/step
# on time step 2437 (time=48.74), 0.348962 s/step
# on time step 2449 (time=48.98), 0.350671 s/step
# on time step 2462 (time=49.24), 0.331275 s/step
# on time step 2474 (time=49.48), 0.352059 s/step
# on time step 2486 (time=49.72), 0.351456 s/step
# on time step 2499 (time=49.98), 0.33291 s/step
# field decay(t = 50.08): 0.0009253350839806123 / 0.032295854442639944 = 0.028651822345313153
# on time step 2511 (time=50.22), 0.352188 s/step
# on time step 2523 (time=50.46), 0.351458 s/step
# on time step 2535 (time=50.7), 0.333676 s/step
# on time step 2547 (time=50.94), 0.350851 s/step
# on time step 2559 (time=51.18), 0.348654 s/step
# on time step 2572 (time=51.44), 0.329623 s/step
# on time step 2584 (time=51.68), 0.348615 s/step
# on time step 2596 (time=51.92), 0.351408 s/step
# on time step 2609 (time=52.18), 0.332188 s/step
# on time step 2621 (time=52.42), 0.353064 s/step
# on time step 2633 (time=52.66), 0.353978 s/step
# on time step 2645 (time=52.9), 0.333768 s/step
# on time step 2657 (time=53.14), 0.351137 s/step
# on time step 2669 (time=53.38), 0.351632 s/step
# on time step 2681 (time=53.62), 0.333523 s/step
# on time step 2693 (time=53.86), 0.352134 s/step
# on time step 2705 (time=54.1), 0.353037 s/step
# on time step 2718 (time=54.36), 0.349129 s/step
# on time step 2731 (time=54.62), 0.327957 s/step
# on time step 2743 (time=54.86), 0.348333 s/step
# on time step 2755 (time=55.1), 0.348849 s/step
# on time step 2768 (time=55.36), 0.329764 s/step
# on time step 2780 (time=55.6), 0.35061 s/step
# on time step 2792 (time=55.84), 0.35003 s/step
# on time step 2805 (time=56.1), 0.331792 s/step
# on time step 2817 (time=56.34), 0.347817 s/step
# on time step 2829 (time=56.58), 0.347787 s/step
# on time step 2842 (time=56.84), 0.329897 s/step
# on time step 2854 (time=57.08), 0.350084 s/step
# on time step 2866 (time=57.32), 0.349184 s/step
# on time step 2879 (time=57.58), 0.331012 s/step
# on time step 2891 (time=57.82), 0.350587 s/step
# on time step 2903 (time=58.06), 0.350133 s/step
# on time step 2916 (time=58.32), 0.348354 s/step
# on time step 2929 (time=58.58), 0.332991 s/step
# on time step 2941 (time=58.82), 0.351477 s/step
# on time step 2953 (time=59.06), 0.350269 s/step
# on time step 2966 (time=59.32), 0.331279 s/step
# on time step 2978 (time=59.56), 0.351269 s/step
# on time step 2990 (time=59.8), 0.350486 s/step
# on time step 3003 (time=60.06), 0.332008 s/step
# field decay(t = 60.1): 0.00015211879174570973 / 0.032295854442639944 = 0.004710164644068639
# on time step 3015 (time=60.3), 0.349137 s/step
# on time step 3027 (time=60.54), 0.348437 s/step
# on time step 3040 (time=60.8), 0.330842 s/step
# on time step 3052 (time=61.04), 0.348979 s/step
# on time step 3064 (time=61.28), 0.348413 s/step
# on time step 3077 (time=61.54), 0.332443 s/step
# on time step 3089 (time=61.78), 0.34941 s/step
# on time step 3101 (time=62.02), 0.349584 s/step
# on time step 3114 (time=62.28), 0.346819 s/step
# on time step 3127 (time=62.54), 0.330995 s/step
# on time step 3139 (time=62.78), 0.350021 s/step
# on time step 3151 (time=63.02), 0.34915 s/step
# on time step 3164 (time=63.28), 0.332589 s/step
# on time step 3176 (time=63.52), 0.351036 s/step
# on time step 3188 (time=63.76), 0.351355 s/step
# on time step 3201 (time=64.02), 0.328593 s/step
# on time step 3213 (time=64.26), 0.34806 s/step
# on time step 3225 (time=64.5), 0.348654 s/step
# on time step 3238 (time=64.76), 0.329563 s/step
# on time step 3250 (time=65), 0.349305 s/step
# on time step 3262 (time=65.24), 0.351566 s/step
# on time step 3275 (time=65.5), 0.33146 s/step
# on time step 3287 (time=65.74), 0.349936 s/step
# on time step 3299 (time=65.98), 0.350064 s/step
# on time step 3312 (time=66.24), 0.348201 s/step
# on time step 3325 (time=66.5), 0.331953 s/step
# on time step 3337 (time=66.74), 0.352551 s/step
# on time step 3349 (time=66.98), 0.35141 s/step
# on time step 3362 (time=67.24), 0.33288 s/step
# on time step 3374 (time=67.48), 0.351046 s/step
# on time step 3386 (time=67.72), 0.347378 s/step
# on time step 3399 (time=67.98), 0.328259 s/step
# on time step 3411 (time=68.22), 0.348532 s/step
# on time step 3423 (time=68.46), 0.348127 s/step
# on time step 3436 (time=68.72), 0.330185 s/step
# on time step 3448 (time=68.96), 0.349076 s/step
# on time step 3460 (time=69.2), 0.351217 s/step
# on time step 3473 (time=69.46), 0.331304 s/step
# on time step 3485 (time=69.7), 0.351483 s/step
# on time step 3497 (time=69.94), 0.351075 s/step
# field decay(t = 70.12): 0.00016091628229198147 / 0.032295854442639944 = 0.004982567734127668
# on time step 3510 (time=70.2), 0.348855 s/step
# on time step 3523 (time=70.46), 0.332719 s/step
# on time step 3535 (time=70.7), 0.34705 s/step
# on time step 3547 (time=70.94), 0.348122 s/step
# on time step 3560 (time=71.2), 0.328602 s/step
# on time step 3572 (time=71.44), 0.350692 s/step
# on time step 3584 (time=71.68), 0.349838 s/step
# on time step 3597 (time=71.94), 0.333276 s/step
# on time step 3609 (time=72.18), 0.35023 s/step
# on time step 3621 (time=72.42), 0.35161 s/step
# on time step 3634 (time=72.68), 0.33309 s/step
# on time step 3646 (time=72.92), 0.352947 s/step
# on time step 3658 (time=73.16), 0.351358 s/step
# on time step 3670 (time=73.4), 0.333681 s/step
# on time step 3682 (time=73.64), 0.351108 s/step
# on time step 3694 (time=73.88), 0.350937 s/step
# on time step 3707 (time=74.14), 0.33032 s/step
# on time step 3719 (time=74.38), 0.348577 s/step
# on time step 3731 (time=74.62), 0.347663 s/step
# on time step 3744 (time=74.88), 0.347895 s/step
# on time step 3757 (time=75.14), 0.328632 s/step
# on time step 3769 (time=75.38), 0.348692 s/step
# on time step 3781 (time=75.62), 0.347692 s/step
# on time step 3794 (time=75.88), 0.329627 s/step
# on time step 3806 (time=76.12), 0.347881 s/step
# on time step 3818 (time=76.36), 0.352024 s/step
# on time step 3831 (time=76.62), 0.333286 s/step
# on time step 3843 (time=76.86), 0.349013 s/step
# on time step 3855 (time=77.1), 0.35098 s/step
# on time step 3868 (time=77.36), 0.332555 s/step
# on time step 3880 (time=77.6), 0.35602 s/step
# on time step 3892 (time=77.84), 0.351902 s/step
# on time step 3905 (time=78.1), 0.328398 s/step
# on time step 3917 (time=78.34), 0.347206 s/step
# on time step 3929 (time=78.58), 0.349539 s/step
# on time step 3942 (time=78.84), 0.348414 s/step
# on time step 3955 (time=79.1), 0.33082 s/step
# on time step 3967 (time=79.34), 0.352086 s/step
# on time step 3979 (time=79.58), 0.350513 s/step
# on time step 3992 (time=79.84), 0.32981 s/step
# on time step 4004 (time=80.08), 0.349947 s/step
# field decay(t = 80.14): 4.537904343524382e-05 / 0.032295854442639944 = 0.0014051042840758613
# on time step 4016 (time=80.32), 0.352723 s/step
# on time step 4029 (time=80.58), 0.333064 s/step
# on time step 4041 (time=80.82), 0.352202 s/step
# on time step 4053 (time=81.06), 0.35322 s/step
# on time step 4066 (time=81.32), 0.330873 s/step
# on time step 4078 (time=81.56), 0.351397 s/step
# on time step 4092 (time=81.84), 0.292531 s/step
# on time step 4108 (time=82.16), 0.25896 s/step
# on time step 4124 (time=82.48), 0.255903 s/step
# on time step 4140 (time=82.8), 0.255868 s/step
# on time step 4157 (time=83.14), 0.244505 s/step
# on time step 4173 (time=83.46), 0.255852 s/step
# on time step 4189 (time=83.78), 0.255387 s/step
# on time step 4205 (time=84.1), 0.255057 s/step
# on time step 4221 (time=84.42), 0.253232 s/step
# on time step 4237 (time=84.74), 0.25317 s/step
# on time step 4253 (time=85.06), 0.252803 s/step
# on time step 4269 (time=85.38), 0.252954 s/step
# on time step 4285 (time=85.7), 0.253155 s/step
# on time step 4302 (time=86.04), 0.252935 s/step
# on time step 4319 (time=86.38), 0.243083 s/step
# on time step 4335 (time=86.7), 0.252259 s/step
# on time step 4351 (time=87.02), 0.25325 s/step
# on time step 4367 (time=87.34), 0.253328 s/step
# on time step 4383 (time=87.66), 0.253108 s/step
# on time step 4399 (time=87.98), 0.25367 s/step
# on time step 4415 (time=88.3), 0.25325 s/step
# on time step 4431 (time=88.62), 0.252745 s/step
# on time step 4447 (time=88.94), 0.252893 s/step
# on time step 4464 (time=89.28), 0.252037 s/step
# on time step 4481 (time=89.62), 0.242122 s/step
# on time step 4497 (time=89.94), 0.252763 s/step
# field decay(t = 90.16): 1.555382731135336e-05 / 0.032295854442639944 = 0.00048160445294854234
# run 0 finished at t = 90.16 (4508 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])
if mp.am_master():
    plt.figure(dpi=300)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical efficiency (in-pixel)")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")
