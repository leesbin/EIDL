# %%
# CIS 3D color router verification
# Find OE

# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

design_dir = "./CIS_result_9_GB/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 2

Air = mp.Medium(index=1.0)
SiN = mp.Medium(epsilon=4)
SiO2 = mp.Medium(epsilon=2.1)
TiO2 = mp.Medium(epsilon=7)
SiPD = mp.Medium(epsilon=11.8)

# 설계 공간
design_region_width_x = 2.8 # 디자인 영역 x
design_region_width_y = 2.8 # 디자인 영역 y
design_region_height = 2 # 디자인 영역 높이 z

# 해상도 및 사이즈 설정
resolution = 25
gapop = 1 ####################################################################################################
air_gap = 0
dti = 0.4
subpixelsize = design_region_width_x/2 - dti
if gapop == 1:
    air_gap = dti/2
PDsize = 2
Lpml = 1 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 1


# 전체 공간
Sx = design_region_width_x * 3
Sy = design_region_width_y * 3
Sz = PDsize + design_region_height + Sourcespace + Lpml
cell_size = mp.Vector3(Sx + 2*Lpml, Sy + 2*Lpml, Sz)

# structure load
structure_weight = np.loadtxt('lastdesign.txt')


# 파장, 주파수 설정
wavelengths = np.linspace(0.40*um_scale, 0.70*um_scale, 31) 
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# constraint 설정
minimum_length = 0.025  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

# source 설정

fcen_red = 1/(0.65*um_scale)
fwidth_red = 1 /(0.60 * um_scale) - 1/(0.70 * um_scale)

fcen_green = 1/(0.55*um_scale)
fwidth_green = 1 /(0.50 * um_scale) - 1/(0.60 * um_scale)

fcen_blue = 1/(0.45*um_scale)
fwidth_blue = 1 /(0.40 * um_scale) - 1/(0.50 * um_scale)

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth= 2 * 2.355 * fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=2 * 2.355 *fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=2 * 2.355 *fwidth_blue, is_integrated=True)

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)

source = [mp.Source(src_0, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_0, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_1, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_1, component=mp.Ey, size=source_size, center=source_center,),
            mp.Source(src_2, component=mp.Ex, size=source_size, center=source_center,),mp.Source(src_2, component=mp.Ey, size=source_size, center=source_center,)]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * design_region_width_x)) + 1
Ny = int(round(design_region_resolution * design_region_width_y)) + 1
Nz = int(round(design_region_resolution * design_region_height)) + 1

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), SiO2, TiO2, grid_type="U_MEAN")

design_variables.update_weights(structure_weight)

design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x-air_gap*2, design_region_width_y-air_gap*2, design_region_height),
    ),
)

# design region과 동일한 size의 Block 생성
geometry = [
    # design region
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(0, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3, -Sy/3, Sz / 2 - Lpml - Sourcespace - design_region_height/2), size=design_region.size, material=design_variables
    ),
    
    # SiO2
    mp.Block(
        center=mp.Vector3(0, 0, -Sz/2 + PDsize/2), size=mp.Vector3(Sx, Sy, PDsize), material=SiO2
    ),
    
    # DTI가 있을 경우 사용
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3+Sx/12, -Sy/3-Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
    mp.Block(
        center=mp.Vector3(-Sx/3-Sx/12, -Sy/3+Sy/12, -Sz/2 + PDsize/2), size=mp.Vector3(subpixelsize, subpixelsize,  PDsize), material=SiPD
    ),
]

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %%
###############################################################################################################################
# ## 2. Optimization Environment


# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_1, monitor_size_1 = mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_2, monitor_size_2 = mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 
monitor_position_3, monitor_size_3 = mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), mp.Vector3(0.01,0.01,0) 

# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)

FourierFields_1_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ex,yee_grid=True)

FourierFields_2_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ex,yee_grid=True)

FourierFields_3_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ex,yee_grid=True)

FourierFields_0_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ey,yee_grid=True)

FourierFields_1_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_1,size=monitor_size_1),mp.Ey,yee_grid=True)

FourierFields_2_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_2,size=monitor_size_2),mp.Ey,yee_grid=True)

FourierFields_3_y = mpa.FourierFields(sim,mp.Volume(center=monitor_position_3,size=monitor_size_3),mp.Ey,yee_grid=True)

ob_list = [FourierFields_0_x, FourierFields_0_y, FourierFields_1_x,FourierFields_1_y, FourierFields_2_x, FourierFields_2_y, FourierFields_3_x, FourierFields_3_y]



# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields_0_x, fields_0_y, fields_1_x, fields_1_y, fields_2_x, fields_2_y, fields_3_x, fields_3_y):
    red = npa.sum(npa.abs(fields_1_x[21:30,1]) ** 2)  + npa.sum(npa.abs(fields_1_y[21:30,1]) ** 2)
    green = npa.sum(npa.abs(fields_0_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_0_y[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_x[11:20,1]) ** 2) + npa.sum(npa.abs(fields_2_y[11:20,1]) ** 2)
    blue = npa.sum(npa.abs(fields_3_x[1:10,1]) ** 2) + npa.sum(npa.abs(fields_3_y[1:10,1]) ** 2)
    bluefactor = 4
    return bluefactor * blue + green + red

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# %%
###############################################################################################################################
# ## 3. Design plot

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
plt.savefig(design_dir+"Lastdesignxy.png")
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
plt.savefig(design_dir+"Lastdesignxz.png")

###############################################################################################################################
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
beam_x0 = mp.Vector3(0, 0, Sourcespace/2)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1.4  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

# %%
###############################################################################################################################
# ## 4. DFT fields

# blue pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[5], fwidth=fwidth_blue, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[5], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

Ex_Namei="Ex_b_field"
Ey_Namei="Ey_b_field"
Ez_Namei="Ez_b_field"

Hx_Namei="Hx_b_field"
Hy_Namei="Hy_b_field"
Hz_Namei="Hz_b_field"

pt = mp.Vector3(0, 0, -Sz/2 + PDsize  - 0.5/resolution) #pt는 transmitted flux region과 동일

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00107884 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.8709% done, 1.56587 s remaining
# subpixel-averaging is 69.9978% done, 1.71455 s remaining
# subpixel-averaging is 67.2229% done, 1.95051 s remaining
# time for set_epsilon = 31.0873 s
# -----------
# on time step 1 (time=0.02), 8.10965 s/step
# on time step 23 (time=0.46), 0.189692 s/step
# on time step 44 (time=0.88), 0.191416 s/step
# on time step 66 (time=1.32), 0.188026 s/step
# on time step 87 (time=1.74), 0.192829 s/step
# on time step 109 (time=2.18), 0.189623 s/step
# on time step 131 (time=2.62), 0.189285 s/step
# on time step 152 (time=3.04), 0.190859 s/step
# on time step 173 (time=3.46), 0.19942 s/step
# on time step 194 (time=3.88), 0.194369 s/step
# on time step 216 (time=4.32), 0.189675 s/step
# on time step 237 (time=4.74), 0.191363 s/step
# on time step 258 (time=5.16), 0.19205 s/step
# on time step 279 (time=5.58), 0.192326 s/step
# on time step 300 (time=6), 0.194423 s/step
# on time step 321 (time=6.42), 0.199559 s/step
# on time step 343 (time=6.86), 0.188373 s/step
# on time step 364 (time=7.28), 0.1909 s/step
# on time step 386 (time=7.72), 0.186584 s/step
# on time step 407 (time=8.14), 0.193047 s/step
# on time step 429 (time=8.58), 0.189632 s/step
# on time step 451 (time=9.02), 0.189363 s/step
# on time step 472 (time=9.44), 0.190812 s/step
# on time step 494 (time=9.88), 0.189468 s/step
# field decay(t = 10.02): 2.8666625570397393e-09 / 2.8666625570397393e-09 = 1.0
# on time step 515 (time=10.3), 0.191644 s/step
# on time step 536 (time=10.72), 0.19106 s/step
# on time step 558 (time=11.16), 0.187362 s/step
# on time step 580 (time=11.6), 0.190424 s/step
# on time step 602 (time=12.04), 0.189537 s/step
# on time step 623 (time=12.46), 0.1909 s/step
# on time step 645 (time=12.9), 0.189402 s/step
# on time step 666 (time=13.32), 0.191851 s/step
# on time step 687 (time=13.74), 0.190673 s/step
# on time step 709 (time=14.18), 0.18999 s/step
# on time step 730 (time=14.6), 0.191752 s/step
# on time step 752 (time=15.04), 0.189431 s/step
# on time step 774 (time=15.48), 0.189583 s/step
# on time step 795 (time=15.9), 0.191526 s/step
# on time step 817 (time=16.34), 0.189325 s/step
# on time step 838 (time=16.76), 0.19325 s/step
# on time step 859 (time=17.18), 0.196158 s/step
# on time step 880 (time=17.6), 0.199012 s/step
# on time step 900 (time=18), 0.20259 s/step
# on time step 920 (time=18.4), 0.203938 s/step
# on time step 942 (time=18.84), 0.184607 s/step
# on time step 964 (time=19.28), 0.183432 s/step
# on time step 986 (time=19.72), 0.182565 s/step
# field decay(t = 20.04): 0.0003410963964221213 / 0.0003410963964221213 = 1.0
# on time step 1008 (time=20.16), 0.183665 s/step
# on time step 1030 (time=20.6), 0.18195 s/step
# on time step 1052 (time=21.04), 0.184956 s/step
# on time step 1075 (time=21.5), 0.181448 s/step
# on time step 1097 (time=21.94), 0.18292 s/step
# on time step 1119 (time=22.38), 0.182672 s/step
# on time step 1141 (time=22.82), 0.183587 s/step
# on time step 1163 (time=23.26), 0.188173 s/step
# on time step 1184 (time=23.68), 0.190503 s/step
# on time step 1206 (time=24.12), 0.186506 s/step
# on time step 1228 (time=24.56), 0.189872 s/step
# on time step 1250 (time=25), 0.18445 s/step
# on time step 1272 (time=25.44), 0.182265 s/step
# on time step 1293 (time=25.86), 0.194695 s/step
# on time step 1313 (time=26.26), 0.20412 s/step
# on time step 1334 (time=26.68), 0.195351 s/step
# on time step 1356 (time=27.12), 0.188104 s/step
# on time step 1378 (time=27.56), 0.18352 s/step
# on time step 1400 (time=28), 0.182251 s/step
# on time step 1422 (time=28.44), 0.187806 s/step
# on time step 1443 (time=28.86), 0.19234 s/step
# on time step 1464 (time=29.28), 0.195494 s/step
# on time step 1485 (time=29.7), 0.19879 s/step
# field decay(t = 30.060000000000002): 0.02742703043991048 / 0.02742703043991048 = 1.0
# on time step 1505 (time=30.1), 0.203187 s/step
# on time step 1527 (time=30.54), 0.188986 s/step
# on time step 1549 (time=30.98), 0.185123 s/step
# on time step 1571 (time=31.42), 0.182044 s/step
# on time step 1593 (time=31.86), 0.184344 s/step
# on time step 1615 (time=32.3), 0.182228 s/step
# on time step 1637 (time=32.74), 0.182158 s/step
# on time step 1660 (time=33.2), 0.181713 s/step
# on time step 1682 (time=33.64), 0.183255 s/step
# on time step 1703 (time=34.06), 0.194435 s/step
# on time step 1724 (time=34.48), 0.190604 s/step
# on time step 1745 (time=34.9), 0.195411 s/step
# on time step 1766 (time=35.32), 0.193615 s/step
# on time step 1788 (time=35.76), 0.18942 s/step
# on time step 1810 (time=36.2), 0.186781 s/step
# on time step 1831 (time=36.62), 0.192931 s/step
# on time step 1853 (time=37.06), 0.182892 s/step
# on time step 1875 (time=37.5), 0.182855 s/step
# on time step 1897 (time=37.94), 0.188032 s/step
# on time step 1919 (time=38.38), 0.188709 s/step
# on time step 1941 (time=38.82), 0.182365 s/step
# on time step 1963 (time=39.26), 0.182205 s/step
# on time step 1986 (time=39.72), 0.180295 s/step
# field decay(t = 40.06): 0.02773241256766784 / 0.02773241256766784 = 1.0
# on time step 2009 (time=40.18), 0.181659 s/step
# on time step 2031 (time=40.62), 0.182619 s/step
# on time step 2054 (time=41.08), 0.18086 s/step
# on time step 2077 (time=41.54), 0.181473 s/step
# on time step 2100 (time=42), 0.181559 s/step
# on time step 2122 (time=42.44), 0.189761 s/step
# on time step 2144 (time=42.88), 0.183059 s/step
# on time step 2166 (time=43.32), 0.182937 s/step
# on time step 2187 (time=43.74), 0.199124 s/step
# on time step 2207 (time=44.14), 0.208049 s/step
# on time step 2228 (time=44.56), 0.192978 s/step
# on time step 2249 (time=44.98), 0.191403 s/step
# on time step 2269 (time=45.38), 0.206193 s/step
# on time step 2290 (time=45.8), 0.197434 s/step
# on time step 2310 (time=46.2), 0.205742 s/step
# on time step 2331 (time=46.62), 0.191189 s/step
# on time step 2352 (time=47.04), 0.196519 s/step
# on time step 2373 (time=47.46), 0.192897 s/step
# on time step 2395 (time=47.9), 0.188363 s/step
# on time step 2417 (time=48.34), 0.185774 s/step
# on time step 2439 (time=48.78), 0.189131 s/step
# on time step 2460 (time=49.2), 0.19427 s/step
# on time step 2481 (time=49.62), 0.193209 s/step
# on time step 2503 (time=50.06), 0.190111 s/step
# field decay(t = 50.08): 0.0024271348815971565 / 0.02773241256766784 = 0.08751978846683033
# on time step 2524 (time=50.48), 0.192677 s/step
# on time step 2545 (time=50.9), 0.194129 s/step
# on time step 2566 (time=51.32), 0.192959 s/step
# on time step 2588 (time=51.76), 0.186268 s/step
# on time step 2611 (time=52.22), 0.179655 s/step
# on time step 2634 (time=52.68), 0.179639 s/step
# on time step 2655 (time=53.1), 0.191747 s/step
# on time step 2676 (time=53.52), 0.192412 s/step
# on time step 2698 (time=53.96), 0.186741 s/step
# on time step 2719 (time=54.38), 0.193916 s/step
# on time step 2740 (time=54.8), 0.190489 s/step
# on time step 2762 (time=55.24), 0.189054 s/step
# on time step 2784 (time=55.68), 0.190208 s/step
# on time step 2806 (time=56.12), 0.184069 s/step
# on time step 2829 (time=56.58), 0.181192 s/step
# on time step 2851 (time=57.02), 0.182796 s/step
# on time step 2874 (time=57.48), 0.181012 s/step
# on time step 2897 (time=57.94), 0.179965 s/step
# on time step 2919 (time=58.38), 0.184157 s/step
# on time step 2942 (time=58.84), 0.180994 s/step
# on time step 2964 (time=59.28), 0.185587 s/step
# on time step 2986 (time=59.72), 0.18229 s/step
# field decay(t = 60.1): 0.004061334800567334 / 0.02773241256766784 = 0.14644722274549923
# on time step 3007 (time=60.14), 0.191917 s/step
# on time step 3027 (time=60.54), 0.200535 s/step
# on time step 3049 (time=60.98), 0.182506 s/step
# on time step 3071 (time=61.42), 0.183819 s/step
# on time step 3093 (time=61.86), 0.183488 s/step
# on time step 3114 (time=62.28), 0.193751 s/step
# on time step 3136 (time=62.72), 0.186719 s/step
# on time step 3158 (time=63.16), 0.185908 s/step
# on time step 3181 (time=63.62), 0.178921 s/step
# on time step 3204 (time=64.08), 0.178657 s/step
# on time step 3227 (time=64.54), 0.178566 s/step
# on time step 3250 (time=65), 0.178082 s/step
# on time step 3273 (time=65.46), 0.179663 s/step
# on time step 3296 (time=65.92), 0.179829 s/step
# on time step 3319 (time=66.38), 0.18088 s/step
# on time step 3341 (time=66.82), 0.188575 s/step
# on time step 3364 (time=67.28), 0.178688 s/step
# on time step 3387 (time=67.74), 0.180851 s/step
# on time step 3410 (time=68.2), 0.180827 s/step
# on time step 3433 (time=68.66), 0.178691 s/step
# on time step 3455 (time=69.1), 0.184831 s/step
# on time step 3477 (time=69.54), 0.188381 s/step
# on time step 3500 (time=70), 0.179555 s/step
# field decay(t = 70.12): 0.001627883944870155 / 0.02773241256766784 = 0.0586996872665901
# on time step 3523 (time=70.46), 0.179346 s/step
# on time step 3544 (time=70.88), 0.190744 s/step
# on time step 3565 (time=71.3), 0.192205 s/step
# on time step 3588 (time=71.76), 0.179791 s/step
# on time step 3611 (time=72.22), 0.177789 s/step
# on time step 3633 (time=72.66), 0.185065 s/step
# on time step 3656 (time=73.12), 0.179852 s/step
# on time step 3678 (time=73.56), 0.182179 s/step
# on time step 3701 (time=74.02), 0.178684 s/step
# on time step 3723 (time=74.46), 0.182298 s/step
# on time step 3746 (time=74.92), 0.179132 s/step
# on time step 3769 (time=75.38), 0.18057 s/step
# on time step 3792 (time=75.84), 0.180291 s/step
# on time step 3815 (time=76.3), 0.178895 s/step
# on time step 3836 (time=76.72), 0.193139 s/step
# on time step 3857 (time=77.14), 0.191436 s/step
# on time step 3879 (time=77.58), 0.189864 s/step
# on time step 3902 (time=78.04), 0.180295 s/step
# on time step 3924 (time=78.48), 0.188073 s/step
# on time step 3947 (time=78.94), 0.178106 s/step
# on time step 3968 (time=79.36), 0.194204 s/step
# on time step 3990 (time=79.8), 0.184112 s/step
# field decay(t = 80.14): 0.001005541162464466 / 0.02773241256766784 = 0.03625869765246417
# on time step 4013 (time=80.26), 0.18112 s/step
# on time step 4036 (time=80.72), 0.180011 s/step
# on time step 4059 (time=81.18), 0.181806 s/step
# on time step 4081 (time=81.62), 0.187751 s/step
# on time step 4103 (time=82.06), 0.188903 s/step
# on time step 4125 (time=82.5), 0.182593 s/step
# on time step 4147 (time=82.94), 0.183894 s/step
# on time step 4168 (time=83.36), 0.200706 s/step
# on time step 4191 (time=83.82), 0.179312 s/step
# on time step 4214 (time=84.28), 0.179787 s/step
# on time step 4236 (time=84.72), 0.186937 s/step
# on time step 4258 (time=85.16), 0.187556 s/step
# on time step 4280 (time=85.6), 0.182394 s/step
# on time step 4302 (time=86.04), 0.184982 s/step
# on time step 4324 (time=86.48), 0.186204 s/step
# on time step 4346 (time=86.92), 0.186345 s/step
# on time step 4368 (time=87.36), 0.183378 s/step
# on time step 4391 (time=87.82), 0.181206 s/step
# on time step 4414 (time=88.28), 0.18148 s/step
# on time step 4436 (time=88.72), 0.182421 s/step
# on time step 4459 (time=89.18), 0.178007 s/step
# on time step 4481 (time=89.62), 0.188464 s/step
# on time step 4502 (time=90.04), 0.195161 s/step
# field decay(t = 90.16): 0.00046503974639920984 / 0.02773241256766784 = 0.016768816822716026
# on time step 4524 (time=90.48), 0.18977 s/step
# on time step 4545 (time=90.9), 0.195202 s/step
# on time step 4566 (time=91.32), 0.198676 s/step
# on time step 4588 (time=91.76), 0.189606 s/step
# on time step 4609 (time=92.18), 0.196895 s/step
# on time step 4629 (time=92.58), 0.202489 s/step
# on time step 4650 (time=93), 0.192509 s/step
# on time step 4672 (time=93.44), 0.189568 s/step
# on time step 4694 (time=93.88), 0.184526 s/step
# on time step 4716 (time=94.32), 0.188382 s/step
# on time step 4738 (time=94.76), 0.18429 s/step
# on time step 4758 (time=95.16), 0.20821 s/step
# on time step 4778 (time=95.56), 0.201116 s/step
# on time step 4799 (time=95.98), 0.19462 s/step
# on time step 4821 (time=96.42), 0.182302 s/step
# on time step 4843 (time=96.86), 0.183637 s/step
# on time step 4866 (time=97.32), 0.179777 s/step
# on time step 4888 (time=97.76), 0.183159 s/step
# on time step 4910 (time=98.2), 0.187542 s/step
# on time step 4932 (time=98.64), 0.187999 s/step
# on time step 4953 (time=99.06), 0.19601 s/step
# on time step 4975 (time=99.5), 0.186236 s/step
# on time step 4996 (time=99.92), 0.191627 s/step
# field decay(t = 100.18): 0.0002906123599983057 / 0.02773241256766784 = 0.010479158972887901
# on time step 5017 (time=100.34), 0.192593 s/step
# on time step 5038 (time=100.76), 0.195019 s/step
# on time step 5060 (time=101.2), 0.190377 s/step
# on time step 5081 (time=101.62), 0.19301 s/step
# on time step 5102 (time=102.04), 0.195414 s/step
# on time step 5124 (time=102.48), 0.190009 s/step
# on time step 5146 (time=102.92), 0.186161 s/step
# on time step 5168 (time=103.36), 0.187275 s/step
# on time step 5190 (time=103.8), 0.185779 s/step
# on time step 5211 (time=104.22), 0.196982 s/step
# on time step 5232 (time=104.64), 0.191129 s/step
# on time step 5254 (time=105.08), 0.188357 s/step
# on time step 5276 (time=105.52), 0.188317 s/step
# on time step 5297 (time=105.94), 0.19134 s/step
# on time step 5318 (time=106.36), 0.190703 s/step
# on time step 5340 (time=106.8), 0.188927 s/step
# on time step 5361 (time=107.22), 0.192088 s/step
# on time step 5382 (time=107.64), 0.192071 s/step
# on time step 5403 (time=108.06), 0.191783 s/step
# on time step 5424 (time=108.48), 0.193771 s/step
# on time step 5445 (time=108.9), 0.191894 s/step
# on time step 5466 (time=109.32), 0.190524 s/step
# on time step 5487 (time=109.74), 0.191024 s/step
# on time step 5508 (time=110.16), 0.191973 s/step
# field decay(t = 110.2): 5.731385753359365e-05 / 0.02773241256766784 = 0.0020666740549076384
# on time step 5529 (time=110.58), 0.194875 s/step
# on time step 5550 (time=111), 0.193886 s/step
# on time step 5571 (time=111.42), 0.191479 s/step
# on time step 5592 (time=111.84), 0.190922 s/step
# on time step 5613 (time=112.26), 0.193192 s/step
# on time step 5634 (time=112.68), 0.191605 s/step
# on time step 5655 (time=113.1), 0.192253 s/step
# on time step 5676 (time=113.52), 0.191185 s/step
# on time step 5697 (time=113.94), 0.191565 s/step
# on time step 5718 (time=114.36), 0.191905 s/step
# on time step 5739 (time=114.78), 0.191631 s/step
# on time step 5760 (time=115.2), 0.191298 s/step
# on time step 5782 (time=115.64), 0.189278 s/step
# on time step 5803 (time=116.06), 0.190616 s/step
# on time step 5824 (time=116.48), 0.191264 s/step
# on time step 5845 (time=116.9), 0.19182 s/step
# on time step 5866 (time=117.32), 0.191444 s/step
# on time step 5888 (time=117.76), 0.190212 s/step
# on time step 5909 (time=118.18), 0.190486 s/step
# on time step 5930 (time=118.6), 0.19153 s/step
# on time step 5951 (time=119.02), 0.192876 s/step
# on time step 5972 (time=119.44), 0.193259 s/step
# on time step 5994 (time=119.88), 0.189869 s/step
# field decay(t = 120.22): 1.4632114870958835e-05 / 0.02773241256766784 = 0.0005276178131006841
# run 0 finished at t = 120.22 (6011 timesteps)

# %%
# green pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[15], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[15], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_g_field"
Ey_Namei="Ey_g_field"
Ez_Namei="Ez_g_field"

Hx_Namei="Hx_g_field"
Hy_Namei="Hy_g_field"
Hz_Namei="Hz_g_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000634909 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 72.2178% done, 1.53931 s remaining
# subpixel-averaging is 67.7316% done, 1.90585 s remaining
# subpixel-averaging is 69.3272% done, 1.76997 s remaining
# time for set_epsilon = 30.7772 s
# -----------
# on time step 1 (time=0.02), 8.15085 s/step
# on time step 22 (time=0.44), 0.19212 s/step
# on time step 43 (time=0.86), 0.193657 s/step
# on time step 64 (time=1.28), 0.194752 s/step
# on time step 85 (time=1.7), 0.192073 s/step
# on time step 106 (time=2.12), 0.194773 s/step
# on time step 127 (time=2.54), 0.197179 s/step
# on time step 148 (time=2.96), 0.195983 s/step
# on time step 169 (time=3.38), 0.194461 s/step
# on time step 190 (time=3.8), 0.194573 s/step
# on time step 210 (time=4.2), 0.200808 s/step
# on time step 231 (time=4.62), 0.19563 s/step
# on time step 252 (time=5.04), 0.195719 s/step
# on time step 273 (time=5.46), 0.195201 s/step
# on time step 294 (time=5.88), 0.193657 s/step
# on time step 315 (time=6.3), 0.192591 s/step
# on time step 336 (time=6.72), 0.19168 s/step
# on time step 357 (time=7.14), 0.190581 s/step
# on time step 378 (time=7.56), 0.190974 s/step
# on time step 399 (time=7.98), 0.193974 s/step
# on time step 420 (time=8.4), 0.19376 s/step
# on time step 441 (time=8.82), 0.193123 s/step
# on time step 462 (time=9.24), 0.195046 s/step
# on time step 483 (time=9.66), 0.192648 s/step
# field decay(t = 10.02): 5.336777754735685e-10 / 5.336777754735685e-10 = 1.0
# on time step 504 (time=10.08), 0.191433 s/step
# on time step 526 (time=10.52), 0.190156 s/step
# on time step 548 (time=10.96), 0.19023 s/step
# on time step 569 (time=11.38), 0.193635 s/step
# on time step 590 (time=11.8), 0.192436 s/step
# on time step 611 (time=12.22), 0.193018 s/step
# on time step 632 (time=12.64), 0.194581 s/step
# on time step 654 (time=13.08), 0.190401 s/step
# on time step 675 (time=13.5), 0.194405 s/step
# on time step 697 (time=13.94), 0.190327 s/step
# on time step 719 (time=14.38), 0.189632 s/step
# on time step 740 (time=14.8), 0.192706 s/step
# on time step 761 (time=15.22), 0.19059 s/step
# on time step 783 (time=15.66), 0.188566 s/step
# on time step 804 (time=16.08), 0.19082 s/step
# on time step 825 (time=16.5), 0.192387 s/step
# on time step 846 (time=16.92), 0.192066 s/step
# on time step 867 (time=17.34), 0.198088 s/step
# on time step 888 (time=17.76), 0.191657 s/step
# on time step 910 (time=18.2), 0.183086 s/step
# on time step 932 (time=18.64), 0.190753 s/step
# on time step 951 (time=19.02), 0.211151 s/step
# on time step 971 (time=19.42), 0.20859 s/step
# on time step 993 (time=19.86), 0.185938 s/step
# field decay(t = 20.04): 3.77359874363366e-05 / 3.77359874363366e-05 = 1.0
# on time step 1015 (time=20.3), 0.186949 s/step
# on time step 1036 (time=20.72), 0.19333 s/step
# on time step 1057 (time=21.14), 0.190986 s/step
# on time step 1079 (time=21.58), 0.18415 s/step
# on time step 1101 (time=22.02), 0.187837 s/step
# on time step 1122 (time=22.44), 0.191326 s/step
# on time step 1144 (time=22.88), 0.18639 s/step
# on time step 1166 (time=23.32), 0.187227 s/step
# on time step 1187 (time=23.74), 0.198553 s/step
# on time step 1208 (time=24.16), 0.196466 s/step
# on time step 1230 (time=24.6), 0.186888 s/step
# on time step 1252 (time=25.04), 0.186917 s/step
# on time step 1274 (time=25.48), 0.18637 s/step
# on time step 1296 (time=25.92), 0.18965 s/step
# on time step 1317 (time=26.34), 0.191994 s/step
# on time step 1338 (time=26.76), 0.191305 s/step
# on time step 1359 (time=27.18), 0.193225 s/step
# on time step 1380 (time=27.6), 0.19316 s/step
# on time step 1401 (time=28.02), 0.193744 s/step
# on time step 1422 (time=28.44), 0.19222 s/step
# on time step 1443 (time=28.86), 0.190589 s/step
# on time step 1464 (time=29.28), 0.194909 s/step
# on time step 1485 (time=29.7), 0.192258 s/step
# field decay(t = 30.060000000000002): 0.021087323181464654 / 0.021087323181464654 = 1.0
# on time step 1506 (time=30.12), 0.196768 s/step
# on time step 1527 (time=30.54), 0.195038 s/step
# on time step 1548 (time=30.96), 0.194423 s/step
# on time step 1569 (time=31.38), 0.194006 s/step
# on time step 1590 (time=31.8), 0.194428 s/step
# on time step 1611 (time=32.22), 0.193408 s/step
# on time step 1632 (time=32.64), 0.196422 s/step
# on time step 1653 (time=33.06), 0.194083 s/step
# on time step 1674 (time=33.48), 0.191981 s/step
# on time step 1695 (time=33.9), 0.197624 s/step
# on time step 1716 (time=34.32), 0.196165 s/step
# on time step 1738 (time=34.76), 0.190054 s/step
# on time step 1759 (time=35.18), 0.191082 s/step
# on time step 1781 (time=35.62), 0.189305 s/step
# on time step 1803 (time=36.06), 0.189082 s/step
# on time step 1825 (time=36.5), 0.190125 s/step
# on time step 1846 (time=36.92), 0.190801 s/step
# on time step 1867 (time=37.34), 0.191858 s/step
# on time step 1889 (time=37.78), 0.18991 s/step
# on time step 1911 (time=38.22), 0.190418 s/step
# on time step 1932 (time=38.64), 0.191021 s/step
# on time step 1954 (time=39.08), 0.188812 s/step
# on time step 1976 (time=39.52), 0.188716 s/step
# on time step 1998 (time=39.96), 0.188944 s/step
# field decay(t = 40.06): 0.08779773558712448 / 0.08779773558712448 = 1.0
# on time step 2020 (time=40.4), 0.189795 s/step
# on time step 2042 (time=40.84), 0.188583 s/step
# on time step 2063 (time=41.26), 0.191 s/step
# on time step 2085 (time=41.7), 0.189303 s/step
# on time step 2107 (time=42.14), 0.188409 s/step
# on time step 2129 (time=42.58), 0.189953 s/step
# on time step 2150 (time=43), 0.190955 s/step
# on time step 2171 (time=43.42), 0.192482 s/step
# on time step 2193 (time=43.86), 0.187917 s/step
# on time step 2215 (time=44.3), 0.189879 s/step
# on time step 2237 (time=44.74), 0.189188 s/step
# on time step 2258 (time=45.16), 0.191243 s/step
# on time step 2280 (time=45.6), 0.188616 s/step
# on time step 2302 (time=46.04), 0.190033 s/step
# on time step 2323 (time=46.46), 0.191045 s/step
# on time step 2345 (time=46.9), 0.189025 s/step
# on time step 2367 (time=47.34), 0.188722 s/step
# on time step 2389 (time=47.78), 0.189048 s/step
# on time step 2411 (time=48.22), 0.190037 s/step
# on time step 2432 (time=48.64), 0.191916 s/step
# on time step 2454 (time=49.08), 0.190373 s/step
# on time step 2475 (time=49.5), 0.190728 s/step
# on time step 2496 (time=49.92), 0.190719 s/step
# field decay(t = 50.08): 0.06589381918967294 / 0.08779773558712448 = 0.7505184359143797
# on time step 2517 (time=50.34), 0.191945 s/step
# on time step 2538 (time=50.76), 0.192199 s/step
# on time step 2559 (time=51.18), 0.193582 s/step
# on time step 2580 (time=51.6), 0.193067 s/step
# on time step 2601 (time=52.02), 0.191988 s/step
# on time step 2622 (time=52.44), 0.192715 s/step
# on time step 2643 (time=52.86), 0.193133 s/step
# on time step 2664 (time=53.28), 0.192635 s/step
# on time step 2685 (time=53.7), 0.191191 s/step
# on time step 2707 (time=54.14), 0.18993 s/step
# on time step 2728 (time=54.56), 0.1905 s/step
# on time step 2750 (time=55), 0.189541 s/step
# on time step 2772 (time=55.44), 0.189421 s/step
# on time step 2793 (time=55.86), 0.192503 s/step
# on time step 2814 (time=56.28), 0.194826 s/step
# on time step 2836 (time=56.72), 0.189275 s/step
# on time step 2858 (time=57.16), 0.189589 s/step
# on time step 2880 (time=57.6), 0.185378 s/step
# on time step 2903 (time=58.06), 0.180655 s/step
# on time step 2925 (time=58.5), 0.183671 s/step
# on time step 2948 (time=58.96), 0.180039 s/step
# on time step 2970 (time=59.4), 0.189745 s/step
# on time step 2991 (time=59.82), 0.193045 s/step
# field decay(t = 60.1): 0.004870238025231511 / 0.08779773558712448 = 0.05547111201289035
# on time step 3012 (time=60.24), 0.196147 s/step
# on time step 3033 (time=60.66), 0.190915 s/step
# on time step 3054 (time=61.08), 0.194055 s/step
# on time step 3075 (time=61.5), 0.195979 s/step
# on time step 3096 (time=61.92), 0.192159 s/step
# on time step 3116 (time=62.32), 0.203121 s/step
# on time step 3137 (time=62.74), 0.192102 s/step
# on time step 3158 (time=63.16), 0.19086 s/step
# on time step 3179 (time=63.58), 0.191787 s/step
# on time step 3200 (time=64), 0.193464 s/step
# on time step 3220 (time=64.4), 0.200944 s/step
# on time step 3241 (time=64.82), 0.198412 s/step
# on time step 3262 (time=65.24), 0.200218 s/step
# on time step 3283 (time=65.66), 0.191477 s/step
# on time step 3304 (time=66.08), 0.191349 s/step
# on time step 3324 (time=66.48), 0.206983 s/step
# on time step 3344 (time=66.88), 0.205269 s/step
# on time step 3365 (time=67.3), 0.191186 s/step
# on time step 3385 (time=67.7), 0.201138 s/step
# on time step 3406 (time=68.12), 0.200105 s/step
# on time step 3426 (time=68.52), 0.201658 s/step
# on time step 3447 (time=68.94), 0.195181 s/step
# on time step 3467 (time=69.34), 0.200742 s/step
# on time step 3488 (time=69.76), 0.200286 s/step
# field decay(t = 70.12): 0.0035190833065528266 / 0.08779773558712448 = 0.04008170920377244
# on time step 3509 (time=70.18), 0.200235 s/step
# on time step 3529 (time=70.58), 0.201581 s/step
# on time step 3550 (time=71), 0.193852 s/step
# on time step 3571 (time=71.42), 0.197042 s/step
# on time step 3592 (time=71.84), 0.198894 s/step
# on time step 3613 (time=72.26), 0.195394 s/step
# on time step 3633 (time=72.66), 0.201051 s/step
# on time step 3654 (time=73.08), 0.198303 s/step
# on time step 3675 (time=73.5), 0.193728 s/step
# on time step 3695 (time=73.9), 0.203303 s/step
# on time step 3716 (time=74.32), 0.19679 s/step
# on time step 3736 (time=74.72), 0.200194 s/step
# on time step 3757 (time=75.14), 0.192311 s/step
# on time step 3778 (time=75.56), 0.19659 s/step
# on time step 3798 (time=75.96), 0.202011 s/step
# on time step 3819 (time=76.38), 0.197509 s/step
# on time step 3840 (time=76.8), 0.195588 s/step
# on time step 3861 (time=77.22), 0.195658 s/step
# on time step 3882 (time=77.64), 0.194694 s/step
# on time step 3903 (time=78.06), 0.196643 s/step
# on time step 3924 (time=78.48), 0.190628 s/step
# on time step 3945 (time=78.9), 0.191781 s/step
# on time step 3966 (time=79.32), 0.190681 s/step
# on time step 3987 (time=79.74), 0.191822 s/step
# field decay(t = 80.14): 0.0007974997348486597 / 0.08779773558712448 = 0.009083374753523972
# on time step 4009 (time=80.18), 0.189722 s/step
# on time step 4030 (time=80.6), 0.190762 s/step
# on time step 4052 (time=81.04), 0.189907 s/step
# on time step 4073 (time=81.46), 0.191605 s/step
# on time step 4095 (time=81.9), 0.190178 s/step
# on time step 4117 (time=82.34), 0.190034 s/step
# on time step 4138 (time=82.76), 0.190569 s/step
# on time step 4160 (time=83.2), 0.18876 s/step
# on time step 4182 (time=83.64), 0.188937 s/step
# on time step 4203 (time=84.06), 0.19408 s/step
# on time step 4224 (time=84.48), 0.191301 s/step
# on time step 4246 (time=84.92), 0.18949 s/step
# on time step 4268 (time=85.36), 0.190121 s/step
# on time step 4289 (time=85.78), 0.190484 s/step
# on time step 4310 (time=86.2), 0.1907 s/step
# on time step 4332 (time=86.64), 0.189474 s/step
# on time step 4353 (time=87.06), 0.191396 s/step
# on time step 4375 (time=87.5), 0.189826 s/step
# on time step 4397 (time=87.94), 0.189906 s/step
# on time step 4419 (time=88.38), 0.189276 s/step
# on time step 4441 (time=88.82), 0.189349 s/step
# on time step 4463 (time=89.26), 0.190303 s/step
# on time step 4484 (time=89.68), 0.190791 s/step
# on time step 4505 (time=90.1), 0.190681 s/step
# field decay(t = 90.16): 0.0010483614608906052 / 0.08779773558712448 = 0.01194064350156597
# on time step 4526 (time=90.52), 0.190617 s/step
# on time step 4548 (time=90.96), 0.190416 s/step
# on time step 4570 (time=91.4), 0.189847 s/step
# on time step 4591 (time=91.82), 0.191613 s/step
# on time step 4613 (time=92.26), 0.189475 s/step
# on time step 4635 (time=92.7), 0.189854 s/step
# on time step 4657 (time=93.14), 0.18905 s/step
# on time step 4679 (time=93.58), 0.190288 s/step
# on time step 4701 (time=94.02), 0.189081 s/step
# on time step 4723 (time=94.46), 0.190307 s/step
# on time step 4745 (time=94.9), 0.18844 s/step
# on time step 4767 (time=95.34), 0.188856 s/step
# on time step 4789 (time=95.78), 0.188158 s/step
# on time step 4811 (time=96.22), 0.189399 s/step
# on time step 4833 (time=96.66), 0.189691 s/step
# on time step 4855 (time=97.1), 0.189705 s/step
# on time step 4877 (time=97.54), 0.190156 s/step
# on time step 4899 (time=97.98), 0.189919 s/step
# on time step 4921 (time=98.42), 0.190364 s/step
# on time step 4942 (time=98.84), 0.190596 s/step
# on time step 4963 (time=99.26), 0.190713 s/step
# on time step 4985 (time=99.7), 0.190244 s/step
# on time step 5007 (time=100.14), 0.190374 s/step
# field decay(t = 100.18): 0.0004855801748400928 / 0.08779773558712448 = 0.005530668548487065
# on time step 5029 (time=100.58), 0.189172 s/step
# on time step 5051 (time=101.02), 0.187484 s/step
# on time step 5073 (time=101.46), 0.188278 s/step
# on time step 5095 (time=101.9), 0.189216 s/step
# on time step 5116 (time=102.32), 0.192908 s/step
# on time step 5137 (time=102.74), 0.193904 s/step
# on time step 5158 (time=103.16), 0.194372 s/step
# on time step 5179 (time=103.58), 0.193112 s/step
# on time step 5200 (time=104), 0.195102 s/step
# on time step 5221 (time=104.42), 0.192982 s/step
# on time step 5243 (time=104.86), 0.190232 s/step
# on time step 5265 (time=105.3), 0.189849 s/step
# on time step 5286 (time=105.72), 0.193322 s/step
# on time step 5307 (time=106.14), 0.190593 s/step
# on time step 5329 (time=106.58), 0.189931 s/step
# on time step 5350 (time=107), 0.190526 s/step
# on time step 5372 (time=107.44), 0.189778 s/step
# on time step 5392 (time=107.84), 0.203257 s/step
# on time step 5413 (time=108.26), 0.196068 s/step
# on time step 5434 (time=108.68), 0.198456 s/step
# on time step 5455 (time=109.1), 0.194782 s/step
# on time step 5475 (time=109.5), 0.205512 s/step
# on time step 5496 (time=109.92), 0.193411 s/step
# field decay(t = 110.2): 4.617564181839336e-05 / 0.08779773558712448 = 0.0005259320358276416
# run 0 finished at t = 110.2 (5510 timesteps)

# %%
# red pixel

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

src = mp.GaussianSource(frequency=frequencies[25], fwidth=fwidth_green, is_integrated=True)
source = [
    mp.GaussianBeam3DSource(
        src = src,
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )]
opt.sim.change_sources(source)

plt.figure()

tran_Ex = opt.sim.add_dft_fields([mp.Ex], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ey = opt.sim.add_dft_fields([mp.Ey], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Ez = opt.sim.add_dft_fields([mp.Ez], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

tran_Hx = opt.sim.add_dft_fields([mp.Hx], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hy = opt.sim.add_dft_fields([mp.Hy], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)
tran_Hz = opt.sim.add_dft_fields([mp.Hz], frequencies[25], 0 , 1, center = (0,0,-Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0), yee_grid=True)

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"

opt.sim.output_dft(tran_Ex,design_dir+Ex_Namei)
opt.sim.output_dft(tran_Ey,design_dir+Ey_Namei)
opt.sim.output_dft(tran_Ez,design_dir+Ez_Namei)

opt.sim.output_dft(tran_Hx,design_dir+Hx_Namei)
opt.sim.output_dft(tran_Hy,design_dir+Hy_Namei)
opt.sim.output_dft(tran_Hz,design_dir+Hz_Namei)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000659943 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 71.709% done, 1.57819 s remaining
# subpixel-averaging is 70.9459% done, 1.63825 s remaining
# subpixel-averaging is 71.7553% done, 1.57458 s remaining
# time for set_epsilon = 30.5876 s
# -----------
# on time step 1 (time=0.02), 8.16847 s/step
# on time step 23 (time=0.46), 0.185869 s/step
# on time step 45 (time=0.9), 0.187463 s/step
# on time step 67 (time=1.34), 0.182273 s/step
# on time step 89 (time=1.78), 0.185615 s/step
# on time step 111 (time=2.22), 0.188032 s/step
# on time step 133 (time=2.66), 0.185414 s/step
# on time step 155 (time=3.1), 0.186525 s/step
# on time step 177 (time=3.54), 0.19052 s/step
# on time step 197 (time=3.94), 0.20043 s/step
# on time step 218 (time=4.36), 0.197159 s/step
# on time step 239 (time=4.78), 0.19732 s/step
# on time step 260 (time=5.2), 0.198424 s/step
# on time step 281 (time=5.62), 0.191382 s/step
# on time step 302 (time=6.04), 0.192259 s/step
# on time step 323 (time=6.46), 0.193219 s/step
# on time step 345 (time=6.9), 0.190068 s/step
# on time step 366 (time=7.32), 0.200228 s/step
# on time step 387 (time=7.74), 0.199038 s/step
# on time step 408 (time=8.16), 0.194977 s/step
# on time step 429 (time=8.58), 0.1923 s/step
# on time step 450 (time=9), 0.196118 s/step
# on time step 471 (time=9.42), 0.193505 s/step
# on time step 492 (time=9.84), 0.192565 s/step
# field decay(t = 10.02): 2.65646466754259e-09 / 2.65646466754259e-09 = 1.0
# on time step 513 (time=10.26), 0.194815 s/step
# on time step 534 (time=10.68), 0.193704 s/step
# on time step 555 (time=11.1), 0.193665 s/step
# on time step 577 (time=11.54), 0.190021 s/step
# on time step 598 (time=11.96), 0.191102 s/step
# on time step 619 (time=12.38), 0.195718 s/step
# on time step 640 (time=12.8), 0.192342 s/step
# on time step 661 (time=13.22), 0.198133 s/step
# on time step 682 (time=13.64), 0.198253 s/step
# on time step 703 (time=14.06), 0.193968 s/step
# on time step 724 (time=14.48), 0.194247 s/step
# on time step 745 (time=14.9), 0.19328 s/step
# on time step 766 (time=15.32), 0.193334 s/step
# on time step 787 (time=15.74), 0.19776 s/step
# on time step 808 (time=16.16), 0.195796 s/step
# on time step 829 (time=16.58), 0.196172 s/step
# on time step 850 (time=17), 0.195988 s/step
# on time step 871 (time=17.42), 0.195121 s/step
# on time step 892 (time=17.84), 0.194739 s/step
# on time step 913 (time=18.26), 0.196912 s/step
# on time step 934 (time=18.68), 0.195432 s/step
# on time step 955 (time=19.1), 0.196158 s/step
# on time step 976 (time=19.52), 0.19523 s/step
# on time step 997 (time=19.94), 0.195205 s/step
# field decay(t = 20.04): 0.0001615964794774902 / 0.0001615964794774902 = 1.0
# on time step 1018 (time=20.36), 0.196918 s/step
# on time step 1039 (time=20.78), 0.193441 s/step
# on time step 1060 (time=21.2), 0.198294 s/step
# on time step 1081 (time=21.62), 0.196864 s/step
# on time step 1102 (time=22.04), 0.197342 s/step
# on time step 1123 (time=22.46), 0.199484 s/step
# on time step 1144 (time=22.88), 0.196418 s/step
# on time step 1165 (time=23.3), 0.195506 s/step
# on time step 1186 (time=23.72), 0.196616 s/step
# on time step 1207 (time=24.14), 0.198281 s/step
# on time step 1228 (time=24.56), 0.200162 s/step
# on time step 1249 (time=24.98), 0.19827 s/step
# on time step 1270 (time=25.4), 0.195634 s/step
# on time step 1291 (time=25.82), 0.197868 s/step
# on time step 1312 (time=26.24), 0.196665 s/step
# on time step 1333 (time=26.66), 0.19634 s/step
# on time step 1354 (time=27.08), 0.194663 s/step
# on time step 1375 (time=27.5), 0.195905 s/step
# on time step 1396 (time=27.92), 0.197637 s/step
# on time step 1417 (time=28.34), 0.195052 s/step
# on time step 1438 (time=28.76), 0.201672 s/step
# on time step 1458 (time=29.16), 0.201945 s/step
# on time step 1479 (time=29.58), 0.196104 s/step
# on time step 1500 (time=30), 0.19644 s/step
# field decay(t = 30.060000000000002): 0.07539985571501275 / 0.07539985571501275 = 1.0
# on time step 1521 (time=30.42), 0.195941 s/step
# on time step 1542 (time=30.84), 0.195725 s/step
# on time step 1563 (time=31.26), 0.19478 s/step
# on time step 1584 (time=31.68), 0.19487 s/step
# on time step 1605 (time=32.1), 0.193303 s/step
# on time step 1626 (time=32.52), 0.192939 s/step
# on time step 1647 (time=32.94), 0.191538 s/step
# on time step 1668 (time=33.36), 0.193724 s/step
# on time step 1689 (time=33.78), 0.194524 s/step
# on time step 1710 (time=34.2), 0.199597 s/step
# on time step 1731 (time=34.62), 0.195745 s/step
# on time step 1752 (time=35.04), 0.193288 s/step
# on time step 1773 (time=35.46), 0.195359 s/step
# on time step 1794 (time=35.88), 0.194092 s/step
# on time step 1815 (time=36.3), 0.193737 s/step
# on time step 1836 (time=36.72), 0.196117 s/step
# on time step 1857 (time=37.14), 0.195736 s/step
# on time step 1878 (time=37.56), 0.196838 s/step
# on time step 1899 (time=37.98), 0.195387 s/step
# on time step 1920 (time=38.4), 0.196791 s/step
# on time step 1941 (time=38.82), 0.194625 s/step
# on time step 1962 (time=39.24), 0.197065 s/step
# on time step 1982 (time=39.64), 0.200653 s/step
# field decay(t = 40.06): 0.2031200749336087 / 0.2031200749336087 = 1.0
# on time step 2003 (time=40.06), 0.196865 s/step
# on time step 2023 (time=40.46), 0.200738 s/step
# on time step 2044 (time=40.88), 0.198157 s/step
# on time step 2065 (time=41.3), 0.192015 s/step
# on time step 2087 (time=41.74), 0.18803 s/step
# on time step 2108 (time=42.16), 0.190772 s/step
# on time step 2130 (time=42.6), 0.188506 s/step
# on time step 2152 (time=43.04), 0.189834 s/step
# on time step 2174 (time=43.48), 0.18989 s/step
# on time step 2195 (time=43.9), 0.191445 s/step
# on time step 2217 (time=44.34), 0.189909 s/step
# on time step 2238 (time=44.76), 0.190584 s/step
# on time step 2259 (time=45.18), 0.190561 s/step
# on time step 2281 (time=45.62), 0.189861 s/step
# on time step 2303 (time=46.06), 0.18882 s/step
# on time step 2325 (time=46.5), 0.189952 s/step
# on time step 2347 (time=46.94), 0.18834 s/step
# on time step 2368 (time=47.36), 0.192383 s/step
# on time step 2390 (time=47.8), 0.190211 s/step
# on time step 2411 (time=48.22), 0.192565 s/step
# on time step 2432 (time=48.64), 0.191059 s/step
# on time step 2453 (time=49.06), 0.192384 s/step
# on time step 2474 (time=49.48), 0.190858 s/step
# on time step 2495 (time=49.9), 0.191639 s/step
# field decay(t = 50.08): 0.12981708906827139 / 0.2031200749336087 = 0.6391150117028219
# on time step 2515 (time=50.3), 0.20065 s/step
# on time step 2536 (time=50.72), 0.19512 s/step
# on time step 2557 (time=51.14), 0.1971 s/step
# on time step 2578 (time=51.56), 0.198206 s/step
# on time step 2599 (time=51.98), 0.198165 s/step
# on time step 2620 (time=52.4), 0.199438 s/step
# on time step 2641 (time=52.82), 0.197567 s/step
# on time step 2662 (time=53.24), 0.198218 s/step
# on time step 2683 (time=53.66), 0.194076 s/step
# on time step 2704 (time=54.08), 0.195894 s/step
# on time step 2725 (time=54.5), 0.197063 s/step
# on time step 2746 (time=54.92), 0.195608 s/step
# on time step 2767 (time=55.34), 0.190697 s/step
# on time step 2789 (time=55.78), 0.189889 s/step
# on time step 2810 (time=56.2), 0.191351 s/step
# on time step 2831 (time=56.62), 0.191081 s/step
# on time step 2853 (time=57.06), 0.190295 s/step
# on time step 2875 (time=57.5), 0.190379 s/step
# on time step 2896 (time=57.92), 0.191474 s/step
# on time step 2917 (time=58.34), 0.190562 s/step
# on time step 2938 (time=58.76), 0.191119 s/step
# on time step 2960 (time=59.2), 0.189362 s/step
# on time step 2982 (time=59.64), 0.188453 s/step
# on time step 3004 (time=60.08), 0.18818 s/step
# field decay(t = 60.1): 0.015378003885862189 / 0.2031200749336087 = 0.07570893172862704
# on time step 3026 (time=60.52), 0.189394 s/step
# on time step 3047 (time=60.94), 0.190817 s/step
# on time step 3069 (time=61.38), 0.18886 s/step
# on time step 3090 (time=61.8), 0.191697 s/step
# on time step 3111 (time=62.22), 0.195993 s/step
# on time step 3132 (time=62.64), 0.193337 s/step
# on time step 3153 (time=63.06), 0.192402 s/step
# on time step 3175 (time=63.5), 0.189872 s/step
# on time step 3196 (time=63.92), 0.191401 s/step
# on time step 3218 (time=64.36), 0.189936 s/step
# on time step 3239 (time=64.78), 0.191739 s/step
# on time step 3260 (time=65.2), 0.191229 s/step
# on time step 3281 (time=65.62), 0.191984 s/step
# on time step 3302 (time=66.04), 0.195267 s/step
# on time step 3323 (time=66.46), 0.199766 s/step
# on time step 3344 (time=66.88), 0.191735 s/step
# on time step 3365 (time=67.3), 0.191779 s/step
# on time step 3386 (time=67.72), 0.19268 s/step
# on time step 3407 (time=68.14), 0.191563 s/step
# on time step 3428 (time=68.56), 0.191229 s/step
# on time step 3450 (time=69), 0.188006 s/step
# on time step 3472 (time=69.44), 0.188267 s/step
# on time step 3494 (time=69.88), 0.187876 s/step
# field decay(t = 70.12): 0.012282635789328221 / 0.2031200749336087 = 0.06046982698949324
# on time step 3515 (time=70.3), 0.190758 s/step
# on time step 3536 (time=70.72), 0.193336 s/step
# on time step 3557 (time=71.14), 0.191275 s/step
# on time step 3579 (time=71.58), 0.189791 s/step
# on time step 3600 (time=72), 0.190965 s/step
# on time step 3622 (time=72.44), 0.189981 s/step
# on time step 3644 (time=72.88), 0.189457 s/step
# on time step 3666 (time=73.32), 0.189213 s/step
# on time step 3688 (time=73.76), 0.189593 s/step
# on time step 3710 (time=74.2), 0.189595 s/step
# on time step 3732 (time=74.64), 0.189207 s/step
# on time step 3754 (time=75.08), 0.188479 s/step
# on time step 3775 (time=75.5), 0.191976 s/step
# on time step 3796 (time=75.92), 0.192184 s/step
# on time step 3818 (time=76.36), 0.190441 s/step
# on time step 3839 (time=76.78), 0.191382 s/step
# on time step 3860 (time=77.2), 0.191087 s/step
# on time step 3881 (time=77.62), 0.193044 s/step
# on time step 3902 (time=78.04), 0.190526 s/step
# on time step 3923 (time=78.46), 0.193306 s/step
# on time step 3944 (time=78.88), 0.19117 s/step
# on time step 3965 (time=79.3), 0.198624 s/step
# on time step 3987 (time=79.74), 0.18938 s/step
# field decay(t = 80.14): 0.004401303081524409 / 0.2031200749336087 = 0.021668479016478344
# on time step 4008 (time=80.16), 0.193566 s/step
# on time step 4029 (time=80.58), 0.196883 s/step
# on time step 4050 (time=81), 0.195453 s/step
# on time step 4071 (time=81.42), 0.195137 s/step
# on time step 4092 (time=81.84), 0.192113 s/step
# on time step 4113 (time=82.26), 0.192775 s/step
# on time step 4134 (time=82.68), 0.196684 s/step
# on time step 4154 (time=83.08), 0.200474 s/step
# on time step 4174 (time=83.48), 0.20046 s/step
# on time step 4195 (time=83.9), 0.194986 s/step
# on time step 4216 (time=84.32), 0.198282 s/step
# on time step 4237 (time=84.74), 0.195602 s/step
# on time step 4258 (time=85.16), 0.190832 s/step
# on time step 4279 (time=85.58), 0.19141 s/step
# on time step 4300 (time=86), 0.191727 s/step
# on time step 4321 (time=86.42), 0.195382 s/step
# on time step 4342 (time=86.84), 0.195721 s/step
# on time step 4363 (time=87.26), 0.19363 s/step
# on time step 4384 (time=87.68), 0.192359 s/step
# on time step 4405 (time=88.1), 0.193318 s/step
# on time step 4426 (time=88.52), 0.192232 s/step
# on time step 4447 (time=88.94), 0.193255 s/step
# on time step 4469 (time=89.38), 0.190278 s/step
# on time step 4491 (time=89.82), 0.1889 s/step
# field decay(t = 90.16): 0.0003348073180290049 / 0.2031200749336087 = 0.0016483221470769895
# on time step 4513 (time=90.26), 0.18757 s/step
# on time step 4535 (time=90.7), 0.19023 s/step
# on time step 4557 (time=91.14), 0.187415 s/step
# on time step 4579 (time=91.58), 0.188356 s/step
# on time step 4601 (time=92.02), 0.189649 s/step
# on time step 4623 (time=92.46), 0.190048 s/step
# on time step 4644 (time=92.88), 0.190875 s/step
# on time step 4665 (time=93.3), 0.190493 s/step
# on time step 4686 (time=93.72), 0.191617 s/step
# on time step 4708 (time=94.16), 0.190229 s/step
# on time step 4730 (time=94.6), 0.189779 s/step
# on time step 4752 (time=95.04), 0.18873 s/step
# on time step 4773 (time=95.46), 0.190941 s/step
# on time step 4795 (time=95.9), 0.190003 s/step
# on time step 4817 (time=96.34), 0.190537 s/step
# on time step 4839 (time=96.78), 0.190075 s/step
# on time step 4861 (time=97.22), 0.190263 s/step
# on time step 4882 (time=97.64), 0.190675 s/step
# on time step 4903 (time=98.06), 0.190653 s/step
# on time step 4924 (time=98.48), 0.190676 s/step
# on time step 4945 (time=98.9), 0.190933 s/step
# on time step 4967 (time=99.34), 0.190153 s/step
# on time step 4988 (time=99.76), 0.191276 s/step
# field decay(t = 100.18): 3.303919970585529e-05 / 0.2031200749336087 = 0.00016265846552417033
# run 0 finished at t = 100.18 (5009 timesteps)

# %%
###############################################################################################################################
# ## 4. DFT fields


###############################################################################################################################
# ## 5. Optical Efficiency

# simulation 1 : geometry가 없는 구조
geometry_1 = [
    mp.Block(
        center=mp.Vector3(0, 0, 0), size=mp.Vector3(Sx, Sy, 0), material=Air
    )
]

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry_1,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)
fcen = (1/(0.40 * um_scale) + 1/(0.70 * um_scale))/2
df = 1 /(0.40 * um_scale) - 1/(0.70 * um_scale)
nfreq = 300

beam_x0 = mp.Vector3(0, 0, 0.5)  # beam focus (relative to source center)
rot_angle = 0  # CCW rotation angle about z axis (0: +y axis)
beam_kdir = mp.Vector3(0, 0, -1).rotate(
    mp.Vector3(0, 0, 1), math.radians(rot_angle)
)  # beam propagation direction
beam_w0 = 1  # beam waist radius
beam_E0 = mp.Vector3(1, 1, 0)

sources = [
    mp.GaussianBeam3DSource(
        src = mp.GaussianSource(frequency=fcen, fwidth=df, is_integrated=True),
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace/2),
        size=mp.Vector3(Sx, Sy, 0),
        beam_x0=beam_x0,
        beam_kdir=beam_kdir,
        beam_w0=beam_w0,
        beam_E0=beam_E0,
    )
]
opt.sim.change_sources(sources)

# reflection moniter 설정

refl_fr = mp.FluxRegion(
    center=mp.Vector3(0, 0, Sz/2 - Lpml - 0.5/resolution), size= mp.Vector3(Sx, Sy, 0)
) 
refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# transmission moiniter 설정

tran_t = mp.FluxRegion(
    center=mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(Sx, Sy, 0)
)
tran_total = opt.sim.add_flux(fcen, df, nfreq, tran_t)


# pt는 transmitted flux region과 동일

pt = mp.Vector3(0, 0, -Sz/2 + PDsize - 0.5/resolution)

opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)

# %%
#source가 끝난 후에 50 동안 계속 실행하며 component는 Ey, pt 설계의 끝에서 |Ey|^2의 값이 최대 값으로부터 1/1000 만큼 감쇠할때까지
#추가적인 50 단위의 시간 실행 -> Fourier-transform 수렴예상

opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

#데이터 저장

straight_refl_data = opt.sim.get_flux_data(refl)
total_flux = mp.get_fluxes(tran_total)
flux_freqs = mp.get_flux_freqs(tran_total)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000359774 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (8.4,8.4,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 8.44145 s
# -----------
# on time step 1 (time=0.02), 8.05822 s/step
# on time step 25 (time=0.5), 0.17337 s/step
# on time step 49 (time=0.98), 0.17244 s/step
# on time step 72 (time=1.44), 0.180952 s/step
# on time step 95 (time=1.9), 0.175345 s/step
# on time step 118 (time=2.36), 0.174633 s/step
# on time step 141 (time=2.82), 0.176143 s/step
# on time step 164 (time=3.28), 0.17923 s/step
# on time step 188 (time=3.76), 0.172896 s/step
# on time step 212 (time=4.24), 0.172001 s/step
# on time step 235 (time=4.7), 0.178334 s/step
# on time step 259 (time=5.18), 0.172358 s/step
# on time step 283 (time=5.66), 0.172316 s/step
# on time step 306 (time=6.12), 0.177282 s/step
# on time step 330 (time=6.6), 0.171286 s/step
# on time step 354 (time=7.08), 0.171831 s/step
# on time step 378 (time=7.56), 0.177061 s/step
# on time step 402 (time=8.04), 0.172881 s/step
# on time step 426 (time=8.52), 0.170889 s/step
# on time step 450 (time=9), 0.178142 s/step
# on time step 474 (time=9.48), 0.172279 s/step
# on time step 498 (time=9.96), 0.172898 s/step
# field decay(t = 10.02): 0.13344553044364213 / 0.13344553044364213 = 1.0
# on time step 522 (time=10.44), 0.176925 s/step
# on time step 546 (time=10.92), 0.17272 s/step
# on time step 570 (time=11.4), 0.172096 s/step
# on time step 594 (time=11.88), 0.174679 s/step
# on time step 617 (time=12.34), 0.174748 s/step
# on time step 641 (time=12.82), 0.171543 s/step
# on time step 665 (time=13.3), 0.173195 s/step
# on time step 688 (time=13.76), 0.176242 s/step
# on time step 711 (time=14.22), 0.174194 s/step
# on time step 735 (time=14.7), 0.17254 s/step
# on time step 758 (time=15.16), 0.178026 s/step
# on time step 782 (time=15.64), 0.171275 s/step
# on time step 806 (time=16.12), 0.172686 s/step
# on time step 829 (time=16.58), 0.178581 s/step
# on time step 853 (time=17.06), 0.171876 s/step
# on time step 877 (time=17.54), 0.171824 s/step
# on time step 900 (time=18), 0.180002 s/step
# on time step 923 (time=18.46), 0.174249 s/step
# on time step 947 (time=18.94), 0.172581 s/step
# on time step 970 (time=19.4), 0.174071 s/step
# on time step 993 (time=19.86), 0.178159 s/step
# field decay(t = 20.04): 0.5262023480760272 / 0.5262023480760272 = 1.0
# on time step 1017 (time=20.34), 0.173193 s/step
# on time step 1041 (time=20.82), 0.172828 s/step
# on time step 1064 (time=21.28), 0.177956 s/step
# on time step 1088 (time=21.76), 0.173078 s/step
# on time step 1112 (time=22.24), 0.172482 s/step
# on time step 1135 (time=22.7), 0.177363 s/step
# on time step 1159 (time=23.18), 0.171163 s/step
# on time step 1183 (time=23.66), 0.171584 s/step
# on time step 1206 (time=24.12), 0.178269 s/step
# on time step 1230 (time=24.6), 0.173304 s/step
# on time step 1254 (time=25.08), 0.172285 s/step
# on time step 1278 (time=25.56), 0.176647 s/step
# on time step 1302 (time=26.04), 0.172802 s/step
# on time step 1325 (time=26.5), 0.174101 s/step
# on time step 1349 (time=26.98), 0.172231 s/step
# on time step 1372 (time=27.44), 0.176863 s/step
# on time step 1396 (time=27.92), 0.170486 s/step
# on time step 1420 (time=28.4), 0.172019 s/step
# on time step 1443 (time=28.86), 0.176172 s/step
# on time step 1467 (time=29.34), 0.172106 s/step
# on time step 1491 (time=29.82), 0.17356 s/step
# field decay(t = 30.060000000000002): 1.5041155313133191e-09 / 0.5262023480760272 = 2.8584356128642746e-09
# run 0 finished at t = 30.060000000000002 (1503 timesteps)

# %%
opt.sim.reset_meep()

# simulation 2 : geometry가 있는 구조

opt.sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# 반사된 flux 구하기

refl = opt.sim.add_flux(fcen, df, nfreq, refl_fr)

# 투과된 flux 구하기

tran = opt.sim.add_flux(fcen, df, nfreq, tran_t)

#반사된 필드와 입사되는 필드를 구분하기 위해서 The Fourier-transformed incident fields을
#the Fourier transforms of the scattered fields 에서 빼줍니다.

opt.sim.load_minus_flux_data(refl, straight_refl_data)

#각각 픽셀의 flux 구하기

#origin
tran_g = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red = opt.sim.add_flux(fcen, df, nfreq, tran_r)
tran_green = opt.sim.add_flux(fcen, df, nfreq, tran_g)
tran_blue = opt.sim.add_flux(fcen, df, nfreq, tran_b)
tran_green0 = opt.sim.add_flux(fcen, df, nfreq, tran_g0)

#1
tran_g_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_1 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_1 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_1 = opt.sim.add_flux(fcen, df, nfreq, tran_r_1)
tran_green_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g_1)
tran_blue_1 = opt.sim.add_flux(fcen, df, nfreq, tran_b_1)
tran_green0_1 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_1)
    
#2
tran_g_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_2 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_2 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_2 = opt.sim.add_flux(fcen, df, nfreq, tran_r_2)
tran_green_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g_2)
tran_blue_2 = opt.sim.add_flux(fcen, df, nfreq, tran_b_2)
tran_green0_2 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_2)
    
#3
tran_g_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_3 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_3 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 + Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_3 = opt.sim.add_flux(fcen, df, nfreq, tran_r_3)
tran_green_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g_3)
tran_blue_3 = opt.sim.add_flux(fcen, df, nfreq, tran_b_3)
tran_green0_3 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_3)
    
#4
tran_g_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_4 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_4 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_4 = opt.sim.add_flux(fcen, df, nfreq, tran_r_4)
tran_green_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g_4)
tran_blue_4 = opt.sim.add_flux(fcen, df, nfreq, tran_b_4)
tran_green0_4 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_4)
    
#5
tran_g_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_5 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_5 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 , -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_5 = opt.sim.add_flux(fcen, df, nfreq, tran_r_5)
tran_green_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g_5)
tran_blue_5 = opt.sim.add_flux(fcen, df, nfreq, tran_b_5)
tran_green0_5 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_5)
    
#6
tran_g_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_6 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_6 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 - Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_6 = opt.sim.add_flux(fcen, df, nfreq, tran_r_6)
tran_green_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g_6)
tran_blue_6 = opt.sim.add_flux(fcen, df, nfreq, tran_b_6)
tran_green0_6 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_6)
    
#7
tran_g_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_7 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_7 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 , design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_7 = opt.sim.add_flux(fcen, df, nfreq, tran_r_7)
tran_green_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g_7)
tran_blue_7 = opt.sim.add_flux(fcen, df, nfreq, tran_b_7)
tran_green0_7 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_7)
    
#8
tran_g_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_r_8 = mp.FluxRegion(
    center=mp.Vector3(-design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_g0_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, -design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)
tran_b_8 = mp.FluxRegion(
    center=mp.Vector3(design_region_width_x/4 + Sx/3, design_region_width_y/4 - Sy/3, -Sz/2 + PDsize - 0.5/resolution), size=mp.Vector3(subpixelsize, subpixelsize, 0)
)

tran_red_8 = opt.sim.add_flux(fcen, df, nfreq, tran_r_8)
tran_green_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g_8)
tran_blue_8 = opt.sim.add_flux(fcen, df, nfreq, tran_b_8)
tran_green0_8 = opt.sim.add_flux(fcen, df, nfreq, tran_g0_8)


opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000795126 s
# Working in 3D dimensions.
# Computational cell is 10.4 x 10.4 x 6 with resolution 25
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...
# subpixel-averaging is 69.0266% done, 1.79528 s remaining
# subpixel-averaging is 71.5472% done, 1.59129 s remaining
# subpixel-averaging is 68.9341% done, 1.80343 s remaining
# time for set_epsilon = 31.1588 s
# -----------
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.plot2D(False, output_plane = mp.Volume(size = (np.inf, np.inf, 0), center = (0,0,-1)))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (0,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,0,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (-2.8,-2.8,0)
#           size (2.4,2.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-2)
#           size (8.4,8.4,2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.1,2.1,2.1)
#      ...(+ 36 objects not shown)...

# %%
opt.sim.run(until_after_sources=mp.stop_when_fields_decayed(10,mp.Ex,pt,1e-3))

# 데이터 저장

refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)

red_flux = mp.get_fluxes(tran_red)
green_flux = mp.get_fluxes(tran_green)
blue_flux = mp.get_fluxes(tran_blue)
green_flux0 = mp.get_fluxes(tran_green0)
    
red_flux_1 = mp.get_fluxes(tran_red_1)
green_flux_1 = mp.get_fluxes(tran_green_1)
blue_flux_1 = mp.get_fluxes(tran_blue_1)
green_flux0_1 = mp.get_fluxes(tran_green0_1)
    
red_flux_2 = mp.get_fluxes(tran_red_2)
green_flux_2 = mp.get_fluxes(tran_green_2)
blue_flux_2 = mp.get_fluxes(tran_blue_2)
green_flux0_2 = mp.get_fluxes(tran_green0_2)
    
red_flux_3 = mp.get_fluxes(tran_red_3)
green_flux_3 = mp.get_fluxes(tran_green_3)
blue_flux_3 = mp.get_fluxes(tran_blue_3)
green_flux0_3 = mp.get_fluxes(tran_green0_3)
    
red_flux_4 = mp.get_fluxes(tran_red_4)
green_flux_4 = mp.get_fluxes(tran_green_4)
blue_flux_4 = mp.get_fluxes(tran_blue_4)
green_flux0_4 = mp.get_fluxes(tran_green0_4)
    
red_flux_5 = mp.get_fluxes(tran_red_5)
green_flux_5 = mp.get_fluxes(tran_green_5)
blue_flux_5 = mp.get_fluxes(tran_blue_5)
green_flux0_5 = mp.get_fluxes(tran_green0_5)
    
red_flux_6 = mp.get_fluxes(tran_red_6)
green_flux_6 = mp.get_fluxes(tran_green_6)
blue_flux_6 = mp.get_fluxes(tran_blue_6)
green_flux0_6 = mp.get_fluxes(tran_green0_6)
    
red_flux_7 = mp.get_fluxes(tran_red_7)
green_flux_7 = mp.get_fluxes(tran_green_7)
blue_flux_7 = mp.get_fluxes(tran_blue_7)
green_flux0_7 = mp.get_fluxes(tran_green0_7)
    
red_flux_8 = mp.get_fluxes(tran_red_8)
green_flux_8 = mp.get_fluxes(tran_green_8)
blue_flux_8 = mp.get_fluxes(tran_blue_8)
green_flux0_8 = mp.get_fluxes(tran_green0_8)
# Out:
# on time step 1 (time=0.02), 8.07746 s/step
# on time step 22 (time=0.44), 0.196794 s/step
# on time step 43 (time=0.86), 0.193901 s/step
# on time step 64 (time=1.28), 0.194406 s/step
# on time step 85 (time=1.7), 0.193636 s/step
# on time step 106 (time=2.12), 0.195713 s/step
# on time step 126 (time=2.52), 0.202949 s/step
# on time step 147 (time=2.94), 0.194965 s/step
# on time step 168 (time=3.36), 0.193456 s/step
# on time step 189 (time=3.78), 0.196316 s/step
# on time step 210 (time=4.2), 0.195099 s/step
# on time step 231 (time=4.62), 0.197449 s/step
# on time step 252 (time=5.04), 0.205852 s/step
# on time step 273 (time=5.46), 0.196192 s/step
# on time step 294 (time=5.88), 0.196035 s/step
# on time step 315 (time=6.3), 0.196894 s/step
# on time step 336 (time=6.72), 0.196835 s/step
# on time step 357 (time=7.14), 0.19908 s/step
# on time step 378 (time=7.56), 0.202453 s/step
# on time step 399 (time=7.98), 0.194596 s/step
# on time step 420 (time=8.4), 0.193664 s/step
# on time step 441 (time=8.82), 0.196045 s/step
# on time step 462 (time=9.24), 0.195605 s/step
# on time step 483 (time=9.66), 0.19681 s/step
# field decay(t = 10.02): 5.0654725440992664e-05 / 5.0654725440992664e-05 = 1.0
# on time step 504 (time=10.08), 0.202655 s/step
# on time step 525 (time=10.5), 0.196388 s/step
# on time step 546 (time=10.92), 0.195416 s/step
# on time step 567 (time=11.34), 0.196105 s/step
# on time step 588 (time=11.76), 0.194687 s/step
# on time step 609 (time=12.18), 0.193737 s/step
# on time step 630 (time=12.6), 0.204248 s/step
# on time step 651 (time=13.02), 0.196288 s/step
# on time step 672 (time=13.44), 0.195921 s/step
# on time step 693 (time=13.86), 0.196256 s/step
# on time step 714 (time=14.28), 0.195662 s/step
# on time step 735 (time=14.7), 0.195776 s/step
# on time step 756 (time=15.12), 0.203013 s/step
# on time step 777 (time=15.54), 0.195313 s/step
# on time step 798 (time=15.96), 0.197977 s/step
# on time step 819 (time=16.38), 0.196373 s/step
# on time step 840 (time=16.8), 0.196891 s/step
# on time step 861 (time=17.22), 0.196919 s/step
# on time step 882 (time=17.64), 0.203277 s/step
# on time step 903 (time=18.06), 0.196171 s/step
# on time step 924 (time=18.48), 0.195857 s/step
# on time step 945 (time=18.9), 0.197107 s/step
# on time step 966 (time=19.32), 0.197576 s/step
# on time step 987 (time=19.74), 0.19566 s/step
# field decay(t = 20.04): 0.02566826898123342 / 0.02566826898123342 = 1.0
# on time step 1008 (time=20.16), 0.204902 s/step
# on time step 1029 (time=20.58), 0.19636 s/step
# on time step 1050 (time=21), 0.196268 s/step
# on time step 1071 (time=21.42), 0.19681 s/step
# on time step 1092 (time=21.84), 0.195404 s/step
# on time step 1113 (time=22.26), 0.196009 s/step
# on time step 1134 (time=22.68), 0.205213 s/step
# on time step 1155 (time=23.1), 0.196477 s/step
# on time step 1176 (time=23.52), 0.194501 s/step
# on time step 1197 (time=23.94), 0.193444 s/step
# on time step 1218 (time=24.36), 0.19711 s/step
# on time step 1239 (time=24.78), 0.198068 s/step
# on time step 1260 (time=25.2), 0.203856 s/step
# on time step 1281 (time=25.62), 0.19603 s/step
# on time step 1302 (time=26.04), 0.196005 s/step
# on time step 1323 (time=26.46), 0.19616 s/step
# on time step 1344 (time=26.88), 0.196367 s/step
# on time step 1365 (time=27.3), 0.196343 s/step
# on time step 1386 (time=27.72), 0.202949 s/step
# on time step 1407 (time=28.14), 0.196538 s/step
# on time step 1428 (time=28.56), 0.195597 s/step
# on time step 1449 (time=28.98), 0.195829 s/step
# on time step 1470 (time=29.4), 0.196564 s/step
# on time step 1491 (time=29.82), 0.1966 s/step
# field decay(t = 30.060000000000002): 0.024699037032826533 / 0.02566826898123342 = 0.9622400735664913
# on time step 1512 (time=30.24), 0.203929 s/step
# on time step 1533 (time=30.66), 0.195994 s/step
# on time step 1554 (time=31.08), 0.19603 s/step
# on time step 1575 (time=31.5), 0.196966 s/step
# on time step 1596 (time=31.92), 0.198823 s/step
# on time step 1617 (time=32.34), 0.196406 s/step
# on time step 1638 (time=32.76), 0.204194 s/step
# on time step 1659 (time=33.18), 0.194044 s/step
# on time step 1680 (time=33.6), 0.195137 s/step
# on time step 1701 (time=34.02), 0.195227 s/step
# on time step 1722 (time=34.44), 0.195621 s/step
# on time step 1743 (time=34.86), 0.196523 s/step
# on time step 1764 (time=35.28), 0.203166 s/step
# on time step 1785 (time=35.7), 0.196817 s/step
# on time step 1806 (time=36.12), 0.19592 s/step
# on time step 1827 (time=36.54), 0.198 s/step
# on time step 1848 (time=36.96), 0.195801 s/step
# on time step 1869 (time=37.38), 0.195054 s/step
# on time step 1890 (time=37.8), 0.20265 s/step
# on time step 1911 (time=38.22), 0.196569 s/step
# on time step 1931 (time=38.62), 0.200769 s/step
# on time step 1952 (time=39.04), 0.197087 s/step
# on time step 1973 (time=39.46), 0.195765 s/step
# on time step 1994 (time=39.88), 0.195157 s/step
# field decay(t = 40.06): 0.0016291834256160177 / 0.02566826898123342 = 0.06347071658034853
# on time step 2015 (time=40.3), 0.195783 s/step
# on time step 2035 (time=40.7), 0.204446 s/step
# on time step 2056 (time=41.12), 0.195232 s/step
# on time step 2077 (time=41.54), 0.194234 s/step
# on time step 2098 (time=41.96), 0.194335 s/step
# on time step 2119 (time=42.38), 0.193799 s/step
# on time step 2140 (time=42.8), 0.195624 s/step
# on time step 2160 (time=43.2), 0.203745 s/step
# on time step 2181 (time=43.62), 0.196077 s/step
# on time step 2202 (time=44.04), 0.196303 s/step
# on time step 2223 (time=44.46), 0.195788 s/step
# on time step 2244 (time=44.88), 0.197017 s/step
# on time step 2265 (time=45.3), 0.196233 s/step
# on time step 2286 (time=45.72), 0.202365 s/step
# on time step 2307 (time=46.14), 0.197711 s/step
# on time step 2328 (time=46.56), 0.198362 s/step
# on time step 2349 (time=46.98), 0.197961 s/step
# on time step 2370 (time=47.4), 0.194986 s/step
# on time step 2391 (time=47.82), 0.196876 s/step
# on time step 2412 (time=48.24), 0.203959 s/step
# on time step 2433 (time=48.66), 0.196236 s/step
# on time step 2454 (time=49.08), 0.196087 s/step
# on time step 2475 (time=49.5), 0.19629 s/step
# on time step 2496 (time=49.92), 0.197993 s/step
# field decay(t = 50.08): 0.0008365707667989884 / 0.02566826898123342 = 0.03259163161374933
# on time step 2517 (time=50.34), 0.196503 s/step
# on time step 2538 (time=50.76), 0.202672 s/step
# on time step 2559 (time=51.18), 0.198116 s/step
# on time step 2580 (time=51.6), 0.196453 s/step
# on time step 2601 (time=52.02), 0.195807 s/step
# on time step 2621 (time=52.42), 0.200644 s/step
# on time step 2641 (time=52.82), 0.201438 s/step
# on time step 2661 (time=53.22), 0.201233 s/step
# on time step 2681 (time=53.62), 0.203628 s/step
# on time step 2700 (time=54), 0.212267 s/step
# on time step 2720 (time=54.4), 0.202229 s/step
# on time step 2741 (time=54.82), 0.19924 s/step
# on time step 2762 (time=55.24), 0.196803 s/step
# on time step 2783 (time=55.66), 0.196402 s/step
# on time step 2804 (time=56.08), 0.197568 s/step
# on time step 2825 (time=56.5), 0.194468 s/step
# on time step 2845 (time=56.9), 0.204589 s/step
# on time step 2866 (time=57.32), 0.194645 s/step
# on time step 2887 (time=57.74), 0.196524 s/step
# on time step 2906 (time=58.12), 0.219257 s/step
# on time step 2925 (time=58.5), 0.213177 s/step
# on time step 2944 (time=58.88), 0.211851 s/step
# on time step 2964 (time=59.28), 0.207597 s/step
# on time step 2984 (time=59.68), 0.2015 s/step
# field decay(t = 60.1): 0.0006517567640648496 / 0.02566826898123342 = 0.02539153553912661
# on time step 3005 (time=60.1), 0.198462 s/step
# on time step 3024 (time=60.48), 0.213106 s/step
# on time step 3045 (time=60.9), 0.198182 s/step
# on time step 3066 (time=61.32), 0.196591 s/step
# on time step 3087 (time=61.74), 0.197802 s/step
# on time step 3107 (time=62.14), 0.200486 s/step
# on time step 3127 (time=62.54), 0.201834 s/step
# on time step 3148 (time=62.96), 0.197307 s/step
# on time step 3168 (time=63.36), 0.205305 s/step
# on time step 3189 (time=63.78), 0.198745 s/step
# on time step 3209 (time=64.18), 0.203035 s/step
# on time step 3229 (time=64.58), 0.206751 s/step
# on time step 3248 (time=64.96), 0.214482 s/step
# on time step 3267 (time=65.34), 0.212182 s/step
# on time step 3287 (time=65.74), 0.20561 s/step
# on time step 3307 (time=66.14), 0.203143 s/step
# on time step 3327 (time=66.54), 0.205258 s/step
# on time step 3347 (time=66.94), 0.203993 s/step
# on time step 3366 (time=67.32), 0.212354 s/step
# on time step 3387 (time=67.74), 0.197869 s/step
# on time step 3408 (time=68.16), 0.19881 s/step
# on time step 3429 (time=68.58), 0.197417 s/step
# on time step 3450 (time=69), 0.198402 s/step
# on time step 3471 (time=69.42), 0.196446 s/step
# on time step 3492 (time=69.84), 0.204161 s/step
# field decay(t = 70.12): 0.0003058999775012325 / 0.02566826898123342 = 0.011917436961755469
# on time step 3513 (time=70.26), 0.197348 s/step
# on time step 3534 (time=70.68), 0.197843 s/step
# on time step 3555 (time=71.1), 0.197633 s/step
# on time step 3576 (time=71.52), 0.197409 s/step
# on time step 3597 (time=71.94), 0.198081 s/step
# on time step 3618 (time=72.36), 0.205087 s/step
# on time step 3639 (time=72.78), 0.196839 s/step
# on time step 3660 (time=73.2), 0.196375 s/step
# on time step 3680 (time=73.6), 0.20136 s/step
# on time step 3701 (time=74.02), 0.19766 s/step
# on time step 3721 (time=74.42), 0.207712 s/step
# on time step 3741 (time=74.82), 0.202961 s/step
# on time step 3762 (time=75.24), 0.205292 s/step
# on time step 3783 (time=75.66), 0.198001 s/step
# on time step 3804 (time=76.08), 0.198173 s/step
# on time step 3825 (time=76.5), 0.197552 s/step
# on time step 3845 (time=76.9), 0.200807 s/step
# on time step 3865 (time=77.3), 0.20037 s/step
# on time step 3886 (time=77.72), 0.19747 s/step
# on time step 3906 (time=78.12), 0.205207 s/step
# on time step 3927 (time=78.54), 0.197362 s/step
# on time step 3948 (time=78.96), 0.196777 s/step
# on time step 3968 (time=79.36), 0.200599 s/step
# on time step 3988 (time=79.76), 0.202133 s/step
# field decay(t = 80.14): 6.846553978414145e-05 / 0.02566826898123342 = 0.002667322047863764
# on time step 4008 (time=80.16), 0.205615 s/step
# on time step 4029 (time=80.58), 0.1989 s/step
# on time step 4050 (time=81), 0.206467 s/step
# on time step 4070 (time=81.4), 0.200277 s/step
# on time step 4091 (time=81.82), 0.198805 s/step
# on time step 4111 (time=82.22), 0.201811 s/step
# on time step 4131 (time=82.62), 0.202619 s/step
# on time step 4151 (time=83.02), 0.202353 s/step
# on time step 4171 (time=83.42), 0.202099 s/step
# on time step 4192 (time=83.84), 0.199053 s/step
# on time step 4212 (time=84.24), 0.206173 s/step
# on time step 4233 (time=84.66), 0.197368 s/step
# on time step 4254 (time=85.08), 0.197604 s/step
# on time step 4275 (time=85.5), 0.199244 s/step
# on time step 4296 (time=85.92), 0.197754 s/step
# on time step 4317 (time=86.34), 0.197644 s/step
# on time step 4338 (time=86.76), 0.205188 s/step
# on time step 4359 (time=87.18), 0.199026 s/step
# on time step 4380 (time=87.6), 0.197673 s/step
# on time step 4402 (time=88.04), 0.188603 s/step
# on time step 4424 (time=88.48), 0.187566 s/step
# on time step 4446 (time=88.92), 0.196775 s/step
# on time step 4468 (time=89.36), 0.189443 s/step
# on time step 4490 (time=89.8), 0.185231 s/step
# field decay(t = 90.16): 6.410509718800131e-05 / 0.02566826898123342 = 0.002497445279027963
# on time step 4512 (time=90.24), 0.184665 s/step
# on time step 4534 (time=90.68), 0.188693 s/step
# on time step 4555 (time=91.1), 0.196291 s/step
# on time step 4577 (time=91.54), 0.188392 s/step
# on time step 4599 (time=91.98), 0.189516 s/step
# on time step 4620 (time=92.4), 0.190697 s/step
# on time step 4642 (time=92.84), 0.184326 s/step
# on time step 4663 (time=93.26), 0.198036 s/step
# on time step 4683 (time=93.66), 0.203077 s/step
# on time step 4704 (time=94.08), 0.198966 s/step
# on time step 4725 (time=94.5), 0.191918 s/step
# on time step 4746 (time=94.92), 0.190557 s/step
# on time step 4768 (time=95.36), 0.188923 s/step
# on time step 4789 (time=95.78), 0.198639 s/step
# on time step 4811 (time=96.22), 0.188646 s/step
# on time step 4833 (time=96.66), 0.188875 s/step
# on time step 4855 (time=97.1), 0.188595 s/step
# on time step 4877 (time=97.54), 0.188934 s/step
# on time step 4898 (time=97.96), 0.196362 s/step
# on time step 4920 (time=98.4), 0.188156 s/step
# on time step 4942 (time=98.84), 0.189662 s/step
# on time step 4963 (time=99.26), 0.192483 s/step
# on time step 4984 (time=99.68), 0.193334 s/step
# on time step 5005 (time=100.1), 0.197612 s/step
# field decay(t = 100.18): 3.735145778426262e-05 / 0.02566826898123342 = 0.0014551607594408104
# on time step 5026 (time=100.52), 0.19183 s/step
# on time step 5048 (time=100.96), 0.189478 s/step
# on time step 5069 (time=101.38), 0.191955 s/step
# on time step 5090 (time=101.8), 0.191127 s/step
# on time step 5112 (time=102.24), 0.196646 s/step
# on time step 5134 (time=102.68), 0.189048 s/step
# on time step 5156 (time=103.12), 0.188064 s/step
# on time step 5178 (time=103.56), 0.187682 s/step
# on time step 5200 (time=104), 0.188663 s/step
# on time step 5221 (time=104.42), 0.197889 s/step
# on time step 5242 (time=104.84), 0.191911 s/step
# on time step 5263 (time=105.26), 0.193438 s/step
# on time step 5283 (time=105.66), 0.200313 s/step
# on time step 5303 (time=106.06), 0.201825 s/step
# on time step 5324 (time=106.48), 0.192594 s/step
# on time step 5345 (time=106.9), 0.198492 s/step
# on time step 5364 (time=107.28), 0.213592 s/step
# on time step 5385 (time=107.7), 0.19778 s/step
# on time step 5406 (time=108.12), 0.191554 s/step
# on time step 5426 (time=108.52), 0.201478 s/step
# on time step 5446 (time=108.92), 0.203863 s/step
# on time step 5465 (time=109.3), 0.213406 s/step
# on time step 5485 (time=109.7), 0.200049 s/step
# on time step 5506 (time=110.12), 0.196351 s/step
# field decay(t = 110.2): 1.1581262912533446e-05 / 0.02566826898123342 = 0.00045118986874419687
# run 0 finished at t = 110.2 (5510 timesteps)

# %%
# 투과율과 반사율

wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Rs = np.append(Rs, -refl_flux[i] / total_flux[i])
    Ts = np.append(Ts, tran_flux[i] / total_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "b", label="reflectance")
    plt.plot(wl, Ts, "r", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "g", label="loss")
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"T_R.png")

# %%
# totalflux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

    
if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 1

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_1[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_1[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_1[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_1[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 2

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_2[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_2[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_2[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_2[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 3

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_3[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_3[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_3[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_3[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 4

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_4[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_4[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_4[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_4[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 5

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_5[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_5[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_5[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_5[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 6

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_6[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_6[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_6[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_6[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 7

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_7[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_7[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_7[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_7[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
# 8

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux_8[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux_8[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux_8[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0_8[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"TransmissionEfficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (total_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (total_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (total_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (total_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllTransmission.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / (total_flux[i]))
    Tg = np.append(Tg, green_flux[i] / (total_flux[i]))
    Tb = np.append(Tb, blue_flux[i] / (total_flux[i]))
    Tg0 = np.append(Tg0, green_flux0[i] / (total_flux[i]))

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg+Tg0, "g", label="Greenpixel")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    #plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical Efficiency")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")

# %%
#sum
wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, (red_flux[i]+red_flux_1[i]+red_flux_2[i]+red_flux_3[i]+red_flux_4[i]+red_flux_5[i]+red_flux_6[i]+red_flux_7[i]+red_flux_8[i]) / (tran_flux[i]))
    Tg = np.append(Tg, (green_flux[i]+green_flux_1[i]+green_flux_2[i]+green_flux_3[i]+green_flux_4[i]+green_flux_5[i]+green_flux_6[i]+green_flux_7[i]+green_flux_8[i]) / (tran_flux[i]))
    Tg0 = np.append(Tg0, (green_flux0[i]+green_flux0_1[i]+green_flux0_2[i]+green_flux0_3[i]+green_flux0_4[i]+green_flux0_5[i]+green_flux0_6[i]+green_flux0_7[i]+green_flux0_8[i]) / (tran_flux[i]))
    Tb = np.append(Tb, (blue_flux[i]+blue_flux_1[i]+blue_flux_2[i]+blue_flux_3[i]+blue_flux_4[i]+blue_flux_5[i]+blue_flux_6[i]+blue_flux_7[i]+blue_flux_8[i]) / (tran_flux[i]))
    s = Tr+Tg+Tb+Tg0

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Tr, "r", label="Redpixel")
    plt.plot(wl, Tg, "g", label="Greenpixel1")
    plt.plot(wl, Tb, "b", label="Bluepixel")
    plt.plot(wl, Tg0, color='limegreen', label="Greenpixel2")
    plt.plot(wl, s,  "k", label="Allpixel")
    
    plt.axis([0.40, 0.70, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Transmittance")
    plt.fill([0.40, 0.40, 0.50, 0.50], [0.0, 1.0, 1.0, 0.0], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [0.0, 1.0, 1.0, 0.0], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [0.0, 1.0, 1.0, 0.0], color='lightcoral', alpha=0.5)
    plt.legend(loc="upper right")
    plt.savefig(design_dir+"AllOpticalEffeciency.png")

# %%
# 입사 flux 대비 효율

wl = []
Tr = []
Tg = []
Tb = []
Tg0 = []

Trt = []
Tgt = []
Tbt = []
Tg0t = []
convenional=[]
for i in range(nfreq):
    wl = np.append(wl, 1 / (flux_freqs[i] * um_scale))
    Tr = np.append(Tr, red_flux[i] / tran_flux[i])
    Tg = np.append(Tg, green_flux[i] /tran_flux[i])
    Tb = np.append(Tb, blue_flux[i] / tran_flux[i])
    Tg0 = np.append(Tg0, green_flux0[i] / tran_flux[i])

    Trt = np.append(Trt, red_flux[i] / total_flux[i])
    Tgt = np.append(Tgt, green_flux[i] / total_flux[i])
    Tbt = np.append(Tbt, blue_flux[i] / total_flux[i])
    Tg0t = np.append(Tg0t, green_flux0[i] / total_flux[i])

    convenional = np.append(convenional,0.25)
if mp.am_master():
    plt.figure(dpi=300)
    plt.plot(wl, Tr, "r",)
    plt.plot(wl, Tg+Tg0, "g",)
    plt.plot(wl, Tb, "b",)
    plt.plot(wl, Trt, "r--",)
    plt.plot(wl, Tgt+Tg0t, "g--",)
    plt.plot(wl, Tbt, "b--",)
    plt.plot(wl, convenional, 'k--')
    
    plt.axis([0.40, 0.70, 0.0, 1.0])
    plt.xlabel("wavelength (μm)")
    plt.ylabel("Optical efficiency (in-pixel)")
    plt.fill([0.40, 0.40, 0.50, 0.50], [-0.03, 1.03, 1.03, -0.03], color='lightblue', alpha=0.5)
    plt.fill([0.50, 0.50, 0.60, 0.60], [-0.03, 1.03, 1.03, -0.03], color='lightgreen', alpha=0.5)
    plt.fill([0.60, 0.60, 0.70, 0.70], [-0.03, 1.03, 1.03, -0.03], color='lightcoral', alpha=0.5)
    plt.tick_params(axis='x', direction='in', pad = 8)
    plt.tick_params(axis='y', direction='in', pad = 10)
    #plt.show()
    plt.savefig(design_dir+"Optical Efficiency.png")
