# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
import nlopt
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

SiO2 = mp.Medium(index=1.5*1.5)
resolution = 100

diameter_values = [10.0, 5.0, 2.5, 2.0, 1.5, 1.0, 0.5]

for diameter_val in diameter_values:
    # Update diameter in the simulation parameters
    diameter = diameter_val

    # Constants
    PI = np.pi

    # Constants
    a = 1.0
    scale_down = 1

    # Parameters of the Plano convex lens
    d = (diameter / (a * scale_down)) / 2.0
    focal = d * math.sqrt(21.0) / 2.0
    r_cur = focal / (2 * a * scale_down)

    # Geometry properties
    Lpml = 0.25 * d
    Lx = diameter / (a * scale_down) + Lpml * 2
    Ly = Lpml + 0.25 * d + focal + r_cur - math.sqrt(r_cur * r_cur - d * d) + 0.5 * d + Lpml 

    pml_layers = [mp.PML(thickness=Lpml,)]

    # Position information
    src_ypos =  - Ly / 2 + Lpml + 0.25 * d
    transmission_ypos = Lpml + 1.0
    lens_ypos = - Ly / 2 + Lpml + 0.5 * d + math.sqrt(r_cur * r_cur - d * d)
    x_center = 0
    y_center = lens_ypos + math.sqrt(r_cur * r_cur - d * d)

    # Source settings
    width = 0.1

    fcen_red = 1/(0.65)
    fwidth_red = fcen_red * width

    fcen_green = 1/(0.55)
    fwidth_green = fcen_green * width

    fcen_blue = 1/(0.45)
    fwidth_blue = fcen_blue * width

    src_0 = mp.GaussianSource(frequency=fcen_red, fwidth=fwidth_red, is_integrated=True)
    src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=fwidth_green, is_integrated=True)
    src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=fwidth_blue, is_integrated=True)

    source_center = [0, src_ypos] # Source position
    source_size = mp.Vector3(Lx)

    source = [mp.Source(src_0, component=mp.Ez, size=source_size, center=source_center,)]

    cell = mp.Vector3(math.ceil(Lx*10)/10, math.ceil(Ly*10)/10)

    geometry = []
    for pos_x in np.arange(-10, 10, 0.01):
        for pos_y in np.arange(-10, 10, 0.01):
            if pos_y <= (lens_ypos):
                if ((pos_x - x_center) ** 2 + (pos_y - y_center) ** 2 <= (r_cur ** 2)):
                    geometry.append(mp.Block(center=mp.Vector3(pos_x, pos_y), size=mp.Vector3(0.5/resolution, 0.5/resolution), material=SiO2))

    sim = mp.Simulation(
        cell_size=cell, 
        boundary_layers=pml_layers,
        geometry=geometry,
        sources=source,
        resolution=resolution,
    )
    sim.plot2D()
    
    tran_total0 = sim.add_dft_fields([mp.Ez], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(Lx - 2 * Lpml ,Ly - 2 * Lpml), yee_grid=True)


    tran_Ex = sim.add_dft_fields([mp.Ex], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(Lx - 2 * Lpml ,Ly - 2 * Lpml), yee_grid=True)
    tran_Ey = sim.add_dft_fields([mp.Ey], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(Lx - 2 * Lpml ,Ly - 2 * Lpml), yee_grid=True)
    tran_Ez = sim.add_dft_fields([mp.Ez], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(Lx - 2 * Lpml ,Ly - 2 * Lpml), yee_grid=True)
    tran_Hx = sim.add_dft_fields([mp.Hx], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(Lx - 2 * Lpml ,Ly - 2 * Lpml), yee_grid=True)
    tran_Hy = sim.add_dft_fields([mp.Hy], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(Lx - 2 * Lpml ,Ly - 2 * Lpml), yee_grid=True)
    tran_Hz = sim.add_dft_fields([mp.Hz], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(Lx - 2 * Lpml ,Ly - 2 * Lpml), yee_grid=True)
    pt = mp.Vector3(0,lens_ypos-focal,0)

    sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, pt, 1e-3)) 

    Ex_Namei="Ex_field"
    Ey_Namei="Ey_field"
    Ez_Namei="Ez_field"

    Hx_Namei="Hx_field"
    Hy_Namei="Hy_field"
    Hz_Namei="Hz_field"



    sim.output_dft(tran_Ex,str(diameter)+Ex_Namei)
    sim.output_dft(tran_Ey,str(diameter)+Ey_Namei)
    sim.output_dft(tran_Ez,str(diameter)+Ez_Namei)

    sim.output_dft(tran_Hx,str(diameter)+Hx_Namei)
    sim.output_dft(tran_Hy,str(diameter)+Hy_Namei)
    sim.output_dft(tran_Hz,str(diameter)+Hz_Namei)

    sim.reset_meep()
# Out:
#      block, center = (-4.99,-3.79,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.99,-3.78,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-3.81,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-3.8,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-3.79,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-3.78,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-3.82,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-3.81,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-3.8,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-3.79,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 208353 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.482984 s
# Working in 2D dimensions.
# Computational cell is 12.5 x 20.7 x 0 with resolution 100
#      block, center = (-4.99,-3.79,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.99,-3.78,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-3.81,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-3.8,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-3.79,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-3.78,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-3.82,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-3.81,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-3.8,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-3.79,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 208353 objects not shown)...
# time for set_epsilon = 7.41992 s
# -----------
# on time step 335 (time=1.675), 0.0119464 s/step
# on time step 679 (time=3.395), 0.0116512 s/step
# on time step 1023 (time=5.115), 0.0116561 s/step
# on time step 1364 (time=6.82), 0.0117823 s/step
# on time step 1704 (time=8.52), 0.0117806 s/step
# on time step 2048 (time=10.24), 0.0116602 s/step
# on time step 2387 (time=11.935), 0.0118086 s/step
# on time step 2728 (time=13.64), 0.0117855 s/step
# on time step 3071 (time=15.355), 0.0116898 s/step
# on time step 3410 (time=17.05), 0.0118193 s/step
# on time step 3750 (time=18.75), 0.0117731 s/step
# on time step 4091 (time=20.455), 0.0117469 s/step
# on time step 4434 (time=22.17), 0.0116858 s/step
# on time step 4773 (time=23.865), 0.0118336 s/step
# on time step 5115 (time=25.575), 0.0117009 s/step
# on time step 5457 (time=27.285), 0.0117268 s/step
# on time step 5797 (time=28.985), 0.011784 s/step
# on time step 6141 (time=30.705), 0.0116483 s/step
# on time step 6486 (time=32.43), 0.0116156 s/step
# on time step 6828 (time=34.14), 0.0117142 s/step
# on time step 7166 (time=35.83), 0.0118669 s/step
# on time step 7506 (time=37.53), 0.0117715 s/step
# on time step 7844 (time=39.22), 0.011835 s/step
# on time step 8187 (time=40.935), 0.0116627 s/step
# on time step 8522 (time=42.61), 0.0119697 s/step
# on time step 8851 (time=44.255), 0.0121637 s/step
# on time step 9185 (time=45.925), 0.0120029 s/step
# on time step 9516 (time=47.58), 0.0121168 s/step
# on time step 9851 (time=49.255), 0.0119447 s/step
# on time step 10191 (time=50.955), 0.0117767 s/step
# on time step 10534 (time=52.67), 0.0116742 s/step
# on time step 10877 (time=54.385), 0.0116718 s/step
# on time step 11220 (time=56.1), 0.0116746 s/step
# on time step 11565 (time=57.825), 0.011618 s/step
# on time step 11911 (time=59.555), 0.0115828 s/step
# on time step 12256 (time=61.28), 0.0116043 s/step
# on time step 12601 (time=63.005), 0.011609 s/step
# on time step 12949 (time=64.745), 0.0115016 s/step
# on time step 13294 (time=66.47), 0.0116031 s/step
# on time step 13643 (time=68.215), 0.0114748 s/step
# on time step 13994 (time=69.97), 0.011409 s/step
# on time step 14344 (time=71.72), 0.0114347 s/step
# on time step 14694 (time=73.47), 0.0114643 s/step
# on time step 15040 (time=75.2), 0.0115848 s/step
# on time step 15383 (time=76.915), 0.0116842 s/step
# on time step 15728 (time=78.64), 0.0116187 s/step
# on time step 16068 (time=80.34), 0.011787 s/step
# on time step 16413 (time=82.065), 0.0116014 s/step
# on time step 16759 (time=83.795), 0.0115716 s/step
# on time step 17102 (time=85.51), 0.0116648 s/step
# on time step 17426 (time=87.13), 0.0123616 s/step
# on time step 17740 (time=88.7), 0.0127466 s/step
# on time step 18078 (time=90.39), 0.0118408 s/step
# on time step 18388 (time=91.94), 0.0129365 s/step
# on time step 18744 (time=93.72), 0.0112601 s/step
# on time step 19099 (time=95.495), 0.0112695 s/step
# on time step 19456 (time=97.28), 0.0112261 s/step
# on time step 19804 (time=99.02), 0.0114959 s/step
# run 0 finished at t = 100.01 (20002 timesteps)
#      block, center = (-2.49,-1.9,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.49,-1.89,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.48,-1.92,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.48,-1.91,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.48,-1.9,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.48,-1.89,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.47,-1.93,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.47,-1.92,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.47,-1.91,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.47,-1.9,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 52199 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.125507 s
# Working in 2D dimensions.
# Computational cell is 6.3 x 10.4 x 0 with resolution 100
#      block, center = (-2.49,-1.9,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.49,-1.89,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.48,-1.92,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.48,-1.91,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.48,-1.9,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.48,-1.89,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.47,-1.93,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.47,-1.92,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.47,-1.91,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-2.47,-1.9,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 52199 objects not shown)...
# time for set_epsilon = 1.61861 s
# -----------
# on time step 1447 (time=7.235), 0.00276611 s/step
# on time step 2880 (time=14.4), 0.00279295 s/step
# on time step 4309 (time=21.545), 0.00279922 s/step
# on time step 5818 (time=29.09), 0.00265121 s/step
# on time step 7337 (time=36.685), 0.00263366 s/step
# on time step 8855 (time=44.275), 0.00263635 s/step
# on time step 10381 (time=51.905), 0.0026216 s/step
# on time step 11877 (time=59.385), 0.00267499 s/step
# on time step 13284 (time=66.42), 0.0028448 s/step
# on time step 14690 (time=73.45), 0.00284599 s/step
# on time step 16108 (time=80.54), 0.00282249 s/step
# on time step 17537 (time=87.685), 0.00280048 s/step
# on time step 18999 (time=94.995), 0.00273697 s/step
# run 0 finished at t = 100.01 (20002 timesteps)
#      block, center = (-1.24,-0.96,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.24,-0.95,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.23,-0.97,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.23,-0.96,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.23,-0.95,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.99,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.98,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.97,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.96,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.95,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 12977 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0304539 s
# Working in 2D dimensions.
# Computational cell is 3.2 x 5.2 x 0 with resolution 100
#      block, center = (-1.24,-0.96,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.24,-0.95,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.23,-0.97,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.23,-0.96,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.23,-0.95,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.99,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.98,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.97,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.96,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-1.22,-0.95,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 12977 objects not shown)...
# time for set_epsilon = 0.383332 s
# -----------
# on time step 8565 (time=42.825), 0.000467019 s/step
# on time step 17348 (time=86.74), 0.00045543 s/step
# run 0 finished at t = 100.01 (20002 timesteps)
#      block, center = (-0.99,-0.77,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.99,-0.76,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.98,-0.78,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.98,-0.77,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.98,-0.76,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.8,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.79,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.78,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.77,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.76,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 8327 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.019985 s
# Working in 2D dimensions.
# Computational cell is 2.5 x 4.2 x 0 with resolution 100
#      block, center = (-0.99,-0.77,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.99,-0.76,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.98,-0.78,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.98,-0.77,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.98,-0.76,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.8,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.79,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.78,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.77,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.97,-0.76,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 8327 objects not shown)...
# time for set_epsilon = 0.239361 s
# -----------
# on time step 13331 (time=66.655), 0.000300073 s/step
# run 0 finished at t = 100.01 (20002 timesteps)
#      block, center = (-0.74,-0.58,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.74,-0.57,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.73,-0.6,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.73,-0.59,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.73,-0.58,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.73,-0.57,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.72,-0.61,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.72,-0.6,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.72,-0.59,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.72,-0.58,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 4702 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0111089 s
# Working in 2D dimensions.
# Computational cell is 1.9 x 3.1 x 0 with resolution 100
#      block, center = (-0.74,-0.58,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.74,-0.57,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.73,-0.6,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.73,-0.59,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.73,-0.58,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.73,-0.57,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.72,-0.61,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.72,-0.6,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.72,-0.59,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.72,-0.58,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 4702 objects not shown)...
# time for set_epsilon = 0.125862 s
# -----------
# run 0 finished at t = 100.01 (20002 timesteps)
#      block, center = (-0.49,-0.39,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.49,-0.38,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.48,-0.41,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.48,-0.4,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.48,-0.39,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.48,-0.38,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.47,-0.42,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.47,-0.41,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.47,-0.4,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.47,-0.39,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 2096 objects not shown)...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00494814 s
# Working in 2D dimensions.
# Computational cell is 1.3 x 2.1 x 0 with resolution 100
#      block, center = (-0.49,-0.39,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.49,-0.38,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.48,-0.41,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.48,-0.4,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.48,-0.39,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.48,-0.38,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.47,-0.42,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.47,-0.41,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.47,-0.4,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.47,-0.39,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 2096 objects not shown)...
# time for set_epsilon = 0.0557871 s
# -----------
# run 0 finished at t = 100.01 (20002 timesteps)
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
#      block, center = (-0.24,-0.2,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.24,-0.19,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.23,-0.21,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.23,-0.2,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.23,-0.19,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.23,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.22,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.21,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.2,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.19,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 529 objects not shown)...
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00129104 s
# Working in 2D dimensions.
# Computational cell is 0.7 x 1.1 x 0 with resolution 100
#      block, center = (-0.24,-0.2,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.24,-0.19,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.23,-0.21,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.23,-0.2,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.23,-0.19,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.23,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.22,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.21,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.2,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-0.22,-0.19,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 529 objects not shown)...
# time for set_epsilon = 0.0153449 s
# -----------
# run 0 finished at t = 100.01 (20002 timesteps)
