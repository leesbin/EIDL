# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
import nlopt
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
from matplotlib import pyplot as plt
import os
import math

mp.verbosity(1)

SiO2 = mp.Medium(index=1.5*1.5)



# Constants
PI = np.pi

import math

# Constants
diameter = 10
a = 1.0
scale_down = 1

# Geometry properties
Lx = diameter / (a * scale_down)
Ly = 2.0 * Lx
resolution = 100
Lpml = 0.25

pml_layers = [mp.PML(thickness = Lpml,)]

# Position information
src_ypos = Ly - Lpml - 0.25
transmission_ypos = Lpml + 1.0


# Parameters of the Plano convex lens
d = (diameter / (a * scale_down)) / 2.0
focal = d * math.sqrt(21.0) / 2.0
r_cur = focal / (2 * a * scale_down)
sin_NA = d / math.sqrt(d * d + focal * focal)
k_airy = 2.0 * math.pi / 1.0
airy_NA = 0.38317 * Lx / 2.0
lens_ypos = src_ypos - 0.5
x_center = Lx / 2.0
y_center = lens_ypos + math.sqrt(r_cur * r_cur - d * d)


# source 설정
width = 0.1

fcen_red = 1/(0.65)
fwidth_red = fcen_red * width

fcen_green = 1/(0.55)
fwidth_green = fcen_green * width

fcen_blue = 1/(0.45)
fwidth_blue = fcen_blue * width

src_0 = mp.GaussianSource(frequency=fcen_red, fwidth=fwidth_red, is_integrated=True)

src_1 = mp.GaussianSource(frequency=fcen_green, fwidth=fwidth_green, is_integrated=True)

src_2 = mp.GaussianSource(frequency=fcen_blue, fwidth=fwidth_blue, is_integrated=True)

source_center = [0, -18] # Source 위치
source_size = mp.Vector3(d*2)

source = [mp.Source(src_0, component=mp.Ez, size=source_size, center=source_center,)]


print(focal)
print(y_center)
print(lens_ypos)
print(r_cur)
# Out:
# 11.4564392373896
# 21.795084971874736
# 19.0
# 5.7282196186948

# %%
cell = mp.Vector3(d*2+Lpml*2,40)
# cell = mp.Vector3(10, 10)

geometry = [
    # mp.Block(
    #     center=mp.Vector3(y=lens_ypos-et/2), size=mp.Vector3(d*2,et), material=SiO2
    # )
]
for pos_x in np.arange(-20, 20, 0.01):
    for pos_y in np.arange(-20, 20, 0.01):
        if pos_y<=(lens_ypos):
            if ((pos_x-x_center)*(pos_x-x_center) + (pos_y-y_center)*(pos_y-y_center) <= (r_cur*r_cur)):
                geometry.append(mp.Block(center=mp.Vector3(pos_x -diameter/2, pos_y-diameter/2-25), size=mp.Vector3(0.5/resolution, 0.5/resolution), material=SiO2))
    
            
sim = mp.Simulation(
    cell_size=cell, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    resolution=resolution,
)
sim.plot2D()
# Out:
#      block, center = (-4.99,-11.01,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-11.03,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-11.02,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-11.01,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.05,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.04,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.03,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.02,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.01,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.96,-11.07,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 207897 objects not shown)...
# <Axes: xlabel='X', ylabel='Y'>

# %%
tran_Ex = sim.add_dft_fields([mp.Ex], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(d*2+Lpml*4,40), yee_grid=True)
tran_Ey = sim.add_dft_fields([mp.Ey], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(d*2+Lpml*4,40), yee_grid=True)
tran_Ez = sim.add_dft_fields([mp.Ez], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(d*2+Lpml*4,40), yee_grid=True)
tran_Hx = sim.add_dft_fields([mp.Hx], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(d*2+Lpml*4,40), yee_grid=True)
tran_Hy = sim.add_dft_fields([mp.Hy], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(d*2+Lpml*4,40), yee_grid=True)
tran_Hz = sim.add_dft_fields([mp.Hz], fcen_red, 0 , 1, center=mp.Vector3(0, 0, 0), size=mp.Vector3(d*2+Lpml*4,40), yee_grid=True)
pt = mp.Vector3(0,lens_ypos-focal,0)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, pt, 1e-3))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.51166 s
# Working in 2D dimensions.
# Computational cell is 10.5 x 40 x 0 with resolution 100
#      block, center = (-4.99,-11.01,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-11.03,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-11.02,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.98,-11.01,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.05,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.04,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.03,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.02,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.97,-11.01,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      block, center = (-4.96,-11.07,0)
#           size (0.005,0.005,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (5.0625,5.0625,5.0625)
#      ...(+ 207897 objects not shown)...
# time for set_epsilon = 10.6832 s
# -----------
# on time step 167 (time=0.835), 0.024077 s/step
# on time step 340 (time=1.7), 0.0231792 s/step
# on time step 513 (time=2.565), 0.0231364 s/step
# on time step 687 (time=3.435), 0.023117 s/step
# on time step 872 (time=4.36), 0.0216494 s/step
# on time step 1097 (time=5.485), 0.0178249 s/step
# on time step 1350 (time=6.75), 0.0158465 s/step
# on time step 1558 (time=7.79), 0.0193171 s/step
# on time step 1753 (time=8.765), 0.020559 s/step
# on time step 1939 (time=9.695), 0.0217691 s/step
# on time step 2113 (time=10.565), 0.0230777 s/step
# on time step 2289 (time=11.445), 0.0228154 s/step
# on time step 2463 (time=12.315), 0.0230815 s/step
# on time step 2637 (time=13.185), 0.0230642 s/step
# on time step 2811 (time=14.055), 0.0231129 s/step
# on time step 2984 (time=14.92), 0.0232461 s/step
# on time step 3158 (time=15.79), 0.0230425 s/step
# on time step 3343 (time=16.715), 0.0216674 s/step
# on time step 3559 (time=17.795), 0.0185231 s/step
# on time step 3813 (time=19.065), 0.0157676 s/step
# on time step 4031 (time=20.155), 0.0183629 s/step
# on time step 4226 (time=21.13), 0.0205492 s/step
# on time step 4415 (time=22.075), 0.0212594 s/step
# on time step 4586 (time=22.93), 0.0234972 s/step
# on time step 4760 (time=23.8), 0.0230119 s/step
# on time step 4934 (time=24.67), 0.023111 s/step
# on time step 5107 (time=25.535), 0.0231314 s/step
# on time step 5280 (time=26.4), 0.023208 s/step
# on time step 5455 (time=27.275), 0.022939 s/step
# on time step 5628 (time=28.14), 0.0231359 s/step
# on time step 5813 (time=29.065), 0.0217288 s/step
# on time step 6017 (time=30.085), 0.0196142 s/step
# on time step 6270 (time=31.35), 0.0158324 s/step
# on time step 6498 (time=32.49), 0.0176086 s/step
# on time step 6693 (time=33.465), 0.020547 s/step
# on time step 6883 (time=34.415), 0.0211386 s/step
# on time step 7052 (time=35.26), 0.0237481 s/step
# on time step 7226 (time=36.13), 0.0230779 s/step
# on time step 7400 (time=37), 0.0230402 s/step
# on time step 7573 (time=37.865), 0.0231621 s/step
# on time step 7735 (time=38.675), 0.0248072 s/step
# on time step 7894 (time=39.47), 0.0252971 s/step
# on time step 8055 (time=40.275), 0.0249561 s/step
# on time step 8225 (time=41.125), 0.0235535 s/step
# on time step 8414 (time=42.07), 0.0211668 s/step
# on time step 8641 (time=43.205), 0.0176564 s/step
# on time step 8882 (time=44.41), 0.0166521 s/step
# on time step 9052 (time=45.26), 0.0239418 s/step
# on time step 9232 (time=46.16), 0.0223158 s/step
# on time step 9381 (time=46.905), 0.0269657 s/step
# on time step 9556 (time=47.78), 0.0229674 s/step
# on time step 9724 (time=48.62), 0.0238502 s/step
# on time step 9896 (time=49.48), 0.0233404 s/step
# field decay(t = 50.005): 0.15748103402078084 / 0.15748103402078084 = 1.0
# on time step 10070 (time=50.35), 0.0230548 s/step
# on time step 10242 (time=51.21), 0.0233944 s/step
# on time step 10409 (time=52.045), 0.0239927 s/step
# on time step 10579 (time=52.895), 0.0236122 s/step
# on time step 10769 (time=53.845), 0.0211341 s/step
# on time step 10965 (time=54.825), 0.0204383 s/step
# on time step 11213 (time=56.065), 0.01614 s/step
# on time step 11458 (time=57.29), 0.0164002 s/step
# on time step 11654 (time=58.27), 0.0204377 s/step
# on time step 11834 (time=59.17), 0.0222294 s/step
# on time step 12008 (time=60.04), 0.0230746 s/step
# on time step 12167 (time=60.835), 0.0253052 s/step
# on time step 12323 (time=61.615), 0.0256834 s/step
# on time step 12488 (time=62.44), 0.0242424 s/step
# on time step 12661 (time=63.305), 0.0231779 s/step
# on time step 12835 (time=64.175), 0.0230569 s/step
# on time step 13010 (time=65.05), 0.0229888 s/step
# on time step 13188 (time=65.94), 0.0225256 s/step
# on time step 13383 (time=66.915), 0.020567 s/step
# on time step 13588 (time=67.94), 0.019522 s/step
# on time step 13836 (time=69.18), 0.016157 s/step
# on time step 14055 (time=70.275), 0.0183217 s/step
# on time step 14245 (time=71.225), 0.0211166 s/step
# on time step 14422 (time=72.11), 0.0226286 s/step
# on time step 14587 (time=72.935), 0.0242498 s/step
# on time step 14761 (time=73.805), 0.0230577 s/step
# on time step 14931 (time=74.655), 0.0236133 s/step
# on time step 15101 (time=75.505), 0.0235844 s/step
# on time step 15268 (time=76.34), 0.0239651 s/step
# on time step 15438 (time=77.19), 0.0237732 s/step
# on time step 15610 (time=78.05), 0.0233055 s/step
# on time step 15788 (time=78.94), 0.02249 s/step
# on time step 15992 (time=79.96), 0.0196098 s/step
# on time step 16210 (time=81.05), 0.0183696 s/step
# on time step 16439 (time=82.195), 0.0174754 s/step
# on time step 16653 (time=83.265), 0.0187538 s/step
# on time step 16830 (time=84.15), 0.0226387 s/step
# on time step 16987 (time=84.935), 0.0256222 s/step
# on time step 17159 (time=85.795), 0.0233538 s/step
# on time step 17324 (time=86.62), 0.0242575 s/step
# on time step 17478 (time=87.39), 0.026038 s/step
# on time step 17641 (time=88.205), 0.0245588 s/step
# on time step 17810 (time=89.05), 0.0237186 s/step
# on time step 17980 (time=89.9), 0.0237192 s/step
# on time step 18144 (time=90.72), 0.0245298 s/step
# on time step 18304 (time=91.52), 0.0250137 s/step
# on time step 18494 (time=92.47), 0.0210895 s/step
# on time step 18700 (time=93.5), 0.0194236 s/step
# on time step 18942 (time=94.71), 0.0165909 s/step
# on time step 19113 (time=95.565), 0.0234455 s/step
# on time step 19296 (time=96.48), 0.0218966 s/step
# on time step 19463 (time=97.315), 0.0240546 s/step
# on time step 19636 (time=98.18), 0.02325 s/step
# on time step 19808 (time=99.04), 0.0232868 s/step
# on time step 19977 (time=99.885), 0.0236721 s/step
# field decay(t = 100.01): 0.8823973349222437 / 0.8823973349222437 = 1.0
# on time step 20148 (time=100.74), 0.0235008 s/step
# on time step 20320 (time=101.6), 0.023316 s/step
# on time step 20483 (time=102.415), 0.0247019 s/step
# on time step 20631 (time=103.155), 0.0271179 s/step
# on time step 20778 (time=103.89), 0.0272631 s/step
# on time step 20932 (time=104.66), 0.0260836 s/step
# on time step 21135 (time=105.675), 0.0197181 s/step
# on time step 21384 (time=106.92), 0.0161205 s/step
# on time step 21634 (time=108.17), 0.0160608 s/step
# on time step 21840 (time=109.2), 0.0194388 s/step
# on time step 22005 (time=110.025), 0.0243738 s/step
# on time step 22178 (time=110.89), 0.0231991 s/step
# on time step 22324 (time=111.62), 0.0274717 s/step
# on time step 22502 (time=112.51), 0.0226041 s/step
# on time step 22671 (time=113.355), 0.0236754 s/step
# on time step 22817 (time=114.085), 0.027536 s/step
# on time step 22986 (time=114.93), 0.0237985 s/step
# on time step 23126 (time=115.63), 0.0287915 s/step
# on time step 23275 (time=116.375), 0.0269637 s/step
# on time step 23470 (time=117.35), 0.0205909 s/step
# on time step 23665 (time=118.325), 0.0205932 s/step
# on time step 23889 (time=119.445), 0.0178803 s/step
# on time step 24117 (time=120.585), 0.0175696 s/step
# on time step 24323 (time=121.615), 0.0194989 s/step
# on time step 24491 (time=122.455), 0.023811 s/step
# on time step 24661 (time=123.305), 0.0236328 s/step
# on time step 24813 (time=124.065), 0.0263371 s/step
# on time step 24978 (time=124.89), 0.0243471 s/step
# on time step 25138 (time=125.69), 0.025005 s/step
# on time step 25302 (time=126.51), 0.0244181 s/step
# on time step 25456 (time=127.28), 0.0261186 s/step
# on time step 25608 (time=128.04), 0.0264091 s/step
# on time step 25777 (time=128.885), 0.0237877 s/step
# on time step 25945 (time=129.725), 0.023934 s/step
# on time step 26108 (time=130.54), 0.024585 s/step
# on time step 26322 (time=131.61), 0.0187094 s/step
# on time step 26551 (time=132.755), 0.0175179 s/step
# on time step 26720 (time=133.6), 0.0237415 s/step
# on time step 26868 (time=134.34), 0.0271414 s/step
# on time step 27019 (time=135.095), 0.0266744 s/step
# on time step 27156 (time=135.78), 0.0295242 s/step
# on time step 27323 (time=136.615), 0.0239602 s/step
# on time step 27472 (time=137.36), 0.0268531 s/step
# on time step 27625 (time=138.125), 0.0262698 s/step
# on time step 27794 (time=138.97), 0.0238003 s/step
# on time step 27962 (time=139.81), 0.0238788 s/step
# on time step 28148 (time=140.74), 0.021704 s/step
# on time step 28341 (time=141.705), 0.0208298 s/step
# on time step 28520 (time=142.6), 0.0227398 s/step
# on time step 28698 (time=143.49), 0.0225126 s/step
# on time step 28872 (time=144.36), 0.0230492 s/step
# on time step 29017 (time=145.085), 0.0276241 s/step
# on time step 29185 (time=145.925), 0.0238234 s/step
# on time step 29358 (time=146.79), 0.0232015 s/step
# on time step 29529 (time=147.645), 0.0234009 s/step
# on time step 29683 (time=148.415), 0.0260694 s/step
# on time step 29834 (time=149.17), 0.0265112 s/step
# on time step 29990 (time=149.95), 0.0257092 s/step
# field decay(t = 150.01500000000001): 4.427547947197542e-14 / 0.8823973349222437 = 5.0176352216518136e-14
# run 0 finished at t = 150.01500000000001 (30003 timesteps)

# %%
Ex_Namei="Ex_r_field"
Ey_Namei="Ey_r_field"
Ez_Namei="Ez_r_field"

Hx_Namei="Hx_r_field"
Hy_Namei="Hy_r_field"
Hz_Namei="Hz_r_field"



sim.output_dft(tran_Ex,str(diameter)+".0"+Ex_Namei)
sim.output_dft(tran_Ey,str(diameter)+".0"+Ey_Namei)
sim.output_dft(tran_Ez,str(diameter)+".0"+Ez_Namei)

sim.output_dft(tran_Hx,str(diameter)+".0"+Hx_Namei)
sim.output_dft(tran_Hy,str(diameter)+".0"+Hy_Namei)
sim.output_dft(tran_Hz,str(diameter)+".0"+Hz_Namei)

# %%
# total_flux0 = np.abs(sim.get_dft_array(tran_total0, mp.Ez, 0))**2


# plt.imshow(npa.rot90(total_flux0.reshape(diameter* resolution+1, diameter*2* resolution+1)))
# plt.colorbar()

# %%
sim.reset_meep()
