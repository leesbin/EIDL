# %%
# Design CIS 3D color router
# Resoultion 20 
# RGGB pattern
# Elapsed run time = 33956.9432 s


# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
import nlopt
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
from matplotlib import pyplot as plt
import os

mp.verbosity(1)

seed = 240  # 난수 발생 시드(seed)를 240으로 설정 (재현성을 위해 난수 시드를 고정)
np.random.seed(seed)  # numpy의 난수 생성기의 시드를 설정하여 난수의 재현성 보장

design_dir = "./CIS_design/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 1 # 1A = 675nm

Air = mp.Medium(index=1.0)
SiN = mp.Medium(index=1.5)
SiO2 = mp.Medium(index=1.5)
HfO2 = mp.Medium(index=1.9)
# SiPD = mp.Medium(epsilon=11.8)

# 해상도 및 사이즈 설정
resolution = 20 # 1 pixel = 27nm
Lpml = 0.5 # PML 영역 크기
pml_layers = [mp.PML(thickness = Lpml, direction = mp.Z)]
Sourcespace = 0.5

# 설계 공간
design_region_width_x = 0.5 # 디자인 영역 x
design_region_width_y = 0.5 # 디자인 영역 y
design_region_height = 0.5 # 디자인 영역 높이 z

# 전체 공간
Sx = design_region_width_x+0.1
Sy = design_region_width_y+0.1
Sz = Lpml + design_region_height + Sourcespace + 1 + Lpml
cell_size = mp.Vector3(Sx, Sy, Sz)

# 파장, 주파수 설정
wavelengths = np.array([0.5])
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# Fabrication Constraints 설정

minimum_length = 0.027 * um_scale # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)


# source 설정
fcen = 1 / 0.5
width = 0.1
fwidth = width * fcen

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2 ] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)
src = mp.GaussianSource(frequency=fcen, fwidth=fwidth)

source = [mp.Source(src, component=mp.Ex, size=source_size, center=source_center,),]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * design_region_width_x)) 
Ny = int(round(design_region_resolution * design_region_width_y)) 
Nz = int(round(design_region_resolution * design_region_height))

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), Air, SiN, grid_type="U_MEAN",do_averaging=False)
design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x, design_region_width_y, design_region_height),
    ),
)

# 대각선대칭

def mapping(x, eta, beta):
    x_copy = (x.reshape(Nx * Ny, Nz)).transpose()

    # projection
    z = 0
    x2 = []

    while z < Nz:
        
        number = z
        x1 = x_copy[int(number)]
        
        # filter
        filtered_field = mpa.conic_filter(
            x1,
            filter_radius,
            0.88,
            0.88,
            design_region_resolution,
        )
        
        z_slice = ((filtered_field.reshape(Nx, Ny)) + filtered_field.reshape(Nx, Ny).transpose()) / 2
        x2 = npa.concatenate((x2,z_slice.flatten()),axis=0) 
        z = z + 1

    x2 = ((x2.reshape(Nz,Nx*Ny)).transpose()).flatten()
    
    x2 = (x2.reshape(Nx * Ny, Nz)).transpose()
        
    # Compute the mean for the pairs of columns
    mean_columns_1layer = npa.mean(x2[:8, :], axis=0)  # Mean for columns 
    mean_columns_2layer = npa.mean(x2[9:17, :], axis=0)  # Mean for columns 
    mean_columns_3layer = npa.mean(x2[18:26, :], axis=0)  # Mean for columns 
    mean_columns_4layer = npa.mean(x2[27:35, :], axis=0)  # Mean for columns 
    mean_columns_5layer = npa.mean(x2[36:44, :], axis=0)  # Mean for columns 
    
    # Create new arrays with mean values
    new_x2_1layer = npa.tile(mean_columns_1layer, 8).reshape(8, -1).flatten()
    new_x2_1layer_e = npa.zeros(Nx * Ny).flatten()
    new_x2_2layer = npa.tile(mean_columns_2layer, 8).reshape(8, -1).flatten()
    new_x2_2layer_e = npa.zeros(Nx * Ny).flatten()
    new_x2_3layer = npa.tile(mean_columns_3layer, 8).reshape(8, -1).flatten()
    new_x2_3layer_e = npa.zeros(Nx * Ny).flatten()
    new_x2_4layer = npa.tile(mean_columns_4layer, 8).reshape(8, -1).flatten()
    new_x2_4layer_e = npa.zeros(Nx * Ny).flatten()
    new_x2_5layer = npa.tile(mean_columns_5layer, 8).reshape(8, -1).flatten()
    
    # Concatenate the arrays to get the final result
    x2 = npa.concatenate([new_x2_1layer, new_x2_1layer_e,new_x2_2layer, new_x2_2layer_e,new_x2_3layer, new_x2_3layer_e,new_x2_4layer, new_x2_4layer_e,new_x2_5layer],axis=0)
    x2 = ((x2.reshape(Nz,Nx*Ny)).transpose()).flatten()
    x2 = mpa.tanh_projection(x2, beta, eta).flatten()
    x = x2

    return x


# design region과 동일한 size의 Block 생성
geometry = [
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
]

# Meep simulation 세팅

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

###############################################################################################################################
# ## 2. Optimization Environment

# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/2, design_region_width_y/2, -Sz/2 + Lpml + 0.5/resolution), mp.Vector3(0.01,0.01,0) 


# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)


ob_list = [FourierFields_0_x]


# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2)

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# 함수 설정

evaluation_history = []
cur_iter = [0]
numevl = 1

def f(v, gradient, beta):
    global numevl
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient
    # f0, dJ_du = opt()

    # Adjoint gradient
    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=1)
        )  # backprop

    evaluation_history.append(np.real(f0))

    np.savetxt(design_dir+"structure_0"+str(numevl) +".txt", design_variables.weights)
    
    numevl += 1
    
    print("First FoM: {}".format(evaluation_history[0]))
    print("Current FoM: {}".format(np.real(f0)))

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %%
opt.plot2D(True,output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(

# %%
f0, dJ_du = opt()
# Out:
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165391 s
# -----------
# run 0 finished at t = 50.425000000000004 (2017 timesteps)
# Starting adjoint run...
# run 1 finished at t = 50.050000000000004 (2002 timesteps)
# Calculating gradient...

# %%
print(dJ_du)
print(f0)
# Out:
# [-2.52118722e-02 -9.02002897e-03 -1.54774866e-03  6.05937203e-03
#   1.31858302e-02  1.92523376e-02  2.37776077e-02  2.64148018e-02
#   2.69621303e-02  3.73895681e-02 -1.32933387e-03 -4.78692818e-04
#  -8.57739024e-05  3.19308847e-04  7.00035799e-04  1.01996413e-03
#   1.25434684e-03  1.39125684e-03  1.42324044e-03  1.98035175e-03
#   1.01605261e-02  3.62972625e-03  6.16492371e-04 -2.44227683e-03
#  -5.30561488e-03 -7.75034303e-03 -9.58140321e-03 -1.06479359e-02
#  -1.08630680e-02 -1.50526425e-02  1.67942013e-02  6.00172333e-03
#   1.02194600e-03 -4.03667897e-03 -8.77297878e-03 -1.28138821e-02
#  -1.58374264e-02 -1.75987672e-02 -1.79565716e-02 -2.48866465e-02
#   1.67942013e-02  6.00172333e-03  1.02194600e-03 -4.03667897e-03
#  -8.77297878e-03 -1.28138821e-02 -1.58374264e-02 -1.75987672e-02
#  -1.79565716e-02 -2.48866465e-02  1.01605261e-02  3.62972625e-03
#   6.16492371e-04 -2.44227683e-03 -5.30561488e-03 -7.75034303e-03
#  -9.58140321e-03 -1.06479359e-02 -1.08630680e-02 -1.50526425e-02
#  -1.32933387e-03 -4.78692818e-04 -8.57739024e-05  3.19308847e-04
#   7.00035799e-04  1.01996413e-03  1.25434684e-03  1.39125684e-03
#   1.42324044e-03  1.98035175e-03 -1.45966777e-02 -5.22268575e-03
#  -8.96680997e-04  3.50811304e-03  7.63476338e-03  1.11470422e-02
#   1.37663934e-02  1.52929197e-02  1.56102479e-02  2.16483595e-02
#  -2.60865313e-02 -9.33110357e-03 -1.59894712e-03  6.26969840e-03
#   1.36404138e-02  1.99173493e-02  2.46021435e-02  2.73321126e-02
#   2.78965565e-02  3.86813537e-02 -4.99690762e-02 -1.78724398e-02
#  -3.06092199e-03  1.20097620e-02  2.61262098e-02  3.81497256e-02
#   4.71254080e-02  5.23556615e-02  5.34354506e-02  7.40905871e-02
#  -2.01622592e-02 -7.21443361e-03 -1.23911005e-03  4.84566673e-03
#   1.05463521e-02  1.53977735e-02  1.90152602e-02  2.11235266e-02
#   2.15622420e-02  2.99034826e-02  2.04000305e-03  7.25960632e-04
#   1.20153464e-04 -4.90075012e-04 -1.05996670e-03 -1.55001595e-03
#  -1.92068716e-03 -2.13628637e-03 -2.17665506e-03 -3.01030507e-03
#   1.35320380e-02  4.83506518e-03  8.22544679e-04 -3.25184398e-03
#  -7.06587749e-03 -1.03205244e-02 -1.27565386e-02 -1.41754995e-02
#  -1.44629419e-02 -2.00432514e-02  2.01669688e-02  7.20745796e-03
#   1.22807041e-03 -4.84635198e-03 -1.05333915e-02 -1.53841797e-02
#  -1.90126204e-02 -2.11263426e-02 -2.15564330e-02 -2.98772273e-02
#   2.01669688e-02  7.20745796e-03  1.22807041e-03 -4.84635198e-03
#  -1.05333915e-02 -1.53841797e-02 -1.90126204e-02 -2.11263426e-02
#  -2.15564330e-02 -2.98772273e-02  1.35320380e-02  4.83506518e-03
#   8.22544679e-04 -3.25184398e-03 -7.06587749e-03 -1.03205244e-02
#  -1.27565386e-02 -1.41754995e-02 -1.44629419e-02 -2.00432514e-02
#   2.04000305e-03  7.25960632e-04  1.20153464e-04 -4.90075012e-04
#  -1.05996670e-03 -1.55001595e-03 -1.92068716e-03 -2.13628637e-03
#  -2.17665506e-03 -3.01030507e-03 -1.12298525e-02 -4.01882385e-03
#  -6.90897948e-04  2.69894100e-03  5.87506155e-03  8.57729457e-03
#   1.05914762e-02  1.17653997e-02  1.20103272e-02  1.66576478e-02
#  -2.27218810e-02 -8.12792665e-03 -1.39328873e-03  5.46071003e-03
#   1.18809724e-02  1.73478028e-02  2.14273276e-02  2.38046129e-02
#   2.42966140e-02  3.36905941e-02 -4.49241488e-02 -1.60683199e-02
#  -2.75255167e-03  1.07964528e-02  2.34872929e-02  3.42955947e-02
#   4.23632788e-02  4.70644305e-02  4.80355151e-02  6.66043978e-02
#  -1.32643713e-02 -4.74794589e-03 -8.17501492e-04  3.18771492e-03
#   6.94075790e-03  1.01323407e-02  1.25097731e-02  1.38955112e-02
#   1.41858574e-02  1.96772982e-02  6.64259527e-03  2.37154620e-03
#   4.01455224e-04 -1.59571383e-03 -3.46417479e-03 -5.06067378e-03
#  -6.25786400e-03 -6.95499984e-03 -7.09420381e-03 -9.82766950e-03
#   1.81376012e-02  6.48158646e-03  1.10401671e-03 -4.35773367e-03
#  -9.47044129e-03 -1.38314569e-02 -1.70938538e-02 -1.89942410e-02
#  -1.93804611e-02 -2.68605500e-02  2.47742469e-02  8.85451954e-03
#   1.50964082e-03 -5.95238663e-03 -1.29381609e-02 -1.88952708e-02
#  -2.33500155e-02 -2.59451004e-02 -2.64739352e-02 -3.66944880e-02
#   2.47742469e-02  8.85451954e-03  1.50964082e-03 -5.95238663e-03
#  -1.29381609e-02 -1.88952708e-02 -2.33500155e-02 -2.59451004e-02
#  -2.64739352e-02 -3.66944880e-02  1.81376012e-02  6.48158646e-03
#   1.10401671e-03 -4.35773367e-03 -9.47044129e-03 -1.38314569e-02
#  -1.70938538e-02 -1.89942410e-02 -1.93804611e-02 -2.68605500e-02
#   6.64259527e-03  2.37154620e-03  4.01455224e-04 -1.59571383e-03
#  -3.46417479e-03 -5.06067378e-03 -6.25786400e-03 -6.95499984e-03
#  -7.09420381e-03 -9.82766950e-03 -6.63069161e-03 -2.37431890e-03
#  -4.09792847e-04  1.59359174e-03  3.47126411e-03  5.06695389e-03
#   6.25445910e-03  6.94671840e-03  7.09274420e-03  9.84020794e-03
#  -1.81256918e-02 -6.48435784e-03 -1.11235416e-03  4.35561154e-03
#   9.47753072e-03  1.38377369e-02  1.70904487e-02  1.89859593e-02
#   1.93790013e-02  2.68730893e-02 -3.80326642e-02 -1.36038497e-02
#  -2.33131090e-03  9.13904149e-03  1.98824659e-02  2.90307544e-02
#   3.58580893e-02  3.98364744e-02  4.06590665e-02  5.63780740e-02
#  -6.36649758e-03 -2.28146137e-03 -3.95893532e-04  1.52976398e-03
#   3.33516494e-03  4.86690821e-03  6.00428559e-03  6.66749525e-03
#   6.80947230e-03  9.45111425e-03  1.12451784e-02  4.01712976e-03
#   6.82756554e-04 -2.70135212e-03 -5.86838204e-03 -8.57133123e-03
#  -1.05950409e-02 -1.17737134e-02 -1.20117527e-02 -1.66450334e-02
#   2.27431562e-02  8.12810619e-03  1.38548843e-03 -5.46362301e-03
#  -1.18750045e-02 -1.73423889e-02 -2.14311687e-02 -2.38129821e-02
#  -2.42979801e-02 -3.36778487e-02  2.93815178e-02  1.05015801e-02
#   1.79121110e-03 -7.05842094e-03 -1.53429298e-02 -2.24063616e-02
#  -2.76874100e-02 -3.07638572e-02 -3.13914370e-02 -4.35117494e-02
#   2.93815178e-02  1.05015801e-02  1.79121110e-03 -7.05842094e-03
#  -1.53429298e-02 -2.24063616e-02 -2.76874100e-02 -3.07638572e-02
#  -3.13914370e-02 -4.35117494e-02  2.27431562e-02  8.12810619e-03
#   1.38548843e-03 -5.46362301e-03 -1.18750045e-02 -1.73423889e-02
#  -2.14311687e-02 -2.38129821e-02 -2.42979801e-02 -3.36778487e-02
#   1.12451784e-02  4.01712976e-03  6.82756554e-04 -2.70135212e-03
#  -5.86838204e-03 -8.57133123e-03 -1.05950409e-02 -1.17737134e-02
#  -1.20117527e-02 -1.66450334e-02 -2.03154011e-03 -7.29816119e-04
#  -1.28688175e-04  4.88243070e-04  1.06746752e-03  1.55661343e-03
#   1.91744171e-03  2.12803671e-03  2.17516082e-03  3.02276850e-03
#  -1.35295126e-02 -4.84079109e-03 -8.31419807e-04  3.25051338e-03
#   7.07408934e-03  1.03276710e-02  1.27535696e-02  1.41673053e-02
#   1.44613880e-02  2.00555842e-02 -3.11411953e-02 -1.11393827e-02
#  -1.91007025e-03  7.48162995e-03  1.62776381e-02  2.37659138e-02
#   2.93529000e-02  3.26085180e-02  3.32826171e-02  4.61517490e-02
#  -1.31691375e-03 -4.75871570e-04 -8.72553912e-05  3.16059683e-04
#   6.95687874e-04  1.01234425e-03  1.24193815e-03  1.37621993e-03
#   1.40958357e-03  1.96502916e-03  1.46144964e-02  5.22177962e-03
#   8.88683479e-04 -3.51073575e-03 -7.62838433e-03 -1.11413112e-02
#  -1.37700748e-02 -1.53012568e-02 -1.56116485e-02 -2.16356897e-02
#   2.61146503e-02  9.33344166e-03  1.59154018e-03 -6.27319016e-03
#  -1.36352671e-02 -1.99125698e-02 -2.46063037e-02 -2.73405456e-02
#  -2.78978543e-02 -3.86684577e-02  3.27542687e-02  1.17073115e-02
#   1.99733497e-03 -7.86809392e-03 -1.71033426e-02 -2.49766584e-02
#  -3.08626034e-02 -3.42914323e-02 -3.49912988e-02 -4.85023311e-02
#   3.27542687e-02  1.17073115e-02  1.99733497e-03 -7.86809392e-03
#  -1.71033426e-02 -2.49766584e-02 -3.08626034e-02 -3.42914323e-02
#  -3.49912988e-02 -4.85023311e-02  2.61146503e-02  9.33344166e-03
#   1.59154018e-03 -6.27319016e-03 -1.36352671e-02 -1.99125698e-02
#  -2.46063037e-02 -2.73405456e-02 -2.78978543e-02 -3.86684577e-02
#   1.46144964e-02  5.22177962e-03  8.88683479e-04 -3.51073575e-03
#  -7.62838433e-03 -1.11413112e-02 -1.37700748e-02 -1.53012568e-02
#  -1.56116485e-02 -2.16356897e-02  1.33526562e-03  4.74042104e-04
#   7.70945665e-05 -3.20928336e-04 -6.92233656e-04 -1.01313409e-03
#  -1.25747543e-03 -1.39948336e-03 -1.42476012e-03 -1.96794284e-03
#  -1.01648822e-02 -3.63761835e-03 -6.25761982e-04  2.44152552e-03
#   5.31464854e-03  7.75812470e-03  9.57875382e-03  1.06398057e-02
#   1.08614455e-02  1.50648247e-02 -2.60962986e-02 -9.33527000e-03
#  -1.60170144e-03  6.26832090e-03  1.36387217e-02  1.99117835e-02
#   2.45907711e-02  2.73172870e-02  2.78826821e-02  3.86655597e-02
#   5.31359927e-04  1.85019821e-04  2.57140415e-05 -1.28187024e-04
#  -2.70428135e-04 -3.98524300e-04 -5.01201935e-04 -5.60520944e-04
#  -5.66912529e-04 -7.75068092e-04  1.58477504e-02  5.66271183e-03
#   9.64058094e-04 -3.80699095e-03 -8.27259025e-03 -1.20819893e-02
#  -1.49322179e-02 -1.65924273e-02 -1.69293019e-02 -2.34623965e-02
#   2.73487010e-02  9.77462461e-03  1.66696035e-03 -6.56951242e-03
#  -1.42795682e-02 -2.08533214e-02 -2.57684839e-02 -2.86317238e-02
#  -2.92155000e-02 -4.04951470e-02  3.39887795e-02  1.21486391e-02
#   2.07278126e-03 -8.16445465e-03 -1.77476981e-02 -2.59174523e-02
#  -3.20248050e-02 -3.55826149e-02 -3.63089401e-02 -5.03290104e-02
#   3.39887795e-02  1.21486391e-02  2.07278126e-03 -8.16445465e-03
#  -1.77476981e-02 -2.59174523e-02 -3.20248050e-02 -3.55826149e-02
#  -3.63089401e-02 -5.03290104e-02  2.73487010e-02  9.77462461e-03
#   1.66696035e-03 -6.56951242e-03 -1.42795682e-02 -2.08533214e-02
#  -2.57684839e-02 -2.86317238e-02 -2.92155000e-02 -4.04951470e-02
#   1.58477504e-02  5.66271183e-03  9.64058094e-04 -3.80699095e-03
#  -8.27259025e-03 -1.20819893e-02 -1.49322179e-02 -1.65924273e-02
#  -1.69293019e-02 -2.34623965e-02  2.56760049e-03  9.14684577e-04
#   1.52416316e-04 -6.17105754e-04 -1.33632932e-03 -1.95372716e-03
#  -2.41957572e-03 -2.69064515e-03 -2.74242240e-03 -3.79466990e-03
#  -8.93334330e-03 -3.19722681e-03 -5.50485972e-04  2.14541550e-03
#   4.67064854e-03  6.81760547e-03  8.41669064e-03  9.34865149e-03
#   9.54377541e-03  1.32380801e-02 -2.42497401e-02 -8.67491918e-03
#  -1.48883039e-03  5.82421921e-03  1.26728114e-02  1.85010740e-02
#   2.28477112e-02  2.53805625e-02  2.59061691e-02  3.59254243e-02
#  -1.31691375e-03 -4.75871570e-04 -8.72553912e-05  3.16059683e-04
#   6.95687874e-04  1.01234425e-03  1.24193815e-03  1.37621993e-03
#   1.40958357e-03  1.96502916e-03  1.46144964e-02  5.22177962e-03
#   8.88683479e-04 -3.51073575e-03 -7.62838433e-03 -1.11413112e-02
#  -1.37700748e-02 -1.53012568e-02 -1.56116485e-02 -2.16356897e-02
#   2.61146503e-02  9.33344166e-03  1.59154018e-03 -6.27319016e-03
#  -1.36352671e-02 -1.99125698e-02 -2.46063037e-02 -2.73405456e-02
#  -2.78978543e-02 -3.86684577e-02  3.27542687e-02  1.17073115e-02
#   1.99733497e-03 -7.86809392e-03 -1.71033426e-02 -2.49766584e-02
#  -3.08626034e-02 -3.42914323e-02 -3.49912988e-02 -4.85023311e-02
#   3.27542687e-02  1.17073115e-02  1.99733497e-03 -7.86809392e-03
#  -1.71033426e-02 -2.49766584e-02 -3.08626034e-02 -3.42914323e-02
#  -3.49912988e-02 -4.85023311e-02  2.61146503e-02  9.33344166e-03
#   1.59154018e-03 -6.27319016e-03 -1.36352671e-02 -1.99125698e-02
#  -2.46063037e-02 -2.73405456e-02 -2.78978543e-02 -3.86684577e-02
#   1.46144964e-02  5.22177962e-03  8.88683479e-04 -3.51073575e-03
#  -7.62838433e-03 -1.11413112e-02 -1.37700748e-02 -1.53012568e-02
#  -1.56116485e-02 -2.16356897e-02  1.33526562e-03  4.74042104e-04
#   7.70945665e-05 -3.20928336e-04 -6.92233656e-04 -1.01313409e-03
#  -1.25747543e-03 -1.39948336e-03 -1.42476012e-03 -1.96794284e-03
#  -1.01648822e-02 -3.63761835e-03 -6.25761982e-04  2.44152552e-03
#   5.31464854e-03  7.75812470e-03  9.57875382e-03  1.06398057e-02
#   1.08614455e-02  1.50648247e-02 -2.60962986e-02 -9.33527000e-03
#  -1.60170144e-03  6.26832090e-03  1.36387217e-02  1.99117835e-02
#   2.45907711e-02  2.73172870e-02  2.78826821e-02  3.86655597e-02
#  -6.36649758e-03 -2.28146137e-03 -3.95893532e-04  1.52976398e-03
#   3.33516494e-03  4.86690821e-03  6.00428559e-03  6.66749525e-03
#   6.80947230e-03  9.45111425e-03  1.12451784e-02  4.01712976e-03
#   6.82756554e-04 -2.70135212e-03 -5.86838204e-03 -8.57133123e-03
#  -1.05950409e-02 -1.17737134e-02 -1.20117527e-02 -1.66450334e-02
#   2.27431562e-02  8.12810619e-03  1.38548843e-03 -5.46362301e-03
#  -1.18750045e-02 -1.73423889e-02 -2.14311687e-02 -2.38129821e-02
#  -2.42979801e-02 -3.36778487e-02  2.93815178e-02  1.05015801e-02
#   1.79121110e-03 -7.05842094e-03 -1.53429298e-02 -2.24063616e-02
#  -2.76874100e-02 -3.07638572e-02 -3.13914370e-02 -4.35117494e-02
#   2.93815178e-02  1.05015801e-02  1.79121110e-03 -7.05842094e-03
#  -1.53429298e-02 -2.24063616e-02 -2.76874100e-02 -3.07638572e-02
#  -3.13914370e-02 -4.35117494e-02  2.27431562e-02  8.12810619e-03
#   1.38548843e-03 -5.46362301e-03 -1.18750045e-02 -1.73423889e-02
#  -2.14311687e-02 -2.38129821e-02 -2.42979801e-02 -3.36778487e-02
#   1.12451784e-02  4.01712976e-03  6.82756554e-04 -2.70135212e-03
#  -5.86838204e-03 -8.57133123e-03 -1.05950409e-02 -1.17737134e-02
#  -1.20117527e-02 -1.66450334e-02 -2.03154011e-03 -7.29816119e-04
#  -1.28688175e-04  4.88243070e-04  1.06746752e-03  1.55661343e-03
#   1.91744171e-03  2.12803671e-03  2.17516082e-03  3.02276850e-03
#  -1.35295126e-02 -4.84079109e-03 -8.31419807e-04  3.25051338e-03
#   7.07408934e-03  1.03276710e-02  1.27535696e-02  1.41673053e-02
#   1.44613880e-02  2.00555842e-02 -3.11411953e-02 -1.11393827e-02
#  -1.91007025e-03  7.48162995e-03  1.62776381e-02  2.37659138e-02
#   2.93529000e-02  3.26085180e-02  3.32826171e-02  4.61517490e-02
#  -1.32643713e-02 -4.74794589e-03 -8.17501492e-04  3.18771492e-03
#   6.94075790e-03  1.01323407e-02  1.25097731e-02  1.38955112e-02
#   1.41858574e-02  1.96772982e-02  6.64259527e-03  2.37154620e-03
#   4.01455224e-04 -1.59571383e-03 -3.46417479e-03 -5.06067378e-03
#  -6.25786400e-03 -6.95499984e-03 -7.09420381e-03 -9.82766950e-03
#   1.81376012e-02  6.48158646e-03  1.10401671e-03 -4.35773367e-03
#  -9.47044129e-03 -1.38314569e-02 -1.70938538e-02 -1.89942410e-02
#  -1.93804611e-02 -2.68605500e-02  2.47742469e-02  8.85451954e-03
#   1.50964082e-03 -5.95238663e-03 -1.29381609e-02 -1.88952708e-02
#  -2.33500155e-02 -2.59451004e-02 -2.64739352e-02 -3.66944880e-02
#   2.47742469e-02  8.85451954e-03  1.50964082e-03 -5.95238663e-03
#  -1.29381609e-02 -1.88952708e-02 -2.33500155e-02 -2.59451004e-02
#  -2.64739352e-02 -3.66944880e-02  1.81376012e-02  6.48158646e-03
#   1.10401671e-03 -4.35773367e-03 -9.47044129e-03 -1.38314569e-02
#  -1.70938538e-02 -1.89942410e-02 -1.93804611e-02 -2.68605500e-02
#   6.64259527e-03  2.37154620e-03  4.01455224e-04 -1.59571383e-03
#  -3.46417479e-03 -5.06067378e-03 -6.25786400e-03 -6.95499984e-03
#  -7.09420381e-03 -9.82766950e-03 -6.63069161e-03 -2.37431890e-03
#  -4.09792847e-04  1.59359174e-03  3.47126411e-03  5.06695389e-03
#   6.25445910e-03  6.94671840e-03  7.09274420e-03  9.84020794e-03
#  -1.81256918e-02 -6.48435784e-03 -1.11235416e-03  4.35561154e-03
#   9.47753072e-03  1.38377369e-02  1.70904487e-02  1.89859593e-02
#   1.93790013e-02  2.68730893e-02 -3.80326642e-02 -1.36038497e-02
#  -2.33131090e-03  9.13904149e-03  1.98824659e-02  2.90307544e-02
#   3.58580893e-02  3.98364744e-02  4.06590665e-02  5.63780740e-02
#  -2.01622592e-02 -7.21443361e-03 -1.23911005e-03  4.84566673e-03
#   1.05463521e-02  1.53977735e-02  1.90152602e-02  2.11235266e-02
#   2.15622420e-02  2.99034826e-02  2.04000305e-03  7.25960632e-04
#   1.20153464e-04 -4.90075012e-04 -1.05996670e-03 -1.55001595e-03
#  -1.92068716e-03 -2.13628637e-03 -2.17665506e-03 -3.01030507e-03
#   1.35320380e-02  4.83506518e-03  8.22544679e-04 -3.25184398e-03
#  -7.06587749e-03 -1.03205244e-02 -1.27565386e-02 -1.41754995e-02
#  -1.44629419e-02 -2.00432514e-02  2.01669688e-02  7.20745796e-03
#   1.22807041e-03 -4.84635198e-03 -1.05333915e-02 -1.53841797e-02
#  -1.90126204e-02 -2.11263426e-02 -2.15564330e-02 -2.98772273e-02
#   2.01669688e-02  7.20745796e-03  1.22807041e-03 -4.84635198e-03
#  -1.05333915e-02 -1.53841797e-02 -1.90126204e-02 -2.11263426e-02
#  -2.15564330e-02 -2.98772273e-02  1.35320380e-02  4.83506518e-03
#   8.22544679e-04 -3.25184398e-03 -7.06587749e-03 -1.03205244e-02
#  -1.27565386e-02 -1.41754995e-02 -1.44629419e-02 -2.00432514e-02
#   2.04000305e-03  7.25960632e-04  1.20153464e-04 -4.90075012e-04
#  -1.05996670e-03 -1.55001595e-03 -1.92068716e-03 -2.13628637e-03
#  -2.17665506e-03 -3.01030507e-03 -1.12298525e-02 -4.01882385e-03
#  -6.90897948e-04  2.69894100e-03  5.87506155e-03  8.57729457e-03
#   1.05914762e-02  1.17653997e-02  1.20103272e-02  1.66576478e-02
#  -2.27218810e-02 -8.12792665e-03 -1.39328873e-03  5.46071003e-03
#   1.18809724e-02  1.73478028e-02  2.14273276e-02  2.38046129e-02
#   2.42966140e-02  3.36905941e-02 -4.49241488e-02 -1.60683199e-02
#  -2.75255167e-03  1.07964528e-02  2.34872929e-02  3.42955947e-02
#   4.23632788e-02  4.70644305e-02  4.80355151e-02  6.66043978e-02]
# 1.5503136584847015

# %%
db = 1e-5
choose = 1000
g_discrete, idx = opt.calculate_fd_gradient(num_gradients=choose, db=db)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.90735e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147991 s
# -----------
# run 2 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148611 s
# -----------
# run 3 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0253978 s
# -----------
# run 4 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014816 s
# -----------
# run 5 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147769 s
# -----------
# run 6 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014957 s
# -----------
# run 7 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149372 s
# -----------
# run 8 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014797 s
# -----------
# run 9 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147929 s
# -----------
# run 10 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014765 s
# -----------
# run 11 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0162652 s
# -----------
# run 12 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.88351e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0197639 s
# -----------
# run 13 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.31266e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0152171 s
# -----------
# run 14 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015142 s
# -----------
# run 15 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0157928 s
# -----------
# run 16 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148599 s
# -----------
# run 17 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.62125e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01512 s
# -----------
# run 18 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148408 s
# -----------
# run 19 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148599 s
# -----------
# run 20 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147769 s
# -----------
# run 21 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.50204e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0164011 s
# -----------
# run 22 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0156109 s
# -----------
# run 23 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0157299 s
# -----------
# run 24 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0157411 s
# -----------
# run 25 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015861 s
# -----------
# run 26 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.90735e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0157912 s
# -----------
# run 27 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016556 s
# -----------
# run 28 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016504 s
# -----------
# run 29 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015089 s
# -----------
# run 30 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148299 s
# -----------
# run 31 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148189 s
# -----------
# run 32 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.90735e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150669 s
# -----------
# run 33 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015178 s
# -----------
# run 34 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0157149 s
# -----------
# run 35 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015512 s
# -----------
# run 36 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015799 s
# -----------
# run 37 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0156138 s
# -----------
# run 38 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014992 s
# -----------
# run 39 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0207062 s
# -----------
# run 40 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.90735e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014889 s
# -----------
# run 41 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.88351e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014946 s
# -----------
# run 42 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0161991 s
# -----------
# run 43 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0159199 s
# -----------
# run 44 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.50204e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0157571 s
# -----------
# run 45 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.40667e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0208681 s
# -----------
# run 46 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0156729 s
# -----------
# run 47 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.50204e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168779 s
# -----------
# run 48 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148909 s
# -----------
# run 49 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.4782e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151482 s
# -----------
# run 50 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147929 s
# -----------
# run 51 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.38283e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015007 s
# -----------
# run 52 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149341 s
# -----------
# run 53 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.50204e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147979 s
# -----------
# run 54 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150399 s
# -----------
# run 55 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.50204e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147908 s
# -----------
# run 56 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.50204e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149791 s
# -----------
# run 57 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.50204e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016398 s
# -----------
# run 58 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.62125e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0233991 s
# -----------
# run 59 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016041 s
# -----------
# run 60 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149801 s
# -----------
# run 61 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015204 s
# -----------
# run 62 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015075 s
# -----------
# run 63 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014914 s
# -----------
# run 64 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.62125e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149291 s
# -----------
# run 65 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014957 s
# -----------
# run 66 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151129 s
# -----------
# run 67 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014951 s
# -----------
# run 68 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148869 s
# -----------
# run 69 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148599 s
# -----------
# run 70 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150449 s
# -----------
# run 71 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148799 s
# -----------
# run 72 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149369 s
# -----------
# run 73 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0154581 s
# -----------
# run 74 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170579 s
# -----------
# run 75 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150442 s
# -----------
# run 76 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150301 s
# -----------
# run 77 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.62125e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014863 s
# -----------
# run 78 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0152938 s
# -----------
# run 79 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.90735e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015305 s
# -----------
# run 80 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151489 s
# -----------
# run 81 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015162 s
# -----------
# run 82 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.62125e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015162 s
# -----------
# run 83 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0153019 s
# -----------
# run 84 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149028 s
# -----------
# run 85 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014981 s
# -----------
# run 86 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150809 s
# -----------
# run 87 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151439 s
# -----------
# run 88 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014935 s
# -----------
# run 89 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150731 s
# -----------
# run 90 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150321 s
# -----------
# run 91 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01508 s
# -----------
# run 92 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.88351e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149839 s
# -----------
# run 93 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150239 s
# -----------
# run 94 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148058 s
# -----------
# run 95 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015017 s
# -----------
# run 96 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02125 s
# -----------
# run 97 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015121 s
# -----------
# run 98 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.00272e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147998 s
# -----------
# run 99 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147991 s
# -----------
# run 100 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147491 s
# -----------
# run 101 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0153351 s
# -----------
# run 102 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148408 s
# -----------
# run 103 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149689 s
# -----------
# run 104 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014765 s
# -----------
# run 105 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015135 s
# -----------
# run 106 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0159562 s
# -----------
# run 107 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148818 s
# -----------
# run 108 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015945 s
# -----------
# run 109 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016355 s
# -----------
# run 110 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015233 s
# -----------
# run 111 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015177 s
# -----------
# run 112 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016268 s
# -----------
# run 113 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166271 s
# -----------
# run 114 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151019 s
# -----------
# run 115 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015079 s
# -----------
# run 116 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.62125e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149961 s
# -----------
# run 117 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0155208 s
# -----------
# run 118 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0152678 s
# -----------
# run 119 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151088 s
# -----------
# run 120 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150042 s
# -----------
# run 121 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150399 s
# -----------
# run 122 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151019 s
# -----------
# run 123 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151491 s
# -----------
# run 124 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149841 s
# -----------
# run 125 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.50204e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150571 s
# -----------
# run 126 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015008 s
# -----------
# run 127 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015018 s
# -----------
# run 128 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148859 s
# -----------
# run 129 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149989 s
# -----------
# ...
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147121 s
# -----------
# run 1959 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.19345e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01508 s
# -----------
# run 1960 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014956 s
# -----------
# run 1961 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015053 s
# -----------
# run 1962 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148032 s
# -----------
# run 1963 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148759 s
# -----------
# run 1964 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015064 s
# -----------
# run 1965 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0148182 s
# -----------
# run 1966 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015842 s
# -----------
# run 1967 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0158381 s
# -----------
# run 1968 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0156879 s
# -----------
# run 1969 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015945 s
# -----------
# run 1970 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.28882e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0159152 s
# -----------
# run 1971 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.81198e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015162 s
# -----------
# run 1972 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0151811 s
# -----------
# run 1973 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147901 s
# -----------
# run 1974 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147998 s
# -----------
# run 1975 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.00272e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015733 s
# -----------
# run 1976 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150869 s
# -----------
# run 1977 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015414 s
# -----------
# run 1978 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150969 s
# -----------
# run 1979 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015347 s
# -----------
# run 1980 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.90735e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015177 s
# -----------
# run 1981 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0149541 s
# -----------
# run 1982 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0153952 s
# -----------
# run 1983 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018096 s
# -----------
# run 1984 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.62125e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150428 s
# -----------
# run 1985 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0153539 s
# -----------
# run 1986 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015048 s
# -----------
# run 1987 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015084 s
# -----------
# run 1988 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015084 s
# -----------
# run 1989 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.014807 s
# -----------
# run 1990 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166841 s
# -----------
# run 1991 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015121 s
# -----------
# run 1992 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.71661e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017031 s
# -----------
# run 1993 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0200729 s
# -----------
# run 1994 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.62125e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018209 s
# -----------
# run 1995 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.5974e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150268 s
# -----------
# run 1996 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0147281 s
# -----------
# run 1997 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015059 s
# -----------
# run 1998 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0150371 s
# -----------
# run 1999 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.78814e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0153439 s
# -----------
# run 2000 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 1.69277e-05 s
# Working in 3D dimensions.
# Computational cell is 0.6 x 0.6 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0163529 s
# -----------
# run 2001 finished at t = 50.050000000000004 (2002 timesteps)

# %%
(m, b) = np.polyfit(np.squeeze(g_discrete), dJ_du[idx], 1)

# %%
min_g = np.min(g_discrete)
max_g = np.max(g_discrete)

fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Best fit")
plt.plot(g_discrete, dJ_du[idx], "o", label="Adjoint comparison")
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(g_discrete) - np.squeeze(dJ_du[idx]))
    / np.abs(np.squeeze(g_discrete))
    * 100
)
plt.semilogy(g_discrete, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()

# %%
f=0

plt.subplot(2, 2, 1)
dJ_du_0 = dJ_du.reshape(Nx *Ny, Nz).transpose()[f]
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, Ny)), )
plt.ylabel("Adjoint Gradient")
plt.colorbar()

plt.subplot(2, 2, 2)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx *Ny, Nz).transpose()[f]
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, Ny)), )
plt.ylabel("Finite Difference Gradient")
plt.colorbar()



plt.subplot(2, 2, 3)
err_p=rel_err.reshape(Nx *Ny, Nz).transpose()[f]
plt.imshow(np.rot90(err_p.reshape(Nx, Ny)),)
plt.ylabel("Relative Error (%)")
plt.colorbar()


plt.subplot(2, 2, 4)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, Ny)),)
plt.ylabel("Error")
plt.colorbar()
