# %%
# Design CIS 3D color router
# Resoultion 20 
# RGGB pattern
# Elapsed run time = 33956.9432 s


# ## 1. Simulation Environment

import meep as mp
import meep.adjoint as mpa
import numpy as np
import nlopt
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
from matplotlib import pyplot as plt
import os

mp.verbosity(1)

seed = 240  # 난수 발생 시드(seed)를 240으로 설정 (재현성을 위해 난수 시드를 고정)
np.random.seed(seed)  # numpy의 난수 생성기의 시드를 설정하여 난수의 재현성 보장

design_dir = "./CIS_design/"

# 디렉터리가 없으면 생성
if not os.path.exists(design_dir):
    os.makedirs(design_dir)

# scaling & refractive index
um_scale = 1 # 1A = 675nm

Air = mp.Medium(index=1.0)
SiN = mp.Medium(index=1.5)
SiO2 = mp.Medium(index=1.5)
HfO2 = mp.Medium(index=1.9)
# SiPD = mp.Medium(epsilon=11.8)

# 해상도 및 사이즈 설정
resolution = 20 # 1 pixel = 27nm
Lpml = 0.5 # PML 영역 크기
# pml_layers = [mp.PML(thickness = Lpml, direction = mp.Z)]
pml_layers = [mp.PML(thickness = Lpml, )]
Sourcespace = 0.5

# 설계 공간
design_region_width_x = 0.5 # 디자인 영역 x
design_region_width_y = 0.5 # 디자인 영역 y
design_region_height = 0.5 # 디자인 영역 높이 z

# 전체 공간
Sx = design_region_width_x +Lpml*2 + 1
Sy = design_region_width_y+Lpml*2 + 1
Sz = Lpml + design_region_height + Sourcespace + 1 + Lpml
cell_size = mp.Vector3(Sx, Sy, Sz)

# 파장, 주파수 설정
wavelengths = np.array([0.5])
frequencies = 1/wavelengths
nf = len(frequencies) # number of frequencies

# Fabrication Constraints 설정

minimum_length = 0.027 * um_scale # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)


# source 설정
fcen = 1 / 0.5
width = 0.1
fwidth = width * fcen

source_center = [0, 0, Sz / 2 - Lpml - Sourcespace / 2 ] # Source 위치
source_size = mp.Vector3(Sx, Sy, 0)
src = mp.GaussianSource(frequency=fcen, fwidth=fwidth)

source = [mp.Source(src, component=mp.Ex, size=source_size, center=source_center,),]


# 설계 영역의 픽셀 - 해상도와 디자인 영역에 따라 결정
Nx = int(round(design_region_resolution * design_region_width_x)) 
Ny = int(round(design_region_resolution * design_region_width_y)) 
Nz = int(round(design_region_resolution * design_region_height))

# 설계 영역과 물질을 바탕으로 설계 영역 설정
design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), Air, SiN, grid_type="U_MEAN",do_averaging=False)
design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0, 0, Sz / 2 - Lpml - Sourcespace - design_region_height/2),
        size=mp.Vector3(design_region_width_x, design_region_width_y, design_region_height),
    ),
)

# 대각선대칭

def mapping(x, eta, beta):
    x_copy = (x.reshape(Nx * Ny, Nz)).transpose()

    # projection
    z = 0
    x2 = []

    while z < Nz:
        
        number = z
        x1 = x_copy[int(number)]
        
        # filter
        filtered_field = mpa.conic_filter(
            x1,
            filter_radius,
            0.88,
            0.88,
            design_region_resolution,
        )
        
        z_slice = ((filtered_field.reshape(Nx, Ny)) + filtered_field.reshape(Nx, Ny).transpose()) / 2
        x2 = npa.concatenate((x2,z_slice.flatten()),axis=0) 
        z = z + 1

    x2 = ((x2.reshape(Nz,Nx*Ny)).transpose()).flatten()
    
    x2 = (x2.reshape(Nx * Ny, Nz)).transpose()
        
    # Compute the mean for the pairs of columns
    mean_columns_1layer = npa.mean(x2[:8, :], axis=0)  # Mean for columns 
    mean_columns_2layer = npa.mean(x2[9:17, :], axis=0)  # Mean for columns 
    mean_columns_3layer = npa.mean(x2[18:26, :], axis=0)  # Mean for columns 
    mean_columns_4layer = npa.mean(x2[27:35, :], axis=0)  # Mean for columns 
    mean_columns_5layer = npa.mean(x2[36:44, :], axis=0)  # Mean for columns 
    
    # Create new arrays with mean values
    new_x2_1layer = npa.tile(mean_columns_1layer, 8).reshape(8, -1).flatten()
    new_x2_1layer_e = npa.zeros(Nx * Ny).flatten()
    new_x2_2layer = npa.tile(mean_columns_2layer, 8).reshape(8, -1).flatten()
    new_x2_2layer_e = npa.zeros(Nx * Ny).flatten()
    new_x2_3layer = npa.tile(mean_columns_3layer, 8).reshape(8, -1).flatten()
    new_x2_3layer_e = npa.zeros(Nx * Ny).flatten()
    new_x2_4layer = npa.tile(mean_columns_4layer, 8).reshape(8, -1).flatten()
    new_x2_4layer_e = npa.zeros(Nx * Ny).flatten()
    new_x2_5layer = npa.tile(mean_columns_5layer, 8).reshape(8, -1).flatten()
    
    # Concatenate the arrays to get the final result
    x2 = npa.concatenate([new_x2_1layer, new_x2_1layer_e,new_x2_2layer, new_x2_2layer_e,new_x2_3layer, new_x2_3layer_e,new_x2_4layer, new_x2_4layer_e,new_x2_5layer],axis=0)
    x2 = ((x2.reshape(Nz,Nx*Ny)).transpose()).flatten()
    x2 = mpa.tanh_projection(x2, beta, eta).flatten()
    x = x2

    return x


# design region과 동일한 size의 Block 생성
geometry = [
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    ),
]

# Meep simulation 세팅

sim = mp.Simulation(
    cell_size=cell_size, 
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air, # 빈공간
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

###############################################################################################################################
# ## 2. Optimization Environment

# 모니터 위치와 크기 설정 (focal point)
monitor_position_0, monitor_size_0 = mp.Vector3(-design_region_width_x/2, design_region_width_y/2, -Sz/2 + Lpml + 0.5/resolution), mp.Vector3(0.01,0.01,0) 


# FourierFields를 통해 monitor_position에서 monitor_size만큼의 영역에 대한 Fourier transform을 구함

FourierFields_0_x = mpa.FourierFields(sim,mp.Volume(center=monitor_position_0,size=monitor_size_0),mp.Ex,yee_grid=True)


ob_list = [FourierFields_0_x]


# J : Objective function
# FourierFields가 측정한 필드, 모니터의 중심에서 E 구성요소의 절댓값을 제곱한 값을 취한 후 평균을 계산하여 평균 강도를 계산
# [frequency index, moniter index]
def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2)

# optimization 설정

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decay_by=1e-3,
)

# 함수 설정

evaluation_history = []
cur_iter = [0]
numevl = 1

def f(v, gradient, beta):
    global numevl
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient
    # f0, dJ_du = opt()

    # Adjoint gradient
    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, np.sum(dJ_du, axis=1)
        )  # backprop

    evaluation_history.append(np.real(f0))

    np.savetxt(design_dir+"structure_0"+str(numevl) +".txt", design_variables.weights)
    
    numevl += 1
    
    print("First FoM: {}".format(evaluation_history[0]))
    print("Current FoM: {}".format(np.real(f0)))

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %%
opt.plot2D(True,output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# /home/user/anaconda3/envs/mp/lib/python3.11/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(

# %%
f0, dJ_du = opt()
# Out:
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000182152 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.1267 s
# -----------
# on time step 1198 (time=29.95), 0.00334024 s/step
# run 0 finished at t = 50.425000000000004 (2017 timesteps)
# Starting adjoint run...
# on time step 1278 (time=31.95), 0.00313015 s/step
# run 1 finished at t = 50.050000000000004 (2002 timesteps)
# Calculating gradient...

# %%
db = 1e-5
choose = 1000
g_discrete, idx = opt.calculate_fd_gradient(num_gradients=choose, db=db)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000242949 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.130182 s
# -----------
# on time step 1165 (time=29.125), 0.00343412 s/step
# run 2 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000181913 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127037 s
# -----------
# on time step 1086 (time=27.15), 0.00368401 s/step
# run 3 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000172853 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127017 s
# -----------
# on time step 1223 (time=30.575), 0.0032708 s/step
# run 4 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0001719 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123502 s
# -----------
# on time step 1225 (time=30.625), 0.00326563 s/step
# run 5 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000169039 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.126982 s
# -----------
# on time step 1217 (time=30.425), 0.0032874 s/step
# run 6 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164032 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127384 s
# -----------
# on time step 1240 (time=31), 0.00322705 s/step
# run 7 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125393 s
# -----------
# on time step 1224 (time=30.6), 0.0032695 s/step
# run 8 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000181913 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12688 s
# -----------
# on time step 1217 (time=30.425), 0.00328805 s/step
# run 9 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164032 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.128319 s
# -----------
# on time step 1115 (time=27.875), 0.00358902 s/step
# run 10 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000168085 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127019 s
# -----------
# on time step 1159 (time=28.975), 0.00345177 s/step
# run 11 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127392 s
# -----------
# on time step 1172 (time=29.3), 0.00341496 s/step
# run 12 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000162125 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125444 s
# -----------
# on time step 1196 (time=29.9), 0.0033455 s/step
# run 13 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127142 s
# -----------
# on time step 1241 (time=31.025), 0.00322503 s/step
# run 14 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000174999 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.129548 s
# -----------
# on time step 1214 (time=30.35), 0.00329735 s/step
# run 15 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124749 s
# -----------
# on time step 1283 (time=32.075), 0.00311776 s/step
# run 16 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000160933 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123818 s
# -----------
# on time step 1252 (time=31.3), 0.003197 s/step
# run 17 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000156879 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12439 s
# -----------
# on time step 1232 (time=30.8), 0.00324837 s/step
# run 18 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164032 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.126631 s
# -----------
# on time step 1191 (time=29.775), 0.00336067 s/step
# run 19 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000180006 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.13038 s
# -----------
# on time step 1218 (time=30.45), 0.00328535 s/step
# run 20 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125999 s
# -----------
# on time step 1257 (time=31.425), 0.00318403 s/step
# run 21 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124889 s
# -----------
# on time step 1279 (time=31.975), 0.00312745 s/step
# run 22 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127949 s
# -----------
# on time step 1257 (time=31.425), 0.00318275 s/step
# run 23 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000157833 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124844 s
# -----------
# on time step 1270 (time=31.75), 0.00315076 s/step
# run 24 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000174046 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125999 s
# -----------
# on time step 1284 (time=32.1), 0.00311542 s/step
# run 25 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000158072 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.138866 s
# -----------
# on time step 1276 (time=31.9), 0.00313555 s/step
# run 26 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000204086 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125128 s
# -----------
# on time step 1264 (time=31.6), 0.0031658 s/step
# run 27 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127971 s
# -----------
# on time step 1262 (time=31.55), 0.00317064 s/step
# run 28 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.141069 s
# -----------
# on time step 1247 (time=31.175), 0.00320801 s/step
# run 29 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124334 s
# -----------
# on time step 1313 (time=32.825), 0.00304709 s/step
# run 30 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00016284 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125823 s
# -----------
# on time step 1208 (time=30.2), 0.00331181 s/step
# run 31 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000158072 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.122871 s
# -----------
# on time step 1257 (time=31.425), 0.00318323 s/step
# run 32 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000170946 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124241 s
# -----------
# on time step 1285 (time=32.125), 0.00311304 s/step
# run 33 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000166893 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.126946 s
# -----------
# on time step 1163 (time=29.075), 0.00343981 s/step
# run 34 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12422 s
# -----------
# on time step 1206 (time=30.15), 0.00331754 s/step
# run 35 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161171 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.140727 s
# -----------
# on time step 1224 (time=30.6), 0.00326939 s/step
# run 36 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000173092 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124273 s
# -----------
# on time step 1261 (time=31.525), 0.00317215 s/step
# run 37 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000174999 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12661 s
# -----------
# on time step 1240 (time=31), 0.00322676 s/step
# run 38 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000157833 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124561 s
# -----------
# on time step 1208 (time=30.2), 0.00331246 s/step
# run 39 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164986 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.139478 s
# -----------
# on time step 1204 (time=30.1), 0.00332304 s/step
# run 40 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000169992 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127916 s
# -----------
# on time step 1235 (time=30.875), 0.00323916 s/step
# run 41 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000165939 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.126199 s
# -----------
# on time step 1263 (time=31.575), 0.00316764 s/step
# run 42 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164986 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123759 s
# -----------
# on time step 1300 (time=32.5), 0.00307839 s/step
# run 43 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000162125 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124283 s
# -----------
# on time step 1284 (time=32.1), 0.00311539 s/step
# run 44 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12596 s
# -----------
# on time step 1214 (time=30.35), 0.0032962 s/step
# run 45 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000167131 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.128907 s
# -----------
# on time step 1140 (time=28.5), 0.0035103 s/step
# run 46 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.139531 s
# -----------
# on time step 1184 (time=29.6), 0.00338058 s/step
# run 47 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000162125 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.128212 s
# -----------
# on time step 1187 (time=29.675), 0.00337074 s/step
# run 48 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164986 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123523 s
# -----------
# on time step 1223 (time=30.575), 0.00327171 s/step
# run 49 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12439 s
# -----------
# on time step 1250 (time=31.25), 0.00320197 s/step
# run 50 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000156879 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.126091 s
# -----------
# on time step 1211 (time=30.275), 0.00330366 s/step
# run 51 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164032 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125433 s
# -----------
# on time step 1232 (time=30.8), 0.0032481 s/step
# run 52 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000157833 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12916 s
# -----------
# on time step 1286 (time=32.15), 0.00311085 s/step
# run 53 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.1237 s
# -----------
# on time step 1252 (time=31.3), 0.00319503 s/step
# run 54 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000167847 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12425 s
# -----------
# on time step 1219 (time=30.475), 0.0032822 s/step
# run 55 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124978 s
# -----------
# on time step 1239 (time=30.975), 0.00323022 s/step
# run 56 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164986 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125444 s
# -----------
# on time step 1251 (time=31.275), 0.00319763 s/step
# run 57 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127179 s
# -----------
# on time step 1259 (time=31.475), 0.00317868 s/step
# run 58 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125771 s
# -----------
# on time step 1261 (time=31.525), 0.0031738 s/step
# run 59 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000157833 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124381 s
# -----------
# on time step 1291 (time=32.275), 0.00309927 s/step
# run 60 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124722 s
# -----------
# on time step 1301 (time=32.525), 0.00307497 s/step
# run 61 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000165939 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124166 s
# -----------
# on time step 1287 (time=32.175), 0.00310992 s/step
# run 62 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124443 s
# -----------
# on time step 1246 (time=31.15), 0.00321239 s/step
# run 63 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124261 s
# -----------
# on time step 1253 (time=31.325), 0.00319437 s/step
# run 64 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125351 s
# -----------
# on time step 1218 (time=30.45), 0.00328536 s/step
# run 65 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000165939 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127563 s
# -----------
# on time step 1179 (time=29.475), 0.00339363 s/step
# run 66 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164032 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125276 s
# -----------
# on time step 1242 (time=31.05), 0.00322068 s/step
# run 67 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000162125 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124225 s
# -----------
# on time step 1223 (time=30.575), 0.00327065 s/step
# run 68 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00016284 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125555 s
# -----------
# on time step 1219 (time=30.475), 0.00328235 s/step
# run 69 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000160933 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.129046 s
# -----------
# on time step 1278 (time=31.95), 0.00313204 s/step
# run 70 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164986 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125355 s
# -----------
# on time step 1278 (time=31.95), 0.00313098 s/step
# run 71 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000156879 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12451 s
# -----------
# on time step 1288 (time=32.2), 0.00310666 s/step
# run 72 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000163794 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.128326 s
# -----------
# on time step 1225 (time=30.625), 0.00326533 s/step
# run 73 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000158787 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12521 s
# -----------
# on time step 1242 (time=31.05), 0.00322294 s/step
# run 74 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124771 s
# -----------
# on time step 1281 (time=32.025), 0.00312422 s/step
# run 75 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161171 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123922 s
# -----------
# on time step 1278 (time=31.95), 0.00313128 s/step
# run 76 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000162125 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124035 s
# -----------
# on time step 1231 (time=30.775), 0.00325071 s/step
# run 77 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000166893 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125604 s
# -----------
# on time step 1270 (time=31.75), 0.00315159 s/step
# run 78 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164986 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127511 s
# -----------
# on time step 1251 (time=31.275), 0.00319847 s/step
# run 79 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164986 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124324 s
# -----------
# on time step 1238 (time=30.95), 0.00323273 s/step
# run 80 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000160933 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.129291 s
# -----------
# on time step 1218 (time=30.45), 0.00328554 s/step
# run 81 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000160933 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.140119 s
# -----------
# on time step 1211 (time=30.275), 0.00330317 s/step
# run 82 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164032 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125893 s
# -----------
# on time step 1268 (time=31.7), 0.00315504 s/step
# run 83 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00016284 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12352 s
# -----------
# on time step 1244 (time=31.1), 0.00321753 s/step
# run 84 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124165 s
# -----------
# on time step 1226 (time=30.65), 0.00326451 s/step
# run 85 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000167847 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124934 s
# -----------
# on time step 1301 (time=32.525), 0.00307529 s/step
# run 86 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125239 s
# -----------
# on time step 1246 (time=31.15), 0.00321082 s/step
# run 87 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000160933 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124719 s
# -----------
# on time step 1289 (time=32.225), 0.00310529 s/step
# run 88 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000157833 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125082 s
# -----------
# on time step 1301 (time=32.525), 0.00307518 s/step
# run 89 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127068 s
# -----------
# on time step 1267 (time=31.675), 0.0031571 s/step
# run 90 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00016284 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123349 s
# -----------
# on time step 1225 (time=30.625), 0.00326575 s/step
# run 91 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00016284 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125894 s
# -----------
# on time step 1218 (time=30.45), 0.00328476 s/step
# run 92 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000177145 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124669 s
# -----------
# on time step 1273 (time=31.825), 0.00314399 s/step
# run 93 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125066 s
# -----------
# on time step 1255 (time=31.375), 0.00318838 s/step
# run 94 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000163078 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.141972 s
# -----------
# on time step 1289 (time=32.225), 0.00310356 s/step
# run 95 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164032 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.140465 s
# -----------
# on time step 1199 (time=29.975), 0.00333831 s/step
# run 96 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123516 s
# -----------
# on time step 1268 (time=31.7), 0.0031554 s/step
# run 97 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123594 s
# -----------
# on time step 1230 (time=30.75), 0.00325276 s/step
# run 98 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000170946 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.15975 s
# -----------
# on time step 1153 (time=28.825), 0.0034718 s/step
# run 99 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000173092 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.129982 s
# -----------
# on time step 1103 (time=27.575), 0.00362689 s/step
# run 100 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000175953 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.129384 s
# -----------
# on time step 1190 (time=29.75), 0.00336239 s/step
# run 101 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000169039 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.147864 s
# -----------
# on time step 1089 (time=27.225), 0.00367354 s/step
# run 102 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000169039 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.130581 s
# -----------
# on time step 1098 (time=27.45), 0.00364372 s/step
# run 103 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000231028 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.209371 s
# -----------
# on time step 1097 (time=27.425), 0.00364881 s/step
# run 104 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000170231 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.149506 s
# -----------
# on time step 1175 (time=29.375), 0.00340691 s/step
# run 105 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000167847 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.129424 s
# -----------
# on time step 1191 (time=29.775), 0.00335866 s/step
# run 106 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000170946 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.145486 s
# -----------
# on time step 1077 (time=26.925), 0.00371582 s/step
# run 107 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000174046 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.129619 s
# -----------
# on time step 1136 (time=28.4), 0.00352186 s/step
# run 108 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000238895 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.207919 s
# -----------
# on time step 983 (time=24.575), 0.00407091 s/step
# run 109 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000168085 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.141905 s
# -----------
# on time step 1262 (time=31.55), 0.00317109 s/step
# run 110 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000168085 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.130015 s
# -----------
# on time step 1247 (time=31.175), 0.00320938 s/step
# run 111 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000168085 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.136453 s
# -----------
# on time step 1159 (time=28.975), 0.00345235 s/step
# run 112 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000169039 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.142141 s
# -----------
# on time step 1220 (time=30.5), 0.00327936 s/step
# run 113 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000235081 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.213101 s
# -----------
# on time step 764 (time=19.1), 0.00524027 s/step
# run 114 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000169992 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.1399 s
# -----------
# ...
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124583 s
# -----------
# on time step 1297 (time=32.425), 0.00308569 s/step
# run 1964 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000163078 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124778 s
# -----------
# on time step 1295 (time=32.375), 0.00308985 s/step
# run 1965 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000164032 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125028 s
# -----------
# on time step 1287 (time=32.175), 0.00310943 s/step
# run 1966 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000157833 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12452 s
# -----------
# on time step 1290 (time=32.25), 0.00310187 s/step
# run 1967 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000157833 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124472 s
# -----------
# on time step 1279 (time=31.975), 0.0031284 s/step
# run 1968 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000158072 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124451 s
# -----------
# on time step 1293 (time=32.325), 0.00309534 s/step
# run 1969 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000173092 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124421 s
# -----------
# on time step 1295 (time=32.375), 0.003089 s/step
# run 1970 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000160933 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124387 s
# -----------
# on time step 1295 (time=32.375), 0.00308896 s/step
# run 1971 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000189781 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125092 s
# -----------
# on time step 1294 (time=32.35), 0.00309258 s/step
# run 1972 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125616 s
# -----------
# on time step 1294 (time=32.35), 0.00309257 s/step
# run 1973 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000163794 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124549 s
# -----------
# on time step 1288 (time=32.2), 0.00310573 s/step
# run 1974 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000172138 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124868 s
# -----------
# on time step 1294 (time=32.35), 0.00309285 s/step
# run 1975 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124835 s
# -----------
# on time step 1290 (time=32.25), 0.0031009 s/step
# run 1976 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124683 s
# -----------
# on time step 1284 (time=32.1), 0.00311577 s/step
# run 1977 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000187159 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124997 s
# -----------
# on time step 1275 (time=31.875), 0.00313739 s/step
# run 1978 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000163078 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124398 s
# -----------
# on time step 1292 (time=32.3), 0.00309636 s/step
# run 1979 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124626 s
# -----------
# on time step 1294 (time=32.35), 0.003092 s/step
# run 1980 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000169039 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124492 s
# -----------
# on time step 1292 (time=32.3), 0.00309687 s/step
# run 1981 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000157833 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124619 s
# -----------
# on time step 1288 (time=32.2), 0.00310629 s/step
# run 1982 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000176907 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.127721 s
# -----------
# on time step 1295 (time=32.375), 0.0030905 s/step
# run 1983 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000169992 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124993 s
# -----------
# on time step 1288 (time=32.2), 0.00310684 s/step
# run 1984 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.126535 s
# -----------
# on time step 1276 (time=31.9), 0.00313546 s/step
# run 1985 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.1244 s
# -----------
# on time step 1284 (time=32.1), 0.0031154 s/step
# run 1986 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161171 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125172 s
# -----------
# on time step 1283 (time=32.075), 0.00311771 s/step
# run 1987 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125121 s
# -----------
# on time step 1279 (time=31.975), 0.00312881 s/step
# run 1988 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00018096 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12497 s
# -----------
# on time step 1295 (time=32.375), 0.00308978 s/step
# run 1989 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124514 s
# -----------
# on time step 1287 (time=32.175), 0.0031089 s/step
# run 1990 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000158072 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124393 s
# -----------
# on time step 1292 (time=32.3), 0.00309704 s/step
# run 1991 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000158072 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124473 s
# -----------
# on time step 1296 (time=32.4), 0.00308827 s/step
# run 1992 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000158072 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124222 s
# -----------
# on time step 1259 (time=31.475), 0.00317816 s/step
# run 1993 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159979 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.12493 s
# -----------
# on time step 1289 (time=32.225), 0.00310518 s/step
# run 1994 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000160933 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.123957 s
# -----------
# on time step 1288 (time=32.2), 0.00310605 s/step
# run 1995 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124455 s
# -----------
# on time step 1295 (time=32.375), 0.00309067 s/step
# run 1996 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000163078 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.125158 s
# -----------
# on time step 1295 (time=32.375), 0.00308963 s/step
# run 1997 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000163078 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.124701 s
# -----------
# on time step 1296 (time=32.4), 0.00308787 s/step
# run 1998 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.142462 s
# -----------
# on time step 1243 (time=31.075), 0.00321992 s/step
# run 1999 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000161886 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.140126 s
# -----------
# on time step 1239 (time=30.975), 0.00323004 s/step
# run 2000 finished at t = 50.050000000000004 (2002 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000159025 s
# Working in 3D dimensions.
# Computational cell is 2.5 x 2.5 x 3 with resolution 20
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.139908 s
# -----------
# on time step 1287 (time=32.175), 0.00310811 s/step
# run 2001 finished at t = 50.050000000000004 (2002 timesteps)

# %%
(m, b) = np.polyfit(np.squeeze(g_discrete), dJ_du[idx], 1)

# %%
min_g = np.min(g_discrete)
max_g = np.max(g_discrete)

fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Best fit")
plt.plot(g_discrete, dJ_du[idx], "o", label="Adjoint comparison")
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(g_discrete) - np.squeeze(dJ_du[idx]))
    / np.abs(np.squeeze(g_discrete))
    * 100
)
plt.semilogy(g_discrete, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()

# %%
opt.plot2D(True,output_plane = mp.Volume(size = (np.inf, 0, np.inf), center = (0,0,0)))
# Out:
#      block, center = (0,0,0.25)
#           size (0.5,0.5,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %%
f=0

plt.subplot(2, 2, 1)
dJ_du_0 = dJ_du.reshape(Nx *Ny, Nz).transpose()[f]
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, Ny)), )
plt.ylabel("Adjoint Gradient")
plt.colorbar()

plt.subplot(2, 2, 2)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx *Ny, Nz).transpose()[f]
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, Ny)), )
plt.ylabel("Finite Difference Gradient")
plt.colorbar()



plt.subplot(2, 2, 3)
err_p=rel_err.reshape(Nx *Ny, Nz).transpose()[f]
plt.imshow(np.rot90(err_p.reshape(Nx, Ny)),)
plt.ylabel("Relative Error (%)")
plt.colorbar()


plt.subplot(2, 2, 4)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, Ny)),)
plt.ylabel("Error")
plt.colorbar()
