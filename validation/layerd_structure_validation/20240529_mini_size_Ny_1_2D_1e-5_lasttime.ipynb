# %% [markdown]
# # Metalens Optimization with FourierFields
#
# This tutorial illustates the adjoint solver for DFT fields. Specifically, we use the `FourierFields` adjoint solver to design a metalens that maximizes the average intensity over three frequencies at a spot near the metalens. In a similar [example](https://github.com/NanoComp/meep/blob/master/python/examples/adjoint_optimization/05-Near2Far.ipynb) based on the `Near2FarFields` adjoint solver, the focal spot is far from the metalens. Compared with `Near2FarFields`, the `FourierFields` adjoint solver has some advantages, including higher efficiency for fields at nearby points and greater flexibility for surrounding media (not limited to homogeneous media surrounding far-field regions when `Near2FarFields` is applied). On the other hand, the disadvantage is that `FourierFields` is less efficient for faraway points, which require a large computational cell.
#
# At first, let us import `meep`, its adjoint module `meep.adjoint`, and other packages for automatic differentiation, nonlinear optimization, and making figures.

# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle

mp.verbosity(1)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1.0)

# %% [markdown]
# Basic setup

# %%
resolution = 25

design_region_width = 3.0
design_region_height = 1.0
pml_size = 1.0

Sx = design_region_width
Sy = 2 * pml_size + design_region_height + 5
cell_size = mp.Vector3(Sx, Sy)

wavelength = 1.55
fcen = 1/wavelength
# nf = len(frequencies) # number of frequencies

minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

pml_layers = [mp.PML(thickness = pml_size, direction = mp.Y)]

fcen = 1 / 1.55
width = 0.2
fwidth = width * fcen
source_center = [0, -(Sy / 2) + pml_size + 2/resolution, 0]
source_size = mp.Vector3(Sx, 0, 0)
src = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ez, size=source_size, center=source_center)]

Nx = int(round(design_region_resolution * design_region_width)) + 1
Ny = int(round(design_region_resolution * design_region_height)) + 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, 1), Air, Si, grid_type="U_MEAN")
design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0,-Sy/2 + pml_size + 1.5),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


def mapping(x, eta, beta):

    # # filter
    # filtered_field = mpa.conic_filter(
    #     x,
    #     filter_radius,
    #     design_region_width,
    #     design_region_height,
    #     design_region_resolution,
    # )

    # projection
    # projected_field = mpa.tanh_projection(x, beta, eta)

    # interpolate to actual materials
    return x


geometry = [
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %% [markdown]
# To use the `mpa.FourierFields` adjoint solver, we need to specify the monitor where DFT fields are evaluated. In this example, we try to focus the light at three different frequencies. The objective function is simply the intensity at the focal spot averaged over those frequencies.

# %%
monitor_position, monitor_size = mp.Vector3(0,-Sy/2 + pml_size + 1.5 + design_region_height/2 + 3), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    fcen=fcen,
    df=0,
    nf=1,
    maximum_run_time=156.68,
    decay_by=1e-5,
    finite_difference_step=0.001 
)
opt.plot2D(True)
# Out:
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %% [markdown]
# To apply `nlopt` for nonlinear optimization, the following function is defined. This function also illustrates the structure in the design region during optimization and records the evaluation history of the objective function.

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, dJ_du
        )  # backprop

    evaluation_history.append(np.real(f0))

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %% [markdown]
# The optimizer runs in multiple loops with increasing beta, which gradually turns on the thresholding. When beta changes, the cost function also changes, which requires the optimizer to be reset.

# %%
f0, dJ_du = opt()
# Out:
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.88622e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0157359 s
# -----------
# run 0 finished at t = 78.02 (3901 timesteps)
# Starting adjoint run...
# run 1 finished at t = 156.70000000000002 (7835 timesteps)
# Calculating gradient...

# %%
print(dJ_du)
print(f0)
# Out:
# [-17.50801409  -8.69074544  -8.50729641  -8.32211062  -8.07785971
#   -7.77640555  -7.42003912  -7.01145526  -6.55372818  -6.05028483
#   -5.50486983  -4.92151379  -4.30449828  -3.65831593  -2.98763416
#   -2.2972556   -1.59207851  -0.87706031  -0.15717847   0.5626073
#    1.27738748   1.98233771   2.67275023   3.34406259   3.99188551
#    4.61202791   5.20051803   5.75362425   6.2678728    6.74006299
#    7.16728143   7.54691304   7.87664995   8.15450059   8.37879662
#    8.54819718   8.6616931    8.71861003   8.71861003   8.6616931
#    8.54819718   8.37879662   8.15450059   7.87664995   7.54691304
#    7.16728143   6.74006299   6.2678728    5.75362425   5.20051803
#    4.61202791   3.99188551   3.34406259   2.67275023   1.98233771
#    1.27738748   0.5626073   -0.15717847  -0.87706031  -1.59207851
#   -2.2972556   -2.98763416  -3.65831593  -4.30449828  -4.92151379
#   -5.50486983  -6.05028483  -6.55372818  -7.01145526  -7.42003912
#   -7.77640555  -8.07785971  -8.32211062  -8.50729641  -8.69074544
#  -17.50801409]
# 3.7766771259683733

# %%
print(dJ_du.size)
# Out:
# 76

# %%
# #x = np.loadtxt('/root/design_result/gd/lastdesign.txt')

# n = Nx * 1  # number of parameters
# x = np.ones((n,)) * 0.5
# opt.update_design([x])

# fdg_list=[]
# eps_diff=0.001

# f0, dJ_du = opt([x])
# for i in range(x.size):
#     print(i)
#     copy_x=x.copy()
#     copy_x[i] = copy_x[i]+eps_diff
#     #print(copy_x)
#     f0_new, dJ_du_new = opt([copy_x])
#     f0_diff = f0_new - f0
#     fdg = f0_diff / eps_diff
#     #fdg_list.append(np.real(fdg))
#     fdg_list.append(fdg)

# # np.savetxt("/root/design_result/gd/fdg_list.txt", fdg_list)

# %%
# print(fdg_list)

# %%
# fd_gradient=np.array(fdg_list)
# #print(x)
# opt.update_design([x])
# #(f, dJ_du)=opt.get_fdf_funcs()
# #adjoint_gradient=dJ_du(x)
# adjoint_gradient=dJ_du

# (m, b) = np.polyfit(fd_gradient, adjoint_gradient, 1)
# min_g = np.min(fd_gradient)
# max_g = np.max(fd_gradient)

# fig = plt.figure(figsize=(12, 6))

# plt.subplot(1, 2, 1)
# plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
# plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Linear Regression")
# plt.plot(fd_gradient, adjoint_gradient, "o", label="Adjoint comparison")
# plt.xlabel("Finite Difference Gradient")
# plt.ylabel("Adjoint Gradient")
# plt.legend()
# plt.grid(True)
# plt.axis("square")

# plt.subplot(1, 2, 2)
# rel_err = (
#     np.abs(np.squeeze(fd_gradient) - np.squeeze(adjoint_gradient))
#     / np.abs(np.squeeze(fd_gradient))
#     * 100
# )
# plt.semilogy(fd_gradient, rel_err, "o")
# plt.grid(True)
# plt.xlabel("Finite Difference Gradient")
# plt.ylabel("Relative Error (%)")

# fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# fig.suptitle("Resolution: {} Nx: {}, Ny:{}".format(resolution, Nx, Ny))
# plt.show()

# %% [markdown]
# We can plot the optimized geometry.

# %%
db = 1e-5
choose = 76
g_discrete, idx = opt.calculate_fd_gradient(num_gradients=choose, db=db)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173509 s
# -----------
# run 2 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018472 s
# -----------
# run 3 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018122 s
# -----------
# run 4 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173221 s
# -----------
# run 5 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017066 s
# -----------
# run 6 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172391 s
# -----------
# run 7 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174792 s
# -----------
# run 8 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169351 s
# -----------
# run 9 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172498 s
# -----------
# run 10 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166941 s
# -----------
# run 11 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016824 s
# -----------
# run 12 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 5.31673e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169499 s
# -----------
# run 13 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170159 s
# -----------
# run 14 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169959 s
# -----------
# run 15 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017463 s
# -----------
# run 16 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166521 s
# -----------
# run 17 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017385 s
# -----------
# run 18 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169728 s
# -----------
# run 19 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171261 s
# -----------
# run 20 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.29018e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01685 s
# -----------
# run 21 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017014 s
# -----------
# run 22 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.38554e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176871 s
# -----------
# run 23 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169048 s
# -----------
# run 24 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173011 s
# -----------
# run 25 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169079 s
# -----------
# run 26 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171721 s
# -----------
# run 27 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169981 s
# -----------
# run 28 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167251 s
# -----------
# run 29 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168769 s
# -----------
# run 30 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168781 s
# -----------
# run 31 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166972 s
# -----------
# run 32 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166452 s
# -----------
# run 33 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167398 s
# -----------
# run 34 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174239 s
# -----------
# run 35 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016959 s
# -----------
# run 36 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167482 s
# -----------
# run 37 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169449 s
# -----------
# run 38 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017009 s
# -----------
# run 39 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169802 s
# -----------
# run 40 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165551 s
# -----------
# run 41 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0178459 s
# -----------
# run 42 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165372 s
# -----------
# run 43 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01685 s
# -----------
# run 44 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0203681 s
# -----------
# run 45 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0164361 s
# -----------
# run 46 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016609 s
# -----------
# run 47 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169251 s
# -----------
# run 48 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170562 s
# -----------
# run 49 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170419 s
# -----------
# run 50 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171611 s
# -----------
# run 51 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016876 s
# -----------
# run 52 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017359 s
# -----------
# run 53 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018522 s
# -----------
# run 54 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167549 s
# -----------
# run 55 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017792 s
# -----------
# run 56 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165648 s
# -----------
# run 57 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168889 s
# -----------
# run 58 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016556 s
# -----------
# run 59 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.6226e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0178049 s
# -----------
# run 60 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166562 s
# -----------
# run 61 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165541 s
# -----------
# run 62 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01718 s
# -----------
# run 63 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171459 s
# -----------
# run 64 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171881 s
# -----------
# run 65 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171931 s
# -----------
# run 66 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017417 s
# -----------
# run 67 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173209 s
# -----------
# run 68 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018286 s
# -----------
# run 69 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174899 s
# -----------
# run 70 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0175171 s
# -----------
# run 71 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174019 s
# -----------
# run 72 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171552 s
# -----------
# run 73 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016973 s
# -----------
# run 74 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.79221e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174282 s
# -----------
# run 75 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017483 s
# -----------
# run 76 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173829 s
# -----------
# run 77 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016624 s
# -----------
# run 78 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169349 s
# -----------
# run 79 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171101 s
# -----------
# run 80 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017745 s
# -----------
# run 81 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168531 s
# -----------
# run 82 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017242 s
# -----------
# run 83 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169461 s
# -----------
# run 84 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016974 s
# -----------
# run 85 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172281 s
# -----------
# run 86 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173659 s
# -----------
# run 87 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017385 s
# -----------
# run 88 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017103 s
# -----------
# run 89 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166941 s
# -----------
# run 90 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167081 s
# -----------
# run 91 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167239 s
# -----------
# run 92 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168228 s
# -----------
# run 93 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.88622e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01665 s
# -----------
# run 94 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169239 s
# -----------
# run 95 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169442 s
# -----------
# run 96 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170951 s
# -----------
# run 97 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168781 s
# -----------
# run 98 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170169 s
# -----------
# run 99 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167899 s
# -----------
# run 100 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.81606e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169852 s
# -----------
# run 101 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0254071 s
# -----------
# run 102 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016808 s
# -----------
# run 103 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167608 s
# -----------
# run 104 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01685 s
# -----------
# run 105 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169239 s
# -----------
# run 106 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168722 s
# -----------
# run 107 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0179131 s
# -----------
# run 108 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016921 s
# -----------
# run 109 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016937 s
# -----------
# run 110 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016433 s
# -----------
# run 111 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167789 s
# -----------
# run 112 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170341 s
# -----------
# run 113 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167658 s
# -----------
# run 114 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166512 s
# -----------
# run 115 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016958 s
# -----------
# run 116 finished at t = 80.12 (4006 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168319 s
# -----------
# run 117 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167038 s
# -----------
# run 118 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167329 s
# -----------
# run 119 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016592 s
# -----------
# run 120 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165939 s
# -----------
# run 121 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166159 s
# -----------
# run 122 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0181079 s
# -----------
# run 123 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.29018e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016819 s
# -----------
# run 124 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016788 s
# -----------
# run 125 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016712 s
# -----------
# run 126 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165019 s
# -----------
# run 127 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01671 s
# -----------
# run 128 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176699 s
# -----------
# run 129 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165122 s
# -----------
# run 130 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173221 s
# -----------
# run 131 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017164 s
# -----------
# run 132 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017338 s
# -----------
# run 133 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170321 s
# -----------
# run 134 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166399 s
# -----------
# run 135 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016654 s
# -----------
# run 136 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172381 s
# -----------
# run 137 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169251 s
# -----------
# run 138 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174561 s
# -----------
# run 139 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172639 s
# -----------
# run 140 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169559 s
# -----------
# run 141 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171561 s
# -----------
# run 142 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016674 s
# -----------
# run 143 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168869 s
# -----------
# run 144 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017555 s
# -----------
# run 145 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016854 s
# -----------
# run 146 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168109 s
# -----------
# run 147 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.19481e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016748 s
# -----------
# run 148 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166919 s
# -----------
# run 149 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016597 s
# -----------
# run 150 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016583 s
# -----------
# run 151 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173912 s
# -----------
# run 152 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0161741 s
# -----------
# run 153 finished at t = 80.12 (4006 timesteps)

# %%
print(g_discrete)
# Out:
# [[-5.222069648613825], [-5.135044425763624], [-5.037362417370517], [-4.893040009479321], [-4.704121916665471], [-4.4732679179038115], [-4.2036926935384855], [-3.899095889892123], [-3.5635943969936075], [-3.2016244821519986], [-2.817869777160808], [-2.4171595021993397], [-2.00436734401066], [-1.584339314009142], [-1.1617893167059634], [-0.7412194952483019], [-0.3268522906552107], [0.07744556875799447], [0.468207365189599], [0.8259655706943646], [1.1644653680420447], [1.50026784964119], [1.8142225513884112], [2.10519092700423], [2.372479090384516], [2.6158036145584873], [2.835254953614807], [3.031253770302555], [3.2044881447923497], [3.355856286058056], [3.4864078394924998], [3.5972755275892605], [3.6896140256814642], [3.7645430044808132], [3.823091546850676], [3.8661467715694893], [3.8944120826389645], [3.8906306549790766], [3.874311767448901], [3.861125125226294], [3.8345599789213476], [3.794086134067953], [3.7389354554662186], [3.6681315101816376], [3.5805336064953504], [3.4748911444726356], [3.349903036342638], [3.204279264545917], [3.0368068129504873], [2.8464232710412314], [2.6322807962220196], [2.3938084984909125], [2.130779668618743], [1.8433598828693218], [1.532146522009725], [1.1982057777526478], [0.8430943327919492], [0.45263092456337967], [0.044937715237836066], [-0.35758249907757994], [-0.7693203895708932], [-1.1864777969439189], [-1.604924490195003], [-2.0202714917427755], [-2.4279363192381], [-2.823218561420759], [-3.2013998330082667], [-3.557811137921973], [-3.8879290254367755], [-4.187471648009478], [-4.452466871374128], [-4.679344232139115], [-4.865000214770987], [-5.006863850320897], [-5.102955309910229], [-5.202064651799176]]

# %%
(m, b) = np.polyfit(np.squeeze(g_discrete), dJ_du[idx], 1)

# %%
min_g = np.min(g_discrete)
max_g = np.max(g_discrete)

fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Best fit")
plt.plot(g_discrete, dJ_du[idx], "o", label="Adjoint comparison")
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(g_discrete) - np.squeeze(dJ_du[idx]))
    / np.abs(np.squeeze(g_discrete))
    * 100
)
plt.semilogy(g_discrete, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()

# %%
plt.figure(dpi=900)
plt.subplot(2, 2, 1)
dJ_du_0 = dJ_du.reshape(Nx, 1)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, 1)),)
plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()


plt.subplot(2, 2, 2)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, 1)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, 1)),)
plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()



plt.subplot(2, 2, 3)
err_p=rel_err.reshape(Nx, 1)
plt.imshow(np.rot90(err_p.reshape(Nx, 1)),)
plt.ylabel("Relative Error (%)")
# plt.colorbar()


plt.subplot(2, 2, 4)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, 1)),)
plt.ylabel("Error")
# plt.colorbar()
# Out:
# Text(0, 0.5, 'Error')

# %%
np.savetxt("Adjoint_gradient_grating.txt", dJ_du)

# %%
np.savetxt("FD_gradient_grating.txt", g_discrete)

# %%
plt.figure(dpi=900)
dJ_du_0 = dJ_du.reshape(Nx, 1)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, 1)),)
# plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
plt.colorbar()

# %%
plt.figure(dpi=900)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, 1)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, 1)),)
# plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))

# %%
plt.figure(dpi=900)
err_p=rel_err.reshape(Nx, 1)
plt.imshow(np.rot90(err_p.reshape(Nx, 1)),)
plt.ylabel("Relative Error (%)")
plt.colorbar()

# %%
plt.figure(dpi=900)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, 1)),)
plt.ylabel("Error")
plt.colorbar()

# %%
gdJ_du = fd_gradient

sdJ_du = g_discrete
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 gdJ_du = fd_gradient
#       3 sdJ_du = g_discrete
#
# NameError: name 'fd_gradient' is not defined

# %%
fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(gdJ_du, sdJ_du, "o", label="Adjoint comparison")
plt.xlabel("Grating Adjoint Gradient")
plt.ylabel("Sum Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(gdJ_du) - np.squeeze(sdJ_du))
    / np.abs(np.squeeze(gdJ_du))
    * 100
)
plt.semilogy(gdJ_du, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()
