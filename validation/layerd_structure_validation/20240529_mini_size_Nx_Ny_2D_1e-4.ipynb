# %% [markdown]
# # Metalens Optimization with FourierFields
#
# This tutorial illustates the adjoint solver for DFT fields. Specifically, we use the `FourierFields` adjoint solver to design a metalens that maximizes the average intensity over three frequencies at a spot near the metalens. In a similar [example](https://github.com/NanoComp/meep/blob/master/python/examples/adjoint_optimization/05-Near2Far.ipynb) based on the `Near2FarFields` adjoint solver, the focal spot is far from the metalens. Compared with `Near2FarFields`, the `FourierFields` adjoint solver has some advantages, including higher efficiency for fields at nearby points and greater flexibility for surrounding media (not limited to homogeneous media surrounding far-field regions when `Near2FarFields` is applied). On the other hand, the disadvantage is that `FourierFields` is less efficient for faraway points, which require a large computational cell.
#
# At first, let us import `meep`, its adjoint module `meep.adjoint`, and other packages for automatic differentiation, nonlinear optimization, and making figures.

# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle

mp.verbosity(0)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1.0)

# %% [markdown]
# Basic setup

# %%
resolution = 25

design_region_width = 3.0
design_region_height = 1.0
pml_size = 1.0

Sx = design_region_width
Sy = 2 * pml_size + design_region_height + 5
cell_size = mp.Vector3(Sx, Sy)

wavelength = 1.55
fcen = 1/wavelength
# nf = len(frequencies) # number of frequencies

minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

pml_layers = [mp.PML(thickness = pml_size, direction = mp.Y)]

fcen = 1 / 1.55
width = 0.2
fwidth = width * fcen
source_center = [0, -(Sy / 2) + pml_size + 2/resolution, 0]
source_size = mp.Vector3(Sx, 0, 0)
src = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ez, size=source_size, center=source_center)]

Nx = int(round(design_region_resolution * design_region_width)) + 1
Ny = int(round(design_region_resolution * design_region_height)) + 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny), Air, Si, grid_type="U_MEAN")
design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0,-Sy/2 + pml_size + 1.5),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


def mapping(x, eta, beta):

    # # filter
    # filtered_field = mpa.conic_filter(
    #     x,
    #     filter_radius,
    #     design_region_width,
    #     design_region_height,
    #     design_region_resolution,
    # )

    # projection
    # projected_field = mpa.tanh_projection(x, beta, eta)

    # interpolate to actual materials
    return x


geometry = [
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %% [markdown]
# To use the `mpa.FourierFields` adjoint solver, we need to specify the monitor where DFT fields are evaluated. In this example, we try to focus the light at three different frequencies. The objective function is simply the intensity at the focal spot averaged over those frequencies.

# %%
monitor_position, monitor_size = mp.Vector3(0,-Sy/2 + pml_size + 1.5 + design_region_height/2 + 3), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    fcen=fcen,
    df=0,
    nf=1,
    # maximum_run_time=2000,
    decay_by=1e-4,
    finite_difference_step=0.001 
)
opt.plot2D(True)

# %% [markdown]
# To apply `nlopt` for nonlinear optimization, the following function is defined. This function also illustrates the structure in the design region during optimization and records the evaluation history of the objective function.

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, dJ_du
        )  # backprop

    evaluation_history.append(np.real(f0))

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %% [markdown]
# The optimizer runs in multiple loops with increasing beta, which gradually turns on the thresholding. When beta changes, the cost function also changes, which requires the optimizer to be reset.

# %%
f0, dJ_du = opt()
# Out:
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...

# %%
print(dJ_du)
print(f0)
# Out:
# [-0.81557647 -0.55128153 -0.56415503 ... -0.63760711 -0.63602327
#  -0.9674194 ]
# 3.7766771259683733

# %%
print(dJ_du.size)
# Out:
# 1976

# %%
#x = np.loadtxt('/root/design_result/gd/lastdesign.txt')

n = Nx * Ny  # number of parameters
x = np.ones((n,)) * 0.5
opt.update_design([x])

fdg_list=[]
eps_diff=0.001

f0, dJ_du = opt([x])
for i in range(x.size):
    print(i)
    copy_x=x.copy()
    copy_x[i] = copy_x[i]+eps_diff
    #print(copy_x)
    f0_new, dJ_du_new = opt([copy_x])
    f0_diff = f0_new - f0
    fdg = f0_diff / eps_diff
    #fdg_list.append(np.real(fdg))
    fdg_list.append(fdg)

# np.savetxt("/root/design_result/gd/fdg_list.txt", fdg_list)
# Out:
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 0
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 2
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 3
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 4
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 5
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 6
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 7
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 8
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 9
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 10
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 11
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 12
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 13
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 14
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 15
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 16
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 17
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 18
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 19
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 20
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 21
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 22
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 23
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 24
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 25
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 26
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 27
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 28
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 29
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 30
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 31
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 32
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 33
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 34
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 35
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 36
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 37
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 38
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 39
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 40
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 41
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 42
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 43
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 44
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 45
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 46
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 47
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 48
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 49
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 50
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 51
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 52
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 53
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 54
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 55
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 56
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 57
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 58
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 59
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 60
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 61
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 62
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 63
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 64
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 65
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 66
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 67
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 68
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 69
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 70
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 71
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 72
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 73
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 74
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 75
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 76
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 77
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 78
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 79
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 80
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 81
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 82
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 83
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 84
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 85
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 86
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 87
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 88
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 89
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 90
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 91
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 92
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 93
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 94
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 95
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 96
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 97
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 98
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 99
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 100
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 101
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 102
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 103
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 104
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 105
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 106
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 107
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 108
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 109
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 110
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 111
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 112
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 113
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 114
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 115
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 116
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 117
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 118
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 119
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 120
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 121
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 122
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 123
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 124
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 125
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 126
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 127
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 128
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 129
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 130
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 131
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 132
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 133
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 134
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 135
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 136
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 137
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 138
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 139
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 140
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 141
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 142
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 143
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 144
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 145
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 146
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 147
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 148
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 149
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 150
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 151
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 152
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 153
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 154
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 155
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 156
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 157
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 158
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 159
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 160
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 161
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 162
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 163
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 164
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 165
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 166
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 167
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 168
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 169
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 170
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 171
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 172
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 173
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 174
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 175
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 176
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 177
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 178
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 179
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 180
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 181
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 182
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 183
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 184
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 185
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 186
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 187
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 188
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 189
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 190
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 191
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 192
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 193
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 194
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 195
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 196
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 197
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 198
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 199
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 200
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 201
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 202
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 203
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 204
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 205
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 206
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 207
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 208
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 209
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 210
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 211
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 212
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 213
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 214
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 215
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 216
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 217
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 218
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 219
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 220
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 221
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 222
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 223
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 224
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 225
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 226
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 227
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 228
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 229
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 230
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 231
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 232
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 233
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 234
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 235
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 236
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 237
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 238
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 239
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 240
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 241
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 242
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 243
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 244
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 245
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 246
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 247
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 248
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 249
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 250
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 251
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 252
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 253
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 254
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 255
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 256
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 257
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 258
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 259
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 260
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 261
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 262
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 263
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 264
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 265
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 266
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 267
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 268
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 269
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 270
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 271
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 272
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 273
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 274
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 275
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 276
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 277
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 278
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 279
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 280
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 281
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 282
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 283
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 284
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 285
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 286
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 287
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 288
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 289
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 290
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 291
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 292
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 293
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 294
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 295
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 296
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 297
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 298
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 299
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 300
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 301
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 302
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 303
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 304
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 305
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 306
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 307
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 308
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 309
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 310
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 311
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 312
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 313
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 314
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 315
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 316
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 317
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 318
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 319
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 320
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 321
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 322
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 323
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 324
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 325
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 326
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 327
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 328
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 329
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 330
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 331
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 332
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 333
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 334
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 335
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 336
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 337
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 338
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 339
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 340
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 341
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 342
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 343
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 344
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 345
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 346
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 347
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 348
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 349
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 350
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 351
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 352
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 353
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 354
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 355
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 356
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 357
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 358
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 359
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 360
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 361
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 362
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 363
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 364
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 365
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 366
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 367
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 368
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 369
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 370
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 371
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 372
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 373
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 374
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 375
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 376
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 377
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 378
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 379
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 380
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 381
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 382
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 383
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 384
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 385
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 386
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 387
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 388
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 389
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 390
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 391
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 392
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 393
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 394
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 395
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 396
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 397
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 398
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 399
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 400
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 401
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 402
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 403
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 404
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 405
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 406
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 407
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 408
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 409
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 410
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 411
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 412
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 413
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 414
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 415
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 416
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 417
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 418
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 419
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 420
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 421
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 422
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 423
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 424
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 425
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 426
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 427
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 428
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 429
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 430
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 431
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 432
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 433
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 434
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 435
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 436
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 437
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 438
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 439
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 440
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 441
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 442
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 443
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 444
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 445
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 446
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 447
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 448
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 449
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 450
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 451
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 452
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 453
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 454
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 455
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 456
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 457
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 458
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 459
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 460
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 461
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 462
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 463
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 464
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 465
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 466
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 467
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 468
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 469
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 470
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 471
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 472
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 473
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 474
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 475
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 476
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 477
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 478
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 479
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 480
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 481
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 482
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 483
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 484
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 485
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 486
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 487
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 488
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 489
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 490
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 491
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 492
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 493
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 494
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 495
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 496
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 497
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 498
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 499
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 500
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 501
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 502
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 503
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 504
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 505
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 506
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 507
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 508
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 509
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 510
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 511
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 512
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 513
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 514
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 515
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 516
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 517
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 518
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 519
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 520
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 521
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 522
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 523
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 524
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 525
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 526
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 527
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 528
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 529
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 530
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 531
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 532
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 533
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 534
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 535
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 536
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 537
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 538
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 539
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 540
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 541
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 542
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 543
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 544
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 545
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 546
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 547
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 548
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 549
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 550
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 551
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 552
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 553
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 554
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 555
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 556
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 557
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 558
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 559
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 560
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 561
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 562
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 563
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 564
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 565
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 566
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 567
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 568
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 569
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 570
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 571
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 572
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 573
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 574
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 575
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 576
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 577
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 578
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 579
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 580
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 581
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 582
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 583
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 584
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 585
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 586
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 587
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 588
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 589
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 590
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 591
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 592
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 593
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 594
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 595
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 596
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 597
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 598
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 599
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 600
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 601
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 602
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 603
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 604
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 605
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 606
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 607
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 608
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 609
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 610
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 611
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 612
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 613
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 614
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 615
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 616
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 617
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 618
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 619
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 620
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 621
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 622
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 623
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 624
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 625
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 626
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 627
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 628
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 629
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 630
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 631
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 632
# ...
# Starting adjoint run...
# Calculating gradient...
# 1769
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1770
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1771
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1772
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1773
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1774
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1775
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1776
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1777
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1778
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1779
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1780
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1781
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1782
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1783
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1784
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1785
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1786
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1787
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1788
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1789
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1790
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1791
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1792
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1793
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1794
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1795
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1796
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1797
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1798
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1799
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1800
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1801
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1802
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1803
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1804
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1805
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1806
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1807
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1808
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1809
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1810
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1811
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1812
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1813
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1814
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1815
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1816
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1817
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1818
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1819
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1820
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1821
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1822
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1823
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1824
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1825
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1826
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1827
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1828
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1829
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1830
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1831
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1832
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1833
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1834
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1835
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1836
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1837
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1838
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1839
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1840
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1841
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1842
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1843
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1844
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1845
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1846
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1847
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1848
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1849
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1850
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1851
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1852
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1853
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1854
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1855
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1856
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1857
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1858
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1859
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1860
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1861
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1862
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1863
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1864
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1865
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1866
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1867
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1868
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1869
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1870
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1871
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1872
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1873
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1874
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1875
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1876
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1877
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1878
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1879
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1880
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1881
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1882
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1883
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1884
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1885
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1886
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1887
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1888
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1889
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1890
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1891
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1892
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1893
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1894
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1895
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1896
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1897
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1898
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1899
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1900
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1901
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1902
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1903
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1904
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1905
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1906
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1907
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1908
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1909
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1910
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1911
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1912
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1913
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1914
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1915
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1916
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1917
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1918
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1919
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1920
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1921
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1922
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1923
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1924
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1925
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1926
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1927
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1928
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1929
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1930
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1931
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1932
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1933
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1934
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1935
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1936
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1937
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1938
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1939
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1940
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1941
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1942
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1943
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1944
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1945
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1946
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1947
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1948
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1949
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1950
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1951
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1952
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1953
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1954
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1955
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1956
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1957
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1958
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1959
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1960
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1961
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1962
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1963
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1964
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1965
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1966
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1967
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1968
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1969
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1970
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1971
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1972
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1973
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1974
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...
# 1975
# Starting forward run...
# Starting adjoint run...
# Calculating gradient...

# %%
print(fdg_list)
# Out:
# [-0.08919631493831126, -0.06759901859787476, -0.05393982244505935, -0.02852580701118157, -0.005938479573641686, 0.0008189002806968659, -0.012408509154404612, -0.038546846133247215, -0.06317728963356473, -0.0725891134911727, -0.06154816682824027, -0.03640005419103254, -0.011709074243304585, -0.002715552267273935, -0.01567388762091504, -0.04149358303329187, -0.065263239472646, -0.07405141116412217, -0.06375408957959294, -0.041005622027912025, -0.01910107529812244, -0.010414719654683324, -0.01959910754512073, -0.04125755134909426, -0.06321095869843418, -0.11221600793809294, -0.08792895359044373, -0.0664846525235685, -0.05296747190497442, -0.027964057627283267, -0.0058210533362412775, 0.000711063115277355, -0.012389501037768369, -0.03810865349973547, -0.06224854157044213, -0.07136054416023718, -0.06036972590917067, -0.03558868363673362, -0.011371134041038289, -0.0026810543432009837, -0.015562487565734529, -0.04099513139554922, -0.06428998345975323, -0.07276925586263694, -0.062482837845934114, -0.04004067498231123, -0.018555336419368018, -0.010164336226248238, -0.019358109176970117, -0.040736944602493, -0.06227463093000374, -0.11022701120522171, -0.08660786464642634, -0.06518149807832607, -0.05176556726449455, -0.02723537245263863, -0.005667283778709731, 0.0005134230378622817, -0.01250959595977541, -0.03774812596568644, -0.06124958396691582, -0.06989945664281905, -0.05886509207919666, -0.03447576969906052, -0.010862225876095977, -0.002647174153214138, -0.015546171636460215, -0.040557533476537344, -0.0632327687826173, -0.07122231065892493, -0.06082377316962706, -0.03868540719409452, -0.01773531993753963, -0.009808625140106386, -0.019139307227744595, -0.04025206371061074, -0.061261933963052684, -0.10779700984353546, -0.0846573478183732, -0.06326441656079318, -0.04999912734349188, -0.02616377369490941, -0.005437872150348966, 0.00022973045732399555, -0.012677272671623996, -0.03720998791645336, -0.05977623944963817, -0.06775109436607529, -0.05665585527747652, -0.03284264092817679, -0.010114124893378929, -0.0025928219293813726, -0.015514549354556095, -0.03990657989549895, -0.061674097262098826, -0.06894842512772392, -0.05838888838516354, -0.03669806671280362, -0.01653245652355473, -0.00928397288824101, -0.018812023113934373, -0.03953238195997244, -0.059768527010728434, -0.10422603250437312, -0.08210556901988575, -0.06076923061804074, -0.04770313724922204, -0.024769726693518734, -0.005133371534737918, -0.00012647546410171628, -0.012878893990597717, -0.036495225479438176, -0.05785162536997568, -0.06495681685048105, -0.053788233197682445, -0.03072457729413891, -0.00914146035801977, -0.002513749206789484, -0.015459307123322219, -0.03904600624693444, -0.059639105435271844, -0.06599221924763476, -0.0552304290184491, -0.0341232800493696, -0.014973289435893378, -0.008598601296982977, -0.018376064612413145, -0.03858390543931556, -0.05781808571558855, -0.09958520287711714, -0.07898902231517901, -0.057742192233201095, -0.04492273588452278, -0.023079647581969454, -0.004754555056551979, -0.0005378444358772327, -0.013097019004426613, -0.035605255542137115, -0.05550565922729511, -0.061570005281508244, -0.050321819791587785, -0.02816705419106391, -0.007963109621034192, -0.002404554304114015, -0.015369852151891905, -0.03798076987870935, -0.05716031121405507, -0.06241126935968566, -0.051415744016125586, -0.031018547294259236, -0.013092025185956757, -0.00776315095474267, -0.017831283934066633, -0.03741450734406904, -0.055441245965237584, -0.09396628119429096, -0.0753517636615797, -0.05423886986810622, -0.04171210379944057, -0.021125261794319172, -0.004302446249937475, -0.0009837407219936978, -0.013310960753409873, -0.034542010768356946, -0.05277439677464635, -0.05765476210006781, -0.04632808626614526, -0.025224585675553968, -0.006601735057731872, -0.0022588816344093487, -0.015233684328208597, -0.03671704154117883, -0.05427688388581764, -0.05827469482588832, -0.0470255765974148, -0.02745276003812691, -0.010929657036085061, -0.0067904459501999526, -0.0171776 ...

# %%
fd_gradient=np.array(fdg_list)
#print(x)
opt.update_design([x])
#(f, dJ_du)=opt.get_fdf_funcs()
#adjoint_gradient=dJ_du(x)
adjoint_gradient=dJ_du

(m, b) = np.polyfit(fd_gradient, adjoint_gradient, 1)
min_g = np.min(fd_gradient)
max_g = np.max(fd_gradient)

fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Linear Regression")
plt.plot(fd_gradient, adjoint_gradient, "o", label="Adjoint comparison")
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(fd_gradient) - np.squeeze(adjoint_gradient))
    / np.abs(np.squeeze(fd_gradient))
    * 100
)
plt.semilogy(fd_gradient, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")

fig.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.suptitle("Resolution: {} Nx: {}, Ny:{}".format(resolution, Nx, Ny))
plt.show()

# %% [markdown]
# We can plot the optimized geometry.

# %%
db = 1e-5
choose = Nx * Ny
g_discrete, idx = opt.calculate_fd_gradient(num_gradients=choose, db=db)

# %%
print(g_discrete)
# Out:
# [[-0.0897456757020798], [-0.06804004256677487], [-0.05435168848322291], [-0.02883535257236502], [-0.006123337170649278], [0.0007193196038812743], [-0.012508889379869713], [-0.038742109731426666], [-0.06352115121677215], [-0.07306312587163077], [-0.06206755573945343], [-0.036854393614671466], [-0.012018834039118074], [-0.002861473402671066], [-0.015742982162336716], [-0.0416174990802709], [-0.06554331085650844], [-0.07450930094021757], [-0.06431890571256815], [-0.04154986988913478], [-0.01950432058084317], [-0.010624865420805206], [-0.019663193762120557], [-0.041302904696394194], [-0.06338025340113518], [-0.11284197053429422], [-0.08837609951628521], [-0.0668015921578835], [-0.053266761457226856], [-0.028204009627774692], [-0.005984097051214831], [0.0006099754812360914], [-0.012475943655942954], [-0.0382448080760156], [-0.06248512758322277], [-0.07170432649861169], [-0.060773867671670694], [-0.035970553058373156], [-0.01165247202061792], [-0.0028218980152594493], [-0.01562445550717939], [-0.04108917269762813], [-0.0644928206505746], [-0.07310614641431457], [-0.06291214954545765], [-0.04047193402634264], [-0.018890669661875137], [-0.010346588541487733], [-0.01940519773757643], [-0.04074083899130443], [-0.06235763875261923], [-0.11060867294299113], [-0.08702503864199683], [-0.06547508131227175], [-0.05204331093855429], [-0.02745924509994779], [-0.005820672832612671], [0.0004178085211137272], [-0.012590255205058297], [-0.03787348199502105], [-0.061467743439624904], [-0.07021814799612613], [-0.05924181414318496], [-0.03483363448797405], [-0.011127143795253145], [-0.0027801358659651494], [-0.01560426695634831], [-0.040644485188590096], [-0.06342026364070108], [-0.07153467633802535], [-0.061223181679892484], [-0.03908809775854394], [-0.01804966711649314], [-0.009980007065202301], [-0.01918299175063254], [-0.04025334849888651], [-0.06133577552525082], [-0.1081462247642939], [-0.08503119053315798], [-0.06352452476265924], [-0.05024602054426452], [-0.026364540239853792], [-0.005577221362518258], [0.00014225783884214138], [-0.012749358024866096], [-0.037319689760728636], [-0.05996794031348784], [-0.06803383928444262], [-0.056993254782256024], [-0.03316597586566772], [-0.010355292123787052], [-0.002714263913627945], [-0.015566994893134732], [-0.03998320384779319], [-0.06183944211146652], [-0.06922554262045466], [-0.05874540939254657], [-0.03705981560520044], [-0.016816719339285413], [-0.009439751724737988], [-0.018850824434757385], [-0.03952998555156739], [-0.059829368581620905], [-0.10452934148252878], [-0.08242395495017263], [-0.06098670676246697], [-0.047910758094182875], [-0.024941015686064102], [-0.005254687929223678], [-0.00020336364814355076], [-0.012939860150051883], [-0.03658487220947748], [-0.05800959921309356], [-0.06519378829006328], [-0.05407552322589381], [-0.03100382853782335], [-0.009352210028623631], [-0.0026203526792833998], [-0.015504494110807341], [-0.0391093724738667], [-0.059776135930000855], [-0.06622437334069531], [-0.05553229288635108], [-0.03443286378246313], [-0.015219210414141314], [-0.008734482925820686], [-0.018408654467449992], [-0.03857688494202094], [-0.05786248374883839], [-0.09983045725636684], [-0.07924139840964628], [-0.057909097117558865], [-0.04508378110834598], [-0.02321592084131296], [-0.004854350543759267], [-0.0006020030030029488], [-0.013144642119211623], [-0.03567102815349443], [-0.05562360978483837], [-0.061752683333526896], [-0.05054963131412293], [-0.028393904649703924], [-0.008137621176906862], [-0.002493409001491642], [-0.015406386055794028], [-0.03802834195321125], [-0.057263684039021705], [-0.06259002933717284], [-0.05165272792817532], [-0.03126620944371439], [-0.013292418898913637], [-0.007875403007506776], [-0.01785652470331911], [-0.03740207761282477], [-0.05546624791685772], [-0.09414299181331741], [-0.07552944086830493], [-0.05434870333775876], [-0.04182059234469904], [-0.02122197021448002], [-0.00437783740370179], [-0.0010333856548250253], [-0.013343406668475664], [-0.0345807861901 ...

# %%
(m, b) = np.polyfit(np.squeeze(g_discrete), dJ_du[idx], 1)

# %%
min_g = np.min(g_discrete)
max_g = np.max(g_discrete)

fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Best fit")
plt.plot(g_discrete, dJ_du[idx], "o", label="Adjoint comparison")
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(g_discrete) - np.squeeze(dJ_du[idx]))
    / np.abs(np.squeeze(g_discrete))
    * 100
)
plt.semilogy(g_discrete, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()

# %%
plt.figure(dpi=900)
plt.subplot(2, 2, 1)
dJ_du_0 = dJ_du.reshape(Nx, Ny)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, Ny)),)
plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()


plt.subplot(2, 2, 2)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, Ny)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, Ny)),)
plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()



plt.subplot(2, 2, 3)
err_p=rel_err.reshape(Nx, Ny)
plt.imshow(np.rot90(err_p.reshape(Nx, Ny)),)
plt.ylabel("Relative Error (%)")
# plt.colorbar()


plt.subplot(2, 2, 4)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, Ny)),)
plt.ylabel("Error")
# plt.colorbar()
# Out:
# Text(0, 0.5, 'Error')

# %%
np.savetxt("Adjoint_gradient_grating.txt", dJ_du)

# %%
np.savetxt("FD_gradient_grating.txt", g_discrete)

# %%
plt.figure(dpi=900)
dJ_du_0 = dJ_du.reshape(Nx, Ny)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, Ny)),)
# plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
plt.colorbar()

# %%
plt.figure(dpi=900)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, Ny)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, Ny)),)
# plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))

# %%
plt.figure(dpi=900)
err_p=rel_err.reshape(Nx, Ny)
plt.imshow(np.rot90(err_p.reshape(Nx, Ny)),)
plt.ylabel("Relative Error (%)")
plt.colorbar()

# %%
plt.figure(dpi=900)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, Ny)),)
plt.ylabel("Error")
plt.colorbar()

# %%
gdJ_du = fd_gradient

sdJ_du = g_discrete

# %%
fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(gdJ_du, sdJ_du, "o", label="Adjoint comparison")
plt.xlabel("Grating Adjoint Gradient")
plt.ylabel("Sum Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(gdJ_du) - np.squeeze(sdJ_du))
    / np.abs(np.squeeze(gdJ_du))
    * 100
)
plt.semilogy(gdJ_du, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()
