# %% [markdown]
# # Metalens Optimization with FourierFields
#
# This tutorial illustates the adjoint solver for DFT fields. Specifically, we use the `FourierFields` adjoint solver to design a metalens that maximizes the average intensity over three frequencies at a spot near the metalens. In a similar [example](https://github.com/NanoComp/meep/blob/master/python/examples/adjoint_optimization/05-Near2Far.ipynb) based on the `Near2FarFields` adjoint solver, the focal spot is far from the metalens. Compared with `Near2FarFields`, the `FourierFields` adjoint solver has some advantages, including higher efficiency for fields at nearby points and greater flexibility for surrounding media (not limited to homogeneous media surrounding far-field regions when `Near2FarFields` is applied). On the other hand, the disadvantage is that `FourierFields` is less efficient for faraway points, which require a large computational cell.
#
# At first, let us import `meep`, its adjoint module `meep.adjoint`, and other packages for automatic differentiation, nonlinear optimization, and making figures.

# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle

mp.verbosity(1)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1.0)

# %% [markdown]
# Basic setup

# %%
resolution = 25

design_region_width = 3.0
design_region_height = 1.0
pml_size = 1.0

Sx = 2 * pml_size + design_region_width
Sy = 2 * pml_size + design_region_height + 5
cell_size = mp.Vector3(Sx, Sy)

wavelength = 1.55
fcen = 1/wavelength
# nf = len(frequencies) # number of frequencies

minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

pml_layers = [mp.PML(thickness = pml_size)]

fcen = 1 / 1.55
width = 0.2
fwidth = width * fcen
source_center = [0, -(Sy / 2) + pml_size + 2/resolution, 0]
source_size = mp.Vector3(Sx, 0, 0)
src = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ez, size=source_size, center=source_center)]

Nx = int(round(design_region_resolution * design_region_width)) + 1
Ny = int(round(design_region_resolution * design_region_height)) + 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, 1), Air, Si, grid_type="U_MEAN")
design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0,-Sy/2 + pml_size + 1.5),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


def mapping(x, eta, beta):

    # # filter
    # filtered_field = mpa.conic_filter(
    #     x,
    #     filter_radius,
    #     design_region_width,
    #     design_region_height,
    #     design_region_resolution,
    # )

    # projection
    # projected_field = mpa.tanh_projection(x, beta, eta)

    # interpolate to actual materials
    return x


geometry = [
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %% [markdown]
# To use the `mpa.FourierFields` adjoint solver, we need to specify the monitor where DFT fields are evaluated. In this example, we try to focus the light at three different frequencies. The objective function is simply the intensity at the focal spot averaged over those frequencies.

# %%
monitor_position, monitor_size = mp.Vector3(0,-Sy/2 + pml_size + 1.5 + design_region_height/2 + 3), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

time = sim.round_time()

print(time)

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    fcen=fcen,
    df=0,
    nf=1,
    # maximum_run_time=2000,
    decay_by=1e-4,
    finite_difference_step=0.001 
)
opt.plot2D(True)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000102043 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0218439 s
# -----------
# 0.0
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %% [markdown]
# To apply `nlopt` for nonlinear optimization, the following function is defined. This function also illustrates the structure in the design region during optimization and records the evaluation history of the objective function.

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, dJ_du
        )  # backprop

    evaluation_history.append(np.real(f0))

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %% [markdown]
# The optimizer runs in multiple loops with increasing beta, which gradually turns on the thresholding. When beta changes, the cost function also changes, which requires the optimizer to be reset.

# %%
f0, dJ_du = opt()
# Out:
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000121832 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0212131 s
# -----------
# run 0 finished at t = 78.02 (3901 timesteps)
# Starting adjoint run...
# run 1 finished at t = 155.12 (7756 timesteps)
# Calculating gradient...

# %%
print(dJ_du)
print(f0)
# Out:
# [-2.11419531 -1.79551923 -1.49196058 -1.18898278 -0.88815855 -0.59092776
#  -0.29859486 -0.01232856  0.26683738  0.53800136  0.80039039  1.0533549
#   1.29636301  1.52899364  1.75092926  1.96194797  2.16191516  2.35077526
#   2.52854284  2.69529438  2.85115936  2.99631229  3.13096429  3.25535558
#   3.36974776  3.47441704  3.56964738  3.65572451  3.73293008  3.80153659
#   3.86180254  3.91396828  3.95825219  3.99484749  4.02391938  4.04560279
#   4.06000052  4.06718184  4.06718165  4.05999994  4.04560185  4.02391808
#   3.99484585  3.95825024  3.91396604  3.86180006  3.80153389  3.73292721
#   3.65572151  3.56964431  3.47441393  3.36974466  3.25535253  3.13096135
#   2.99630949  2.85115675  2.695292    2.52854072  2.35077342  2.16191365
#   1.9619468   1.75092845  1.5289932   1.29636293  1.05335519  0.80039104
#   0.53800235  0.26683871 -0.01232694 -0.29859296 -0.59092563 -0.88815622
#  -1.18898029 -1.49195799 -1.79551658 -2.11419262]
# 3.776677125968375

# %%
print(dJ_du.size)
# Out:
# 76

# %%
# #x = np.loadtxt('/root/design_result/gd/lastdesign.txt')

# n = Nx * 1  # number of parameters
# x = np.ones((n,)) * 0.5
# opt.update_design([x])

# fdg_list=[]
# eps_diff=0.001

# f0, dJ_du = opt([x])
# for i in range(x.size):
#     print(i)
#     copy_x=x.copy()
#     copy_x[i] = copy_x[i]+eps_diff
#     #print(copy_x)
#     f0_new, dJ_du_new = opt([copy_x])
#     f0_diff = f0_new - f0
#     fdg = f0_diff / eps_diff
#     #fdg_list.append(np.real(fdg))
#     fdg_list.append(fdg)

# # np.savetxt("/root/design_result/gd/fdg_list.txt", fdg_list)

# %%
# print(fdg_list)

# %%
# fd_gradient=np.array(fdg_list)
# #print(x)
# opt.update_design([x])
# #(f, dJ_du)=opt.get_fdf_funcs()
# #adjoint_gradient=dJ_du(x)
# adjoint_gradient=dJ_du

# (m, b) = np.polyfit(fd_gradient, adjoint_gradient, 1)
# min_g = np.min(fd_gradient)
# max_g = np.max(fd_gradient)

# fig = plt.figure(figsize=(12, 6))

# plt.subplot(1, 2, 1)
# plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
# plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Linear Regression")
# plt.plot(fd_gradient, adjoint_gradient, "o", label="Adjoint comparison")
# plt.xlabel("Finite Difference Gradient")
# plt.ylabel("Adjoint Gradient")
# plt.legend()
# plt.grid(True)
# plt.axis("square")

# plt.subplot(1, 2, 2)
# rel_err = (
#     np.abs(np.squeeze(fd_gradient) - np.squeeze(adjoint_gradient))
#     / np.abs(np.squeeze(fd_gradient))
#     * 100
# )
# plt.semilogy(fd_gradient, rel_err, "o")
# plt.grid(True)
# plt.xlabel("Finite Difference Gradient")
# plt.ylabel("Relative Error (%)")

# fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# fig.suptitle("Resolution: {} Nx: {}, Ny:{}".format(resolution, Nx, Ny))
# plt.show()

# %% [markdown]
# We can plot the optimized geometry.

# %%
db = 1e-5
choose = 76
g_discrete, idx = opt.calculate_fd_gradient(num_gradients=choose, db=db)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000132084 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222039 s
# -----------
# run 2 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022207 s
# -----------
# run 3 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.70364e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0238631 s
# -----------
# run 4 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.17912e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0228169 s
# -----------
# run 5 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0230889 s
# -----------
# run 6 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0231481 s
# -----------
# run 7 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0223289 s
# -----------
# run 8 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022824 s
# -----------
# run 9 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222011 s
# -----------
# run 10 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0236239 s
# -----------
# run 11 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.021961 s
# -----------
# run 12 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224268 s
# -----------
# run 13 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.48906e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022428 s
# -----------
# run 14 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.08375e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022238 s
# -----------
# run 15 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.021945 s
# -----------
# run 16 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.5129e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0219922 s
# -----------
# run 17 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0223751 s
# -----------
# run 18 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.48906e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0235231 s
# -----------
# run 19 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.023257 s
# -----------
# run 20 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000123024 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022558 s
# -----------
# run 21 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0214839 s
# -----------
# run 22 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0218189 s
# -----------
# run 23 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.08375e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0217869 s
# -----------
# run 24 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.70364e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022161 s
# -----------
# run 25 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.41753e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022109 s
# -----------
# run 26 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.799e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022166 s
# -----------
# run 27 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224149 s
# -----------
# run 28 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.5129e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02191 s
# -----------
# run 29 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.08375e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0230751 s
# -----------
# run 30 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0218508 s
# -----------
# run 31 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0226521 s
# -----------
# run 32 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022393 s
# -----------
# run 33 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.48906e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221529 s
# -----------
# run 34 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0220828 s
# -----------
# run 35 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224929 s
# -----------
# run 36 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222449 s
# -----------
# run 37 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0239959 s
# -----------
# run 38 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0225151 s
# -----------
# run 39 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022516 s
# -----------
# run 40 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000102043 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221331 s
# -----------
# run 41 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0226052 s
# -----------
# run 42 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022244 s
# -----------
# run 43 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.58443e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222981 s
# -----------
# run 44 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.799e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022577 s
# -----------
# run 45 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0234361 s
# -----------
# run 46 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221941 s
# -----------
# run 47 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.48906e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224569 s
# -----------
# run 48 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000103951 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022644 s
# -----------
# run 49 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0223861 s
# -----------
# run 50 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0246649 s
# -----------
# run 51 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.17912e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221899 s
# -----------
# run 52 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0226638 s
# -----------
# run 53 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0231621 s
# -----------
# run 54 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.89437e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222011 s
# -----------
# run 55 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022306 s
# -----------
# run 56 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.89301e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0217922 s
# -----------
# run 57 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02215 s
# -----------
# run 58 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221939 s
# -----------
# run 59 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222111 s
# -----------
# run 60 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0238781 s
# -----------
# run 61 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224102 s
# -----------
# run 62 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.08375e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.026396 s
# -----------
# run 63 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.023298 s
# -----------
# run 64 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.89301e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0225639 s
# -----------
# run 65 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222142 s
# -----------
# run 66 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0219529 s
# -----------
# run 67 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0218909 s
# -----------
# run 68 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222571 s
# -----------
# run 69 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.023387 s
# -----------
# run 70 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.41753e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0247221 s
# -----------
# run 71 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000103951 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0226939 s
# -----------
# run 72 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.08375e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022104 s
# -----------
# run 73 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0220881 s
# -----------
# run 74 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.17912e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0220571 s
# -----------
# run 75 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022119 s
# -----------
# run 76 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.021801 s
# -----------
# run 77 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221391 s
# -----------
# run 78 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.70364e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0233181 s
# -----------
# run 79 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.48906e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022181 s
# -----------
# run 80 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0227039 s
# -----------
# run 81 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022083 s
# -----------
# run 82 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.70364e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022315 s
# -----------
# run 83 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0220861 s
# -----------
# run 84 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0230911 s
# -----------
# run 85 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.17912e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022228 s
# -----------
# run 86 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0220881 s
# -----------
# run 87 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022085 s
# -----------
# run 88 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.98974e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.023015 s
# -----------
# run 89 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02229 s
# -----------
# run 90 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0220809 s
# -----------
# run 91 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.58443e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022805 s
# -----------
# run 92 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0226269 s
# -----------
# run 93 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.48906e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022229 s
# -----------
# run 94 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.023041 s
# -----------
# run 95 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.5129e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222352 s
# -----------
# run 96 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022234 s
# -----------
# run 97 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224221 s
# -----------
# run 98 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.60827e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.024884 s
# -----------
# run 99 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.5129e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02232 s
# -----------
# run 100 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.027051 s
# -----------
# run 101 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.5129e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224328 s
# -----------
# run 102 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022089 s
# -----------
# run 103 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.5129e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022455 s
# -----------
# run 104 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0226338 s
# -----------
# run 105 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0232949 s
# -----------
# run 106 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221479 s
# -----------
# run 107 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.5129e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02231 s
# -----------
# run 108 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.08375e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0228269 s
# -----------
# run 109 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222921 s
# -----------
# run 110 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.41753e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0239511 s
# -----------
# run 111 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.026185 s
# -----------
# run 112 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.799e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221801 s
# -----------
# run 113 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0219722 s
# -----------
# run 114 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022274 s
# -----------
# run 115 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.48906e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0223901 s
# -----------
# run 116 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000100136 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02228 s
# -----------
# run 117 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0219948 s
# -----------
# run 118 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0220599 s
# -----------
# run 119 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.41753e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224202 s
# -----------
# run 120 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.5129e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.021935 s
# -----------
# run 121 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02317 s
# -----------
# run 122 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0233471 s
# -----------
# run 123 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0233531 s
# -----------
# run 124 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0229759 s
# -----------
# run 125 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0234809 s
# -----------
# run 126 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02316 s
# -----------
# run 127 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.48906e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0232971 s
# -----------
# run 128 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0232079 s
# -----------
# run 129 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022155 s
# -----------
# run 130 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0235341 s
# -----------
# run 131 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000113964 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0230589 s
# -----------
# run 132 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0217371 s
# -----------
# run 133 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0217979 s
# -----------
# run 134 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.021878 s
# -----------
# run 135 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.91685e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0223591 s
# -----------
# run 136 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.70364e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0221751 s
# -----------
# run 137 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000106812 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.021919 s
# -----------
# run 138 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.70364e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0218542 s
# -----------
# run 139 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.91685e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022701 s
# -----------
# run 140 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.17912e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022475 s
# -----------
# run 141 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.82149e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0236521 s
# -----------
# run 142 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0217981 s
# -----------
# run 143 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.32217e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224741 s
# -----------
# run 144 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0234671 s
# -----------
# run 145 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0232651 s
# -----------
# run 146 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000126123 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0219791 s
# -----------
# run 147 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02197 s
# -----------
# run 148 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.39369e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0224361 s
# -----------
# run 149 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.022748 s
# -----------
# run 150 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000127077 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0230439 s
# -----------
# run 151 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0229921 s
# -----------
# run 152 finished at t = 78.56 (3928 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 2D dimensions.
# Computational cell is 5 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.021805 s
# -----------
# run 153 finished at t = 78.56 (3928 timesteps)

# %%
print(g_discrete)
# Out:
# [[-1.1479967835459348], [-0.9851767073243421], [-0.8308367411835603], [-0.6765322613233593], [-0.5230816111811976], [-0.37123624152535223], [-0.2216790981890426], [-0.07502435419581843], [0.06818244786543914], [0.20746305509078408], [0.3424049278777374], [0.47265863281076287], [0.5979351569873614], [0.7180023896324882], [0.8326816381298839], [0.941843525970043], [1.0454040076268711], [1.1433199688326567], [1.23558499898202], [1.322224940247807], [1.4032936405339311], [1.4788686412359195], [1.5490470960166645], [1.6139417396754394], [1.6736771099701284], [1.7283859087502405], [1.7782056027204616], [1.8232752674762762], [1.8637326097525884], [1.8997113321983503], [1.9313386252051143], [1.9587330404746692], [1.982002477429745], [2.001242572768902], [2.016535167381761], [2.0279471983908337], [2.035529662736124], [2.0393169701815594], [2.0393264218210305], [2.0355579989583816], [2.027994361109009], [2.016601062226897], [2.001327068068548], [1.9821054065616293], [1.958854205641458], [1.9314777893963961], [1.8998682366433426], [1.863906948162963], [1.8234667136685088], [1.7784137801957198], [1.7286104056601912], [1.6739174542479416], [1.6141974081396169], [1.5493174765790483], [1.479153046357595], [1.4035912594856368], [1.3225348471479492], [1.2359061051459008], [1.1436510225060204], [1.0457435503763435], [0.9421898843342545], [0.8330328923111806], [0.7183563599078012], [0.5982893809708401], [0.47301036065761076], [0.3427511090947632], [0.20780033942457973], [0.06850720013495959], [-0.07471606160436295], [-0.2213914359838753], [-0.3709736367873972], [-0.5228486755104456], [-0.676333803673046], [-0.8306776936084502], [-0.9850621449203344], [-1.1467553577393375]]

# %%
(m, b) = np.polyfit(np.squeeze(g_discrete), dJ_du[idx], 1)

# %%
min_g = np.min(g_discrete)
max_g = np.max(g_discrete)

fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Best fit")
plt.plot(g_discrete, dJ_du[idx], "o", label="Adjoint comparison")
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(g_discrete) - np.squeeze(dJ_du[idx]))
    / np.abs(np.squeeze(g_discrete))
    * 100
)
plt.semilogy(g_discrete, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()

# %%
plt.figure(dpi=900)
plt.subplot(2, 2, 1)
dJ_du_0 = dJ_du.reshape(Nx, 1)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, 1)),)
plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()


plt.subplot(2, 2, 2)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, 1)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, 1)),)
plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()



plt.subplot(2, 2, 3)
err_p=rel_err.reshape(Nx, 1)
plt.imshow(np.rot90(err_p.reshape(Nx, 1)),)
plt.ylabel("Relative Error (%)")
# plt.colorbar()


plt.subplot(2, 2, 4)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, 1)),)
plt.ylabel("Error")
# plt.colorbar()
# Out:
# Text(0, 0.5, 'Error')

# %%
np.savetxt("Adjoint_gradient_grating.txt", dJ_du)

# %%
np.savetxt("FD_gradient_grating.txt", g_discrete)

# %%
plt.figure(dpi=900)
dJ_du_0 = dJ_du.reshape(Nx, 1)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, 1)),)
# plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
plt.colorbar()

# %%
plt.figure(dpi=900)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, 1)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, 1)),)
# plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))

# %%
plt.figure(dpi=900)
err_p=rel_err.reshape(Nx, 1)
plt.imshow(np.rot90(err_p.reshape(Nx, 1)),)
plt.ylabel("Relative Error (%)")
plt.colorbar()

# %%
plt.figure(dpi=900)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, 1)),)
plt.ylabel("Error")
plt.colorbar()

# %%
gdJ_du = fd_gradient

sdJ_du = g_discrete

# %%
fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(gdJ_du, sdJ_du, "o", label="Adjoint comparison")
plt.xlabel("Grating Adjoint Gradient")
plt.ylabel("Sum Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(gdJ_du) - np.squeeze(sdJ_du))
    / np.abs(np.squeeze(gdJ_du))
    * 100
)
plt.semilogy(gdJ_du, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()
