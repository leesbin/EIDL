# %% [markdown]
# # Metalens Optimization with FourierFields
#
# This tutorial illustates the adjoint solver for DFT fields. Specifically, we use the `FourierFields` adjoint solver to design a metalens that maximizes the average intensity over three frequencies at a spot near the metalens. In a similar [example](https://github.com/NanoComp/meep/blob/master/python/examples/adjoint_optimization/05-Near2Far.ipynb) based on the `Near2FarFields` adjoint solver, the focal spot is far from the metalens. Compared with `Near2FarFields`, the `FourierFields` adjoint solver has some advantages, including higher efficiency for fields at nearby points and greater flexibility for surrounding media (not limited to homogeneous media surrounding far-field regions when `Near2FarFields` is applied). On the other hand, the disadvantage is that `FourierFields` is less efficient for faraway points, which require a large computational cell.
#
# At first, let us import `meep`, its adjoint module `meep.adjoint`, and other packages for automatic differentiation, nonlinear optimization, and making figures.

# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle

mp.verbosity(1)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1.0)

# %% [markdown]
# Basic setup

# %%
resolution = 25

design_region_width = 3.0
design_region_height = 1.0
pml_size = 1.0

Sx = design_region_width
Sy = 2 * pml_size + design_region_height + 5
cell_size = mp.Vector3(Sx, Sy)

wavelength = 1.55
fcen = 1/wavelength
# nf = len(frequencies) # number of frequencies

minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

pml_layers = [mp.PML(thickness = pml_size, direction = mp.Y)]

fcen = 1 / 1.55
width = 0.2
fwidth = width * fcen
source_center = [0, -(Sy / 2) + pml_size + 2/resolution, 0]
source_size = mp.Vector3(Sx, 0, 0)
src = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ez, size=source_size, center=source_center)]

Nx = int(round(design_region_resolution * design_region_width)) + 1
Ny = int(round(design_region_resolution * design_region_height)) + 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, 1), Air, Si, grid_type="U_MEAN")
design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0,-Sy/2 + pml_size + 1.5),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


def mapping(x, eta, beta):

    # # filter
    # filtered_field = mpa.conic_filter(
    #     x,
    #     filter_radius,
    #     design_region_width,
    #     design_region_height,
    #     design_region_resolution,
    # )

    # projection
    # projected_field = mpa.tanh_projection(x, beta, eta)

    # interpolate to actual materials
    return x


geometry = [
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %% [markdown]
# To use the `mpa.FourierFields` adjoint solver, we need to specify the monitor where DFT fields are evaluated. In this example, we try to focus the light at three different frequencies. The objective function is simply the intensity at the focal spot averaged over those frequencies.

# %%
monitor_position, monitor_size = mp.Vector3(0,-Sy/2 + pml_size + 1.5 + design_region_height/2 + 3), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    fcen=fcen,
    df=0,
    nf=1,
    maximum_run_time=161.36,
    decay_by=1e-7,
    finite_difference_step=0.001 
)
opt.plot2D(True)
# Out:
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %% [markdown]
# To apply `nlopt` for nonlinear optimization, the following function is defined. This function also illustrates the structure in the design region during optimization and records the evaluation history of the objective function.

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, dJ_du
        )  # backprop

    evaluation_history.append(np.real(f0))

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %% [markdown]
# The optimizer runs in multiple loops with increasing beta, which gradually turns on the thresholding. When beta changes, the cost function also changes, which requires the optimizer to be reset.

# %%
f0, dJ_du = opt()
# Out:
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.1008e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.019974 s
# -----------
# run 0 finished at t = 81.14 (4057 timesteps)
# Starting adjoint run...
# run 1 finished at t = 161.36 (8068 timesteps)
# Calculating gradient...

# %%
print(dJ_du)
print(f0)
# Out:
# [-14.73452903  -7.31912293  -7.17465381  -7.03320689  -6.8460458
#   -6.61410842  -6.33857277  -6.02085734  -5.66262472  -5.26578595
#   -4.832499    -4.36517116  -3.86645804  -3.33925805  -2.78670782
#   -2.21217329  -1.61923649  -1.01168223  -0.39347837   0.2312473
#    0.85823056   1.48310173   2.10141756   2.70869569   3.30045335
#    3.87224759   4.4197154    4.93861685   5.4248774    5.87463038
#    6.28425858   6.65043347   6.97015232   7.24077312   7.46004472
#    7.62613275   7.73764208   7.79363323   7.79363323   7.73764208
#    7.62613275   7.46004472   7.24077312   6.97015232   6.65043347
#    6.28425858   5.87463038   5.4248774    4.93861685   4.4197154
#    3.87224759   3.30045335   2.70869569   2.10141756   1.48310173
#    0.85823056   0.2312473   -0.39347837  -1.01168223  -1.61923649
#   -2.21217329  -2.78670782  -3.33925805  -3.86645804  -4.36517116
#   -4.832499    -5.26578595  -5.66262472  -6.02085734  -6.33857277
#   -6.61410842  -6.8460458   -7.03320689  -7.17465381  -7.31912293
#  -14.73452903]
# 3.776703955295858

# %%
print(dJ_du.size)
# Out:
# 76

# %%
# #x = np.loadtxt('/root/design_result/gd/lastdesign.txt')

# n = Nx * 1  # number of parameters
# x = np.ones((n,)) * 0.5
# opt.update_design([x])

# fdg_list=[]
# eps_diff=0.001

# f0, dJ_du = opt([x])
# for i in range(x.size):
#     print(i)
#     copy_x=x.copy()
#     copy_x[i] = copy_x[i]+eps_diff
#     #print(copy_x)
#     f0_new, dJ_du_new = opt([copy_x])
#     f0_diff = f0_new - f0
#     fdg = f0_diff / eps_diff
#     #fdg_list.append(np.real(fdg))
#     fdg_list.append(fdg)

# # np.savetxt("/root/design_result/gd/fdg_list.txt", fdg_list)

# %%
# print(fdg_list)

# %%
# fd_gradient=np.array(fdg_list)
# #print(x)
# opt.update_design([x])
# #(f, dJ_du)=opt.get_fdf_funcs()
# #adjoint_gradient=dJ_du(x)
# adjoint_gradient=dJ_du

# (m, b) = np.polyfit(fd_gradient, adjoint_gradient, 1)
# min_g = np.min(fd_gradient)
# max_g = np.max(fd_gradient)

# fig = plt.figure(figsize=(12, 6))

# plt.subplot(1, 2, 1)
# plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
# plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Linear Regression")
# plt.plot(fd_gradient, adjoint_gradient, "o", label="Adjoint comparison")
# plt.xlabel("Finite Difference Gradient")
# plt.ylabel("Adjoint Gradient")
# plt.legend()
# plt.grid(True)
# plt.axis("square")

# plt.subplot(1, 2, 2)
# rel_err = (
#     np.abs(np.squeeze(fd_gradient) - np.squeeze(adjoint_gradient))
#     / np.abs(np.squeeze(fd_gradient))
#     * 100
# )
# plt.semilogy(fd_gradient, rel_err, "o")
# plt.grid(True)
# plt.xlabel("Finite Difference Gradient")
# plt.ylabel("Relative Error (%)")

# fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# fig.suptitle("Resolution: {} Nx: {}, Ny:{}".format(resolution, Nx, Ny))
# plt.show()

# %% [markdown]
# We can plot the optimized geometry.

# %%
db = 1e-5
choose = 76
g_discrete, idx = opt.calculate_fd_gradient(num_gradients=choose, db=db)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.12328e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0158122 s
# -----------
# run 2 finished at t = 86.36 (4318 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0180268 s
# -----------
# run 3 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0181849 s
# -----------
# run 4 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168259 s
# -----------
# run 5 finished at t = 139.4 (6970 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017432 s
# -----------
# run 6 finished at t = 139.4 (6970 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173399 s
# -----------
# run 7 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.71933e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0178499 s
# -----------
# run 8 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0188501 s
# -----------
# run 9 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0179541 s
# -----------
# run 10 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0192389 s
# -----------
# run 11 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168371 s
# -----------
# run 12 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017225 s
# -----------
# run 13 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176721 s
# -----------
# run 14 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0177031 s
# -----------
# run 15 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016901 s
# -----------
# run 16 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169051 s
# -----------
# run 17 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016983 s
# -----------
# run 18 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169241 s
# -----------
# run 19 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173681 s
# -----------
# run 20 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01683 s
# -----------
# run 21 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0225551 s
# -----------
# run 22 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016849 s
# -----------
# run 23 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016974 s
# -----------
# run 24 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0177379 s
# -----------
# run 25 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016737 s
# -----------
# run 26 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01688 s
# -----------
# run 27 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167849 s
# -----------
# run 28 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167339 s
# -----------
# run 29 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0175121 s
# -----------
# run 30 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016814 s
# -----------
# run 31 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172992 s
# -----------
# run 32 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171051 s
# -----------
# run 33 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018563 s
# -----------
# run 34 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169809 s
# -----------
# run 35 finished at t = 139.4 (6970 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.020591 s
# -----------
# run 36 finished at t = 139.4 (6970 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.48091e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174689 s
# -----------
# run 37 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018436 s
# -----------
# run 38 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.020663 s
# -----------
# run 39 finished at t = 86.36 (4318 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0210791 s
# -----------
# run 40 finished at t = 86.36 (4318 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017977 s
# -----------
# run 41 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0177569 s
# -----------
# run 42 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.19481e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017302 s
# -----------
# run 43 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.019469 s
# -----------
# run 44 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170531 s
# -----------
# run 45 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.1008e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0219278 s
# -----------
# run 46 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0197659 s
# -----------
# run 47 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169468 s
# -----------
# run 48 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018127 s
# -----------
# run 49 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167441 s
# -----------
# run 50 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0187359 s
# -----------
# run 51 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017112 s
# -----------
# run 52 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172629 s
# -----------
# run 53 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 6.81877e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170681 s
# -----------
# run 54 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016818 s
# -----------
# run 55 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016999 s
# -----------
# run 56 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172968 s
# -----------
# run 57 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174382 s
# -----------
# run 58 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 7.39098e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173011 s
# -----------
# run 59 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174479 s
# -----------
# run 60 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0179141 s
# -----------
# run 61 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0177062 s
# -----------
# run 62 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016839 s
# -----------
# run 63 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172641 s
# -----------
# run 64 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017391 s
# -----------
# run 65 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168149 s
# -----------
# run 66 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.12328e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017283 s
# -----------
# run 67 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172899 s
# -----------
# run 68 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016834 s
# -----------
# run 69 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170689 s
# -----------
# run 70 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016953 s
# -----------
# run 71 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016788 s
# -----------
# run 72 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170441 s
# -----------
# run 73 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170822 s
# -----------
# run 74 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173841 s
# -----------
# run 75 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01736 s
# -----------
# run 76 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01736 s
# -----------
# run 77 finished at t = 86.36 (4318 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016923 s
# -----------
# run 78 finished at t = 86.36 (4318 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172298 s
# -----------
# run 79 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017417 s
# -----------
# run 80 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018301 s
# -----------
# run 81 finished at t = 139.4 (6970 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174129 s
# -----------
# run 82 finished at t = 139.4 (6970 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174539 s
# -----------
# run 83 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174551 s
# -----------
# run 84 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173271 s
# -----------
# run 85 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174501 s
# -----------
# run 86 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173481 s
# -----------
# run 87 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174148 s
# -----------
# run 88 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0175829 s
# -----------
# run 89 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174131 s
# -----------
# run 90 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017241 s
# -----------
# run 91 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0180511 s
# -----------
# run 92 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0180631 s
# -----------
# run 93 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169241 s
# -----------
# run 94 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173211 s
# -----------
# run 95 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172 s
# -----------
# run 96 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170989 s
# -----------
# run 97 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017158 s
# -----------
# run 98 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0209479 s
# -----------
# run 99 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0178211 s
# -----------
# run 100 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169542 s
# -----------
# run 101 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016923 s
# -----------
# run 102 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166659 s
# -----------
# run 103 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168831 s
# -----------
# run 104 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171161 s
# -----------
# run 105 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0182531 s
# -----------
# run 106 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.019033 s
# -----------
# run 107 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018595 s
# -----------
# run 108 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168672 s
# -----------
# run 109 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016937 s
# -----------
# run 110 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166509 s
# -----------
# run 111 finished at t = 139.4 (6970 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016813 s
# -----------
# run 112 finished at t = 139.4 (6970 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169261 s
# -----------
# run 113 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016679 s
# -----------
# run 114 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016911 s
# -----------
# run 115 finished at t = 86.36 (4318 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170832 s
# -----------
# run 116 finished at t = 86.36 (4318 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170701 s
# -----------
# run 117 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0194709 s
# -----------
# run 118 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0186112 s
# -----------
# run 119 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016582 s
# -----------
# run 120 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165689 s
# -----------
# run 121 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0178161 s
# -----------
# run 122 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167851 s
# -----------
# run 123 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176849 s
# -----------
# run 124 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0179451 s
# -----------
# run 125 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017411 s
# -----------
# run 126 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016655 s
# -----------
# run 127 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166552 s
# -----------
# run 128 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167542 s
# -----------
# run 129 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01683 s
# -----------
# run 130 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.40939e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165679 s
# -----------
# run 131 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01651 s
# -----------
# run 132 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01771 s
# -----------
# run 133 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016818 s
# -----------
# run 134 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166788 s
# -----------
# run 135 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166671 s
# -----------
# run 136 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166531 s
# -----------
# run 137 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168488 s
# -----------
# run 138 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0193889 s
# -----------
# run 139 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0178831 s
# -----------
# run 140 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0262189 s
# -----------
# run 141 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165849 s
# -----------
# run 142 finished at t = 161.36 (8068 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166051 s
# -----------
# run 143 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0188112 s
# -----------
# run 144 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016814 s
# -----------
# run 145 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168312 s
# -----------
# run 146 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017694 s
# -----------
# run 147 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0185061 s
# -----------
# run 148 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016566 s
# -----------
# run 149 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166719 s
# -----------
# run 150 finished at t = 100.4 (5020 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017684 s
# -----------
# run 151 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.00543e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.019135 s
# -----------
# run 152 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.015934 s
# -----------
# run 153 finished at t = 86.36 (4318 timesteps)

# %%
print(g_discrete)
# Out:
# [[-4.034932560736948], [-3.0667291863295527], [-7.5624511558736165], [-4.6915835092864455], [-4.5270833435751], [-4.325496402701745], [-4.089236891946513], [-3.8210934508509093], [-3.5241854728251805], [-3.2018898567187644], [-2.8578036811666148], [-2.495668768087711], [-2.119299722602719], [-1.732549517008408], [-1.339221178975336], [-0.9430194307213923], [2.176121307639889], [-1.982431230995729], [-0.7073478320407388], [-0.3365865689275438], [-0.6863949797430989], [0.08871470469351549], [0.5241925437271533], [0.9718008788350828], [1.4265760621690047], [9.28605788610426], [2.7681689060088384], [2.997176647889787], [3.204350351415641], [3.3896725131654644], [3.5532759558254408], [3.695397608893813], [-2.1255491108540525], [4.8989405557531285], [5.113863696859511], [5.278148108356362], [5.744069519808547], [5.052388224635607], [5.049227746622975], [5.921607003944728], [1.3277832185298877], [3.996676033102275], [3.917139240794398], [3.817059278921064], [3.696091301419457], [3.553896187247218], [3.3901721091300625], [3.2046911770056137], [2.9973319431331187], [2.7681245623245583], [2.5172885514734844], [2.245257871447137], [1.952724956888474], [1.6406639380406316], [4.04175817005914], [-0.865109083658666], [-0.3331331758449352], [-0.710538602088917], [-1.8079690693006965], [-1.7732695884564718], [-2.064028411075114], [-2.324903468764461], [4.217429230379821], [-2.1198083799411904], [-2.496044824606969], [-2.858031206498523], [-3.2019513058312294], [-3.5240622989540777], [-3.820767238815747], [-4.088691247616794], [-10.291589315425398], [-3.5427093228790336], [-3.570658133744686], [-3.590011550747007], [-3.242407375347866], [-4.029016932083351]]

# %%
(m, b) = np.polyfit(np.squeeze(g_discrete), dJ_du[idx], 1)

# %%
min_g = np.min(g_discrete)
max_g = np.max(g_discrete)

fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Best fit")
plt.plot(g_discrete, dJ_du[idx], "o", label="Adjoint comparison")
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(g_discrete) - np.squeeze(dJ_du[idx]))
    / np.abs(np.squeeze(g_discrete))
    * 100
)
plt.semilogy(g_discrete, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()

# %%
plt.figure(dpi=900)
plt.subplot(2, 2, 1)
dJ_du_0 = dJ_du.reshape(Nx, 1)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, 1)),)
plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()


plt.subplot(2, 2, 2)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, 1)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, 1)),)
plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()



plt.subplot(2, 2, 3)
err_p=rel_err.reshape(Nx, 1)
plt.imshow(np.rot90(err_p.reshape(Nx, 1)),)
plt.ylabel("Relative Error (%)")
# plt.colorbar()


plt.subplot(2, 2, 4)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, 1)),)
plt.ylabel("Error")
# plt.colorbar()
# Out:
# Text(0, 0.5, 'Error')

# %%
np.savetxt("Adjoint_gradient_grating.txt", dJ_du)

# %%
np.savetxt("FD_gradient_grating.txt", g_discrete)

# %%
plt.figure(dpi=900)
dJ_du_0 = dJ_du.reshape(Nx, 1)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, 1)),)
# plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
plt.colorbar()

# %%
plt.figure(dpi=900)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, 1)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, 1)),)
# plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))

# %%
plt.figure(dpi=900)
err_p=rel_err.reshape(Nx, 1)
plt.imshow(np.rot90(err_p.reshape(Nx, 1)),)
plt.ylabel("Relative Error (%)")
plt.colorbar()

# %%
plt.figure(dpi=900)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, 1)),)
plt.ylabel("Error")
plt.colorbar()

# %%
gdJ_du = fd_gradient

sdJ_du = g_discrete

# %%
fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(gdJ_du, sdJ_du, "o", label="Adjoint comparison")
plt.xlabel("Grating Adjoint Gradient")
plt.ylabel("Sum Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(gdJ_du) - np.squeeze(sdJ_du))
    / np.abs(np.squeeze(gdJ_du))
    * 100
)
plt.semilogy(gdJ_du, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()
