# %% [markdown]
# # Metalens Optimization with FourierFields
#
# This tutorial illustates the adjoint solver for DFT fields. Specifically, we use the `FourierFields` adjoint solver to design a metalens that maximizes the average intensity over three frequencies at a spot near the metalens. In a similar [example](https://github.com/NanoComp/meep/blob/master/python/examples/adjoint_optimization/05-Near2Far.ipynb) based on the `Near2FarFields` adjoint solver, the focal spot is far from the metalens. Compared with `Near2FarFields`, the `FourierFields` adjoint solver has some advantages, including higher efficiency for fields at nearby points and greater flexibility for surrounding media (not limited to homogeneous media surrounding far-field regions when `Near2FarFields` is applied). On the other hand, the disadvantage is that `FourierFields` is less efficient for faraway points, which require a large computational cell.
#
# At first, let us import `meep`, its adjoint module `meep.adjoint`, and other packages for automatic differentiation, nonlinear optimization, and making figures.

# %%
import meep as mp
import meep.adjoint as mpa
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle

mp.verbosity(1)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1.0)

# %% [markdown]
# Basic setup

# %%
resolution = 25

design_region_width = 3.0
design_region_height = 1.0
pml_size = 1.0

Sx = design_region_width
Sy = 2 * pml_size + design_region_height + 5
cell_size = mp.Vector3(Sx, Sy)

wavelength = 1.55
fcen = 1/wavelength
# nf = len(frequencies) # number of frequencies

minimum_length = 0.09  # minimum length scale (microns)
eta_i = 0.5  # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55  # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e  # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)
design_region_resolution = int(resolution)

pml_layers = [mp.PML(thickness = pml_size, direction = mp.Y)]

fcen = 1 / 1.55
width = 0.2
fwidth = width * fcen
source_center = [0, -(Sy / 2) + pml_size + 2/resolution, 0]
source_size = mp.Vector3(Sx, 0, 0)
src = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ez, size=source_size, center=source_center)]

Nx = int(round(design_region_resolution * design_region_width)) + 1
Ny = int(round(design_region_resolution * design_region_height)) + 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, 1), Air, Si, grid_type="U_MEAN")
design_region = mpa.DesignRegion(
    design_variables,
    volume=mp.Volume(
        center=mp.Vector3(0,-Sy/2 + pml_size + 1.5),
        size=mp.Vector3(design_region_width, design_region_height, 0),
    ),
)


def mapping(x, eta, beta):

    # # filter
    # filtered_field = mpa.conic_filter(
    #     x,
    #     filter_radius,
    #     design_region_width,
    #     design_region_height,
    #     design_region_resolution,
    # )

    # projection
    # projected_field = mpa.tanh_projection(x, beta, eta)

    # interpolate to actual materials
    return x


geometry = [
    mp.Block(
        center=design_region.center, size=design_region.size, material=design_variables
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point = mp.Vector3(0,0,0)
)

# %% [markdown]
# To use the `mpa.FourierFields` adjoint solver, we need to specify the monitor where DFT fields are evaluated. In this example, we try to focus the light at three different frequencies. The objective function is simply the intensity at the focal spot averaged over those frequencies.

# %%
monitor_position, monitor_size = mp.Vector3(0,-Sy/2 + pml_size + 1.5 + design_region_height/2 + 3), mp.Vector3(0.01,0)
FourierFields = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list = [FourierFields]

def J(fields):
    return npa.mean(npa.abs(fields[:,1]) ** 2) # The index 1 corresponds to the point at the center of our monitor.

opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    fcen=fcen,
    df=0,
    nf=1,
    maximum_run_time=161.36,
    decay_by=1e-6,
    finite_difference_step=0.001 
)
opt.plot2D(True)
# Out:
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %% [markdown]
# To apply `nlopt` for nonlinear optimization, the following function is defined. This function also illustrates the structure in the design region during optimization and records the evaluation history of the objective function.

# %%
evaluation_history = []
cur_iter = [0]

def f(v, gradient, beta):
    print("Current iteration: {}".format(cur_iter[0] + 1))

    f0, dJ_du = opt([mapping(v, eta_i, beta)])  # compute objective and gradient

    if gradient.size > 0:
        gradient[:] = tensor_jacobian_product(mapping, 0)(
            v, eta_i, beta, dJ_du
        )  # backprop

    evaluation_history.append(np.real(f0))

    cur_iter[0] = cur_iter[0] + 1

    return np.real(f0)

# %% [markdown]
# The optimizer runs in multiple loops with increasing beta, which gradually turns on the thresholding. When beta changes, the cost function also changes, which requires the optimizer to be reset.

# %%
f0, dJ_du = opt()
# Out:
# Starting forward run...
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.29153e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0242932 s
# -----------
# run 0 finished at t = 81.14 (4057 timesteps)
# Starting adjoint run...
# run 1 finished at t = 161.36 (8068 timesteps)
# Calculating gradient...

# %%
print(dJ_du)
print(f0)
# Out:
# [-14.73452903  -7.31912293  -7.17465381  -7.03320689  -6.8460458
#   -6.61410842  -6.33857277  -6.02085734  -5.66262472  -5.26578595
#   -4.832499    -4.36517116  -3.86645804  -3.33925805  -2.78670782
#   -2.21217329  -1.61923649  -1.01168223  -0.39347837   0.2312473
#    0.85823056   1.48310173   2.10141756   2.70869569   3.30045335
#    3.87224759   4.4197154    4.93861685   5.4248774    5.87463038
#    6.28425858   6.65043347   6.97015232   7.24077312   7.46004472
#    7.62613275   7.73764208   7.79363323   7.79363323   7.73764208
#    7.62613275   7.46004472   7.24077312   6.97015232   6.65043347
#    6.28425858   5.87463038   5.4248774    4.93861685   4.4197154
#    3.87224759   3.30045335   2.70869569   2.10141756   1.48310173
#    0.85823056   0.2312473   -0.39347837  -1.01168223  -1.61923649
#   -2.21217329  -2.78670782  -3.33925805  -3.86645804  -4.36517116
#   -4.832499    -5.26578595  -5.66262472  -6.02085734  -6.33857277
#   -6.61410842  -6.8460458   -7.03320689  -7.17465381  -7.31912293
#  -14.73452903]
# 3.776703955295858

# %%
print(dJ_du.size)
# Out:
# 76

# %%
# #x = np.loadtxt('/root/design_result/gd/lastdesign.txt')

# n = Nx * 1  # number of parameters
# x = np.ones((n,)) * 0.5
# opt.update_design([x])

# fdg_list=[]
# eps_diff=0.001

# f0, dJ_du = opt([x])
# for i in range(x.size):
#     print(i)
#     copy_x=x.copy()
#     copy_x[i] = copy_x[i]+eps_diff
#     #print(copy_x)
#     f0_new, dJ_du_new = opt([copy_x])
#     f0_diff = f0_new - f0
#     fdg = f0_diff / eps_diff
#     #fdg_list.append(np.real(fdg))
#     fdg_list.append(fdg)

# # np.savetxt("/root/design_result/gd/fdg_list.txt", fdg_list)

# %%
# print(fdg_list)

# %%
# fd_gradient=np.array(fdg_list)
# #print(x)
# opt.update_design([x])
# #(f, dJ_du)=opt.get_fdf_funcs()
# #adjoint_gradient=dJ_du(x)
# adjoint_gradient=dJ_du

# (m, b) = np.polyfit(fd_gradient, adjoint_gradient, 1)
# min_g = np.min(fd_gradient)
# max_g = np.max(fd_gradient)

# fig = plt.figure(figsize=(12, 6))

# plt.subplot(1, 2, 1)
# plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
# plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Linear Regression")
# plt.plot(fd_gradient, adjoint_gradient, "o", label="Adjoint comparison")
# plt.xlabel("Finite Difference Gradient")
# plt.ylabel("Adjoint Gradient")
# plt.legend()
# plt.grid(True)
# plt.axis("square")

# plt.subplot(1, 2, 2)
# rel_err = (
#     np.abs(np.squeeze(fd_gradient) - np.squeeze(adjoint_gradient))
#     / np.abs(np.squeeze(fd_gradient))
#     * 100
# )
# plt.semilogy(fd_gradient, rel_err, "o")
# plt.grid(True)
# plt.xlabel("Finite Difference Gradient")
# plt.ylabel("Relative Error (%)")

# fig.tight_layout(rect=[0, 0.03, 1, 0.95])
# fig.suptitle("Resolution: {} Nx: {}, Ny:{}".format(resolution, Nx, Ny))
# plt.show()

# %% [markdown]
# We can plot the optimized geometry.

# %%
db = 1e-5
choose = 76
g_discrete, idx = opt.calculate_fd_gradient(num_gradients=choose, db=db)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.29018e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016046 s
# -----------
# run 2 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017957 s
# -----------
# run 3 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0179431 s
# -----------
# run 4 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168309 s
# -----------
# run 5 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0187321 s
# -----------
# run 6 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167351 s
# -----------
# run 7 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168319 s
# -----------
# run 8 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0202861 s
# -----------
# run 9 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165949 s
# -----------
# run 10 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0179811 s
# -----------
# run 11 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169029 s
# -----------
# run 12 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173619 s
# -----------
# run 13 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172939 s
# -----------
# run 14 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173481 s
# -----------
# run 15 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173202 s
# -----------
# run 16 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173471 s
# -----------
# run 17 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016679 s
# -----------
# run 18 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017029 s
# -----------
# run 19 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168881 s
# -----------
# run 20 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166051 s
# -----------
# run 21 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168509 s
# -----------
# run 22 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0165181 s
# -----------
# run 23 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166869 s
# -----------
# run 24 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017195 s
# -----------
# run 25 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170708 s
# -----------
# run 26 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016839 s
# -----------
# run 27 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168731 s
# -----------
# run 28 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.50475e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017051 s
# -----------
# run 29 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01701 s
# -----------
# run 30 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172329 s
# -----------
# run 31 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016669 s
# -----------
# run 32 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016633 s
# -----------
# run 33 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167079 s
# -----------
# run 34 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173929 s
# -----------
# run 35 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017086 s
# -----------
# run 36 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166249 s
# -----------
# run 37 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0260041 s
# -----------
# run 38 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01666 s
# -----------
# run 39 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016844 s
# -----------
# run 40 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169659 s
# -----------
# run 41 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168879 s
# -----------
# run 42 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016922 s
# -----------
# run 43 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168099 s
# -----------
# run 44 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0186429 s
# -----------
# run 45 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171139 s
# -----------
# run 46 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176311 s
# -----------
# run 47 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017276 s
# -----------
# run 48 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167999 s
# -----------
# run 49 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016839 s
# -----------
# run 50 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167961 s
# -----------
# run 51 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168998 s
# -----------
# run 52 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166819 s
# -----------
# run 53 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0185781 s
# -----------
# run 54 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168011 s
# -----------
# run 55 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169351 s
# -----------
# run 56 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176461 s
# -----------
# run 57 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016891 s
# -----------
# run 58 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017072 s
# -----------
# run 59 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017108 s
# -----------
# run 60 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016907 s
# -----------
# run 61 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016752 s
# -----------
# run 62 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0185862 s
# -----------
# run 63 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017293 s
# -----------
# run 64 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017144 s
# -----------
# run 65 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017169 s
# -----------
# run 66 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016758 s
# -----------
# run 67 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169311 s
# -----------
# run 68 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166841 s
# -----------
# run 69 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.91006e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018018 s
# -----------
# run 70 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0193639 s
# -----------
# run 71 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168529 s
# -----------
# run 72 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166821 s
# -----------
# run 73 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.69549e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176191 s
# -----------
# run 74 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0186958 s
# -----------
# run 75 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171809 s
# -----------
# run 76 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168009 s
# -----------
# run 77 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171859 s
# -----------
# run 78 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0178659 s
# -----------
# run 79 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.023711 s
# -----------
# run 80 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016789 s
# -----------
# run 81 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016896 s
# -----------
# run 82 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169191 s
# -----------
# run 83 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167651 s
# -----------
# run 84 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016814 s
# -----------
# run 85 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.60012e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01915 s
# -----------
# run 86 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167661 s
# -----------
# run 87 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0210419 s
# -----------
# run 88 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172272 s
# -----------
# run 89 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170231 s
# -----------
# run 90 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.8147e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0222259 s
# -----------
# run 91 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.018398 s
# -----------
# run 92 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0266881 s
# -----------
# run 93 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017225 s
# -----------
# run 94 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016789 s
# -----------
# run 95 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168278 s
# -----------
# run 96 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.50475e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168631 s
# -----------
# run 97 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0180361 s
# -----------
# run 98 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.98023e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017683 s
# -----------
# run 99 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017781 s
# -----------
# run 100 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.8147e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176761 s
# -----------
# run 101 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168521 s
# -----------
# run 102 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0167179 s
# -----------
# run 103 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.021076 s
# -----------
# run 104 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172751 s
# -----------
# run 105 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.02493 s
# -----------
# run 106 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172219 s
# -----------
# run 107 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017509 s
# -----------
# run 108 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0173688 s
# -----------
# run 109 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017334 s
# -----------
# run 110 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0180602 s
# -----------
# run 111 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174751 s
# -----------
# run 112 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171599 s
# -----------
# run 113 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0178499 s
# -----------
# run 114 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0175729 s
# -----------
# run 115 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017441 s
# -----------
# run 116 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 4.1008e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0226729 s
# -----------
# run 117 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0176029 s
# -----------
# run 118 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016876 s
# -----------
# run 119 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.88486e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168679 s
# -----------
# run 120 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.019438 s
# -----------
# run 121 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0183721 s
# -----------
# run 122 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0170901 s
# -----------
# run 123 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0171142 s
# -----------
# run 124 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169768 s
# -----------
# run 125 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169039 s
# -----------
# run 126 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0187042 s
# -----------
# run 127 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168719 s
# -----------
# run 128 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0172088 s
# -----------
# run 129 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0190201 s
# -----------
# run 130 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0177231 s
# -----------
# run 131 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016937 s
# -----------
# run 132 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016854 s
# -----------
# run 133 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016829 s
# -----------
# run 134 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169811 s
# -----------
# run 135 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0182409 s
# -----------
# run 136 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.71797e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168409 s
# -----------
# run 137 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168059 s
# -----------
# run 138 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.5034e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0174789 s
# -----------
# run 139 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168111 s
# -----------
# run 140 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.09944e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0183549 s
# -----------
# run 141 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 3.00407e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017858 s
# -----------
# run 142 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168519 s
# -----------
# run 143 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.81334e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.01703 s
# -----------
# run 144 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016561 s
# -----------
# run 145 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.016907 s
# -----------
# run 146 finished at t = 89.48 (4474 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.90871e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0168581 s
# -----------
# run 147 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0169308 s
# -----------
# run 148 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017112 s
# -----------
# run 149 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.69413e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017158 s
# -----------
# run 150 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.59876e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.017853 s
# -----------
# run 151 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0166368 s
# -----------
# run 152 finished at t = 81.68 (4084 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 2.7895e-05 s
# Working in 2D dimensions.
# Computational cell is 3 x 8 x 0 with resolution 25
#      block, center = (0,-1.5,0)
#           size (3,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 0.0156939 s
# -----------
# run 153 finished at t = 81.68 (4084 timesteps)

# %%
print(g_discrete)
# Out:
# [[-5.187777245296843], [-5.101939064688921], [-1.7012610101563295], [-3.903311146968846], [-3.834940169422651], [-3.7482805456345853], [-3.6426095555874833], [-3.5171543686374203], [-3.371144355313049], [-3.2038501743159027], [-3.0146501742489558], [-2.8030726890726494], [-2.5688409433399784], [-2.3119405700988693], [-2.0326463703312925], [-1.7315642828918951], [-3.644629638888119], [0.04435833718119397], [0.43420273962979644], [0.8084185319390257], [1.1644653680420447], [1.50026784964119], [-2.470768071693996], [1.262330196372119], [1.6690856317058687], [2.071024591865367], [2.4639154806660457], [2.8434538205779343], [3.205327741095942], [3.5452987389827935], [3.8592805705395246], [4.143410691082039], [4.394124932227683], [4.608229485114634], [8.100767473662174], [3.8661467715694893], [3.8944120826389645], [3.9083787406912758], [3.908303600974605], [3.8941931090885613], [7.15542672007352], [4.7825417909042045], [4.607731864592068], [4.393579458339403], [4.142846448784709], [3.8587253957000907], [3.544777201014426], [3.204859612093713], [2.843053125411998], [2.4635902009517707], [2.070777069240748], [1.6689134946457072], [1.2622277578255847], [0.8548031979582759], [-1.7927824946362134], [1.1651050927596884], [0.8090553986761505], [0.4348173803681021], [0.044937715237836066], [-0.35758249907757994], [-5.052542147243599], [-2.032278376473684], [-2.31151104093108], [-2.5683532296039147], [-2.802536382962017], [-3.014082184993327], [-3.203274961682822], [-3.3705936438366275], [-3.5166657680552045], [-3.642224555644446], [-3.7480419604385413], [-3.834888988141216], [-0.5665787717656912], [-5.006863850320897], [-5.102955309910229], [-5.184381081635436]]

# %%
(m, b) = np.polyfit(np.squeeze(g_discrete), dJ_du[idx], 1)

# %%
min_g = np.min(g_discrete)
max_g = np.max(g_discrete)

fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot([min_g, max_g], [min_g, max_g], label="y=x comparison")
plt.plot([min_g, max_g], [m * min_g + b, m * max_g + b], "--", label="Best fit")
plt.plot(g_discrete, dJ_du[idx], "o", label="Adjoint comparison")
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(g_discrete) - np.squeeze(dJ_du[idx]))
    / np.abs(np.squeeze(g_discrete))
    * 100
)
plt.semilogy(g_discrete, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()

# %%
plt.figure(dpi=900)
plt.subplot(2, 2, 1)
dJ_du_0 = dJ_du.reshape(Nx, 1)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, 1)),)
plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()


plt.subplot(2, 2, 2)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, 1)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, 1)),)
plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
# plt.colorbar()



plt.subplot(2, 2, 3)
err_p=rel_err.reshape(Nx, 1)
plt.imshow(np.rot90(err_p.reshape(Nx, 1)),)
plt.ylabel("Relative Error (%)")
# plt.colorbar()


plt.subplot(2, 2, 4)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, 1)),)
plt.ylabel("Error")
# plt.colorbar()
# Out:
# Text(0, 0.5, 'Error')

# %%
np.savetxt("Adjoint_gradient_grating.txt", dJ_du)

# %%
np.savetxt("FD_gradient_grating.txt", g_discrete)

# %%
plt.figure(dpi=900)
dJ_du_0 = dJ_du.reshape(Nx, 1)
plt.imshow(np.rot90(dJ_du_0.reshape(Nx, 1)),)
# plt.ylabel("Adjoint Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))
plt.colorbar()

# %%
plt.figure(dpi=900)
g_discrete_0 = np.squeeze(g_discrete).reshape(Nx, 1)
plt.imshow(np.rot90(g_discrete_0.reshape(Nx, 1)),)
# plt.ylabel("Finite Difference Gradient")
plt.clim(np.min(dJ_du_0), np.max(dJ_du_0))

# %%
plt.figure(dpi=900)
err_p=rel_err.reshape(Nx, 1)
plt.imshow(np.rot90(err_p.reshape(Nx, 1)),)
plt.ylabel("Relative Error (%)")
plt.colorbar()

# %%
plt.figure(dpi=900)
r_err = (
    np.abs(np.squeeze(g_discrete_0) - np.squeeze(dJ_du_0)))
plt.imshow(np.rot90(r_err.reshape(Nx, 1)),)
plt.ylabel("Error")
plt.colorbar()

# %%
gdJ_du = fd_gradient

sdJ_du = g_discrete

# %%
fig = plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(gdJ_du, sdJ_du, "o", label="Adjoint comparison")
plt.xlabel("Grating Adjoint Gradient")
plt.ylabel("Sum Adjoint Gradient")
plt.legend()
plt.grid(True)
plt.axis("square")

plt.subplot(1, 2, 2)
rel_err = (
    np.abs(np.squeeze(gdJ_du) - np.squeeze(sdJ_du))
    / np.abs(np.squeeze(gdJ_du))
    * 100
)
plt.semilogy(gdJ_du, rel_err, "o")
plt.grid(True)
plt.xlabel("Finite Difference Gradient")
plt.ylabel("Relative Error (%)")
plt.show()

plt.savefig("graph.png")
plt.cla()   # clear the current axes
plt.clf()   # clear the current figure
plt.close() # closes the current figure
plt.show()
