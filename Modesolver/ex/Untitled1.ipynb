# %%
import matplotlib.pyplot as plt
import numpy as np

import meep as mp

resolution = 40  # pixels/μm

Si = mp.Medium(index=3.45)

dpml = 1.0
pml_layers = [mp.PML(dpml)]

sx = 5
sy = 3
cell = mp.Vector3(sx + 2 * dpml, sy + 2 * dpml, 0)

a = 1.0  # waveguide width/height

k_point = mp.Vector3(z=0.5)


def parallel_waveguide(s, xodd):
    geometry = [
        mp.Block(
            center=mp.Vector3(-0.5 * (s + a)),
            size=mp.Vector3(a, a, mp.inf),
            material=Si,
        ),
        mp.Block(
            center=mp.Vector3(0.5 * (s + a)), size=mp.Vector3(a, a, mp.inf), material=Si
        ),
    ]

    symmetries = [mp.Mirror(mp.X, phase=-1 if xodd else 1), mp.Mirror(mp.Y, phase=-1)]

    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell,
        geometry=geometry,
        boundary_layers=pml_layers,
        symmetries=symmetries,
        k_point=k_point,
    )

    sim.init_sim()
    EigenmodeData = sim.get_eigenmode(
        0.22,
        mp.Z,
        mp.Volume(center=mp.Vector3(), size=mp.Vector3(sx, sy)),
        2 if xodd else 1,
        k_point,
        match_frequency=False,
        parity=mp.ODD_Y,
    )

    fcen = EigenmodeData.freq
    print(f'freq:, {"xodd" if xodd else "xeven"}, {s}, {fcen}')

    sim.reset_meep()

    eig_sources = [
        mp.EigenModeSource(
            src=mp.GaussianSource(fcen, fwidth=0.1 * fcen),
            size=mp.Vector3(sx, sy),
            center=mp.Vector3(),
            eig_band=2 if xodd else 1,
            eig_kpoint=k_point,
            eig_match_freq=False,
            eig_parity=mp.ODD_Y,
        )
    ]

    sim.change_sources(eig_sources)

    flux_reg = mp.FluxRegion(
        direction=mp.Z, center=mp.Vector3(), size=mp.Vector3(sx, sy)
    )
    wvg_flux = sim.add_flux(fcen, 0, 1, flux_reg)

    force_reg1 = mp.ForceRegion(
        mp.Vector3(0.49 * s), direction=mp.X, weight=1, size=mp.Vector3(y=sy)
    )
    force_reg2 = mp.ForceRegion(
        mp.Vector3(0.5 * s + 1.01 * a), direction=mp.X, weight=-1, size=mp.Vector3(y=sy)
    )
    wvg_force = sim.add_force(fcen, 0, 1, force_reg1, force_reg2)

    sim.run(until_after_sources=1500)

    flux = mp.get_fluxes(wvg_flux)[0]
    force = mp.get_forces(wvg_force)[0]
    print(
        f'data:, {"xodd" if xodd else "xeven"}, {s}, {flux}, {force}, {-force / flux}'
    )

    sim.reset_meep()
    return flux, force


s = np.arange(0.05, 1.05, 0.05)
fluxes_odd = np.zeros(s.size)
forces_odd = np.zeros(s.size)
fluxes_even = np.zeros(s.size)
forces_even = np.zeros(s.size)

for k in range(len(s)):
    fluxes_odd[k], forces_odd[k] = parallel_waveguide(s[k], True)
    fluxes_even[k], forces_even[k] = parallel_waveguide(s[k], False)

plt.figure(dpi=150)
plt.plot(s, -forces_odd / fluxes_odd, "rs", label="anti-symmetric")
plt.plot(s, -forces_even / fluxes_even, "bo", label="symmetric")
plt.grid(True)
plt.xlabel("waveguide separation s/a")
plt.ylabel("optical force (F/L)(ac/P)")
plt.legend(loc="upper right")
plt.show()
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000707865 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00893593 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.235389 after 27 iters
# Dominant planewave for band 2: (-0.400000,0.000000,0.500000)
# freq:, xodd, 0.05, 0.23538931364680254
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00194907 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.013716 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.235389 after 27 iters
# FloatProgress(value=0.0, description='0% done ', max=1924.828125)
# Meep progress: 189.9625/1924.828125 = 9.9% done in 4.0s, 36.5s to go
# on time step 15208 (time=190.1), 0.000263022 s/step
# Meep progress: 370.5/1924.828125 = 19.2% done in 8.0s, 33.6s to go
# on time step 29651 (time=370.638), 0.000276961 s/step
# Meep progress: 556.9125/1924.828125 = 28.9% done in 12.0s, 29.5s to go
# on time step 44566 (time=557.075), 0.000268196 s/step
# Meep progress: 750.8125/1924.828125 = 39.0% done in 16.0s, 25.0s to go
# on time step 60080 (time=751), 0.000257836 s/step
# Meep progress: 944.2625/1924.828125 = 49.1% done in 20.0s, 20.8s to go
# on time step 75558 (time=944.475), 0.000258444 s/step
# Meep progress: 1136.8625/1924.828125 = 59.1% done in 24.0s, 16.6s to go
# on time step 90968 (time=1137.1), 0.000259587 s/step
# Meep progress: 1328.5375000000001/1924.828125 = 69.0% done in 28.0s, 12.6s to go
# on time step 106303 (time=1328.79), 0.000260845 s/step
# Meep progress: 1521.0/1924.828125 = 79.0% done in 32.0s, 8.5s to go
# on time step 121700 (time=1521.25), 0.000259796 s/step
# Meep progress: 1712.325/1924.828125 = 89.0% done in 36.0s, 4.5s to go
# on time step 137007 (time=1712.59), 0.000261323 s/step
# Meep progress: 1904.6625000000001/1924.828125 = 99.0% done in 40.0s, 0.4s to go
# on time step 152394 (time=1904.93), 0.000259965 s/step
# run 0 finished at t = 1924.8375 (153987 timesteps)
# data:, xodd, 0.05, 29272306.540884376, -11802681.98065391, 0.40320300568625184
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000669003 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00886202 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.213015 after 30 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.05, 0.21301453307406007
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000503063 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.525,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0136392 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.213015 after 30 iters
# FloatProgress(value=0.0, description='0% done ', max=1969.4515380859375)
# Meep progress: 189.32500000000002/1969.4515380859375 = 9.6% done in 4.0s, 37.6s to go
# on time step 15152 (time=189.4), 0.000264004 s/step
# Meep progress: 368.82500000000005/1969.4515380859375 = 18.7% done in 8.0s, 34.7s to go
# on time step 29512 (time=368.9), 0.000278553 s/step
# Meep progress: 561.025/1969.4515380859375 = 28.5% done in 12.0s, 30.1s to go
# on time step 44890 (time=561.125), 0.000260115 s/step
# Meep progress: 754.825/1969.4515380859375 = 38.3% done in 16.0s, 25.7s to go
# on time step 60395 (time=754.938), 0.00025799 s/step
# Meep progress: 948.2750000000001/1969.4515380859375 = 48.1% done in 20.0s, 21.5s to go
# on time step 75872 (time=948.4), 0.000258449 s/step
# Meep progress: 1140.5/1969.4515380859375 = 57.9% done in 24.0s, 17.4s to go
# on time step 91251 (time=1140.64), 0.000260104 s/step
# Meep progress: 1334.4250000000002/1969.4515380859375 = 67.8% done in 28.0s, 13.3s to go
# on time step 106767 (time=1334.59), 0.000257809 s/step
# Meep progress: 1527.95/1969.4515380859375 = 77.6% done in 32.0s, 9.2s to go
# on time step 122251 (time=1528.14), 0.000258341 s/step
# Meep progress: 1721.3625000000002/1969.4515380859375 = 87.4% done in 36.0s, 5.2s to go
# on time step 137726 (time=1721.58), 0.000258493 s/step
# Meep progress: 1915.3500000000001/1969.4515380859375 = 97.3% done in 40.0s, 1.1s to go
# on time step 153246 (time=1915.58), 0.000257733 s/step
# run 0 finished at t = 1969.4625 (157557 timesteps)
# data:, xeven, 0.05, 21260688.895833977, 24855685.39724775, -1.1690912518887482
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000835896 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00877714 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.234644 after 27 iters
# Dominant planewave for band 2: (0.200000,-0.000000,0.500000)
# freq:, xodd, 0.1, 0.23464402794275566
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000503778 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132401 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.234644 after 27 iters
# FloatProgress(value=0.0, description='0% done ', max=1926.177490234375)
# Meep progress: 190.3375/1926.177490234375 = 9.9% done in 4.0s, 36.5s to go
# on time step 15233 (time=190.413), 0.000262596 s/step
# Meep progress: 381.975/1926.177490234375 = 19.8% done in 8.0s, 32.3s to go
# on time step 30565 (time=382.062), 0.0002609 s/step
# Meep progress: 574.45/1926.177490234375 = 29.8% done in 12.0s, 28.2s to go
# on time step 45964 (time=574.55), 0.000259762 s/step
# Meep progress: 766.5250000000001/1926.177490234375 = 39.8% done in 16.0s, 24.2s to go
# on time step 61331 (time=766.638), 0.000260301 s/step
# Meep progress: 958.3375000000001/1926.177490234375 = 49.8% done in 20.0s, 20.2s to go
# on time step 76678 (time=958.475), 0.000260645 s/step
# Meep progress: 1149.4125000000001/1926.177490234375 = 59.7% done in 24.0s, 16.2s to go
# on time step 91965 (time=1149.56), 0.00026167 s/step
# Meep progress: 1341.0875/1926.177490234375 = 69.6% done in 28.0s, 12.2s to go
# on time step 107301 (time=1341.26), 0.000260834 s/step
# Meep progress: 1532.5625/1926.177490234375 = 79.6% done in 32.0s, 8.2s to go
# on time step 122620 (time=1532.75), 0.000261115 s/step
# Meep progress: 1724.9/1926.177490234375 = 89.6% done in 36.0s, 4.2s to go
# on time step 138009 (time=1725.11), 0.000259938 s/step
# Meep progress: 1917.3000000000002/1926.177490234375 = 99.5% done in 40.0s, 0.2s to go
# on time step 153403 (time=1917.54), 0.000259856 s/step
# run 0 finished at t = 1926.1875 (154095 timesteps)
# data:, xodd, 0.1, 28900852.637445264, -13463027.453162791, 0.4658349572607238
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000498056 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00868607 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.215375 after 31 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.1, 0.21537502196837244
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00050807 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.55,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132031 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.215375 after 31 iters
# FloatProgress(value=0.0, description='0% done ', max=1964.306396484375)
# Meep progress: 190.4/1964.306396484375 = 9.7% done in 4.0s, 37.3s to go
# on time step 15237 (time=190.463), 0.000262525 s/step
# Meep progress: 371.33750000000003/1964.306396484375 = 18.9% done in 8.0s, 34.3s to go
# on time step 29714 (time=371.425), 0.000276319 s/step
# Meep progress: 551.6125000000001/1964.306396484375 = 28.1% done in 12.0s, 30.7s to go
# on time step 44137 (time=551.712), 0.000277338 s/step
# Meep progress: 730.8875/1964.306396484375 = 37.2% done in 16.0s, 27.0s to go
# on time step 58480 (time=731), 0.000278883 s/step
# Meep progress: 910.4875000000001/1964.306396484375 = 46.4% done in 20.0s, 23.1s to go
# on time step 72850 (time=910.625), 0.000278376 s/step
# Meep progress: 1089.7875000000001/1964.306396484375 = 55.5% done in 24.0s, 19.3s to go
# on time step 87196 (time=1089.95), 0.000278837 s/step
# Meep progress: 1271.9125000000001/1964.306396484375 = 64.8% done in 28.0s, 15.2s to go
# on time step 101767 (time=1272.09), 0.00027452 s/step
# Meep progress: 1455.1625000000001/1964.306396484375 = 74.1% done in 32.0s, 11.2s to go
# on time step 116428 (time=1455.35), 0.000272847 s/step
# Meep progress: 1635.4750000000001/1964.306396484375 = 83.3% done in 36.0s, 7.2s to go
# on time step 130855 (time=1635.69), 0.000277258 s/step
# Meep progress: 1831.1125000000002/1964.306396484375 = 93.2% done in 40.0s, 2.9s to go
# on time step 146509 (time=1831.36), 0.000255541 s/step
# run 0 finished at t = 1964.3125 (157145 timesteps)
# data:, xeven, 0.1, 33902733.47912677, 31561930.745482188, -0.9309553391886302
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000480175 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.008744 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.233747 after 27 iters
# Dominant planewave for band 2: (-0.200000,0.000000,0.500000)
# freq:, xodd, 0.15000000000000002, 0.23374670103964185
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000498056 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132639 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.233747 after 27 iters
# FloatProgress(value=0.0, description='0% done ', max=1927.8135375976562)
# Meep progress: 193.925/1927.8135375976562 = 10.1% done in 4.0s, 35.8s to go
# on time step 15528 (time=194.1), 0.00025761 s/step
# Meep progress: 389.5/1927.8135375976562 = 20.2% done in 8.0s, 31.6s to go
# on time step 31176 (time=389.7), 0.000255626 s/step
# Meep progress: 582.8875/1927.8135375976562 = 30.2% done in 12.0s, 27.7s to go
# on time step 46649 (time=583.113), 0.000258521 s/step
# Meep progress: 778.85/1927.8135375976562 = 40.4% done in 16.0s, 23.6s to go
# on time step 62328 (time=779.1), 0.00025512 s/step
# Meep progress: 974.5625/1927.8135375976562 = 50.6% done in 20.0s, 19.6s to go
# on time step 77986 (time=974.825), 0.000255467 s/step
# Meep progress: 1168.1875/1927.8135375976562 = 60.6% done in 24.0s, 15.6s to go
# on time step 93478 (time=1168.48), 0.000258205 s/step
# Meep progress: 1362.0/1927.8135375976562 = 70.6% done in 28.0s, 11.6s to go
# on time step 108984 (time=1362.3), 0.000257975 s/step
# Meep progress: 1546.1750000000002/1927.8135375976562 = 80.2% done in 32.0s, 7.9s to go
# on time step 123718 (time=1546.48), 0.000271497 s/step
# Meep progress: 1741.6125000000002/1927.8135375976562 = 90.3% done in 36.0s, 3.8s to go
# on time step 139358 (time=1741.98), 0.000255768 s/step
# run 0 finished at t = 1927.825 (154226 timesteps)
# data:, xodd, 0.15000000000000002, 29184468.077013, -12991876.139498433, 0.4451640545654289
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000505924 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00844812 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.217298 after 32 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.15000000000000002, 0.21729769552095707
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000468016 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.575,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132389 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.217298 after 32 iters
# FloatProgress(value=0.0, description='0% done ', max=1960.1981506347656)
# Meep progress: 197.82500000000002/1960.1981506347656 = 10.1% done in 4.0s, 35.6s to go
# on time step 15832 (time=197.9), 0.000252667 s/step
# Meep progress: 396.0625/1960.1981506347656 = 20.2% done in 8.0s, 31.6s to go
# on time step 31692 (time=396.15), 0.000252209 s/step
# Meep progress: 595.4875000000001/1960.1981506347656 = 30.4% done in 12.0s, 27.5s to go
# on time step 47648 (time=595.6), 0.000250701 s/step
# Meep progress: 794.875/1960.1981506347656 = 40.6% done in 16.0s, 23.5s to go
# on time step 63601 (time=795.013), 0.000250752 s/step
# Meep progress: 993.9625000000001/1960.1981506347656 = 50.7% done in 20.0s, 19.4s to go
# on time step 79530 (time=994.125), 0.000251124 s/step
# Meep progress: 1190.4125000000001/1960.1981506347656 = 60.7% done in 24.0s, 15.5s to go
# on time step 95246 (time=1190.58), 0.000254528 s/step
# Meep progress: 1385.5625/1960.1981506347656 = 70.7% done in 28.0s, 11.6s to go
# on time step 110860 (time=1385.75), 0.000256182 s/step
# Meep progress: 1581.3875/1960.1981506347656 = 80.7% done in 32.0s, 7.7s to go
# on time step 126528 (time=1581.6), 0.000255308 s/step
# Meep progress: 1779.8875/1960.1981506347656 = 90.8% done in 36.0s, 3.6s to go
# on time step 142409 (time=1780.11), 0.000251882 s/step
# run 0 finished at t = 1960.2 (156816 timesteps)
# data:, xeven, 0.15000000000000002, 42909885.4853781, 32152816.858759794, -0.7493102462302337
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000575066 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00865006 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.232876 after 26 iters
# Dominant planewave for band 2: (-0.200000,0.000000,0.500000)
# freq:, xodd, 0.2, 0.23287607652672557
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000513077 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0133431 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.232876 after 26 iters
# FloatProgress(value=0.0, description='0% done ', max=1929.4129333496094)
# Meep progress: 192.01250000000002/1929.4129333496094 = 10.0% done in 4.0s, 36.2s to go
# on time step 15366 (time=192.075), 0.000260316 s/step
# Meep progress: 385.725/1929.4129333496094 = 20.0% done in 8.0s, 32.0s to go
# on time step 30865 (time=385.812), 0.000258096 s/step
# Meep progress: 579.4625/1929.4129333496094 = 30.0% done in 12.0s, 28.0s to go
# on time step 46366 (time=579.575), 0.000258058 s/step
# Meep progress: 775.8625000000001/1929.4129333496094 = 40.2% done in 16.0s, 23.8s to go
# on time step 62080 (time=776), 0.000254565 s/step
# Meep progress: 969.1500000000001/1929.4129333496094 = 50.2% done in 20.0s, 19.8s to go
# on time step 77544 (time=969.3), 0.000258666 s/step
# Meep progress: 1161.3125/1929.4129333496094 = 60.2% done in 24.0s, 15.9s to go
# on time step 92919 (time=1161.49), 0.000260175 s/step
# Meep progress: 1353.775/1929.4129333496094 = 70.2% done in 28.0s, 11.9s to go
# on time step 108317 (time=1353.96), 0.000259786 s/step
# Meep progress: 1545.0625/1929.4129333496094 = 80.1% done in 32.0s, 8.0s to go
# on time step 123620 (time=1545.25), 0.000261393 s/step
# Meep progress: 1739.2375000000002/1929.4129333496094 = 90.1% done in 36.0s, 3.9s to go
# on time step 139156 (time=1739.45), 0.000257468 s/step
# run 0 finished at t = 1929.4250000000002 (154354 timesteps)
# data:, xodd, 0.2, 29792734.372541122, -12111487.73682229, 0.40652487903174833
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000482082 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00868201 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.218868 after 33 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.2, 0.21886831081470112
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000499964 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.6,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.013283 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.218868 after 33 iters
# FloatProgress(value=0.0, description='0% done ', max=1956.895751953125)
# Meep progress: 190.7125/1956.895751953125 = 9.7% done in 4.0s, 37.0s to go
# on time step 15296 (time=191.2), 0.000261525 s/step
# Meep progress: 379.5375/1956.895751953125 = 19.4% done in 8.0s, 33.2s to go
# on time step 30404 (time=380.05), 0.000264768 s/step
# Meep progress: 565.95/1956.895751953125 = 28.9% done in 12.0s, 29.5s to go
# on time step 45321 (time=566.513), 0.000268166 s/step
# Meep progress: 757.9375/1956.895751953125 = 38.7% done in 16.0s, 25.3s to go
# on time step 60681 (time=758.513), 0.000260423 s/step
# Meep progress: 950.3625000000001/1956.895751953125 = 48.6% done in 20.0s, 21.2s to go
# on time step 76074 (time=950.925), 0.000259862 s/step
# Meep progress: 1143.275/1956.895751953125 = 58.4% done in 24.0s, 17.1s to go
# on time step 91510 (time=1143.88), 0.000259136 s/step
# Meep progress: 1335.4625/1956.895751953125 = 68.2% done in 28.0s, 13.0s to go
# on time step 106886 (time=1336.08), 0.000260148 s/step
# Meep progress: 1527.7250000000001/1956.895751953125 = 78.1% done in 32.0s, 9.0s to go
# on time step 122269 (time=1528.36), 0.00026004 s/step
# Meep progress: 1719.625/1956.895751953125 = 87.9% done in 36.0s, 5.0s to go
# on time step 137622 (time=1720.28), 0.000260546 s/step
# Meep progress: 1912.775/1956.895751953125 = 97.7% done in 40.0s, 0.9s to go
# on time step 153077 (time=1913.46), 0.000258829 s/step
# run 0 finished at t = 1956.9 (156552 timesteps)
# data:, xeven, 0.2, 48569242.52661833, 29555345.172270015, -0.6085197881369517
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000633001 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00873303 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.232076 after 26 iters
# Dominant planewave for band 2: (-0.200000,0.000000,0.500000)
# freq:, xodd, 0.25, 0.2320757595677261
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000504971 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0134912 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.232076 after 26 iters
# FloatProgress(value=0.0, description='0% done ', max=1930.8937683105469)
# Meep progress: 191.275/1930.8937683105469 = 9.9% done in 4.0s, 36.4s to go
# on time step 15313 (time=191.413), 0.000261218 s/step
# Meep progress: 386.4125/1930.8937683105469 = 20.0% done in 8.0s, 32.0s to go
# on time step 30926 (time=386.575), 0.000256205 s/step
# Meep progress: 581.85/1930.8937683105469 = 30.1% done in 12.0s, 27.8s to go
# on time step 46562 (time=582.025), 0.000255832 s/step
# Meep progress: 776.4875000000001/1930.8937683105469 = 40.2% done in 16.0s, 23.8s to go
# on time step 62135 (time=776.688), 0.000256871 s/step
# Meep progress: 971.4250000000001/1930.8937683105469 = 50.3% done in 20.0s, 19.8s to go
# on time step 77731 (time=971.638), 0.000256484 s/step
# Meep progress: 1166.8375/1930.8937683105469 = 60.4% done in 24.0s, 15.7s to go
# on time step 93366 (time=1167.08), 0.000255846 s/step
# Meep progress: 1361.3875/1930.8937683105469 = 70.5% done in 28.0s, 11.7s to go
# on time step 108931 (time=1361.64), 0.000257004 s/step
# Meep progress: 1555.9125000000001/1930.8937683105469 = 80.6% done in 32.0s, 7.7s to go
# on time step 124493 (time=1556.16), 0.000257041 s/step
# Meep progress: 1749.1875/1930.8937683105469 = 90.6% done in 36.0s, 3.7s to go
# on time step 139957 (time=1749.46), 0.000258673 s/step
# run 0 finished at t = 1930.9 (154472 timesteps)
# data:, xodd, 0.25, 30479846.39265691, -11067666.699385393, 0.363114254475107
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000625849 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00919199 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.220156 after 34 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.25, 0.22015579481100603
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00072217 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.625,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0236859 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.220156 after 34 iters
# FloatProgress(value=0.0, description='0% done ', max=1954.2237854003906)
# Meep progress: 192.32500000000002/1954.2237854003906 = 9.8% done in 4.0s, 36.6s to go
# on time step 15391 (time=192.388), 0.000259901 s/step
# Meep progress: 385.6625/1954.2237854003906 = 19.7% done in 8.0s, 32.5s to go
# on time step 30860 (time=385.75), 0.000258598 s/step
# Meep progress: 579.1875/1954.2237854003906 = 29.6% done in 12.0s, 28.5s to go
# on time step 46343 (time=579.288), 0.000258351 s/step
# Meep progress: 772.9250000000001/1954.2237854003906 = 39.6% done in 16.0s, 24.5s to go
# on time step 61843 (time=773.038), 0.000258066 s/step
# Meep progress: 967.075/1954.2237854003906 = 49.5% done in 20.0s, 20.4s to go
# on time step 77377 (time=967.213), 0.000257514 s/step
# Meep progress: 1162.3125/1954.2237854003906 = 59.5% done in 24.0s, 16.4s to go
# on time step 92998 (time=1162.48), 0.000256073 s/step
# Meep progress: 1356.9375/1954.2237854003906 = 69.4% done in 28.0s, 12.3s to go
# on time step 108570 (time=1357.12), 0.000256886 s/step
# Meep progress: 1552.3500000000001/1954.2237854003906 = 79.4% done in 32.0s, 8.3s to go
# on time step 124204 (time=1552.55), 0.000255858 s/step
# Meep progress: 1747.5/1954.2237854003906 = 89.4% done in 36.0s, 4.3s to go
# on time step 139818 (time=1747.73), 0.000256194 s/step
# Meep progress: 1941.9750000000001/1954.2237854003906 = 99.4% done in 40.0s, 0.3s to go
# on time step 155377 (time=1942.21), 0.000257091 s/step
# run 0 finished at t = 1954.2250000000001 (156338 timesteps)
# data:, xeven, 0.25, 51313477.28776565, 25550467.723917153, -0.4979289861926584
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000578165 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.65,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.65,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0086329 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.231358 after 26 iters
# Dominant planewave for band 2: (-0.200000,0.000000,0.500000)
# freq:, xodd, 0.3, 0.23135793083586811
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000497103 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.65,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.65,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132229 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.231358 after 26 iters
# FloatProgress(value=0.0, description='0% done ', max=1932.230712890625)
# Meep progress: 192.2375/1932.230712890625 = 9.9% done in 4.0s, 36.2s to go
# on time step 15384 (time=192.3), 0.000260019 s/step
# Meep progress: 386.55/1932.230712890625 = 20.0% done in 8.0s, 32.0s to go
# on time step 30930 (time=386.625), 0.000257306 s/step
# Meep progress: 581.0625/1932.230712890625 = 30.1% done in 12.0s, 27.9s to go
# on time step 46493 (time=581.163), 0.000257028 s/step
# Meep progress: 775.4250000000001/1932.230712890625 = 40.1% done in 16.0s, 23.9s to go
# on time step 62043 (time=775.538), 0.00025724 s/step
# Meep progress: 969.9625000000001/1932.230712890625 = 50.2% done in 20.0s, 19.8s to go
# on time step 77608 (time=970.1), 0.000256991 s/step
# Meep progress: 1164.3625/1932.230712890625 = 60.3% done in 24.0s, 15.8s to go
# on time step 93162 (time=1164.53), 0.000257183 s/step
# Meep progress: 1358.6000000000001/1932.230712890625 = 70.3% done in 28.0s, 11.8s to go
# on time step 108702 (time=1358.78), 0.000257402 s/step
# Meep progress: 1552.6875/1932.230712890625 = 80.4% done in 32.0s, 7.8s to go
# on time step 124230 (time=1552.88), 0.000257603 s/step
# Meep progress: 1745.95/1932.230712890625 = 90.4% done in 36.0s, 3.8s to go
# on time step 139692 (time=1746.15), 0.000258705 s/step
# run 0 finished at t = 1932.2375000000002 (154579 timesteps)
# data:, xodd, 0.3, 31437622.41825747, -10055191.852736168, 0.31984581145985747
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000746012 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.65,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.65,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00847602 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.221215 after 35 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.3, 0.22121514866665
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000494003 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.65,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.65,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132861 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.221215 after 35 iters
# FloatProgress(value=0.0, description='0% done ', max=1952.0486145019531)
# Meep progress: 191.8/1952.0486145019531 = 9.8% done in 4.0s, 36.7s to go
# on time step 15349 (time=191.863), 0.000260607 s/step
# Meep progress: 385.2375/1952.0486145019531 = 19.7% done in 8.0s, 32.5s to go
# on time step 30826 (time=385.325), 0.000258462 s/step
# Meep progress: 576.75/1952.0486145019531 = 29.5% done in 12.0s, 28.6s to go
# on time step 46149 (time=576.863), 0.000261054 s/step
# Meep progress: 768.7125000000001/1952.0486145019531 = 39.4% done in 16.0s, 24.6s to go
# on time step 61508 (time=768.85), 0.00026045 s/step
# Meep progress: 959.5375/1952.0486145019531 = 49.2% done in 20.0s, 20.7s to go
# on time step 76777 (time=959.713), 0.000261971 s/step
# Meep progress: 1152.9125000000001/1952.0486145019531 = 59.1% done in 24.0s, 16.6s to go
# on time step 92249 (time=1153.11), 0.00025854 s/step
# Meep progress: 1344.9875000000002/1952.0486145019531 = 68.9% done in 28.0s, 12.6s to go
# on time step 107616 (time=1345.2), 0.000260304 s/step
# Meep progress: 1537.8875/1952.0486145019531 = 78.8% done in 32.0s, 8.6s to go
# on time step 123051 (time=1538.14), 0.000259166 s/step
# Meep progress: 1729.125/1952.0486145019531 = 88.6% done in 36.0s, 4.6s to go
# on time step 138351 (time=1729.39), 0.000261448 s/step
# Meep progress: 1921.8875/1952.0486145019531 = 98.5% done in 40.0s, 0.6s to go
# on time step 153774 (time=1922.18), 0.00025936 s/step
# run 0 finished at t = 1952.0500000000002 (156164 timesteps)
# data:, xeven, 0.3, 52218173.42008418, 21413000.503884036, -0.4100679725355571
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000917912 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.675,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.675,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00951481 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.230723 after 24 iters
# Dominant planewave for band 2: (0.200000,-0.000000,0.500000)
# freq:, xodd, 0.35000000000000003, 0.2307232812586098
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000385046 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.675,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.675,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0154049 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.230723 after 24 iters
# FloatProgress(value=0.0, description='0% done ', max=1933.4196472167969)
# Meep progress: 188.16250000000002/1933.4196472167969 = 9.7% done in 4.0s, 37.1s to go
# on time step 15058 (time=188.225), 0.000265653 s/step
# Meep progress: 380.5625/1933.4196472167969 = 19.7% done in 8.0s, 32.6s to go
# on time step 30451 (time=380.638), 0.000259869 s/step
# Meep progress: 573.6875/1933.4196472167969 = 29.7% done in 12.0s, 28.4s to go
# on time step 45903 (time=573.788), 0.000258869 s/step
# Meep progress: 769.0250000000001/1933.4196472167969 = 39.8% done in 16.0s, 24.2s to go
# on time step 61532 (time=769.15), 0.000255944 s/step
# Meep progress: 964.575/1933.4196472167969 = 49.9% done in 20.0s, 20.1s to go
# on time step 77177 (time=964.713), 0.000255684 s/step
# Meep progress: 1157.8/1933.4196472167969 = 59.9% done in 24.0s, 16.1s to go
# on time step 92637 (time=1157.96), 0.000258738 s/step
# Meep progress: 1349.65/1933.4196472167969 = 69.8% done in 28.0s, 12.1s to go
# on time step 107986 (time=1349.83), 0.000260609 s/step
# Meep progress: 1544.2250000000001/1933.4196472167969 = 79.9% done in 32.0s, 8.1s to go
# on time step 123554 (time=1544.43), 0.000256939 s/step
# Meep progress: 1740.8375/1933.4196472167969 = 90.0% done in 36.0s, 4.0s to go
# on time step 139284 (time=1741.05), 0.000254292 s/step
# run 0 finished at t = 1933.4250000000002 (154674 timesteps)
# data:, xodd, 0.35000000000000003, 32507189.267413877, -9070045.250888329, 0.2790165946454312
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000456095 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.675,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.675,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00852919 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.22209 after 31 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.35000000000000003, 0.2220901139787869
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000486135 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.675,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.675,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.013298 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.22209 after 31 iters
# FloatProgress(value=0.0, description='0% done ', max=1950.2676696777344)
# Meep progress: 193.70000000000002/1950.2676696777344 = 9.9% done in 4.0s, 36.3s to go
# on time step 15501 (time=193.763), 0.000258056 s/step
# Meep progress: 387.2375/1950.2676696777344 = 19.9% done in 8.0s, 32.3s to go
# on time step 30986 (time=387.325), 0.00025833 s/step
# Meep progress: 578.4/1950.2676696777344 = 29.7% done in 12.0s, 28.5s to go
# on time step 46279 (time=578.488), 0.00026156 s/step
# Meep progress: 768.7375000000001/1950.2676696777344 = 39.4% done in 16.0s, 24.6s to go
# on time step 61508 (time=768.85), 0.000262667 s/step
# Meep progress: 959.1875/1950.2676696777344 = 49.2% done in 20.0s, 20.7s to go
# on time step 76747 (time=959.338), 0.000262497 s/step
# Meep progress: 1150.7250000000001/1950.2676696777344 = 59.0% done in 24.0s, 16.7s to go
# on time step 92072 (time=1150.9), 0.000261023 s/step
# Meep progress: 1344.95/1950.2676696777344 = 69.0% done in 28.0s, 12.6s to go
# on time step 107611 (time=1345.14), 0.00025742 s/step
# Meep progress: 1540.0875/1950.2676696777344 = 79.0% done in 32.0s, 8.5s to go
# on time step 123223 (time=1540.29), 0.000256224 s/step
# Meep progress: 1734.9250000000002/1950.2676696777344 = 89.0% done in 36.0s, 4.5s to go
# on time step 138811 (time=1735.14), 0.000256612 s/step
# Meep progress: 1929.6125000000002/1950.2676696777344 = 98.9% done in 40.0s, 0.4s to go
# on time step 154388 (time=1929.85), 0.00025679 s/step
# run 0 finished at t = 1950.275 (156022 timesteps)
# data:, xeven, 0.35000000000000003, 52095683.654139765, 17690543.921530068, -0.33957792048524726
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000637054 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.7,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.7,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00874615 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.230167 after 24 iters
# Dominant planewave for band 2: (0.200000,-0.000000,0.500000)
# freq:, xodd, 0.4, 0.2301674662732153
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000594854 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.7,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.7,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132401 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.230167 after 24 iters
# FloatProgress(value=0.0, description='0% done ', max=1934.4662780761719)
# Meep progress: 194.95000000000002/1934.4662780761719 = 10.1% done in 4.0s, 35.7s to go
# on time step 15602 (time=195.025), 0.000256379 s/step
# Meep progress: 389.55/1934.4662780761719 = 20.1% done in 8.0s, 31.7s to go
# on time step 31172 (time=389.65), 0.000256915 s/step
# Meep progress: 584.1875/1934.4662780761719 = 30.2% done in 12.0s, 27.7s to go
# on time step 46744 (time=584.3), 0.000256882 s/step
# Meep progress: 779.1375/1934.4662780761719 = 40.3% done in 16.0s, 23.7s to go
# on time step 62342 (time=779.275), 0.000256452 s/step
# Meep progress: 976.6500000000001/1934.4662780761719 = 50.5% done in 20.0s, 19.6s to go
# on time step 78144 (time=976.8), 0.000253138 s/step
# Meep progress: 1173.3375/1934.4662780761719 = 60.7% done in 24.0s, 15.6s to go
# on time step 93880 (time=1173.5), 0.000254201 s/step
# Meep progress: 1368.4250000000002/1934.4662780761719 = 70.7% done in 28.0s, 11.6s to go
# on time step 109489 (time=1368.61), 0.000256273 s/step
# Meep progress: 1566.0625/1934.4662780761719 = 81.0% done in 32.0s, 7.5s to go
# on time step 125302 (time=1566.28), 0.000252962 s/step
# Meep progress: 1761.2/1934.4662780761719 = 91.0% done in 36.0s, 3.5s to go
# on time step 140915 (time=1761.44), 0.000256211 s/step
# run 0 finished at t = 1934.4750000000001 (154758 timesteps)
# data:, xodd, 0.4, 33512451.812299885, -8100268.900312155, 0.24170922932410333
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000693083 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.7,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.7,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00868011 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.222815 after 32 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.4, 0.22281545973894626
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.0038259 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.7,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.7,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.019032 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.222815 after 32 iters
# FloatProgress(value=0.0, description='0% done ', max=1948.8018798828125)
# Meep progress: 182.55/1948.8018798828125 = 9.4% done in 4.0s, 38.7s to go
# on time step 14609 (time=182.613), 0.000273817 s/step
# Meep progress: 360.5375/1948.8018798828125 = 18.5% done in 8.0s, 35.2s to go
# on time step 28850 (time=360.625), 0.000280891 s/step
# ...
# on time step 108288 (time=1353.6), 0.000257678 s/step
# Meep progress: 1549.6750000000002/1939.6175842285156 = 79.9% done in 32.0s, 8.1s to go
# on time step 123990 (time=1549.88), 0.000254751 s/step
# Meep progress: 1743.5625/1939.6175842285156 = 89.9% done in 36.0s, 4.0s to go
# on time step 139502 (time=1743.78), 0.000257866 s/step
# run 0 finished at t = 1939.625 (155170 timesteps)
# data:, xodd, 0.9000000000000001, 40294013.07215857, -2053335.4915417237, 0.050958823283861254
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000497103 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.95,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.95,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00868797 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.225913 after 44 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.9000000000000001, 0.22591320789789476
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000533104 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.95,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.95,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.013242 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.225913 after 44 iters
# FloatProgress(value=0.0, description='0% done ', max=1942.6478576660156)
# Meep progress: 193.625/1942.6478576660156 = 10.0% done in 4.0s, 36.1s to go
# on time step 15495 (time=193.688), 0.000258158 s/step
# Meep progress: 388.225/1942.6478576660156 = 20.0% done in 8.0s, 32.0s to go
# on time step 31065 (time=388.312), 0.000256918 s/step
# Meep progress: 584.6875/1942.6478576660156 = 30.1% done in 12.0s, 27.9s to go
# on time step 46783 (time=584.788), 0.000254496 s/step
# Meep progress: 781.45/1942.6478576660156 = 40.2% done in 16.0s, 23.8s to go
# on time step 62526 (time=781.575), 0.000254096 s/step
# Meep progress: 978.2750000000001/1942.6478576660156 = 50.4% done in 20.0s, 19.7s to go
# on time step 78273 (time=978.413), 0.000254021 s/step
# Meep progress: 1174.6000000000001/1942.6478576660156 = 60.5% done in 24.0s, 15.7s to go
# on time step 93980 (time=1174.75), 0.000254671 s/step
# Meep progress: 1371.2875000000001/1942.6478576660156 = 70.6% done in 28.0s, 11.7s to go
# on time step 109717 (time=1371.46), 0.000254184 s/step
# Meep progress: 1569.0125/1942.6478576660156 = 80.8% done in 32.0s, 7.6s to go
# on time step 125536 (time=1569.2), 0.000252869 s/step
# Meep progress: 1766.6125000000002/1942.6478576660156 = 90.9% done in 36.0s, 3.6s to go
# on time step 141346 (time=1766.83), 0.000253016 s/step
# run 0 finished at t = 1942.65 (155412 timesteps)
# data:, xeven, 0.9000000000000001, 41333462.95925612, 2143520.861779653, -0.051859213051967085
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00059104 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00942588 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.227367 after 23 iters
# Dominant planewave for band 2: (0.200000,-0.000000,0.500000)
# freq:, xodd, 0.9500000000000001, 0.2273671268131195
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000490189 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132289 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.227367 after 23 iters
# FloatProgress(value=0.0, description='0% done ', max=1939.8173217773438)
# Meep progress: 186.28750000000002/1939.8173217773438 = 9.6% done in 4.0s, 37.7s to go
# on time step 14909 (time=186.363), 0.00026831 s/step
# Meep progress: 378.2875/1939.8173217773438 = 19.5% done in 8.0s, 33.0s to go
# on time step 30271 (time=378.388), 0.000260389 s/step
# Meep progress: 572.975/1939.8173217773438 = 29.5% done in 12.0s, 28.6s to go
# on time step 45848 (time=573.1), 0.000256804 s/step
# Meep progress: 767.1875/1939.8173217773438 = 39.5% done in 16.0s, 24.5s to go
# on time step 61387 (time=767.338), 0.000257426 s/step
# Meep progress: 959.725/1939.8173217773438 = 49.5% done in 20.0s, 20.4s to go
# on time step 76790 (time=959.875), 0.000259691 s/step
# Meep progress: 1154.3875/1939.8173217773438 = 59.5% done in 24.0s, 16.3s to go
# on time step 92365 (time=1154.56), 0.000256826 s/step
# Meep progress: 1345.2375000000002/1939.8173217773438 = 69.3% done in 28.0s, 12.4s to go
# on time step 107634 (time=1345.43), 0.00026198 s/step
# Meep progress: 1526.4250000000002/1939.8173217773438 = 78.7% done in 32.0s, 8.7s to go
# on time step 122130 (time=1526.62), 0.000275943 s/step
# Meep progress: 1711.2625/1939.8173217773438 = 88.2% done in 36.0s, 4.8s to go
# on time step 136919 (time=1711.49), 0.000270479 s/step
# Meep progress: 1897.5/1939.8173217773438 = 97.8% done in 40.0s, 0.9s to go
# on time step 151819 (time=1897.74), 0.000268474 s/step
# run 0 finished at t = 1939.825 (155186 timesteps)
# data:, xodd, 0.9500000000000001, 40690537.254130386, -1776659.9860419708, 0.043662731090178146
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000854015 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00851893 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.226021 after 45 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 0.9500000000000001, 0.22602064762883464
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000481844 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (0.975,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.013274 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.226021 after 45 iters
# FloatProgress(value=0.0, description='0% done ', max=1942.4374694824219)
# Meep progress: 194.8375/1942.4374694824219 = 10.0% done in 4.0s, 35.9s to go
# on time step 15592 (time=194.9), 0.000256552 s/step
# Meep progress: 391.21250000000003/1942.4374694824219 = 20.1% done in 8.0s, 31.7s to go
# on time step 31303 (time=391.288), 0.000254601 s/step
# Meep progress: 585.5375/1942.4374694824219 = 30.1% done in 12.0s, 27.8s to go
# on time step 46851 (time=585.638), 0.000257279 s/step
# Meep progress: 778.3875/1942.4374694824219 = 40.1% done in 16.0s, 23.9s to go
# on time step 62280 (time=778.5), 0.00025926 s/step
# Meep progress: 971.95/1942.4374694824219 = 50.0% done in 20.0s, 20.0s to go
# on time step 77767 (time=972.088), 0.000258294 s/step
# Meep progress: 1161.0875/1942.4374694824219 = 59.8% done in 24.0s, 16.2s to go
# on time step 92901 (time=1161.26), 0.000264322 s/step
# Meep progress: 1355.0125/1942.4374694824219 = 69.8% done in 28.0s, 12.1s to go
# on time step 108416 (time=1355.2), 0.000257822 s/step
# Meep progress: 1547.025/1942.4374694824219 = 79.6% done in 32.0s, 8.2s to go
# on time step 123778 (time=1547.23), 0.000260389 s/step
# Meep progress: 1738.5625/1942.4374694824219 = 89.5% done in 36.0s, 4.2s to go
# on time step 139102 (time=1738.78), 0.000261038 s/step
# Meep progress: 1929.9750000000001/1942.4374694824219 = 99.4% done in 40.0s, 0.3s to go
# on time step 154417 (time=1930.21), 0.000261194 s/step
# run 0 finished at t = 1942.4375 (155395 timesteps)
# data:, xeven, 0.9500000000000001, 40446492.00134382, 1779869.29094364, -0.0440055293518287
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000635862 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00860405 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.22728 after 23 iters
# Dominant planewave for band 2: (0.200000,-0.000000,0.500000)
# freq:, xodd, 1.0, 0.22727959569236175
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000501871 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0132401 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_2(0,0,0.5) = 0.22728 after 23 iters
# FloatProgress(value=0.0, description='0% done ', max=1939.9866943359375)
# Meep progress: 193.25/1939.9866943359375 = 10.0% done in 4.0s, 36.2s to go
# on time step 15478 (time=193.475), 0.000258448 s/step
# Meep progress: 385.32500000000005/1939.9866943359375 = 19.9% done in 8.0s, 32.3s to go
# on time step 30845 (time=385.562), 0.000260304 s/step
# Meep progress: 576.9875000000001/1939.9866943359375 = 29.7% done in 12.0s, 28.3s to go
# on time step 46179 (time=577.238), 0.000260872 s/step
# Meep progress: 770.5/1939.9866943359375 = 39.7% done in 16.0s, 24.3s to go
# on time step 61662 (time=770.775), 0.000258364 s/step
# Meep progress: 957.7625/1939.9866943359375 = 49.4% done in 20.0s, 20.5s to go
# on time step 76643 (time=958.038), 0.000267011 s/step
# Meep progress: 1140.9125000000001/1939.9866943359375 = 58.8% done in 24.0s, 16.8s to go
# on time step 91297 (time=1141.21), 0.00027298 s/step
# Meep progress: 1328.9125000000001/1939.9866943359375 = 68.5% done in 28.0s, 12.9s to go
# on time step 106339 (time=1329.24), 0.00026593 s/step
# Meep progress: 1511.1375/1939.9866943359375 = 77.9% done in 32.0s, 9.1s to go
# on time step 120917 (time=1511.46), 0.000274386 s/step
# Meep progress: 1694.8625000000002/1939.9866943359375 = 87.4% done in 36.0s, 5.2s to go
# on time step 135618 (time=1695.23), 0.000272108 s/step
# Meep progress: 1879.3375/1939.9866943359375 = 96.9% done in 40.0s, 1.3s to go
# on time step 150376 (time=1879.7), 0.000271044 s/step
# run 0 finished at t = 1939.9875000000002 (155199 timesteps)
# data:, xodd, 1.0, 41039903.9962964, -1538255.7474176942, 0.03748195287095488
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000710964 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.00854897 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.226111 after 45 iters
# Dominant planewave for band 1: (0.000000,0.000000,0.500000)
# freq:, xeven, 1.0, 0.226111151803112
# -----------
# Initializing structure...
# Halving computational cell along direction x
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000702143 s
# Working in 2D dimensions.
# Computational cell is 7 x 5 x 0 with resolution 40
#      block, center = (-1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
#      block, center = (1,0,0)
#           size (1,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.9025,11.9025,11.9025)
# time for set_epsilon = 0.0139942 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,0,0.5) = 0.226111 after 45 iters
# FloatProgress(value=0.0, description='0% done ', max=1942.2603759765625)
# Meep progress: 191.4625/1942.2603759765625 = 9.9% done in 4.0s, 36.6s to go
# on time step 15323 (time=191.538), 0.000261058 s/step
# Meep progress: 386.02500000000003/1942.2603759765625 = 19.9% done in 8.0s, 32.3s to go
# on time step 30890 (time=386.125), 0.000256967 s/step
# Meep progress: 582.25/1942.2603759765625 = 30.0% done in 12.0s, 28.0s to go
# on time step 46588 (time=582.35), 0.000254817 s/step
# Meep progress: 777.3375000000001/1942.2603759765625 = 40.0% done in 16.0s, 24.0s to go
# on time step 62197 (time=777.463), 0.000256275 s/step
# Meep progress: 972.5625/1942.2603759765625 = 50.1% done in 20.0s, 19.9s to go
# on time step 77817 (time=972.713), 0.000256085 s/step
# Meep progress: 1169.8875/1942.2603759765625 = 60.2% done in 24.0s, 15.8s to go
# on time step 93605 (time=1170.06), 0.000253369 s/step
# Meep progress: 1366.3500000000001/1942.2603759765625 = 70.3% done in 28.0s, 11.8s to go
# on time step 109324 (time=1366.55), 0.00025448 s/step
# Meep progress: 1563.125/1942.2603759765625 = 80.5% done in 32.0s, 7.8s to go
# on time step 125068 (time=1563.35), 0.00025408 s/step
# Meep progress: 1759.7125/1942.2603759765625 = 90.6% done in 36.0s, 3.7s to go
# on time step 140796 (time=1759.95), 0.000254328 s/step
# run 0 finished at t = 1942.2625 (155381 timesteps)
# data:, xeven, 1.0, 39494384.98867461, 1473785.223880936, -0.03731632292295621
