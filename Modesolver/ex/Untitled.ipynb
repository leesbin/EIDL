# %%
import math
import meep as mp
from meep import mpb

num_bands = 8

k_points = [mp.Vector3(),          # Gamma
            mp.Vector3(0.5),       # X
            mp.Vector3(0.5, 0.5),  # M
            mp.Vector3()]          # Gamma

k_points = mp.interpolate(4, k_points)

geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]

geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1))

resolution = 32

ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)
#print_heading("Square lattice of rods: TE bands")
ms.run_te()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0052373409271240234
# solve_kpoint (0,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 15.71381876587248 (194.191% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 6.919549592600122 (77.7107% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 6.101610186813387 (12.5632% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.824355205040595 (4.6496% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.704424884120756 (2.08054% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.631869889487239 (1.28005% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.589001620434106 (0.764081% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.566675694015029 (0.400261% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 71.2328%)
#     iteration    9: trace = 5.556978649925462 (0.17435% change)
#     iteration   10: trace = 5.552004364464547 (0.0895543% change)
#     iteration   11: trace = 5.550179354671764 (0.0328766% change)
#     iteration   12: trace = 5.549263072040669 (0.0165104% change)
#     iteration   13: trace = 5.548897246560112 (0.00659254% change)
#     iteration   14: trace = 5.548741160266851 (0.00281296% change)
#     iteration   15: trace = 5.548659430307089 (0.00147296% change)
#     switching back to exact line minimization
#     iteration   16: trace = 5.548603678621322 (0.00100478% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.548537245631508 (0.0011973% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.548457732496042 (0.00143306% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 5.548375713791911 (0.00147824% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.548294556978823 (0.00146272% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 5.548242399000603 (0.000940077% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 5.548204426742343 (0.000684404% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 5.548175626661764 (0.00051909% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 5.54815271788037 (0.000412907% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 5.54813468233168 (0.000325074% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 5.548124849057896 (0.000177236% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 5.548120472684112 (7.88803e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 5.548118932765705 (2.77557e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 5.548118272239313 (1.19054e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 5.548117931109598 (6.14857e-06% change)
# Finished solving for bands 2 to 8 after 30 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.552709, 0.773227, 0.77323, 0.922997, 1.00017, 1.00017, 1.09282
# elapsed time for k point: 0.10149717330932617
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.58122640264875 (0.239407% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.57378241988973 (0.133464% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.571423772624866 (0.0423258% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.569947409214105 (0.0265024% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.569097741232472 (0.0152557% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.568411051061243 (0.0123311% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.567981280710294 (0.0077183% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 5.567696324894288 (0.00511789% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.567558164117022 (0.0024815% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 5.567469348396673 (0.00159525% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.567431395895182 (0.000681685% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.567416663654496 (0.000264615% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.567411160853533 (9.88394e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.567409742037 (2.54843e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.567409128878203 (1.10134e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 5.567408837672097 (5.23055e-06% change)
# Finished solving for bands 1 to 8 after 16 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.1, 0.0897333, 0.551138, 0.7616, 0.774682, 0.907199, 1.00188, 1.00357, 1.11423
# elapsed time for k point: 0.04282569885253906
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.623773241906769 (0.354138% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.606399769365889 (0.309407% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.597743139803558 (0.154526% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.590924714711074 (0.121881% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.585998336655011 (0.0881527% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.582526815936877 (0.0621661% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.581002562087725 (0.0273077% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 5.580427515335577 (0.0103042% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.580249977588533 (0.00318149% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.580153682666739 (0.00172565% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.58010601737545 (0.000854197% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.580083534766594 (0.000402907% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.580073072455419 (0.000187494% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.580068263949125 (8.61729e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 5.580062344279451 (0.000106086% change)
#     large trace change predicted (0.000234667%)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 5.580049278891004 (0.000234144% change)
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration   17: trace = 5.578695003069904 (0.0242729% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.578633194071903 (0.00110795% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.578575559053507 (0.00103314% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.578521663803262 (0.000966116% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 5.578470811993783 (0.000911568% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 5.578422367420441 (0.000868424% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 5.578375812442868 (0.000834558% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 5.578330737872848 (0.000808026% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 5.578286820658634 (0.000787285% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 5.578243803462719 (0.000771157% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 5.578201478647358 (0.000758751% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 5.578159676248346 (0.000749391% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 5.578118255006288 (0.000742564% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 5.578077095618652 (0.000737875% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.5780360955762 (0.000735024% change)
#     linmin: converged after 4 iterations.
#     iteration   32: trace = 5.57799516512646 (0.000733782% change)
#     linmin: converged after 4 iterations.
#     iteration   33: trace = 5.577954224042777 (0.000733978% change)
#     linmin: converged after 4 iterations.
#     iteration   34: trace = 5.577913198976379 (0.000735489% change)
#     linmin: converged after 4 iterations.
#     iteration   35: trace = 5.577872021238378 (0.000738231% change)
#     linmin: converged after 4 iterations.
#     iteration   36: trace = 5.577830624908818 (0.000742155% change)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 5.577788945205446 (0.000747241% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 5.577746917070755 (0.000753494% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.577704473958231 (0.000760939% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.577661546786375 (0.000769624% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.577618063117816 (0.000779607% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.577573946497642 (0.000790961% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.57752911602257 (0.000803766% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.577483486139353 (0.000818105% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.577436966701979 (0.000834061% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.577389463318454 (0.00085171% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.577340878021664 (0.000871116% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.577291110301882 (0.000892324% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.577240058538563 (0.000915355% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.577187621865304 (0.000940195% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.577133702491508 (0.000966789% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.577078208485473 (0.000995032% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.577021056993818 (0.00102476% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.576962177830116 (0.00105575% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.576901517311782 (0.0010877% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.576839042161987 (0.00112025% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.576774743229834 (0.00115297% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.576708638728357 (0.00118536% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 5.576640776660874 (0.00121689% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 5.576571236116209 (0.001247% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 5.57650012717321 (0.00127515% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.576427589266692 (0.00130079% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.576353788019006 (0.00132346% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.576278910711143 (0.00134277% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.576203160722057 (0.00135844% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 5.576126751374729 (0.00137028% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 5.576049899670552 (0.00137824% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 5.575972820365562 (0.00138234% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 5.575895720754142 (0.00138272% change)
#     resetting CG direction...
#     large trace change predicted (0.563123%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 5.544163486074897 (0.570721% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 5.512763634687686 (0.567967% change)
#     linmin: converged after 3 iterations.
#     iteration   72: trace = 5.504475619976947 (0.150455% change)
#     linmin: converged after 3 iterations.
#     iteration   73: trace = 5.502588960606232 (0.0342809% change)
#     linmin: converged after 3 iterations.
#     iteration   74: trace = 5.501373876834299 (0.0220845% change)
#     linmin: converged after 3 iterations.
#     iteration   75: trace = 5.500776508205356 (0.0108591% change)
#     linmin: converged after 3 iterations.
#     iteration   76: trace = 5.500381458547032 (0.00718197% change)
#     linmin: converged after 3 iterations.
#     iteration   77: trace = 5.499954744965896 (0.00775819% change)
#     linmin: converged after 3 iterations.
#     iteration   78: trace = 5.499735161929975 (0.00399253% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 5.499604967362332 (0.00236732% change)
#     linmin: converged after 3 iterations.
#     iteration   80: trace = 5.499496572277149 (0.00197098% change)
#     linmin: converged after 3 iterations.
#     iteration   81: trace = 5.499439504132496 (0.0010377% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 5.499408035210617 (0.000572222% change)
#     linmin: converged after 3 iterations.
#     iteration   83: trace = 5.499389833281092 (0.00033098% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 5.499381600646811 (0.000149701% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 5.499377560963432 (7.34571e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   86: trace = 5.499375830654699 (3.14637e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   87: trace = 5.499375327334652 (9.15231e-06% change)
# Finished solving for bands 1 to 8 after 87 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.2, 0.178692, 0.544896, 0.728534, 0.778528, 0.880244, 1.00699, 1.01696, 1.10027
# elapsed time for k point: 0.22209811210632324
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.496163863506162 (0.277995% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.489521103750238 (0.120935% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.48706922613197 (0.0446747% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.48620870426581 (0.015684% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.485739301835058 (0.00855641% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.485576162597223 (0.00297392% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.485498587984506 (0.00141417% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.485469818756621 (0.000524461% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.485462076643418 (0.000141139% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.485459960526548 (3.85768e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.485459323994136 (1.1604e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.485459174201405 (2.73072e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.3, 0.265798, 0.528176, 0.685449, 0.783377, 0.860714, 1.01515, 1.03843, 1.09664
# elapsed time for k point: 0.0358273983001709
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.518166799686552 (0.240354% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.511317179522384 (0.124206% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.507827487498603 (0.0633387% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.506159609550743 (0.0302865% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.505015588578577 (0.0207793% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.50461643336642 (0.00725102% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.504453319771551 (0.00296326% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.504401076947847 (0.000949106% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.504383248956272 (0.000323887% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.504375649392231 (0.000138064% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.504370453867026 (9.4389e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.504366823574028 (6.59529e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.504364141876113 (4.87195e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.504362900960613 (2.25442e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.504362430806101 (8.54149e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.4, 0.348956, 0.490738, 0.652797, 0.787382, 0.849999, 1.02443, 1.06441, 1.09121
# elapsed time for k point: 0.03702712059020996
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.568058558667191 (0.237297% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.559204696423842 (0.159138% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.553745585563408 (0.0982477% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.550308522995818 (0.0619064% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.547656099210352 (0.0478002% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.546447605510784 (0.0217862% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.545503995713663 (0.0170143% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.544442959676259 (0.0191351% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 5.542906295231764 (0.0277192% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 5.541170837952524 (0.0313144% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.539951246867336 (0.0220121% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.539379525855512 (0.0103205% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 5.539090195396337 (0.00522329% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.538953751871276 (0.00246331% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.538903897189413 (0.000900078% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.538883530419229 (0.000367705% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.538874646100848 (0.000160399% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.538870035219373 (8.32459e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 5.538868765161473 (2.29299e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 5.538868274896733 (8.85135e-06% change)
# Finished solving for bands 1 to 8 after 20 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.5, 0.412791, 0.441588, 0.641998, 0.788933, 0.846588, 1.02916, 1.08607, 1.08787
# elapsed time for k point: 0.05243563652038574
# solve_kpoint (0.5,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.490819287184203 (1.61954% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.441577408892643 (0.900843% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.429085971892242 (0.229819% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.423911738026705 (0.0953512% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.421563649800992 (0.0433008% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.420538399001128 (0.0189124% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.420080572057373 (0.00844651% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.419922360371919 (0.00291903% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.419861845007228 (0.00111654% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.419827989000327 (0.000624667% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.419810762404365 (0.000317844% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.419802473019934 (0.000152946% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.419799238800691 (5.96741e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.419798382847712 (1.57931e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.419798064396852 (5.8757e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 7, 0.5, 0.1, 0, 0.509902, 0.423741, 0.445781, 0.63823, 0.793147, 0.842943, 0.986523, 1.05018, 1.10383
# elapsed time for k point: 0.04074263572692871
# solve_kpoint (0.5,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.25682070059241 (0.493558% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.245516524551845 (0.21527% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.242859253578107 (0.0506708% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.241807940927992 (0.0200543% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.241214539300268 (0.0113212% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.241004484305456 (0.00400783% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.240908614887097 (0.00182924% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.240871819890713 (0.000702075% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.240860346551077 (0.000218921% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.240855569848786 (9.11435e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.240854459338006 (2.11895e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.240854136792172 (6.15445e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 8, 0.5, 0.2, 0, 0.538516, 0.454781, 0.457434, 0.627898, 0.805254, 0.826101, 0.927945, 1.00456, 1.10879
# elapsed time for k point: 0.028725147247314453
# solve_kpoint (0.5,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.102473668611426 (0.25214% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.098134748958484 (0.0850718% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.097087000996987 (0.0205537% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.09676882400939 (0.00624252% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.096616774646574 (0.00298329% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.096573280102542 (0.000853404% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.096556502468307 (0.000329195% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.096548182726259 (0.000163243% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.096545587900843 (5.09134e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.096544595143286 (1.9479e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.096544381763723 (4.18675e-06% change)
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 9, 0.5, 0.3, 0, 0.583095, 0.473767, 0.501279, 0.61358, 0.781467, 0.824181, 0.894949, 0.959051, 1.1107
# elapsed time for k point: 0.029392242431640625
# solve_kpoint (0.5,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.010056939524118 (0.187149% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.007389065147786 (0.0532646% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 5.006708674537114 (0.0135887% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.006529340350575 (0.00358194% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.006460370700577 (0.0013776% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.006443553933422 (0.000335902% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.006439536923001 (8.02368e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.006437635838126 (3.79728e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.006436995536624 (1.27896e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.006436662251828 (6.65713e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 10, 0.5, 0.4, 0, 0.640312, 0.489649, 0.556045, 0.59957, 0.719611, 0.849247, 0.884337, 0.917168, 1.11162
# elapsed time for k point: 0.027284622192382812
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.978991971034203 (0.165157% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.976789333563986 (0.0442484% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.976199317167654 (0.0118561% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.976051154097584 (0.00297748% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.975999333316754 (0.00104141% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.975987219756451 (0.00024344% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.975985159587711 (4.14022e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.975984493515178 (1.33857e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.975984373254375 (2.41682e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 11, 0.5, 0.5, 0, 0.707107, 0.496836, 0.593141, 0.593154, 0.679169, 0.878684, 0.881977, 0.881982, 1.11192
# elapsed time for k point: 0.026693105697631836
# solve_kpoint (0.4,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.042734226984008 (0.320848% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.038219577418023 (0.0895679% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.036942684527165 (0.0253473% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 5.036564339725695 (0.00751168% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 5.036423006644141 (0.00280618% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.036388302480102 (0.000689066% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.036381739612544 (0.000130309% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.036379334209641 (4.77605e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.03637879133195 (1.07791e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.036378571174419 (4.37135e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 12, 0.4, 0.4, 0, 0.565685, 0.470987, 0.546003, 0.606732, 0.743602, 0.839223, 0.882254, 0.93697, 1.11121
# elapsed time for k point: 0.026059389114379883
# solve_kpoint (0.3,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.219135119269174 (0.37591% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.211334931596594 (0.149565% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.20858616413313 (0.0527599% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.207408517432953 (0.0226123% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.20682274609136 (0.0112494% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 5.206658313132811 (0.00315808% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 5.206604933762932 (0.00102522% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.206579361532559 (0.000491151% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.206571414707273 (0.000152631% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.206567830690144 (6.88364e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.206566745491196 (2.08429e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.206566438481884 (5.89658e-06% change)
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 13, 0.3, 0.3, 0, 0.424264, 0.372435, 0.536186, 0.644572, 0.809689, 0.825804, 0.883642, 1.0102, 1.10725
# elapsed time for k point: 0.03486990928649902
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.468253982574492 (0.621988% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.44322827640582 (0.458704% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.431414120867464 (0.217279% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.424247346066448 (0.132038% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.419939660564401 (0.0794469% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.418540372712533 (0.0258207% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.417858690978834 (0.0125813% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 5.417473746880827 (0.00710535% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.417269306469774 (0.00377379% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 5.4171457793378 (0.00228027% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.417106290635556 (0.00072896% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 5.417094608901285 (0.000215646% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 5.417090468067772 (7.64401e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.417089423848496 (1.92764e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.417088993061116 (7.95238e-06% change)
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 14, 0.2, 0.2, 0, 0.282843, 0.252088, 0.542887, 0.698081, 0.789371, 0.888483, 0.897858, 1.07884, 1.09039
# elapsed time for k point: 0.044997215270996094
# solve_kpoint (0.1,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 5.600085817530365 (1.22437% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.549461222882304 (0.908101% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 5.534348241979997 (0.272704% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.52726631301646 (0.128045% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.524126040381007 (0.0568304% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.52324148520181 (0.0160139% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 5.52291934411599 (0.00583263% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.522755157068779 (0.00297287% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.522648375035605 (0.00193351% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.522539954924505 (0.00196321% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 5.522446227902559 (0.00169719% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.522358274956582 (0.00159266% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.522300657922917 (0.00104335% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.522279600468606 (0.000381317% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.522271221036378 (0.000151739% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.52226862089162 (4.70847e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.522267958223736 (1.19999e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.522267758598212 (3.61492e-06% change)
# Finished solving for bands 1 to 8 after 18 iterations.
# tefreqs:, 15, 0.1, 0.1, 0, 0.141421, 0.126841, 0.549908, 0.750378, 0.777261, 0.903059, 0.961984, 1.04191, 1.10004
# elapsed time for k point: 0.04343819618225098
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.623403457641749 (0.879778% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.591472124106355 (0.569446% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.580924585268048 (0.188814% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.575048509405303 (0.105344% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.571612990609277 (0.0616421% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.570321254282725 (0.0231869% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.569684541150731 (0.0114311% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 5.569458334382221 (0.00406148% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 5.569343268231904 (0.00206604% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.56928727149459 (0.00100545% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.56925404907905 (0.000596531% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.569204413928835 (0.000891239% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.569129372476914 (0.00134744% change)
#     large trace change predicted (0.00857963%)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 5.568671205952582 (0.00822724% change)
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration   15: trace = 5.566395626355503 (0.0408723% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 5.565534381684911 (0.0154734% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 5.564700896609797 (0.014977% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.563773267293824 (0.0166713% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 5.562653347423145 (0.0201308% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 5.561299061684942 (0.024349% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.559790435713979 (0.0271309% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 5.558287794965412 (0.0270306% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 5.556932559086646 (0.0243852% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 5.555762934376689 (0.0210502% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 5.554772275535711 (0.0178328% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 5.553967562344528 (0.0144879% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 5.553350095188399 (0.0111182% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 5.552888682320533 (0.00830908% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 5.552531676164561 (0.0064294% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 5.552231531804969 (0.00540569% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 5.551957267902229 (0.00493983% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 5.551696627781403 (0.00469467% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 5.551451537697242 (0.00441479% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 5.551227770934092 (0.00403086% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 5.551026402669199 (0.00362752% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 5.550843641270919 (0.00329244% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 5.550675022103701 (0.00303777% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 5.550517921288803 (0.00283034% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 5.550371262094092 (0.0026423% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 5.550234318980406 (0.00246731% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 5.550106235496948 (0.00230774% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 5.549986222375288 (0.00216238% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 5.549873752924009 (0.0020265% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 5.549768613371125 (0.00189447% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 5.549670995046599 (0.00175898% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 5.54958144398114 (0.00161364% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 5.549500290356865 (0.00146235% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 5.549426831217789 (0.00132372% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 5.549359176630933 (0.00121913% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 5.549295141373307 (0.00115393% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 5.549233501000666 (0.00111078% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 5.549174477980974 (0.00106363% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 5.549118869421712 (0.00100211% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 5.549066767288221 (0.000938931% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 5.549017417302733 (0.000889342% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 5.548970216877034 (0.000850612% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 5.548925474469321 (0.000806322% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 5.548883876928784 (0.000749653% change)
#     linmin: converged after 2 iterations.
#     iteration   59: trace = 5.548845268407103 (0.000695791% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 5.548808286755434 (0.000666477% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 5.548771195444646 (0.000668458% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 5.548733099981934 (0.000686559% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 5.548694615030923 (0.000693583% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 5.548657301497029 (0.000672476% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 5.548622445080611 (0.000628197% change)
#     linmin: converged after 2 iterations.
#     iteration   66: trace = 5.548590613036822 (0.000573694% change)
#     linmin: converged after 2 iterations.
#     iteration   67: trace = 5.54856212341897 (0.000513458% change)
#     linmin: converged after 2 iterations.
#     iteration   68: trace = 5.548537342662893 (0.000446617% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 5.548516328136273 (0.000378741% change)
#     resetting CG direction...
#     large trace change predicted (0.0033937%)
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 5.548328024000297 (0.00339383% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 5.548230700813246 (0.00175411% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 5.548179283108833 (0.000926745% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 5.54815800656 (0.000383488% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 5.548148167345909 (0.000177342% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 5.548144506492823 (6.59834e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 5.548141721875896 (5.01901e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 5.548138700074194 (5.44651e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 5.548134467998475 (7.62792e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   79: trace = 5.548128692633779 (0.000104096% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 5.548123652481542 (9.08442e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 5.548120921953004 (4.92154e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 5.548118985423645 (3.49042e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 5.548118257112809 (1.31272e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 5.5481179069904 (6.31065e-06% change)
# Finished solving for bands 2 to 8 after 84 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.552709, 0.773227, 0.77323, 0.922997, 1.00017, 1.00017, 1.09282
# elapsed time for k point: 0.1829698085784912
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.49683586573984884 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.4415884758349937 at Vector3<0.5, 0.0, 0.0> to 0.5931405182468669 at Vector3<0.5, 0.5, 0.0>
# Band 3 range: 0.5931535893552137 at Vector3<0.5, 0.5, 0.0> to 0.7732265678573124 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.6791690135255464 at Vector3<0.5, 0.5, 0.0> to 0.8096891662050543 at Vector3<0.3, 0.3, 0.0>
# Band 5 range: 0.824181449220366 at Vector3<0.5, 0.30000000000000004, 0.0> to 0.9229965269593968 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.881977093673053 at Vector3<0.5, 0.5, 0.0> to 1.0291597307276759 at Vector3<0.5, 0.0, 0.0>
# Band 7 range: 0.881981814316286 at Vector3<0.5, 0.5, 0.0> to 1.0860733987653355 at Vector3<0.5, 0.0, 0.0>
# Band 8 range: 1.0878690871311276 at Vector3<0.5, 0.0, 0.0> to 1.1142330229403659 at Vector3<0.1, 0.0, 0.0>
# Gap from band 2 (0.5931405182468669) to band 3 (0.5931535893552137), 0.002203687645929299%
# Gap from band 4 (0.8096891662050543) to band 5 (0.824181449220366), 1.773981719052858%
# Gap from band 7 (1.0860733987653355) to band 8 (1.0878690871311276), 0.16520109224983964%
# total elapsed time for run: 0.983318567276001
# done

# %%
# tefreqs:, k index, kx, ky, kz, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8

# %%
ms.run_tm(mpb.output_efield_z)
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.005202531814575195
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 13.30866539011265 (195.065% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 5.561442851795494 (82.1111% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.836067596015504 (13.9529% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 4.558289075074801 (5.91373% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 4.432760399991261 (2.7923% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 4.385931917800129 (1.06203% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.375951645576932 (0.227811% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.374249689349272 (0.038901% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 4.373946790468479 (0.00692483% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.373864115621023 (0.00189018% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 4.373818039341063 (0.00105345% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.373791185606425 (0.000613967% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.373776227340552 (0.000341998% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.373755384631541 (0.000476539% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.373732713330319 (0.00051835% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.373724018329723 (0.000198801% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.373722250694053 (4.04149e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.373721988849802 (5.98676e-06% change)
# Finished solving for bands 2 to 8 after 18 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# elapsed time for k point: 0.05072283744812012
# Outputting fields to e.k01.b01.z.tm.h5...
# Outputting fields to e.k01.b02.z.tm.h5...
# Outputting fields to e.k01.b03.z.tm.h5...
# Outputting fields to e.k01.b04.z.tm.h5...
# Outputting fields to e.k01.b05.z.tm.h5...
# Outputting fields to e.k01.b06.z.tm.h5...
# Outputting fields to e.k01.b07.z.tm.h5...
# Outputting fields to e.k01.b08.z.tm.h5...
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.372232610687698 (0.839987% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.348001441986478 (0.555746% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 4.329936941622101 (0.416332% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 4.313033429089904 (0.391151% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.302105738900737 (0.253686% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 4.296325540211076 (0.134448% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 4.293456296502064 (0.066806% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.291859257067863 (0.037204% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.29116092329958 (0.0162724% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.29097425470299 (0.00435017% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 58.2883%)
#     iteration   11: trace = 4.290916282450917 (0.00135104% change)
#     iteration   12: trace = 4.290888581051236 (0.000645584% change)
#     iteration   13: trace = 4.290875079853954 (0.000314649% change)
#     iteration   14: trace = 4.290865916249452 (0.000213561% change)
#     iteration   15: trace = 4.2908608039677 (0.000119143% change)
#     iteration   16: trace = 4.29085800296651 (6.52783e-05% change)
#     iteration   17: trace = 4.290857448734378 (1.29166e-05% change)
#     iteration   18: trace = 4.29085733978144 (2.53919e-06% change)
# Finished solving for bands 1 to 8 after 18 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.1, 0.0643671, 0.518896, 0.552617, 0.579095, 0.812721, 0.852958, 0.941428, 1.04995
# elapsed time for k point: 0.07307767868041992
# Outputting fields to e.k02.b01.z.tm.h5...
# Outputting fields to e.k02.b02.z.tm.h5...
# Outputting fields to e.k02.b03.z.tm.h5...
# Outputting fields to e.k02.b04.z.tm.h5...
# Outputting fields to e.k02.b05.z.tm.h5...
# Outputting fields to e.k02.b06.z.tm.h5...
# Outputting fields to e.k02.b07.z.tm.h5...
# Outputting fields to e.k02.b08.z.tm.h5...
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.21307668743782 (0.515666% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.209108280590451 (0.094237% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.208519092196844 (0.0139989% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.208361728985613 (0.00373923% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.208319537811546 (0.00100256% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.208309586482161 (0.000236468% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.208308119836859 (3.48512e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.208307969627512 (3.56935e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.2, 0.126061, 0.48795, 0.553991, 0.610359, 0.812384, 0.849484, 0.912816, 1.02959
# elapsed time for k point: 0.029556989669799805
# Outputting fields to e.k03.b01.z.tm.h5...
# Outputting fields to e.k03.b02.z.tm.h5...
# Outputting fields to e.k03.b03.z.tm.h5...
# Outputting fields to e.k03.b04.z.tm.h5...
# Outputting fields to e.k03.b05.z.tm.h5...
# Outputting fields to e.k03.b06.z.tm.h5...
# Outputting fields to e.k03.b07.z.tm.h5...
# Outputting fields to e.k03.b08.z.tm.h5...
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.153950498416561 (0.446636% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.150919161801984 (0.0730014% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.150508698665933 (0.00988898% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.150451669200347 (0.00137405% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.150445324093791 (0.000152878% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.150444375615221 (2.28525e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.150444119703265 (6.16589e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.3, 0.181523, 0.45665, 0.555709, 0.644685, 0.802314, 0.845326, 0.880698, 1.025
# elapsed time for k point: 0.03094959259033203
# Outputting fields to e.k04.b01.z.tm.h5...
# Outputting fields to e.k04.b02.z.tm.h5...
# Outputting fields to e.k04.b03.z.tm.h5...
# Outputting fields to e.k04.b04.z.tm.h5...
# Outputting fields to e.k04.b05.z.tm.h5...
# Outputting fields to e.k04.b06.z.tm.h5...
# Outputting fields to e.k04.b07.z.tm.h5...
# Outputting fields to e.k04.b08.z.tm.h5...
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.123905399346163 (0.437377% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.120354157614313 (0.0861507% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.119752234761473 (0.0146096% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.11963530111445 (0.00283841% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.119609417530907 (0.0006283% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.119601698776915 (0.000187366% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.119598937194651 (6.70352e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.119598626300593 (7.54671e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.4, 0.224302, 0.429317, 0.557116, 0.682524, 0.772176, 0.842059, 0.865404, 1.0269
# elapsed time for k point: 0.03245973587036133
# Outputting fields to e.k05.b01.z.tm.h5...
# Outputting fields to e.k05.b02.z.tm.h5...
# Outputting fields to e.k05.b03.z.tm.h5...
# Outputting fields to e.k05.b04.z.tm.h5...
# Outputting fields to e.k05.b05.z.tm.h5...
# Outputting fields to e.k05.b06.z.tm.h5...
# Outputting fields to e.k05.b07.z.tm.h5...
# Outputting fields to e.k05.b08.z.tm.h5...
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.11716571604259 (0.467243% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.11218327067794 (0.12109% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.111188958937896 (0.0241826% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.110889430815074 (0.00728595% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.110807042430699 (0.00200417% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.1107836775416 (0.000568379% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.110777732782468 (0.000144614% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.110777279786336 (1.10197e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.110777245124082 (8.43204e-07% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.5, 0.241821, 0.417114, 0.557658, 0.713395, 0.741311, 0.84083, 0.862516, 1.02856
# elapsed time for k point: 0.03720712661743164
# Outputting fields to e.k06.b01.z.tm.h5...
# Outputting fields to e.k06.b02.z.tm.h5...
# Outputting fields to e.k06.b03.z.tm.h5...
# Outputting fields to e.k06.b04.z.tm.h5...
# Outputting fields to e.k06.b05.z.tm.h5...
# Outputting fields to e.k06.b06.z.tm.h5...
# Outputting fields to e.k06.b07.z.tm.h5...
# Outputting fields to e.k06.b08.z.tm.h5...
# solve_kpoint (0.5,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.110059681367565 (0.89808% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.101196125277951 (0.215888% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.099627972088559 (0.0382438% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.099504340242943 (0.00301573% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.099491102149282 (0.00032292% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.09949001538834 (2.65097e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.099489970449639 (1.0962e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 7, 0.5, 0.1, 0, 0.509902, 0.245235, 0.4236, 0.551085, 0.711571, 0.749855, 0.841982, 0.862609, 1.01714
# elapsed time for k point: 0.02790379524230957
# Outputting fields to e.k07.b01.z.tm.h5...
# Outputting fields to e.k07.b02.z.tm.h5...
# Outputting fields to e.k07.b03.z.tm.h5...
# Outputting fields to e.k07.b04.z.tm.h5...
# Outputting fields to e.k07.b05.z.tm.h5...
# Outputting fields to e.k07.b06.z.tm.h5...
# Outputting fields to e.k07.b07.z.tm.h5...
# Outputting fields to e.k07.b08.z.tm.h5...
# solve_kpoint (0.5,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.085143988179797 (0.762375% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.080119338551203 (0.123074% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.079494032561477 (0.0153269% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.079455626435144 (0.000941448% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.079453225908293 (5.88443e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.079452946764392 (6.84268e-06% change)
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 8, 0.5, 0.2, 0, 0.538516, 0.25442, 0.441321, 0.535034, 0.706018, 0.772267, 0.845818, 0.862861, 0.989395
# elapsed time for k point: 0.024280309677124023
# Outputting fields to e.k08.b01.z.tm.h5...
# Outputting fields to e.k08.b02.z.tm.h5...
# Outputting fields to e.k08.b03.z.tm.h5...
# Outputting fields to e.k08.b04.z.tm.h5...
# Outputting fields to e.k08.b05.z.tm.h5...
# Outputting fields to e.k08.b06.z.tm.h5...
# Outputting fields to e.k08.b07.z.tm.h5...
# Outputting fields to e.k08.b08.z.tm.h5...
# solve_kpoint (0.5,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.072736993687815 (0.634138% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.069415929804305 (0.081577% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.068882795153066 (0.0131019% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.068777003901827 (0.00260004% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.068760921276237 (0.00039527% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.068759373720781 (3.80351e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.068759283087937 (2.22753e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 9, 0.5, 0.3, 0, 0.583095, 0.266397, 0.465222, 0.516482, 0.697068, 0.802974, 0.853388, 0.863228, 0.954203
# elapsed time for k point: 0.024333477020263672
# Outputting fields to e.k09.b01.z.tm.h5...
# Outputting fields to e.k09.b02.z.tm.h5...
# Outputting fields to e.k09.b03.z.tm.h5...
# Outputting fields to e.k09.b04.z.tm.h5...
# Outputting fields to e.k09.b05.z.tm.h5...
# Outputting fields to e.k09.b06.z.tm.h5...
# Outputting fields to e.k09.b07.z.tm.h5...
# Outputting fields to e.k09.b08.z.tm.h5...
# solve_kpoint (0.5,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.080410536915432 (0.563622% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.077287254775257 (0.0765726% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.076189669308384 (0.0269231% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.075628846884457 (0.0137594% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.075534308235371 (0.00231964% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.075527487574874 (0.000167356% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.075526996409106 (1.20516e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.075526953552012 (1.05157e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 10, 0.5, 0.4, 0, 0.640312, 0.276774, 0.48701, 0.501823, 0.687264, 0.837704, 0.86397, 0.865932, 0.916273
# elapsed time for k point: 0.028876066207885742
# Outputting fields to e.k10.b01.z.tm.h5...
# Outputting fields to e.k10.b02.z.tm.h5...
# Outputting fields to e.k10.b03.z.tm.h5...
# Outputting fields to e.k10.b04.z.tm.h5...
# Outputting fields to e.k10.b05.z.tm.h5...
# Outputting fields to e.k10.b06.z.tm.h5...
# Outputting fields to e.k10.b07.z.tm.h5...
# Outputting fields to e.k10.b08.z.tm.h5...
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.109442394203747 (0.504919% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.105340119416278 (0.0998754% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 4.100310511948751 (0.122589% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.09380408072562 (0.158807% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 4.09224182707502 (0.0381687% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.092157129374291 (0.00206974% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.092151257996867 (0.000143479% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.09215066710022 (1.44398e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.092150601322291 (1.60742e-06% change)
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 11, 0.5, 0.5, 0, 0.707107, 0.280948, 0.496196, 0.496197, 0.682617, 0.859474, 0.878316, 0.878316, 0.879351
# elapsed time for k point: 0.037004947662353516
# Outputting fields to e.k11.b01.z.tm.h5...
# Outputting fields to e.k11.b02.z.tm.h5...
# Outputting fields to e.k11.b03.z.tm.h5...
# Outputting fields to e.k11.b04.z.tm.h5...
# Outputting fields to e.k11.b05.z.tm.h5...
# Outputting fields to e.k11.b06.z.tm.h5...
# Outputting fields to e.k11.b07.z.tm.h5...
# Outputting fields to e.k11.b08.z.tm.h5...
# solve_kpoint (0.4,0.4,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.126323580077038 (1.11567% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 4.089033099217453 (0.907824% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 4.060561725856448 (0.698719% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.05005274748801 (0.259141% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.04716920700151 (0.071223% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.046718796939656 (0.0111296% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.046656935610447 (0.00152869% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.046652820456806 (0.000101693% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.04665239965133 (1.03989e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.046652261454692 (3.41509e-06% change)
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 12, 0.4, 0.4, 0, 0.565685, 0.27141, 0.485365, 0.501693, 0.689111, 0.830636, 0.844978, 0.893706, 0.898991
# elapsed time for k point: 0.030748605728149414
# Outputting fields to e.k12.b01.z.tm.h5...
# Outputting fields to e.k12.b02.z.tm.h5...
# Outputting fields to e.k12.b03.z.tm.h5...
# Outputting fields to e.k12.b04.z.tm.h5...
# Outputting fields to e.k12.b05.z.tm.h5...
# Outputting fields to e.k12.b06.z.tm.h5...
# Outputting fields to e.k12.b07.z.tm.h5...
# Outputting fields to e.k12.b08.z.tm.h5...
# solve_kpoint (0.3,0.3,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.05014586872208 (0.874825% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.045158295823573 (0.123221% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.044571707226599 (0.0145021% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.044525080406675 (0.00115283% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.044514974554709 (0.000249865% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.044513398010213 (3.89798e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.044513255723245 (3.51802e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, 0.3, 0.3, 0, 0.424264, 0.236529, 0.473888, 0.515941, 0.679199, 0.819377, 0.829518, 0.897603, 0.933446
# elapsed time for k point: 0.0252382755279541
# Outputting fields to e.k13.b01.z.tm.h5...
# Outputting fields to e.k13.b02.z.tm.h5...
# Outputting fields to e.k13.b03.z.tm.h5...
# Outputting fields to e.k13.b04.z.tm.h5...
# Outputting fields to e.k13.b05.z.tm.h5...
# Outputting fields to e.k13.b06.z.tm.h5...
# Outputting fields to e.k13.b07.z.tm.h5...
# Outputting fields to e.k13.b08.z.tm.h5...
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.118864818068977 (0.847801% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.114001816224571 (0.118136% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.113487122546013 (0.0125116% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.113430168771871 (0.00138457% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.113416440845812 (0.000333735% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.113415367538882 (2.60928e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.1134152710184 (2.34648e-06% change)
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 14, 0.2, 0.2, 0, 0.282843, 0.172884, 0.482973, 0.533242, 0.640233, 0.819202, 0.838111, 0.910409, 0.976551
# elapsed time for k point: 0.02491450309753418
# Outputting fields to e.k14.b01.z.tm.h5...
# Outputting fields to e.k14.b02.z.tm.h5...
# Outputting fields to e.k14.b03.z.tm.h5...
# Outputting fields to e.k14.b04.z.tm.h5...
# Outputting fields to e.k14.b05.z.tm.h5...
# Outputting fields to e.k14.b06.z.tm.h5...
# Outputting fields to e.k14.b07.z.tm.h5...
# Outputting fields to e.k14.b08.z.tm.h5...
# solve_kpoint (0.1,0.1,0):
# Solving for bands 1 to 8...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.250027210007303 (0.91784% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.24231358467024 (0.181661% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.241112275157148 (0.0283213% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.240834106008546 (0.00655909% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.240767170121177 (0.00157838% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.24075312832631 (0.000331115% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.240750094726097 (7.15345e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.240749691475294 (9.50895e-06% change)
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 15, 0.1, 0.1, 0, 0.141421, 0.0904174, 0.510404, 0.546943, 0.593803, 0.81373, 0.851132, 0.935551, 1.02882
# elapsed time for k point: 0.029778480529785156
# Outputting fields to e.k15.b01.z.tm.h5...
# Outputting fields to e.k15.b02.z.tm.h5...
# Outputting fields to e.k15.b03.z.tm.h5...
# Outputting fields to e.k15.b04.z.tm.h5...
# Outputting fields to e.k15.b05.z.tm.h5...
# Outputting fields to e.k15.b06.z.tm.h5...
# Outputting fields to e.k15.b07.z.tm.h5...
# Outputting fields to e.k15.b08.z.tm.h5...
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.407941873235159 (1.14501% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.390607127453769 (0.394036% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.386369581446385 (0.0965605% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.384520392753067 (0.0421665% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.382811564738854 (0.0389817% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 4.380357516140724 (0.0560082% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.377812894463372 (0.0581085% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.375796459632527 (0.0460709% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 4.374248716323692 (0.0353768% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 4.373812438957171 (0.00997426% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.373736295675938 (0.00174091% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.373725632536517 (0.0002438% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.373723713801891 (4.38696e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.373723044393275 (1.53052e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.373722608335686 (9.96994e-06% change)
# Finished solving for bands 2 to 8 after 15 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# elapsed time for k point: 0.04555845260620117
# Outputting fields to e.k16.b01.z.tm.h5...
# Outputting fields to e.k16.b02.z.tm.h5...
# Outputting fields to e.k16.b03.z.tm.h5...
# Outputting fields to e.k16.b04.z.tm.h5...
# Outputting fields to e.k16.b05.z.tm.h5...
# Outputting fields to e.k16.b06.z.tm.h5...
# Outputting fields to e.k16.b07.z.tm.h5...
# Outputting fields to e.k16.b08.z.tm.h5...
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28094795584045873 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.4171142494115706 at Vector3<0.5, 0.0, 0.0> to 0.5460267985034354 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4961974535699281 at Vector3<0.5, 0.5, 0.0> to 0.5576576363777933 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.5520955872374774 at Vector3<0.0, 0.0, 0.0> to 0.7133951517520883 at Vector3<0.5, 0.0, 0.0>
# Band 5 range: 0.7413109658608321 at Vector3<0.5, 0.0, 0.0> to 0.859474108109626 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 0.8295176175038242 at Vector3<0.3, 0.3, 0.0> to 0.8783155718493126 at Vector3<0.5, 0.5, 0.0>
# Band 7 range: 0.8625159058773564 at Vector3<0.5, 0.0, 0.0> to 0.9511074680719058 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8793510958411626 at Vector3<0.5, 0.5, 0.0> to 1.0825931586302648 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.28094795584045873) to band 2 (0.4171142494115706), 39.012653183809086%
# Gap from band 4 (0.7133951517520883) to band 5 (0.7413109658608321), 3.83800051030951%
# total elapsed time for run: 0.8139817714691162
# done
